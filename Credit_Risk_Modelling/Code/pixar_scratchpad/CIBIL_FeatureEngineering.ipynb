# %% [markdown]
# **[dateClosed_lt_PHED](#dateClosed_lt_PHED)** <br>
# **[dateClosed_lt_PHED_CNT](#dateClosed_lt_PHED_CNT)** <br>
# **[ignore_case](#ignore_case)**<br>
# **[currentBalance_sanctionedAmount_NCC_L](#currentBalance_sanctionedAmount_NCC_L)**<br>
# **[util_CC_L](#util_CC_L)**<br>
# **[util_highCredit_CC_L](#util_highCredit_CC_L)**<br>
# **[util_highCredit_CC_A](#util_highCredit_CC_A)**<br>
# **[SancAmt](#SancAmt)**<br>
# **[Secured_CNT_Unsecured_CNT](#Secured_CNT_Unsecured_CNT)**<br>
# **[Loans_Sec_UnsecwoRLCC_L](#Loans_Sec_UnsecwoRLCC_L)**<br>
# **[Disb_Sec_UnsecwoRLCC_L](#Disb_Sec_UnsecwoRLCC_L)**<br>
# **[Bal_Sec_UnsecwoRLCC_L](#Bal_Sec_UnsecwoRLCC_L)**<br>
# **[creditLimit_difference](#creditLimit_difference)**<br>
# **[Mode_SancAmt_Prodwise](#Mode_SancAmt_Prodwise)**<br>
# **[currentBalance_sanctionedAmount_NCC_L_P](#currentBalance_sanctionedAmount_NCC_L_P)**<br>
# **[WtAvg_SancAmt](#WtAvg_SancAmt)**<br>
# **[WtAvg_SancAmt_L](#WtAvg_SancAmt_L)**<br>
# **[WAvg_Cur_Bal_L](#WAvg_Cur_Bal_L)**<br>
# **[DPD_flags_1m](#DPD_flags_1m)**<br>
# **[DPD1M_num](#DPD1M_num)**<br>
# **[DPD_flags_3m](#DPD_flags_3m)**<br>
# **[DPD3M_num](#DPD3M_num)**<br>
# **[DPD_flags_6m](#DPD_flags_6m)**<br>
# **[DPD6M_num](#DPD6M_num)**<br>
# **[DPD_flags_1y](#DPD_flags_1y)**<br>
# **[DPD1Y_num](#DPD1Y_num)**<br>
# **[DPD_flags_2y](#DPD_flags_2y)**<br>
# **[DPD2Y_num](#DPD2Y_num)**<br>
# **[DPD_flags_3y](#DPD_flags_3y)**<br>
# **[DPD3Y_num](#DPD3Y_num)**<br>
# **[STD_flags](#STD_flags)**<br>
# **[STD_num](#STD_num)**<br>
# **[SUB_flags](#SUB_flags)**<br>
# **[SUB_num](#SUB_num)**<br>
# **[DBT_flags](#DBT_flags)**<br>
# **[DBT_num](#DBT_num)**<br>
# **[LOS_flags](#LOS_flags)**<br>
# **[LOS_num](#LOS_num)**<br>
# **[XXX_flags](#XXX_flags)**<br>
# **[XXX_num](#XXX_num)**<br>
# **[SMA_flags](#SMA_flags)**<br>
# **[SMA_num](#SMA_num)**<br>
# **[Ever_DPD_flags](#Ever_DPD_flags)**<br>
# **[Ever_DPD_prod](#Ever_DPD_prod)**<br>
# **[Ever_DPD_Sec_L](#Ever_DPD_Sec_L)**<br>
# **[Ever_DPD_UnsecwoRLCC_L](#Ever_DPD_UnsecwoRLCC_L)**<br>
# **[writeOff_restructured](#writeOff_restructured)**<br>
# **[opened_last_CNT](#opened_last_CNT)**<br>
# **[overdueAmount_sum_P](#overdueAmount_sum_P)**<br>
# **[Overdue_Current](#Overdue_Current)**<br>
# **[Overdue_Disbursed](#Overdue_Disbursed)**<br>
# **[dateClosed_lt_PHED_wo](#dateClosed_lt_PHED_wo)**<br>
# **[dateClosed_lt_PHED_suit](#dateClosed_lt_PHED_suit)**<br>
# **[dateClosed_lt_PHED_PH1M](#dateClosed_lt_PHED_PH1M)**<br>
# **[dateClosed_lt_PHED_restruct](#dateClosed_lt_PHED_restruct)**<br>

# %%
import numpy as np
import pandas as pd

import datetime as dt
from datetime import date

import time

from dask import delayed

# %%
start_time_nb = time.time()    #You can use time.clock() also

# %%
test_df = pd.read_csv('cibil_test.csv')
#test_df = pd.read_csv('one.csv')
test_df.shape
# Out:
# (6226, 33)

# %%
df = test_df[test_df['bureauName']=='CIBIL']

df.reset_index(drop=True, inplace=True)
#df.head()

# %%
df.shape
# Out:
# (4462, 33)

# %% [raw]
# df.head(10)

# %%
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### Function for checking if the string is number

# %%
def hasNumbers(inputString):
    return any(char.isdigit() for char in inputString)

# %% [markdown]
# ### Filling missing values

# %%
df['paymentHist1'].fillna('missing', inplace=True)
df['paymentHist2'].fillna('missing', inplace=True)

# %% [markdown]
# ### Concatenate payment history strings

# %%
df['paymentHistComp'] = df['paymentHist1'].map(str) + df['paymentHist2'].map(str) 
#df.head()

# %% [markdown]
# ### Function for calculating the month difference

# %%
def diff_month(d1, d2):
    return (d1.year - d2.year) * 12 + d1.month - d2.month

#diff_month(df['loginDate'][0], df['dateReportedAndCertified'][0])

# %% [markdown]
# ### Handling date fields

# %%
df['PHED'] = df['PHED'].apply(lambda x: x if pd.isnull(x) else str(int(x)))
df['PHSD'] = df['PHSD'].apply(lambda x: x if pd.isnull(x) else str(int(x)))
df['dateClosed'] = df['dateClosed'].apply(lambda x: x if pd.isnull(x) else str(int(x)))
df['dateReportedAndCertified'] = df['dateReportedAndCertified'].apply(lambda x: x if pd.isnull(x) else str(int(x)))
df['dateOpenedOrDisbursed'] = df['dateOpenedOrDisbursed'].apply(lambda x: x if pd.isnull(x) else str(int(x)))

#df.head()

# %% [raw]
# df['PHED'] = df['PHED'].apply(lambda x: x if pd.isnull(x) else int(x))
# df['PHSD'] = df['PHSD'].apply(lambda x: x if pd.isnull(x) else int(x))
# df['dateClosed'] = df['dateClosed'].apply(lambda x: x if pd.isnull(x) else int(x))
# df['dateReportedAndCertified'] = df['dateReportedAndCertified'].apply(lambda x: x if pd.isnull(x) else int(x))
# df['dateOpenedOrDisbursed'] = df['dateOpenedOrDisbursed'].apply(lambda x: x if pd.isnull(x) else int(x))
#
# #df.head()

# %%
df['PHED'] = df['PHED'].astype(str).apply(lambda x: x.zfill(8))
df['PHSD'] = df['PHSD'].astype(str).apply(lambda x: x.zfill(8))
df['dateClosed'] = df['dateClosed'].astype(str).apply(lambda x: x.zfill(8))
df['dateReportedAndCertified'] = df['dateReportedAndCertified'].astype(str).apply(lambda x: x.zfill(8))
df['dateOpenedOrDisbursed'] = df['dateOpenedOrDisbursed'].astype(str).apply(lambda x: x.zfill(8))

#df.head()

# %%
df['PHED'] = df['PHED'].apply(lambda x: 'unknown' if x=='00000nan' else dt.datetime.strptime(x,'%d%m%Y'))
df['PHSD'] = df['PHSD'].apply(lambda x: 'unknown' if x=='00000nan' else dt.datetime.strptime(x,'%d%m%Y'))
df['dateClosed'] = df['dateClosed'].apply(lambda x: 'unknown' if x=='00000nan' else dt.datetime.strptime(x,'%d%m%Y'))
df['dateReportedAndCertified'] = df['dateReportedAndCertified'].apply(lambda x: 'unknown' if x=='00000nan' else dt.datetime.strptime(x,'%d%m%Y'))
df['dateOpenedOrDisbursed'] = df['dateOpenedOrDisbursed'].apply(lambda x: 'unknown' if x=='00000nan' else dt.datetime.strptime(x,'%d%m%Y'))

#df.head()

# %%
df['PHED'] = pd.to_datetime(df['PHED'],errors='coerce').dt.date
df['PHSD'] = pd.to_datetime(df['PHSD'],errors='coerce').dt.date
df['dateClosed'] = pd.to_datetime(df['dateClosed'],errors='coerce').dt.date
df['dateReportedAndCertified'] = pd.to_datetime(df['dateReportedAndCertified'],errors='coerce').dt.date
df['dateOpenedOrDisbursed'] = pd.to_datetime(df['dateOpenedOrDisbursed'],errors='coerce').dt.date

#df.head()

# %%
df['loginDate'] = df['loginDate'].str.replace('Z','')
df['loginDate'] = df['loginDate'].str.replace('{','')
df['loginDate'] = df['loginDate'].str.replace('}','')
df['loginDate'] = df['loginDate'].str.replace('"','')
df['loginDate'] = df['loginDate'].str.replace('T','')

#df.head(2)

# %%
df['loginDate'] =  pd.to_datetime(df['loginDate'], format='%Y-%m-%d%H:%M:%S.%f')

# %%
df['loginDate'] = pd.to_datetime(df['loginDate'],errors='coerce').dt.date

#df.head(2)

# %% [raw]
# type(df['loginDate'][0])

# %% [raw]
# diff_month(df['loginDate'][0], df['dateReportedAndCertified'][0])

# %% [markdown]
# ### Function for Unique ID list

# %%
#@delayed
def get_unique_values(values):
    unique = []
    for piece in values:
        if piece not in unique:
            unique.append(piece)
    return unique

id_list = list(df['ID'].values)
unq_id_list = get_unique_values(id_list)
#unq_id_list = unq_id_list.compute()

# %%
start_time = time.time()

df2 = pd.DataFrame() 

grp_df = df.groupby('ID')

for x in range(0, len(unq_id_list)):
    grp_slice = grp_df.get_group(unq_id_list[x])
    #print(grp_slice)
    grp_slice.reset_index(drop=True, inplace=True)
    grp_slice.sort_values(by='dateReportedAndCertified', inplace=True, ascending=False)
    grp_slice.reset_index(drop=True, inplace=True)
    #print(grp_slice[['ID','accountType','dateReportedAndCertified','creditLimit']])
    #print(grp_slice[x])

    df2 = df2.append(grp_slice)

print("%s seconds" % (time.time() - start_time))
# Out:
# 5.839976072311401 seconds

# %%
df2.shape
# Out:
# (4462, 34)

# %%
df = df2.copy()
df.reset_index(drop=True, inplace=True)

# %%
df.shape
# Out:
# (4462, 34)

# %% [raw]
# df[['ID','accountType','dateReportedAndCertified','creditLimit']].head(20)

# %% [markdown]
# <a id="dateClosed_lt_PHED"></a>
# ### 1.) Code for dateClosed_lt_PHED -> **Discrep**

# %% [markdown]
# - dateClosed -> This is the date the account was closed. DDMMYYYY <br>
# - PHED -> This is the date of the end of the payment history. DDMMYYYY<br>
# - DateClosed<PaymentHistEndDate

# %% [raw]
# df['dateClosed'][0]

# %%
def numOfDays(date1, date2):
    return (date2-date1).days
     
# Driver program
# YYMMDD
#date1 = date(2018, 12, 13)
#date2 = date(2019, 2, 25)
#print(numOfDays(date1, date2), "days")

# %% [raw]
# ((df.dateClosed - df.PHED)/np.timedelta64(1, 'D'))

# %%
days_diff = list()

for x in range(0, df.shape[0]):
    if pd.isnull(df['dateClosed'][x]) or pd.isnull(df['PHED'][x]):
        days_diff.append('unknown')
    else:
        date1 = df['PHED'][x]
        date2 = df['dateClosed'][x]      
        days_diff.append(numOfDays(date1, date2))                                         

df['days_diff'] = pd.Series(days_diff).values

# %%
dateClosed_lt_PHED = list()

for x in range(0, df.shape[0]):
    if pd.isnull(df['dateClosed'][x]) or pd.isnull(df['PHED'][x]):
        dateClosed_lt_PHED.append('unknown')
    elif (df['days_diff'][x]>=0):
        dateClosed_lt_PHED.append(0)
    else:
        dateClosed_lt_PHED.append(1)

df['dateClosed_lt_PHED'] = pd.Series(dateClosed_lt_PHED).values

df.drop(['days_diff'], axis=1, inplace=True)

# %% [raw]
# df['dateClosed_lt_PHED'].value_counts()

# %% [raw]
# df.head()

# %%
def group_slice(df):
    grp_df = df.groupby('ID')
    for x in range(0, len(unq_id_list)):
        grp_slice = grp_df.get_group(unq_id_list[x])
        #print(grp_slice)
        grp_slice.reset_index(drop=True, inplace=True)
        return [grp_slice,x]

# %% [markdown]
# <a id='dateClosed_lt_PHED_CNT'></a>
# ### 2.) Code for dateClosed_lt_PHED_CNT

# %% [markdown]
# Indicates count of accounts where Date Closed for the application is < PaymenT History End Date <br>
# Sum(dateClosed_lt_PHED) for the application

# %%
df['dateClosed_lt_PHED_CNT'] = np.ones(df.shape[0])

# %%
dateClosed_lt_PHED_CNT = list()
count_list = list()
count = 0

for i in range(0, group_slice(df)[0].shape[0]):
    grp_slice_list = group_slice(df)
    #print(grp_slice_list[0])
    if (grp_slice_list[0]['dateClosed_lt_PHED'][i]==1) or (grp_slice_list[0]['dateClosed_lt_PHED'][i]==0):
        count = count + grp_slice_list[0]['dateClosed_lt_PHED'][i]
    else:
        continue
        
count_list.append(count)
count = 0

for i in range(0, grp_slice_list[0].shape[0]):
    if (grp_slice_list[0]['dateClosed_lt_PHED'][i]==1) or (grp_slice_list[0]['dateClosed_lt_PHED'][i]==0):
        dateClosed_lt_PHED_CNT.append(count_list[grp_slice_list[1]])
    else:
        dateClosed_lt_PHED_CNT.append('unknown')

print(dateClosed_lt_PHED_CNT)
            
#df['dateClosed_lt_PHED_CNT'] = dateClosed_lt_PHED_CNT
# Out:
# [0]

# %%
dateClosed_lt_PHED_CNT = list()
count_list = list()
count = 0

grp_df = df.groupby('ID')

for x in range(0, len(unq_id_list)):
    grp_slice = grp_df.get_group(unq_id_list[x])
    #print(grp_slice)
    grp_slice.reset_index(drop=True, inplace=True)
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['dateClosed_lt_PHED'][i]==1) or (grp_slice['dateClosed_lt_PHED'][i]==0):
            count = count + grp_slice['dateClosed_lt_PHED'][i]
        else:
            continue
    count_list.append(count)
    count = 0
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['dateClosed_lt_PHED'][i]==1) or (grp_slice['dateClosed_lt_PHED'][i]==0):
            dateClosed_lt_PHED_CNT.append(count_list[x])
        else:
            dateClosed_lt_PHED_CNT.append('unknown')
            
df['dateClosed_lt_PHED_CNT'] = pd.Series(dateClosed_lt_PHED_CNT).values

# %%
df['dateClosed_lt_PHED_CNT'].value_counts()
# Out:
# 0          1843
# unknown    1736
# 1           341
# 3           224
# 2           135
# 7            94
# 4            89
# Name: dateClosed_lt_PHED_CNT, dtype: int64

# %% [raw]
# df[df['ID']=='3004CD0129020']

# %% [markdown]
# <a id='ignore_case'></a>
# ### Code for ignore_case

# %% [markdown]
# - Indicates whether Date Closed for the account is < PaymenT History End Date but Payment History fields comprise only 'XXX'
# - DateClosed<PaymentHistEndDate where PaymentHist Fields contain only 'XXX'

# %%
piece = list()
ign_case = list()

for x in range(0, df.shape[0]):
    if df['paymentHist1'][x] == 'missing': #df[df['paymentHist1']=='missing']['paymentHist2'].value_counts()
        ign_case.append('unknown')
    elif df['paymentHist2'][x] == 'missing':
        if len(set(df['paymentHist1'][x]))==1 and (list(set(df['paymentHist1'][x]))[0] == 'X') and (df['dateClosed_lt_PHED'][x]==1):
            ign_case.append(1)
        else:
            ign_case.append(0)
    elif len(set(df['paymentHistComp'][x]))==1 and (list(set(df['paymentHistComp'][x]))[0] == 'X') and (df['dateClosed_lt_PHED'][x]==1):
        ign_case.append(1)
    else:
        ign_case.append(0)
    
df['ignore_case'] = pd.Series(ign_case).values

# %% [raw]
# a = df[['ID','paymentHistComp','dateClosed_lt_PHED','ignore_case']]
# a[a['ignore_case']==1]

# %% [raw]
# df['ignore_case'].value_counts()

# %% [markdown]
# ### payHistComp

# %%
piece = list()
comp_list = list()

for value in df['paymentHistComp']:
    #print(value)
    
    chunks, chunk_size = len(value), 3
    for i in range(0, chunks, chunk_size):
        piece.append(value[i:i+chunk_size])
    comp_list.append(piece)
    piece = list()
df['payHistComp'] = pd.Series(comp_list).values
    
#df[['paymentHistComp','payHistComp']]

# %% [markdown]
# ### Code for ignore_case_CNT

# %% [markdown]
# Indicates count of accounts where Date Closed for the application is < PaymenT History End Date but Payment History fields comprise only 'XXX' <br>
# Sum(ignore_case) for the application

# %%
ignore_case_CNT = list()
count_list = list()
count = 0

grp_df = df.groupby('ID')

for x in range(0, len(unq_id_list)):
    grp_slice = grp_df.get_group(unq_id_list[x])
    #print(grp_slice)
    grp_slice.reset_index(drop=True, inplace=True)
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['ignore_case'][i]==1) or (grp_slice['ignore_case'][i]==0):
            count = count + grp_slice['ignore_case'][i]
        else:
            continue
    count_list.append(count)
    count = 0
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['ignore_case'][i]==1) or (grp_slice['ignore_case'][i]==0):
            ignore_case_CNT.append(count_list[x])
        else:
            ignore_case_CNT.append('unknown')
            
df['ignore_case_CNT'] = pd.Series(ignore_case_CNT).values

# %% [raw]
# df['ignore_case_CNT'].value_counts()

# %% [raw]
# df[df['ignore_case_CNT']==1]

# %% [raw]
# df[df['ID']=='25288000638']

# %% [markdown]
# <a id='currentBalance_sanctionedAmount_NCC_L'></a>
# ### Code for currentBalance_sanctionedAmount_NCC_L

# %% [markdown]
# - Ratio of current balance to total amount sanctioned for all the live accounts (other than credit cards)
# - For an applicant for all the accounts other than credit card (account type=10,35,36) where DateClosed is null and current balance>0, ratio of sum(current balance)/ sum(sanctioned amount)

# %% [markdown]
# **High
# Credit/Sanctioned
# Amount** -> For Credit Card (Account Type 10), Fleet
# Card (Account Type 16), Secured Credit
# Card (Account Type 31) and Corporate
# Credit Card (Account Type 35), this field
# contains the highest amount of credit
# used in the history of the account.
# For all other accounts, this field contains
# the amount of loan sanctioned.

# %% [markdown]
# **Current Balance** -> The entire amount of credit/loan,
# including the current and overdue portion,
# if any, outstanding as of the date in the
# Date Reported and Certified field. This is
# inclusive of interest for Credit Cards
# (Account Type = 10), but for the other
# Account Types, this is exclusive of
# interest.

# %% [raw]
# df['accountType'].value_counts()

# %%
df['dateClosed'].fillna('unknown', inplace=True)
df['currentBalance'].fillna('unknown', inplace=True)
df['sanctionAmount'].fillna('unknown', inplace=True)
df['creditLimit'].fillna('unknown', inplace=True)
#df['dateClosed'].value_counts()

# %%
sumCurrentBalance = list()
sumSanctionAmount = list()

sum_cur_bal = list()
sum_sanc_amt = list()

curr_bal = 0
sanc_amt = 0

grp_df = df.groupby('ID')

for x in range(0, len(unq_id_list)):
    grp_slice = grp_df.get_group(unq_id_list[x])
    #print(grp_slice)
    grp_slice.reset_index(drop=True, inplace=True)
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['currentBalance'][i]=='unknown') or (grp_slice['sanctionAmount'][i]=='unknown'):
            continue
        else:
            curr_bal = curr_bal + float(grp_slice['currentBalance'][i])
            sanc_amt = sanc_amt + float(grp_slice['sanctionAmount'][i])
    
    sum_cur_bal.append(curr_bal)
    sum_sanc_amt.append(sanc_amt)
    
    curr_bal = 0
    sanc_amt = 0
    
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['currentBalance'][i]=='unknown') and (grp_slice['sanctionAmount'][i]=='unknown'):
            sumCurrentBalance.append('unknown')
            sumSanctionAmount.append('unknown')
        else:
            sumCurrentBalance.append(sum_cur_bal[x])
            sumSanctionAmount.append(sum_sanc_amt[x])
            
df['sumCurrentBalance'] = pd.Series(sumCurrentBalance).values
df['sumSanctionAmount'] = pd.Series(sumSanctionAmount).values

# %% [raw]
# df[['ID','currentBalance','sumCurrentBalance','sanctionAmount','sumSanctionAmount','creditLimit']].head(60)

# %%
currentBalance_sanctionedAmount_NCC_L = list()
ratio_list = list()
ratio = 0

grp_df = df.groupby('ID')

for x in range(0, len(unq_id_list)):
    grp_slice = grp_df.get_group(unq_id_list[x])
    #print(grp_slice)
    grp_slice.reset_index(drop=True, inplace=True)
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['dateClosed'][i]!='unknown') or (grp_slice['currentBalance'][i]=='unknown') or (grp_slice['sumSanctionAmount'][i]==0) or (grp_slice['sanctionAmount'][i]==0) or (grp_slice['currentBalance'][i]=='unknown'):
            continue
        else:
            ratio = float(grp_slice['sumCurrentBalance'][i])/float(grp_slice['sumSanctionAmount'][i])
            
    ratio_list.append(ratio)
    ratio = 0
    
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['dateClosed'][i]!='unknown') or (grp_slice['accountType'][i]==10) or (grp_slice['accountType'][i]==35) or (grp_slice['accountType'][i]=='36') or (grp_slice['currentBalance'][i]=='unknown'):
            currentBalance_sanctionedAmount_NCC_L.append('unknown')
        else:
            currentBalance_sanctionedAmount_NCC_L.append(ratio_list[x])
            
df['currentBalance_sanctionedAmount_NCC_L'] = pd.Series(currentBalance_sanctionedAmount_NCC_L).values

# %% [raw]
# df[['ID','currentBalance','sumCurrentBalance','sanctionAmount','sumSanctionAmount','currentBalance_sanctionedAmount_NCC_L','dateClosed','accountType']].head(10)

# %% [markdown]
# <a id='util_CC_L'></a>
# ### Code for util_CC_L

# %% [markdown]
# - Indicates Total Credit Card Utilization
# - For an applicant, for account type =10 (Prod =Credit Card) where DateClosed is null, sum(Current Balance)/sum(Credit Limit)

# %% [markdown]
# **Credit Limit /
# High Credit /
# Sanctioned
# Amount** -> This field contains the sum of all the
# amounts of loan sanctioned.
# For Credit Card and Fleet Card, this field
# contains the highest amount of credit used
# in the history of the account. For all other
# accounts, this field contains the amount of
# loan sanctioned.
# Credit Limit /
# High Credit /
# Sanctioned
# Amount
# N
# Credit Limit will take precedence over High
# Credit/Sanctioned Amount when both
# amounts provided in the account.

# %%
sumCurrentBalance = list()
sumCreditLimit = list()

sum_cur_bal = list()
sum_cred_lmt = list()

curr_bal = 0
cred_lmt = 0

grp_df = df.groupby('ID')

for x in range(0, len(unq_id_list)):
    grp_slice = grp_df.get_group(unq_id_list[x])
    #print(grp_slice)
    grp_slice.reset_index(drop=True, inplace=True)
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['currentBalance'][i]=='unknown') or (grp_slice['creditLimit'][i]=='unknown'):
            continue
        else:
            curr_bal = curr_bal + float(grp_slice['currentBalance'][i])
            cred_lmt = cred_lmt + float(grp_slice['creditLimit'][i])
    
    sum_cur_bal.append(curr_bal)
    sum_cred_lmt.append(cred_lmt)
    
    curr_bal = 0
    cred_lmt = 0
    
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['currentBalance'][i]=='unknown') and (grp_slice['creditLimit'][i]=='unknown'):
            sumCurrentBalance.append('unknown')
            sumCreditLimit.append('unknown')
        else:
            sumCurrentBalance.append(sum_cur_bal[x])
            sumCreditLimit.append(sum_cred_lmt[x])
            
df['sumCurrentBalance'] = pd.Series(sumCurrentBalance).values
df['sumCreditLimit'] = pd.Series(sumCreditLimit).values

# %%
util_CC_L = list()
ratio_list = list()
ratio = 0

grp_df = df.groupby('ID')

for x in range(0, len(unq_id_list)):
    grp_slice = grp_df.get_group(unq_id_list[x])
    #print(grp_slice)
    grp_slice.reset_index(drop=True, inplace=True)
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['dateClosed'][i]!='unknown') or (grp_slice['accountType'][i]!=10) or (grp_slice['sumCreditLimit'][i]==0):
            continue
        else:
            ratio = float(grp_slice['sumCurrentBalance'][i])/float(grp_slice['sumCreditLimit'][i])
    
    ratio_list.append(ratio)
    ratio = 0
    
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['dateClosed'][i]!='unknown') or (grp_slice['accountType'][i]!=10) or (grp_slice['sumCreditLimit'][i]==0):
            util_CC_L.append('unknown')
        else:
            util_CC_L.append(ratio_list[x])
            
df['util_CC_L'] = pd.Series(util_CC_L).values

# %% [raw]
# a = df[['ID','util_CC_L','dateClosed','accountType','sumCurrentBalance','sumCreditLimit']]
# a[a['accountType']==10].head(60)

# %% [markdown]
# ### Code for mean_util_CC_L

# %% [markdown]
# - Indicates average utilization per live credit card
# - For an applicant, for account type =10 (Prod =Credit Card) where DateClosed is null, average((Current Balance)/(Credit Limit))

# %% [raw]
# curr_bal = list()
# curr_bal_list = list()
#
# cred_lmt = list()
# cred_lmt_list = list()
#
# grp_df = df.groupby('ID')
#
# for x in range(0, len(unq_id_list)):
#     grp_slice = grp_df.get_group(unq_id_list[x])
#     #print(grp_slice)
#     grp_slice.reset_index(drop=True, inplace=True)
#     #print(grp_slice.shape[0])
#     for i in range(0, grp_slice.shape[0]):
#         if (grp_slice['dateClosed'][i]!='unknown') or (grp_slice['accountType'][i]!=10) or (grp_slice['creditLimit'][i]==0) or (grp_slice['sanctionAmount'][i]=='unknown') or (grp_slice['creditLimit'][i]=='unknown'):
#             continue
#         else:
#             curr_bal.append(grp_slice['currentBalance'][i])
#             cred_lmt.append(grp_slice['creditLimit'][i])
#
#     curr_bal_list.append(curr_bal)
#     cred_lmt_list.append(cred_lmt)
#
#     curr_bal = list()
#     cred_lmt = list()
#
# print(curr_bal_list[9])
# print(cred_lmt_list[9])
# #print(len(curr_bal_list))

# %%
mean_util_CC_L = list()
ratio_list = list()
ratio = list()

grp_df = df.groupby('ID')

for x in range(0, len(unq_id_list)):
    grp_slice = grp_df.get_group(unq_id_list[x])
    #print(grp_slice)
    grp_slice.reset_index(drop=True, inplace=True)
    #print(grp_slice.shape[0])
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['dateClosed'][i]!='unknown') or (grp_slice['accountType'][i]!=10) or (grp_slice['creditLimit'][i]==0) or (grp_slice['currentBalance'][i]=='unknown') or (grp_slice['creditLimit'][i]=='unknown'):
            continue
        else:
            ratio.append(float(grp_slice['currentBalance'][i])/float(grp_slice['creditLimit'][i]))
    
    ratio_list.append(ratio)
    ratio = list()
    
#print(ratio_list)
#print(len(ratio_list))

    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['dateClosed'][i]!='unknown') or (grp_slice['accountType'][i]!=10) or (grp_slice['creditLimit'][i]==0) or (grp_slice['currentBalance'][i]=='unknown') or (grp_slice['creditLimit'][i]=='unknown'):
            mean_util_CC_L.append('unknown')
        else:
            mean_util_CC_L.append(np.mean(ratio_list[x]))
            
df['mean_util_CC_L'] = pd.Series(mean_util_CC_L).values

# %% [raw]
# d = df[['ID','mean_util_CC_L','dateClosed','accountType','currentBalance','creditLimit']]
# d[d['accountType']==10].head(50)

# %% [markdown]
# ### Code for mode_util_CC_L

# %% [markdown]
# - Indicates maximum utilization per live credit card
# - For an applicant, for account type =10 (Prod =Credit Card) where DateClosed is null, max((Current Balance)/(Credit Limit))

# %%
mode_util_CC_L = list()
ratio_list = list()
ratio = list()

grp_df = df.groupby('ID')

for x in range(0, len(unq_id_list)):
    grp_slice = grp_df.get_group(unq_id_list[x])
    #print(grp_slice)
    grp_slice.reset_index(drop=True, inplace=True)
    #print(grp_slice.shape[0])
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['dateClosed'][i]!='unknown') or (grp_slice['accountType'][i]!=10) or (grp_slice['creditLimit'][i]==0) or (grp_slice['currentBalance'][i]=='unknown') or (grp_slice['creditLimit'][i]=='unknown'):
            continue
        else:
            ratio.append(float(grp_slice['currentBalance'][i])/float(grp_slice['creditLimit'][i]))
    
    ratio_list.append(ratio)
    ratio = list()
    
#print(ratio_list)
#print(len(ratio_list))

    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['dateClosed'][i]!='unknown') or (grp_slice['accountType'][i]!=10) or (grp_slice['creditLimit'][i]==0) or (grp_slice['currentBalance'][i]=='unknown') or (grp_slice['creditLimit'][i]=='unknown'):
            mode_util_CC_L.append('unknown')
        else:
            mode_util_CC_L.append(np.max(ratio_list[x]))
            
df['mode_util_CC_L'] = pd.Series(mode_util_CC_L).values

# %% [raw]
# d = df[['ID','mode_util_CC_L','dateClosed','accountType','currentBalance','creditLimit']]
# d[d['accountType']==10].head(50)

# %% [markdown]
# ### Code for median_util_CC_L

# %% [markdown]
# - Indicates median utilization per live credit card
# - For an applicant, for account type =10 (Prod =Credit Card) where DateClosed is null, median((Current Balance)/(Credit Limit))

# %%
median_util_CC_L = list()
ratio_list = list()
ratio = list()

grp_df = df.groupby('ID')

for x in range(0, len(unq_id_list)):
    grp_slice = grp_df.get_group(unq_id_list[x])
    #print(grp_slice)
    grp_slice.reset_index(drop=True, inplace=True)
    #print(grp_slice.shape[0])
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['dateClosed'][i]!='unknown') or (grp_slice['accountType'][i]!=10) or (grp_slice['creditLimit'][i]==0) or (grp_slice['currentBalance'][i]=='unknown') or (grp_slice['creditLimit'][i]=='unknown'):
            continue
        else:
            ratio.append(float(grp_slice['currentBalance'][i])/float(grp_slice['creditLimit'][i]))
    
    ratio_list.append(ratio)
    ratio = list()
    
#print(ratio_list)
#print(len(ratio_list))

    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['dateClosed'][i]!='unknown') or (grp_slice['accountType'][i]!=10) or (grp_slice['creditLimit'][i]==0) or (grp_slice['currentBalance'][i]=='unknown') or (grp_slice['creditLimit'][i]=='unknown'):
            median_util_CC_L.append('unknown')
        else:
            median_util_CC_L.append(np.median(ratio_list[x]))
            
df['median_util_CC_L'] = pd.Series(median_util_CC_L).values

# %% [raw]
# d = df[['ID','median_util_CC_L','dateClosed','accountType','currentBalance','creditLimit']]
# d[d['accountType']==10].head(50)

# %% [markdown]
# ### Code for min_util_CC_L

# %% [markdown]
# - Indicates minimum utilization per live credit card
# - For an applicant, for account type =10 (Prod =Credit Card) where DateClosed is null, min((Current Balance)/(Credit Limit))

# %%
min_util_CC_L = list()
ratio_list = list()
ratio = list()

grp_df = df.groupby('ID')

for x in range(0, len(unq_id_list)):
    grp_slice = grp_df.get_group(unq_id_list[x])
    #print(grp_slice)
    grp_slice.reset_index(drop=True, inplace=True)
    #print(grp_slice.shape[0])
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['dateClosed'][i]!='unknown') or (grp_slice['accountType'][i]!=10) or (grp_slice['creditLimit'][i]==0) or (grp_slice['currentBalance'][i]=='unknown') or (grp_slice['creditLimit'][i]=='unknown'):
            continue
        else:
            ratio.append(float(grp_slice['currentBalance'][i])/float(grp_slice['creditLimit'][i]))
    
    ratio_list.append(ratio)
    ratio = list()
    
#print(ratio_list)
#print(len(ratio_list))

    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['dateClosed'][i]!='unknown') or (grp_slice['accountType'][i]!=10) or (grp_slice['creditLimit'][i]==0) or (grp_slice['currentBalance'][i]=='unknown') or (grp_slice['creditLimit'][i]=='unknown'):
            min_util_CC_L.append('unknown')
        else:
            min_util_CC_L.append(np.min(ratio_list[x]))
            
df['min_util_CC_L'] = pd.Series(min_util_CC_L).values

# %% [raw]
# d = df[['ID','min_util_CC_L','dateClosed','accountType','currentBalance','creditLimit']]
# d[d['accountType']==10].head(50)

# %% [markdown]
# <a id='util_highCredit_CC_L'></a>
# ### Code for util_highCredit_CC_L

# %% [markdown]
# - Indicates Total Credit Card Highest Utilization till date
# - For an applicant, for account type =10 (Prod =Credit Card) where DateClosed is null, sum(HighCredit/Sanc Amount)/sum(Credit Limit)

# %%
util_highCredit_CC_L = list()
ratio_list = list()
ratio = 0

grp_df = df.groupby('ID')

for x in range(0, len(unq_id_list)):
    grp_slice = grp_df.get_group(unq_id_list[x])
    #print(grp_slice)
    grp_slice.reset_index(drop=True, inplace=True)
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['dateClosed'][i]!='unknown') or (grp_slice['accountType'][i]!=10) or (grp_slice['sumCreditLimit'][i]==0):
            continue
        else:
            ratio = float(grp_slice['sumSanctionAmount'][i])/float(grp_slice['sumCreditLimit'][i])
    
    ratio_list.append(ratio)
    ratio = 0
    
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['dateClosed'][i]!='unknown') or (grp_slice['accountType'][i]!=10) or (grp_slice['sumCreditLimit'][i]==0):
            util_highCredit_CC_L.append('unknown')
        else:
            util_highCredit_CC_L.append(ratio_list[x])
            
df['util_highCredit_CC_L'] = pd.Series(util_highCredit_CC_L).values

# %% [raw]
# a = df[['ID','util_highCredit_CC_L','dateClosed','accountType','sumSanctionAmount','sumCreditLimit']]
# a[a['accountType']==10].head(60)

# %% [markdown]
# ### Code for mean_util_highCredit_CC_L

# %% [markdown]
# - Indicates average highest utilization per live credit card
# - For an applicant, for account type =10 (Prod =Credit Card) where DateClosed is null, average((High Credit or Sanctioned Amount)/(Credit Limit))

# %%
mean_util_highCredit_CC_L = list()
ratio_list = list()
ratio = list()

grp_df = df.groupby('ID')

for x in range(0, len(unq_id_list)):
    grp_slice = grp_df.get_group(unq_id_list[x])
    #print(grp_slice)
    grp_slice.reset_index(drop=True, inplace=True)
    #print(grp_slice.shape[0])
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['dateClosed'][i]!='unknown') or (grp_slice['accountType'][i]!=10) or (grp_slice['creditLimit'][i]==0) or (grp_slice['sanctionAmount'][i]=='unknown') or (grp_slice['creditLimit'][i]=='unknown'):
            continue
        else:
            ratio.append(float(grp_slice['sanctionAmount'][i])/float(grp_slice['creditLimit'][i]))
    
    ratio_list.append(ratio)
    ratio = list()
    
#print(ratio_list)
#print(len(ratio_list))

    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['dateClosed'][i]!='unknown') or (grp_slice['accountType'][i]!=10) or (grp_slice['creditLimit'][i]==0) or (grp_slice['sanctionAmount'][i]=='unknown') or (grp_slice['creditLimit'][i]=='unknown'):
            mean_util_highCredit_CC_L.append('unknown')
        else:
            mean_util_highCredit_CC_L.append(np.mean(ratio_list[x]))
            
df['mean_util_highCredit_CC_L'] = pd.Series(mean_util_highCredit_CC_L).values

# %% [raw]
# d = df[['ID','mean_util_highCredit_CC_L','dateClosed','accountType','sanctionAmount','creditLimit']]
# d[d['accountType']==10].head(50)

# %% [markdown]
# ### Code for mode_util_highCredit_CC_L

# %% [markdown]
# - Indicates maximum highest utilization per live credit card
# - For an applicant, for account type =10 (Prod =Credit Card) where DateClosed is null, max((High Credit or Sanctioned Amount)/(Credit Limit))

# %%
mode_util_highCredit_CC_L = list()
ratio_list = list()
ratio = list()

grp_df = df.groupby('ID')

for x in range(0, len(unq_id_list)):
    grp_slice = grp_df.get_group(unq_id_list[x])
    #print(grp_slice)
    grp_slice.reset_index(drop=True, inplace=True)
    #print(grp_slice.shape[0])
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['dateClosed'][i]!='unknown') or (grp_slice['accountType'][i]!=10) or (grp_slice['creditLimit'][i]==0) or (grp_slice['sanctionAmount'][i]=='unknown') or (grp_slice['creditLimit'][i]=='unknown'):
            continue
        else:
            ratio.append(float(grp_slice['sanctionAmount'][i])/float(grp_slice['creditLimit'][i]))
    
    ratio_list.append(ratio)
    ratio = list()
    
#print(ratio_list)
#print(len(ratio_list))

    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['dateClosed'][i]!='unknown') or (grp_slice['accountType'][i]!=10) or (grp_slice['creditLimit'][i]==0) or (grp_slice['sanctionAmount'][i]=='unknown') or (grp_slice['creditLimit'][i]=='unknown'):
            mode_util_highCredit_CC_L.append('unknown')
        else:
            mode_util_highCredit_CC_L.append(np.max(ratio_list[x]))
            
df['mode_util_highCredit_CC_L'] = pd.Series(mode_util_highCredit_CC_L).values

# %% [raw]
# d = df[['ID','mode_util_highCredit_CC_L','dateClosed','accountType','sanctionAmount','creditLimit']]
# d[d['accountType']==10].head(50)

# %% [markdown]
# ### Code for median_util_highCredit_CC_L

# %% [markdown]
# - Indicates median utilization per live credit card
# - For an applicant, for account type =10 (Prod =Credit Card) where DateClosed is null, median((High Credit or Sanctioned Amount)/(Credit Limit))

# %%
median_util_highCredit_CC_L = list()
ratio_list = list()
ratio = list()

grp_df = df.groupby('ID')

for x in range(0, len(unq_id_list)):
    grp_slice = grp_df.get_group(unq_id_list[x])
    #print(grp_slice)
    grp_slice.reset_index(drop=True, inplace=True)
    #print(grp_slice.shape[0])
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['dateClosed'][i]!='unknown') or (grp_slice['accountType'][i]!=10) or (grp_slice['creditLimit'][i]==0) or (grp_slice['sanctionAmount'][i]=='unknown') or (grp_slice['creditLimit'][i]=='unknown'):
            continue
        else:
            ratio.append(float(grp_slice['sanctionAmount'][i])/float(grp_slice['creditLimit'][i]))
    
    ratio_list.append(ratio)
    ratio = list()
    
#print(ratio_list)
#print(len(ratio_list))

    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['dateClosed'][i]!='unknown') or (grp_slice['accountType'][i]!=10) or (grp_slice['creditLimit'][i]==0) or (grp_slice['sanctionAmount'][i]=='unknown') or (grp_slice['creditLimit'][i]=='unknown'):
            median_util_highCredit_CC_L.append('unknown')
        else:
            median_util_highCredit_CC_L.append(np.median(ratio_list[x]))
            
df['median_util_highCredit_CC_L'] = pd.Series(median_util_highCredit_CC_L).values

# %% [raw]
# d = df[['ID','median_util_highCredit_CC_L','dateClosed','accountType','sanctionAmount','creditLimit']]
# d[d['accountType']==10].head(50)

# %% [markdown]
# ### Code for min_util_highCredit_CC_L

# %% [markdown]
# - Indicates minimum utilization per live credit card
# - For an applicant, for account type =10 (Prod =Credit Card) where DateClosed is null, min((High Credit or Sanctioned Amount)/(Credit Limit))

# %%
min_util_highCredit_CC_L = list()
ratio_list = list()
ratio = list()

grp_df = df.groupby('ID')

for x in range(0, len(unq_id_list)):
    grp_slice = grp_df.get_group(unq_id_list[x])
    #print(grp_slice)
    grp_slice.reset_index(drop=True, inplace=True)
    #print(grp_slice.shape[0])
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['dateClosed'][i]!='unknown') or (grp_slice['accountType'][i]!=10) or (grp_slice['creditLimit'][i]==0) or (grp_slice['sanctionAmount'][i]=='unknown') or (grp_slice['creditLimit'][i]=='unknown'):
            continue
        else:
            ratio.append(float(grp_slice['sanctionAmount'][i])/float(grp_slice['creditLimit'][i]))
    
    ratio_list.append(ratio)
    ratio = list()
    
#print(ratio_list)
#print(len(ratio_list))

    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['dateClosed'][i]!='unknown') or (grp_slice['accountType'][i]!=10) or (grp_slice['creditLimit'][i]==0) or (grp_slice['sanctionAmount'][i]=='unknown') or (grp_slice['creditLimit'][i]=='unknown'):
            min_util_highCredit_CC_L.append('unknown')
        else:
            min_util_highCredit_CC_L.append(np.min(ratio_list[x]))
            
df['min_util_highCredit_CC_L'] = pd.Series(min_util_highCredit_CC_L).values

# %% [raw]
# d = df[['ID','min_util_highCredit_CC_L','dateClosed','accountType','sanctionAmount','creditLimit']]
# d[d['accountType']==10].head(50)

# %% [markdown]
# <a id='util_highCredit_CC_A'></a>
# ### Code for util_highCredit_CC_A

# %% [markdown]
# - Indicates Total Credit Card Highest Utilization till date for all credit cards
# - For an applicant, for account type =10 (Prod =Credit Card)  sum(HighCredit/Sanc Amount)/sum(Credit Limit)

# %%
util_highCredit_CC_A = list()
ratio_list = list()
ratio = 0

grp_df = df.groupby('ID')

for x in range(0, len(unq_id_list)):
    grp_slice = grp_df.get_group(unq_id_list[x])
    #print(grp_slice)
    grp_slice.reset_index(drop=True, inplace=True)
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['accountType'][i]!=10) or (grp_slice['sumCreditLimit'][i]==0):
            continue
        else:
            ratio = float(grp_slice['sumSanctionAmount'][i])/float(grp_slice['sumCreditLimit'][i])
    
    ratio_list.append(ratio)
    ratio = 0
    
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['accountType'][i]!=10) or (grp_slice['sumCreditLimit'][i]==0):
            util_highCredit_CC_A.append('unknown')
        else:
            util_highCredit_CC_A.append(ratio_list[x])
            
df['util_highCredit_CC_A'] = pd.Series(util_highCredit_CC_A).values

# %% [raw]
# a = df[['ID','util_highCredit_CC_A','dateClosed','accountType','sanctionAmount','sumSanctionAmount','creditLimit','sumCreditLimit']]
# a[a['accountType']==10].head(60)

# %% [markdown]
# ### Code for mean_util_highCredit_CC_A

# %% [markdown]
# - Indicates average highest utilization per all (live+closed) credit card
# - For an applicant, for account type =10 (Prod =Credit Card), average((High Credit or Sanctioned Amount)/(Credit Limit))

# %%
mean_util_highCredit_CC_A = list()
ratio_list = list()
ratio = list()

grp_df = df.groupby('ID')

for x in range(0, len(unq_id_list)):
    grp_slice = grp_df.get_group(unq_id_list[x])
    #print(grp_slice)
    grp_slice.reset_index(drop=True, inplace=True)
    #print(grp_slice.shape[0])
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['accountType'][i]!=10) or (grp_slice['creditLimit'][i]==0) or (grp_slice['sanctionAmount'][i]=='unknown') or (grp_slice['creditLimit'][i]=='unknown'):
            continue
        else:
            ratio.append(float(grp_slice['sanctionAmount'][i])/float(grp_slice['creditLimit'][i]))
    
    ratio_list.append(ratio)
    ratio = list()
    
#print(ratio_list)
#print(len(ratio_list))

    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['accountType'][i]!=10) or (grp_slice['creditLimit'][i]==0) or (grp_slice['sanctionAmount'][i]=='unknown') or (grp_slice['creditLimit'][i]=='unknown'):
            mean_util_highCredit_CC_A.append('unknown')
        else:
            mean_util_highCredit_CC_A.append(np.mean(ratio_list[x]))
            
df['mean_util_highCredit_CC_A'] = pd.Series(mean_util_highCredit_CC_A).values

# %% [raw]
# a = df[['ID','mean_util_highCredit_CC_A','dateClosed','accountType','sanctionAmount','creditLimit']]
# a[a['accountType']==10].head(60)

# %% [markdown]
# ### Code for mode_util_highCredit_CC_A

# %% [markdown]
# - Indicates maximum highest utilization per all (live+closed) credit card
# - For an applicant, for account type =10 (Prod =Credit Card), max((High Credit or Sanctioned Amount)/(Credit Limit))

# %%
mode_util_highCredit_CC_A = list()
ratio_list = list()
ratio = list()

grp_df = df.groupby('ID')

for x in range(0, len(unq_id_list)):
    grp_slice = grp_df.get_group(unq_id_list[x])
    #print(grp_slice)
    grp_slice.reset_index(drop=True, inplace=True)
    #print(grp_slice.shape[0])
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['accountType'][i]!=10) or (grp_slice['creditLimit'][i]==0) or (grp_slice['sanctionAmount'][i]=='unknown') or (grp_slice['creditLimit'][i]=='unknown'):
            continue
        else:
            ratio.append(float(grp_slice['sanctionAmount'][i])/float(grp_slice['creditLimit'][i]))
    
    ratio_list.append(ratio)
    ratio = list()
    
#print(ratio_list)
#print(len(ratio_list))

    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['accountType'][i]!=10) or (grp_slice['creditLimit'][i]==0) or (grp_slice['sanctionAmount'][i]=='unknown') or (grp_slice['creditLimit'][i]=='unknown'):
            mode_util_highCredit_CC_A.append('unknown')
        else:
            mode_util_highCredit_CC_A.append(np.max(ratio_list[x]))
            
df['mode_util_highCredit_CC_A'] = pd.Series(mode_util_highCredit_CC_A).values

# %% [raw]
# a = df[['ID','mode_util_highCredit_CC_A','dateClosed','accountType','sanctionAmount','creditLimit']]
# a[a['accountType']==10].head(60)

# %% [markdown]
# ### Code for median_util_highCredit_CC_A

# %% [markdown]
# - Indicates median utilization per all (live+closed) credit card
# - For an applicant, for account type =10 (Prod =Credit Card), median((High Credit or Sanctioned Amount)/(Credit Limit))

# %%
median_util_highCredit_CC_A = list()
ratio_list = list()
ratio = list()

grp_df = df.groupby('ID')

for x in range(0, len(unq_id_list)):
    grp_slice = grp_df.get_group(unq_id_list[x])
    #print(grp_slice)
    grp_slice.reset_index(drop=True, inplace=True)
    #print(grp_slice.shape[0])
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['accountType'][i]!=10) or (grp_slice['creditLimit'][i]==0) or (grp_slice['sanctionAmount'][i]=='unknown') or (grp_slice['creditLimit'][i]=='unknown'):
            continue
        else:
            ratio.append(float(grp_slice['sanctionAmount'][i])/float(grp_slice['creditLimit'][i]))
    
    ratio_list.append(ratio)
    ratio = list()
    
#print(ratio_list)
#print(len(ratio_list))

    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['accountType'][i]!=10) or (grp_slice['creditLimit'][i]==0) or (grp_slice['sanctionAmount'][i]=='unknown') or (grp_slice['creditLimit'][i]=='unknown'):
            median_util_highCredit_CC_A.append('unknown')
        else:
            median_util_highCredit_CC_A.append(np.median(ratio_list[x]))
            
df['median_util_highCredit_CC_A'] = pd.Series(median_util_highCredit_CC_A).values

# %% [raw]
# a = df[['ID','median_util_highCredit_CC_A','dateClosed','accountType','sanctionAmount','creditLimit']]
# a[a['accountType']==10].head(60)

# %% [markdown]
# ### Code for min_util_highCredit_CC_A

# %% [markdown]
# - Indicates minimum utilization per all (live+closed) credit card
# - For an applicant, for account type =10 (Prod =Credit Card), min((High Credit or Sanctioned Amount)/(Credit Limit))

# %%
min_util_highCredit_CC_A = list()
ratio_list = list()
ratio = list()

grp_df = df.groupby('ID')

for x in range(0, len(unq_id_list)):
    grp_slice = grp_df.get_group(unq_id_list[x])
    #print(grp_slice)
    grp_slice.reset_index(drop=True, inplace=True)
    #print(grp_slice.shape[0])
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['accountType'][i]!=10) or (grp_slice['creditLimit'][i]==0) or (grp_slice['sanctionAmount'][i]=='unknown') or (grp_slice['creditLimit'][i]=='unknown'):
            continue
        else:
            ratio.append(float(grp_slice['sanctionAmount'][i])/float(grp_slice['creditLimit'][i]))
    
    ratio_list.append(ratio)
    ratio = list()
    
#print(ratio_list)
#print(len(ratio_list))

    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['accountType'][i]!=10) or (grp_slice['creditLimit'][i]==0) or (grp_slice['sanctionAmount'][i]=='unknown') or (grp_slice['creditLimit'][i]=='unknown'):
            min_util_highCredit_CC_A.append('unknown')
        else:
            min_util_highCredit_CC_A.append(np.median(ratio_list[x]))
            
df['min_util_highCredit_CC_A'] = pd.Series(min_util_highCredit_CC_A).values

# %% [raw]
# a = df[['ID','min_util_highCredit_CC_A','dateClosed','accountType','sanctionAmount','creditLimit']]
# a[a['accountType']==10].head(60)

# %% [markdown]
# <a id='SancAmt'></a>
# ### Code for Mean_SancAmt

# %% [markdown]
# - Indicates the total average sanctioned amount (excluding account types - 10,35,36)
# - For an applicant,  (excluding account types - 10,35,36), compute the average of sanctioned amount for the loans

# %%
Mean_SancAmt = list()
sanc_amt_list = list()
sanc_amt = list()

grp_df = df.groupby('ID')

for x in range(0, len(unq_id_list)):
    grp_slice = grp_df.get_group(unq_id_list[x])
    #print(grp_slice)
    grp_slice.reset_index(drop=True, inplace=True)
    #print(grp_slice.shape[0])
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['accountType'][i]==10) or (grp_slice['accountType'][i]==35) or (grp_slice['accountType'][i]==36) or (grp_slice['sanctionAmount'][i]=='unknown'):
            continue
        else:
            sanc_amt.append(float(grp_slice['sanctionAmount'][i]))
                            
    sanc_amt_list.append(sanc_amt)
    sanc_amt = list()

    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['accountType'][i]==10) or (grp_slice['accountType'][i]==35) or (grp_slice['accountType'][i]==36) or (grp_slice['sanctionAmount'][i]=='unknown'):
            Mean_SancAmt.append('unknown')
        else:
            Mean_SancAmt.append(np.mean(sanc_amt_list[x]))
            
df['Mean_SancAmt'] = pd.Series(Mean_SancAmt).values

# %% [raw]
# a = df[['ID','Mean_SancAmt','accountType','sanctionAmount']]
# a.head(60)

# %% [markdown]
# ### Code for Mean_SancAmt_L

# %% [markdown]
# - Indicates the total average sanctioned amount for all the live products(excluding account types - 10,35,36)
# - For an applicant,  (excluding account types - 10,35,36), compute the average of sanctioned amount for the loans where dateClosed is null

# %%
Mean_SancAmt_L = list()
sanc_amt_list = list()
sanc_amt = list()

grp_df = df.groupby('ID')

for x in range(0, len(unq_id_list)):
    grp_slice = grp_df.get_group(unq_id_list[x])
    #print(grp_slice)
    grp_slice.reset_index(drop=True, inplace=True)
    #print(grp_slice.shape[0])
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['dateClosed'][i]!='unknown') or (grp_slice['accountType'][i]==10) or (grp_slice['accountType'][i]==35) or (grp_slice['accountType'][i]==36) or (grp_slice['sanctionAmount'][i]=='unknown'):
            continue
        else:
            sanc_amt.append(float(grp_slice['sanctionAmount'][i]))
                            
    sanc_amt_list.append(sanc_amt)
    sanc_amt = list()

    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['dateClosed'][i]!='unknown') or (grp_slice['accountType'][i]==10) or (grp_slice['accountType'][i]==35) or (grp_slice['accountType'][i]==36) or (grp_slice['sanctionAmount'][i]=='unknown'):
            Mean_SancAmt_L.append('unknown')
        else:
            Mean_SancAmt_L.append(np.mean(sanc_amt_list[x]))
            
df['Mean_SancAmt_L'] = pd.Series(Mean_SancAmt_L).values

# %% [raw]
# a = df[['ID','Mean_SancAmt_L','dateClosed','accountType','sanctionAmount']]
# a[a['accountType']!=10].head(60)

# %% [markdown]
# ### Code for Median_SancAmt

# %% [markdown]
# - Indicates the median sanctioned amount (excluding account types - 10,35,36)
# - For an applicant,  (excluding account types - 10,35,36), compute the median of sanctioned amount for the loans

# %%
Median_SancAmt = list()
sanc_amt_list = list()
sanc_amt = list()

grp_df = df.groupby('ID')

for x in range(0, len(unq_id_list)):
    grp_slice = grp_df.get_group(unq_id_list[x])
    #print(grp_slice)
    grp_slice.reset_index(drop=True, inplace=True)
    #print(grp_slice.shape[0])
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['accountType'][i]==10) or (grp_slice['accountType'][i]==35) or (grp_slice['accountType'][i]==36) or (grp_slice['sanctionAmount'][i]=='unknown'):
            continue
        else:
            sanc_amt.append(float(grp_slice['sanctionAmount'][i]))
                            
    sanc_amt_list.append(sanc_amt)
    sanc_amt = list()

    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['accountType'][i]==10) or (grp_slice['accountType'][i]==35) or (grp_slice['accountType'][i]==36) or (grp_slice['sanctionAmount'][i]=='unknown'):
            Median_SancAmt.append('unknown')
        else:
            Median_SancAmt.append(np.median(sanc_amt_list[x]))
            
df['Median_SancAmt'] = pd.Series(Median_SancAmt).values

# %% [raw]
# a = df[['ID','Median_SancAmt','accountType','sanctionAmount']]
# a[a['accountType']!=10].head(60)

# %% [markdown]
# ### Code for Median_SancAmt_L

# %% [markdown]
# - Indicates the median sanctioned amount for all the live products (excluding account types - 10,35,36)
# - For an applicant,  (excluding account types - 10,35,36), compute the median of sanctioned amount for the loans where dateClosed is null

# %%
Median_SancAmt_L = list()
sanc_amt_list = list()
sanc_amt = list()

grp_df = df.groupby('ID')

for x in range(0, len(unq_id_list)):
    grp_slice = grp_df.get_group(unq_id_list[x])
    #print(grp_slice)
    grp_slice.reset_index(drop=True, inplace=True)
    #print(grp_slice.shape[0])
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['dateClosed'][i]!='unknown') or (grp_slice['accountType'][i]==10) or (grp_slice['accountType'][i]==35) or (grp_slice['accountType'][i]==36) or (grp_slice['sanctionAmount'][i]=='unknown'):
            continue
        else:
            sanc_amt.append(float(grp_slice['sanctionAmount'][i]))
                            
    sanc_amt_list.append(sanc_amt)
    sanc_amt = list()

    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['dateClosed'][i]!='unknown') or (grp_slice['accountType'][i]==10) or (grp_slice['accountType'][i]==35) or (grp_slice['accountType'][i]==36) or (grp_slice['sanctionAmount'][i]=='unknown'):
            Median_SancAmt_L.append('unknown')
        else:
            Median_SancAmt_L.append(np.median(sanc_amt_list[x]))
            
df['Median_SancAmt_L'] = pd.Series(Median_SancAmt_L).values

# %% [raw]
# a = df[['ID','Median_SancAmt_L','dateClosed','accountType','sanctionAmount']]
# a[a['accountType']!=10].head(60)

# %% [markdown]
# ### Code for Mode_SancAmt

# %% [markdown]
# - Indicates the maximum sanctioned amount (excluding account types - 10,35,36)
# - For an applicant,  (excluding account types - 10,35,36), compute the mode of sanctioned amount for the loans

# %%
Mode_SancAmt = list()
sanc_amt_list = list()
sanc_amt = list()

grp_df = df.groupby('ID')

for x in range(0, len(unq_id_list)):
    grp_slice = grp_df.get_group(unq_id_list[x])
    #print(grp_slice)
    grp_slice.reset_index(drop=True, inplace=True)
    #print(grp_slice.shape[0])
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['accountType'][i]==10) or (grp_slice['accountType'][i]==35) or (grp_slice['accountType'][i]==36) or (grp_slice['sanctionAmount'][i]=='unknown'):
            continue
        else:
            sanc_amt.append(float(grp_slice['sanctionAmount'][i]))
                            
    sanc_amt_list.append(sanc_amt)
    sanc_amt = list()

    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['accountType'][i]==10) or (grp_slice['accountType'][i]==35) or (grp_slice['accountType'][i]==36) or (grp_slice['sanctionAmount'][i]=='unknown'):
            Mode_SancAmt.append('unknown')
        else:
            Mode_SancAmt.append(np.max(sanc_amt_list[x]))
            
df['Mode_SancAmt'] = pd.Series(Mode_SancAmt).values

# %% [raw]
# a = df[['ID','Mode_SancAmt','accountType','sanctionAmount']]
# a[a['accountType']!=10].head(60)

# %% [markdown]
# ### Code for Mode_SancAmt_L

# %% [markdown]
# - Indicates the maximum sanctioned amount for all the live products (excluding account types - 10,35,36)
# - For an applicant,  (excluding account types - 10,35,36), compute the mode of sanctioned amount for the loans where dateClosed is null

# %%
Mode_SancAmt_L = list()
sanc_amt_list = list()
sanc_amt = list()

grp_df = df.groupby('ID')

for x in range(0, len(unq_id_list)):
    grp_slice = grp_df.get_group(unq_id_list[x])
    #print(grp_slice)
    grp_slice.reset_index(drop=True, inplace=True)
    #print(grp_slice.shape[0])
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['dateClosed'][i]!='unknown') or (grp_slice['accountType'][i]==10) or (grp_slice['accountType'][i]==35) or (grp_slice['accountType'][i]==36) or (grp_slice['sanctionAmount'][i]=='unknown'):
            continue
        else:
            sanc_amt.append(float(grp_slice['sanctionAmount'][i]))
                            
    sanc_amt_list.append(sanc_amt)
    sanc_amt = list()

    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['dateClosed'][i]!='unknown') or (grp_slice['accountType'][i]==10) or (grp_slice['accountType'][i]==35) or (grp_slice['accountType'][i]==36) or (grp_slice['sanctionAmount'][i]=='unknown'):
            Mode_SancAmt_L.append('unknown')
        else:
            Mode_SancAmt_L.append(np.max(sanc_amt_list[x]))
            
df['Mode_SancAmt_L'] = pd.Series(Mode_SancAmt_L).values

# %% [raw]
# a = df[['ID','Mode_SancAmt_L','dateClosed','accountType','sanctionAmount']]
# a[a['accountType']!=10].head(60)

# %% [markdown]
# <a id='Secured_CNT_Unsecured_CNT'></a>
# ### Secured_CNT and  Unsecured_CNT
# - Count of all secured loans for an applicant
#
# - Count of all unsecured loans for an applicant

# %%
Secured_CNT = list()
Unsecured_CNT = list()

sec_L = [0, 1, 2, 3, 4, 7, 11, 13, 15, 16, 17, 31,
         32, 33, 34, 42, 43, 44, 50, 54, 58, 59, 98]
unsec_L = [5, 6, 8, 9, 35, 36, 37, 39, 40, 41, 51, 52, 53, 56, 57, 61, 99]

sec_cnt_list = list()
sec_cnt = 0

unsec_cnt_list = list()
unsec_cnt = 0

grp_df = df.groupby('ID')

for x in range(0, len(unq_id_list)):
    grp_slice = grp_df.get_group(unq_id_list[x])
    # print(grp_slice)
    grp_slice.reset_index(drop=True, inplace=True)
    # print(grp_slice.shape[0])

    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['accountType'][i] in sec_L):
            sec_cnt = sec_cnt + 1
        elif (grp_slice['accountType'][i] in unsec_L):
            unsec_cnt = unsec_cnt + 1
        else:
            continue
    # print(sec_cnt)
    sec_cnt_list.append(sec_cnt)
    sec_cnt = 0

    unsec_cnt_list.append(unsec_cnt)
    unsec_cnt = 0

    for i in range(0, grp_slice.shape[0]):
        if (pd.isnull(grp_slice['accountType'][i])):
            Secured_CNT.append('unknown')
        else:
            Secured_CNT.append(sec_cnt_list[x])

        if (pd.isnull(grp_slice['accountType'][i])):
            Unsecured_CNT.append('unknown')
        else:
            Unsecured_CNT.append(unsec_cnt_list[x])

df['Secured_CNT'] = pd.Series(Secured_CNT).values
df['Unsecured_CNT'] = pd.Series(Unsecured_CNT).values

# %% [raw]
# df[['ID', 'accountType', 'Secured_CNT', 'Unsecured_CNT']][0:60]

# %% [markdown]
# ### Secured_Unsecured_CNT
# - Count  of all secured and unsecured loans for an applicant

# %%
Secured_Unsecured_CNT = list()

for x in range(0, df.shape[0]):
    if (df['Secured_CNT'][x]=='unknown') and (df['Unsecured_CNT'][x]=='unknown'):
        Secured_Unsecured_CNT.append('unknown')
    elif (df['Secured_CNT'][x]=='unknown'):
        Secured_Unsecured_CNT.append(df['Unsecured_CNT'][x])
    elif (df['Unsecured_CNT'][x]=='unknown'):
        Secured_Unsecured_CNT.append(df['Secured_CNT'][x])
    elif (df['Secured_CNT'][x]!='unknown') and (df['Unsecured_CNT'][x]!='unknown'):
        Secured_Unsecured_CNT.append(df['Secured_CNT'][x] + df['Unsecured_CNT'][x])
        
df['Secured_Unsecured_CNT'] = pd.Series(Secured_Unsecured_CNT).values

# %% [raw]
# df[['ID', 'accountType', 'Secured_CNT', 'Unsecured_CNT', 'Secured_Unsecured_CNT']][0:60]

# %% [markdown]
# <a id='Loans_Sec_UnsecwoRLCC_L'></a>
# ### Loans_Sec_UnsecwoRLCC_L
# - Ratio of total live secured loans to live unsecured loans (without RL/CC)
#
# <a id='Per_Sec_UnsecwoRLCC_L'></a>
# ### Per_Sec_UnsecwoRLCC_L
# - Percentage: Total live secured loans/ (Total live secured loans + total live unsecured loans (without RL/CC))

# %%
Loans_Sec_UnsecwoRLCC_L = list()
Per_Sec_UnsecwoRLCC_L = list()

sec_L_cnt = 0
sec_L_cnt_list = list()

unsec_L_cnt = 0
unsec_L_cnt_list = list()

for x in range(0, len(unq_id_list)):
    grp_slice = grp_df.get_group(unq_id_list[x])
    # print(grp_slice)
    grp_slice.reset_index(drop=True, inplace=True)
    # print(grp_slice.shape[0])

    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['accountType'][i] in sec_L) and (grp_slice['dateClosed'][i]=='unknown'):
            sec_L_cnt = sec_L_cnt + 1
        elif (grp_slice['accountType'][i] in unsec_L) and (grp_slice['dateClosed'][i]=='unknown'):
            unsec_L_cnt = unsec_L_cnt + 1
        else:
            continue
            
    sec_L_cnt_list.append(sec_L_cnt)
    unsec_L_cnt_list.append(unsec_L_cnt)
    
    sec_L_cnt = 0
    unsec_L_cnt = 0
    
    for i in range(0, grp_slice.shape[0]):
        if (pd.isnull(grp_slice['accountType'][i])) or (unsec_L_cnt_list[0] == 0):
            Loans_Sec_UnsecwoRLCC_L.append('unknown')
            Per_Sec_UnsecwoRLCC_L.append('unknown')
        else:
            Loans_Sec_UnsecwoRLCC_L.append(sec_L_cnt_list[0]/unsec_L_cnt_list[0])
            Per_Sec_UnsecwoRLCC_L.append(sec_L_cnt_list[0]/(unsec_L_cnt_list[0]+sec_L_cnt_list[0]))
            
    sec_L_cnt_list = list()
    unsec_L_cnt_list = list()
            
df['Loans_Sec_UnsecwoRLCC_L'] = pd.Series(Loans_Sec_UnsecwoRLCC_L).values
df['Per_Sec_UnsecwoRLCC_L'] = pd.Series(Per_Sec_UnsecwoRLCC_L).values

# %% [raw]
# df[['ID','accountType','Secured_CNT','Unsecured_CNT','Secured_Unsecured_CNT','dateClosed','Loans_Sec_UnsecwoRLCC_L','Per_Sec_UnsecwoRLCC_L']][0:60]

# %% [raw]
# df[df['Loans_Sec_UnsecwoRLCC_L']!='unknown']

# %% [markdown]
# <a id='Disb_Sec_UnsecwoRLCC_L'></a>
# ### Disb_Sec_UnsecwoRLCC_L
# - Ratio of total sum disbursed amount for live secured loans to total sum of disbursed amount for live unsecured loans (without RL/CC)

# %% [raw]
# df['accountType'].value_counts()

# %%
sanc_amt_sec_L_list = list()
sanc_amt_sec_L = list()

sanc_amt_unsec_L_list = list()
sanc_amt_unsec_L = list()

Disb_Sec_UnsecwoRLCC_L = list()

grp_df = df.groupby('ID')

for x in range(0, len(unq_id_list)):
    grp_slice = grp_df.get_group(unq_id_list[x])
    #print(grp_slice)
    grp_slice.reset_index(drop=True, inplace=True)
    #print(grp_slice.shape[0])
    
    if grp_slice.shape[0] > 1:
        #print(grp_slice)
        #print('---')
        for i in range(0, grp_slice.shape[0]):
            if grp_slice['accountType'][i]=='unknown' or grp_slice['sanctionAmount'][i]=='unknown':
                continue
            elif grp_slice['accountType'][i] in sec_L:
                sanc_amt_sec_L.append(grp_slice['sanctionAmount'][i])
                #print('sec',sanc_amt_sec_L)
                
            elif grp_slice['accountType'][i] in unsec_L:
                sanc_amt_unsec_L.append(grp_slice['sanctionAmount'][i])
                #print('unsec',sanc_amt_unsec_L)
                
        #print(sum(sanc_amt_sec_L))
        #print(sum(sanc_amt_unsec_L))
        
        for i in range(0, grp_slice.shape[0]):
            if sum(sanc_amt_unsec_L) > 0:
                Disb_Sec_UnsecwoRLCC_L.append(sum(sanc_amt_sec_L)/sum(sanc_amt_unsec_L))  
                #print('var', Disb_Sec_UnsecwoRLCC_L)
            else:
                Disb_Sec_UnsecwoRLCC_L.append('unknown')
                #print('var', 'unknown')
            
        sanc_amt_sec_L = list()
        sanc_amt_unsec_L = list()
        #Disb_Sec_UnsecwoRLCC_L = list()
        
    else:
        Disb_Sec_UnsecwoRLCC_L.append('unknown') 
 
df['Disb_Sec_UnsecwoRLCC_L'] = pd.Series(Disb_Sec_UnsecwoRLCC_L).values

# %% [raw]
# df[['ID','accountType','sanctionAmount','Disb_Sec_UnsecwoRLCC_L']][0:20]

# %% [markdown]
# <a id='Bal_Sec_UnsecwoRLCC_L'></a>
# ### Bal_Sec_UnsecwoRLCC_L
# - Ratio of total sum current balance (each >0) for live secured loans to total sum of current balance (each >0) )for live unsecured loans (without RL/CC)

# %%
sec_L = [1, 2, 3, 4, 7, 11, 13, 15, 16, 17, 31,
         32, 33, 34, 42, 43, 44, 50, 54, 58, 59, 0, 98]
unsec_L = [5, 6, 8, 9, 35, 36, 37, 39, 40, 41, 51, 52, 53, 56, 57, 61, 99]

curr_bal_sec_L_list = list()
curr_bal_sec_L = list()

curr_bal_unsec_L_list = list()
curr_bal_unsec_L = list()

Bal_Sec_UnsecwoRLCC_L = list()

grp_df = df.groupby('ID')

for x in range(0, len(unq_id_list)):
    grp_slice = grp_df.get_group(unq_id_list[x])
    # print(grp_slice)
    grp_slice.reset_index(drop=True, inplace=True)
    # print(grp_slice.shape[0])

    if grp_slice.shape[0] > 1:
        # print(grp_slice)
        #print('---', '\n')
        for i in range(0, grp_slice.shape[0]):
            if (grp_slice['accountType'][i] == 'unknown') or (grp_slice['currentBalance'][i] == 'unknown') or (grp_slice['currentBalance'][i] < 0):
                continue
            elif grp_slice['accountType'][i] in sec_L:
                curr_bal_sec_L.append(grp_slice['currentBalance'][i])
                #print('sec',curr_bal_sec_L)
            elif grp_slice['accountType'][i] in unsec_L:
                curr_bal_unsec_L.append(grp_slice['currentBalance'][i])
                #print('unsec',curr_bal_unsec_L)

        #print(sum(curr_bal_sec_L))
        #print(sum(curr_bal_unsec_L))

        for i in range(0, grp_slice.shape[0]):
            if sum(curr_bal_unsec_L) > 0 and (grp_slice['currentBalance'][i] >= 0):
                Bal_Sec_UnsecwoRLCC_L.append(
                    sum(curr_bal_sec_L)/sum(curr_bal_unsec_L))
                #print('var', Bal_Sec_UnsecwoRLCC_L)
            else:
                Bal_Sec_UnsecwoRLCC_L.append('unknown')
                #print('var', 'unknown')

        curr_bal_sec_L = list()
        curr_bal_unsec_L = list()
        #Bal_Sec_UnsecwoRLCC_L = list()

    else:
        Bal_Sec_UnsecwoRLCC_L.append('unknown')

df['Bal_Sec_UnsecwoRLCC_L'] = pd.Series(Bal_Sec_UnsecwoRLCC_L).values

# %% [raw]
# for x in range(0, df.shape[0]):
#     if df['currentBalance'][x]=='unknown':
#         continue
#     elif df['currentBalance'][x]<0 :
#          print(df['currentBalance'][x])
#     else:
#         continue
#
# a = [-302.0,-3.0,-3027.0,-20.0,-1447.0,-564.0]
#
# df[['ID','accountType','currentBalance','Bal_Sec_UnsecwoRLCC_L']][df['currentBalance']==-564.0]
# #[df[df['currentBalance']==i] for i in a]
# #df[['ID','accountType','currentBalance','Bal_Sec_UnsecwoRLCC_L']][0:20]

# %% [markdown]
# <a id='creditLimit_difference'></a>
# ### creditLimit_difference
# - Compute the difference in amount between the recent credit card limit and the previous credit card limit
# - For an applicant, the difference between consecutive credit card limits
# - If credit cards=0 or credit cards=1, then this variable would have NA

# %%
df[df['accountType']==10][['ID','creditLimit']]
# Out:
#                  ID creditLimit
# 16      64093000505       23000
# 19      64093000505     unknown
# 67      25889002386       61000
# 68      25889002386     unknown
# 132     75597000262       35000
# ...             ...         ...
# 3970    56777001232       10000
# 4032    36849001285       28000
# 4057  3061CD0134423       62000
# 4385  3054CD0291410       10000
# 4388  3054CD0291410       36000
#
# [116 rows x 2 columns]

# %%
# 71095000152 
creditLimit_difference = list()

for x in range(0, len(unq_id_list)):
    #grp_slice = grp_df[grp_slice['accountType']==10]
    grp_slice = grp_df.get_group(unq_id_list[x])
    grp_slice.reset_index(drop=True, inplace=True)
    #print(grp_slice[['ID','dateReportedAndCertified','creditLimit']])
    #print(grp_slice.shape[0])
    
    
    #print(grp_slice)
    if grp_slice.shape[0] > 1:
        #print(grp_slice.shape[0])
        for i in range(0, grp_slice.shape[0]):
            if grp_slice['creditLimit'][i]=='unknown':
                #grp_slice['creditLimit_difference'][i] = 'unknown'
                creditLimit_difference.append('unknown')
            elif (i+1 < grp_slice.shape[0]) and (grp_slice['accountType'][i]==10) and (grp_slice['accountType'][i+1]==10) and (grp_slice['creditLimit'][i]!='unknown') and (grp_slice['creditLimit'][i+1]!='unknown'):
                creditLimit_difference.append(grp_slice['creditLimit'][i] - grp_slice['creditLimit'][i+1])
            elif (i+1 < grp_slice.shape[0]) and (grp_slice['accountType'][i]==10) and (grp_slice['accountType'][i+1]==10) and (grp_slice['creditLimit'][i]!='unknown') and (grp_slice['creditLimit'][i+1]=='unknown'):
                creditLimit_difference.append('unknown')
            else:
                creditLimit_difference.append('unknown')
    else:
        creditLimit_difference.append('unknown')

df['creditLimit_difference'] = pd.Series(creditLimit_difference).values

# %% [raw]
# a = df[df['ID']=='71095000152']
# #a[['ID','dateReportedAndCertified','creditLimit','creditLimit_difference']]
# df[['ID','dateReportedAndCertified','creditLimit','creditLimit_difference']][0:60]

# %%
df[df['accountType']==10][['ID','dateReportedAndCertified','creditLimit','creditLimit_difference']][0:60]
# Out:
#                    ID dateReportedAndCertified creditLimit  \
# 16        64093000505               2020-06-11       23000
# 19        64093000505               2020-05-31     unknown
# 67        25889002386               2020-06-29       61000
# 68        25889002386               2020-05-31     unknown
# 132       75597000262               2019-12-12       35000
# 280   794491420000432               2020-04-14       50000
# 338       33083002224               2020-06-30     unknown
# 339       33083002224               2020-06-26       25000
# 343       33083002224               2020-05-31     unknown
# 344       33083002224               2020-05-31       52000
# 347       33083002224               2020-05-31       52000
# 351       33083002224               2020-03-31       51000
# 355       33083002224               2020-01-31       74000
# 358       33083002224               2019-12-20       61000
# 397       61372000705               2017-08-31     unknown
# 403   889441420000003               2020-06-09       20000
# 421       32933001673               2020-05-31     unknown
# 429       32933001673               2020-04-30     unknown
# 432       32933001673               2020-04-21      250000
# 445     3078CD0357323               2020-01-31     unknown
# 477       31188001675               2020-05-31     unknown
# 479       31188001675               2020-04-08       20000
# 591       28179000143               2020-06-03      100000
# 769       28751005998               2020-05-31     unknown
# 790   840791420000156               2020-04-21       20000
# 791   840791420000156               2020-04-08       20000
# 807       71095000152               2020-06-16      175000
# 808       71095000152               2020-03-31      200000
# 812       30831001547               2020-05-31     unknown
# 813       30831001547               2020-04-23       20000
# 1034      88487000010               2020-05-31     unknown
# 1035      88487000010               2020-05-31       35000
# 1077    3004CD0129020               2020-05-31     unknown
# 1091  702071420000423               2020-06-30     unknown
# 1111    3018CD0149505               2020-05-31       15000
# 1163      27522001669               2010-10-01     unknown
# 1166      46924000816               2020-05-31     unknown
# 1182      33102001540               2020-05-31       42000
# 1221      44475001717               2019-09-30       21000
# 1383      51585001791               2020-05-31       30000
# 1418      34482014011               2020-05-31     unknown
# 1419      34482014011               2020-05-31     unknown
# 1420      34482014011               2020-02-29     unknown
# 1641  689771420000971               2020-06-30     unknown
# 1643  689771420000971               2020-03-31       80800
# 1661    3054CD0291430               2020-05-31       60000
# 1684    3021CD0119288               2020-05-31      105000
# 1710  560391420000302               2020-05-31     unknown
# 1721    3024CD0103180               2020-06-25       25000
# 1733      38181002393               2016-02-29     unknown
# 1739      32931004619               2020-06-16       10000
# 1740      32931004619               2020-05-31     unknown
# 1743      32931004619               2020-05-31       60000
# 1773    3000CD0172023               2020-04-08       32000
# 1774    3000CD0172023               2020-03-31      100000
# 1779    3000CD0172023               2019-09-30      120000
# 1785    3000CD0172023               2018-12-04     unknown
# 1786    3000CD0172023               2018-12-04      120000
# 1787    3000CD0172023               2018-11-22          70
# 1844    3061CD0134429               2020-06-08       19000
#
#      creditLimit_difference
# 16                  unknown
# 19                  unknown
# 67                  unknown
# 68                  unknown
# 132                 unknown
# 280                 unknown
# 338                 unknown
# 339                 unknown
# 343                 unknown
# 344                 unknown
# 347                 unknown
# 351                 unknown
# 355                 unknown
# 358                 unknown
# 397                 unknown
# 403                 unknown
# 421                 unknown
# 429                 unknown
# 432                 unknown
# 445                 unknown
# 477                 unknown
# 479                 unknown
# 591                 unknown
# 769                 unknown
# 790                       0
# 791                 unknown
# 807                  -25000
# 808                 unknown
# 812                 unknown
# 813                 unknown
# 1034                unknown
# 1035                unknown
# 1077                unknown
# 1091                unknown
# 1111                unknown
# 1163                unknown
# 1166                unknown
# 1182                unknown
# 1221                unknown
# 1383                unknown
# 1418                unknown
# 1419                unknown
# 1420                unknown
# 1641                unknown
# 1643                unknown
# 1661                unknown
# 1684                unknown
# 1710                unknown
# 1721                unknown
# 1733                unknown
# 1739                unknown
# 1740                unknown
# 1743                unknown
# 1773                 -68000
# 1774                unknown
# 1779                unknown
# 1785                unknown
# 1786                 119930
# 1787                unknown
# 1844                unknown

# %% [raw]
# df['creditLimit_difference'].value_counts()

# %% [markdown]
# ### Code for Mean_SancAmt_Prodwise

# %% [markdown]
# - Indicates the average sanctioned amount per product (excluding account types - 10,35,36)
# - For an applicant, for each product (excluding account types - 10,35,36), compute the average of sanctioned amount

# %% [raw]
# df['accountType'].value_counts()

# %%
bureau_accType_dict = {0: "OTH", 1: "AL", 2: "HL", 3: "HL", 4: "LAS", 5: "PL", 6: "CD",
                      7: "GL", 8: "PL", 9: "SEL", 10: "CC", 11: "HL", 12: "RL",
                      13: "AL", 14: "RL", 15: "LAS", 16: "CV", 17: "CV", 
                      31: "CC", 32: "AL", 33: "CV", 34: "CV", 35: "SCC", 36: "SCC",
                      37: "PL", 38: "RL", 39: "BL", 40: "MFBL", 41: "MFPL", 42: "MFHL",
                      43: "MFOT", 44: "HL", 50: "BL", 51: "BL", 52: "PLBL", 53: "PLBL",
                      54: "PLBL", 55: "RL", 56: "PLRLBL", 57: "PLRLBL", 58: "PLRLBL",
                      59: "BL", 61: "BL", 98: "SEC", 99: "UNSEC"}

# %%
df = df.replace({"accountType": bureau_accType_dict})

df['accountType'].fillna('unknown', inplace=True)

# %%
Mean_SancAmt_AL = list()
Mean_SancAmt_BL = list()
Mean_SancAmt_CD = list()
Mean_SancAmt_CV = list()
Mean_SancAmt_GL = list()
Mean_SancAmt_HL = list()
Mean_SancAmt_LAS = list()
Mean_SancAmt_MFBL = list()
Mean_SancAmt_MFHL = list()
Mean_SancAmt_MFOT = list()
Mean_SancAmt_OTH = list()
Mean_SancAmt_PL = list()
Mean_SancAmt_PLBL = list()
Mean_SancAmt_RL = list()
Mean_SancAmt_SEL = list()

sanc_amt_list_AL = list()
sanc_amt_list_BL = list()
sanc_amt_list_CD = list()
sanc_amt_list_CV = list()
sanc_amt_list_GL = list()
sanc_amt_list_HL = list()
sanc_amt_list_LAS = list()
sanc_amt_list_MFBL = list()
sanc_amt_list_MFHL = list()
sanc_amt_list_MFOT = list()
sanc_amt_list_OTH = list()
sanc_amt_list_PL = list()
sanc_amt_list_PLBL = list()
sanc_amt_list_RL = list()
sanc_amt_list_SEL = list()

sanc_amt_AL = list()
sanc_amt_BL = list()
sanc_amt_CD = list()
sanc_amt_CV = list()
sanc_amt_GL = list()
sanc_amt_HL = list()
sanc_amt_LAS = list()
sanc_amt_MFBL = list()
sanc_amt_MFHL = list()
sanc_amt_MFOT = list()
sanc_amt_OTH = list()
sanc_amt_PL = list() 
sanc_amt_PLBL = list()
sanc_amt_RL = list()
sanc_amt_SEL = list()

grp_df = df.groupby('ID')

for x in range(0, len(unq_id_list)):
    grp_slice = grp_df.get_group(unq_id_list[x])
    #print(grp_slice)
    grp_slice.reset_index(drop=True, inplace=True)
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['sanctionAmount'][i]=='unknown'):
            continue
        elif (grp_slice['accountType'][i]=='AL'):
            sanc_amt_AL.append(float(grp_slice['sanctionAmount'][i]))
        elif (grp_slice['accountType'][i]=='BL'):
            sanc_amt_BL.append(float(grp_slice['sanctionAmount'][i]))
        elif (grp_slice['accountType'][i]=='CD'):
            sanc_amt_CD.append(float(grp_slice['sanctionAmount'][i]))
        elif (grp_slice['accountType'][i]=='CV'):
            sanc_amt_CV.append(float(grp_slice['sanctionAmount'][i]))
        elif (grp_slice['accountType'][i]=='GL'):
            sanc_amt_GL.append(float(grp_slice['sanctionAmount'][i]))
        elif (grp_slice['accountType'][i]=='HL'):
            sanc_amt_HL.append(float(grp_slice['sanctionAmount'][i]))
        elif (grp_slice['accountType'][i]=='LAS'):
            sanc_amt_LAS.append(float(grp_slice['sanctionAmount'][i]))
        elif (grp_slice['accountType'][i]=='MFBL'):
            sanc_amt_MFBL.append(float(grp_slice['sanctionAmount'][i]))
        elif (grp_slice['accountType'][i]=='MFHL'):
            sanc_amt_MFHL.append(float(grp_slice['sanctionAmount'][i]))
        elif (grp_slice['accountType'][i]=='MFOT'):
            sanc_amt_MFOT.append(float(grp_slice['sanctionAmount'][i]))
        elif (grp_slice['accountType'][i]=='OTH'):
            sanc_amt_OTH.append(float(grp_slice['sanctionAmount'][i]))
        elif (grp_slice['accountType'][i]=='PL'):
            sanc_amt_PL.append(float(grp_slice['sanctionAmount'][i]))
        elif (grp_slice['accountType'][i]=='PLBL'):
            sanc_amt_PLBL.append(float(grp_slice['sanctionAmount'][i]))
        elif (grp_slice['accountType'][i]=='RL'):
            sanc_amt_RL.append(float(grp_slice['sanctionAmount'][i]))
        elif (grp_slice['accountType'][i]=='SEL'):
            sanc_amt_SEL.append(float(grp_slice['sanctionAmount'][i]))
            
    sanc_amt_list_AL.append(sanc_amt_AL)
    sanc_amt_list_BL.append(sanc_amt_BL)
    sanc_amt_list_CD.append(sanc_amt_CD)
    sanc_amt_list_CV.append(sanc_amt_CV)
    sanc_amt_list_GL.append(sanc_amt_GL)
    sanc_amt_list_HL.append(sanc_amt_HL)
    sanc_amt_list_LAS.append(sanc_amt_LAS)
    sanc_amt_list_MFBL.append(sanc_amt_MFBL)
    sanc_amt_list_MFHL.append(sanc_amt_MFHL)
    sanc_amt_list_MFOT.append(sanc_amt_MFOT)
    sanc_amt_list_OTH.append(sanc_amt_OTH)
    sanc_amt_list_PL.append(sanc_amt_PL)
    sanc_amt_list_PLBL.append(sanc_amt_PLBL)
    sanc_amt_list_RL.append(sanc_amt_RL)
    sanc_amt_list_SEL.append(sanc_amt_SEL)
    
    sanc_amt_AL = list()
    sanc_amt_BL = list()
    sanc_amt_CD = list()
    sanc_amt_CV = list()
    sanc_amt_GL = list()
    sanc_amt_HL = list()
    sanc_amt_LAS = list()
    sanc_amt_MFBL = list()
    sanc_amt_MFHL = list()
    sanc_amt_MFOT = list()
    sanc_amt_OTH = list()
    sanc_amt_PL = list()
    sanc_amt_PLBL = list()
    sanc_amt_RL = list()
    sanc_amt_SEL = list()
    
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['sanctionAmount'][i]=='unknown'):
            Mean_SancAmt_AL.append('unknown')
            Mean_SancAmt_BL.append('unknown')
            Mean_SancAmt_CD.append('unknown')
            Mean_SancAmt_CV.append('unknown')
            Mean_SancAmt_GL.append('unknown')
            Mean_SancAmt_HL.append('unknown')
            Mean_SancAmt_LAS.append('unknown')
            Mean_SancAmt_MFBL.append('unknown')
            Mean_SancAmt_MFHL.append('unknown')
            Mean_SancAmt_MFOT.append('unknown')
            Mean_SancAmt_OTH.append('unknown')
            Mean_SancAmt_PL.append('unknown')
            Mean_SancAmt_PLBL.append('unknown')
            Mean_SancAmt_RL.append('unknown')
            Mean_SancAmt_SEL.append('unknown')
        else:
            Mean_SancAmt_AL.append(np.mean(sanc_amt_list_AL[x]))
            Mean_SancAmt_BL.append(np.mean(sanc_amt_list_BL[x]))
            Mean_SancAmt_CD.append(np.mean(sanc_amt_list_CD[x]))
            Mean_SancAmt_CV.append(np.mean(sanc_amt_list_CV[x]))
            Mean_SancAmt_GL.append(np.mean(sanc_amt_list_GL[x]))
            Mean_SancAmt_HL.append(np.mean(sanc_amt_list_HL[x]))
            Mean_SancAmt_LAS.append(np.mean(sanc_amt_list_LAS[x]))
            Mean_SancAmt_MFBL.append(np.mean(sanc_amt_list_MFBL[x]))
            Mean_SancAmt_MFHL.append(np.mean(sanc_amt_list_MFHL[x]))
            Mean_SancAmt_MFOT.append(np.mean(sanc_amt_list_MFOT[x]))
            Mean_SancAmt_OTH.append(np.mean(sanc_amt_list_OTH[x]))
            Mean_SancAmt_PL.append(np.mean(sanc_amt_list_PL[x]))
            Mean_SancAmt_PLBL.append(np.mean(sanc_amt_list_PLBL[x]))
            Mean_SancAmt_RL.append(np.mean(sanc_amt_list_RL[x]))
            Mean_SancAmt_SEL.append(np.mean(sanc_amt_list_SEL[x]))
            
df['Mean_SancAmt_AL'] = pd.Series(Mean_SancAmt_AL).values
df['Mean_SancAmt_BL'] = pd.Series(Mean_SancAmt_BL).values
df['Mean_SancAmt_CD'] = pd.Series(Mean_SancAmt_CD).values
df['Mean_SancAmt_CV'] = pd.Series(Mean_SancAmt_CV).values
df['Mean_SancAmt_GL'] = pd.Series(Mean_SancAmt_GL).values
df['Mean_SancAmt_HL'] = pd.Series(Mean_SancAmt_HL).values
df['Mean_SancAmt_LAS'] = pd.Series(Mean_SancAmt_LAS).values
df['Mean_SancAmt_MFBL'] = pd.Series(Mean_SancAmt_MFBL).values
df['Mean_SancAmt_MFHL'] = pd.Series(Mean_SancAmt_MFHL).values
df['Mean_SancAmt_MFOT'] = pd.Series(Mean_SancAmt_MFOT).values
df['Mean_SancAmt_OTH'] = pd.Series(Mean_SancAmt_OTH).values
df['Mean_SancAmt_PL'] = pd.Series(Mean_SancAmt_PL).values
df['Mean_SancAmt_PLBL'] = pd.Series(Mean_SancAmt_PLBL).values
df['Mean_SancAmt_RL'] = pd.Series(Mean_SancAmt_RL).values
df['Mean_SancAmt_SEL'] = pd.Series(Mean_SancAmt_SEL).values

# %% [raw]
# a = df[['ID','Mean_SancAmt_AL','accountType','sanctionAmount']]
# a.head(60)

# %% [markdown]
# ### Code for Mean_SancAmt_Prodwise_L

# %% [markdown]
# - Indicates the average sanctioned amount per live product (excluding account types - 10,35,36)
# - For an applicant, for each product (excluding account types - 10,35,36), compute the average of sanctioned amount for the loans where dateClosed is null

# %%
Mean_SancAmt_L_AL = list()
Mean_SancAmt_L_BL = list()
Mean_SancAmt_L_CD = list()
Mean_SancAmt_L_CV = list()
Mean_SancAmt_L_GL = list()
Mean_SancAmt_L_HL = list()
Mean_SancAmt_L_LAS = list()
Mean_SancAmt_L_MFBL = list()
Mean_SancAmt_L_MFHL = list()
Mean_SancAmt_L_MFOT = list()
Mean_SancAmt_L_OTH = list()
Mean_SancAmt_L_PL = list()
Mean_SancAmt_L_PLBL = list()
Mean_SancAmt_L_RL = list()
Mean_SancAmt_L_SEL = list()

sanc_amt_list_AL = list()
sanc_amt_list_BL = list()
sanc_amt_list_CD = list()
sanc_amt_list_CV = list()
sanc_amt_list_GL = list()
sanc_amt_list_HL = list()
sanc_amt_list_LAS = list()
sanc_amt_list_MFBL = list()
sanc_amt_list_MFHL = list()
sanc_amt_list_MFOT = list()
sanc_amt_list_OTH = list()
sanc_amt_list_PL = list()
sanc_amt_list_PLBL = list()
sanc_amt_list_RL = list()
sanc_amt_list_SEL = list()

sanc_amt_AL = list()
sanc_amt_BL = list()
sanc_amt_CD = list()
sanc_amt_CV = list()
sanc_amt_GL = list()
sanc_amt_HL = list()
sanc_amt_LAS = list()
sanc_amt_MFBL = list()
sanc_amt_MFHL = list()
sanc_amt_MFOT = list()
sanc_amt_OTH = list()
sanc_amt_PL = list() 
sanc_amt_PLBL = list()
sanc_amt_RL = list()
sanc_amt_SEL = list()

grp_df = df.groupby('ID')

for x in range(0, len(unq_id_list)):
    grp_slice = grp_df.get_group(unq_id_list[x])
    #print(grp_slice)
    grp_slice.reset_index(drop=True, inplace=True)
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['dateClosed'][i]!='unknown') or (grp_slice['sanctionAmount'][i]=='unknown'):
            continue
        elif (grp_slice['accountType'][i]=='AL'):
            sanc_amt_AL.append(float(grp_slice['sanctionAmount'][i]))
        elif (grp_slice['accountType'][i]=='BL'):
            sanc_amt_BL.append(float(grp_slice['sanctionAmount'][i]))
        elif (grp_slice['accountType'][i]=='CD'):
            sanc_amt_CD.append(float(grp_slice['sanctionAmount'][i]))
        elif (grp_slice['accountType'][i]=='CV'):
            sanc_amt_CV.append(float(grp_slice['sanctionAmount'][i]))
        elif (grp_slice['accountType'][i]=='GL'):
            sanc_amt_GL.append(float(grp_slice['sanctionAmount'][i]))
        elif (grp_slice['accountType'][i]=='HL'):
            sanc_amt_HL.append(float(grp_slice['sanctionAmount'][i]))
        elif (grp_slice['accountType'][i]=='LAS'):
            sanc_amt_LAS.append(float(grp_slice['sanctionAmount'][i]))
        elif (grp_slice['accountType'][i]=='MFBL'):
            sanc_amt_MFBL.append(float(grp_slice['sanctionAmount'][i]))
        elif (grp_slice['accountType'][i]=='MFHL'):
            sanc_amt_MFHL.append(float(grp_slice['sanctionAmount'][i]))
        elif (grp_slice['accountType'][i]=='MFOT'):
            sanc_amt_MFOT.append(float(grp_slice['sanctionAmount'][i]))
        elif (grp_slice['accountType'][i]=='OTH'):
            sanc_amt_OTH.append(float(grp_slice['sanctionAmount'][i]))
        elif (grp_slice['accountType'][i]=='PL'):
            sanc_amt_PL.append(float(grp_slice['sanctionAmount'][i]))
        elif (grp_slice['accountType'][i]=='PLBL'):
            sanc_amt_PLBL.append(float(grp_slice['sanctionAmount'][i]))
        elif (grp_slice['accountType'][i]=='RL'):
            sanc_amt_RL.append(float(grp_slice['sanctionAmount'][i]))
        elif (grp_slice['accountType'][i]=='SEL'):
            sanc_amt_SEL.append(float(grp_slice['sanctionAmount'][i]))
            
    sanc_amt_list_AL.append(sanc_amt_AL)
    sanc_amt_list_BL.append(sanc_amt_BL)
    sanc_amt_list_CD.append(sanc_amt_CD)
    sanc_amt_list_CV.append(sanc_amt_CV)
    sanc_amt_list_GL.append(sanc_amt_GL)
    sanc_amt_list_HL.append(sanc_amt_HL)
    sanc_amt_list_LAS.append(sanc_amt_LAS)
    sanc_amt_list_MFBL.append(sanc_amt_MFBL)
    sanc_amt_list_MFHL.append(sanc_amt_MFHL)
    sanc_amt_list_MFOT.append(sanc_amt_MFOT)
    sanc_amt_list_OTH.append(sanc_amt_OTH)
    sanc_amt_list_PL.append(sanc_amt_PL)
    sanc_amt_list_PLBL.append(sanc_amt_PLBL)
    sanc_amt_list_RL.append(sanc_amt_RL)
    sanc_amt_list_SEL.append(sanc_amt_SEL)
    
    sanc_amt_AL = list()
    sanc_amt_BL = list()
    sanc_amt_CD = list()
    sanc_amt_CV = list()
    sanc_amt_GL = list()
    sanc_amt_HL = list()
    sanc_amt_LAS = list()
    sanc_amt_MFBL = list()
    sanc_amt_MFHL = list()
    sanc_amt_MFOT = list()
    sanc_amt_OTH = list()
    sanc_amt_PL = list()
    sanc_amt_PLBL = list()
    sanc_amt_RL = list()
    sanc_amt_SEL = list()
    
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['dateClosed'][i]!='unknown') or (grp_slice['sanctionAmount'][i]=='unknown'):
            Mean_SancAmt_L_AL.append('unknown')
            Mean_SancAmt_L_BL.append('unknown')
            Mean_SancAmt_L_CD.append('unknown')
            Mean_SancAmt_L_CV.append('unknown')
            Mean_SancAmt_L_GL.append('unknown')
            Mean_SancAmt_L_HL.append('unknown')
            Mean_SancAmt_L_LAS.append('unknown')
            Mean_SancAmt_L_MFBL.append('unknown')
            Mean_SancAmt_L_MFHL.append('unknown')
            Mean_SancAmt_L_MFOT.append('unknown')
            Mean_SancAmt_L_OTH.append('unknown')
            Mean_SancAmt_L_PL.append('unknown')
            Mean_SancAmt_L_PLBL.append('unknown')
            Mean_SancAmt_L_RL.append('unknown')
            Mean_SancAmt_L_SEL.append('unknown')
        else:
            Mean_SancAmt_L_AL.append(np.mean(sanc_amt_list_AL[x]))
            Mean_SancAmt_L_BL.append(np.mean(sanc_amt_list_BL[x]))
            Mean_SancAmt_L_CD.append(np.mean(sanc_amt_list_CD[x]))
            Mean_SancAmt_L_CV.append(np.mean(sanc_amt_list_CV[x]))
            Mean_SancAmt_L_GL.append(np.mean(sanc_amt_list_GL[x]))
            Mean_SancAmt_L_HL.append(np.mean(sanc_amt_list_HL[x]))
            Mean_SancAmt_L_LAS.append(np.mean(sanc_amt_list_LAS[x]))
            Mean_SancAmt_L_MFBL.append(np.mean(sanc_amt_list_MFBL[x]))
            Mean_SancAmt_L_MFHL.append(np.mean(sanc_amt_list_MFHL[x]))
            Mean_SancAmt_L_MFOT.append(np.mean(sanc_amt_list_MFOT[x]))
            Mean_SancAmt_L_OTH.append(np.mean(sanc_amt_list_OTH[x]))
            Mean_SancAmt_L_PL.append(np.mean(sanc_amt_list_PL[x]))
            Mean_SancAmt_L_PLBL.append(np.mean(sanc_amt_list_PLBL[x]))
            Mean_SancAmt_L_RL.append(np.mean(sanc_amt_list_RL[x]))
            Mean_SancAmt_L_SEL.append(np.mean(sanc_amt_list_SEL[x]))
            
df['Mean_SancAmt_L_AL'] = pd.Series(Mean_SancAmt_L_AL).values
df['Mean_SancAmt_L_BL'] = pd.Series(Mean_SancAmt_L_BL).values
df['Mean_SancAmt_L_CD'] = pd.Series(Mean_SancAmt_L_CD).values
df['Mean_SancAmt_L_CV'] = pd.Series(Mean_SancAmt_L_CV).values
df['Mean_SancAmt_L_GL'] = pd.Series(Mean_SancAmt_L_GL).values
df['Mean_SancAmt_L_HL'] = pd.Series(Mean_SancAmt_L_HL).values
df['Mean_SancAmt_L_LAS'] = pd.Series(Mean_SancAmt_L_LAS).values
df['Mean_SancAmt_L_MFBL'] = pd.Series(Mean_SancAmt_L_MFBL).values
df['Mean_SancAmt_L_MFHL'] = pd.Series(Mean_SancAmt_L_MFHL).values
df['Mean_SancAmt_L_MFOT'] = pd.Series(Mean_SancAmt_L_MFOT).values
df['Mean_SancAmt_L_OTH'] = pd.Series(Mean_SancAmt_L_OTH).values
df['Mean_SancAmt_L_PL'] = pd.Series(Mean_SancAmt_L_PL).values
df['Mean_SancAmt_L_PLBL'] = pd.Series(Mean_SancAmt_L_PLBL).values
df['Mean_SancAmt_L_RL'] = pd.Series(Mean_SancAmt_L_RL).values
df['Mean_SancAmt_L_SEL'] = pd.Series(Mean_SancAmt_L_SEL).values

# %% [raw]
# a = df[['ID','Mean_SancAmt_L_PL','dateClosed','accountType','sanctionAmount']]
# a.head(60)

# %% [markdown]
# ### Code for Med_SancAmt_Prodwise

# %% [markdown]
# - Indicates the median sanctioned amount per product (excluding the account types - 10,35,36)
# - For an applicant, for each product (excluding account types - 10,35,36), compute the median of sanctioned amount for the loans

# %%
Med_SancAmt_AL = list()
Med_SancAmt_BL = list()
Med_SancAmt_CD = list()
Med_SancAmt_CV = list()
Med_SancAmt_GL = list()
Med_SancAmt_HL = list()
Med_SancAmt_LAS = list()
Med_SancAmt_MFBL = list()
Med_SancAmt_MFHL = list()
Med_SancAmt_MFOT = list()
Med_SancAmt_OTH = list()
Med_SancAmt_PL = list()
Med_SancAmt_PLBL = list()
Med_SancAmt_RL = list()
Med_SancAmt_SEL = list()

sanc_amt_list_AL = list()
sanc_amt_list_BL = list()
sanc_amt_list_CD = list()
sanc_amt_list_CV = list()
sanc_amt_list_GL = list()
sanc_amt_list_HL = list()
sanc_amt_list_LAS = list()
sanc_amt_list_MFBL = list()
sanc_amt_list_MFHL = list()
sanc_amt_list_MFOT = list()
sanc_amt_list_OTH = list()
sanc_amt_list_PL = list()
sanc_amt_list_PLBL = list()
sanc_amt_list_RL = list()
sanc_amt_list_SEL = list()

sanc_amt_AL = list()
sanc_amt_BL = list()
sanc_amt_CD = list()
sanc_amt_CV = list()
sanc_amt_GL = list()
sanc_amt_HL = list()
sanc_amt_LAS = list()
sanc_amt_MFBL = list()
sanc_amt_MFHL = list()
sanc_amt_MFOT = list()
sanc_amt_OTH = list()
sanc_amt_PL = list() 
sanc_amt_PLBL = list()
sanc_amt_RL = list()
sanc_amt_SEL = list()

grp_df = df.groupby('ID')

for x in range(0, len(unq_id_list)):
    grp_slice = grp_df.get_group(unq_id_list[x])
    #print(grp_slice)
    grp_slice.reset_index(drop=True, inplace=True)
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['sanctionAmount'][i]=='unknown'):
            continue
        elif (grp_slice['accountType'][i]=='AL'):
            sanc_amt_AL.append(float(grp_slice['sanctionAmount'][i]))
        elif (grp_slice['accountType'][i]=='BL'):
            sanc_amt_BL.append(float(grp_slice['sanctionAmount'][i]))
        elif (grp_slice['accountType'][i]=='CD'):
            sanc_amt_CD.append(float(grp_slice['sanctionAmount'][i]))
        elif (grp_slice['accountType'][i]=='CV'):
            sanc_amt_CV.append(float(grp_slice['sanctionAmount'][i]))
        elif (grp_slice['accountType'][i]=='GL'):
            sanc_amt_GL.append(float(grp_slice['sanctionAmount'][i]))
        elif (grp_slice['accountType'][i]=='HL'):
            sanc_amt_HL.append(float(grp_slice['sanctionAmount'][i]))
        elif (grp_slice['accountType'][i]=='LAS'):
            sanc_amt_LAS.append(float(grp_slice['sanctionAmount'][i]))
        elif (grp_slice['accountType'][i]=='MFBL'):
            sanc_amt_MFBL.append(float(grp_slice['sanctionAmount'][i]))
        elif (grp_slice['accountType'][i]=='MFHL'):
            sanc_amt_MFHL.append(float(grp_slice['sanctionAmount'][i]))
        elif (grp_slice['accountType'][i]=='MFOT'):
            sanc_amt_MFOT.append(float(grp_slice['sanctionAmount'][i]))
        elif (grp_slice['accountType'][i]=='OTH'):
            sanc_amt_OTH.append(float(grp_slice['sanctionAmount'][i]))
        elif (grp_slice['accountType'][i]=='PL'):
            sanc_amt_PL.append(float(grp_slice['sanctionAmount'][i]))
        elif (grp_slice['accountType'][i]=='PLBL'):
            sanc_amt_PLBL.append(float(grp_slice['sanctionAmount'][i]))
        elif (grp_slice['accountType'][i]=='RL'):
            sanc_amt_RL.append(float(grp_slice['sanctionAmount'][i]))
        elif (grp_slice['accountType'][i]=='SEL'):
            sanc_amt_SEL.append(float(grp_slice['sanctionAmount'][i]))
            
    sanc_amt_list_AL.append(sanc_amt_AL)
    sanc_amt_list_BL.append(sanc_amt_BL)
    sanc_amt_list_CD.append(sanc_amt_CD)
    sanc_amt_list_CV.append(sanc_amt_CV)
    sanc_amt_list_GL.append(sanc_amt_GL)
    sanc_amt_list_HL.append(sanc_amt_HL)
    sanc_amt_list_LAS.append(sanc_amt_LAS)
    sanc_amt_list_MFBL.append(sanc_amt_MFBL)
    sanc_amt_list_MFHL.append(sanc_amt_MFHL)
    sanc_amt_list_MFOT.append(sanc_amt_MFOT)
    sanc_amt_list_OTH.append(sanc_amt_OTH)
    sanc_amt_list_PL.append(sanc_amt_PL)
    sanc_amt_list_PLBL.append(sanc_amt_PLBL)
    sanc_amt_list_RL.append(sanc_amt_RL)
    sanc_amt_list_SEL.append(sanc_amt_SEL)
    
    sanc_amt_AL = list()
    sanc_amt_BL = list()
    sanc_amt_CD = list()
    sanc_amt_CV = list()
    sanc_amt_GL = list()
    sanc_amt_HL = list()
    sanc_amt_LAS = list()
    sanc_amt_MFBL = list()
    sanc_amt_MFHL = list()
    sanc_amt_MFOT = list()
    sanc_amt_OTH = list()
    sanc_amt_PL = list()
    sanc_amt_PLBL = list()
    sanc_amt_RL = list()
    sanc_amt_SEL = list()
    
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['sanctionAmount'][i]=='unknown'):
            Med_SancAmt_AL.append('unknown')
            Med_SancAmt_BL.append('unknown')
            Med_SancAmt_CD.append('unknown')
            Med_SancAmt_CV.append('unknown')
            Med_SancAmt_GL.append('unknown')
            Med_SancAmt_HL.append('unknown')
            Med_SancAmt_LAS.append('unknown')
            Med_SancAmt_MFBL.append('unknown')
            Med_SancAmt_MFHL.append('unknown')
            Med_SancAmt_MFOT.append('unknown')
            Med_SancAmt_OTH.append('unknown')
            Med_SancAmt_PL.append('unknown')
            Med_SancAmt_PLBL.append('unknown')
            Med_SancAmt_RL.append('unknown')
            Med_SancAmt_SEL.append('unknown')
        else:
            Med_SancAmt_AL.append(np.median(sanc_amt_list_AL[x]))
            Med_SancAmt_BL.append(np.median(sanc_amt_list_BL[x]))
            Med_SancAmt_CD.append(np.median(sanc_amt_list_CD[x]))
            Med_SancAmt_CV.append(np.median(sanc_amt_list_CV[x]))
            Med_SancAmt_GL.append(np.median(sanc_amt_list_GL[x]))
            Med_SancAmt_HL.append(np.median(sanc_amt_list_HL[x]))
            Med_SancAmt_LAS.append(np.median(sanc_amt_list_LAS[x]))
            Med_SancAmt_MFBL.append(np.median(sanc_amt_list_MFBL[x]))
            Med_SancAmt_MFHL.append(np.median(sanc_amt_list_MFHL[x]))
            Med_SancAmt_MFOT.append(np.median(sanc_amt_list_MFOT[x]))
            Med_SancAmt_OTH.append(np.median(sanc_amt_list_OTH[x]))
            Med_SancAmt_PL.append(np.median(sanc_amt_list_PL[x]))
            Med_SancAmt_PLBL.append(np.median(sanc_amt_list_PLBL[x]))
            Med_SancAmt_RL.append(np.median(sanc_amt_list_RL[x]))
            Med_SancAmt_SEL.append(np.median(sanc_amt_list_SEL[x]))
            
df['Med_SancAmt_AL'] = pd.Series(Med_SancAmt_AL).values
df['Med_SancAmt_BL'] = pd.Series(Med_SancAmt_BL).values
df['Med_SancAmt_CD'] = pd.Series(Med_SancAmt_CD).values
df['Med_SancAmt_CV'] = pd.Series(Med_SancAmt_CV).values
df['Med_SancAmt_GL'] = pd.Series(Med_SancAmt_GL).values
df['Med_SancAmt_HL'] = pd.Series(Med_SancAmt_HL).values
df['Med_SancAmt_LAS'] = pd.Series(Med_SancAmt_LAS).values
df['Med_SancAmt_MFBL'] = pd.Series(Med_SancAmt_MFBL).values
df['Med_SancAmt_MFHL'] = pd.Series(Med_SancAmt_MFHL).values
df['Med_SancAmt_MFOT'] = pd.Series(Med_SancAmt_MFOT).values
df['Med_SancAmt_OTH'] = pd.Series(Med_SancAmt_OTH).values
df['Med_SancAmt_PL'] = pd.Series(Med_SancAmt_PL).values
df['Med_SancAmt_PLBL'] = pd.Series(Med_SancAmt_PLBL).values
df['Med_SancAmt_RL'] = pd.Series(Med_SancAmt_RL).values
df['Med_SancAmt_SEL'] = pd.Series(Med_SancAmt_SEL).values

# %% [raw]
# a = df[['ID','Med_SancAmt_PL','accountType','sanctionAmount']]
# a[a['accountType']!=10].head(60)

# %% [markdown]
# ### Code for Med_SancAmt_Prodwise_L

# %% [markdown]
# - Indicates the median sanctioned amount per live product (excluding the account types - 10,35,36)
# - For an applicant, for each product (excluding account types - 10,35,36), compute the median of sanctioned amount for the loans where dateClosed is null

# %%
Med_SancAmt_L_AL = list()
Med_SancAmt_L_BL = list()
Med_SancAmt_L_CD = list()
Med_SancAmt_L_CV = list()
Med_SancAmt_L_GL = list()
Med_SancAmt_L_HL = list()
Med_SancAmt_L_LAS = list()
Med_SancAmt_L_MFBL = list()
Med_SancAmt_L_MFHL = list()
Med_SancAmt_L_MFOT = list()
Med_SancAmt_L_OTH = list()
Med_SancAmt_L_PL = list()
Med_SancAmt_L_PLBL = list()
Med_SancAmt_L_RL = list()
Med_SancAmt_L_SEL = list()

sanc_amt_list_AL = list()
sanc_amt_list_BL = list()
sanc_amt_list_CD = list()
sanc_amt_list_CV = list()
sanc_amt_list_GL = list()
sanc_amt_list_HL = list()
sanc_amt_list_LAS = list()
sanc_amt_list_MFBL = list()
sanc_amt_list_MFHL = list()
sanc_amt_list_MFOT = list()
sanc_amt_list_OTH = list()
sanc_amt_list_PL = list()
sanc_amt_list_PLBL = list()
sanc_amt_list_RL = list()
sanc_amt_list_SEL = list()

sanc_amt_AL = list()
sanc_amt_BL = list()
sanc_amt_CD = list()
sanc_amt_CV = list()
sanc_amt_GL = list()
sanc_amt_HL = list()
sanc_amt_LAS = list()
sanc_amt_MFBL = list()
sanc_amt_MFHL = list()
sanc_amt_MFOT = list()
sanc_amt_OTH = list()
sanc_amt_PL = list() 
sanc_amt_PLBL = list()
sanc_amt_RL = list()
sanc_amt_SEL = list()

grp_df = df.groupby('ID')

for x in range(0, len(unq_id_list)):
    grp_slice = grp_df.get_group(unq_id_list[x])
    #print(grp_slice)
    grp_slice.reset_index(drop=True, inplace=True)
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['dateClosed'][i]!='unknown') or (grp_slice['sanctionAmount'][i]=='unknown'):
            continue
        elif (grp_slice['accountType'][i]=='AL'):
            sanc_amt_AL.append(float(grp_slice['sanctionAmount'][i]))
        elif (grp_slice['accountType'][i]=='BL'):
            sanc_amt_BL.append(float(grp_slice['sanctionAmount'][i]))
        elif (grp_slice['accountType'][i]=='CD'):
            sanc_amt_CD.append(float(grp_slice['sanctionAmount'][i]))
        elif (grp_slice['accountType'][i]=='CV'):
            sanc_amt_CV.append(float(grp_slice['sanctionAmount'][i]))
        elif (grp_slice['accountType'][i]=='GL'):
            sanc_amt_GL.append(float(grp_slice['sanctionAmount'][i]))
        elif (grp_slice['accountType'][i]=='HL'):
            sanc_amt_HL.append(float(grp_slice['sanctionAmount'][i]))
        elif (grp_slice['accountType'][i]=='LAS'):
            sanc_amt_LAS.append(float(grp_slice['sanctionAmount'][i]))
        elif (grp_slice['accountType'][i]=='MFBL'):
            sanc_amt_MFBL.append(float(grp_slice['sanctionAmount'][i]))
        elif (grp_slice['accountType'][i]=='MFHL'):
            sanc_amt_MFHL.append(float(grp_slice['sanctionAmount'][i]))
        elif (grp_slice['accountType'][i]=='MFOT'):
            sanc_amt_MFOT.append(float(grp_slice['sanctionAmount'][i]))
        elif (grp_slice['accountType'][i]=='OTH'):
            sanc_amt_OTH.append(float(grp_slice['sanctionAmount'][i]))
        elif (grp_slice['accountType'][i]=='PL'):
            sanc_amt_PL.append(float(grp_slice['sanctionAmount'][i]))
        elif (grp_slice['accountType'][i]=='PLBL'):
            sanc_amt_PLBL.append(float(grp_slice['sanctionAmount'][i]))
        elif (grp_slice['accountType'][i]=='RL'):
            sanc_amt_RL.append(float(grp_slice['sanctionAmount'][i]))
        elif (grp_slice['accountType'][i]=='SEL'):
            sanc_amt_SEL.append(float(grp_slice['sanctionAmount'][i]))
            
    sanc_amt_list_AL.append(sanc_amt_AL)
    sanc_amt_list_BL.append(sanc_amt_BL)
    sanc_amt_list_CD.append(sanc_amt_CD)
    sanc_amt_list_CV.append(sanc_amt_CV)
    sanc_amt_list_GL.append(sanc_amt_GL)
    sanc_amt_list_HL.append(sanc_amt_HL)
    sanc_amt_list_LAS.append(sanc_amt_LAS)
    sanc_amt_list_MFBL.append(sanc_amt_MFBL)
    sanc_amt_list_MFHL.append(sanc_amt_MFHL)
    sanc_amt_list_MFOT.append(sanc_amt_MFOT)
    sanc_amt_list_OTH.append(sanc_amt_OTH)
    sanc_amt_list_PL.append(sanc_amt_PL)
    sanc_amt_list_PLBL.append(sanc_amt_PLBL)
    sanc_amt_list_RL.append(sanc_amt_RL)
    sanc_amt_list_SEL.append(sanc_amt_SEL)
    
    sanc_amt_AL = list()
    sanc_amt_BL = list()
    sanc_amt_CD = list()
    sanc_amt_CV = list()
    sanc_amt_GL = list()
    sanc_amt_HL = list()
    sanc_amt_LAS = list()
    sanc_amt_MFBL = list()
    sanc_amt_MFHL = list()
    sanc_amt_MFOT = list()
    sanc_amt_OTH = list()
    sanc_amt_PL = list()
    sanc_amt_PLBL = list()
    sanc_amt_RL = list()
    sanc_amt_SEL = list()
    
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['dateClosed'][i]!='unknown') or (grp_slice['sanctionAmount'][i]=='unknown'):
            Med_SancAmt_L_AL.append('unknown')
            Med_SancAmt_L_BL.append('unknown')
            Med_SancAmt_L_CD.append('unknown')
            Med_SancAmt_L_CV.append('unknown')
            Med_SancAmt_L_GL.append('unknown')
            Med_SancAmt_L_HL.append('unknown')
            Med_SancAmt_L_LAS.append('unknown')
            Med_SancAmt_L_MFBL.append('unknown')
            Med_SancAmt_L_MFHL.append('unknown')
            Med_SancAmt_L_MFOT.append('unknown')
            Med_SancAmt_L_OTH.append('unknown')
            Med_SancAmt_L_PL.append('unknown')
            Med_SancAmt_L_PLBL.append('unknown')
            Med_SancAmt_L_RL.append('unknown')
            Med_SancAmt_L_SEL.append('unknown')
        else:
            Med_SancAmt_L_AL.append(np.median(sanc_amt_list_AL[x]))
            Med_SancAmt_L_BL.append(np.median(sanc_amt_list_BL[x]))
            Med_SancAmt_L_CD.append(np.median(sanc_amt_list_CD[x]))
            Med_SancAmt_L_CV.append(np.median(sanc_amt_list_CV[x]))
            Med_SancAmt_L_GL.append(np.median(sanc_amt_list_GL[x]))
            Med_SancAmt_L_HL.append(np.median(sanc_amt_list_HL[x]))
            Med_SancAmt_L_LAS.append(np.median(sanc_amt_list_LAS[x]))
            Med_SancAmt_L_MFBL.append(np.median(sanc_amt_list_MFBL[x]))
            Med_SancAmt_L_MFHL.append(np.median(sanc_amt_list_MFHL[x]))
            Med_SancAmt_L_MFOT.append(np.median(sanc_amt_list_MFOT[x]))
            Med_SancAmt_L_OTH.append(np.median(sanc_amt_list_OTH[x]))
            Med_SancAmt_L_PL.append(np.median(sanc_amt_list_PL[x]))
            Med_SancAmt_L_PLBL.append(np.median(sanc_amt_list_PLBL[x]))
            Med_SancAmt_L_RL.append(np.median(sanc_amt_list_RL[x]))
            Med_SancAmt_L_SEL.append(np.median(sanc_amt_list_SEL[x]))
            
df['Med_SancAmt_L_AL'] = pd.Series(Med_SancAmt_L_AL).values
df['Med_SancAmt_L_BL'] = pd.Series(Med_SancAmt_L_BL).values
df['Med_SancAmt_L_CD'] = pd.Series(Med_SancAmt_L_CD).values
df['Med_SancAmt_L_CV'] = pd.Series(Med_SancAmt_L_CV).values
df['Med_SancAmt_L_GL'] = pd.Series(Med_SancAmt_L_GL).values
df['Med_SancAmt_L_HL'] = pd.Series(Med_SancAmt_L_HL).values
df['Med_SancAmt_L_LAS'] = pd.Series(Med_SancAmt_L_LAS).values
df['Med_SancAmt_L_MFBL'] = pd.Series(Med_SancAmt_L_MFBL).values
df['Med_SancAmt_L_MFHL'] = pd.Series(Med_SancAmt_L_MFHL).values
df['Med_SancAmt_L_MFOT'] = pd.Series(Med_SancAmt_L_MFOT).values
df['Med_SancAmt_L_OTH'] = pd.Series(Med_SancAmt_L_OTH).values
df['Med_SancAmt_L_PL'] = pd.Series(Med_SancAmt_L_PL).values
df['Med_SancAmt_L_PLBL'] = pd.Series(Med_SancAmt_L_PLBL).values
df['Med_SancAmt_L_RL'] = pd.Series(Med_SancAmt_L_RL).values
df['Med_SancAmt_L_SEL'] = pd.Series(Med_SancAmt_L_SEL).values

# %% [raw]
# a = df[['ID','Med_SancAmt_L_PL','dateClosed','accountType','sanctionAmount']]
# a[a['accountType']!=10].head(60)

# %% [markdown]
# <a id='Mode_SancAmt_Prodwise'></a>
# ### Code for Mode_SancAmt_Prodwise

# %% [markdown]
# - Indicates the maximum sanctioned amount per product (excluding thr account types -10,35,36)
# - For an applicant, for each product (excluding account types - 10,35,36), compute the mode of sanctioned amount for the loans

# %%
a = np.ones(4462)
df['Mode_SancAmt_AL'] = pd.Series(a).values
df['Mode_SancAmt_AL'] = pd.Series(a).values
df['Mode_SancAmt_BL'] = pd.Series(a).values
df['Mode_SancAmt_CD'] = pd.Series(a).values
df['Mode_SancAmt_CV'] = pd.Series(a).values
df['Mode_SancAmt_GL'] = pd.Series(a).values
df['Mode_SancAmt_HL'] = pd.Series(a).values
df['Mode_SancAmt_LAS'] = pd.Series(a).values
df['Mode_SancAmt_MFBL'] = pd.Series(a).values
df['Mode_SancAmt_MFHL'] = pd.Series(a).values
df['Mode_SancAmt_MFOT'] = pd.Series(a).values
df['Mode_SancAmt_OTH'] = pd.Series(a).values
df['Mode_SancAmt_PL'] = pd.Series(a).values
df['Mode_SancAmt_PLBL'] = pd.Series(a).values
df['Mode_SancAmt_RL'] = pd.Series(a).values
df['Mode_SancAmt_SEL'] = pd.Series(a).values

# %%
Mode_SancAmt_AL = list()
Mode_SancAmt_BL = list()
Mode_SancAmt_CD = list()
Mode_SancAmt_CV = list()
Mode_SancAmt_GL = list()
Mode_SancAmt_HL = list()
Mode_SancAmt_LAS = list()
Mode_SancAmt_MFBL = list()
Mode_SancAmt_MFHL = list()
Mode_SancAmt_MFOT = list()
Mode_SancAmt_OTH = list()
Mode_SancAmt_PL = list()
Mode_SancAmt_PLBL = list()
Mode_SancAmt_RL = list()
Mode_SancAmt_SEL = list()

sanc_amt_list_AL = list()
sanc_amt_list_BL = list()
sanc_amt_list_CD = list()
sanc_amt_list_CV = list()
sanc_amt_list_GL = list()
sanc_amt_list_HL = list()
sanc_amt_list_LAS = list()
sanc_amt_list_MFBL = list()
sanc_amt_list_MFHL = list()
sanc_amt_list_MFOT = list()
sanc_amt_list_OTH = list()
sanc_amt_list_PL = list()
sanc_amt_list_PLBL = list()
sanc_amt_list_RL = list()
sanc_amt_list_SEL = list()

sanc_amt_AL = list()
sanc_amt_BL = list()
sanc_amt_CD = list()
sanc_amt_CV = list()
sanc_amt_GL = list()
sanc_amt_HL = list()
sanc_amt_LAS = list()
sanc_amt_MFBL = list()
sanc_amt_MFHL = list()
sanc_amt_MFOT = list()
sanc_amt_OTH = list()
sanc_amt_PL = list() 
sanc_amt_PLBL = list()
sanc_amt_RL = list()
sanc_amt_SEL = list()

grp_df = df.groupby('ID')

for x in range(0, len(unq_id_list)):
    grp_slice = grp_df.get_group(unq_id_list[x])
    #print(grp_slice)
    grp_slice.reset_index(drop=True, inplace=True)
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['sanctionAmount'][i]=='unknown'):
            continue
        elif (grp_slice['accountType'][i]=='AL'):
            sanc_amt_AL.append(float(grp_slice['sanctionAmount'][i]))
        elif (grp_slice['accountType'][i]=='BL'):
            sanc_amt_BL.append(float(grp_slice['sanctionAmount'][i]))
        elif (grp_slice['accountType'][i]=='CD'):
            sanc_amt_CD.append(float(grp_slice['sanctionAmount'][i]))
        elif (grp_slice['accountType'][i]=='CV'):
            sanc_amt_CV.append(float(grp_slice['sanctionAmount'][i]))
        elif (grp_slice['accountType'][i]=='GL'):
            sanc_amt_GL.append(float(grp_slice['sanctionAmount'][i]))
        elif (grp_slice['accountType'][i]=='HL'):
            sanc_amt_HL.append(float(grp_slice['sanctionAmount'][i]))
        elif (grp_slice['accountType'][i]=='LAS'):
            sanc_amt_LAS.append(float(grp_slice['sanctionAmount'][i]))
        elif (grp_slice['accountType'][i]=='MFBL'):
            sanc_amt_MFBL.append(float(grp_slice['sanctionAmount'][i]))
        elif (grp_slice['accountType'][i]=='MFHL'):
            sanc_amt_MFHL.append(float(grp_slice['sanctionAmount'][i]))
        elif (grp_slice['accountType'][i]=='MFOT'):
            sanc_amt_MFOT.append(float(grp_slice['sanctionAmount'][i]))
        elif (grp_slice['accountType'][i]=='OTH'):
            sanc_amt_OTH.append(float(grp_slice['sanctionAmount'][i]))
        elif (grp_slice['accountType'][i]=='PL'):
            sanc_amt_PL.append(float(grp_slice['sanctionAmount'][i]))
        elif (grp_slice['accountType'][i]=='PLBL'):
            sanc_amt_PLBL.append(float(grp_slice['sanctionAmount'][i]))
        elif (grp_slice['accountType'][i]=='RL'):
            sanc_amt_RL.append(float(grp_slice['sanctionAmount'][i]))
        elif (grp_slice['accountType'][i]=='SEL'):
            sanc_amt_SEL.append(float(grp_slice['sanctionAmount'][i]))
            
    sanc_amt_list_AL.append(sanc_amt_AL)
    sanc_amt_list_BL.append(sanc_amt_BL)
    sanc_amt_list_CD.append(sanc_amt_CD)
    sanc_amt_list_CV.append(sanc_amt_CV)
    sanc_amt_list_GL.append(sanc_amt_GL)
    sanc_amt_list_HL.append(sanc_amt_HL)
    sanc_amt_list_LAS.append(sanc_amt_LAS)
    sanc_amt_list_MFBL.append(sanc_amt_MFBL)
    sanc_amt_list_MFHL.append(sanc_amt_MFHL)
    sanc_amt_list_MFOT.append(sanc_amt_MFOT)
    sanc_amt_list_OTH.append(sanc_amt_OTH)
    sanc_amt_list_PL.append(sanc_amt_PL)
    sanc_amt_list_PLBL.append(sanc_amt_PLBL)
    sanc_amt_list_RL.append(sanc_amt_RL)
    sanc_amt_list_SEL.append(sanc_amt_SEL)
    
    sanc_amt_AL = list()
    sanc_amt_BL = list()
    sanc_amt_CD = list()
    sanc_amt_CV = list()
    sanc_amt_GL = list()
    sanc_amt_HL = list()
    sanc_amt_LAS = list()
    sanc_amt_MFBL = list()
    sanc_amt_MFHL = list()
    sanc_amt_MFOT = list()
    sanc_amt_OTH = list()
    sanc_amt_PL = list()
    sanc_amt_PLBL = list()
    sanc_amt_RL = list()
    sanc_amt_SEL = list()
    
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['sanctionAmount'][i]=='unknown') or pd.isnull(sanc_amt_list_AL[i]) or pd.isnull(sanc_amt_list_BL[i]): 
            Mode_SancAmt_AL.append('unknown')
            Mode_SancAmt_BL.append('unknown')
            Mode_SancAmt_CD.append('unknown')
            Mode_SancAmt_CV.append('unknown')
            Mode_SancAmt_GL.append('unknown')
            Mode_SancAmt_HL.append('unknown')
            Mode_SancAmt_LAS.append('unknown')
            Mode_SancAmt_MFBL.append('unknown')
            Mode_SancAmt_MFHL.append('unknown')
            Mode_SancAmt_MFOT.append('unknown')
            Mode_SancAmt_OTH.append('unknown')
            Mode_SancAmt_PL.append('unknown')
            Mode_SancAmt_PLBL.append('unknown')
            Mode_SancAmt_RL.append('unknown')
            Mode_SancAmt_SEL.append('unknown')
        else:
            Mode_SancAmt_AL.append(np.max(sanc_amt_list_AL[x]))
            Mode_SancAmt_BL.append(np.max(sanc_amt_list_BL[x]))
            Mode_SancAmt_CD.append(np.max(sanc_amt_list_CD[x]))
            Mode_SancAmt_CV.append(np.max(sanc_amt_list_CV[x]))
            Mode_SancAmt_GL.append(np.max(sanc_amt_list_GL[x]))
            Mode_SancAmt_HL.append(np.max(sanc_amt_list_HL[x]))
            Mode_SancAmt_LAS.append(np.max(sanc_amt_list_LAS[x]))
            Mode_SancAmt_MFBL.append(np.max(sanc_amt_list_MFBL[x]))
            Mode_SancAmt_MFHL.append(np.max(sanc_amt_list_MFHL[x]))
            Mode_SancAmt_MFOT.append(np.max(sanc_amt_list_MFOT[x]))
            Mode_SancAmt_OTH.append(np.max(sanc_amt_list_OTH[x]))
            Mode_SancAmt_PL.append(np.max(sanc_amt_list_PL[x]))
            Mode_SancAmt_PLBL.append(np.max(sanc_amt_list_PLBL[x]))
            Mode_SancAmt_RL.append(np.max(sanc_amt_list_RL[x]))
            Mode_SancAmt_SEL.append(np.max(sanc_amt_list_SEL[x]))
            
df['Mode_SancAmt_AL'] = pd.Series(Mode_SancAmt_AL).values
df['Mode_SancAmt_BL'] = pd.Series(Mode_SancAmt_BL).values
df['Mode_SancAmt_CD'] = pd.Series(Mode_SancAmt_CD).values
df['Mode_SancAmt_CV'] = pd.Series(Mode_SancAmt_CV).values
df['Mode_SancAmt_GL'] = pd.Series(Mode_SancAmt_GL).values
df['Mode_SancAmt_HL'] = pd.Series(Mode_SancAmt_HL).values
df['Mode_SancAmt_LAS'] = pd.Series(Mode_SancAmt_LAS).values
df['Mode_SancAmt_MFBL'] = pd.Series(Mode_SancAmt_MFBL).values
df['Mode_SancAmt_MFHL'] = pd.Series(Mode_SancAmt_MFHL).values
df['Mode_SancAmt_MFOT'] = pd.Series(Mode_SancAmt_MFOT).values
df['Mode_SancAmt_OTH'] = pd.Series(Mode_SancAmt_OTH).values
df['Mode_SancAmt_PL'] = pd.Series(Mode_SancAmt_PL).values
df['Mode_SancAmt_PLBL'] = pd.Series(Mode_SancAmt_PLBL).values
df['Mode_SancAmt_RL'] = pd.Series(Mode_SancAmt_RL).values
df['Mode_SancAmt_SEL'] = pd.Series(Mode_SancAmt_SEL).values
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-221-a0f08b9bff8a> in <module>
#     138         else:
#     139             Mode_SancAmt_AL.append(np.max(sanc_amt_list_AL[x]))
# --> 140             Mode_SancAmt_BL.append(np.max(sanc_amt_list_BL[x]))
#     141             Mode_SancAmt_CD.append(np.max(sanc_amt_list_CD[x]))
#     142             Mode_SancAmt_CV.append(np.max(sanc_amt_list_CV[x]))
#
# <__array_function__ internals> in amax(*args, **kwargs)
#
# ~/anaconda3/envs/ml_env/lib/python3.7/site-packages/numpy/core/fromnumeric.py in amax(a, axis, out, keepdims, initial, where)
#    2704     """
#    2705     return _wrapreduction(a, np.maximum, 'max', axis, None, out,
# -> 2706                           keepdims=keepdims, initial=initial, where=where)
#    2707
#    2708
#
# ~/anaconda3/envs/ml_env/lib/python3.7/site-packages/numpy/core/fromnumeric.py in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      85                 return reduction(axis=axis, out=out, **passkwargs)
#      86
# ---> 87     return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#      88
#      89
#
# ValueError: zero-size array to reduction operation maximum which has no identity

# %%
a = df[['ID','Mode_SancAmt_CD','accountType','sanctionAmount']]
a.head(60)
#a[a['accountType']=='BL'].head(60)

# %% [markdown]
# ### Code for Mode_SancAmt_Prodwise_L

# %% [markdown]
# - Indicates the maximum sanctioned amount per live product (excluding thr account types -10,35,36)
# - For an applicant, for each product (excluding account types - 10,35,36), compute the mode of sanctioned amount for the loans where dateClosed is null

# %% [raw]
# Mode_SancAmt_L_AL = list()
# Mode_SancAmt_L_BL = list()
# Mode_SancAmt_L_CD = list()
# Mode_SancAmt_L_CV = list()
# Mode_SancAmt_L_GL = list()
# Mode_SancAmt_L_HL = list()
# Mode_SancAmt_L_LAS = list()
# Mode_SancAmt_L_MFBL = list()
# Mode_SancAmt_L_MFHL = list()
# Mode_SancAmt_L_MFOT = list()
# Mode_SancAmt_L_OTH = list()
# Mode_SancAmt_L_PL = list()
# Mode_SancAmt_L_PLBL = list()
# Mode_SancAmt_L_RL = list()
# Mode_SancAmt_L_SEL = list()
#
# sanc_amt_list_AL = list()
# sanc_amt_list_BL = list()
# sanc_amt_list_CD = list()
# sanc_amt_list_CV = list()
# sanc_amt_list_GL = list()
# sanc_amt_list_HL = list()
# sanc_amt_list_LAS = list()
# sanc_amt_list_MFBL = list()
# sanc_amt_list_MFHL = list()
# sanc_amt_list_MFOT = list()
# sanc_amt_list_OTH = list()
# sanc_amt_list_PL = list()
# sanc_amt_list_PLBL = list()
# sanc_amt_list_RL = list()
# sanc_amt_list_SEL = list()
#
# sanc_amt_AL = list()
# sanc_amt_BL = list()
# sanc_amt_CD = list()
# sanc_amt_CV = list()
# sanc_amt_GL = list()
# sanc_amt_HL = list()
# sanc_amt_LAS = list()
# sanc_amt_MFBL = list()
# sanc_amt_MFHL = list()
# sanc_amt_MFOT = list()
# sanc_amt_OTH = list()
# sanc_amt_PL = list()
# sanc_amt_PLBL = list()
# sanc_amt_RL = list()
# sanc_amt_SEL = list()
#
# grp_df = df.groupby('ID')
#
# for x in range(0, len(unq_id_list)):
#     grp_slice = grp_df.get_group(unq_id_list[x])
#     #print(grp_slice)
#     grp_slice.reset_index(drop=True, inplace=True)
#     for i in range(0, grp_slice.shape[0]):
#         if (grp_slice['dateClosed'][i]!='unknown') or (grp_slice['sanctionAmount'][i]=='unknown'):
#             continue
#         elif (grp_slice['accountType'][i]=='AL'):
#             sanc_amt_AL.append(float(grp_slice['sanctionAmount'][i]))
#         elif (grp_slice['accountType'][i]=='BL'):
#             sanc_amt_BL.append(float(grp_slice['sanctionAmount'][i]))
#         elif (grp_slice['accountType'][i]=='CD'):
#             sanc_amt_CD.append(float(grp_slice['sanctionAmount'][i]))
#         elif (grp_slice['accountType'][i]=='CV'):
#             sanc_amt_CV.append(float(grp_slice['sanctionAmount'][i]))
#         elif (grp_slice['accountType'][i]=='GL'):
#             sanc_amt_GL.append(float(grp_slice['sanctionAmount'][i]))
#         elif (grp_slice['accountType'][i]=='HL'):
#             sanc_amt_HL.append(float(grp_slice['sanctionAmount'][i]))
#         elif (grp_slice['accountType'][i]=='LAS'):
#             sanc_amt_LAS.append(float(grp_slice['sanctionAmount'][i]))
#         elif (grp_slice['accountType'][i]=='MFBL'):
#             sanc_amt_MFBL.append(float(grp_slice['sanctionAmount'][i]))
#         elif (grp_slice['accountType'][i]=='MFHL'):
#             sanc_amt_MFHL.append(float(grp_slice['sanctionAmount'][i]))
#         elif (grp_slice['accountType'][i]=='MFOT'):
#             sanc_amt_MFOT.append(float(grp_slice['sanctionAmount'][i]))
#         elif (grp_slice['accountType'][i]=='OTH'):
#             sanc_amt_OTH.append(float(grp_slice['sanctionAmount'][i]))
#         elif (grp_slice['accountType'][i]=='PL'):
#             sanc_amt_PL.append(float(grp_slice['sanctionAmount'][i]))
#         elif (grp_slice['accountType'][i]=='PLBL'):
#             sanc_amt_PLBL.append(float(grp_slice['sanctionAmount'][i]))
#         elif (grp_slice['accountType'][i]=='RL'):
#             sanc_amt_RL.append(float(grp_slice['sanctionAmount'][i]))
#         elif (grp_slice['accountType'][i]=='SEL'):
#             sanc_amt_SEL.append(float(grp_slice['sanctionAmount'][i]))
#
#     sanc_amt_list_AL.append(sanc_amt_AL)
#     sanc_amt_list_BL.append(sanc_amt_BL)
#     sanc_amt_list_CD.append(sanc_amt_CD)
#     sanc_amt_list_CV.append(sanc_amt_CV)
#     sanc_amt_list_GL.append(sanc_amt_GL)
#     sanc_amt_list_HL.append(sanc_amt_HL)
#     sanc_amt_list_LAS.append(sanc_amt_LAS)
#     sanc_amt_list_MFBL.append(sanc_amt_MFBL)
#     sanc_amt_list_MFHL.append(sanc_amt_MFHL)
#     sanc_amt_list_MFOT.append(sanc_amt_MFOT)
#     sanc_amt_list_OTH.append(sanc_amt_OTH)
#     sanc_amt_list_PL.append(sanc_amt_PL)
#     sanc_amt_list_PLBL.append(sanc_amt_PLBL)
#     sanc_amt_list_RL.append(sanc_amt_RL)
#     sanc_amt_list_SEL.append(sanc_amt_SEL)
#
#     sanc_amt_AL = list()
#     sanc_amt_BL = list()
#     sanc_amt_CD = list()
#     sanc_amt_CV = list()
#     sanc_amt_GL = list()
#     sanc_amt_HL = list()
#     sanc_amt_LAS = list()
#     sanc_amt_MFBL = list()
#     sanc_amt_MFHL = list()
#     sanc_amt_MFOT = list()
#     sanc_amt_OTH = list()
#     sanc_amt_PL = list()
#     sanc_amt_PLBL = list()
#     sanc_amt_RL = list()
#     sanc_amt_SEL = list()
#
#     for i in range(0, grp_slice.shape[0]):
#         if (grp_slice['dateClosed'][i]!='unknown') or (grp_slice['sanctionAmount'][i]=='unknown'):
#             Mode_SancAmt_L_AL.append('unknown')
#             Mode_SancAmt_L_BL.append('unknown')
#             Mode_SancAmt_L_CD.append('unknown')
#             Mode_SancAmt_L_CV.append('unknown')
#             Mode_SancAmt_L_GL.append('unknown')
#             Mode_SancAmt_L_HL.append('unknown')
#             Mode_SancAmt_L_LAS.append('unknown')
#             Mode_SancAmt_L_MFBL.append('unknown')
#             Mode_SancAmt_L_MFHL.append('unknown')
#             Mode_SancAmt_L_MFOT.append('unknown')
#             Mode_SancAmt_L_OTH.append('unknown')
#             Mode_SancAmt_L_PL.append('unknown')
#             Mode_SancAmt_L_PLBL.append('unknown')
#             Mode_SancAmt_L_RL.append('unknown')
#             Mode_SancAmt_L_SEL.append('unknown')
#         else:
#             Mode_SancAmt_L_AL.append(np.max(sanc_amt_list_AL[x]))
#             Mode_SancAmt_L_BL.append(np.max(sanc_amt_list_BL[x]))
#             Mode_SancAmt_L_CD.append(np.max(sanc_amt_list_CD[x]))
#             Mode_SancAmt_L_CV.append(np.max(sanc_amt_list_CV[x]))
#             Mode_SancAmt_L_GL.append(np.max(sanc_amt_list_GL[x]))
#             Mode_SancAmt_L_HL.append(np.max(sanc_amt_list_HL[x]))
#             Mode_SancAmt_L_LAS.append(np.max(sanc_amt_list_LAS[x]))
#             Mode_SancAmt_L_MFBL.append(np.max(sanc_amt_list_MFBL[x]))
#             Mode_SancAmt_L_MFHL.append(np.max(sanc_amt_list_MFHL[x]))
#             Mode_SancAmt_L_MFOT.append(np.max(sanc_amt_list_MFOT[x]))
#             Mode_SancAmt_L_OTH.append(np.max(sanc_amt_list_OTH[x]))
#             Mode_SancAmt_L_PL.append(np.max(sanc_amt_list_PL[x]))
#             Mode_SancAmt_L_PLBL.append(np.max(sanc_amt_list_PLBL[x]))
#             Mode_SancAmt_L_RL.append(np.max(sanc_amt_list_RL[x]))
#             Mode_SancAmt_L_SEL.append(np.max(sanc_amt_list_SEL[x]))
#
# df['Mode_SancAmt_L_AL'] = pd.Series(Mode_SancAmt_L_AL).values
# df['Mode_SancAmt_L_BL'] = pd.Series(Mode_SancAmt_L_BL).values
# df['Mode_SancAmt_L_CD'] = pd.Series(Mode_SancAmt_L_CD).values
# df['Mode_SancAmt_L_CV'] = pd.Series(Mode_SancAmt_L_CV).values
# df['Mode_SancAmt_L_GL'] = pd.Series(Mode_SancAmt_L_GL).values
# df['Mode_SancAmt_L_HL'] = pd.Series(Mode_SancAmt_L_HL).values
# df['Mode_SancAmt_L_LAS'] = pd.Series(Mode_SancAmt_L_LAS).values
# df['Mode_SancAmt_L_MFBL'] = pd.Series(Mode_SancAmt_L_MFBL).values
# df['Mode_SancAmt_L_MFHL'] = pd.Series(Mode_SancAmt_L_MFHL).values
# df['Mode_SancAmt_L_MFOT'] = pd.Series(Mode_SancAmt_L_MFOT).values
# df['Mode_SancAmt_L_OTH'] = pd.Series(Mode_SancAmt_L_OTH).values
# df['Mode_SancAmt_L_PL'] = pd.Series(Mode_SancAmt_L_PL).values
# df['Mode_SancAmt_L_PLBL'] = pd.Series(Mode_SancAmt_L_PLBL).values
# df['Mode_SancAmt_L_RL'] = pd.Series(Mode_SancAmt_L_RL).values
# df['Mode_SancAmt_L_SEL'] = pd.Series(Mode_SancAmt_L_SEL).values

# %% [raw]
# a = df[['ID','Mode_SancAmt_L','dateClosed','accountType','sanctionAmount']]
# a[a['accountType']!=10].head(60)

# %% [markdown]
# <a id='currentBalance_sanctionedAmount_NCC_L_P'></a>
# ### Code for currentBalance_sanctionedAmount_NCC_L_P

# %% [markdown]
# - Ratio of current balance to total amount sanctioned for all the live accounts per product (other than credit cards)
# - For an applicant for all the accounts other than credit card (account type=10,35,36) where DateClosed is null and current balance>0, ratio of sum(current balance)/ sum(sanctioned amount) per product

# %%
start_time = time.time()    #You can use time.clock() also

currentBalance_sanctionedAmount_NCC_L_AL = list()
currentBalance_sanctionedAmount_NCC_L_BL = list()
currentBalance_sanctionedAmount_NCC_L_CD = list()
currentBalance_sanctionedAmount_NCC_L_CV = list()
currentBalance_sanctionedAmount_NCC_L_GL = list()
currentBalance_sanctionedAmount_NCC_L_HL = list()
currentBalance_sanctionedAmount_NCC_L_LAS = list()
currentBalance_sanctionedAmount_NCC_L_MFBL = list()
currentBalance_sanctionedAmount_NCC_L_MFHL = list()
currentBalance_sanctionedAmount_NCC_L_MFOT = list()
currentBalance_sanctionedAmount_NCC_L_OTH = list()
currentBalance_sanctionedAmount_NCC_L_PL = list()
currentBalance_sanctionedAmount_NCC_L_PLBL = list()
currentBalance_sanctionedAmount_NCC_L_RL = list()
currentBalance_sanctionedAmount_NCC_L_SEL = list()

currentBalance_AL = list()
currentBalance_BL = list()
currentBalance_CD = list()
currentBalance_CV = list()
currentBalance_GL = list()
currentBalance_HL = list()
currentBalance_LAS = list()
currentBalance_MFBL = list()
currentBalance_MFHL = list()
currentBalance_MFOT = list()
currentBalance_OTH = list()
currentBalance_PL = list()
currentBalance_PLBL = list()
currentBalance_RL = list()
currentBalance_SEL = list()

sanctionedAmount_AL = list()
sanctionedAmount_BL = list()
sanctionedAmount_CD = list()
sanctionedAmount_CV = list()
sanctionedAmount_GL = list()
sanctionedAmount_HL = list()
sanctionedAmount_LAS = list()
sanctionedAmount_MFBL = list()
sanctionedAmount_MFHL = list()
sanctionedAmount_MFOT = list()
sanctionedAmount_OTH = list()
sanctionedAmount_PL = list()
sanctionedAmount_PLBL = list()
sanctionedAmount_RL = list()
sanctionedAmount_SEL = list()

currBal_AL = 0
currBal_BL = 0
currBal_CD = 0
currBal_CV = 0
currBal_GL = 0
currBal_HL = 0
currBal_LAS = 0
currBal_MFBL = 0
currBal_MFHL = 0
currBal_MFOT = 0
currBal_OTH = 0
currBal_PL = 0
currBal_PLBL = 0
currBal_RL = 0
currBal_SEL = 0

sanc_amt_AL = 0
sanc_amt_BL = 0
sanc_amt_CD = 0
sanc_amt_CV = 0
sanc_amt_GL = 0
sanc_amt_HL = 0
sanc_amt_LAS = 0
sanc_amt_MFBL = 0
sanc_amt_MFHL = 0
sanc_amt_MFOT = 0
sanc_amt_OTH = 0
sanc_amt_PL = 0
sanc_amt_PLBL = 0
sanc_amt_RL = 0
sanc_amt_SEL = 0

grp_df = df.groupby('ID')

for x in range(0, len(unq_id_list)):
    grp_slice = grp_df.get_group(unq_id_list[x])
    # print(grp_slice)
    grp_slice.reset_index(drop=True, inplace=True)
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['dateClosed'][i] != 'unknown') or (grp_slice['currentBalance'][i] == 'unknown') or (grp_slice['sanctionAmount'][i] == 'unknown'):
            continue
        elif (grp_slice['accountType'][i] == 'AL'):
            currBal_AL = float(grp_slice['currentBalance'][i])
            sanc_amt_AL = float(grp_slice['sanctionAmount'][i])
        elif (grp_slice['accountType'][i] == 'BL'):
            currBal_BL = float(grp_slice['currentBalance'][i])
            sanc_amt_BL = float(grp_slice['sanctionAmount'][i])
        elif (grp_slice['accountType'][i] == 'CD'):
            currBal_CD = float(grp_slice['currentBalance'][i])
            sanc_amt_CD = float(grp_slice['sanctionAmount'][i])
        elif (grp_slice['accountType'][i] == 'CV'):
            currBal_CV = float(grp_slice['currentBalance'][i])
            sanc_amt_CV = float(grp_slice['sanctionAmount'][i])
        elif (grp_slice['accountType'][i] == 'GL'):
            currBal_GL = float(grp_slice['currentBalance'][i])
            sanc_amt_GL = float(grp_slice['sanctionAmount'][i])
        elif (grp_slice['accountType'][i] == 'HL'):
            currBal_HL = float(grp_slice['currentBalance'][i])
            sanc_amt_HL = float(grp_slice['sanctionAmount'][i])
        elif (grp_slice['accountType'][i] == 'LAS'):
            currBal_LAS = float(grp_slice['currentBalance'][i])
            sanc_amt_LAS = float(grp_slice['sanctionAmount'][i])
        elif (grp_slice['accountType'][i] == 'MFBL'):
            currBal_MFBL = float(grp_slice['currentBalance'][i])
            sanc_amt_MFBL = float(grp_slice['sanctionAmount'][i])
        elif (grp_slice['accountType'][i] == 'MFHL'):
            currBal_MFHL = float(grp_slice['currentBalance'][i])
            sanc_amt_MFHL = float(grp_slice['sanctionAmount'][i])
        elif (grp_slice['accountType'][i] == 'MFOT'):
            currBal_MFOT = float(grp_slice['currentBalance'][i])
            sanc_amt_MFOT = float(grp_slice['sanctionAmount'][i])
        elif (grp_slice['accountType'][i] == 'OTH'):
            currBal_OTH = float(grp_slice['currentBalance'][i])
            sanc_amt_OTH = float(grp_slice['sanctionAmount'][i])
        elif (grp_slice['accountType'][i] == 'PL'):
            currBal_PL = float(grp_slice['currentBalance'][i])
            sanc_amt_PL = float(grp_slice['sanctionAmount'][i])
        elif (grp_slice['accountType'][i] == 'PLBL'):
            currBal_PLBL = float(grp_slice['currentBalance'][i])
            sanc_amt_PLBL = float(grp_slice['sanctionAmount'][i])
        elif (grp_slice['accountType'][i] == 'RL'):
            currBal_RL = float(grp_slice['currentBalance'][i])
            sanc_amt_RL = float(grp_slice['sanctionAmount'][i])
        elif (grp_slice['accountType'][i] == 'SEL'):
            currBal_SEL = float(grp_slice['currentBalance'][i])
            sanc_amt_SEL = float(grp_slice['sanctionAmount'][i])

    currentBalance_AL.append(currBal_AL)
    currentBalance_BL.append(currBal_BL)
    currentBalance_CD.append(currBal_CD)
    currentBalance_CV.append(currBal_CV)
    currentBalance_GL.append(currBal_GL)
    currentBalance_HL.append(currBal_HL)
    currentBalance_LAS.append(currBal_LAS)
    currentBalance_MFBL.append(currBal_MFBL)
    currentBalance_MFHL.append(currBal_MFHL)
    currentBalance_MFOT.append(currBal_MFOT)
    currentBalance_OTH.append(currBal_OTH)
    currentBalance_PL.append(currBal_PL)
    currentBalance_PLBL.append(currBal_PLBL)
    currentBalance_RL.append(currBal_RL)
    currentBalance_SEL.append(currBal_SEL)

    sanctionedAmount_AL.append(sanc_amt_AL)
    sanctionedAmount_BL.append(sanc_amt_BL)
    sanctionedAmount_CD.append(sanc_amt_CD)
    sanctionedAmount_CV.append(sanc_amt_CV)
    sanctionedAmount_GL.append(sanc_amt_GL)
    sanctionedAmount_HL.append(sanc_amt_HL)
    sanctionedAmount_LAS.append(sanc_amt_LAS)
    sanctionedAmount_MFBL.append(sanc_amt_MFBL)
    sanctionedAmount_MFHL.append(sanc_amt_MFHL)
    sanctionedAmount_MFOT.append(sanc_amt_MFOT)
    sanctionedAmount_OTH.append(sanc_amt_OTH)
    sanctionedAmount_PL.append(sanc_amt_PL)
    sanctionedAmount_PLBL.append(sanc_amt_PLBL)
    sanctionedAmount_RL.append(sanc_amt_RL)
    sanctionedAmount_SEL.append(sanc_amt_SEL)

    currBal_AL = 0
    currBal_BL = 0
    currBal_CD = 0
    currBal_CV = 0
    currBal_GL = 0
    currBal_HL = 0
    currBal_LAS = 0
    currBal_MFBL = 0
    currBal_MFHL = 0
    currBal_MFOT = 0
    currBal_OTH = 0
    currBal_PL = 0
    currBal_PLBL = 0
    currBal_RL = 0
    currBal_SEL = 0

    sanc_amt_AL = 0
    sanc_amt_BL = 0
    sanc_amt_CD = 0
    sanc_amt_CV = 0
    sanc_amt_GL = 0
    sanc_amt_HL = 0
    sanc_amt_LAS = 0
    sanc_amt_MFBL = 0
    sanc_amt_MFHL = 0
    sanc_amt_MFOT = 0
    sanc_amt_OTH = 0
    sanc_amt_PL = 0
    sanc_amt_PLBL = 0
    sanc_amt_RL = 0
    sanc_amt_SEL = 0
    
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['dateClosed'][i] != 'unknown') or (grp_slice['accountType'][i] == 'CC') or (grp_slice['accountType'][i] == 'SCC') or (grp_slice['currentBalance'][i] == 'unknown') or (sum(sanctionedAmount_AL) == 0):
            currentBalance_sanctionedAmount_NCC_L_AL.append('unknown')
        else:
            currentBalance_sanctionedAmount_NCC_L_AL.append(sum(currentBalance_AL)/sum(sanctionedAmount_AL))
        
        if (grp_slice['dateClosed'][i] != 'unknown') or (grp_slice['accountType'][i] == 'CC') or (grp_slice['accountType'][i] == 'SCC') or (grp_slice['currentBalance'][i] == 'unknown') or (sum(sanctionedAmount_BL) == 0):
            currentBalance_sanctionedAmount_NCC_L_BL.append('unknown')
        else:
            currentBalance_sanctionedAmount_NCC_L_BL.append(sum(currentBalance_BL)/sum(sanctionedAmount_BL))
            
        if (grp_slice['dateClosed'][i] != 'unknown') or (grp_slice['accountType'][i] == 'CC') or (grp_slice['accountType'][i] == 'SCC') or (grp_slice['currentBalance'][i] == 'unknown') or (sum(sanctionedAmount_CD) == 0):
            currentBalance_sanctionedAmount_NCC_L_CD.append('unknown')
        else:
            currentBalance_sanctionedAmount_NCC_L_CD.append(sum(currentBalance_CD)/sum(sanctionedAmount_CD))
            
        if (grp_slice['dateClosed'][i] != 'unknown') or (grp_slice['accountType'][i] == 'CC') or (grp_slice['accountType'][i] == 'SCC') or (grp_slice['currentBalance'][i] == 'unknown') or (sum(sanctionedAmount_CV) == 0):
            currentBalance_sanctionedAmount_NCC_L_CV.append('unknown')
        else:
            currentBalance_sanctionedAmount_NCC_L_CV.append(sum(currentBalance_CV)/sum(sanctionedAmount_CV))
            
        if (grp_slice['dateClosed'][i] != 'unknown') or (grp_slice['accountType'][i] == 'CC') or (grp_slice['accountType'][i] == 'SCC') or (grp_slice['currentBalance'][i] == 'unknown') or (sum(sanctionedAmount_GL) == 0):
            currentBalance_sanctionedAmount_NCC_L_GL.append('unknown')
        else:
            currentBalance_sanctionedAmount_NCC_L_GL.append(sum(currentBalance_GL)/sum(sanctionedAmount_GL))
            
        if (grp_slice['dateClosed'][i] != 'unknown') or (grp_slice['accountType'][i] == 'CC') or (grp_slice['accountType'][i] == 'SCC') or (grp_slice['currentBalance'][i] == 'unknown') or (sum(sanctionedAmount_HL) == 0):
            currentBalance_sanctionedAmount_NCC_L_HL.append('unknown')
        else:
            currentBalance_sanctionedAmount_NCC_L_HL.append(sum(currentBalance_HL)/sum(sanctionedAmount_HL))
            
        if (grp_slice['dateClosed'][i] != 'unknown') or (grp_slice['accountType'][i] == 'CC') or (grp_slice['accountType'][i] == 'SCC') or (grp_slice['currentBalance'][i] == 'unknown') or (sum(sanctionedAmount_LAS) == 0):
            currentBalance_sanctionedAmount_NCC_L_LAS.append('unknown')
        else:
            currentBalance_sanctionedAmount_NCC_L_LAS.append(sum(currentBalance_LAS)/sum(sanctionedAmount_LAS))
            
        if (grp_slice['dateClosed'][i] != 'unknown') or (grp_slice['accountType'][i] == 'CC') or (grp_slice['accountType'][i] == 'SCC') or (grp_slice['currentBalance'][i] == 'unknown') or (sum(sanctionedAmount_MFBL) == 0):
            currentBalance_sanctionedAmount_NCC_L_MFBL.append('unknown')
        else:
            currentBalance_sanctionedAmount_NCC_L_MFBL.append(sum(currentBalance_MFBL)/sum(sanctionedAmount_MFBL))
            
        if (grp_slice['dateClosed'][i] != 'unknown') or (grp_slice['accountType'][i] == 'CC') or (grp_slice['accountType'][i] == 'SCC') or (grp_slice['currentBalance'][i] == 'unknown') or (sum(sanctionedAmount_MFHL) == 0):
            currentBalance_sanctionedAmount_NCC_L_MFHL.append('unknown')
        else:
            currentBalance_sanctionedAmount_NCC_L_MFHL.append(sum(currentBalance_MFHL)/sum(sanctionedAmount_MFHL))
            
        if (grp_slice['dateClosed'][i] != 'unknown') or (grp_slice['accountType'][i] == 'CC') or (grp_slice['accountType'][i] == 'SCC') or (grp_slice['currentBalance'][i] == 'unknown') or (sum(sanctionedAmount_MFOT) == 0):
            currentBalance_sanctionedAmount_NCC_L_MFOT.append('unknown')
        else:
            currentBalance_sanctionedAmount_NCC_L_MFOT.append(sum(currentBalance_MFOT)/sum(sanctionedAmount_MFOT))
            
        if (grp_slice['dateClosed'][i] != 'unknown') or (grp_slice['accountType'][i] == 'CC') or (grp_slice['accountType'][i] == 'SCC') or (grp_slice['currentBalance'][i] == 'unknown') or (sum(sanctionedAmount_OTH) == 0):
            currentBalance_sanctionedAmount_NCC_L_OTH.append('unknown')
        else:
            currentBalance_sanctionedAmount_NCC_L_OTH.append(sum(currentBalance_OTH)/sum(sanctionedAmount_OTH))
            
        if (grp_slice['dateClosed'][i] != 'unknown') or (grp_slice['accountType'][i] == 'CC') or (grp_slice['accountType'][i] == 'SCC') or (grp_slice['currentBalance'][i] == 'unknown') or (sum(sanctionedAmount_PL) == 0):
            currentBalance_sanctionedAmount_NCC_L_PL.append('unknown')
        else:
            currentBalance_sanctionedAmount_NCC_L_PL.append(sum(currentBalance_PL)/sum(sanctionedAmount_PL))
            
        if (grp_slice['dateClosed'][i] != 'unknown') or (grp_slice['accountType'][i] == 'CC') or (grp_slice['accountType'][i] == 'SCC') or (grp_slice['currentBalance'][i] == 'unknown') or (sum(sanctionedAmount_PLBL) == 0):
            currentBalance_sanctionedAmount_NCC_L_PLBL.append('unknown')
        else:
            currentBalance_sanctionedAmount_NCC_L_PLBL.append(sum(currentBalance_PLBL)/sum(sanctionedAmount_PLBL))
            
        if (grp_slice['dateClosed'][i] != 'unknown') or (grp_slice['accountType'][i] == 'CC') or (grp_slice['accountType'][i] == 'SCC') or (grp_slice['currentBalance'][i] == 'unknown') or (sum(sanctionedAmount_RL) == 0):
            currentBalance_sanctionedAmount_NCC_L_RL.append('unknown')
        else:
            currentBalance_sanctionedAmount_NCC_L_RL.append(sum(currentBalance_RL)/sum(sanctionedAmount_RL))
            
        if (grp_slice['dateClosed'][i] != 'unknown') or (grp_slice['accountType'][i] == 'CC') or (grp_slice['accountType'][i] == 'SCC') or (grp_slice['currentBalance'][i] == 'unknown') or (sum(sanctionedAmount_SEL) == 0):
            currentBalance_sanctionedAmount_NCC_L_SEL.append('unknown')
        else:
            currentBalance_sanctionedAmount_NCC_L_SEL.append(sum(currentBalance_SEL)/sum(sanctionedAmount_SEL))
            
df['currentBalance_sanctionedAmount_NCC_L_AL'] = pd.Series(currentBalance_sanctionedAmount_NCC_L_AL).values
df['currentBalance_sanctionedAmount_NCC_L_BL'] = pd.Series(currentBalance_sanctionedAmount_NCC_L_BL).values
df['currentBalance_sanctionedAmount_NCC_L_CD'] = pd.Series(currentBalance_sanctionedAmount_NCC_L_CD).values
df['currentBalance_sanctionedAmount_NCC_L_CV'] = pd.Series(currentBalance_sanctionedAmount_NCC_L_CV).values
df['currentBalance_sanctionedAmount_NCC_L_GL'] = pd.Series(currentBalance_sanctionedAmount_NCC_L_GL).values
df['currentBalance_sanctionedAmount_NCC_L_HL'] = pd.Series(currentBalance_sanctionedAmount_NCC_L_HL).values
df['currentBalance_sanctionedAmount_NCC_L_LAS'] = pd.Series(currentBalance_sanctionedAmount_NCC_L_LAS).values
df['currentBalance_sanctionedAmount_NCC_L_MFBL'] = pd.Series(currentBalance_sanctionedAmount_NCC_L_MFBL).values
df['currentBalance_sanctionedAmount_NCC_L_MFHL'] = pd.Series(currentBalance_sanctionedAmount_NCC_L_MFHL).values
df['currentBalance_sanctionedAmount_NCC_L_MFOT'] = pd.Series(currentBalance_sanctionedAmount_NCC_L_MFOT).values
df['currentBalance_sanctionedAmount_NCC_L_OTH'] = pd.Series(currentBalance_sanctionedAmount_NCC_L_OTH).values
df['currentBalance_sanctionedAmount_NCC_L_PL'] = pd.Series(currentBalance_sanctionedAmount_NCC_L_PL).values
df['currentBalance_sanctionedAmount_NCC_L_PLBL'] = pd.Series(currentBalance_sanctionedAmount_NCC_L_PLBL).values
df['currentBalance_sanctionedAmount_NCC_L_RL'] = pd.Series(currentBalance_sanctionedAmount_NCC_L_RL).values
df['currentBalance_sanctionedAmount_NCC_L_SEL'] = pd.Series(currentBalance_sanctionedAmount_NCC_L_SEL).values

print("%s seconds" % (time.time() - start_time))

# %% [raw]
# df[['ID','currentBalance','sanctionAmount','currentBalance_sanctionedAmount_NCC_L_PL','dateClosed','accountType']].head(10)

# %% [markdown]
# <a id='WtAvg_SancAmt'></a>
# ### WtAvg_SancAmt
# - Indicates the weighted average sanctioned amount (excluding the account types -10,35,36)
# - (no of accounts per product) * (sum of sanctioned amount for the product)/(sum of all the accounts for all the products) (excluding account types - 10,35,36)
# - Weights - Count of loans per product

# %%
totAcc = list()

grp_df = df.groupby('ID')

for x in range(0, len(unq_id_list)):
    grp_slice = grp_df.get_group(unq_id_list[x])
    # print(grp_slice)
    grp_slice.reset_index(drop=True, inplace=True)
    for i in range(0, grp_slice.shape[0]):
        #print(grp_slice.shape[0])
        totAcc.append(grp_slice.shape[0])
        
df['totAcc'] = pd.Series(totAcc).values

# %% [raw]
# df[['ID','accountType','sanctionAmount','count_PL','totAcc']].head(20)

# %%
start_time = time.time()  # You can use time.clock() also

sanc_amt_grp = list()

sanc_amt_list_AL = list()
sanc_amt_list_BL = list()
sanc_amt_list_CD = list()
sanc_amt_list_CV = list()
sanc_amt_list_GL = list()
sanc_amt_list_HL = list()
sanc_amt_list_LAS = list()
sanc_amt_list_MFBL = list()
sanc_amt_list_MFHL = list()
sanc_amt_list_MFOT = list()
sanc_amt_list_OTH = list()
sanc_amt_list_PL = list()
sanc_amt_list_PLBL = list()
sanc_amt_list_RL = list()
sanc_amt_list_SEL = list()

sanc_amt_AL = 0
sanc_amt_BL = 0
sanc_amt_CD = 0
sanc_amt_CV = 0
sanc_amt_GL = 0
sanc_amt_HL = 0
sanc_amt_LAS = 0
sanc_amt_MFBL = 0
sanc_amt_MFHL = 0
sanc_amt_MFOT = 0
sanc_amt_OTH = 0
sanc_amt_PL = 0
sanc_amt_PLBL = 0
sanc_amt_RL = 0
sanc_amt_SEL = 0

grp_df = df.groupby('ID')

for x in range(0, len(unq_id_list)):
    grp_slice = grp_df.get_group(unq_id_list[x])
    # print(grp_slice)
    grp_slice.reset_index(drop=True, inplace=True)
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['accountType'][i] == 'AL') and (grp_slice['sanctionAmount'][i]!='unknown'):
            sanc_amt_AL = sanc_amt_AL + grp_slice['sanctionAmount'][i]
        elif (grp_slice['accountType'][i] == 'BL') and (grp_slice['sanctionAmount'][i]!='unknown'):
            sanc_amt_BL = sanc_amt_BL + grp_slice['sanctionAmount'][i]
        elif (grp_slice['accountType'][i] == 'CD') and (grp_slice['sanctionAmount'][i]!='unknown'):
            sanc_amt_CD = sanc_amt_CD + grp_slice['sanctionAmount'][i]
        elif (grp_slice['accountType'][i] == 'CV') and (grp_slice['sanctionAmount'][i]!='unknown'):
            sanc_amt_CV = sanc_amt_CV + grp_slice['sanctionAmount'][i]
        elif (grp_slice['accountType'][i] == 'GL') and (grp_slice['sanctionAmount'][i]!='unknown'):
            sanc_amt_GL = sanc_amt_GL + grp_slice['sanctionAmount'][i]
        elif (grp_slice['accountType'][i] == 'HL') and (grp_slice['sanctionAmount'][i]!='unknown'):
            sanc_amt_HL = sanc_amt_HL + grp_slice['sanctionAmount'][i]
        elif (grp_slice['accountType'][i] == 'LAS') and (grp_slice['sanctionAmount'][i]!='unknown'):
            sanc_amt_LAS = sanc_amt_LAS + grp_slice['sanctionAmount'][i]
        elif (grp_slice['accountType'][i] == 'MFBL') and (grp_slice['sanctionAmount'][i]!='unknown'):
            sanc_amt_MFBL = sanc_amt_MFBL + grp_slice['sanctionAmount'][i]
        elif (grp_slice['accountType'][i] == 'MFHL') and (grp_slice['sanctionAmount'][i]!='unknown'):
            sanc_amt_MFHL = sanc_amt_MFHL + grp_slice['sanctionAmount'][i]
        elif (grp_slice['accountType'][i] == 'MFOT') and (grp_slice['sanctionAmount'][i]!='unknown'):
            sanc_amt_MFOT = sanc_amt_MFOT + grp_slice['sanctionAmount'][i]
        elif (grp_slice['accountType'][i] == 'OTH') and (grp_slice['sanctionAmount'][i]!='unknown'):
            sanc_amt_OTH = sanc_amt_OTH + grp_slice['sanctionAmount'][i]
        elif (grp_slice['accountType'][i] == 'PL') and (grp_slice['sanctionAmount'][i]!='unknown'):
            sanc_amt_PL = sanc_amt_PL + grp_slice['sanctionAmount'][i]
        elif (grp_slice['accountType'][i] == 'PLBL') and (grp_slice['sanctionAmount'][i]!='unknown'):
            sanc_amt_PLBL = sanc_amt_PLBL + grp_slice['sanctionAmount'][i]
        elif (grp_slice['accountType'][i] == 'RL') and (grp_slice['sanctionAmount'][i]!='unknown'):
            sanc_amt_RL = sanc_amt_RL + grp_slice['sanctionAmount'][i]
        elif (grp_slice['accountType'][i] == 'SEL') and (grp_slice['sanctionAmount'][i]!='unknown'):
            sanc_amt_SEL = sanc_amt_SEL + grp_slice['sanctionAmount'][i]

    sanc_amt_list_AL.append(sanc_amt_AL)
    sanc_amt_list_BL.append(sanc_amt_BL)
    sanc_amt_list_CD.append(sanc_amt_CD)
    sanc_amt_list_CV.append(sanc_amt_CV)
    sanc_amt_list_GL.append(sanc_amt_GL)
    sanc_amt_list_HL.append(sanc_amt_HL)
    sanc_amt_list_LAS.append(sanc_amt_LAS)
    sanc_amt_list_MFBL.append(sanc_amt_MFBL)
    sanc_amt_list_MFHL.append(sanc_amt_MFHL)
    sanc_amt_list_MFOT.append(sanc_amt_MFOT)
    sanc_amt_list_OTH.append(sanc_amt_OTH)
    sanc_amt_list_PL.append(sanc_amt_PL)
    sanc_amt_list_PLBL.append(sanc_amt_PLBL)
    sanc_amt_list_RL.append(sanc_amt_RL)
    sanc_amt_list_SEL.append(sanc_amt_SEL)

    sanc_amt_AL = 0
    sanc_amt_BL = 0
    sanc_amt_CD = 0
    sanc_amt_CV = 0
    sanc_amt_GL = 0
    sanc_amt_HL = 0
    sanc_amt_LAS = 0
    sanc_amt_MFBL = 0
    sanc_amt_MFHL = 0
    sanc_amt_MFOT = 0
    sanc_amt_OTH = 0
    sanc_amt_PL = 0
    sanc_amt_PLBL = 0
    sanc_amt_RL = 0
    sanc_amt_SEL = 0

    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['accountType'][i] == 'unknown') or (grp_slice['sanctionAmount'][i] == 'unknown'):
            sanc_amt_grp.append('unknown')
            
        elif (grp_slice['accountType'][i] == 'AL'):
            sanc_amt_grp.append(sanc_amt_list_AL[x])

        elif (grp_slice['accountType'][i] == 'BL'):
            sanc_amt_grp.append(sanc_amt_list_BL[x])

        
        elif (grp_slice['accountType'][i] == 'CD'):
            sanc_amt_grp.append(sanc_amt_list_CD[x])

        
        elif (grp_slice['accountType'][i] == 'CV'):
            sanc_amt_grp.append(sanc_amt_list_CV[x])

        
        elif (grp_slice['accountType'][i] == 'GL'):
            sanc_amt_grp.append(sanc_amt_list_GL[x])

        
        elif (grp_slice['accountType'][i] == 'HL'):
            sanc_amt_grp.append(sanc_amt_list_HL[x])

        
        elif (grp_slice['accountType'][i] == 'LAS'):
            sanc_amt_grp.append(sanc_amt_list_LAS[x])

        
        elif (grp_slice['accountType'][i] == 'MFBL'):
            sanc_amt_grp.append(sanc_amt_list_MFBL[x])

        
        elif (grp_slice['accountType'][i] == 'MFHL'):
            sanc_amt_grp.append(sanc_amt_list_MFHL[x])

        
        elif (grp_slice['accountType'][i] == 'MFOT'):
            sanc_amt_grp.append(sanc_amt_list_MFOT[x])

        
        elif (grp_slice['accountType'][i] == 'OTH'):
            sanc_amt_grp.append(sanc_amt_list_OTH[x])

        
        elif (grp_slice['accountType'][i] == 'PL'):
            sanc_amt_grp.append(sanc_amt_list_PL[x])

        
        elif (grp_slice['accountType'][i] == 'PLBL'):
            sanc_amt_grp.append(sanc_amt_list_PLBL[x])

        
        elif (grp_slice['accountType'][i] == 'RL'):
            sanc_amt_grp.append(sanc_amt_list_RL[x])

        
        elif (grp_slice['accountType'][i] == 'SEL'):
            sanc_amt_grp.append(sanc_amt_list_SEL[x])
            
        else:
            sanc_amt_grp.append('unknown')

df['sanc_amt_grp'] = pd.Series(sanc_amt_grp).values

print("%s seconds" % (time.time() - start_time))

# %% [raw]
# df[['ID','accountType',df[['ID','accountType','sanctionAmount','sanc_amt_grp','count_PL','totAcc']].head(20)'sanctionAmount','sanc_amt_grp','count_PL','totAcc']].head(20)

# %%
start_time = time.time()  # You can use time.clock() also

cnt_grp = list()

cnt_list_AL = list()
cnt_list_BL = list()
cnt_list_CD = list()
cnt_list_CV = list()
cnt_list_GL = list()
cnt_list_HL = list()
cnt_list_LAS = list()
cnt_list_MFBL = list()
cnt_list_MFHL = list()
cnt_list_MFOT = list()
cnt_list_OTH = list()
cnt_list_PL = list()
cnt_list_PLBL = list()
cnt_list_RL = list()
cnt_list_SEL = list()

cnt_AL = 0
cnt_BL = 0
cnt_CD = 0
cnt_CV = 0
cnt_GL = 0
cnt_HL = 0
cnt_LAS = 0
cnt_MFBL = 0
cnt_MFHL = 0
cnt_MFOT = 0
cnt_OTH = 0
cnt_PL = 0
cnt_PLBL = 0
cnt_RL = 0
cnt_SEL = 0

grp_df = df.groupby('ID')

for x in range(0, len(unq_id_list)):
    grp_slice = grp_df.get_group(unq_id_list[x])
    # print(grp_slice)
    grp_slice.reset_index(drop=True, inplace=True)
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['accountType'][i] == 'AL'):
            cnt_AL = cnt_AL + 1
        elif (grp_slice['accountType'][i] == 'BL'):
            cnt_BL = cnt_BL + 1
        elif (grp_slice['accountType'][i] == 'CD'):
            cnt_CD = cnt_CD + 1
        elif (grp_slice['accountType'][i] == 'CV'):
            cnt_CV = cnt_CV + 1
        elif (grp_slice['accountType'][i] == 'GL'):
            cnt_GL = cnt_GL + 1
        elif (grp_slice['accountType'][i] == 'HL'):
            cnt_HL = cnt_HL + 1
        elif (grp_slice['accountType'][i] == 'LAS'):
            cnt_LAS = cnt_LAS + 1
        elif (grp_slice['accountType'][i] == 'MFBL'):
            cnt_MFBL = cnt_MFBL + 1
        elif (grp_slice['accountType'][i] == 'MFHL'):
            cnt_MFHL = cnt_MFHL + 1
        elif (grp_slice['accountType'][i] == 'MFOT'):
            cnt_MFOT = cnt_MFOT + 1
        elif (grp_slice['accountType'][i] == 'OTH'):
            cnt_OTH = cnt_OTH + 1
        elif (grp_slice['accountType'][i] == 'PL'):
            cnt_PL = cnt_PL + 1
        elif (grp_slice['accountType'][i] == 'PLBL'):
            cnt_PLBL = cnt_PLBL + 1
        elif (grp_slice['accountType'][i] == 'RL'):
            cnt_RL = cnt_RL + 1
        elif (grp_slice['accountType'][i] == 'SEL'):
            cnt_SEL = cnt_SEL + 1

    cnt_list_AL.append(cnt_AL)
    cnt_list_BL.append(cnt_BL)
    cnt_list_CD.append(cnt_CD)
    cnt_list_CV.append(cnt_CV)
    cnt_list_GL.append(cnt_GL)
    cnt_list_HL.append(cnt_HL)
    cnt_list_LAS.append(cnt_LAS)
    cnt_list_MFBL.append(cnt_MFBL)
    cnt_list_MFHL.append(cnt_MFHL)
    cnt_list_MFOT.append(cnt_MFOT)
    cnt_list_OTH.append(cnt_OTH)
    cnt_list_PL.append(cnt_PL)
    cnt_list_PLBL.append(cnt_PLBL)
    cnt_list_RL.append(cnt_RL)
    cnt_list_SEL.append(cnt_SEL)

    cnt_AL = 0
    cnt_BL = 0
    cnt_CD = 0
    cnt_CV = 0
    cnt_GL = 0
    cnt_HL = 0
    cnt_LAS = 0
    cnt_MFBL = 0
    cnt_MFHL = 0
    cnt_MFOT = 0
    cnt_OTH = 0
    cnt_PL = 0
    cnt_PLBL = 0
    cnt_RL = 0
    cnt_SEL = 0

    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['accountType'][i] == 'unknown') or (grp_slice['sanctionAmount'][i] == 'unknown'):
            cnt_grp.append('unknown')

        elif (grp_slice['accountType'][i] == 'AL'):
            cnt_grp.append(cnt_list_AL[x])

        elif (grp_slice['accountType'][i] == 'BL'):
            cnt_grp.append(cnt_list_BL[x])

        elif (grp_slice['accountType'][i] == 'CD'):
            cnt_grp.append(cnt_list_CD[x])

        elif (grp_slice['accountType'][i] == 'CV'):
            cnt_grp.append(cnt_list_CV[x])

        elif (grp_slice['accountType'][i] == 'GL'):
            cnt_grp.append(cnt_list_GL[x])

        elif (grp_slice['accountType'][i] == 'HL'):
            cnt_grp.append(cnt_list_HL[x])

        elif (grp_slice['accountType'][i] == 'LAS'):
            cnt_grp.append(cnt_list_LAS[x])

        elif (grp_slice['accountType'][i] == 'MFBL'):
            cnt_grp.append(cnt_list_MFBL[x])

        elif (grp_slice['accountType'][i] == 'MFHL'):
            cnt_grp.append(cnt_list_MFHL[x])

        elif (grp_slice['accountType'][i] == 'MFOT'):
            cnt_grp.append(cnt_list_MFOT[x])

        elif (grp_slice['accountType'][i] == 'OTH'):
            cnt_grp.append(cnt_list_OTH[x])

        elif (grp_slice['accountType'][i] == 'PL'):
            cnt_grp.append(cnt_list_PL[x])

        elif (grp_slice['accountType'][i] == 'PLBL'):
            cnt_grp.append(cnt_list_PLBL[x])

        elif (grp_slice['accountType'][i] == 'RL'):
            cnt_grp.append(cnt_list_RL[x])

        elif (grp_slice['accountType'][i] == 'SEL'):
            cnt_grp.append(cnt_list_SEL[x])

        else:
            cnt_grp.append('unknown')

df['cnt_grp'] = pd.Series(cnt_grp).values

print("%s seconds" % (time.time() - start_time))

# %% [raw]
# df[['ID','accountType','sanctionAmount','sanc_amt_grp','cnt_grp','totAcc']].head(20)

# %%
WtAvg_SancAmt = list()

for x in range(0, df.shape[0]):
    if (df['cnt_grp'][x]=='unknown') or (df['sanc_amt_grp'][x]=='unknown'):
        WtAvg_SancAmt.append('unknown')
    else:
        WtAvg_SancAmt.append(df['cnt_grp'][x]*(df['sanc_amt_grp'][x]/df['totAcc'][x]))
        
df['WtAvg_SancAmt'] = pd.Series(WtAvg_SancAmt).values

# %% [raw]
# df[['ID','accountType','sanctionAmount','sanc_amt_grp','cnt_grp','totAcc','WtAvg_SancAmt']].head(20)

# %% [markdown]
# <a id='WtAvg_SancAmt_L'></a>
# ### WtAvg_SancAmt_L
# - Indicates the weighted average sanctioned amount for all the live products (excluding the account types -10,35,36)
# - (no of live accounts per product) * (sum of sanctioned amount for the live accounts of the product)/(sum of all the live accounts for all the products) (excluding account types - 10,35,36)
# - Weights - Count of loans per product

# %%
df['totAcc_L'] = pd.Series(np.ones(4462)).values

# %%
totAcc_L = list()
cnt_L = list()
cnt = 0

grp_df = df.groupby('ID')

for x in range(0, len(unq_id_list)):
    grp_slice = grp_df.get_group(unq_id_list[x])
    #print(grp_slice)
    grp_slice.reset_index(drop=True, inplace=True)
    for i in range(0, grp_slice.shape[0]):
        # print(grp_slice.shape[0])
        if (grp_slice['dateClosed'][i] == 'unknown'):
            cnt = cnt + 1
        else:
            continue
    
    #print(cnt)
    
    for i in range(0, grp_slice.shape[0]):
        # print(grp_slice.shape[0])
        if (grp_slice['dateClosed'][i] == 'unknown'):
            #print('----',cnt)
            grp_slice['totAcc_L'][i] = cnt
        else:
            grp_slice['totAcc_L'][i] = 0
    
    cnt = 0
    #print(grp_slice['totAcc_L'][0])
    
    for i in range(0, grp_slice.shape[0]):
        # print(grp_slice.shape[0])
        if (grp_slice['dateClosed'][i] == 'unknown'):
            totAcc_L.append(grp_slice['totAcc_L'][0])
        else:
            totAcc_L.append(0)
    
#print(len(totAcc_L))
df['totAcc_L'] = pd.Series(totAcc_L).values

# %% [raw]
# df[['ID','accountType','sanctionAmount','sanc_amt_grp','cnt_grp','totAcc','totAcc_L','dateClosed']][0:20]

# %%
start_time = time.time()  # You can use time.clock() also

sanc_amt_grp_L = list()

sanc_amt_list_L_AL = list()
sanc_amt_list_L_BL = list()
sanc_amt_list_L_CD = list()
sanc_amt_list_L_CV = list()
sanc_amt_list_L_GL = list()
sanc_amt_list_L_HL = list()
sanc_amt_list_L_LAS = list()
sanc_amt_list_L_MFBL = list()
sanc_amt_list_L_MFHL = list()
sanc_amt_list_L_MFOT = list()
sanc_amt_list_L_OTH = list()
sanc_amt_list_L_PL = list()
sanc_amt_list_L_PLBL = list()
sanc_amt_list_L_RL = list()
sanc_amt_list_L_SEL = list()

sanc_amt_AL = 0
sanc_amt_BL = 0
sanc_amt_CD = 0
sanc_amt_CV = 0
sanc_amt_GL = 0
sanc_amt_HL = 0
sanc_amt_LAS = 0
sanc_amt_MFBL = 0
sanc_amt_MFHL = 0
sanc_amt_MFOT = 0
sanc_amt_OTH = 0
sanc_amt_PL = 0
sanc_amt_PLBL = 0
sanc_amt_RL = 0
sanc_amt_SEL = 0

grp_df = df.groupby('ID')

for x in range(0, len(unq_id_list)):
    grp_slice = grp_df.get_group(unq_id_list[x])
    # print(grp_slice)
    grp_slice.reset_index(drop=True, inplace=True)
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['accountType'][i] == 'AL') and (grp_slice['sanctionAmount'][i] != 'unknown') and (grp_slice['dateClosed'][i] == 'unknown'):
            sanc_amt_AL = sanc_amt_AL + grp_slice['sanctionAmount'][i]
        elif (grp_slice['accountType'][i] == 'BL') and (grp_slice['sanctionAmount'][i] != 'unknown') and (grp_slice['dateClosed'][i] == 'unknown'):
            sanc_amt_BL = sanc_amt_BL + grp_slice['sanctionAmount'][i]
        elif (grp_slice['accountType'][i] == 'CD') and (grp_slice['sanctionAmount'][i] != 'unknown') and (grp_slice['dateClosed'][i] == 'unknown'):
            sanc_amt_CD = sanc_amt_CD + grp_slice['sanctionAmount'][i]
        elif (grp_slice['accountType'][i] == 'CV') and (grp_slice['sanctionAmount'][i] != 'unknown') and (grp_slice['dateClosed'][i] == 'unknown'):
            sanc_amt_CV = sanc_amt_CV + grp_slice['sanctionAmount'][i]
        elif (grp_slice['accountType'][i] == 'GL') and (grp_slice['sanctionAmount'][i] != 'unknown') and (grp_slice['dateClosed'][i] == 'unknown'):
            sanc_amt_GL = sanc_amt_GL + grp_slice['sanctionAmount'][i]
        elif (grp_slice['accountType'][i] == 'HL') and (grp_slice['sanctionAmount'][i] != 'unknown') and (grp_slice['dateClosed'][i] == 'unknown'):
            sanc_amt_HL = sanc_amt_HL + grp_slice['sanctionAmount'][i]
        elif (grp_slice['accountType'][i] == 'LAS') and (grp_slice['sanctionAmount'][i] != 'unknown') and (grp_slice['dateClosed'][i] == 'unknown'):
            sanc_amt_LAS = sanc_amt_LAS + grp_slice['sanctionAmount'][i]
        elif (grp_slice['accountType'][i] == 'MFBL') and (grp_slice['sanctionAmount'][i] != 'unknown') and (grp_slice['dateClosed'][i] == 'unknown'):
            sanc_amt_MFBL = sanc_amt_MFBL + grp_slice['sanctionAmount'][i]
        elif (grp_slice['accountType'][i] == 'MFHL') and (grp_slice['sanctionAmount'][i] != 'unknown') and (grp_slice['dateClosed'][i] == 'unknown'):
            sanc_amt_MFHL = sanc_amt_MFHL + grp_slice['sanctionAmount'][i]
        elif (grp_slice['accountType'][i] == 'MFOT') and (grp_slice['sanctionAmount'][i] != 'unknown') and (grp_slice['dateClosed'][i] == 'unknown'):
            sanc_amt_MFOT = sanc_amt_MFOT + grp_slice['sanctionAmount'][i]
        elif (grp_slice['accountType'][i] == 'OTH') and (grp_slice['sanctionAmount'][i] != 'unknown') and (grp_slice['dateClosed'][i] == 'unknown'):
            sanc_amt_OTH = sanc_amt_OTH + grp_slice['sanctionAmount'][i]
        elif (grp_slice['accountType'][i] == 'PL') and (grp_slice['sanctionAmount'][i] != 'unknown') and (grp_slice['dateClosed'][i] == 'unknown'):
            sanc_amt_PL = sanc_amt_PL + grp_slice['sanctionAmount'][i]
        elif (grp_slice['accountType'][i] == 'PLBL') and (grp_slice['sanctionAmount'][i] != 'unknown') and (grp_slice['dateClosed'][i] == 'unknown'):
            sanc_amt_PLBL = sanc_amt_PLBL + grp_slice['sanctionAmount'][i]
        elif (grp_slice['accountType'][i] == 'RL') and (grp_slice['sanctionAmount'][i] != 'unknown') and (grp_slice['dateClosed'][i] == 'unknown'):
            sanc_amt_RL = sanc_amt_RL + grp_slice['sanctionAmount'][i]
        elif (grp_slice['accountType'][i] == 'SEL') and (grp_slice['sanctionAmount'][i] != 'unknown') and (grp_slice['dateClosed'][i] == 'unknown'):
            sanc_amt_SEL = sanc_amt_SEL + grp_slice['sanctionAmount'][i]

    sanc_amt_list_L_AL.append(sanc_amt_AL)
    sanc_amt_list_L_BL.append(sanc_amt_BL)
    sanc_amt_list_L_CD.append(sanc_amt_CD)
    sanc_amt_list_L_CV.append(sanc_amt_CV)
    sanc_amt_list_L_GL.append(sanc_amt_GL)
    sanc_amt_list_L_HL.append(sanc_amt_HL)
    sanc_amt_list_L_LAS.append(sanc_amt_LAS)
    sanc_amt_list_L_MFBL.append(sanc_amt_MFBL)
    sanc_amt_list_L_MFHL.append(sanc_amt_MFHL)
    sanc_amt_list_L_MFOT.append(sanc_amt_MFOT)
    sanc_amt_list_L_OTH.append(sanc_amt_OTH)
    sanc_amt_list_L_PL.append(sanc_amt_PL)
    sanc_amt_list_L_PLBL.append(sanc_amt_PLBL)
    sanc_amt_list_L_RL.append(sanc_amt_RL)
    sanc_amt_list_L_SEL.append(sanc_amt_SEL)

    sanc_amt_AL = 0
    sanc_amt_BL = 0
    sanc_amt_CD = 0
    sanc_amt_CV = 0
    sanc_amt_GL = 0
    sanc_amt_HL = 0
    sanc_amt_LAS = 0
    sanc_amt_MFBL = 0
    sanc_amt_MFHL = 0
    sanc_amt_MFOT = 0
    sanc_amt_OTH = 0
    sanc_amt_PL = 0
    sanc_amt_PLBL = 0
    sanc_amt_RL = 0
    sanc_amt_SEL = 0

    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['accountType'][i] == 'unknown') or (grp_slice['sanctionAmount'][i] == 'unknown'):
            sanc_amt_grp_L.append('unknown')

        elif (grp_slice['accountType'][i] == 'AL') and (grp_slice['dateClosed'][i] == 'unknown'):
            sanc_amt_grp_L.append(sanc_amt_list_L_AL[x])

        elif (grp_slice['accountType'][i] == 'BL') and (grp_slice['dateClosed'][i] == 'unknown'):
            sanc_amt_grp_L.append(sanc_amt_list_L_BL[x])

        elif (grp_slice['accountType'][i] == 'CD') and (grp_slice['dateClosed'][i] == 'unknown'):
            sanc_amt_grp_L.append(sanc_amt_list_L_CD[x])

        elif (grp_slice['accountType'][i] == 'CV') and (grp_slice['dateClosed'][i] == 'unknown'):
            sanc_amt_grp_L.append(sanc_amt_list_L_CV[x])

        elif (grp_slice['accountType'][i] == 'GL') and (grp_slice['dateClosed'][i] == 'unknown'):
            sanc_amt_grp_L.append(sanc_amt_list_L_GL[x])

        elif (grp_slice['accountType'][i] == 'HL') and (grp_slice['dateClosed'][i] == 'unknown'):
            sanc_amt_grp_L.append(sanc_amt_list_L_HL[x])

        elif (grp_slice['accountType'][i] == 'LAS') and (grp_slice['dateClosed'][i] == 'unknown'):
            sanc_amt_grp_L.append(sanc_amt_list_L_LAS[x])

        elif (grp_slice['accountType'][i] == 'MFBL') and (grp_slice['dateClosed'][i] == 'unknown'):
            sanc_amt_grp_L.append(sanc_amt_list_L_MFBL[x])

        elif (grp_slice['accountType'][i] == 'MFHL') and (grp_slice['dateClosed'][i] == 'unknown'):
            sanc_amt_grp_L.append(sanc_amt_list_L_MFHL[x])

        elif (grp_slice['accountType'][i] == 'MFOT') and (grp_slice['dateClosed'][i] == 'unknown'):
            sanc_amt_grp_L.append(sanc_amt_list_L_MFOT[x])

        elif (grp_slice['accountType'][i] == 'OTH') and (grp_slice['dateClosed'][i] == 'unknown'):
            sanc_amt_grp_L.append(sanc_amt_list_L_OTH[x])

        elif (grp_slice['accountType'][i] == 'PL') and (grp_slice['dateClosed'][i] == 'unknown'):
            sanc_amt_grp_L.append(sanc_amt_list_L_PL[x])

        elif (grp_slice['accountType'][i] == 'PLBL') and (grp_slice['dateClosed'][i] == 'unknown'):
            sanc_amt_grp_L.append(sanc_amt_list_L_PLBL[x])

        elif (grp_slice['accountType'][i] == 'RL') and (grp_slice['dateClosed'][i] == 'unknown'):
            sanc_amt_grp_L.append(sanc_amt_list_L_RL[x])

        elif (grp_slice['accountType'][i] == 'SEL') and (grp_slice['dateClosed'][i] == 'unknown'):
            sanc_amt_grp_L.append(sanc_amt_list_L_SEL[x])

        else:
            sanc_amt_grp_L.append('unknown')

df['sanc_amt_grp_L'] = pd.Series(sanc_amt_grp_L).values

print("%s seconds" % (time.time() - start_time))

# %% [raw]
# df[['ID','accountType','sanctionAmount','sanc_amt_grp','cnt_grp','totAcc','dateClosed','sanc_amt_grp_L','totAcc_L']][0:20]

# %%
start_time = time.time()  # You can use time.clock() also

cnt_grp_L = list()

cnt_list_AL = list()
cnt_list_BL = list()
cnt_list_CD = list()
cnt_list_CV = list()
cnt_list_GL = list()
cnt_list_HL = list()
cnt_list_LAS = list()
cnt_list_MFBL = list()
cnt_list_MFHL = list()
cnt_list_MFOT = list()
cnt_list_OTH = list()
cnt_list_PL = list()
cnt_list_PLBL = list()
cnt_list_RL = list()
cnt_list_SEL = list()

cnt_AL = 0
cnt_BL = 0
cnt_CD = 0
cnt_CV = 0
cnt_GL = 0
cnt_HL = 0
cnt_LAS = 0
cnt_MFBL = 0
cnt_MFHL = 0
cnt_MFOT = 0
cnt_OTH = 0
cnt_PL = 0
cnt_PLBL = 0
cnt_RL = 0
cnt_SEL = 0

grp_df = df.groupby('ID')

for x in range(0, len(unq_id_list)):
    grp_slice = grp_df.get_group(unq_id_list[x])
    # print(grp_slice)
    grp_slice.reset_index(drop=True, inplace=True)
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['accountType'][i] == 'AL') and (grp_slice['dateClosed'][i] == 'unknown'):
            cnt_AL = cnt_AL + 1
        elif (grp_slice['accountType'][i] == 'BL') and (grp_slice['dateClosed'][i] == 'unknown'):
            cnt_BL = cnt_BL + 1
        elif (grp_slice['accountType'][i] == 'CD') and (grp_slice['dateClosed'][i] == 'unknown'):
            cnt_CD = cnt_CD + 1
        elif (grp_slice['accountType'][i] == 'CV') and (grp_slice['dateClosed'][i] == 'unknown'):
            cnt_CV = cnt_CV + 1
        elif (grp_slice['accountType'][i] == 'GL') and (grp_slice['dateClosed'][i] == 'unknown'):
            cnt_GL = cnt_GL + 1
        elif (grp_slice['accountType'][i] == 'HL') and (grp_slice['dateClosed'][i] == 'unknown'):
            cnt_HL = cnt_HL + 1
        elif (grp_slice['accountType'][i] == 'LAS') and (grp_slice['dateClosed'][i] == 'unknown'):
            cnt_LAS = cnt_LAS + 1
        elif (grp_slice['accountType'][i] == 'MFBL') and (grp_slice['dateClosed'][i] == 'unknown'):
            cnt_MFBL = cnt_MFBL + 1
        elif (grp_slice['accountType'][i] == 'MFHL') and (grp_slice['dateClosed'][i] == 'unknown'):
            cnt_MFHL = cnt_MFHL + 1
        elif (grp_slice['accountType'][i] == 'MFOT') and (grp_slice['dateClosed'][i] == 'unknown'):
            cnt_MFOT = cnt_MFOT + 1
        elif (grp_slice['accountType'][i] == 'OTH') and (grp_slice['dateClosed'][i] == 'unknown'):
            cnt_OTH = cnt_OTH + 1
        elif (grp_slice['accountType'][i] == 'PL') and (grp_slice['dateClosed'][i] == 'unknown'):
            cnt_PL = cnt_PL + 1
        elif (grp_slice['accountType'][i] == 'PLBL') and (grp_slice['dateClosed'][i] == 'unknown'):
            cnt_PLBL = cnt_PLBL + 1
        elif (grp_slice['accountType'][i] == 'RL') and (grp_slice['dateClosed'][i] == 'unknown'):
            cnt_RL = cnt_RL + 1
        elif (grp_slice['accountType'][i] == 'SEL') and (grp_slice['dateClosed'][i] == 'unknown'):
            cnt_SEL = cnt_SEL + 1

    cnt_list_AL.append(cnt_AL)
    cnt_list_BL.append(cnt_BL)
    cnt_list_CD.append(cnt_CD)
    cnt_list_CV.append(cnt_CV)
    cnt_list_GL.append(cnt_GL)
    cnt_list_HL.append(cnt_HL)
    cnt_list_LAS.append(cnt_LAS)
    cnt_list_MFBL.append(cnt_MFBL)
    cnt_list_MFHL.append(cnt_MFHL)
    cnt_list_MFOT.append(cnt_MFOT)
    cnt_list_OTH.append(cnt_OTH)
    cnt_list_PL.append(cnt_PL)
    cnt_list_PLBL.append(cnt_PLBL)
    cnt_list_RL.append(cnt_RL)
    cnt_list_SEL.append(cnt_SEL)

    cnt_AL = 0
    cnt_BL = 0
    cnt_CD = 0
    cnt_CV = 0
    cnt_GL = 0
    cnt_HL = 0
    cnt_LAS = 0
    cnt_MFBL = 0
    cnt_MFHL = 0
    cnt_MFOT = 0
    cnt_OTH = 0
    cnt_PL = 0
    cnt_PLBL = 0
    cnt_RL = 0
    cnt_SEL = 0

    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['accountType'][i] == 'unknown') or (grp_slice['sanctionAmount'][i] == 'unknown'):
            cnt_grp_L.append('unknown')

        elif (grp_slice['accountType'][i] == 'AL') and (grp_slice['dateClosed'][i] == 'unknown'):
            cnt_grp_L.append(cnt_list_AL[x])

        elif (grp_slice['accountType'][i] == 'BL') and (grp_slice['dateClosed'][i] == 'unknown'):
            cnt_grp_L.append(cnt_list_BL[x])

        elif (grp_slice['accountType'][i] == 'CD') and (grp_slice['dateClosed'][i] == 'unknown'):
            cnt_grp_L.append(cnt_list_CD[x])

        elif (grp_slice['accountType'][i] == 'CV') and (grp_slice['dateClosed'][i] == 'unknown'):
            cnt_grp_L.append(cnt_list_CV[x])

        elif (grp_slice['accountType'][i] == 'GL') and (grp_slice['dateClosed'][i] == 'unknown'):
            cnt_grp_L.append(cnt_list_GL[x])

        elif (grp_slice['accountType'][i] == 'HL') and (grp_slice['dateClosed'][i] == 'unknown'):
            cnt_grp_L.append(cnt_list_HL[x])

        elif (grp_slice['accountType'][i] == 'LAS') and (grp_slice['dateClosed'][i] == 'unknown'):
            cnt_grp_L.append(cnt_list_LAS[x])

        elif (grp_slice['accountType'][i] == 'MFBL') and (grp_slice['dateClosed'][i] == 'unknown'):
            cnt_grp_L.append(cnt_list_MFBL[x])

        elif (grp_slice['accountType'][i] == 'MFHL') and (grp_slice['dateClosed'][i] == 'unknown'):
            cnt_grp_L.append(cnt_list_MFHL[x])

        elif (grp_slice['accountType'][i] == 'MFOT') and (grp_slice['dateClosed'][i] == 'unknown'):
            cnt_grp_L.append(cnt_list_MFOT[x])

        elif (grp_slice['accountType'][i] == 'OTH') and (grp_slice['dateClosed'][i] == 'unknown'):
            cnt_grp_L.append(cnt_list_OTH[x])

        elif (grp_slice['accountType'][i] == 'PL') and (grp_slice['dateClosed'][i] == 'unknown'):
            cnt_grp_L.append(cnt_list_PL[x])

        elif (grp_slice['accountType'][i] == 'PLBL') and (grp_slice['dateClosed'][i] == 'unknown'):
            cnt_grp_L.append(cnt_list_PLBL[x])

        elif (grp_slice['accountType'][i] == 'RL') and (grp_slice['dateClosed'][i] == 'unknown'):
            cnt_grp_L.append(cnt_list_RL[x])

        elif (grp_slice['accountType'][i] == 'SEL') and (grp_slice['dateClosed'][i] == 'unknown'):
            cnt_grp_L.append(cnt_list_SEL[x])

        else:
            cnt_grp_L.append('unknown')

df['cnt_grp_L'] = pd.Series(cnt_grp_L).values

print("%s seconds" % (time.time() - start_time))

# %% [raw]
# df[['ID','accountType','sanctionAmount','sanc_amt_grp','cnt_grp','totAcc','dateClosed','cnt_grp_L','sanc_amt_grp_L','totAcc_L']][0:20]

# %%
WtAvg_SancAmt_L = list()

for x in range(0, df.shape[0]):
    if (df['cnt_grp_L'][x] == 'unknown') or (df['sanc_amt_grp_L'][x] == 'unknown'):
        WtAvg_SancAmt_L.append('unknown')
    else:
        WtAvg_SancAmt_L.append(
            df['cnt_grp_L'][x]*(df['sanc_amt_grp_L'][x]/df['totAcc_L'][x]))

df['WtAvg_SancAmt_L'] = pd.Series(WtAvg_SancAmt_L).values

# %% [raw]
# df[['ID','accountType','sanctionAmount','sanc_amt_grp','cnt_grp','totAcc','dateClosed','cnt_grp_L','sanc_amt_grp_L','totAcc_L','WtAvg_SancAmt','WtAvg_SancAmt_L']][0:20]

# %% [markdown]
# <a id='WAvg_Cur_Bal_L'></a>
# ### WAvg_Cur_Bal_L
# - Indicates the weighted average current balance for all the live products (excluding the account types -10,35,36)
# - (no of live accounts per product) * (sum of current balance for the live accounts of the product where current balance >0)/(sum of all the live accounts for all the products) (excluding account types - 10,35,36)

# %% [raw]
# for x in range(0, df.shape[0]):
#     if df['currentBalance'][x]=='unknown':
#         continue
#     elif df['currentBalance'][x] <0 :
#         print(df['currentBalance'][x])
#     else:
#         continue

# %%
start_time = time.time()  # You can use time.clock() also

curr_bal_grp_L = list()

curr_bal_list_L_AL = list()
curr_bal_list_L_BL = list()
curr_bal_list_L_CD = list()
curr_bal_list_L_CV = list()
curr_bal_list_L_GL = list()
curr_bal_list_L_HL = list()
curr_bal_list_L_LAS = list()
curr_bal_list_L_MFBL = list()
curr_bal_list_L_MFHL = list()
curr_bal_list_L_MFOT = list()
curr_bal_list_L_OTH = list()
curr_bal_list_L_PL = list()
curr_bal_list_L_PLBL = list()
curr_bal_list_L_RL = list()
curr_bal_list_L_SEL = list()

curr_bal_AL = 0
curr_bal_BL = 0
curr_bal_CD = 0
curr_bal_CV = 0
curr_bal_GL = 0
curr_bal_HL = 0
curr_bal_LAS = 0
curr_bal_MFBL = 0
curr_bal_MFHL = 0
curr_bal_MFOT = 0
curr_bal_OTH = 0
curr_bal_PL = 0
curr_bal_PLBL = 0
curr_bal_RL = 0
curr_bal_SEL = 0

grp_df = df.groupby('ID')

for x in range(0, len(unq_id_list)):
    grp_slice = grp_df.get_group(unq_id_list[x])
    # print(grp_slice)
    grp_slice.reset_index(drop=True, inplace=True)
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['accountType'][i] == 'AL') and (grp_slice['currentBalance'][i] != 'unknown') and (grp_slice['dateClosed'][i] == 'unknown') and (grp_slice['currentBalance'][i] >=0) :
            curr_bal_AL = curr_bal_AL + grp_slice['currentBalance'][i]
        elif (grp_slice['accountType'][i] == 'BL') and (grp_slice['currentBalance'][i] != 'unknown') and (grp_slice['dateClosed'][i] == 'unknown') and (grp_slice['currentBalance'][i] >=0) :
            curr_bal_BL = curr_bal_BL + grp_slice['currentBalance'][i]
        elif (grp_slice['accountType'][i] == 'CD') and (grp_slice['currentBalance'][i] != 'unknown') and (grp_slice['dateClosed'][i] == 'unknown') and (grp_slice['currentBalance'][i] >=0) :
            curr_bal_CD = curr_bal_CD + grp_slice['currentBalance'][i]
        elif (grp_slice['accountType'][i] == 'CV') and (grp_slice['currentBalance'][i] != 'unknown') and (grp_slice['dateClosed'][i] == 'unknown') and (grp_slice['currentBalance'][i] >=0) :
            curr_bal_CV = curr_bal_CV + grp_slice['currentBalance'][i]
        elif (grp_slice['accountType'][i] == 'GL') and (grp_slice['currentBalance'][i] != 'unknown') and (grp_slice['dateClosed'][i] == 'unknown') and (grp_slice['currentBalance'][i] >=0) :
            curr_bal_GL = curr_bal_GL + grp_slice['currentBalance'][i]
        elif (grp_slice['accountType'][i] == 'HL') and (grp_slice['currentBalance'][i] != 'unknown') and (grp_slice['dateClosed'][i] == 'unknown') and (grp_slice['currentBalance'][i] >=0) :
            curr_bal_HL = curr_bal_HL + grp_slice['currentBalance'][i]
        elif (grp_slice['accountType'][i] == 'LAS') and (grp_slice['currentBalance'][i] != 'unknown') and (grp_slice['dateClosed'][i] == 'unknown') and (grp_slice['currentBalance'][i] >=0) :
            curr_bal_LAS = curr_bal_LAS + grp_slice['currentBalance'][i]
        elif (grp_slice['accountType'][i] == 'MFBL') and (grp_slice['currentBalance'][i] != 'unknown') and (grp_slice['dateClosed'][i] == 'unknown') and (grp_slice['currentBalance'][i] >=0) :
            curr_bal_MFBL = curr_bal_MFBL + grp_slice['currentBalance'][i]
        elif (grp_slice['accountType'][i] == 'MFHL') and (grp_slice['currentBalance'][i] != 'unknown') and (grp_slice['dateClosed'][i] == 'unknown') and (grp_slice['currentBalance'][i] >=0) :
            curr_bal_MFHL = curr_bal_MFHL + grp_slice['currentBalance'][i]
        elif (grp_slice['accountType'][i] == 'MFOT') and (grp_slice['currentBalance'][i] != 'unknown') and (grp_slice['dateClosed'][i] == 'unknown') and (grp_slice['currentBalance'][i] >=0) :
            curr_bal_MFOT = curr_bal_MFOT + grp_slice['currentBalance'][i]
        elif (grp_slice['accountType'][i] == 'OTH') and (grp_slice['currentBalance'][i] != 'unknown') and (grp_slice['dateClosed'][i] == 'unknown') and (grp_slice['currentBalance'][i] >=0) :
            curr_bal_OTH = curr_bal_OTH + grp_slice['currentBalance'][i]
        elif (grp_slice['accountType'][i] == 'PL') and (grp_slice['currentBalance'][i] != 'unknown') and (grp_slice['dateClosed'][i] == 'unknown') and (grp_slice['currentBalance'][i] >=0) :
            curr_bal_PL = curr_bal_PL + grp_slice['currentBalance'][i]
        elif (grp_slice['accountType'][i] == 'PLBL') and (grp_slice['currentBalance'][i] != 'unknown') and (grp_slice['dateClosed'][i] == 'unknown') and (grp_slice['currentBalance'][i] >=0) :
            curr_bal_PLBL = curr_bal_PLBL + grp_slice['currentBalance'][i]
        elif (grp_slice['accountType'][i] == 'RL') and (grp_slice['currentBalance'][i] != 'unknown') and (grp_slice['dateClosed'][i] == 'unknown') and (grp_slice['currentBalance'][i] >=0) :
            curr_bal_RL = curr_bal_RL + grp_slice['currentBalance'][i]
        elif (grp_slice['accountType'][i] == 'SEL') and (grp_slice['currentBalance'][i] != 'unknown') and (grp_slice['dateClosed'][i] == 'unknown') and (grp_slice['currentBalance'][i] >=0) :
            curr_bal_SEL = curr_bal_SEL + grp_slice['currentBalance'][i]

    curr_bal_list_L_AL.append(curr_bal_AL)
    curr_bal_list_L_BL.append(curr_bal_BL)
    curr_bal_list_L_CD.append(curr_bal_CD)
    curr_bal_list_L_CV.append(curr_bal_CV)
    curr_bal_list_L_GL.append(curr_bal_GL)
    curr_bal_list_L_HL.append(curr_bal_HL)
    curr_bal_list_L_LAS.append(curr_bal_LAS)
    curr_bal_list_L_MFBL.append(curr_bal_MFBL)
    curr_bal_list_L_MFHL.append(curr_bal_MFHL)
    curr_bal_list_L_MFOT.append(curr_bal_MFOT)
    curr_bal_list_L_OTH.append(curr_bal_OTH)
    curr_bal_list_L_PL.append(curr_bal_PL)
    curr_bal_list_L_PLBL.append(curr_bal_PLBL)
    curr_bal_list_L_RL.append(curr_bal_RL)
    curr_bal_list_L_SEL.append(curr_bal_SEL)

    curr_bal_AL = 0
    curr_bal_BL = 0
    curr_bal_CD = 0
    curr_bal_CV = 0
    curr_bal_GL = 0
    curr_bal_HL = 0
    curr_bal_LAS = 0
    curr_bal_MFBL = 0
    curr_bal_MFHL = 0
    curr_bal_MFOT = 0
    curr_bal_OTH = 0
    curr_bal_PL = 0
    curr_bal_PLBL = 0
    curr_bal_RL = 0
    curr_bal_SEL = 0

    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['accountType'][i] == 'unknown') or (grp_slice['currentBalance'][i] == 'unknown'):
            curr_bal_grp_L.append('unknown')

        elif (grp_slice['accountType'][i] == 'AL') and (grp_slice['dateClosed'][i] == 'unknown') and (grp_slice['currentBalance'][i] >=0) :
            curr_bal_grp_L.append(curr_bal_list_L_AL[x])

        elif (grp_slice['accountType'][i] == 'BL') and (grp_slice['dateClosed'][i] == 'unknown') and (grp_slice['currentBalance'][i] >=0) :
            curr_bal_grp_L.append(curr_bal_list_L_BL[x])

        elif (grp_slice['accountType'][i] == 'CD') and (grp_slice['dateClosed'][i] == 'unknown') and (grp_slice['currentBalance'][i] >=0) :
            curr_bal_grp_L.append(curr_bal_list_L_CD[x])

        elif (grp_slice['accountType'][i] == 'CV') and (grp_slice['dateClosed'][i] == 'unknown') and (grp_slice['currentBalance'][i] >=0) :
            curr_bal_grp_L.append(curr_bal_list_L_CV[x])

        elif (grp_slice['accountType'][i] == 'GL') and (grp_slice['dateClosed'][i] == 'unknown') and (grp_slice['currentBalance'][i] >=0) :
            curr_bal_grp_L.append(curr_bal_list_L_GL[x])

        elif (grp_slice['accountType'][i] == 'HL') and (grp_slice['dateClosed'][i] == 'unknown') and (grp_slice['currentBalance'][i] >=0) :
            curr_bal_grp_L.append(curr_bal_list_L_HL[x])

        elif (grp_slice['accountType'][i] == 'LAS') and (grp_slice['dateClosed'][i] == 'unknown') and (grp_slice['currentBalance'][i] >=0) :
            curr_bal_grp_L.append(curr_bal_list_L_LAS[x])

        elif (grp_slice['accountType'][i] == 'MFBL') and (grp_slice['dateClosed'][i] == 'unknown') and (grp_slice['currentBalance'][i] >=0) :
            curr_bal_grp_L.append(curr_bal_list_L_MFBL[x])

        elif (grp_slice['accountType'][i] == 'MFHL') and (grp_slice['dateClosed'][i] == 'unknown') and (grp_slice['currentBalance'][i] >=0) :
            curr_bal_grp_L.append(curr_bal_list_L_MFHL[x])

        elif (grp_slice['accountType'][i] == 'MFOT') and (grp_slice['dateClosed'][i] == 'unknown') and (grp_slice['currentBalance'][i] >=0) :
            curr_bal_grp_L.append(curr_bal_list_L_MFOT[x])

        elif (grp_slice['accountType'][i] == 'OTH') and (grp_slice['dateClosed'][i] == 'unknown') and (grp_slice['currentBalance'][i] >=0) :
            curr_bal_grp_L.append(curr_bal_list_L_OTH[x])

        elif (grp_slice['accountType'][i] == 'PL') and (grp_slice['dateClosed'][i] == 'unknown') and (grp_slice['currentBalance'][i] >=0) :
            curr_bal_grp_L.append(curr_bal_list_L_PL[x])

        elif (grp_slice['accountType'][i] == 'PLBL') and (grp_slice['dateClosed'][i] == 'unknown') and (grp_slice['currentBalance'][i] >=0) :
            curr_bal_grp_L.append(curr_bal_list_L_PLBL[x])

        elif (grp_slice['accountType'][i] == 'RL') and (grp_slice['dateClosed'][i] == 'unknown') and (grp_slice['currentBalance'][i] >=0) :
            curr_bal_grp_L.append(curr_bal_list_L_RL[x])

        elif (grp_slice['accountType'][i] == 'SEL') and (grp_slice['dateClosed'][i] == 'unknown') and (grp_slice['currentBalance'][i] >=0) :
            curr_bal_grp_L.append(curr_bal_list_L_SEL[x])

        else:
            curr_bal_grp_L.append('unknown')

df['curr_bal_grp_L'] = pd.Series(curr_bal_grp_L).values

print("%s seconds" % (time.time() - start_time))

# %%
WAvg_Cur_Bal_L = list()

for x in range(0, df.shape[0]):
    if (df['cnt_grp_L'][x] == 'unknown') or (df['curr_bal_grp_L'][x] == 'unknown'):
        WAvg_Cur_Bal_L.append('unknown')
    else:
        WAvg_Cur_Bal_L.append(
            df['cnt_grp_L'][x]*(df['curr_bal_grp_L'][x]/df['totAcc_L'][x]))

df['WAvg_Cur_Bal_L'] = pd.Series(WAvg_Cur_Bal_L).values

# %% [raw]
# df[['ID','accountType','currentBalance','cnt_grp_L','curr_bal_grp_L','totAcc_L','dateClosed','WAvg_Cur_Bal_L']][0:20]

# %% [markdown]
# <a id='Disb_Sec_UnsecwoRLCC_L'></a>
# ### Disb_Sec_UnsecwoRLCC_L
# - Ratio of total sum disbursed amount for live secured loans to total sum of disbursed amount for live unsecured loans (without RL/CC)

# %% [markdown]
# <a id='DPD_flags_1m'></a>
# ### Code for DPD flags for last 1 month

# %%
df['dateReportedAndCertified'].fillna('unknown', inplace=True)

#df['dateReportedAndCertified'].value_counts()

# %%
mo_diff_ld_drc = list()

for x in range(0, df.shape[0]):
    if (df['dateReportedAndCertified'][x]=='unknown'):
        mo_diff_ld_drc.append(-1)
    elif (df['dateClosed'][x]=='unknown'):
        mo_diff = diff_month(df['loginDate'][x], df['dateReportedAndCertified'][x])
        mo_diff_ld_drc.append(int(mo_diff))
    elif (df['dateClosed'][x]!='unknown'):
        mo_diff = diff_month(df['loginDate'][x], df['dateClosed'][x])
        mo_diff_ld_drc.append(int(mo_diff))

df['mo_diff_ld_drc'] = pd.Series(mo_diff_ld_drc).values

#print(df['mo_diff_ld_drc'].value_counts())

# %%
df.to_csv('b.csv')

# %%
def hasNumbers(inputString):
    return any(char.isdigit() for char in inputString)

#hasNumbers('45')

# %% [raw]
# piece = list()
#
# dpd30_1m = list()
# dpd60_1m = list()
# dpd90_1m = list()
#
# count = 0
#
# for value in df['paymentHist1']:
#     #print(value)
#     chunks, chunk_size = len(value), 3
#     for i in range(0, chunks, chunk_size):
#         piece.append(value[i:i+chunk_size])
#     #print(piece)
#     if hasNumbers(piece[0]):
#         #count = count + 1
#         #print(piece)
#         if (int(piece[0]) > 0) and (int(piece[0]) <= 30):
#             #print(piece)
#             dpd30_1m.append(1)
#             dpd60_1m.append(0)
#             dpd90_1m.append(0)
#         elif (int(piece[0]) > 30) and (int(piece[0]) <= 60):
#             #print(piece)
#             dpd30_1m.append(0)
#             dpd60_1m.append(1)
#             dpd90_1m.append(0)
#         elif (int(piece[0]) > 60) and (int(piece[0]) <= 90):
#             #print(piece)
#             dpd30_1m.append(0)
#             dpd60_1m.append(0)
#             dpd90_1m.append(1)
#         else:
#             dpd30_1m.append(0)
#             dpd60_1m.append(0)
#             dpd90_1m.append(0)
#     else:
#         dpd30_1m.append(0)
#         dpd60_1m.append(0)
#         dpd90_1m.append(0)
#
#
#     piece = list()
#
# df['DPD30P1M_flag'] = pd.Series(dpd30_1m).values
# df['DPD60P1M_flag'] = pd.Series(dpd60_1m).values
# df['DPD90P1M_flag'] = pd.Series(dpd90_1m).values

# %%
import time
start_time = time.time()    #You can use time.clock() also



dpd30_1m = list()
dpd60_1m = list()
dpd90_1m = list()

for x in range(0, df.shape[0]):
    if (df['mo_diff_ld_drc'][x] == -1):
        dpd30_1m.append('unknown')
        dpd60_1m.append('unknown')
        dpd90_1m.append('unknown')
    elif (hasNumbers(df['payHistComp'][x][0])):
        if (df['mo_diff_ld_drc'][x] == 1) and (int(df['payHistComp'][x][0]) > 0) and (int(df['payHistComp'][x][0]) <= 30):
            # print(df['payHistComp'][x])
            dpd30_1m.append(1)
            dpd60_1m.append(0)
            dpd90_1m.append(0)
        elif (df['mo_diff_ld_drc'][x] == 1) and (int(df['payHistComp'][x][0]) > 30) and (int(df['payHistComp'][x][0]) <= 60):
            # print(df['payHistComp'][x])
            dpd30_1m.append(0)
            dpd60_1m.append(1)
            dpd90_1m.append(0)
        elif (df['mo_diff_ld_drc'][x] == 1) and (int(df['payHistComp'][x][0]) > 60) and (int(df['payHistComp'][x][0]) <= 90):
            # print(df['payHistComp'][x])
            dpd30_1m.append(0)
            dpd60_1m.append(0)
            dpd90_1m.append(1)
        else:
            dpd30_1m.append(0)
            dpd60_1m.append(0)
            dpd90_1m.append(0)
    else:
        dpd30_1m.append(0)
        dpd60_1m.append(0)
        dpd90_1m.append(0)

df['DPD30P1M_flag'] = pd.Series(dpd30_1m).values
df['DPD60P1M_flag'] = pd.Series(dpd60_1m).values
df['DPD90P1M_flag'] = pd.Series(dpd90_1m).values

print("%s seconds" % (time.time() - start_time))

#df['DPD30P1M_flag'].value_counts()

# %% [markdown]
# <a id='DPD1M_num'></a>
# ### Code for DPD1M (numerical)

# %% [markdown]
# - For an applicant, Count of all loans where DPD30P1M_flag =1
# - For an applicant, Count of all loans where DPD60P1M_flag =1
# - For an applicant, Count of all loans where DPD90P1M_flag =1

# %%
start_time = time.time()

DPD30P1M = list()
count_list_30_1m = list()
count_30_1m = 0

DPD60P1M = list()
count_list_60_1m = list()
count_60_1m = 0

DPD90P1M = list()
count_list_90_1m = list()
count_90_1m = 0

grp_df = df.groupby('ID')

for x in range(0, len(unq_id_list)):
    grp_slice = grp_df.get_group(unq_id_list[x])
    #print(grp_slice)
    grp_slice.reset_index(drop=True, inplace=True)
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['DPD30P1M_flag'][i]==1) or (grp_slice['DPD30P1M_flag'][i]==0):
            count_30_1m = count_30_1m + grp_slice['DPD30P1M_flag'][i]
        
        if (grp_slice['DPD60P1M_flag'][i]==1) or (grp_slice['DPD60P1M_flag'][i]==0):
            count_60_1m = count_60_1m + grp_slice['DPD60P1M_flag'][i]

        if (grp_slice['DPD90P1M_flag'][i]==1) or (grp_slice['DPD90P1M_flag'][i]==0):
            count_90_1m = count_90_1m + grp_slice['DPD90P1M_flag'][i]

    count_list_30_1m.append(count_30_1m)
    count_30_1m = 0
    count_list_60_1m.append(count_60_1m)
    count_60_1m = 0
    count_list_90_1m.append(count_90_1m)
    count_90_1m = 0

    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['DPD30P1M_flag'][i]==1) or (grp_slice['DPD30P1M_flag'][i]==0):
            DPD30P1M.append(count_list_30_1m[x])
        else:
            DPD30P1M.append('unknown')

        if (grp_slice['DPD60P1M_flag'][i]==1) or (grp_slice['DPD60P1M_flag'][i]==0):
            DPD60P1M.append(count_list_60_1m[x])
        else:
            DPD60P1M.append('unknown')

        if (grp_slice['DPD90P1M_flag'][i]==1) or (grp_slice['DPD90P1M_flag'][i]==0):
            DPD90P1M.append(count_list_90_1m[x])
        else:
            DPD90P1M.append('unknown')
            
df['DPD30P1M'] = pd.Series(DPD30P1M).values
df['DPD60P1M'] = pd.Series(DPD60P1M).values
df['DPD90P1M'] = pd.Series(DPD90P1M).values
#df['DPD60P1M'].value_counts()

print("%s seconds" % (time.time() - start_time))

# %% [markdown]
# ### Code for DPD30P1M_P

# %% [markdown]
# - DPD 30 in last 1 month productwise
# - For an applicant, Count of all loans where DPD30P1M_flag =1 per product

# %% [raw]
# df.to_csv('b.csv')

# %%
start_time = time.time()

DPD30P1M_AL = list()
DPD30P1M_BL = list()
DPD30P1M_CC = list()
DPD30P1M_CD = list()
DPD30P1M_CV = list()
DPD30P1M_GL = list()
DPD30P1M_HL = list()
DPD30P1M_LAS = list()
DPD30P1M_MFBL = list()
DPD30P1M_MFHL = list()
DPD30P1M_MFOT = list()
DPD30P1M_OTH = list()
DPD30P1M_PL = list()
DPD30P1M_PLBL = list()
DPD30P1M_RL = list()
DPD30P1M_SCC = list()
DPD30P1M_SEL = list()

count_list_AL = list()
count_list_BL = list()
count_list_CC = list()
count_list_CD = list()
count_list_CV = list()
count_list_GL = list()
count_list_HL = list()
count_list_LAS = list()
count_list_MFBL = list()
count_list_MFHL = list()
count_list_MFOT = list()
count_list_OTH = list()
count_list_PL = list()
count_list_PLBL = list()
count_list_RL = list()
count_list_SCC = list()
count_list_SEL = list()

count_AL = 0
count_BL = 0
count_CC = 0
count_CD = 0
count_CV = 0
count_GL = 0
count_HL = 0
count_LAS = 0
count_MFBL = 0
count_MFHL = 0
count_MFOT = 0
count_OTH = 0
count_PL = 0 
count_PLBL = 0
count_RL = 0
count_SCC = 0
count_SEL = 0

grp_df = df.groupby('ID')

for x in range(0, len(unq_id_list)):
    grp_slice = grp_df.get_group(unq_id_list[x])
    #print(grp_slice)
    grp_slice.reset_index(drop=True, inplace=True)
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['accountType'][i]=='unknown'):
            continue
        elif (grp_slice['accountType'][i]=='AL') and (grp_slice['DPD30P1M_flag'][i]==1):
            count_AL = count_AL + 1
        elif (grp_slice['accountType'][i]=='BL') and (grp_slice['DPD30P1M_flag'][i]==1):
            count_BL = count_BL + 1
        elif (grp_slice['accountType'][i]=='CC') and (grp_slice['DPD30P1M_flag'][i]==1):
            count_CC = count_CC + 1
        elif (grp_slice['accountType'][i]=='CD') and (grp_slice['DPD30P1M_flag'][i]==1):
            count_CD = count_CD + 1
        elif (grp_slice['accountType'][i]=='CV') and (grp_slice['DPD30P1M_flag'][i]==1):
            count_CV = count_CV + 1
        elif (grp_slice['accountType'][i]=='GL') and (grp_slice['DPD30P1M_flag'][i]==1):
            count_GL = count_GL + 1
        elif (grp_slice['accountType'][i]=='HL') and (grp_slice['DPD30P1M_flag'][i]==1):
            count_HL = count_HL + 1
        elif (grp_slice['accountType'][i]=='LAS') and (grp_slice['DPD30P1M_flag'][i]==1):
            count_LAS = count_LAS + 1
        elif (grp_slice['accountType'][i]=='MFBL') and (grp_slice['DPD30P1M_flag'][i]==1):
            count_MFBL = count_MFBL + 1
        elif (grp_slice['accountType'][i]=='MFHL') and (grp_slice['DPD30P1M_flag'][i]==1):
            count_MFHL = count_MFHL + 1
        elif (grp_slice['accountType'][i]=='MFOT') and (grp_slice['DPD30P1M_flag'][i]==1):
            count_MFOT = count_MFOT + 1
        elif (grp_slice['accountType'][i]=='OTH') and (grp_slice['DPD30P1M_flag'][i]==1):
            count_OTH = count_OTH + 1
        elif (grp_slice['accountType'][i]=='PL') and (grp_slice['DPD30P1M_flag'][i]==1):
            count_PL = count_PL + 1
        elif (grp_slice['accountType'][i]=='PLBL') and (grp_slice['DPD30P1M_flag'][i]==1):
            count_PLBL = count_PLBL + 1
        elif (grp_slice['accountType'][i]=='RL') and (grp_slice['DPD30P1M_flag'][i]==1):
            count_RL = count_RL + 1
        elif (grp_slice['accountType'][i]=='SCC') and (grp_slice['DPD30P1M_flag'][i]==1):
            count_SCC = count_SCC + 1
        elif (grp_slice['accountType'][i]=='SEL') and (grp_slice['DPD30P1M_flag'][i]==1):
            count_SEL = count_SEL + 1
            
    count_list_AL.append(count_AL)
    count_list_BL.append(count_BL)
    count_list_CC.append(count_CC)
    count_list_CD.append(count_CD)
    count_list_CV.append(count_CV)
    count_list_GL.append(count_GL)
    count_list_HL.append(count_HL)
    count_list_LAS.append(count_LAS)
    count_list_MFBL.append(count_MFBL)
    count_list_MFHL.append(count_MFHL)
    count_list_MFOT.append(count_MFOT)
    count_list_OTH.append(count_OTH)
    count_list_PL.append(count_PL)
    count_list_PLBL.append(count_PLBL)
    count_list_RL.append(count_RL)
    count_list_SCC.append(count_SCC)
    count_list_SEL.append(count_SEL)
    
    count_AL = 0
    count_BL = 0
    count_CC = 0
    count_CD = 0
    count_CV = 0
    count_GL = 0
    count_HL = 0
    count_LAS = 0
    count_MFBL = 0
    count_MFHL = 0
    count_MFOT = 0
    count_OTH = 0
    count_PL = 0
    count_PLBL = 0
    count_RL = 0
    count_SCC = 0
    count_SEL = 0
    
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['accountType'][i]=='unknown'):
            DPD30P1M_AL.append('unknown')
            DPD30P1M_BL.append('unknown')
            DPD30P1M_CC.append('unknown')
            DPD30P1M_CD.append('unknown')
            DPD30P1M_CV.append('unknown')
            DPD30P1M_GL.append('unknown')
            DPD30P1M_HL.append('unknown')
            DPD30P1M_LAS.append('unknown')
            DPD30P1M_MFBL.append('unknown')
            DPD30P1M_MFHL.append('unknown')
            DPD30P1M_MFOT.append('unknown')
            DPD30P1M_OTH.append('unknown')
            DPD30P1M_PL.append('unknown')
            DPD30P1M_PLBL.append('unknown')
            DPD30P1M_RL.append('unknown')
            DPD30P1M_SCC.append('unknown')
            DPD30P1M_SEL.append('unknown')
        else:
            DPD30P1M_AL.append(count_list_AL[x])
            DPD30P1M_BL.append(count_list_BL[x])
            DPD30P1M_CC.append(count_list_CC[x])
            DPD30P1M_CD.append(count_list_CD[x])
            DPD30P1M_CV.append(count_list_CV[x])
            DPD30P1M_GL.append(count_list_GL[x])
            DPD30P1M_HL.append(count_list_HL[x])
            DPD30P1M_LAS.append(count_list_LAS[x])
            DPD30P1M_MFBL.append(count_list_MFBL[x])
            DPD30P1M_MFHL.append(count_list_MFHL[x])
            DPD30P1M_MFOT.append(count_list_MFOT[x])
            DPD30P1M_OTH.append(count_list_OTH[x])
            DPD30P1M_PL.append(count_list_PL[x])
            DPD30P1M_PLBL.append(count_list_PLBL[x])
            DPD30P1M_RL.append(count_list_RL[x])
            DPD30P1M_SCC.append(count_list_SCC[x])
            DPD30P1M_SEL.append(count_list_SEL[x])
            
df['DPD30P1M_AL'] = pd.Series(DPD30P1M_AL).values
df['DPD30P1M_BL'] = pd.Series(DPD30P1M_BL).values
df['DPD30P1M_CC'] = pd.Series(DPD30P1M_CC).values
df['DPD30P1M_CD'] = pd.Series(DPD30P1M_CD).values
df['DPD30P1M_CV'] = pd.Series(DPD30P1M_CV).values
df['DPD30P1M_GL'] = pd.Series(DPD30P1M_GL).values
df['DPD30P1M_HL'] = pd.Series(DPD30P1M_HL).values
df['DPD30P1M_LAS'] = pd.Series(DPD30P1M_LAS).values
df['DPD30P1M_MFBL'] = pd.Series(DPD30P1M_MFBL).values
df['DPD30P1M_MFHL'] = pd.Series(DPD30P1M_MFHL).values
df['DPD30P1M_MFOT'] = pd.Series(DPD30P1M_MFOT).values
df['DPD30P1M_OTH'] = pd.Series(DPD30P1M_OTH).values
df['DPD30P1M_PL'] = pd.Series(DPD30P1M_PL).values
df['DPD30P1M_PLBL'] = pd.Series(DPD30P1M_PLBL).values
df['DPD30P1M_RL'] = pd.Series(DPD30P1M_RL).values
df['DPD30P1M_SCC'] = pd.Series(DPD30P1M_SCC).values
df['DPD30P1M_SEL'] = pd.Series(DPD30P1M_SEL).values

print("%s seconds" % (time.time() - start_time))

# %% [raw]
# d = df[['ID','DPD30P1M_AL','DPD30P1M_flag','accountType']]
# d[d['DPD30P1M_flag']!=0].head(60)

# %% [raw]
# df['DPD30P1M_PL'].value_counts()

# %% [markdown]
# ### Code for DPD60P1M_P

# %% [markdown]
# - DPD 60 in last 1 month productwise
# - For an applicant, Count of all loans where DPD60P1M_flag =1 per product

# %%
DPD60P1M_AL = list()
DPD60P1M_BL = list()
DPD60P1M_CC = list()
DPD60P1M_CD = list()
DPD60P1M_CV = list()
DPD60P1M_GL = list()
DPD60P1M_HL = list()
DPD60P1M_LAS = list()
DPD60P1M_MFBL = list()
DPD60P1M_MFHL = list()
DPD60P1M_MFOT = list()
DPD60P1M_OTH = list()
DPD60P1M_PL = list()
DPD60P1M_PLBL = list()
DPD60P1M_RL = list()
DPD60P1M_SCC = list()
DPD60P1M_SEL = list()

count_list_AL = list()
count_list_BL = list()
count_list_CC = list()
count_list_CD = list()
count_list_CV = list()
count_list_GL = list()
count_list_HL = list()
count_list_LAS = list()
count_list_MFBL = list()
count_list_MFHL = list()
count_list_MFOT = list()
count_list_OTH = list()
count_list_PL = list()
count_list_PLBL = list()
count_list_RL = list()
count_list_SCC = list()
count_list_SEL = list()

count_AL = 0
count_BL = 0
count_CC = 0
count_CD = 0
count_CV = 0
count_GL = 0
count_HL = 0
count_LAS = 0
count_MFBL = 0
count_MFHL = 0
count_MFOT = 0
count_OTH = 0
count_PL = 0 
count_PLBL = 0
count_RL = 0
count_SCC = 0
count_SEL = 0

grp_df = df.groupby('ID')

for x in range(0, len(unq_id_list)):
    grp_slice = grp_df.get_group(unq_id_list[x])
    #print(grp_slice)
    grp_slice.reset_index(drop=True, inplace=True)
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['accountType'][i]=='unknown'):
            continue
        elif (grp_slice['accountType'][i]=='AL') and (grp_slice['DPD60P1M_flag'][i]==1):
            count_AL = count_AL + 1
        elif (grp_slice['accountType'][i]=='BL') and (grp_slice['DPD60P1M_flag'][i]==1):
            count_BL = count_BL + 1
        elif (grp_slice['accountType'][i]=='CC') and (grp_slice['DPD60P1M_flag'][i]==1):
            count_CC = count_CC + 1
        elif (grp_slice['accountType'][i]=='CD') and (grp_slice['DPD60P1M_flag'][i]==1):
            count_CD = count_CD + 1
        elif (grp_slice['accountType'][i]=='CV') and (grp_slice['DPD60P1M_flag'][i]==1):
            count_CV = count_CV + 1
        elif (grp_slice['accountType'][i]=='GL') and (grp_slice['DPD60P1M_flag'][i]==1):
            count_GL = count_GL + 1
        elif (grp_slice['accountType'][i]=='HL') and (grp_slice['DPD60P1M_flag'][i]==1):
            count_HL = count_HL + 1
        elif (grp_slice['accountType'][i]=='LAS') and (grp_slice['DPD60P1M_flag'][i]==1):
            count_LAS = count_LAS + 1
        elif (grp_slice['accountType'][i]=='MFBL') and (grp_slice['DPD60P1M_flag'][i]==1):
            count_MFBL = count_MFBL + 1
        elif (grp_slice['accountType'][i]=='MFHL') and (grp_slice['DPD60P1M_flag'][i]==1):
            count_MFHL = count_MFHL + 1
        elif (grp_slice['accountType'][i]=='MFOT') and (grp_slice['DPD60P1M_flag'][i]==1):
            count_MFOT = count_MFOT + 1
        elif (grp_slice['accountType'][i]=='OTH') and (grp_slice['DPD60P1M_flag'][i]==1):
            count_OTH = count_OTH + 1
        elif (grp_slice['accountType'][i]=='PL') and (grp_slice['DPD60P1M_flag'][i]==1):
            count_PL = count_PL + 1
        elif (grp_slice['accountType'][i]=='PLBL') and (grp_slice['DPD60P1M_flag'][i]==1):
            count_PLBL = count_PLBL + 1
        elif (grp_slice['accountType'][i]=='RL') and (grp_slice['DPD60P1M_flag'][i]==1):
            count_RL = count_RL + 1
        elif (grp_slice['accountType'][i]=='SCC') and (grp_slice['DPD60P1M_flag'][i]==1):
            count_SCC = count_SCC + 1
        elif (grp_slice['accountType'][i]=='SEL') and (grp_slice['DPD60P1M_flag'][i]==1):
            count_SEL = count_SEL + 1
            
    count_list_AL.append(count_AL)
    count_list_BL.append(count_BL)
    count_list_CC.append(count_CC)
    count_list_CD.append(count_CD)
    count_list_CV.append(count_CV)
    count_list_GL.append(count_GL)
    count_list_HL.append(count_HL)
    count_list_LAS.append(count_LAS)
    count_list_MFBL.append(count_MFBL)
    count_list_MFHL.append(count_MFHL)
    count_list_MFOT.append(count_MFOT)
    count_list_OTH.append(count_OTH)
    count_list_PL.append(count_PL)
    count_list_PLBL.append(count_PLBL)
    count_list_RL.append(count_RL)
    count_list_SCC.append(count_SCC)
    count_list_SEL.append(count_SEL)
    
    count_AL = 0
    count_BL = 0
    count_CC = 0
    count_CD = 0
    count_CV = 0
    count_GL = 0
    count_HL = 0
    count_LAS = 0
    count_MFBL = 0
    count_MFHL = 0
    count_MFOT = 0
    count_OTH = 0
    count_PL = 0
    count_PLBL = 0
    count_RL = 0
    count_SCC = 0
    count_SEL = 0
    
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['accountType'][i]=='unknown'):
            DPD60P1M_AL.append('unknown')
            DPD60P1M_BL.append('unknown')
            DPD60P1M_CC.append('unknown')
            DPD60P1M_CD.append('unknown')
            DPD60P1M_CV.append('unknown')
            DPD60P1M_GL.append('unknown')
            DPD60P1M_HL.append('unknown')
            DPD60P1M_LAS.append('unknown')
            DPD60P1M_MFBL.append('unknown')
            DPD60P1M_MFHL.append('unknown')
            DPD60P1M_MFOT.append('unknown')
            DPD60P1M_OTH.append('unknown')
            DPD60P1M_PL.append('unknown')
            DPD60P1M_PLBL.append('unknown')
            DPD60P1M_RL.append('unknown')
            DPD60P1M_SCC.append('unknown')
            DPD60P1M_SEL.append('unknown')
        else:
            DPD60P1M_AL.append(count_list_AL[x])
            DPD60P1M_BL.append(count_list_BL[x])
            DPD60P1M_CC.append(count_list_CC[x])
            DPD60P1M_CD.append(count_list_CD[x])
            DPD60P1M_CV.append(count_list_CV[x])
            DPD60P1M_GL.append(count_list_GL[x])
            DPD60P1M_HL.append(count_list_HL[x])
            DPD60P1M_LAS.append(count_list_LAS[x])
            DPD60P1M_MFBL.append(count_list_MFBL[x])
            DPD60P1M_MFHL.append(count_list_MFHL[x])
            DPD60P1M_MFOT.append(count_list_MFOT[x])
            DPD60P1M_OTH.append(count_list_OTH[x])
            DPD60P1M_PL.append(count_list_PL[x])
            DPD60P1M_PLBL.append(count_list_PLBL[x])
            DPD60P1M_RL.append(count_list_RL[x])
            DPD60P1M_SCC.append(count_list_SCC[x])
            DPD60P1M_SEL.append(count_list_SEL[x])
            
df['DPD60P1M_AL'] = pd.Series(DPD60P1M_AL).values
df['DPD60P1M_BL'] = pd.Series(DPD60P1M_BL).values
df['DPD60P1M_CC'] = pd.Series(DPD60P1M_CC).values
df['DPD60P1M_CD'] = pd.Series(DPD60P1M_CD).values
df['DPD60P1M_CV'] = pd.Series(DPD60P1M_CV).values
df['DPD60P1M_GL'] = pd.Series(DPD60P1M_GL).values
df['DPD60P1M_HL'] = pd.Series(DPD60P1M_HL).values
df['DPD60P1M_LAS'] = pd.Series(DPD60P1M_LAS).values
df['DPD60P1M_MFBL'] = pd.Series(DPD60P1M_MFBL).values
df['DPD60P1M_MFHL'] = pd.Series(DPD60P1M_MFHL).values
df['DPD60P1M_MFOT'] = pd.Series(DPD60P1M_MFOT).values
df['DPD60P1M_OTH'] = pd.Series(DPD60P1M_OTH).values
df['DPD60P1M_PL'] = pd.Series(DPD60P1M_PL).values
df['DPD60P1M_PLBL'] = pd.Series(DPD60P1M_PLBL).values
df['DPD60P1M_RL'] = pd.Series(DPD60P1M_RL).values
df['DPD60P1M_SCC'] = pd.Series(DPD60P1M_SCC).values
df['DPD60P1M_SEL'] = pd.Series(DPD60P1M_SEL).values

# %% [raw]
# d = df[['ID','DPD60P1M_GL','DPD60P1M_flag','accountType']]
# d[d['DPD60P1M_flag']!=0].head(60)

# %% [markdown]
# ### Code for DPD90P1M_P

# %% [markdown]
# - DPD 90 in last 1 month productwise
# - For an applicant, Count of all loans where DPD90P1M_flag =1 per product

# %%
DPD90P1M_AL = list()
DPD90P1M_BL = list()
DPD90P1M_CC = list()
DPD90P1M_CD = list()
DPD90P1M_CV = list()
DPD90P1M_GL = list()
DPD90P1M_HL = list()
DPD90P1M_LAS = list()
DPD90P1M_MFBL = list()
DPD90P1M_MFHL = list()
DPD90P1M_MFOT = list()
DPD90P1M_OTH = list()
DPD90P1M_PL = list()
DPD90P1M_PLBL = list()
DPD90P1M_RL = list()
DPD90P1M_SCC = list()
DPD90P1M_SEL = list()

count_list_AL = list()
count_list_BL = list()
count_list_CC = list()
count_list_CD = list()
count_list_CV = list()
count_list_GL = list()
count_list_HL = list()
count_list_LAS = list()
count_list_MFBL = list()
count_list_MFHL = list()
count_list_MFOT = list()
count_list_OTH = list()
count_list_PL = list()
count_list_PLBL = list()
count_list_RL = list()
count_list_SCC = list()
count_list_SEL = list()

count_AL = 0
count_BL = 0
count_CC = 0
count_CD = 0
count_CV = 0
count_GL = 0
count_HL = 0
count_LAS = 0
count_MFBL = 0
count_MFHL = 0
count_MFOT = 0
count_OTH = 0
count_PL = 0 
count_PLBL = 0
count_RL = 0
count_SCC = 0
count_SEL = 0

grp_df = df.groupby('ID')

for x in range(0, len(unq_id_list)):
    grp_slice = grp_df.get_group(unq_id_list[x])
    #print(grp_slice)
    grp_slice.reset_index(drop=True, inplace=True)
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['accountType'][i]=='unknown'):
            continue
        elif (grp_slice['accountType'][i]=='AL') and (grp_slice['DPD90P1M_flag'][i]==1):
            count_AL = count_AL + 1
        elif (grp_slice['accountType'][i]=='BL') and (grp_slice['DPD90P1M_flag'][i]==1):
            count_BL = count_BL + 1
        elif (grp_slice['accountType'][i]=='CC') and (grp_slice['DPD90P1M_flag'][i]==1):
            count_CC = count_CC + 1
        elif (grp_slice['accountType'][i]=='CD') and (grp_slice['DPD90P1M_flag'][i]==1):
            count_CD = count_CD + 1
        elif (grp_slice['accountType'][i]=='CV') and (grp_slice['DPD90P1M_flag'][i]==1):
            count_CV = count_CV + 1
        elif (grp_slice['accountType'][i]=='GL') and (grp_slice['DPD90P1M_flag'][i]==1):
            count_GL = count_GL + 1
        elif (grp_slice['accountType'][i]=='HL') and (grp_slice['DPD90P1M_flag'][i]==1):
            count_HL = count_HL + 1
        elif (grp_slice['accountType'][i]=='LAS') and (grp_slice['DPD90P1M_flag'][i]==1):
            count_LAS = count_LAS + 1
        elif (grp_slice['accountType'][i]=='MFBL') and (grp_slice['DPD90P1M_flag'][i]==1):
            count_MFBL = count_MFBL + 1
        elif (grp_slice['accountType'][i]=='MFHL') and (grp_slice['DPD90P1M_flag'][i]==1):
            count_MFHL = count_MFHL + 1
        elif (grp_slice['accountType'][i]=='MFOT') and (grp_slice['DPD90P1M_flag'][i]==1):
            count_MFOT = count_MFOT + 1
        elif (grp_slice['accountType'][i]=='OTH') and (grp_slice['DPD90P1M_flag'][i]==1):
            count_OTH = count_OTH + 1
        elif (grp_slice['accountType'][i]=='PL') and (grp_slice['DPD90P1M_flag'][i]==1):
            count_PL = count_PL + 1
        elif (grp_slice['accountType'][i]=='PLBL') and (grp_slice['DPD90P1M_flag'][i]==1):
            count_PLBL = count_PLBL + 1
        elif (grp_slice['accountType'][i]=='RL') and (grp_slice['DPD90P1M_flag'][i]==1):
            count_RL = count_RL + 1
        elif (grp_slice['accountType'][i]=='SCC') and (grp_slice['DPD90P1M_flag'][i]==1):
            count_SCC = count_SCC + 1
        elif (grp_slice['accountType'][i]=='SEL') and (grp_slice['DPD90P1M_flag'][i]==1):
            count_SEL = count_SEL + 1
            
    count_list_AL.append(count_AL)
    count_list_BL.append(count_BL)
    count_list_CC.append(count_CC)
    count_list_CD.append(count_CD)
    count_list_CV.append(count_CV)
    count_list_GL.append(count_GL)
    count_list_HL.append(count_HL)
    count_list_LAS.append(count_LAS)
    count_list_MFBL.append(count_MFBL)
    count_list_MFHL.append(count_MFHL)
    count_list_MFOT.append(count_MFOT)
    count_list_OTH.append(count_OTH)
    count_list_PL.append(count_PL)
    count_list_PLBL.append(count_PLBL)
    count_list_RL.append(count_RL)
    count_list_SCC.append(count_SCC)
    count_list_SEL.append(count_SEL)
    
    count_AL = 0
    count_BL = 0
    count_CC = 0
    count_CD = 0
    count_CV = 0
    count_GL = 0
    count_HL = 0
    count_LAS = 0
    count_MFBL = 0
    count_MFHL = 0
    count_MFOT = 0
    count_OTH = 0
    count_PL = 0
    count_PLBL = 0
    count_RL = 0
    count_SCC = 0
    count_SEL = 0
    
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['accountType'][i]=='unknown'):
            DPD90P1M_AL.append('unknown')
            DPD90P1M_BL.append('unknown')
            DPD90P1M_CC.append('unknown')
            DPD90P1M_CD.append('unknown')
            DPD90P1M_CV.append('unknown')
            DPD90P1M_GL.append('unknown')
            DPD90P1M_HL.append('unknown')
            DPD90P1M_LAS.append('unknown')
            DPD90P1M_MFBL.append('unknown')
            DPD90P1M_MFHL.append('unknown')
            DPD90P1M_MFOT.append('unknown')
            DPD90P1M_OTH.append('unknown')
            DPD90P1M_PL.append('unknown')
            DPD90P1M_PLBL.append('unknown')
            DPD90P1M_RL.append('unknown')
            DPD90P1M_SCC.append('unknown')
            DPD90P1M_SEL.append('unknown')
        else:
            DPD90P1M_AL.append(count_list_AL[x])
            DPD90P1M_BL.append(count_list_BL[x])
            DPD90P1M_CC.append(count_list_CC[x])
            DPD90P1M_CD.append(count_list_CD[x])
            DPD90P1M_CV.append(count_list_CV[x])
            DPD90P1M_GL.append(count_list_GL[x])
            DPD90P1M_HL.append(count_list_HL[x])
            DPD90P1M_LAS.append(count_list_LAS[x])
            DPD90P1M_MFBL.append(count_list_MFBL[x])
            DPD90P1M_MFHL.append(count_list_MFHL[x])
            DPD90P1M_MFOT.append(count_list_MFOT[x])
            DPD90P1M_OTH.append(count_list_OTH[x])
            DPD90P1M_PL.append(count_list_PL[x])
            DPD90P1M_PLBL.append(count_list_PLBL[x])
            DPD90P1M_RL.append(count_list_RL[x])
            DPD90P1M_SCC.append(count_list_SCC[x])
            DPD90P1M_SEL.append(count_list_SEL[x])
            
df['DPD90P1M_AL'] = pd.Series(DPD90P1M_AL).values
df['DPD90P1M_BL'] = pd.Series(DPD90P1M_BL).values
df['DPD90P1M_CC'] = pd.Series(DPD90P1M_CC).values
df['DPD90P1M_CD'] = pd.Series(DPD90P1M_CD).values
df['DPD90P1M_CV'] = pd.Series(DPD90P1M_CV).values
df['DPD90P1M_GL'] = pd.Series(DPD90P1M_GL).values
df['DPD90P1M_HL'] = pd.Series(DPD90P1M_HL).values
df['DPD90P1M_LAS'] = pd.Series(DPD90P1M_LAS).values
df['DPD90P1M_MFBL'] = pd.Series(DPD90P1M_MFBL).values
df['DPD90P1M_MFHL'] = pd.Series(DPD90P1M_MFHL).values
df['DPD90P1M_MFOT'] = pd.Series(DPD90P1M_MFOT).values
df['DPD90P1M_OTH'] = pd.Series(DPD90P1M_OTH).values
df['DPD90P1M_PL'] = pd.Series(DPD90P1M_PL).values
df['DPD90P1M_PLBL'] = pd.Series(DPD90P1M_PLBL).values
df['DPD90P1M_RL'] = pd.Series(DPD90P1M_RL).values
df['DPD90P1M_SCC'] = pd.Series(DPD90P1M_SCC).values
df['DPD90P1M_SEL'] = pd.Series(DPD90P1M_SEL).values

# %% [raw]
# d = df[['ID','DPD90P1M_HL','DPD90P1M_flag','accountType']]
# d[d['DPD90P1M_flag']!=0].head(60)

# %% [markdown]
# <a id='DPD_flags_3m'></a>
# ### Code for DPD flags for last 3 months

# %%
def CheckForLess(list1, val):  
    return(any(x < val for x in list1))

# %%
def CheckForInBetween(list1, val1, val2):  
    #return(any(x >= val1 for x in list1) and any(x <= val2 for x in list1))
    return any(list(x for x in list1 if val1 <= x <= val2)) 

#match = [117, 0, 29]
#CheckForInBetween(match, 1, 30)

# %%
def CheckForMore(list1, val):  
    return(any(x > val for x in list1))

# %%
intPayHist = list()
intPayHistComp = list()

for x in range(0, df.shape[0]):
    for i in range(0, len(df['payHistComp'][x])):
        if hasNumbers(df['payHistComp'][x][i]):
            a = int(df['payHistComp'][x][i])
            intPayHist.append(a)
        else:
            intPayHist.append(0)
            
    intPayHistComp.append(intPayHist)
    intPayHist = list()        
#print(len(intPayHistComp))
#intPayHistComp[0]
df['intPayHistComp'] = pd.Series(intPayHistComp).values

# %%
dpd30_3m = list()
dpd60_3m = list()
dpd90_3m = list()
matching = list()

for x in range(0, df.shape[0]):
    if (df['mo_diff_ld_drc'][x] == -1):
        #print(df['mo_diff_ld_drc'][x])
        dpd30_3m.append('unknown')
        dpd60_3m.append('unknown')
        dpd90_3m.append('unknown')
    elif (df['mo_diff_ld_drc'][x] >= 0) and (df['mo_diff_ld_drc'][x] <= 3):
        #print(df['mo_diff_ld_drc'][x])
        for i in range(0, 3-df['mo_diff_ld_drc'][x]):
            a = df['intPayHistComp'][x][i]
            matching.append(a)
        #print(matching)
        if (sum(matching) > 0) and (sum(matching) <= 30):
            dpd30_3m.append(1)
            dpd60_3m.append(0)
            dpd90_3m.append(0)
            #print('3',matching)
        elif (sum(matching) > 30) and (sum(matching) <= 60):
            dpd30_3m.append(0)
            dpd60_3m.append(1)
            dpd90_3m.append(0)
            #print('2',matching)
        elif (sum(matching) > 60) and (sum(matching) <= 90):
            dpd30_3m.append(0)
            dpd60_3m.append(0)
            dpd90_3m.append(1)
            #print('1',matching)
        else:
            dpd30_3m.append(0)
            dpd60_3m.append(0)
            dpd90_3m.append(0)
    else:
        dpd30_3m.append(0)
        dpd60_3m.append(0)
        dpd90_3m.append(0)
            
            
        matching = list()
        
df['DPD30P3M_flag'] = pd.Series(dpd30_3m).values
df['DPD60P3M_flag'] = pd.Series(dpd60_3m).values
df['DPD90P3M_flag'] = pd.Series(dpd90_3m).values

#df['DPD30P3M_flag'].value_counts()
#print(len(dpd30_3m))

# %% [raw]
# a = df[['mo_diff_ld_drc','intPayHistComp']]
# a.to_csv('a.csv')

# %% [raw]
# piece = list()
# sum_dpd_3m = 0
#
# dpd30_3m = list()
# dpd60_3m = list()
# dpd90_3m = list()
#
# for value in df['paymentHist1']:
#     #print(value)
#     chunks, chunk_size = len(value), 3
#     for i in range(0, chunks, chunk_size):
#         piece.append(value[i:i+chunk_size])
#     #print(piece)
#     if len(piece)>=3:
#         #print(piece)
#         for x in range(0,3):
#             #print(x)
#             if hasNumbers(piece[x]):
#                 piece[x] = int(piece[x])
#                 sum_dpd_3m = piece[x] + sum_dpd_3m
#             else:
#                 continue
#         #print(piece)
#         #print(sum_dpd_3m)
#         if (sum_dpd_3m > 0) and (sum_dpd_3m <= 30):
#             #print(piece)
#             #print(sum_dpd_3m)
#             dpd30_3m.append(1)
#             dpd60_3m.append(0)
#             dpd90_3m.append(0)
#             sum_dpd_3m = 0
#         elif (sum_dpd_3m <= 60) and (sum_dpd_3m > 30):
#             #print(piece)
#             #print(sum_dpd_3m)
#             dpd30_3m.append(0)
#             dpd60_3m.append(1)
#             dpd90_3m.append(0)
#             sum_dpd_3m = 0
#         elif (sum_dpd_3m <= 90) and (sum_dpd_3m > 60):
#             #print(piece)
#             dpd30_3m.append(0)
#             dpd60_3m.append(0)
#             dpd90_3m.append(1)
#             sum_dpd_3m = 0
#         else:
#             dpd30_3m.append(0)
#             dpd60_3m.append(0)
#             dpd90_3m.append(0)
#     else:
#         dpd30_3m.append(0)
#         dpd60_3m.append(0)
#         dpd90_3m.append(0)
#
#
#
#         sum_dpd_3m = 0
#     piece = list()
#
# df['DPD30P3M_flag'] = pd.Series(dpd30_3m).values
# df['DPD60P3M_flag'] = pd.Series(dpd60_3m).values
# df['DPD90P3M_flag'] = pd.Series(dpd90_3m).values

# %% [markdown]
# <a id='DPD3M_num'></a>
# ### Code for DPD1M (numerical)

# %% [markdown]
# - For an applicant, Count of all loans where DPD30P3M_flag =1
# - For an applicant, Count of all loans where DPD60P3M_flag =1
# - For an applicant, Count of all loans where DPD90P3M_flag =1

# %%
DPD30P3M = list()
count_list_30_3m = list()
count_30_3m = 0

DPD60P3M = list()
count_list_60_3m = list()
count_60_3m = 0

DPD90P3M = list()
count_list_90_3m = list()
count_90_3m = 0

grp_df = df.groupby('ID')

for x in range(0, len(unq_id_list)):
    grp_slice = grp_df.get_group(unq_id_list[x])
    #print(grp_slice)
    grp_slice.reset_index(drop=True, inplace=True)
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['DPD30P3M_flag'][i]==1) or (grp_slice['DPD30P3M_flag'][i]==0):
            count_30_3m = count_30_3m + grp_slice['DPD30P3M_flag'][i]
        
        if (grp_slice['DPD60P3M_flag'][i]==1) or (grp_slice['DPD60P3M_flag'][i]==0):
            count_60_3m = count_60_3m + grp_slice['DPD60P3M_flag'][i]

        if (grp_slice['DPD90P3M_flag'][i]==1) or (grp_slice['DPD90P3M_flag'][i]==0):
            count_90_3m = count_90_3m + grp_slice['DPD90P3M_flag'][i]

    count_list_30_3m.append(count_30_3m)
    count_30_3m = 0
    count_list_60_3m.append(count_60_3m)
    count_60_3m = 0
    count_list_90_3m.append(count_90_3m)
    count_90_3m = 0

    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['DPD30P3M_flag'][i]==1) or (grp_slice['DPD30P3M_flag'][i]==0):
            DPD30P3M.append(count_list_30_3m[x])
        else:
            DPD30P3M.append('unknown')

        if (grp_slice['DPD60P3M_flag'][i]==1) or (grp_slice['DPD60P3M_flag'][i]==0):
            DPD60P3M.append(count_list_60_3m[x])
        else:
            DPD60P3M.append('unknown')

        if (grp_slice['DPD90P3M_flag'][i]==1) or (grp_slice['DPD90P3M_flag'][i]==0):
            DPD90P3M.append(count_list_90_3m[x])
        else:
            DPD90P3M.append('unknown')
            
df['DPD30P3M'] = pd.Series(DPD30P3M).values
df['DPD60P3M'] = pd.Series(DPD60P3M).values
df['DPD90P3M'] = pd.Series(DPD90P3M).values
#df['DPD60P3M'].value_counts()

# %% [markdown]
# ### Code for DPD30P3M_P

# %% [markdown]
# - DPD 30 in last 3 month productwise
# - For an applicant, Count of all loans where DPD30P3M_flag =1 per product

# %%
DPD30P3M_AL = list()
DPD30P3M_BL = list()
DPD30P3M_CC = list()
DPD30P3M_CD = list()
DPD30P3M_CV = list()
DPD30P3M_GL = list()
DPD30P3M_HL = list()
DPD30P3M_LAS = list()
DPD30P3M_MFBL = list()
DPD30P3M_MFHL = list()
DPD30P3M_MFOT = list()
DPD30P3M_OTH = list()
DPD30P3M_PL = list()
DPD30P3M_PLBL = list()
DPD30P3M_RL = list()
DPD30P3M_SCC = list()
DPD30P3M_SEL = list()

count_list_AL = list()
count_list_BL = list()
count_list_CC = list()
count_list_CD = list()
count_list_CV = list()
count_list_GL = list()
count_list_HL = list()
count_list_LAS = list()
count_list_MFBL = list()
count_list_MFHL = list()
count_list_MFOT = list()
count_list_OTH = list()
count_list_PL = list()
count_list_PLBL = list()
count_list_RL = list()
count_list_SCC = list()
count_list_SEL = list()

count_AL = 0
count_BL = 0
count_CC = 0
count_CD = 0
count_CV = 0
count_GL = 0
count_HL = 0
count_LAS = 0
count_MFBL = 0
count_MFHL = 0
count_MFOT = 0
count_OTH = 0
count_PL = 0 
count_PLBL = 0
count_RL = 0
count_SCC = 0
count_SEL = 0

grp_df = df.groupby('ID')

for x in range(0, len(unq_id_list)):
    grp_slice = grp_df.get_group(unq_id_list[x])
    #print(grp_slice)
    grp_slice.reset_index(drop=True, inplace=True)
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['accountType'][i]=='unknown'):
            continue
        elif (grp_slice['accountType'][i]=='AL') and (grp_slice['DPD30P3M_flag'][i]==1):
            count_AL = count_AL + 1
        elif (grp_slice['accountType'][i]=='BL') and (grp_slice['DPD30P3M_flag'][i]==1):
            count_BL = count_BL + 1
        elif (grp_slice['accountType'][i]=='CC') and (grp_slice['DPD30P3M_flag'][i]==1):
            count_CC = count_CC + 1
        elif (grp_slice['accountType'][i]=='CD') and (grp_slice['DPD30P3M_flag'][i]==1):
            count_CD = count_CD + 1
        elif (grp_slice['accountType'][i]=='CV') and (grp_slice['DPD30P3M_flag'][i]==1):
            count_CV = count_CV + 1
        elif (grp_slice['accountType'][i]=='GL') and (grp_slice['DPD30P3M_flag'][i]==1):
            count_GL = count_GL + 1
        elif (grp_slice['accountType'][i]=='HL') and (grp_slice['DPD30P3M_flag'][i]==1):
            count_HL = count_HL + 1
        elif (grp_slice['accountType'][i]=='LAS') and (grp_slice['DPD30P3M_flag'][i]==1):
            count_LAS = count_LAS + 1
        elif (grp_slice['accountType'][i]=='MFBL') and (grp_slice['DPD30P3M_flag'][i]==1):
            count_MFBL = count_MFBL + 1
        elif (grp_slice['accountType'][i]=='MFHL') and (grp_slice['DPD30P3M_flag'][i]==1):
            count_MFHL = count_MFHL + 1
        elif (grp_slice['accountType'][i]=='MFOT') and (grp_slice['DPD30P3M_flag'][i]==1):
            count_MFOT = count_MFOT + 1
        elif (grp_slice['accountType'][i]=='OTH') and (grp_slice['DPD30P3M_flag'][i]==1):
            count_OTH = count_OTH + 1
        elif (grp_slice['accountType'][i]=='PL') and (grp_slice['DPD30P3M_flag'][i]==1):
            count_PL = count_PL + 1
        elif (grp_slice['accountType'][i]=='PLBL') and (grp_slice['DPD30P3M_flag'][i]==1):
            count_PLBL = count_PLBL + 1
        elif (grp_slice['accountType'][i]=='RL') and (grp_slice['DPD30P3M_flag'][i]==1):
            count_RL = count_RL + 1
        elif (grp_slice['accountType'][i]=='SCC') and (grp_slice['DPD30P3M_flag'][i]==1):
            count_SCC = count_SCC + 1
        elif (grp_slice['accountType'][i]=='SEL') and (grp_slice['DPD30P3M_flag'][i]==1):
            count_SEL = count_SEL + 1
            
    count_list_AL.append(count_AL)
    count_list_BL.append(count_BL)
    count_list_CC.append(count_CC)
    count_list_CD.append(count_CD)
    count_list_CV.append(count_CV)
    count_list_GL.append(count_GL)
    count_list_HL.append(count_HL)
    count_list_LAS.append(count_LAS)
    count_list_MFBL.append(count_MFBL)
    count_list_MFHL.append(count_MFHL)
    count_list_MFOT.append(count_MFOT)
    count_list_OTH.append(count_OTH)
    count_list_PL.append(count_PL)
    count_list_PLBL.append(count_PLBL)
    count_list_RL.append(count_RL)
    count_list_SCC.append(count_SCC)
    count_list_SEL.append(count_SEL)
    
    count_AL = 0
    count_BL = 0
    count_CC = 0
    count_CD = 0
    count_CV = 0
    count_GL = 0
    count_HL = 0
    count_LAS = 0
    count_MFBL = 0
    count_MFHL = 0
    count_MFOT = 0
    count_OTH = 0
    count_PL = 0
    count_PLBL = 0
    count_RL = 0
    count_SCC = 0
    count_SEL = 0
    
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['accountType'][i]=='unknown'):
            DPD30P3M_AL.append('unknown')
            DPD30P3M_BL.append('unknown')
            DPD30P3M_CC.append('unknown')
            DPD30P3M_CD.append('unknown')
            DPD30P3M_CV.append('unknown')
            DPD30P3M_GL.append('unknown')
            DPD30P3M_HL.append('unknown')
            DPD30P3M_LAS.append('unknown')
            DPD30P3M_MFBL.append('unknown')
            DPD30P3M_MFHL.append('unknown')
            DPD30P3M_MFOT.append('unknown')
            DPD30P3M_OTH.append('unknown')
            DPD30P3M_PL.append('unknown')
            DPD30P3M_PLBL.append('unknown')
            DPD30P3M_RL.append('unknown')
            DPD30P3M_SCC.append('unknown')
            DPD30P3M_SEL.append('unknown')
        else:
            DPD30P3M_AL.append(count_list_AL[x])
            DPD30P3M_BL.append(count_list_BL[x])
            DPD30P3M_CC.append(count_list_CC[x])
            DPD30P3M_CD.append(count_list_CD[x])
            DPD30P3M_CV.append(count_list_CV[x])
            DPD30P3M_GL.append(count_list_GL[x])
            DPD30P3M_HL.append(count_list_HL[x])
            DPD30P3M_LAS.append(count_list_LAS[x])
            DPD30P3M_MFBL.append(count_list_MFBL[x])
            DPD30P3M_MFHL.append(count_list_MFHL[x])
            DPD30P3M_MFOT.append(count_list_MFOT[x])
            DPD30P3M_OTH.append(count_list_OTH[x])
            DPD30P3M_PL.append(count_list_PL[x])
            DPD30P3M_PLBL.append(count_list_PLBL[x])
            DPD30P3M_RL.append(count_list_RL[x])
            DPD30P3M_SCC.append(count_list_SCC[x])
            DPD30P3M_SEL.append(count_list_SEL[x])
            
df['DPD30P3M_AL'] = pd.Series(DPD30P3M_AL).values
df['DPD30P3M_BL'] = pd.Series(DPD30P3M_BL).values
df['DPD30P3M_CC'] = pd.Series(DPD30P3M_CC).values
df['DPD30P3M_CD'] = pd.Series(DPD30P3M_CD).values
df['DPD30P3M_CV'] = pd.Series(DPD30P3M_CV).values
df['DPD30P3M_GL'] = pd.Series(DPD30P3M_GL).values
df['DPD30P3M_HL'] = pd.Series(DPD30P3M_HL).values
df['DPD30P3M_LAS'] = pd.Series(DPD30P3M_LAS).values
df['DPD30P3M_MFBL'] = pd.Series(DPD30P3M_MFBL).values
df['DPD30P3M_MFHL'] = pd.Series(DPD30P3M_MFHL).values
df['DPD30P3M_MFOT'] = pd.Series(DPD30P3M_MFOT).values
df['DPD30P3M_OTH'] = pd.Series(DPD30P3M_OTH).values
df['DPD30P3M_PL'] = pd.Series(DPD30P3M_PL).values
df['DPD30P3M_PLBL'] = pd.Series(DPD30P3M_PLBL).values
df['DPD30P3M_RL'] = pd.Series(DPD30P3M_RL).values
df['DPD30P3M_SCC'] = pd.Series(DPD30P3M_SCC).values
df['DPD30P3M_SEL'] = pd.Series(DPD30P3M_SEL).values

# %% [raw]
# d = df[['ID','DPD30P3M_GL','DPD30P3M_flag','accountType']]
# d[d['DPD30P3M_flag']!=0].head(60)

# %% [markdown]
# ### Code for DPD60P3M_P

# %% [markdown]
# - DPD 60 in last 3 month productwise
# - For an applicant, Count of all loans where DPD60P3M_flag =1 per product

# %%
DPD60P3M_AL = list()
DPD60P3M_BL = list()
DPD60P3M_CC = list()
DPD60P3M_CD = list()
DPD60P3M_CV = list()
DPD60P3M_GL = list()
DPD60P3M_HL = list()
DPD60P3M_LAS = list()
DPD60P3M_MFBL = list()
DPD60P3M_MFHL = list()
DPD60P3M_MFOT = list()
DPD60P3M_OTH = list()
DPD60P3M_PL = list()
DPD60P3M_PLBL = list()
DPD60P3M_RL = list()
DPD60P3M_SCC = list()
DPD60P3M_SEL = list()

count_list_AL = list()
count_list_BL = list()
count_list_CC = list()
count_list_CD = list()
count_list_CV = list()
count_list_GL = list()
count_list_HL = list()
count_list_LAS = list()
count_list_MFBL = list()
count_list_MFHL = list()
count_list_MFOT = list()
count_list_OTH = list()
count_list_PL = list()
count_list_PLBL = list()
count_list_RL = list()
count_list_SCC = list()
count_list_SEL = list()

count_AL = 0
count_BL = 0
count_CC = 0
count_CD = 0
count_CV = 0
count_GL = 0
count_HL = 0
count_LAS = 0
count_MFBL = 0
count_MFHL = 0
count_MFOT = 0
count_OTH = 0
count_PL = 0 
count_PLBL = 0
count_RL = 0
count_SCC = 0
count_SEL = 0

grp_df = df.groupby('ID')

for x in range(0, len(unq_id_list)):
    grp_slice = grp_df.get_group(unq_id_list[x])
    #print(grp_slice)
    grp_slice.reset_index(drop=True, inplace=True)
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['accountType'][i]=='unknown'):
            continue
        elif (grp_slice['accountType'][i]=='AL') and (grp_slice['DPD60P3M_flag'][i]==1):
            count_AL = count_AL + 1
        elif (grp_slice['accountType'][i]=='BL') and (grp_slice['DPD60P3M_flag'][i]==1):
            count_BL = count_BL + 1
        elif (grp_slice['accountType'][i]=='CC') and (grp_slice['DPD60P3M_flag'][i]==1):
            count_CC = count_CC + 1
        elif (grp_slice['accountType'][i]=='CD') and (grp_slice['DPD60P3M_flag'][i]==1):
            count_CD = count_CD + 1
        elif (grp_slice['accountType'][i]=='CV') and (grp_slice['DPD60P3M_flag'][i]==1):
            count_CV = count_CV + 1
        elif (grp_slice['accountType'][i]=='GL') and (grp_slice['DPD60P3M_flag'][i]==1):
            count_GL = count_GL + 1
        elif (grp_slice['accountType'][i]=='HL') and (grp_slice['DPD60P3M_flag'][i]==1):
            count_HL = count_HL + 1
        elif (grp_slice['accountType'][i]=='LAS') and (grp_slice['DPD60P3M_flag'][i]==1):
            count_LAS = count_LAS + 1
        elif (grp_slice['accountType'][i]=='MFBL') and (grp_slice['DPD60P3M_flag'][i]==1):
            count_MFBL = count_MFBL + 1
        elif (grp_slice['accountType'][i]=='MFHL') and (grp_slice['DPD60P3M_flag'][i]==1):
            count_MFHL = count_MFHL + 1
        elif (grp_slice['accountType'][i]=='MFOT') and (grp_slice['DPD60P3M_flag'][i]==1):
            count_MFOT = count_MFOT + 1
        elif (grp_slice['accountType'][i]=='OTH') and (grp_slice['DPD60P3M_flag'][i]==1):
            count_OTH = count_OTH + 1
        elif (grp_slice['accountType'][i]=='PL') and (grp_slice['DPD60P3M_flag'][i]==1):
            count_PL = count_PL + 1
        elif (grp_slice['accountType'][i]=='PLBL') and (grp_slice['DPD60P3M_flag'][i]==1):
            count_PLBL = count_PLBL + 1
        elif (grp_slice['accountType'][i]=='RL') and (grp_slice['DPD60P3M_flag'][i]==1):
            count_RL = count_RL + 1
        elif (grp_slice['accountType'][i]=='SCC') and (grp_slice['DPD60P3M_flag'][i]==1):
            count_SCC = count_SCC + 1
        elif (grp_slice['accountType'][i]=='SEL') and (grp_slice['DPD60P3M_flag'][i]==1):
            count_SEL = count_SEL + 1
            
    count_list_AL.append(count_AL)
    count_list_BL.append(count_BL)
    count_list_CC.append(count_CC)
    count_list_CD.append(count_CD)
    count_list_CV.append(count_CV)
    count_list_GL.append(count_GL)
    count_list_HL.append(count_HL)
    count_list_LAS.append(count_LAS)
    count_list_MFBL.append(count_MFBL)
    count_list_MFHL.append(count_MFHL)
    count_list_MFOT.append(count_MFOT)
    count_list_OTH.append(count_OTH)
    count_list_PL.append(count_PL)
    count_list_PLBL.append(count_PLBL)
    count_list_RL.append(count_RL)
    count_list_SCC.append(count_SCC)
    count_list_SEL.append(count_SEL)
    
    count_AL = 0
    count_BL = 0
    count_CC = 0
    count_CD = 0
    count_CV = 0
    count_GL = 0
    count_HL = 0
    count_LAS = 0
    count_MFBL = 0
    count_MFHL = 0
    count_MFOT = 0
    count_OTH = 0
    count_PL = 0
    count_PLBL = 0
    count_RL = 0
    count_SCC = 0
    count_SEL = 0
    
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['accountType'][i]=='unknown'):
            DPD60P3M_AL.append('unknown')
            DPD60P3M_BL.append('unknown')
            DPD60P3M_CC.append('unknown')
            DPD60P3M_CD.append('unknown')
            DPD60P3M_CV.append('unknown')
            DPD60P3M_GL.append('unknown')
            DPD60P3M_HL.append('unknown')
            DPD60P3M_LAS.append('unknown')
            DPD60P3M_MFBL.append('unknown')
            DPD60P3M_MFHL.append('unknown')
            DPD60P3M_MFOT.append('unknown')
            DPD60P3M_OTH.append('unknown')
            DPD60P3M_PL.append('unknown')
            DPD60P3M_PLBL.append('unknown')
            DPD60P3M_RL.append('unknown')
            DPD60P3M_SCC.append('unknown')
            DPD60P3M_SEL.append('unknown')
        else:
            DPD60P3M_AL.append(count_list_AL[x])
            DPD60P3M_BL.append(count_list_BL[x])
            DPD60P3M_CC.append(count_list_CC[x])
            DPD60P3M_CD.append(count_list_CD[x])
            DPD60P3M_CV.append(count_list_CV[x])
            DPD60P3M_GL.append(count_list_GL[x])
            DPD60P3M_HL.append(count_list_HL[x])
            DPD60P3M_LAS.append(count_list_LAS[x])
            DPD60P3M_MFBL.append(count_list_MFBL[x])
            DPD60P3M_MFHL.append(count_list_MFHL[x])
            DPD60P3M_MFOT.append(count_list_MFOT[x])
            DPD60P3M_OTH.append(count_list_OTH[x])
            DPD60P3M_PL.append(count_list_PL[x])
            DPD60P3M_PLBL.append(count_list_PLBL[x])
            DPD60P3M_RL.append(count_list_RL[x])
            DPD60P3M_SCC.append(count_list_SCC[x])
            DPD60P3M_SEL.append(count_list_SEL[x])
            
df['DPD60P3M_AL'] = pd.Series(DPD60P3M_AL).values
df['DPD60P3M_BL'] = pd.Series(DPD60P3M_BL).values
df['DPD60P3M_CC'] = pd.Series(DPD60P3M_CC).values
df['DPD60P3M_CD'] = pd.Series(DPD60P3M_CD).values
df['DPD60P3M_CV'] = pd.Series(DPD60P3M_CV).values
df['DPD60P3M_GL'] = pd.Series(DPD60P3M_GL).values
df['DPD60P3M_HL'] = pd.Series(DPD60P3M_HL).values
df['DPD60P3M_LAS'] = pd.Series(DPD60P3M_LAS).values
df['DPD60P3M_MFBL'] = pd.Series(DPD60P3M_MFBL).values
df['DPD60P3M_MFHL'] = pd.Series(DPD60P3M_MFHL).values
df['DPD60P3M_MFOT'] = pd.Series(DPD60P3M_MFOT).values
df['DPD60P3M_OTH'] = pd.Series(DPD60P3M_OTH).values
df['DPD60P3M_PL'] = pd.Series(DPD60P3M_PL).values
df['DPD60P3M_PLBL'] = pd.Series(DPD60P3M_PLBL).values
df['DPD60P3M_RL'] = pd.Series(DPD60P3M_RL).values
df['DPD60P3M_SCC'] = pd.Series(DPD60P3M_SCC).values
df['DPD60P3M_SEL'] = pd.Series(DPD60P3M_SEL).values

# %% [raw]
# d = df[['ID','DPD60P3M_PL','DPD60P3M_flag','accountType']]
# d[d['DPD60P3M_flag']!=0].head(60)

# %% [markdown]
# ### Code for DPD90P3M_P

# %% [markdown]
# - DPD 90 in last 3 month productwise
# - For an applicant, Count of all loans where DPD90P3M_flag =1 per product

# %%
DPD90P3M_AL = list()
DPD90P3M_BL = list()
DPD90P3M_CC = list()
DPD90P3M_CD = list()
DPD90P3M_CV = list()
DPD90P3M_GL = list()
DPD90P3M_HL = list()
DPD90P3M_LAS = list()
DPD90P3M_MFBL = list()
DPD90P3M_MFHL = list()
DPD90P3M_MFOT = list()
DPD90P3M_OTH = list()
DPD90P3M_PL = list()
DPD90P3M_PLBL = list()
DPD90P3M_RL = list()
DPD90P3M_SCC = list()
DPD90P3M_SEL = list()

count_list_AL = list()
count_list_BL = list()
count_list_CC = list()
count_list_CD = list()
count_list_CV = list()
count_list_GL = list()
count_list_HL = list()
count_list_LAS = list()
count_list_MFBL = list()
count_list_MFHL = list()
count_list_MFOT = list()
count_list_OTH = list()
count_list_PL = list()
count_list_PLBL = list()
count_list_RL = list()
count_list_SCC = list()
count_list_SEL = list()

count_AL = 0
count_BL = 0
count_CC = 0
count_CD = 0
count_CV = 0
count_GL = 0
count_HL = 0
count_LAS = 0
count_MFBL = 0
count_MFHL = 0
count_MFOT = 0
count_OTH = 0
count_PL = 0 
count_PLBL = 0
count_RL = 0
count_SCC = 0
count_SEL = 0

grp_df = df.groupby('ID')

for x in range(0, len(unq_id_list)):
    grp_slice = grp_df.get_group(unq_id_list[x])
    #print(grp_slice)
    grp_slice.reset_index(drop=True, inplace=True)
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['accountType'][i]=='unknown'):
            continue
        elif (grp_slice['accountType'][i]=='AL') and (grp_slice['DPD90P3M_flag'][i]==1):
            count_AL = count_AL + 1
        elif (grp_slice['accountType'][i]=='BL') and (grp_slice['DPD90P3M_flag'][i]==1):
            count_BL = count_BL + 1
        elif (grp_slice['accountType'][i]=='CC') and (grp_slice['DPD90P3M_flag'][i]==1):
            count_CC = count_CC + 1
        elif (grp_slice['accountType'][i]=='CD') and (grp_slice['DPD90P3M_flag'][i]==1):
            count_CD = count_CD + 1
        elif (grp_slice['accountType'][i]=='CV') and (grp_slice['DPD90P3M_flag'][i]==1):
            count_CV = count_CV + 1
        elif (grp_slice['accountType'][i]=='GL') and (grp_slice['DPD90P3M_flag'][i]==1):
            count_GL = count_GL + 1
        elif (grp_slice['accountType'][i]=='HL') and (grp_slice['DPD90P3M_flag'][i]==1):
            count_HL = count_HL + 1
        elif (grp_slice['accountType'][i]=='LAS') and (grp_slice['DPD90P3M_flag'][i]==1):
            count_LAS = count_LAS + 1
        elif (grp_slice['accountType'][i]=='MFBL') and (grp_slice['DPD90P3M_flag'][i]==1):
            count_MFBL = count_MFBL + 1
        elif (grp_slice['accountType'][i]=='MFHL') and (grp_slice['DPD90P3M_flag'][i]==1):
            count_MFHL = count_MFHL + 1
        elif (grp_slice['accountType'][i]=='MFOT') and (grp_slice['DPD90P3M_flag'][i]==1):
            count_MFOT = count_MFOT + 1
        elif (grp_slice['accountType'][i]=='OTH') and (grp_slice['DPD90P3M_flag'][i]==1):
            count_OTH = count_OTH + 1
        elif (grp_slice['accountType'][i]=='PL') and (grp_slice['DPD90P3M_flag'][i]==1):
            count_PL = count_PL + 1
        elif (grp_slice['accountType'][i]=='PLBL') and (grp_slice['DPD90P3M_flag'][i]==1):
            count_PLBL = count_PLBL + 1
        elif (grp_slice['accountType'][i]=='RL') and (grp_slice['DPD90P3M_flag'][i]==1):
            count_RL = count_RL + 1
        elif (grp_slice['accountType'][i]=='SCC') and (grp_slice['DPD90P3M_flag'][i]==1):
            count_SCC = count_SCC + 1
        elif (grp_slice['accountType'][i]=='SEL') and (grp_slice['DPD90P3M_flag'][i]==1):
            count_SEL = count_SEL + 1
            
    count_list_AL.append(count_AL)
    count_list_BL.append(count_BL)
    count_list_CC.append(count_CC)
    count_list_CD.append(count_CD)
    count_list_CV.append(count_CV)
    count_list_GL.append(count_GL)
    count_list_HL.append(count_HL)
    count_list_LAS.append(count_LAS)
    count_list_MFBL.append(count_MFBL)
    count_list_MFHL.append(count_MFHL)
    count_list_MFOT.append(count_MFOT)
    count_list_OTH.append(count_OTH)
    count_list_PL.append(count_PL)
    count_list_PLBL.append(count_PLBL)
    count_list_RL.append(count_RL)
    count_list_SCC.append(count_SCC)
    count_list_SEL.append(count_SEL)
    
    count_AL = 0
    count_BL = 0
    count_CC = 0
    count_CD = 0
    count_CV = 0
    count_GL = 0
    count_HL = 0
    count_LAS = 0
    count_MFBL = 0
    count_MFHL = 0
    count_MFOT = 0
    count_OTH = 0
    count_PL = 0
    count_PLBL = 0
    count_RL = 0
    count_SCC = 0
    count_SEL = 0
    
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['accountType'][i]=='unknown'):
            DPD90P3M_AL.append('unknown')
            DPD90P3M_BL.append('unknown')
            DPD90P3M_CC.append('unknown')
            DPD90P3M_CD.append('unknown')
            DPD90P3M_CV.append('unknown')
            DPD90P3M_GL.append('unknown')
            DPD90P3M_HL.append('unknown')
            DPD90P3M_LAS.append('unknown')
            DPD90P3M_MFBL.append('unknown')
            DPD90P3M_MFHL.append('unknown')
            DPD90P3M_MFOT.append('unknown')
            DPD90P3M_OTH.append('unknown')
            DPD90P3M_PL.append('unknown')
            DPD90P3M_PLBL.append('unknown')
            DPD90P3M_RL.append('unknown')
            DPD90P3M_SCC.append('unknown')
            DPD90P3M_SEL.append('unknown')
        else:
            DPD90P3M_AL.append(count_list_AL[x])
            DPD90P3M_BL.append(count_list_BL[x])
            DPD90P3M_CC.append(count_list_CC[x])
            DPD90P3M_CD.append(count_list_CD[x])
            DPD90P3M_CV.append(count_list_CV[x])
            DPD90P3M_GL.append(count_list_GL[x])
            DPD90P3M_HL.append(count_list_HL[x])
            DPD90P3M_LAS.append(count_list_LAS[x])
            DPD90P3M_MFBL.append(count_list_MFBL[x])
            DPD90P3M_MFHL.append(count_list_MFHL[x])
            DPD90P3M_MFOT.append(count_list_MFOT[x])
            DPD90P3M_OTH.append(count_list_OTH[x])
            DPD90P3M_PL.append(count_list_PL[x])
            DPD90P3M_PLBL.append(count_list_PLBL[x])
            DPD90P3M_RL.append(count_list_RL[x])
            DPD90P3M_SCC.append(count_list_SCC[x])
            DPD90P3M_SEL.append(count_list_SEL[x])
            
df['DPD90P3M_AL'] = pd.Series(DPD90P3M_AL).values
df['DPD90P3M_BL'] = pd.Series(DPD90P3M_BL).values
df['DPD90P3M_CC'] = pd.Series(DPD90P3M_CC).values
df['DPD90P3M_CD'] = pd.Series(DPD90P3M_CD).values
df['DPD90P3M_CV'] = pd.Series(DPD90P3M_CV).values
df['DPD90P3M_GL'] = pd.Series(DPD90P3M_GL).values
df['DPD90P3M_HL'] = pd.Series(DPD90P3M_HL).values
df['DPD90P3M_LAS'] = pd.Series(DPD90P3M_LAS).values
df['DPD90P3M_MFBL'] = pd.Series(DPD90P3M_MFBL).values
df['DPD90P3M_MFHL'] = pd.Series(DPD90P3M_MFHL).values
df['DPD90P3M_MFOT'] = pd.Series(DPD90P3M_MFOT).values
df['DPD90P3M_OTH'] = pd.Series(DPD90P3M_OTH).values
df['DPD90P3M_PL'] = pd.Series(DPD90P3M_PL).values
df['DPD90P3M_PLBL'] = pd.Series(DPD90P3M_PLBL).values
df['DPD90P3M_RL'] = pd.Series(DPD90P3M_RL).values
df['DPD90P3M_SCC'] = pd.Series(DPD90P3M_SCC).values
df['DPD90P3M_SEL'] = pd.Series(DPD90P3M_SEL).values

# %% [raw]
# d = df[['ID','DPD90P3M_GL','DPD90P3M_flag','accountType']]
# d[d['DPD90P3M_flag']!=0].head(60)

# %% [markdown]
# <a id='DPD_flags_6m'></a>
# ### Code for DPD flags for last 6 months

# %%
dpd30_6m = list()
dpd60_6m = list()
dpd90_6m = list()
matching = list()

for x in range(0, df.shape[0]):
    if (df['mo_diff_ld_drc'][x] == -1):
        #print(df['mo_diff_ld_drc'][x])
        dpd30_6m.append('unknown')
        dpd60_6m.append('unknown')
        dpd90_6m.append('unknown')
    elif (df['mo_diff_ld_drc'][x] >= 0) and (df['mo_diff_ld_drc'][x] <= 6):
        #print(df['mo_diff_ld_drc'][x])
        if (6-df['mo_diff_ld_drc'][x] <= len(df['intPayHistComp'][x])):
            for i in range(0, 6-df['mo_diff_ld_drc'][x]):
                a = df['intPayHistComp'][x][i]
                matching.append(a)
        else:
            for i in range(0,len(df['intPayHistComp'][x])):
                a = df['intPayHistComp'][x][i]
                matching.append(a)
    
        #print(matching)
        if (sum(matching) > 0) and (sum(matching) <= 30):
            dpd30_6m.append(1)
            dpd60_6m.append(0)
            dpd90_6m.append(0)
            #print('3',matching)
        elif (sum(matching) > 30) and (sum(matching) <= 60):
            dpd30_6m.append(0)
            dpd60_6m.append(1)
            dpd90_6m.append(0)
            #print('2',matching)
        elif (sum(matching) > 60) and (sum(matching) <= 90):
            dpd30_6m.append(0)
            dpd60_6m.append(0)
            dpd90_6m.append(1)
            #print('1',matching)
        else:
            dpd30_6m.append(0)
            dpd60_6m.append(0)
            dpd90_6m.append(0)
    else:
        dpd30_6m.append(0)
        dpd60_6m.append(0)
        dpd90_6m.append(0)
            
            
        matching = list()
        
df['DPD30P6M_flag'] = pd.Series(dpd30_6m).values
df['DPD60P6M_flag'] = pd.Series(dpd60_6m).values
df['DPD90P6M_flag'] = pd.Series(dpd90_6m).values

#df['DPD30P6M_flag'].value_counts()
#print(len(dpd30_6m))

# %% [raw]
# piece = list()
# sum_dpd_6m = 0
#
# dpd30_6m = list()
# dpd60_6m = list()
# dpd90_6m = list()
#
# for value in df['paymentHist1']:
#     #print(value)
#     chunks, chunk_size = len(value), 3
#     for i in range(0, chunks, chunk_size):
#         piece.append(value[i:i+chunk_size])
#     #print(piece)
#     if len(piece)>=6:
#         #print(piece)
#         for x in range(0,6):
#             #print(x)
#             if hasNumbers(piece[x]):
#                 piece[x] = int(piece[x])
#                 sum_dpd_6m = piece[x] + sum_dpd_6m
#             else:
#                 continue
#         #print(piece)
#         #print(sum_dpd_6m)
#         if (sum_dpd_6m <= 30) and (sum_dpd_6m > 0):
#             #print(piece)
#             dpd30_6m.append(1)
#             dpd60_6m.append(0)
#             dpd90_6m.append(0)
#             sum_dpd_6m = 0
#         elif (sum_dpd_6m <= 60) and (sum_dpd_6m > 30):
#             #print(piece)
#             dpd30_6m.append(0)
#             dpd60_6m.append(1)
#             dpd90_6m.append(0)
#             sum_dpd_6m = 0
#         elif (sum_dpd_6m <= 90) and (sum_dpd_6m > 60):
#             #print(piece)
#             dpd30_6m.append(0)
#             dpd60_6m.append(0)
#             dpd90_6m.append(1)
#             sum_dpd_6m = 0
#         else:
#             dpd30_6m.append(0)
#             dpd60_6m.append(0)
#             dpd90_6m.append(0)
#     else:
#         dpd30_6m.append(0)
#         dpd60_6m.append(0)
#         dpd90_6m.append(0)
#
#
#
#         sum_dpd_6m = 0
#     piece = list()
#
# df['DPD30P6M_flag'] = pd.Series(dpd30_6m).values
# df['DPD60P6M_flag'] = pd.Series(dpd60_6m).values
# df['DPD90P6M_flag'] = pd.Series(dpd90_6m).values

# %% [markdown]
# <a id='DPD6M_num'></a>
# ### Code for DPD6M (numerical)

# %% [markdown]
# - For an applicant, Count of all loans where DPD30P6M_flag =1
# - For an applicant, Count of all loans where DPD60P6M_flag =1
# - For an applicant, Count of all loans where DPD90P6M_flag =1

# %%
DPD30P6M = list()
count_list_30_6m = list()
count_30_6m = 0

DPD60P6M = list()
count_list_60_6m = list()
count_60_6m = 0

DPD90P6M = list()
count_list_90_6m = list()
count_90_6m = 0

grp_df = df.groupby('ID')

for x in range(0, len(unq_id_list)):
    grp_slice = grp_df.get_group(unq_id_list[x])
    #print(grp_slice)
    grp_slice.reset_index(drop=True, inplace=True)
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['DPD30P6M_flag'][i]==1) or (grp_slice['DPD30P6M_flag'][i]==0):
            count_30_6m = count_30_6m + grp_slice['DPD30P6M_flag'][i]
        
        if (grp_slice['DPD60P6M_flag'][i]==1) or (grp_slice['DPD60P6M_flag'][i]==0):
            count_60_6m = count_60_6m + grp_slice['DPD60P6M_flag'][i]

        if (grp_slice['DPD90P6M_flag'][i]==1) or (grp_slice['DPD90P6M_flag'][i]==0):
            count_90_6m = count_90_6m + grp_slice['DPD90P6M_flag'][i]

    count_list_30_6m.append(count_30_6m)
    count_30_6m = 0
    count_list_60_6m.append(count_60_6m)
    count_60_6m = 0
    count_list_90_6m.append(count_90_6m)
    count_90_6m = 0

    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['DPD30P6M_flag'][i]==1) or (grp_slice['DPD30P6M_flag'][i]==0):
            DPD30P6M.append(count_list_30_6m[x])
        else:
            DPD30P6M.append('unknown')

        if (grp_slice['DPD60P6M_flag'][i]==1) or (grp_slice['DPD60P6M_flag'][i]==0):
            DPD60P6M.append(count_list_60_6m[x])
        else:
            DPD60P6M.append('unknown')

        if (grp_slice['DPD90P6M_flag'][i]==1) or (grp_slice['DPD90P6M_flag'][i]==0):
            DPD90P6M.append(count_list_90_6m[x])
        else:
            DPD90P6M.append('unknown')
            
df['DPD30P6M'] = pd.Series(DPD30P6M).values
df['DPD60P6M'] = pd.Series(DPD60P6M).values
df['DPD90P6M'] = pd.Series(DPD90P6M).values
#df['DPD60P6M'].value_counts()

# %% [markdown]
# ### Code for DPD30P6M_P

# %% [markdown]
# - DPD 30 in last 6 month productwise
# - For an applicant, Count of all loans where DPD30P6M_flag =1 per product

# %%
import time
start_time = time.time()    #You can use time.clock() also



DPD30P6M_AL = list()
DPD30P6M_BL = list()
DPD30P6M_CC = list()
DPD30P6M_CD = list()
DPD30P6M_CV = list()
DPD30P6M_GL = list()
DPD30P6M_HL = list()
DPD30P6M_LAS = list()
DPD30P6M_MFBL = list()
DPD30P6M_MFHL = list()
DPD30P6M_MFOT = list()
DPD30P6M_OTH = list()
DPD30P6M_PL = list()
DPD30P6M_PLBL = list()
DPD30P6M_RL = list()
DPD30P6M_SCC = list()
DPD30P6M_SEL = list()

count_list_AL = list()
count_list_BL = list()
count_list_CC = list()
count_list_CD = list()
count_list_CV = list()
count_list_GL = list()
count_list_HL = list()
count_list_LAS = list()
count_list_MFBL = list()
count_list_MFHL = list()
count_list_MFOT = list()
count_list_OTH = list()
count_list_PL = list()
count_list_PLBL = list()
count_list_RL = list()
count_list_SCC = list()
count_list_SEL = list()

count_AL = 0
count_BL = 0
count_CC = 0
count_CD = 0
count_CV = 0
count_GL = 0
count_HL = 0
count_LAS = 0
count_MFBL = 0
count_MFHL = 0
count_MFOT = 0
count_OTH = 0
count_PL = 0 
count_PLBL = 0
count_RL = 0
count_SCC = 0
count_SEL = 0

grp_df = df.groupby('ID')

for x in range(0, len(unq_id_list)):
    grp_slice = grp_df.get_group(unq_id_list[x])
    #print(grp_slice)
    grp_slice.reset_index(drop=True, inplace=True)
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['accountType'][i]=='unknown'):
            continue
        elif (grp_slice['accountType'][i]=='AL') and (grp_slice['DPD30P6M_flag'][i]==1):
            count_AL = count_AL + 1
        elif (grp_slice['accountType'][i]=='BL') and (grp_slice['DPD30P6M_flag'][i]==1):
            count_BL = count_BL + 1
        elif (grp_slice['accountType'][i]=='CC') and (grp_slice['DPD30P6M_flag'][i]==1):
            count_CC = count_CC + 1
        elif (grp_slice['accountType'][i]=='CD') and (grp_slice['DPD30P6M_flag'][i]==1):
            count_CD = count_CD + 1
        elif (grp_slice['accountType'][i]=='CV') and (grp_slice['DPD30P6M_flag'][i]==1):
            count_CV = count_CV + 1
        elif (grp_slice['accountType'][i]=='GL') and (grp_slice['DPD30P6M_flag'][i]==1):
            count_GL = count_GL + 1
        elif (grp_slice['accountType'][i]=='HL') and (grp_slice['DPD30P6M_flag'][i]==1):
            count_HL = count_HL + 1
        elif (grp_slice['accountType'][i]=='LAS') and (grp_slice['DPD30P6M_flag'][i]==1):
            count_LAS = count_LAS + 1
        elif (grp_slice['accountType'][i]=='MFBL') and (grp_slice['DPD30P6M_flag'][i]==1):
            count_MFBL = count_MFBL + 1
        elif (grp_slice['accountType'][i]=='MFHL') and (grp_slice['DPD30P6M_flag'][i]==1):
            count_MFHL = count_MFHL + 1
        elif (grp_slice['accountType'][i]=='MFOT') and (grp_slice['DPD30P6M_flag'][i]==1):
            count_MFOT = count_MFOT + 1
        elif (grp_slice['accountType'][i]=='OTH') and (grp_slice['DPD30P6M_flag'][i]==1):
            count_OTH = count_OTH + 1
        elif (grp_slice['accountType'][i]=='PL') and (grp_slice['DPD30P6M_flag'][i]==1):
            count_PL = count_PL + 1
        elif (grp_slice['accountType'][i]=='PLBL') and (grp_slice['DPD30P6M_flag'][i]==1):
            count_PLBL = count_PLBL + 1
        elif (grp_slice['accountType'][i]=='RL') and (grp_slice['DPD30P6M_flag'][i]==1):
            count_RL = count_RL + 1
        elif (grp_slice['accountType'][i]=='SCC') and (grp_slice['DPD30P6M_flag'][i]==1):
            count_SCC = count_SCC + 1
        elif (grp_slice['accountType'][i]=='SEL') and (grp_slice['DPD30P6M_flag'][i]==1):
            count_SEL = count_SEL + 1
            
    count_list_AL.append(count_AL)
    count_list_BL.append(count_BL)
    count_list_CC.append(count_CC)
    count_list_CD.append(count_CD)
    count_list_CV.append(count_CV)
    count_list_GL.append(count_GL)
    count_list_HL.append(count_HL)
    count_list_LAS.append(count_LAS)
    count_list_MFBL.append(count_MFBL)
    count_list_MFHL.append(count_MFHL)
    count_list_MFOT.append(count_MFOT)
    count_list_OTH.append(count_OTH)
    count_list_PL.append(count_PL)
    count_list_PLBL.append(count_PLBL)
    count_list_RL.append(count_RL)
    count_list_SCC.append(count_SCC)
    count_list_SEL.append(count_SEL)
    
    count_AL = 0
    count_BL = 0
    count_CC = 0
    count_CD = 0
    count_CV = 0
    count_GL = 0
    count_HL = 0
    count_LAS = 0
    count_MFBL = 0
    count_MFHL = 0
    count_MFOT = 0
    count_OTH = 0
    count_PL = 0
    count_PLBL = 0
    count_RL = 0
    count_SCC = 0
    count_SEL = 0
    
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['accountType'][i]=='unknown'):
            DPD30P6M_AL.append('unknown')
            DPD30P6M_BL.append('unknown')
            DPD30P6M_CC.append('unknown')
            DPD30P6M_CD.append('unknown')
            DPD30P6M_CV.append('unknown')
            DPD30P6M_GL.append('unknown')
            DPD30P6M_HL.append('unknown')
            DPD30P6M_LAS.append('unknown')
            DPD30P6M_MFBL.append('unknown')
            DPD30P6M_MFHL.append('unknown')
            DPD30P6M_MFOT.append('unknown')
            DPD30P6M_OTH.append('unknown')
            DPD30P6M_PL.append('unknown')
            DPD30P6M_PLBL.append('unknown')
            DPD30P6M_RL.append('unknown')
            DPD30P6M_SCC.append('unknown')
            DPD30P6M_SEL.append('unknown')
        else:
            DPD30P6M_AL.append(count_list_AL[x])
            DPD30P6M_BL.append(count_list_BL[x])
            DPD30P6M_CC.append(count_list_CC[x])
            DPD30P6M_CD.append(count_list_CD[x])
            DPD30P6M_CV.append(count_list_CV[x])
            DPD30P6M_GL.append(count_list_GL[x])
            DPD30P6M_HL.append(count_list_HL[x])
            DPD30P6M_LAS.append(count_list_LAS[x])
            DPD30P6M_MFBL.append(count_list_MFBL[x])
            DPD30P6M_MFHL.append(count_list_MFHL[x])
            DPD30P6M_MFOT.append(count_list_MFOT[x])
            DPD30P6M_OTH.append(count_list_OTH[x])
            DPD30P6M_PL.append(count_list_PL[x])
            DPD30P6M_PLBL.append(count_list_PLBL[x])
            DPD30P6M_RL.append(count_list_RL[x])
            DPD30P6M_SCC.append(count_list_SCC[x])
            DPD30P6M_SEL.append(count_list_SEL[x])
            
df['DPD30P6M_AL'] = pd.Series(DPD30P6M_AL).values
df['DPD30P6M_BL'] = pd.Series(DPD30P6M_BL).values
df['DPD30P6M_CC'] = pd.Series(DPD30P6M_CC).values
df['DPD30P6M_CD'] = pd.Series(DPD30P6M_CD).values
df['DPD30P6M_CV'] = pd.Series(DPD30P6M_CV).values
df['DPD30P6M_GL'] = pd.Series(DPD30P6M_GL).values
df['DPD30P6M_HL'] = pd.Series(DPD30P6M_HL).values
df['DPD30P6M_LAS'] = pd.Series(DPD30P6M_LAS).values
df['DPD30P6M_MFBL'] = pd.Series(DPD30P6M_MFBL).values
df['DPD30P6M_MFHL'] = pd.Series(DPD30P6M_MFHL).values
df['DPD30P6M_MFOT'] = pd.Series(DPD30P6M_MFOT).values
df['DPD30P6M_OTH'] = pd.Series(DPD30P6M_OTH).values
df['DPD30P6M_PL'] = pd.Series(DPD30P6M_PL).values
df['DPD30P6M_PLBL'] = pd.Series(DPD30P6M_PLBL).values
df['DPD30P6M_RL'] = pd.Series(DPD30P6M_RL).values
df['DPD30P6M_SCC'] = pd.Series(DPD30P6M_SCC).values
df['DPD30P6M_SEL'] = pd.Series(DPD30P6M_SEL).values

print("%s seconds" % (time.time() - start_time))

# %% [raw]
# d = df[['ID','DPD30P6M_GL','DPD30P6M_flag','accountType']]
# d[d['DPD30P6M_flag']!=0].head(60)

# %% [markdown]
# ### Code for DPD60P6M_P

# %% [markdown]
# - DPD 60 in last 6 month productwise
# - For an applicant, Count of all loans where DPD60P6M_flag =1 per product

# %%
DPD60P6M_AL = list()
DPD60P6M_BL = list()
DPD60P6M_CC = list()
DPD60P6M_CD = list()
DPD60P6M_CV = list()
DPD60P6M_GL = list()
DPD60P6M_HL = list()
DPD60P6M_LAS = list()
DPD60P6M_MFBL = list()
DPD60P6M_MFHL = list()
DPD60P6M_MFOT = list()
DPD60P6M_OTH = list()
DPD60P6M_PL = list()
DPD60P6M_PLBL = list()
DPD60P6M_RL = list()
DPD60P6M_SCC = list()
DPD60P6M_SEL = list()

count_list_AL = list()
count_list_BL = list()
count_list_CC = list()
count_list_CD = list()
count_list_CV = list()
count_list_GL = list()
count_list_HL = list()
count_list_LAS = list()
count_list_MFBL = list()
count_list_MFHL = list()
count_list_MFOT = list()
count_list_OTH = list()
count_list_PL = list()
count_list_PLBL = list()
count_list_RL = list()
count_list_SCC = list()
count_list_SEL = list()

count_AL = 0
count_BL = 0
count_CC = 0
count_CD = 0
count_CV = 0
count_GL = 0
count_HL = 0
count_LAS = 0
count_MFBL = 0
count_MFHL = 0
count_MFOT = 0
count_OTH = 0
count_PL = 0 
count_PLBL = 0
count_RL = 0
count_SCC = 0
count_SEL = 0

grp_df = df.groupby('ID')

for x in range(0, len(unq_id_list)):
    grp_slice = grp_df.get_group(unq_id_list[x])
    #print(grp_slice)
    grp_slice.reset_index(drop=True, inplace=True)
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['accountType'][i]=='unknown'):
            continue
        elif (grp_slice['accountType'][i]=='AL') and (grp_slice['DPD60P6M_flag'][i]==1):
            count_AL = count_AL + 1
        elif (grp_slice['accountType'][i]=='BL') and (grp_slice['DPD60P6M_flag'][i]==1):
            count_BL = count_BL + 1
        elif (grp_slice['accountType'][i]=='CC') and (grp_slice['DPD60P6M_flag'][i]==1):
            count_CC = count_CC + 1
        elif (grp_slice['accountType'][i]=='CD') and (grp_slice['DPD60P6M_flag'][i]==1):
            count_CD = count_CD + 1
        elif (grp_slice['accountType'][i]=='CV') and (grp_slice['DPD60P6M_flag'][i]==1):
            count_CV = count_CV + 1
        elif (grp_slice['accountType'][i]=='GL') and (grp_slice['DPD60P6M_flag'][i]==1):
            count_GL = count_GL + 1
        elif (grp_slice['accountType'][i]=='HL') and (grp_slice['DPD60P6M_flag'][i]==1):
            count_HL = count_HL + 1
        elif (grp_slice['accountType'][i]=='LAS') and (grp_slice['DPD60P6M_flag'][i]==1):
            count_LAS = count_LAS + 1
        elif (grp_slice['accountType'][i]=='MFBL') and (grp_slice['DPD60P6M_flag'][i]==1):
            count_MFBL = count_MFBL + 1
        elif (grp_slice['accountType'][i]=='MFHL') and (grp_slice['DPD60P6M_flag'][i]==1):
            count_MFHL = count_MFHL + 1
        elif (grp_slice['accountType'][i]=='MFOT') and (grp_slice['DPD60P6M_flag'][i]==1):
            count_MFOT = count_MFOT + 1
        elif (grp_slice['accountType'][i]=='OTH') and (grp_slice['DPD60P6M_flag'][i]==1):
            count_OTH = count_OTH + 1
        elif (grp_slice['accountType'][i]=='PL') and (grp_slice['DPD60P6M_flag'][i]==1):
            count_PL = count_PL + 1
        elif (grp_slice['accountType'][i]=='PLBL') and (grp_slice['DPD60P6M_flag'][i]==1):
            count_PLBL = count_PLBL + 1
        elif (grp_slice['accountType'][i]=='RL') and (grp_slice['DPD60P6M_flag'][i]==1):
            count_RL = count_RL + 1
        elif (grp_slice['accountType'][i]=='SCC') and (grp_slice['DPD60P6M_flag'][i]==1):
            count_SCC = count_SCC + 1
        elif (grp_slice['accountType'][i]=='SEL') and (grp_slice['DPD60P6M_flag'][i]==1):
            count_SEL = count_SEL + 1
            
    count_list_AL.append(count_AL)
    count_list_BL.append(count_BL)
    count_list_CC.append(count_CC)
    count_list_CD.append(count_CD)
    count_list_CV.append(count_CV)
    count_list_GL.append(count_GL)
    count_list_HL.append(count_HL)
    count_list_LAS.append(count_LAS)
    count_list_MFBL.append(count_MFBL)
    count_list_MFHL.append(count_MFHL)
    count_list_MFOT.append(count_MFOT)
    count_list_OTH.append(count_OTH)
    count_list_PL.append(count_PL)
    count_list_PLBL.append(count_PLBL)
    count_list_RL.append(count_RL)
    count_list_SCC.append(count_SCC)
    count_list_SEL.append(count_SEL)
    
    count_AL = 0
    count_BL = 0
    count_CC = 0
    count_CD = 0
    count_CV = 0
    count_GL = 0
    count_HL = 0
    count_LAS = 0
    count_MFBL = 0
    count_MFHL = 0
    count_MFOT = 0
    count_OTH = 0
    count_PL = 0
    count_PLBL = 0
    count_RL = 0
    count_SCC = 0
    count_SEL = 0
    
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['accountType'][i]=='unknown'):
            DPD60P6M_AL.append('unknown')
            DPD60P6M_BL.append('unknown')
            DPD60P6M_CC.append('unknown')
            DPD60P6M_CD.append('unknown')
            DPD60P6M_CV.append('unknown')
            DPD60P6M_GL.append('unknown')
            DPD60P6M_HL.append('unknown')
            DPD60P6M_LAS.append('unknown')
            DPD60P6M_MFBL.append('unknown')
            DPD60P6M_MFHL.append('unknown')
            DPD60P6M_MFOT.append('unknown')
            DPD60P6M_OTH.append('unknown')
            DPD60P6M_PL.append('unknown')
            DPD60P6M_PLBL.append('unknown')
            DPD60P6M_RL.append('unknown')
            DPD60P6M_SCC.append('unknown')
            DPD60P6M_SEL.append('unknown')
        else:
            DPD60P6M_AL.append(count_list_AL[x])
            DPD60P6M_BL.append(count_list_BL[x])
            DPD60P6M_CC.append(count_list_CC[x])
            DPD60P6M_CD.append(count_list_CD[x])
            DPD60P6M_CV.append(count_list_CV[x])
            DPD60P6M_GL.append(count_list_GL[x])
            DPD60P6M_HL.append(count_list_HL[x])
            DPD60P6M_LAS.append(count_list_LAS[x])
            DPD60P6M_MFBL.append(count_list_MFBL[x])
            DPD60P6M_MFHL.append(count_list_MFHL[x])
            DPD60P6M_MFOT.append(count_list_MFOT[x])
            DPD60P6M_OTH.append(count_list_OTH[x])
            DPD60P6M_PL.append(count_list_PL[x])
            DPD60P6M_PLBL.append(count_list_PLBL[x])
            DPD60P6M_RL.append(count_list_RL[x])
            DPD60P6M_SCC.append(count_list_SCC[x])
            DPD60P6M_SEL.append(count_list_SEL[x])
            
df['DPD60P6M_AL'] = pd.Series(DPD60P6M_AL).values
df['DPD60P6M_BL'] = pd.Series(DPD60P6M_BL).values
df['DPD60P6M_CC'] = pd.Series(DPD60P6M_CC).values
df['DPD60P6M_CD'] = pd.Series(DPD60P6M_CD).values
df['DPD60P6M_CV'] = pd.Series(DPD60P6M_CV).values
df['DPD60P6M_GL'] = pd.Series(DPD60P6M_GL).values
df['DPD60P6M_HL'] = pd.Series(DPD60P6M_HL).values
df['DPD60P6M_LAS'] = pd.Series(DPD60P6M_LAS).values
df['DPD60P6M_MFBL'] = pd.Series(DPD60P6M_MFBL).values
df['DPD60P6M_MFHL'] = pd.Series(DPD60P6M_MFHL).values
df['DPD60P6M_MFOT'] = pd.Series(DPD60P6M_MFOT).values
df['DPD60P6M_OTH'] = pd.Series(DPD60P6M_OTH).values
df['DPD60P6M_PL'] = pd.Series(DPD60P6M_PL).values
df['DPD60P6M_PLBL'] = pd.Series(DPD60P6M_PLBL).values
df['DPD60P6M_RL'] = pd.Series(DPD60P6M_RL).values
df['DPD60P6M_SCC'] = pd.Series(DPD60P6M_SCC).values
df['DPD60P6M_SEL'] = pd.Series(DPD60P6M_SEL).values

# %% [raw]
# d = df[['ID','DPD60P6M_GL','DPD60P6M_flag','accountType']]
# d[d['DPD60P6M_flag']!=0].head(60)

# %% [markdown]
# ### Code for DPD90P6M_P

# %% [markdown]
# - DPD 90 in last 6 month productwise
# - For an applicant, Count of all loans where DPD90P6M_flag =1 per product

# %%
DPD90P6M_AL = list()
DPD90P6M_BL = list()
DPD90P6M_CC = list()
DPD90P6M_CD = list()
DPD90P6M_CV = list()
DPD90P6M_GL = list()
DPD90P6M_HL = list()
DPD90P6M_LAS = list()
DPD90P6M_MFBL = list()
DPD90P6M_MFHL = list()
DPD90P6M_MFOT = list()
DPD90P6M_OTH = list()
DPD90P6M_PL = list()
DPD90P6M_PLBL = list()
DPD90P6M_RL = list()
DPD90P6M_SCC = list()
DPD90P6M_SEL = list()

count_list_AL = list()
count_list_BL = list()
count_list_CC = list()
count_list_CD = list()
count_list_CV = list()
count_list_GL = list()
count_list_HL = list()
count_list_LAS = list()
count_list_MFBL = list()
count_list_MFHL = list()
count_list_MFOT = list()
count_list_OTH = list()
count_list_PL = list()
count_list_PLBL = list()
count_list_RL = list()
count_list_SCC = list()
count_list_SEL = list()

count_AL = 0
count_BL = 0
count_CC = 0
count_CD = 0
count_CV = 0
count_GL = 0
count_HL = 0
count_LAS = 0
count_MFBL = 0
count_MFHL = 0
count_MFOT = 0
count_OTH = 0
count_PL = 0 
count_PLBL = 0
count_RL = 0
count_SCC = 0
count_SEL = 0

grp_df = df.groupby('ID')

for x in range(0, len(unq_id_list)):
    grp_slice = grp_df.get_group(unq_id_list[x])
    #print(grp_slice)
    grp_slice.reset_index(drop=True, inplace=True)
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['accountType'][i]=='unknown'):
            continue
        elif (grp_slice['accountType'][i]=='AL') and (grp_slice['DPD90P6M_flag'][i]==1):
            count_AL = count_AL + 1
        elif (grp_slice['accountType'][i]=='BL') and (grp_slice['DPD90P6M_flag'][i]==1):
            count_BL = count_BL + 1
        elif (grp_slice['accountType'][i]=='CC') and (grp_slice['DPD90P6M_flag'][i]==1):
            count_CC = count_CC + 1
        elif (grp_slice['accountType'][i]=='CD') and (grp_slice['DPD90P6M_flag'][i]==1):
            count_CD = count_CD + 1
        elif (grp_slice['accountType'][i]=='CV') and (grp_slice['DPD90P6M_flag'][i]==1):
            count_CV = count_CV + 1
        elif (grp_slice['accountType'][i]=='GL') and (grp_slice['DPD90P6M_flag'][i]==1):
            count_GL = count_GL + 1
        elif (grp_slice['accountType'][i]=='HL') and (grp_slice['DPD90P6M_flag'][i]==1):
            count_HL = count_HL + 1
        elif (grp_slice['accountType'][i]=='LAS') and (grp_slice['DPD90P6M_flag'][i]==1):
            count_LAS = count_LAS + 1
        elif (grp_slice['accountType'][i]=='MFBL') and (grp_slice['DPD90P6M_flag'][i]==1):
            count_MFBL = count_MFBL + 1
        elif (grp_slice['accountType'][i]=='MFHL') and (grp_slice['DPD90P6M_flag'][i]==1):
            count_MFHL = count_MFHL + 1
        elif (grp_slice['accountType'][i]=='MFOT') and (grp_slice['DPD90P6M_flag'][i]==1):
            count_MFOT = count_MFOT + 1
        elif (grp_slice['accountType'][i]=='OTH') and (grp_slice['DPD90P6M_flag'][i]==1):
            count_OTH = count_OTH + 1
        elif (grp_slice['accountType'][i]=='PL') and (grp_slice['DPD90P6M_flag'][i]==1):
            count_PL = count_PL + 1
        elif (grp_slice['accountType'][i]=='PLBL') and (grp_slice['DPD90P6M_flag'][i]==1):
            count_PLBL = count_PLBL + 1
        elif (grp_slice['accountType'][i]=='RL') and (grp_slice['DPD90P6M_flag'][i]==1):
            count_RL = count_RL + 1
        elif (grp_slice['accountType'][i]=='SCC') and (grp_slice['DPD90P6M_flag'][i]==1):
            count_SCC = count_SCC + 1
        elif (grp_slice['accountType'][i]=='SEL') and (grp_slice['DPD90P6M_flag'][i]==1):
            count_SEL = count_SEL + 1
            
    count_list_AL.append(count_AL)
    count_list_BL.append(count_BL)
    count_list_CC.append(count_CC)
    count_list_CD.append(count_CD)
    count_list_CV.append(count_CV)
    count_list_GL.append(count_GL)
    count_list_HL.append(count_HL)
    count_list_LAS.append(count_LAS)
    count_list_MFBL.append(count_MFBL)
    count_list_MFHL.append(count_MFHL)
    count_list_MFOT.append(count_MFOT)
    count_list_OTH.append(count_OTH)
    count_list_PL.append(count_PL)
    count_list_PLBL.append(count_PLBL)
    count_list_RL.append(count_RL)
    count_list_SCC.append(count_SCC)
    count_list_SEL.append(count_SEL)
    
    count_AL = 0
    count_BL = 0
    count_CC = 0
    count_CD = 0
    count_CV = 0
    count_GL = 0
    count_HL = 0
    count_LAS = 0
    count_MFBL = 0
    count_MFHL = 0
    count_MFOT = 0
    count_OTH = 0
    count_PL = 0
    count_PLBL = 0
    count_RL = 0
    count_SCC = 0
    count_SEL = 0
    
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['accountType'][i]=='unknown'):
            DPD90P6M_AL.append('unknown')
            DPD90P6M_BL.append('unknown')
            DPD90P6M_CC.append('unknown')
            DPD90P6M_CD.append('unknown')
            DPD90P6M_CV.append('unknown')
            DPD90P6M_GL.append('unknown')
            DPD90P6M_HL.append('unknown')
            DPD90P6M_LAS.append('unknown')
            DPD90P6M_MFBL.append('unknown')
            DPD90P6M_MFHL.append('unknown')
            DPD90P6M_MFOT.append('unknown')
            DPD90P6M_OTH.append('unknown')
            DPD90P6M_PL.append('unknown')
            DPD90P6M_PLBL.append('unknown')
            DPD90P6M_RL.append('unknown')
            DPD90P6M_SCC.append('unknown')
            DPD90P6M_SEL.append('unknown')
        else:
            DPD90P6M_AL.append(count_list_AL[x])
            DPD90P6M_BL.append(count_list_BL[x])
            DPD90P6M_CC.append(count_list_CC[x])
            DPD90P6M_CD.append(count_list_CD[x])
            DPD90P6M_CV.append(count_list_CV[x])
            DPD90P6M_GL.append(count_list_GL[x])
            DPD90P6M_HL.append(count_list_HL[x])
            DPD90P6M_LAS.append(count_list_LAS[x])
            DPD90P6M_MFBL.append(count_list_MFBL[x])
            DPD90P6M_MFHL.append(count_list_MFHL[x])
            DPD90P6M_MFOT.append(count_list_MFOT[x])
            DPD90P6M_OTH.append(count_list_OTH[x])
            DPD90P6M_PL.append(count_list_PL[x])
            DPD90P6M_PLBL.append(count_list_PLBL[x])
            DPD90P6M_RL.append(count_list_RL[x])
            DPD90P6M_SCC.append(count_list_SCC[x])
            DPD90P6M_SEL.append(count_list_SEL[x])
            
df['DPD90P6M_AL'] = pd.Series(DPD90P6M_AL).values
df['DPD90P6M_BL'] = pd.Series(DPD90P6M_BL).values
df['DPD90P6M_CC'] = pd.Series(DPD90P6M_CC).values
df['DPD90P6M_CD'] = pd.Series(DPD90P6M_CD).values
df['DPD90P6M_CV'] = pd.Series(DPD90P6M_CV).values
df['DPD90P6M_GL'] = pd.Series(DPD90P6M_GL).values
df['DPD90P6M_HL'] = pd.Series(DPD90P6M_HL).values
df['DPD90P6M_LAS'] = pd.Series(DPD90P6M_LAS).values
df['DPD90P6M_MFBL'] = pd.Series(DPD90P6M_MFBL).values
df['DPD90P6M_MFHL'] = pd.Series(DPD90P6M_MFHL).values
df['DPD90P6M_MFOT'] = pd.Series(DPD90P6M_MFOT).values
df['DPD90P6M_OTH'] = pd.Series(DPD90P6M_OTH).values
df['DPD90P6M_PL'] = pd.Series(DPD90P6M_PL).values
df['DPD90P6M_PLBL'] = pd.Series(DPD90P6M_PLBL).values
df['DPD90P6M_RL'] = pd.Series(DPD90P6M_RL).values
df['DPD90P6M_SCC'] = pd.Series(DPD90P6M_SCC).values
df['DPD90P6M_SEL'] = pd.Series(DPD90P6M_SEL).values

# %% [raw]
# d = df[['ID','DPD90P6M_GL','DPD90P6M_flag','accountType']]
# d[d['DPD90P6M_flag']!=0].head(60)

# %% [markdown]
# <a id='DPD_flags_1y'></a>
# ### Code for DPD flags for last 1 year

# %%
dpd30_1y = list()
dpd60_1y = list()
dpd90_1y = list()
matching = list()

for x in range(0, df.shape[0]):
    if (df['mo_diff_ld_drc'][x] == -1):
        # print(df['mo_diff_ld_drc'][x])
        dpd30_1y.append('unknown')
        dpd60_1y.append('unknown')
        dpd90_1y.append('unknown')
    elif (df['mo_diff_ld_drc'][x] >= 0) and (df['mo_diff_ld_drc'][x] <= 12):
        # print(df['mo_diff_ld_drc'][x])
        if (12-df['mo_diff_ld_drc'][x] <= len(df['intPayHistComp'][x])):
            for i in range(0, 12-df['mo_diff_ld_drc'][x]):
                a = df['intPayHistComp'][x][i]
                matching.append(a)
        else:
            for i in range(0, len(df['intPayHistComp'][x])):
                a = df['intPayHistComp'][x][i]
                matching.append(a)

        # print(matching)
        if (sum(matching) > 0) and (sum(matching) <= 30):
            dpd30_1y.append(1)
            dpd60_1y.append(0)
            dpd90_1y.append(0)
            # print('3',matching)
        elif (sum(matching) > 30) and (sum(matching) <= 60):
            dpd30_1y.append(0)
            dpd60_1y.append(1)
            dpd90_1y.append(0)
            # print('2',matching)
        elif (sum(matching) > 60) and (sum(matching) <= 90):
            dpd30_1y.append(0)
            dpd60_1y.append(0)
            dpd90_1y.append(1)
            # print('1',matching)
        else:
            dpd30_1y.append(0)
            dpd60_1y.append(0)
            dpd90_1y.append(0)
    else:
        dpd30_1y.append(0)
        dpd60_1y.append(0)
        dpd90_1y.append(0)

        matching = list()

df['DPD30P1Y_flag'] = pd.Series(dpd30_1y).values
df['DPD60P1Y_flag'] = pd.Series(dpd60_1y).values
df['DPD90P1Y_flag'] = pd.Series(dpd90_1y).values

# df['DPD30P1Y_flag'].value_counts()
# print(len(dpd30_1y))

# %% [raw]
# piece = list()
# sum_dpd_1y = 0
#
# dpd30_1y = list()
# dpd60_1y = list()
# dpd90_1y = list()
#
# for value in df['paymentHist1']:
#     #print(value)
#     chunks, chunk_size = len(value), 3
#     for i in range(0, chunks, chunk_size):
#         piece.append(value[i:i+chunk_size])
#     #print(piece)
#     if len(piece)>=12:
#         #print(piece)
#         for x in range(0,12):
#             #print(x)
#             if hasNumbers(piece[x]):
#                 piece[x] = int(piece[x])
#                 sum_dpd_1y = piece[x] + sum_dpd_1y
#             else:
#                 continue
#         #print(piece)
#         #print(sum_dpd_1y)
#         if (sum_dpd_1y <= 30) and (sum_dpd_1y > 0):
#             #print(piece)
#             dpd30_1y.append(1)
#             dpd60_1y.append(0)
#             dpd90_1y.append(0)
#             sum_dpd_1y = 0
#         elif (sum_dpd_1y <= 60) and (sum_dpd_1y > 30):
#             #print(piece)
#             dpd30_1y.append(0)
#             dpd60_1y.append(1)
#             dpd90_1y.append(0)
#             sum_dpd_1y = 0
#         elif (sum_dpd_1y <= 90) and (sum_dpd_1y > 60):
#             #print(piece)
#             dpd30_1y.append(0)
#             dpd60_1y.append(0)
#             dpd90_1y.append(1)
#             sum_dpd_1y = 0
#         else:
#             dpd30_1y.append(0)
#             dpd60_1y.append(0)
#             dpd90_1y.append(0)
#     else:
#         dpd30_1y.append(0)
#         dpd60_1y.append(0)
#         dpd90_1y.append(0)
#
#
#
#         sum_dpd_1y = 0
#     piece = list()
#
# df['DPD30P1Y_flag'] = pd.Series(dpd30_1y).values
# df['DPD60P1Y_flag'] = pd.Series(dpd60_1y).values
# df['DPD90P1Y_flag'] = pd.Series(dpd90_1y).values

# %% [markdown]
# <a id='DPD1Y_num'></a>
# ### Code for DPD1Y (numerical)

# %% [markdown]
# - For an applicant, Count of all loans where DPD30P1Y_flag =1
# - For an applicant, Count of all loans where DPD60P1Y_flag =1
# - For an applicant, Count of all loans where DPD90P1Y_flag =1

# %%
DPD30P1Y = list()
count_list_30_1y = list()
count_30_1y = 0

DPD60P1Y = list()
count_list_60_1y = list()
count_60_1y = 0

DPD90P1Y = list()
count_list_90_1y = list()
count_90_1y = 0

grp_df = df.groupby('ID')

for x in range(0, len(unq_id_list)):
    grp_slice = grp_df.get_group(unq_id_list[x])
    #print(grp_slice)
    grp_slice.reset_index(drop=True, inplace=True)
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['DPD30P1Y_flag'][i]==1) or (grp_slice['DPD30P1Y_flag'][i]==0):
            count_30_1y = count_30_1y + grp_slice['DPD30P1Y_flag'][i]
        
        if (grp_slice['DPD60P1Y_flag'][i]==1) or (grp_slice['DPD60P1Y_flag'][i]==0):
            count_60_1y = count_60_1y + grp_slice['DPD60P1Y_flag'][i]

        if (grp_slice['DPD90P1Y_flag'][i]==1) or (grp_slice['DPD90P1Y_flag'][i]==0):
            count_90_1y = count_90_1y + grp_slice['DPD90P1Y_flag'][i]

    count_list_30_1y.append(count_30_1y)
    count_30_1y = 0
    count_list_60_1y.append(count_60_1y)
    count_60_1y = 0
    count_list_90_1y.append(count_90_1y)
    count_90_1y = 0

    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['DPD30P1Y_flag'][i]==1) or (grp_slice['DPD30P1Y_flag'][i]==0):
            DPD30P1Y.append(count_list_30_1y[x])
        else:
            DPD30P1Y.append('unknown')

        if (grp_slice['DPD60P1Y_flag'][i]==1) or (grp_slice['DPD60P1Y_flag'][i]==0):
            DPD60P1Y.append(count_list_60_1y[x])
        else:
            DPD60P1Y.append('unknown')

        if (grp_slice['DPD90P1Y_flag'][i]==1) or (grp_slice['DPD90P1Y_flag'][i]==0):
            DPD90P1Y.append(count_list_90_1y[x])
        else:
            DPD90P1Y.append('unknown')
            
df['DPD30P1Y'] = pd.Series(DPD30P1Y).values
df['DPD60P1Y'] = pd.Series(DPD60P1Y).values
df['DPD90P1Y'] = pd.Series(DPD90P1Y).values
#df['DPD60P1Y'].value_counts()

# %% [markdown]
# ### Code for DPD30P1Y_P

# %% [markdown]
# - DPD 30 in last 1 year productwise
# - For an applicant, Count of all loans where DPD30P1Y_flag =1 per product

# %%
DPD30P1Y_AL = list()
DPD30P1Y_BL = list()
DPD30P1Y_CC = list()
DPD30P1Y_CD = list()
DPD30P1Y_CV = list()
DPD30P1Y_GL = list()
DPD30P1Y_HL = list()
DPD30P1Y_LAS = list()
DPD30P1Y_MFBL = list()
DPD30P1Y_MFHL = list()
DPD30P1Y_MFOT = list()
DPD30P1Y_OTH = list()
DPD30P1Y_PL = list()
DPD30P1Y_PLBL = list()
DPD30P1Y_RL = list()
DPD30P1Y_SCC = list()
DPD30P1Y_SEL = list()

count_list_AL = list()
count_list_BL = list()
count_list_CC = list()
count_list_CD = list()
count_list_CV = list()
count_list_GL = list()
count_list_HL = list()
count_list_LAS = list()
count_list_MFBL = list()
count_list_MFHL = list()
count_list_MFOT = list()
count_list_OTH = list()
count_list_PL = list()
count_list_PLBL = list()
count_list_RL = list()
count_list_SCC = list()
count_list_SEL = list()

count_AL = 0
count_BL = 0
count_CC = 0
count_CD = 0
count_CV = 0
count_GL = 0
count_HL = 0
count_LAS = 0
count_MFBL = 0
count_MFHL = 0
count_MFOT = 0
count_OTH = 0
count_PL = 0 
count_PLBL = 0
count_RL = 0
count_SCC = 0
count_SEL = 0

grp_df = df.groupby('ID')

for x in range(0, len(unq_id_list)):
    grp_slice = grp_df.get_group(unq_id_list[x])
    #print(grp_slice)
    grp_slice.reset_index(drop=True, inplace=True)
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['accountType'][i]=='unknown'):
            continue
        elif (grp_slice['accountType'][i]=='AL') and (grp_slice['DPD30P1Y_flag'][i]==1):
            count_AL = count_AL + 1
        elif (grp_slice['accountType'][i]=='BL') and (grp_slice['DPD30P1Y_flag'][i]==1):
            count_BL = count_BL + 1
        elif (grp_slice['accountType'][i]=='CC') and (grp_slice['DPD30P1Y_flag'][i]==1):
            count_CC = count_CC + 1
        elif (grp_slice['accountType'][i]=='CD') and (grp_slice['DPD30P1Y_flag'][i]==1):
            count_CD = count_CD + 1
        elif (grp_slice['accountType'][i]=='CV') and (grp_slice['DPD30P1Y_flag'][i]==1):
            count_CV = count_CV + 1
        elif (grp_slice['accountType'][i]=='GL') and (grp_slice['DPD30P1Y_flag'][i]==1):
            count_GL = count_GL + 1
        elif (grp_slice['accountType'][i]=='HL') and (grp_slice['DPD30P1Y_flag'][i]==1):
            count_HL = count_HL + 1
        elif (grp_slice['accountType'][i]=='LAS') and (grp_slice['DPD30P1Y_flag'][i]==1):
            count_LAS = count_LAS + 1
        elif (grp_slice['accountType'][i]=='MFBL') and (grp_slice['DPD30P1Y_flag'][i]==1):
            count_MFBL = count_MFBL + 1
        elif (grp_slice['accountType'][i]=='MFHL') and (grp_slice['DPD30P1Y_flag'][i]==1):
            count_MFHL = count_MFHL + 1
        elif (grp_slice['accountType'][i]=='MFOT') and (grp_slice['DPD30P1Y_flag'][i]==1):
            count_MFOT = count_MFOT + 1
        elif (grp_slice['accountType'][i]=='OTH') and (grp_slice['DPD30P1Y_flag'][i]==1):
            count_OTH = count_OTH + 1
        elif (grp_slice['accountType'][i]=='PL') and (grp_slice['DPD30P1Y_flag'][i]==1):
            count_PL = count_PL + 1
        elif (grp_slice['accountType'][i]=='PLBL') and (grp_slice['DPD30P1Y_flag'][i]==1):
            count_PLBL = count_PLBL + 1
        elif (grp_slice['accountType'][i]=='RL') and (grp_slice['DPD30P1Y_flag'][i]==1):
            count_RL = count_RL + 1
        elif (grp_slice['accountType'][i]=='SCC') and (grp_slice['DPD30P1Y_flag'][i]==1):
            count_SCC = count_SCC + 1
        elif (grp_slice['accountType'][i]=='SEL') and (grp_slice['DPD30P1Y_flag'][i]==1):
            count_SEL = count_SEL + 1
            
    count_list_AL.append(count_AL)
    count_list_BL.append(count_BL)
    count_list_CC.append(count_CC)
    count_list_CD.append(count_CD)
    count_list_CV.append(count_CV)
    count_list_GL.append(count_GL)
    count_list_HL.append(count_HL)
    count_list_LAS.append(count_LAS)
    count_list_MFBL.append(count_MFBL)
    count_list_MFHL.append(count_MFHL)
    count_list_MFOT.append(count_MFOT)
    count_list_OTH.append(count_OTH)
    count_list_PL.append(count_PL)
    count_list_PLBL.append(count_PLBL)
    count_list_RL.append(count_RL)
    count_list_SCC.append(count_SCC)
    count_list_SEL.append(count_SEL)
    
    count_AL = 0
    count_BL = 0
    count_CC = 0
    count_CD = 0
    count_CV = 0
    count_GL = 0
    count_HL = 0
    count_LAS = 0
    count_MFBL = 0
    count_MFHL = 0
    count_MFOT = 0
    count_OTH = 0
    count_PL = 0
    count_PLBL = 0
    count_RL = 0
    count_SCC = 0
    count_SEL = 0
    
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['accountType'][i]=='unknown'):
            DPD30P1Y_AL.append('unknown')
            DPD30P1Y_BL.append('unknown')
            DPD30P1Y_CC.append('unknown')
            DPD30P1Y_CD.append('unknown')
            DPD30P1Y_CV.append('unknown')
            DPD30P1Y_GL.append('unknown')
            DPD30P1Y_HL.append('unknown')
            DPD30P1Y_LAS.append('unknown')
            DPD30P1Y_MFBL.append('unknown')
            DPD30P1Y_MFHL.append('unknown')
            DPD30P1Y_MFOT.append('unknown')
            DPD30P1Y_OTH.append('unknown')
            DPD30P1Y_PL.append('unknown')
            DPD30P1Y_PLBL.append('unknown')
            DPD30P1Y_RL.append('unknown')
            DPD30P1Y_SCC.append('unknown')
            DPD30P1Y_SEL.append('unknown')
        else:
            DPD30P1Y_AL.append(count_list_AL[x])
            DPD30P1Y_BL.append(count_list_BL[x])
            DPD30P1Y_CC.append(count_list_CC[x])
            DPD30P1Y_CD.append(count_list_CD[x])
            DPD30P1Y_CV.append(count_list_CV[x])
            DPD30P1Y_GL.append(count_list_GL[x])
            DPD30P1Y_HL.append(count_list_HL[x])
            DPD30P1Y_LAS.append(count_list_LAS[x])
            DPD30P1Y_MFBL.append(count_list_MFBL[x])
            DPD30P1Y_MFHL.append(count_list_MFHL[x])
            DPD30P1Y_MFOT.append(count_list_MFOT[x])
            DPD30P1Y_OTH.append(count_list_OTH[x])
            DPD30P1Y_PL.append(count_list_PL[x])
            DPD30P1Y_PLBL.append(count_list_PLBL[x])
            DPD30P1Y_RL.append(count_list_RL[x])
            DPD30P1Y_SCC.append(count_list_SCC[x])
            DPD30P1Y_SEL.append(count_list_SEL[x])
            
df['DPD30P1Y_AL'] = pd.Series(DPD30P1Y_AL).values
df['DPD30P1Y_BL'] = pd.Series(DPD30P1Y_BL).values
df['DPD30P1Y_CC'] = pd.Series(DPD30P1Y_CC).values
df['DPD30P1Y_CD'] = pd.Series(DPD30P1Y_CD).values
df['DPD30P1Y_CV'] = pd.Series(DPD30P1Y_CV).values
df['DPD30P1Y_GL'] = pd.Series(DPD30P1Y_GL).values
df['DPD30P1Y_HL'] = pd.Series(DPD30P1Y_HL).values
df['DPD30P1Y_LAS'] = pd.Series(DPD30P1Y_LAS).values
df['DPD30P1Y_MFBL'] = pd.Series(DPD30P1Y_MFBL).values
df['DPD30P1Y_MFHL'] = pd.Series(DPD30P1Y_MFHL).values
df['DPD30P1Y_MFOT'] = pd.Series(DPD30P1Y_MFOT).values
df['DPD30P1Y_OTH'] = pd.Series(DPD30P1Y_OTH).values
df['DPD30P1Y_PL'] = pd.Series(DPD30P1Y_PL).values
df['DPD30P1Y_PLBL'] = pd.Series(DPD30P1Y_PLBL).values
df['DPD30P1Y_RL'] = pd.Series(DPD30P1Y_RL).values
df['DPD30P1Y_SCC'] = pd.Series(DPD30P1Y_SCC).values
df['DPD30P1Y_SEL'] = pd.Series(DPD30P1Y_SEL).values

# %% [raw]
# d = df[['ID','DPD30P1Y_GL','DPD30P1Y_flag','accountType']]
# d[d['DPD30P1Y_flag']!=0].head(60)

# %% [markdown]
# ### Code for DPD60P1Y_P

# %% [markdown]
# - DPD 60 in last 1 year productwise
# - For an applicant, Count of all loans where DPD60P1Y_flag =1 per product

# %%
DPD60P1Y_AL = list()
DPD60P1Y_BL = list()
DPD60P1Y_CC = list()
DPD60P1Y_CD = list()
DPD60P1Y_CV = list()
DPD60P1Y_GL = list()
DPD60P1Y_HL = list()
DPD60P1Y_LAS = list()
DPD60P1Y_MFBL = list()
DPD60P1Y_MFHL = list()
DPD60P1Y_MFOT = list()
DPD60P1Y_OTH = list()
DPD60P1Y_PL = list()
DPD60P1Y_PLBL = list()
DPD60P1Y_RL = list()
DPD60P1Y_SCC = list()
DPD60P1Y_SEL = list()

count_list_AL = list()
count_list_BL = list()
count_list_CC = list()
count_list_CD = list()
count_list_CV = list()
count_list_GL = list()
count_list_HL = list()
count_list_LAS = list()
count_list_MFBL = list()
count_list_MFHL = list()
count_list_MFOT = list()
count_list_OTH = list()
count_list_PL = list()
count_list_PLBL = list()
count_list_RL = list()
count_list_SCC = list()
count_list_SEL = list()

count_AL = 0
count_BL = 0
count_CC = 0
count_CD = 0
count_CV = 0
count_GL = 0
count_HL = 0
count_LAS = 0
count_MFBL = 0
count_MFHL = 0
count_MFOT = 0
count_OTH = 0
count_PL = 0 
count_PLBL = 0
count_RL = 0
count_SCC = 0
count_SEL = 0

grp_df = df.groupby('ID')

for x in range(0, len(unq_id_list)):
    grp_slice = grp_df.get_group(unq_id_list[x])
    #print(grp_slice)
    grp_slice.reset_index(drop=True, inplace=True)
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['accountType'][i]=='unknown'):
            continue
        elif (grp_slice['accountType'][i]=='AL') and (grp_slice['DPD60P1Y_flag'][i]==1):
            count_AL = count_AL + 1
        elif (grp_slice['accountType'][i]=='BL') and (grp_slice['DPD60P1Y_flag'][i]==1):
            count_BL = count_BL + 1
        elif (grp_slice['accountType'][i]=='CC') and (grp_slice['DPD60P1Y_flag'][i]==1):
            count_CC = count_CC + 1
        elif (grp_slice['accountType'][i]=='CD') and (grp_slice['DPD60P1Y_flag'][i]==1):
            count_CD = count_CD + 1
        elif (grp_slice['accountType'][i]=='CV') and (grp_slice['DPD60P1Y_flag'][i]==1):
            count_CV = count_CV + 1
        elif (grp_slice['accountType'][i]=='GL') and (grp_slice['DPD60P1Y_flag'][i]==1):
            count_GL = count_GL + 1
        elif (grp_slice['accountType'][i]=='HL') and (grp_slice['DPD60P1Y_flag'][i]==1):
            count_HL = count_HL + 1
        elif (grp_slice['accountType'][i]=='LAS') and (grp_slice['DPD60P1Y_flag'][i]==1):
            count_LAS = count_LAS + 1
        elif (grp_slice['accountType'][i]=='MFBL') and (grp_slice['DPD60P1Y_flag'][i]==1):
            count_MFBL = count_MFBL + 1
        elif (grp_slice['accountType'][i]=='MFHL') and (grp_slice['DPD60P1Y_flag'][i]==1):
            count_MFHL = count_MFHL + 1
        elif (grp_slice['accountType'][i]=='MFOT') and (grp_slice['DPD60P1Y_flag'][i]==1):
            count_MFOT = count_MFOT + 1
        elif (grp_slice['accountType'][i]=='OTH') and (grp_slice['DPD60P1Y_flag'][i]==1):
            count_OTH = count_OTH + 1
        elif (grp_slice['accountType'][i]=='PL') and (grp_slice['DPD60P1Y_flag'][i]==1):
            count_PL = count_PL + 1
        elif (grp_slice['accountType'][i]=='PLBL') and (grp_slice['DPD60P1Y_flag'][i]==1):
            count_PLBL = count_PLBL + 1
        elif (grp_slice['accountType'][i]=='RL') and (grp_slice['DPD60P1Y_flag'][i]==1):
            count_RL = count_RL + 1
        elif (grp_slice['accountType'][i]=='SCC') and (grp_slice['DPD60P1Y_flag'][i]==1):
            count_SCC = count_SCC + 1
        elif (grp_slice['accountType'][i]=='SEL') and (grp_slice['DPD60P1Y_flag'][i]==1):
            count_SEL = count_SEL + 1
            
    count_list_AL.append(count_AL)
    count_list_BL.append(count_BL)
    count_list_CC.append(count_CC)
    count_list_CD.append(count_CD)
    count_list_CV.append(count_CV)
    count_list_GL.append(count_GL)
    count_list_HL.append(count_HL)
    count_list_LAS.append(count_LAS)
    count_list_MFBL.append(count_MFBL)
    count_list_MFHL.append(count_MFHL)
    count_list_MFOT.append(count_MFOT)
    count_list_OTH.append(count_OTH)
    count_list_PL.append(count_PL)
    count_list_PLBL.append(count_PLBL)
    count_list_RL.append(count_RL)
    count_list_SCC.append(count_SCC)
    count_list_SEL.append(count_SEL)
    
    count_AL = 0
    count_BL = 0
    count_CC = 0
    count_CD = 0
    count_CV = 0
    count_GL = 0
    count_HL = 0
    count_LAS = 0
    count_MFBL = 0
    count_MFHL = 0
    count_MFOT = 0
    count_OTH = 0
    count_PL = 0
    count_PLBL = 0
    count_RL = 0
    count_SCC = 0
    count_SEL = 0
    
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['accountType'][i]=='unknown'):
            DPD60P1Y_AL.append('unknown')
            DPD60P1Y_BL.append('unknown')
            DPD60P1Y_CC.append('unknown')
            DPD60P1Y_CD.append('unknown')
            DPD60P1Y_CV.append('unknown')
            DPD60P1Y_GL.append('unknown')
            DPD60P1Y_HL.append('unknown')
            DPD60P1Y_LAS.append('unknown')
            DPD60P1Y_MFBL.append('unknown')
            DPD60P1Y_MFHL.append('unknown')
            DPD60P1Y_MFOT.append('unknown')
            DPD60P1Y_OTH.append('unknown')
            DPD60P1Y_PL.append('unknown')
            DPD60P1Y_PLBL.append('unknown')
            DPD60P1Y_RL.append('unknown')
            DPD60P1Y_SCC.append('unknown')
            DPD60P1Y_SEL.append('unknown')
        else:
            DPD60P1Y_AL.append(count_list_AL[x])
            DPD60P1Y_BL.append(count_list_BL[x])
            DPD60P1Y_CC.append(count_list_CC[x])
            DPD60P1Y_CD.append(count_list_CD[x])
            DPD60P1Y_CV.append(count_list_CV[x])
            DPD60P1Y_GL.append(count_list_GL[x])
            DPD60P1Y_HL.append(count_list_HL[x])
            DPD60P1Y_LAS.append(count_list_LAS[x])
            DPD60P1Y_MFBL.append(count_list_MFBL[x])
            DPD60P1Y_MFHL.append(count_list_MFHL[x])
            DPD60P1Y_MFOT.append(count_list_MFOT[x])
            DPD60P1Y_OTH.append(count_list_OTH[x])
            DPD60P1Y_PL.append(count_list_PL[x])
            DPD60P1Y_PLBL.append(count_list_PLBL[x])
            DPD60P1Y_RL.append(count_list_RL[x])
            DPD60P1Y_SCC.append(count_list_SCC[x])
            DPD60P1Y_SEL.append(count_list_SEL[x])
            
df['DPD60P1Y_AL'] = pd.Series(DPD60P1Y_AL).values
df['DPD60P1Y_BL'] = pd.Series(DPD60P1Y_BL).values
df['DPD60P1Y_CC'] = pd.Series(DPD60P1Y_CC).values
df['DPD60P1Y_CD'] = pd.Series(DPD60P1Y_CD).values
df['DPD60P1Y_CV'] = pd.Series(DPD60P1Y_CV).values
df['DPD60P1Y_GL'] = pd.Series(DPD60P1Y_GL).values
df['DPD60P1Y_HL'] = pd.Series(DPD60P1Y_HL).values
df['DPD60P1Y_LAS'] = pd.Series(DPD60P1Y_LAS).values
df['DPD60P1Y_MFBL'] = pd.Series(DPD60P1Y_MFBL).values
df['DPD60P1Y_MFHL'] = pd.Series(DPD60P1Y_MFHL).values
df['DPD60P1Y_MFOT'] = pd.Series(DPD60P1Y_MFOT).values
df['DPD60P1Y_OTH'] = pd.Series(DPD60P1Y_OTH).values
df['DPD60P1Y_PL'] = pd.Series(DPD60P1Y_PL).values
df['DPD60P1Y_PLBL'] = pd.Series(DPD60P1Y_PLBL).values
df['DPD60P1Y_RL'] = pd.Series(DPD60P1Y_RL).values
df['DPD60P1Y_SCC'] = pd.Series(DPD60P1Y_SCC).values
df['DPD60P1Y_SEL'] = pd.Series(DPD60P1Y_SEL).values

# %% [raw]
# d = df[['ID','DPD60P1Y_GL','DPD60P1Y_flag','accountType']]
# d[d['DPD60P1Y_flag']!=0].head(60)

# %% [markdown]
# ### Code for DPD90P1Y_P

# %% [markdown]
# - DPD 90 in last 1 year productwise
# - For an applicant, Count of all loans where DPD90P1Y_flag =1 per product

# %%
DPD90P1Y_AL = list()
DPD90P1Y_BL = list()
DPD90P1Y_CC = list()
DPD90P1Y_CD = list()
DPD90P1Y_CV = list()
DPD90P1Y_GL = list()
DPD90P1Y_HL = list()
DPD90P1Y_LAS = list()
DPD90P1Y_MFBL = list()
DPD90P1Y_MFHL = list()
DPD90P1Y_MFOT = list()
DPD90P1Y_OTH = list()
DPD90P1Y_PL = list()
DPD90P1Y_PLBL = list()
DPD90P1Y_RL = list()
DPD90P1Y_SCC = list()
DPD90P1Y_SEL = list()

count_list_AL = list()
count_list_BL = list()
count_list_CC = list()
count_list_CD = list()
count_list_CV = list()
count_list_GL = list()
count_list_HL = list()
count_list_LAS = list()
count_list_MFBL = list()
count_list_MFHL = list()
count_list_MFOT = list()
count_list_OTH = list()
count_list_PL = list()
count_list_PLBL = list()
count_list_RL = list()
count_list_SCC = list()
count_list_SEL = list()

count_AL = 0
count_BL = 0
count_CC = 0
count_CD = 0
count_CV = 0
count_GL = 0
count_HL = 0
count_LAS = 0
count_MFBL = 0
count_MFHL = 0
count_MFOT = 0
count_OTH = 0
count_PL = 0 
count_PLBL = 0
count_RL = 0
count_SCC = 0
count_SEL = 0

grp_df = df.groupby('ID')

for x in range(0, len(unq_id_list)):
    grp_slice = grp_df.get_group(unq_id_list[x])
    #print(grp_slice)
    grp_slice.reset_index(drop=True, inplace=True)
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['accountType'][i]=='unknown'):
            continue
        elif (grp_slice['accountType'][i]=='AL') and (grp_slice['DPD90P1Y_flag'][i]==1):
            count_AL = count_AL + 1
        elif (grp_slice['accountType'][i]=='BL') and (grp_slice['DPD90P1Y_flag'][i]==1):
            count_BL = count_BL + 1
        elif (grp_slice['accountType'][i]=='CC') and (grp_slice['DPD90P1Y_flag'][i]==1):
            count_CC = count_CC + 1
        elif (grp_slice['accountType'][i]=='CD') and (grp_slice['DPD90P1Y_flag'][i]==1):
            count_CD = count_CD + 1
        elif (grp_slice['accountType'][i]=='CV') and (grp_slice['DPD90P1Y_flag'][i]==1):
            count_CV = count_CV + 1
        elif (grp_slice['accountType'][i]=='GL') and (grp_slice['DPD90P1Y_flag'][i]==1):
            count_GL = count_GL + 1
        elif (grp_slice['accountType'][i]=='HL') and (grp_slice['DPD90P1Y_flag'][i]==1):
            count_HL = count_HL + 1
        elif (grp_slice['accountType'][i]=='LAS') and (grp_slice['DPD90P1Y_flag'][i]==1):
            count_LAS = count_LAS + 1
        elif (grp_slice['accountType'][i]=='MFBL') and (grp_slice['DPD90P1Y_flag'][i]==1):
            count_MFBL = count_MFBL + 1
        elif (grp_slice['accountType'][i]=='MFHL') and (grp_slice['DPD90P1Y_flag'][i]==1):
            count_MFHL = count_MFHL + 1
        elif (grp_slice['accountType'][i]=='MFOT') and (grp_slice['DPD90P1Y_flag'][i]==1):
            count_MFOT = count_MFOT + 1
        elif (grp_slice['accountType'][i]=='OTH') and (grp_slice['DPD90P1Y_flag'][i]==1):
            count_OTH = count_OTH + 1
        elif (grp_slice['accountType'][i]=='PL') and (grp_slice['DPD90P1Y_flag'][i]==1):
            count_PL = count_PL + 1
        elif (grp_slice['accountType'][i]=='PLBL') and (grp_slice['DPD90P1Y_flag'][i]==1):
            count_PLBL = count_PLBL + 1
        elif (grp_slice['accountType'][i]=='RL') and (grp_slice['DPD90P1Y_flag'][i]==1):
            count_RL = count_RL + 1
        elif (grp_slice['accountType'][i]=='SCC') and (grp_slice['DPD90P1Y_flag'][i]==1):
            count_SCC = count_SCC + 1
        elif (grp_slice['accountType'][i]=='SEL') and (grp_slice['DPD90P1Y_flag'][i]==1):
            count_SEL = count_SEL + 1
            
    count_list_AL.append(count_AL)
    count_list_BL.append(count_BL)
    count_list_CC.append(count_CC)
    count_list_CD.append(count_CD)
    count_list_CV.append(count_CV)
    count_list_GL.append(count_GL)
    count_list_HL.append(count_HL)
    count_list_LAS.append(count_LAS)
    count_list_MFBL.append(count_MFBL)
    count_list_MFHL.append(count_MFHL)
    count_list_MFOT.append(count_MFOT)
    count_list_OTH.append(count_OTH)
    count_list_PL.append(count_PL)
    count_list_PLBL.append(count_PLBL)
    count_list_RL.append(count_RL)
    count_list_SCC.append(count_SCC)
    count_list_SEL.append(count_SEL)
    
    count_AL = 0
    count_BL = 0
    count_CC = 0
    count_CD = 0
    count_CV = 0
    count_GL = 0
    count_HL = 0
    count_LAS = 0
    count_MFBL = 0
    count_MFHL = 0
    count_MFOT = 0
    count_OTH = 0
    count_PL = 0
    count_PLBL = 0
    count_RL = 0
    count_SCC = 0
    count_SEL = 0
    
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['accountType'][i]=='unknown'):
            DPD90P1Y_AL.append('unknown')
            DPD90P1Y_BL.append('unknown')
            DPD90P1Y_CC.append('unknown')
            DPD90P1Y_CD.append('unknown')
            DPD90P1Y_CV.append('unknown')
            DPD90P1Y_GL.append('unknown')
            DPD90P1Y_HL.append('unknown')
            DPD90P1Y_LAS.append('unknown')
            DPD90P1Y_MFBL.append('unknown')
            DPD90P1Y_MFHL.append('unknown')
            DPD90P1Y_MFOT.append('unknown')
            DPD90P1Y_OTH.append('unknown')
            DPD90P1Y_PL.append('unknown')
            DPD90P1Y_PLBL.append('unknown')
            DPD90P1Y_RL.append('unknown')
            DPD90P1Y_SCC.append('unknown')
            DPD90P1Y_SEL.append('unknown')
        else:
            DPD90P1Y_AL.append(count_list_AL[x])
            DPD90P1Y_BL.append(count_list_BL[x])
            DPD90P1Y_CC.append(count_list_CC[x])
            DPD90P1Y_CD.append(count_list_CD[x])
            DPD90P1Y_CV.append(count_list_CV[x])
            DPD90P1Y_GL.append(count_list_GL[x])
            DPD90P1Y_HL.append(count_list_HL[x])
            DPD90P1Y_LAS.append(count_list_LAS[x])
            DPD90P1Y_MFBL.append(count_list_MFBL[x])
            DPD90P1Y_MFHL.append(count_list_MFHL[x])
            DPD90P1Y_MFOT.append(count_list_MFOT[x])
            DPD90P1Y_OTH.append(count_list_OTH[x])
            DPD90P1Y_PL.append(count_list_PL[x])
            DPD90P1Y_PLBL.append(count_list_PLBL[x])
            DPD90P1Y_RL.append(count_list_RL[x])
            DPD90P1Y_SCC.append(count_list_SCC[x])
            DPD90P1Y_SEL.append(count_list_SEL[x])
            
df['DPD90P1Y_AL'] = pd.Series(DPD90P1Y_AL).values
df['DPD90P1Y_BL'] = pd.Series(DPD90P1Y_BL).values
df['DPD90P1Y_CC'] = pd.Series(DPD90P1Y_CC).values
df['DPD90P1Y_CD'] = pd.Series(DPD90P1Y_CD).values
df['DPD90P1Y_CV'] = pd.Series(DPD90P1Y_CV).values
df['DPD90P1Y_GL'] = pd.Series(DPD90P1Y_GL).values
df['DPD90P1Y_HL'] = pd.Series(DPD90P1Y_HL).values
df['DPD90P1Y_LAS'] = pd.Series(DPD90P1Y_LAS).values
df['DPD90P1Y_MFBL'] = pd.Series(DPD90P1Y_MFBL).values
df['DPD90P1Y_MFHL'] = pd.Series(DPD90P1Y_MFHL).values
df['DPD90P1Y_MFOT'] = pd.Series(DPD90P1Y_MFOT).values
df['DPD90P1Y_OTH'] = pd.Series(DPD90P1Y_OTH).values
df['DPD90P1Y_PL'] = pd.Series(DPD90P1Y_PL).values
df['DPD90P1Y_PLBL'] = pd.Series(DPD90P1Y_PLBL).values
df['DPD90P1Y_RL'] = pd.Series(DPD90P1Y_RL).values
df['DPD90P1Y_SCC'] = pd.Series(DPD90P1Y_SCC).values
df['DPD90P1Y_SEL'] = pd.Series(DPD90P1Y_SEL).values

# %% [raw]
# d = df[['ID','DPD90P1Y_GL','DPD90P1Y_flag','accountType']]
# d[d['DPD90P1Y_flag']!=0].head(60)

# %% [markdown]
# <a id='DPD_flags_2y'></a>
# ### Code for DPD flags for last 2 year

# %%
dpd30_2y = list()
dpd60_2y = list()
dpd90_2y = list()
matching = list()

for x in range(0, df.shape[0]):
    if (df['mo_diff_ld_drc'][x] == -1):
        # print(df['mo_diff_ld_drc'][x])
        dpd30_2y.append('unknown')
        dpd60_2y.append('unknown')
        dpd90_2y.append('unknown')
    elif (df['mo_diff_ld_drc'][x] >= 0) and (df['mo_diff_ld_drc'][x] <= 24):
        # print(df['mo_diff_ld_drc'][x])
        if (24-df['mo_diff_ld_drc'][x] <= len(df['intPayHistComp'][x])):
            for i in range(0, 24-df['mo_diff_ld_drc'][x]):
                a = df['intPayHistComp'][x][i]
                matching.append(a)
        else:
            for i in range(0, len(df['intPayHistComp'][x])):
                a = df['intPayHistComp'][x][i]
                matching.append(a)

        # print(matching)
        if (sum(matching) > 0) and (sum(matching) <= 30):
            dpd30_2y.append(1)
            dpd60_2y.append(0)
            dpd90_2y.append(0)
            # print('3',matching)
        elif (sum(matching) > 30) and (sum(matching) <= 60):
            dpd30_2y.append(0)
            dpd60_2y.append(1)
            dpd90_2y.append(0)
            # print('2',matching)
        elif (sum(matching) > 60) and (sum(matching) <= 90):
            dpd30_2y.append(0)
            dpd60_2y.append(0)
            dpd90_2y.append(1)
            # print('1',matching)
        else:
            dpd30_2y.append(0)
            dpd60_2y.append(0)
            dpd90_2y.append(0)
    else:
        dpd30_2y.append(0)
        dpd60_2y.append(0)
        dpd90_2y.append(0)

        matching = list()

df['DPD30P2Y_flag'] = pd.Series(dpd30_2y).values
df['DPD60P2Y_flag'] = pd.Series(dpd60_2y).values
df['DPD90P2Y_flag'] = pd.Series(dpd90_2y).values

# df['DPD30P2Y_flag'].value_counts()
# print(len(dpd30_2y))

# %% [raw]
# piece = list()
# sum_dpd_2y = 0
#
# dpd30_2y = list()
# dpd60_2y = list()
# dpd90_2y = list()
#
# for value in df['paymentHistComp']:
#     #print(value)
#     chunks, chunk_size = len(value), 3
#     for i in range(0, chunks, chunk_size):
#         piece.append(value[i:i+chunk_size])
#     #print(piece)
#     if len(piece)>=24:
#         #print(piece)
#         for x in range(0,24):
#             #print(x)
#             if hasNumbers(piece[x]):
#                 piece[x] = int(piece[x])
#                 sum_dpd_2y = piece[x] + sum_dpd_2y
#             else:
#                 continue
#         #print(piece)
#         #print(sum_dpd_2y)
#         if (sum_dpd_2y <= 30) and (sum_dpd_2y > 0):
#             #print(piece)
#             dpd30_2y.append(1)
#             dpd60_2y.append(0)
#             dpd90_2y.append(0)
#             sum_dpd_2y = 0
#         elif (sum_dpd_2y <= 60) and (sum_dpd_2y > 30):
#             #print(piece)
#             dpd30_2y.append(0)
#             dpd60_2y.append(1)
#             dpd90_2y.append(0)
#             sum_dpd_2y = 0
#         elif (sum_dpd_2y <= 90) and (sum_dpd_2y > 60):
#             #print(piece)
#             dpd30_2y.append(0)
#             dpd60_2y.append(0)
#             dpd90_2y.append(1)
#             sum_dpd_2y = 0
#         else:
#             dpd30_2y.append(0)
#             dpd60_2y.append(0)
#             dpd90_2y.append(0)
#     else:
#         dpd30_2y.append(0)
#         dpd60_2y.append(0)
#         dpd90_2y.append(0)
#
#
#
#         sum_dpd_2y = 0
#     piece = list()
#
# df['DPD30P2Y_flag'] = pd.Series(dpd30_2y).values
# df['DPD60P2Y_flag'] = pd.Series(dpd60_2y).values
# df['DPD90P2Y_flag'] = pd.Series(dpd90_2y).values

# %% [markdown]
# <a id='DPD2Y_num'></a>
# ### Code for DPD2Y (numerical)

# %% [markdown]
# - For an applicant, Count of all loans where DPD30P2Y_flag =1
# - For an applicant, Count of all loans where DPD60P2Y_flag =1
# - For an applicant, Count of all loans where DPD90P2Y_flag =1

# %%
DPD30P2Y = list()
count_list_30_2y = list()
count_30_2y = 0

DPD60P2Y = list()
count_list_60_2y = list()
count_60_2y = 0

DPD90P2Y = list()
count_list_90_2y = list()
count_90_2y = 0

grp_df = df.groupby('ID')

for x in range(0, len(unq_id_list)):
    grp_slice = grp_df.get_group(unq_id_list[x])
    #print(grp_slice)
    grp_slice.reset_index(drop=True, inplace=True)
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['DPD30P2Y_flag'][i]==1) or (grp_slice['DPD30P2Y_flag'][i]==0):
            count_30_2y = count_30_2y + grp_slice['DPD30P2Y_flag'][i]
        
        if (grp_slice['DPD60P2Y_flag'][i]==1) or (grp_slice['DPD60P2Y_flag'][i]==0):
            count_60_2y = count_60_2y + grp_slice['DPD60P2Y_flag'][i]

        if (grp_slice['DPD90P2Y_flag'][i]==1) or (grp_slice['DPD90P2Y_flag'][i]==0):
            count_90_2y = count_90_2y + grp_slice['DPD90P2Y_flag'][i]

    count_list_30_2y.append(count_30_2y)
    count_30_2y = 0
    count_list_60_2y.append(count_60_2y)
    count_60_2y = 0
    count_list_90_2y.append(count_90_2y)
    count_90_2y = 0

    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['DPD30P2Y_flag'][i]==1) or (grp_slice['DPD30P2Y_flag'][i]==0):
            DPD30P2Y.append(count_list_30_2y[x])
        else:
            DPD30P2Y.append('unknown')

        if (grp_slice['DPD60P2Y_flag'][i]==1) or (grp_slice['DPD60P2Y_flag'][i]==0):
            DPD60P2Y.append(count_list_60_2y[x])
        else:
            DPD60P2Y.append('unknown')

        if (grp_slice['DPD90P2Y_flag'][i]==1) or (grp_slice['DPD90P2Y_flag'][i]==0):
            DPD90P2Y.append(count_list_90_2y[x])
        else:
            DPD90P2Y.append('unknown')
            
df['DPD30P2Y'] = pd.Series(DPD30P2Y).values
df['DPD60P2Y'] = pd.Series(DPD60P2Y).values
df['DPD90P2Y'] = pd.Series(DPD90P2Y).values
#df['DPD60P2Y'].value_counts()

# %% [markdown]
# ### Code for DPD30P2Y_P

# %% [markdown]
# - DPD 30 in last 2 year productwise
# - For an applicant, Count of all loans where DPD30P2Y_flag =1 per product

# %%
DPD30P2Y_AL = list()
DPD30P2Y_BL = list()
DPD30P2Y_CC = list()
DPD30P2Y_CD = list()
DPD30P2Y_CV = list()
DPD30P2Y_GL = list()
DPD30P2Y_HL = list()
DPD30P2Y_LAS = list()
DPD30P2Y_MFBL = list()
DPD30P2Y_MFHL = list()
DPD30P2Y_MFOT = list()
DPD30P2Y_OTH = list()
DPD30P2Y_PL = list()
DPD30P2Y_PLBL = list()
DPD30P2Y_RL = list()
DPD30P2Y_SCC = list()
DPD30P2Y_SEL = list()

count_list_AL = list()
count_list_BL = list()
count_list_CC = list()
count_list_CD = list()
count_list_CV = list()
count_list_GL = list()
count_list_HL = list()
count_list_LAS = list()
count_list_MFBL = list()
count_list_MFHL = list()
count_list_MFOT = list()
count_list_OTH = list()
count_list_PL = list()
count_list_PLBL = list()
count_list_RL = list()
count_list_SCC = list()
count_list_SEL = list()

count_AL = 0
count_BL = 0
count_CC = 0
count_CD = 0
count_CV = 0
count_GL = 0
count_HL = 0
count_LAS = 0
count_MFBL = 0
count_MFHL = 0
count_MFOT = 0
count_OTH = 0
count_PL = 0 
count_PLBL = 0
count_RL = 0
count_SCC = 0
count_SEL = 0

grp_df = df.groupby('ID')

for x in range(0, len(unq_id_list)):
    grp_slice = grp_df.get_group(unq_id_list[x])
    #print(grp_slice)
    grp_slice.reset_index(drop=True, inplace=True)
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['accountType'][i]=='unknown'):
            continue
        elif (grp_slice['accountType'][i]=='AL') and (grp_slice['DPD30P2Y_flag'][i]==1):
            count_AL = count_AL + 1
        elif (grp_slice['accountType'][i]=='BL') and (grp_slice['DPD30P2Y_flag'][i]==1):
            count_BL = count_BL + 1
        elif (grp_slice['accountType'][i]=='CC') and (grp_slice['DPD30P2Y_flag'][i]==1):
            count_CC = count_CC + 1
        elif (grp_slice['accountType'][i]=='CD') and (grp_slice['DPD30P2Y_flag'][i]==1):
            count_CD = count_CD + 1
        elif (grp_slice['accountType'][i]=='CV') and (grp_slice['DPD30P2Y_flag'][i]==1):
            count_CV = count_CV + 1
        elif (grp_slice['accountType'][i]=='GL') and (grp_slice['DPD30P2Y_flag'][i]==1):
            count_GL = count_GL + 1
        elif (grp_slice['accountType'][i]=='HL') and (grp_slice['DPD30P2Y_flag'][i]==1):
            count_HL = count_HL + 1
        elif (grp_slice['accountType'][i]=='LAS') and (grp_slice['DPD30P2Y_flag'][i]==1):
            count_LAS = count_LAS + 1
        elif (grp_slice['accountType'][i]=='MFBL') and (grp_slice['DPD30P2Y_flag'][i]==1):
            count_MFBL = count_MFBL + 1
        elif (grp_slice['accountType'][i]=='MFHL') and (grp_slice['DPD30P2Y_flag'][i]==1):
            count_MFHL = count_MFHL + 1
        elif (grp_slice['accountType'][i]=='MFOT') and (grp_slice['DPD30P2Y_flag'][i]==1):
            count_MFOT = count_MFOT + 1
        elif (grp_slice['accountType'][i]=='OTH') and (grp_slice['DPD30P2Y_flag'][i]==1):
            count_OTH = count_OTH + 1
        elif (grp_slice['accountType'][i]=='PL') and (grp_slice['DPD30P2Y_flag'][i]==1):
            count_PL = count_PL + 1
        elif (grp_slice['accountType'][i]=='PLBL') and (grp_slice['DPD30P2Y_flag'][i]==1):
            count_PLBL = count_PLBL + 1
        elif (grp_slice['accountType'][i]=='RL') and (grp_slice['DPD30P2Y_flag'][i]==1):
            count_RL = count_RL + 1
        elif (grp_slice['accountType'][i]=='SCC') and (grp_slice['DPD30P2Y_flag'][i]==1):
            count_SCC = count_SCC + 1
        elif (grp_slice['accountType'][i]=='SEL') and (grp_slice['DPD30P2Y_flag'][i]==1):
            count_SEL = count_SEL + 1
            
    count_list_AL.append(count_AL)
    count_list_BL.append(count_BL)
    count_list_CC.append(count_CC)
    count_list_CD.append(count_CD)
    count_list_CV.append(count_CV)
    count_list_GL.append(count_GL)
    count_list_HL.append(count_HL)
    count_list_LAS.append(count_LAS)
    count_list_MFBL.append(count_MFBL)
    count_list_MFHL.append(count_MFHL)
    count_list_MFOT.append(count_MFOT)
    count_list_OTH.append(count_OTH)
    count_list_PL.append(count_PL)
    count_list_PLBL.append(count_PLBL)
    count_list_RL.append(count_RL)
    count_list_SCC.append(count_SCC)
    count_list_SEL.append(count_SEL)
    
    count_AL = 0
    count_BL = 0
    count_CC = 0
    count_CD = 0
    count_CV = 0
    count_GL = 0
    count_HL = 0
    count_LAS = 0
    count_MFBL = 0
    count_MFHL = 0
    count_MFOT = 0
    count_OTH = 0
    count_PL = 0
    count_PLBL = 0
    count_RL = 0
    count_SCC = 0
    count_SEL = 0
    
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['accountType'][i]=='unknown'):
            DPD30P2Y_AL.append('unknown')
            DPD30P2Y_BL.append('unknown')
            DPD30P2Y_CC.append('unknown')
            DPD30P2Y_CD.append('unknown')
            DPD30P2Y_CV.append('unknown')
            DPD30P2Y_GL.append('unknown')
            DPD30P2Y_HL.append('unknown')
            DPD30P2Y_LAS.append('unknown')
            DPD30P2Y_MFBL.append('unknown')
            DPD30P2Y_MFHL.append('unknown')
            DPD30P2Y_MFOT.append('unknown')
            DPD30P2Y_OTH.append('unknown')
            DPD30P2Y_PL.append('unknown')
            DPD30P2Y_PLBL.append('unknown')
            DPD30P2Y_RL.append('unknown')
            DPD30P2Y_SCC.append('unknown')
            DPD30P2Y_SEL.append('unknown')
        else:
            DPD30P2Y_AL.append(count_list_AL[x])
            DPD30P2Y_BL.append(count_list_BL[x])
            DPD30P2Y_CC.append(count_list_CC[x])
            DPD30P2Y_CD.append(count_list_CD[x])
            DPD30P2Y_CV.append(count_list_CV[x])
            DPD30P2Y_GL.append(count_list_GL[x])
            DPD30P2Y_HL.append(count_list_HL[x])
            DPD30P2Y_LAS.append(count_list_LAS[x])
            DPD30P2Y_MFBL.append(count_list_MFBL[x])
            DPD30P2Y_MFHL.append(count_list_MFHL[x])
            DPD30P2Y_MFOT.append(count_list_MFOT[x])
            DPD30P2Y_OTH.append(count_list_OTH[x])
            DPD30P2Y_PL.append(count_list_PL[x])
            DPD30P2Y_PLBL.append(count_list_PLBL[x])
            DPD30P2Y_RL.append(count_list_RL[x])
            DPD30P2Y_SCC.append(count_list_SCC[x])
            DPD30P2Y_SEL.append(count_list_SEL[x])
            
df['DPD30P2Y_AL'] = pd.Series(DPD30P2Y_AL).values
df['DPD30P2Y_BL'] = pd.Series(DPD30P2Y_BL).values
df['DPD30P2Y_CC'] = pd.Series(DPD30P2Y_CC).values
df['DPD30P2Y_CD'] = pd.Series(DPD30P2Y_CD).values
df['DPD30P2Y_CV'] = pd.Series(DPD30P2Y_CV).values
df['DPD30P2Y_GL'] = pd.Series(DPD30P2Y_GL).values
df['DPD30P2Y_HL'] = pd.Series(DPD30P2Y_HL).values
df['DPD30P2Y_LAS'] = pd.Series(DPD30P2Y_LAS).values
df['DPD30P2Y_MFBL'] = pd.Series(DPD30P2Y_MFBL).values
df['DPD30P2Y_MFHL'] = pd.Series(DPD30P2Y_MFHL).values
df['DPD30P2Y_MFOT'] = pd.Series(DPD30P2Y_MFOT).values
df['DPD30P2Y_OTH'] = pd.Series(DPD30P2Y_OTH).values
df['DPD30P2Y_PL'] = pd.Series(DPD30P2Y_PL).values
df['DPD30P2Y_PLBL'] = pd.Series(DPD30P2Y_PLBL).values
df['DPD30P2Y_RL'] = pd.Series(DPD30P2Y_RL).values
df['DPD30P2Y_SCC'] = pd.Series(DPD30P2Y_SCC).values
df['DPD30P2Y_SEL'] = pd.Series(DPD30P2Y_SEL).values

# %% [raw]
# d = df[['ID','DPD30P2Y_GL','DPD30P2Y_flag','accountType']]
# d[d['DPD30P2Y_flag']!=0].head(60)

# %% [markdown]
# ### Code for DPD60P2Y_P

# %% [markdown]
# - DPD 60 in last 2 year productwise
# - For an applicant, Count of all loans where DPD60P2Y_flag =1 per product

# %%
DPD60P2Y_AL = list()
DPD60P2Y_BL = list()
DPD60P2Y_CC = list()
DPD60P2Y_CD = list()
DPD60P2Y_CV = list()
DPD60P2Y_GL = list()
DPD60P2Y_HL = list()
DPD60P2Y_LAS = list()
DPD60P2Y_MFBL = list()
DPD60P2Y_MFHL = list()
DPD60P2Y_MFOT = list()
DPD60P2Y_OTH = list()
DPD60P2Y_PL = list()
DPD60P2Y_PLBL = list()
DPD60P2Y_RL = list()
DPD60P2Y_SCC = list()
DPD60P2Y_SEL = list()

count_list_AL = list()
count_list_BL = list()
count_list_CC = list()
count_list_CD = list()
count_list_CV = list()
count_list_GL = list()
count_list_HL = list()
count_list_LAS = list()
count_list_MFBL = list()
count_list_MFHL = list()
count_list_MFOT = list()
count_list_OTH = list()
count_list_PL = list()
count_list_PLBL = list()
count_list_RL = list()
count_list_SCC = list()
count_list_SEL = list()

count_AL = 0
count_BL = 0
count_CC = 0
count_CD = 0
count_CV = 0
count_GL = 0
count_HL = 0
count_LAS = 0
count_MFBL = 0
count_MFHL = 0
count_MFOT = 0
count_OTH = 0
count_PL = 0 
count_PLBL = 0
count_RL = 0
count_SCC = 0
count_SEL = 0

grp_df = df.groupby('ID')

for x in range(0, len(unq_id_list)):
    grp_slice = grp_df.get_group(unq_id_list[x])
    #print(grp_slice)
    grp_slice.reset_index(drop=True, inplace=True)
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['accountType'][i]=='unknown'):
            continue
        elif (grp_slice['accountType'][i]=='AL') and (grp_slice['DPD60P2Y_flag'][i]==1):
            count_AL = count_AL + 1
        elif (grp_slice['accountType'][i]=='BL') and (grp_slice['DPD60P2Y_flag'][i]==1):
            count_BL = count_BL + 1
        elif (grp_slice['accountType'][i]=='CC') and (grp_slice['DPD60P2Y_flag'][i]==1):
            count_CC = count_CC + 1
        elif (grp_slice['accountType'][i]=='CD') and (grp_slice['DPD60P2Y_flag'][i]==1):
            count_CD = count_CD + 1
        elif (grp_slice['accountType'][i]=='CV') and (grp_slice['DPD60P2Y_flag'][i]==1):
            count_CV = count_CV + 1
        elif (grp_slice['accountType'][i]=='GL') and (grp_slice['DPD60P2Y_flag'][i]==1):
            count_GL = count_GL + 1
        elif (grp_slice['accountType'][i]=='HL') and (grp_slice['DPD60P2Y_flag'][i]==1):
            count_HL = count_HL + 1
        elif (grp_slice['accountType'][i]=='LAS') and (grp_slice['DPD60P2Y_flag'][i]==1):
            count_LAS = count_LAS + 1
        elif (grp_slice['accountType'][i]=='MFBL') and (grp_slice['DPD60P2Y_flag'][i]==1):
            count_MFBL = count_MFBL + 1
        elif (grp_slice['accountType'][i]=='MFHL') and (grp_slice['DPD60P2Y_flag'][i]==1):
            count_MFHL = count_MFHL + 1
        elif (grp_slice['accountType'][i]=='MFOT') and (grp_slice['DPD60P2Y_flag'][i]==1):
            count_MFOT = count_MFOT + 1
        elif (grp_slice['accountType'][i]=='OTH') and (grp_slice['DPD60P2Y_flag'][i]==1):
            count_OTH = count_OTH + 1
        elif (grp_slice['accountType'][i]=='PL') and (grp_slice['DPD60P2Y_flag'][i]==1):
            count_PL = count_PL + 1
        elif (grp_slice['accountType'][i]=='PLBL') and (grp_slice['DPD60P2Y_flag'][i]==1):
            count_PLBL = count_PLBL + 1
        elif (grp_slice['accountType'][i]=='RL') and (grp_slice['DPD60P2Y_flag'][i]==1):
            count_RL = count_RL + 1
        elif (grp_slice['accountType'][i]=='SCC') and (grp_slice['DPD60P2Y_flag'][i]==1):
            count_SCC = count_SCC + 1
        elif (grp_slice['accountType'][i]=='SEL') and (grp_slice['DPD60P2Y_flag'][i]==1):
            count_SEL = count_SEL + 1
            
    count_list_AL.append(count_AL)
    count_list_BL.append(count_BL)
    count_list_CC.append(count_CC)
    count_list_CD.append(count_CD)
    count_list_CV.append(count_CV)
    count_list_GL.append(count_GL)
    count_list_HL.append(count_HL)
    count_list_LAS.append(count_LAS)
    count_list_MFBL.append(count_MFBL)
    count_list_MFHL.append(count_MFHL)
    count_list_MFOT.append(count_MFOT)
    count_list_OTH.append(count_OTH)
    count_list_PL.append(count_PL)
    count_list_PLBL.append(count_PLBL)
    count_list_RL.append(count_RL)
    count_list_SCC.append(count_SCC)
    count_list_SEL.append(count_SEL)
    
    count_AL = 0
    count_BL = 0
    count_CC = 0
    count_CD = 0
    count_CV = 0
    count_GL = 0
    count_HL = 0
    count_LAS = 0
    count_MFBL = 0
    count_MFHL = 0
    count_MFOT = 0
    count_OTH = 0
    count_PL = 0
    count_PLBL = 0
    count_RL = 0
    count_SCC = 0
    count_SEL = 0
    
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['accountType'][i]=='unknown'):
            DPD60P2Y_AL.append('unknown')
            DPD60P2Y_BL.append('unknown')
            DPD60P2Y_CC.append('unknown')
            DPD60P2Y_CD.append('unknown')
            DPD60P2Y_CV.append('unknown')
            DPD60P2Y_GL.append('unknown')
            DPD60P2Y_HL.append('unknown')
            DPD60P2Y_LAS.append('unknown')
            DPD60P2Y_MFBL.append('unknown')
            DPD60P2Y_MFHL.append('unknown')
            DPD60P2Y_MFOT.append('unknown')
            DPD60P2Y_OTH.append('unknown')
            DPD60P2Y_PL.append('unknown')
            DPD60P2Y_PLBL.append('unknown')
            DPD60P2Y_RL.append('unknown')
            DPD60P2Y_SCC.append('unknown')
            DPD60P2Y_SEL.append('unknown')
        else:
            DPD60P2Y_AL.append(count_list_AL[x])
            DPD60P2Y_BL.append(count_list_BL[x])
            DPD60P2Y_CC.append(count_list_CC[x])
            DPD60P2Y_CD.append(count_list_CD[x])
            DPD60P2Y_CV.append(count_list_CV[x])
            DPD60P2Y_GL.append(count_list_GL[x])
            DPD60P2Y_HL.append(count_list_HL[x])
            DPD60P2Y_LAS.append(count_list_LAS[x])
            DPD60P2Y_MFBL.append(count_list_MFBL[x])
            DPD60P2Y_MFHL.append(count_list_MFHL[x])
            DPD60P2Y_MFOT.append(count_list_MFOT[x])
            DPD60P2Y_OTH.append(count_list_OTH[x])
            DPD60P2Y_PL.append(count_list_PL[x])
            DPD60P2Y_PLBL.append(count_list_PLBL[x])
            DPD60P2Y_RL.append(count_list_RL[x])
            DPD60P2Y_SCC.append(count_list_SCC[x])
            DPD60P2Y_SEL.append(count_list_SEL[x])
            
df['DPD60P2Y_AL'] = pd.Series(DPD60P2Y_AL).values
df['DPD60P2Y_BL'] = pd.Series(DPD60P2Y_BL).values
df['DPD60P2Y_CC'] = pd.Series(DPD60P2Y_CC).values
df['DPD60P2Y_CD'] = pd.Series(DPD60P2Y_CD).values
df['DPD60P2Y_CV'] = pd.Series(DPD60P2Y_CV).values
df['DPD60P2Y_GL'] = pd.Series(DPD60P2Y_GL).values
df['DPD60P2Y_HL'] = pd.Series(DPD60P2Y_HL).values
df['DPD60P2Y_LAS'] = pd.Series(DPD60P2Y_LAS).values
df['DPD60P2Y_MFBL'] = pd.Series(DPD60P2Y_MFBL).values
df['DPD60P2Y_MFHL'] = pd.Series(DPD60P2Y_MFHL).values
df['DPD60P2Y_MFOT'] = pd.Series(DPD60P2Y_MFOT).values
df['DPD60P2Y_OTH'] = pd.Series(DPD60P2Y_OTH).values
df['DPD60P2Y_PL'] = pd.Series(DPD60P2Y_PL).values
df['DPD60P2Y_PLBL'] = pd.Series(DPD60P2Y_PLBL).values
df['DPD60P2Y_RL'] = pd.Series(DPD60P2Y_RL).values
df['DPD60P2Y_SCC'] = pd.Series(DPD60P2Y_SCC).values
df['DPD60P2Y_SEL'] = pd.Series(DPD60P2Y_SEL).values

# %% [raw]
# d = df[['ID','DPD60P2Y_GL','DPD60P2Y_flag','accountType']]
# d[d['DPD60P2Y_flag']!=0].head(60)

# %% [markdown]
# ### Code for DPD90P2Y_P

# %% [markdown]
# - DPD 90 in last 2 year productwise
# - For an applicant, Count of all loans where DPD90P2Y_flag =1 per product

# %%
DPD90P2Y_AL = list()
DPD90P2Y_BL = list()
DPD90P2Y_CC = list()
DPD90P2Y_CD = list()
DPD90P2Y_CV = list()
DPD90P2Y_GL = list()
DPD90P2Y_HL = list()
DPD90P2Y_LAS = list()
DPD90P2Y_MFBL = list()
DPD90P2Y_MFHL = list()
DPD90P2Y_MFOT = list()
DPD90P2Y_OTH = list()
DPD90P2Y_PL = list()
DPD90P2Y_PLBL = list()
DPD90P2Y_RL = list()
DPD90P2Y_SCC = list()
DPD90P2Y_SEL = list()

count_list_AL = list()
count_list_BL = list()
count_list_CC = list()
count_list_CD = list()
count_list_CV = list()
count_list_GL = list()
count_list_HL = list()
count_list_LAS = list()
count_list_MFBL = list()
count_list_MFHL = list()
count_list_MFOT = list()
count_list_OTH = list()
count_list_PL = list()
count_list_PLBL = list()
count_list_RL = list()
count_list_SCC = list()
count_list_SEL = list()

count_AL = 0
count_BL = 0
count_CC = 0
count_CD = 0
count_CV = 0
count_GL = 0
count_HL = 0
count_LAS = 0
count_MFBL = 0
count_MFHL = 0
count_MFOT = 0
count_OTH = 0
count_PL = 0 
count_PLBL = 0
count_RL = 0
count_SCC = 0
count_SEL = 0

grp_df = df.groupby('ID')

for x in range(0, len(unq_id_list)):
    grp_slice = grp_df.get_group(unq_id_list[x])
    #print(grp_slice)
    grp_slice.reset_index(drop=True, inplace=True)
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['accountType'][i]=='unknown'):
            continue
        elif (grp_slice['accountType'][i]=='AL') and (grp_slice['DPD90P2Y_flag'][i]==1):
            count_AL = count_AL + 1
        elif (grp_slice['accountType'][i]=='BL') and (grp_slice['DPD90P2Y_flag'][i]==1):
            count_BL = count_BL + 1
        elif (grp_slice['accountType'][i]=='CC') and (grp_slice['DPD90P2Y_flag'][i]==1):
            count_CC = count_CC + 1
        elif (grp_slice['accountType'][i]=='CD') and (grp_slice['DPD90P2Y_flag'][i]==1):
            count_CD = count_CD + 1
        elif (grp_slice['accountType'][i]=='CV') and (grp_slice['DPD90P2Y_flag'][i]==1):
            count_CV = count_CV + 1
        elif (grp_slice['accountType'][i]=='GL') and (grp_slice['DPD90P2Y_flag'][i]==1):
            count_GL = count_GL + 1
        elif (grp_slice['accountType'][i]=='HL') and (grp_slice['DPD90P2Y_flag'][i]==1):
            count_HL = count_HL + 1
        elif (grp_slice['accountType'][i]=='LAS') and (grp_slice['DPD90P2Y_flag'][i]==1):
            count_LAS = count_LAS + 1
        elif (grp_slice['accountType'][i]=='MFBL') and (grp_slice['DPD90P2Y_flag'][i]==1):
            count_MFBL = count_MFBL + 1
        elif (grp_slice['accountType'][i]=='MFHL') and (grp_slice['DPD90P2Y_flag'][i]==1):
            count_MFHL = count_MFHL + 1
        elif (grp_slice['accountType'][i]=='MFOT') and (grp_slice['DPD90P2Y_flag'][i]==1):
            count_MFOT = count_MFOT + 1
        elif (grp_slice['accountType'][i]=='OTH') and (grp_slice['DPD90P2Y_flag'][i]==1):
            count_OTH = count_OTH + 1
        elif (grp_slice['accountType'][i]=='PL') and (grp_slice['DPD90P2Y_flag'][i]==1):
            count_PL = count_PL + 1
        elif (grp_slice['accountType'][i]=='PLBL') and (grp_slice['DPD90P2Y_flag'][i]==1):
            count_PLBL = count_PLBL + 1
        elif (grp_slice['accountType'][i]=='RL') and (grp_slice['DPD90P2Y_flag'][i]==1):
            count_RL = count_RL + 1
        elif (grp_slice['accountType'][i]=='SCC') and (grp_slice['DPD90P2Y_flag'][i]==1):
            count_SCC = count_SCC + 1
        elif (grp_slice['accountType'][i]=='SEL') and (grp_slice['DPD90P2Y_flag'][i]==1):
            count_SEL = count_SEL + 1
            
    count_list_AL.append(count_AL)
    count_list_BL.append(count_BL)
    count_list_CC.append(count_CC)
    count_list_CD.append(count_CD)
    count_list_CV.append(count_CV)
    count_list_GL.append(count_GL)
    count_list_HL.append(count_HL)
    count_list_LAS.append(count_LAS)
    count_list_MFBL.append(count_MFBL)
    count_list_MFHL.append(count_MFHL)
    count_list_MFOT.append(count_MFOT)
    count_list_OTH.append(count_OTH)
    count_list_PL.append(count_PL)
    count_list_PLBL.append(count_PLBL)
    count_list_RL.append(count_RL)
    count_list_SCC.append(count_SCC)
    count_list_SEL.append(count_SEL)
    
    count_AL = 0
    count_BL = 0
    count_CC = 0
    count_CD = 0
    count_CV = 0
    count_GL = 0
    count_HL = 0
    count_LAS = 0
    count_MFBL = 0
    count_MFHL = 0
    count_MFOT = 0
    count_OTH = 0
    count_PL = 0
    count_PLBL = 0
    count_RL = 0
    count_SCC = 0
    count_SEL = 0
    
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['accountType'][i]=='unknown'):
            DPD90P2Y_AL.append('unknown')
            DPD90P2Y_BL.append('unknown')
            DPD90P2Y_CC.append('unknown')
            DPD90P2Y_CD.append('unknown')
            DPD90P2Y_CV.append('unknown')
            DPD90P2Y_GL.append('unknown')
            DPD90P2Y_HL.append('unknown')
            DPD90P2Y_LAS.append('unknown')
            DPD90P2Y_MFBL.append('unknown')
            DPD90P2Y_MFHL.append('unknown')
            DPD90P2Y_MFOT.append('unknown')
            DPD90P2Y_OTH.append('unknown')
            DPD90P2Y_PL.append('unknown')
            DPD90P2Y_PLBL.append('unknown')
            DPD90P2Y_RL.append('unknown')
            DPD90P2Y_SCC.append('unknown')
            DPD90P2Y_SEL.append('unknown')
        else:
            DPD90P2Y_AL.append(count_list_AL[x])
            DPD90P2Y_BL.append(count_list_BL[x])
            DPD90P2Y_CC.append(count_list_CC[x])
            DPD90P2Y_CD.append(count_list_CD[x])
            DPD90P2Y_CV.append(count_list_CV[x])
            DPD90P2Y_GL.append(count_list_GL[x])
            DPD90P2Y_HL.append(count_list_HL[x])
            DPD90P2Y_LAS.append(count_list_LAS[x])
            DPD90P2Y_MFBL.append(count_list_MFBL[x])
            DPD90P2Y_MFHL.append(count_list_MFHL[x])
            DPD90P2Y_MFOT.append(count_list_MFOT[x])
            DPD90P2Y_OTH.append(count_list_OTH[x])
            DPD90P2Y_PL.append(count_list_PL[x])
            DPD90P2Y_PLBL.append(count_list_PLBL[x])
            DPD90P2Y_RL.append(count_list_RL[x])
            DPD90P2Y_SCC.append(count_list_SCC[x])
            DPD90P2Y_SEL.append(count_list_SEL[x])
            
df['DPD90P2Y_AL'] = pd.Series(DPD90P2Y_AL).values
df['DPD90P2Y_BL'] = pd.Series(DPD90P2Y_BL).values
df['DPD90P2Y_CC'] = pd.Series(DPD90P2Y_CC).values
df['DPD90P2Y_CD'] = pd.Series(DPD90P2Y_CD).values
df['DPD90P2Y_CV'] = pd.Series(DPD90P2Y_CV).values
df['DPD90P2Y_GL'] = pd.Series(DPD90P2Y_GL).values
df['DPD90P2Y_HL'] = pd.Series(DPD90P2Y_HL).values
df['DPD90P2Y_LAS'] = pd.Series(DPD90P2Y_LAS).values
df['DPD90P2Y_MFBL'] = pd.Series(DPD90P2Y_MFBL).values
df['DPD90P2Y_MFHL'] = pd.Series(DPD90P2Y_MFHL).values
df['DPD90P2Y_MFOT'] = pd.Series(DPD90P2Y_MFOT).values
df['DPD90P2Y_OTH'] = pd.Series(DPD90P2Y_OTH).values
df['DPD90P2Y_PL'] = pd.Series(DPD90P2Y_PL).values
df['DPD90P2Y_PLBL'] = pd.Series(DPD90P2Y_PLBL).values
df['DPD90P2Y_RL'] = pd.Series(DPD90P2Y_RL).values
df['DPD90P2Y_SCC'] = pd.Series(DPD90P2Y_SCC).values
df['DPD90P2Y_SEL'] = pd.Series(DPD90P2Y_SEL).values

# %% [raw]
# d = df[['ID','DPD90P2Y_GL','DPD90P2Y_flag','accountType']]
# d[d['DPD90P2Y_flag']!=0].head(60)

# %% [markdown]
# <a id='DPD_flags_3y'></a>
# ### Code for DPD flags for last 3 year

# %%
dpd30_3y = list()
dpd60_3y = list()
dpd90_3y = list()
matching = list()

for x in range(0, df.shape[0]):
    if (df['mo_diff_ld_drc'][x] == -1):
        # print(df['mo_diff_ld_drc'][x])
        dpd30_3y.append('unknown')
        dpd60_3y.append('unknown')
        dpd90_3y.append('unknown')
    elif (df['mo_diff_ld_drc'][x] >= 0) and (df['mo_diff_ld_drc'][x] <= 36):
        # print(df['mo_diff_ld_drc'][x])
        if (36-df['mo_diff_ld_drc'][x] <= len(df['intPayHistComp'][x])):
            for i in range(0, 36-df['mo_diff_ld_drc'][x]):
                a = df['intPayHistComp'][x][i]
                matching.append(a)
        else:
            for i in range(0, len(df['intPayHistComp'][x])):
                a = df['intPayHistComp'][x][i]
                matching.append(a)

        # print(matching)
        if (sum(matching) > 0) and (sum(matching) <= 30):
            dpd30_3y.append(1)
            dpd60_3y.append(0)
            dpd90_3y.append(0)
            # print('3',matching)
        elif (sum(matching) > 30) and (sum(matching) <= 60):
            dpd30_3y.append(0)
            dpd60_3y.append(1)
            dpd90_3y.append(0)
            # print('2',matching)
        elif (sum(matching) > 60) and (sum(matching) <= 90):
            dpd30_3y.append(0)
            dpd60_3y.append(0)
            dpd90_3y.append(1)
            # print('1',matching)
        else:
            dpd30_3y.append(0)
            dpd60_3y.append(0)
            dpd90_3y.append(0)
    else:
        dpd30_3y.append(0)
        dpd60_3y.append(0)
        dpd90_3y.append(0)

        matching = list()

df['DPD30P3Y_flag'] = pd.Series(dpd30_3y).values
df['DPD60P3Y_flag'] = pd.Series(dpd60_3y).values
df['DPD90P3Y_flag'] = pd.Series(dpd90_3y).values

# df['DPD30P3Y_flag'].value_counts()
# print(len(dpd30_3y))

# %% [raw]
# piece = list()
# sum_dpd_3y = 0
#
# dpd30_3y = list()
# dpd60_3y = list()
# dpd90_3y = list()
#
# for value in df['paymentHistComp']:
#     #print(value)
#     chunks, chunk_size = len(value), 3
#     for i in range(0, chunks, chunk_size):
#         piece.append(value[i:i+chunk_size])
#     #print(piece)
#     if len(piece)==36:
#         #print(piece)
#         for x in range(0,36):
#             #print(x)
#             if hasNumbers(piece[x]):
#                 piece[x] = int(piece[x])
#                 sum_dpd_3y = piece[x] + sum_dpd_3y
#             else:
#                 continue
#         #print(piece)
#         #print(sum_dpd_3y)
#         if (sum_dpd_3y <= 30) and (sum_dpd_3y > 0):
#             #print(piece)
#             dpd30_3y.append(1)
#             dpd60_3y.append(0)
#             dpd90_3y.append(0)
#             sum_dpd_3y = 0
#         elif (sum_dpd_3y <= 60) and (sum_dpd_3y > 30):
#             #print(piece)
#             dpd30_3y.append(0)
#             dpd60_3y.append(1)
#             dpd90_3y.append(0)
#             sum_dpd_3y = 0
#         elif (sum_dpd_3y <= 90) and (sum_dpd_3y > 60):
#             #print(piece)
#             dpd30_3y.append(0)
#             dpd60_3y.append(0)
#             dpd90_3y.append(1)
#             sum_dpd_3y = 0
#         else:
#             dpd30_3y.append(0)
#             dpd60_3y.append(0)
#             dpd90_3y.append(0)
#     else:
#         dpd30_3y.append(0)
#         dpd60_3y.append(0)
#         dpd90_3y.append(0)
#
#
#
#         sum_dpd_3y = 0
#     piece = list()
#
# df['DPD30P3Y_flag'] = pd.Series(dpd30_3y).values
# df['DPD60P3Y_flag'] = pd.Series(dpd60_3y).values
# df['DPD90P3Y_flag'] = pd.Series(dpd90_3y).values

# %% [markdown]
# <a id='DPD3Y_num'></a>
# ### Code for DPD3Y (numerical)

# %% [markdown]
# - For an applicant, Count of all loans where DPD30P3Y_flag =1
# - For an applicant, Count of all loans where DPD60P3Y_flag =1
# - For an applicant, Count of all loans where DPD90P3Y_flag =1

# %%
DPD30P3Y = list()
count_list_30_3y = list()
count_30_3y = 0

DPD60P3Y = list()
count_list_60_3y = list()
count_60_3y = 0

DPD90P3Y = list()
count_list_90_3y = list()
count_90_3y = 0

grp_df = df.groupby('ID')

for x in range(0, len(unq_id_list)):
    grp_slice = grp_df.get_group(unq_id_list[x])
    #print(grp_slice)
    grp_slice.reset_index(drop=True, inplace=True)
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['DPD30P3Y_flag'][i]==1) or (grp_slice['DPD30P3Y_flag'][i]==0):
            count_30_3y = count_30_3y + grp_slice['DPD30P3Y_flag'][i]
        
        if (grp_slice['DPD60P3Y_flag'][i]==1) or (grp_slice['DPD60P3Y_flag'][i]==0):
            count_60_3y = count_60_3y + grp_slice['DPD60P3Y_flag'][i]

        if (grp_slice['DPD90P3Y_flag'][i]==1) or (grp_slice['DPD90P3Y_flag'][i]==0):
            count_90_3y = count_90_3y + grp_slice['DPD90P3Y_flag'][i]

    count_list_30_3y.append(count_30_3y)
    count_30_3y = 0
    count_list_60_3y.append(count_60_3y)
    count_60_3y = 0
    count_list_90_3y.append(count_90_3y)
    count_90_3y = 0

    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['DPD30P3Y_flag'][i]==1) or (grp_slice['DPD30P3Y_flag'][i]==0):
            DPD30P3Y.append(count_list_30_3y[x])
        else:
            DPD30P3Y.append('unknown')

        if (grp_slice['DPD60P3Y_flag'][i]==1) or (grp_slice['DPD60P3Y_flag'][i]==0):
            DPD60P3Y.append(count_list_60_3y[x])
        else:
            DPD60P3Y.append('unknown')

        if (grp_slice['DPD90P3Y_flag'][i]==1) or (grp_slice['DPD90P3Y_flag'][i]==0):
            DPD90P3Y.append(count_list_90_3y[x])
        else:
            DPD90P3Y.append('unknown')
            
df['DPD30P3Y'] = pd.Series(DPD30P3Y).values
df['DPD60P3Y'] = pd.Series(DPD60P3Y).values
df['DPD90P3Y'] = pd.Series(DPD90P3Y).values
#df['DPD60P3Y'].value_counts()

# %% [markdown]
# ### Code for DPD30P3Y_P

# %% [markdown]
# - DPD 30 in last 3 year productwise
# - For an applicant, Count of all loans where DPD30P3Y_flag =1 per product

# %%
DPD30P3Y_AL = list()
DPD30P3Y_BL = list()
DPD30P3Y_CC = list()
DPD30P3Y_CD = list()
DPD30P3Y_CV = list()
DPD30P3Y_GL = list()
DPD30P3Y_HL = list()
DPD30P3Y_LAS = list()
DPD30P3Y_MFBL = list()
DPD30P3Y_MFHL = list()
DPD30P3Y_MFOT = list()
DPD30P3Y_OTH = list()
DPD30P3Y_PL = list()
DPD30P3Y_PLBL = list()
DPD30P3Y_RL = list()
DPD30P3Y_SCC = list()
DPD30P3Y_SEL = list()

count_list_AL = list()
count_list_BL = list()
count_list_CC = list()
count_list_CD = list()
count_list_CV = list()
count_list_GL = list()
count_list_HL = list()
count_list_LAS = list()
count_list_MFBL = list()
count_list_MFHL = list()
count_list_MFOT = list()
count_list_OTH = list()
count_list_PL = list()
count_list_PLBL = list()
count_list_RL = list()
count_list_SCC = list()
count_list_SEL = list()

count_AL = 0
count_BL = 0
count_CC = 0
count_CD = 0
count_CV = 0
count_GL = 0
count_HL = 0
count_LAS = 0
count_MFBL = 0
count_MFHL = 0
count_MFOT = 0
count_OTH = 0
count_PL = 0 
count_PLBL = 0
count_RL = 0
count_SCC = 0
count_SEL = 0

grp_df = df.groupby('ID')

for x in range(0, len(unq_id_list)):
    grp_slice = grp_df.get_group(unq_id_list[x])
    #print(grp_slice)
    grp_slice.reset_index(drop=True, inplace=True)
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['accountType'][i]=='unknown'):
            continue
        elif (grp_slice['accountType'][i]=='AL') and (grp_slice['DPD30P3Y_flag'][i]==1):
            count_AL = count_AL + 1
        elif (grp_slice['accountType'][i]=='BL') and (grp_slice['DPD30P3Y_flag'][i]==1):
            count_BL = count_BL + 1
        elif (grp_slice['accountType'][i]=='CC') and (grp_slice['DPD30P3Y_flag'][i]==1):
            count_CC = count_CC + 1
        elif (grp_slice['accountType'][i]=='CD') and (grp_slice['DPD30P3Y_flag'][i]==1):
            count_CD = count_CD + 1
        elif (grp_slice['accountType'][i]=='CV') and (grp_slice['DPD30P3Y_flag'][i]==1):
            count_CV = count_CV + 1
        elif (grp_slice['accountType'][i]=='GL') and (grp_slice['DPD30P3Y_flag'][i]==1):
            count_GL = count_GL + 1
        elif (grp_slice['accountType'][i]=='HL') and (grp_slice['DPD30P3Y_flag'][i]==1):
            count_HL = count_HL + 1
        elif (grp_slice['accountType'][i]=='LAS') and (grp_slice['DPD30P3Y_flag'][i]==1):
            count_LAS = count_LAS + 1
        elif (grp_slice['accountType'][i]=='MFBL') and (grp_slice['DPD30P3Y_flag'][i]==1):
            count_MFBL = count_MFBL + 1
        elif (grp_slice['accountType'][i]=='MFHL') and (grp_slice['DPD30P3Y_flag'][i]==1):
            count_MFHL = count_MFHL + 1
        elif (grp_slice['accountType'][i]=='MFOT') and (grp_slice['DPD30P3Y_flag'][i]==1):
            count_MFOT = count_MFOT + 1
        elif (grp_slice['accountType'][i]=='OTH') and (grp_slice['DPD30P3Y_flag'][i]==1):
            count_OTH = count_OTH + 1
        elif (grp_slice['accountType'][i]=='PL') and (grp_slice['DPD30P3Y_flag'][i]==1):
            count_PL = count_PL + 1
        elif (grp_slice['accountType'][i]=='PLBL') and (grp_slice['DPD30P3Y_flag'][i]==1):
            count_PLBL = count_PLBL + 1
        elif (grp_slice['accountType'][i]=='RL') and (grp_slice['DPD30P3Y_flag'][i]==1):
            count_RL = count_RL + 1
        elif (grp_slice['accountType'][i]=='SCC') and (grp_slice['DPD30P3Y_flag'][i]==1):
            count_SCC = count_SCC + 1
        elif (grp_slice['accountType'][i]=='SEL') and (grp_slice['DPD30P3Y_flag'][i]==1):
            count_SEL = count_SEL + 1
            
    count_list_AL.append(count_AL)
    count_list_BL.append(count_BL)
    count_list_CC.append(count_CC)
    count_list_CD.append(count_CD)
    count_list_CV.append(count_CV)
    count_list_GL.append(count_GL)
    count_list_HL.append(count_HL)
    count_list_LAS.append(count_LAS)
    count_list_MFBL.append(count_MFBL)
    count_list_MFHL.append(count_MFHL)
    count_list_MFOT.append(count_MFOT)
    count_list_OTH.append(count_OTH)
    count_list_PL.append(count_PL)
    count_list_PLBL.append(count_PLBL)
    count_list_RL.append(count_RL)
    count_list_SCC.append(count_SCC)
    count_list_SEL.append(count_SEL)
    
    count_AL = 0
    count_BL = 0
    count_CC = 0
    count_CD = 0
    count_CV = 0
    count_GL = 0
    count_HL = 0
    count_LAS = 0
    count_MFBL = 0
    count_MFHL = 0
    count_MFOT = 0
    count_OTH = 0
    count_PL = 0
    count_PLBL = 0
    count_RL = 0
    count_SCC = 0
    count_SEL = 0
    
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['accountType'][i]=='unknown'):
            DPD30P3Y_AL.append('unknown')
            DPD30P3Y_BL.append('unknown')
            DPD30P3Y_CC.append('unknown')
            DPD30P3Y_CD.append('unknown')
            DPD30P3Y_CV.append('unknown')
            DPD30P3Y_GL.append('unknown')
            DPD30P3Y_HL.append('unknown')
            DPD30P3Y_LAS.append('unknown')
            DPD30P3Y_MFBL.append('unknown')
            DPD30P3Y_MFHL.append('unknown')
            DPD30P3Y_MFOT.append('unknown')
            DPD30P3Y_OTH.append('unknown')
            DPD30P3Y_PL.append('unknown')
            DPD30P3Y_PLBL.append('unknown')
            DPD30P3Y_RL.append('unknown')
            DPD30P3Y_SCC.append('unknown')
            DPD30P3Y_SEL.append('unknown')
        else:
            DPD30P3Y_AL.append(count_list_AL[x])
            DPD30P3Y_BL.append(count_list_BL[x])
            DPD30P3Y_CC.append(count_list_CC[x])
            DPD30P3Y_CD.append(count_list_CD[x])
            DPD30P3Y_CV.append(count_list_CV[x])
            DPD30P3Y_GL.append(count_list_GL[x])
            DPD30P3Y_HL.append(count_list_HL[x])
            DPD30P3Y_LAS.append(count_list_LAS[x])
            DPD30P3Y_MFBL.append(count_list_MFBL[x])
            DPD30P3Y_MFHL.append(count_list_MFHL[x])
            DPD30P3Y_MFOT.append(count_list_MFOT[x])
            DPD30P3Y_OTH.append(count_list_OTH[x])
            DPD30P3Y_PL.append(count_list_PL[x])
            DPD30P3Y_PLBL.append(count_list_PLBL[x])
            DPD30P3Y_RL.append(count_list_RL[x])
            DPD30P3Y_SCC.append(count_list_SCC[x])
            DPD30P3Y_SEL.append(count_list_SEL[x])
            
df['DPD30P3Y_AL'] = pd.Series(DPD30P3Y_AL).values
df['DPD30P3Y_BL'] = pd.Series(DPD30P3Y_BL).values
df['DPD30P3Y_CC'] = pd.Series(DPD30P3Y_CC).values
df['DPD30P3Y_CD'] = pd.Series(DPD30P3Y_CD).values
df['DPD30P3Y_CV'] = pd.Series(DPD30P3Y_CV).values
df['DPD30P3Y_GL'] = pd.Series(DPD30P3Y_GL).values
df['DPD30P3Y_HL'] = pd.Series(DPD30P3Y_HL).values
df['DPD30P3Y_LAS'] = pd.Series(DPD30P3Y_LAS).values
df['DPD30P3Y_MFBL'] = pd.Series(DPD30P3Y_MFBL).values
df['DPD30P3Y_MFHL'] = pd.Series(DPD30P3Y_MFHL).values
df['DPD30P3Y_MFOT'] = pd.Series(DPD30P3Y_MFOT).values
df['DPD30P3Y_OTH'] = pd.Series(DPD30P3Y_OTH).values
df['DPD30P3Y_PL'] = pd.Series(DPD30P3Y_PL).values
df['DPD30P3Y_PLBL'] = pd.Series(DPD30P3Y_PLBL).values
df['DPD30P3Y_RL'] = pd.Series(DPD30P3Y_RL).values
df['DPD30P3Y_SCC'] = pd.Series(DPD30P3Y_SCC).values
df['DPD30P3Y_SEL'] = pd.Series(DPD30P3Y_SEL).values

# %% [raw]
# d = df[['ID','DPD30P3Y_GL','DPD30P3Y_flag','accountType']]
# d[d['DPD30P3Y_flag']!=0].head(60)

# %% [markdown]
# ### Code for DPD60P3Y_P

# %% [markdown]
# - DPD 60 in last 3 year productwise
# - For an applicant, Count of all loans where DPD60P3Y_flag =1 per product

# %%
DPD60P3Y_AL = list()
DPD60P3Y_BL = list()
DPD60P3Y_CC = list()
DPD60P3Y_CD = list()
DPD60P3Y_CV = list()
DPD60P3Y_GL = list()
DPD60P3Y_HL = list()
DPD60P3Y_LAS = list()
DPD60P3Y_MFBL = list()
DPD60P3Y_MFHL = list()
DPD60P3Y_MFOT = list()
DPD60P3Y_OTH = list()
DPD60P3Y_PL = list()
DPD60P3Y_PLBL = list()
DPD60P3Y_RL = list()
DPD60P3Y_SCC = list()
DPD60P3Y_SEL = list()

count_list_AL = list()
count_list_BL = list()
count_list_CC = list()
count_list_CD = list()
count_list_CV = list()
count_list_GL = list()
count_list_HL = list()
count_list_LAS = list()
count_list_MFBL = list()
count_list_MFHL = list()
count_list_MFOT = list()
count_list_OTH = list()
count_list_PL = list()
count_list_PLBL = list()
count_list_RL = list()
count_list_SCC = list()
count_list_SEL = list()

count_AL = 0
count_BL = 0
count_CC = 0
count_CD = 0
count_CV = 0
count_GL = 0
count_HL = 0
count_LAS = 0
count_MFBL = 0
count_MFHL = 0
count_MFOT = 0
count_OTH = 0
count_PL = 0 
count_PLBL = 0
count_RL = 0
count_SCC = 0
count_SEL = 0

grp_df = df.groupby('ID')

for x in range(0, len(unq_id_list)):
    grp_slice = grp_df.get_group(unq_id_list[x])
    #print(grp_slice)
    grp_slice.reset_index(drop=True, inplace=True)
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['accountType'][i]=='unknown'):
            continue
        elif (grp_slice['accountType'][i]=='AL') and (grp_slice['DPD60P3Y_flag'][i]==1):
            count_AL = count_AL + 1
        elif (grp_slice['accountType'][i]=='BL') and (grp_slice['DPD60P3Y_flag'][i]==1):
            count_BL = count_BL + 1
        elif (grp_slice['accountType'][i]=='CC') and (grp_slice['DPD60P3Y_flag'][i]==1):
            count_CC = count_CC + 1
        elif (grp_slice['accountType'][i]=='CD') and (grp_slice['DPD60P3Y_flag'][i]==1):
            count_CD = count_CD + 1
        elif (grp_slice['accountType'][i]=='CV') and (grp_slice['DPD60P3Y_flag'][i]==1):
            count_CV = count_CV + 1
        elif (grp_slice['accountType'][i]=='GL') and (grp_slice['DPD60P3Y_flag'][i]==1):
            count_GL = count_GL + 1
        elif (grp_slice['accountType'][i]=='HL') and (grp_slice['DPD60P3Y_flag'][i]==1):
            count_HL = count_HL + 1
        elif (grp_slice['accountType'][i]=='LAS') and (grp_slice['DPD60P3Y_flag'][i]==1):
            count_LAS = count_LAS + 1
        elif (grp_slice['accountType'][i]=='MFBL') and (grp_slice['DPD60P3Y_flag'][i]==1):
            count_MFBL = count_MFBL + 1
        elif (grp_slice['accountType'][i]=='MFHL') and (grp_slice['DPD60P3Y_flag'][i]==1):
            count_MFHL = count_MFHL + 1
        elif (grp_slice['accountType'][i]=='MFOT') and (grp_slice['DPD60P3Y_flag'][i]==1):
            count_MFOT = count_MFOT + 1
        elif (grp_slice['accountType'][i]=='OTH') and (grp_slice['DPD60P3Y_flag'][i]==1):
            count_OTH = count_OTH + 1
        elif (grp_slice['accountType'][i]=='PL') and (grp_slice['DPD60P3Y_flag'][i]==1):
            count_PL = count_PL + 1
        elif (grp_slice['accountType'][i]=='PLBL') and (grp_slice['DPD60P3Y_flag'][i]==1):
            count_PLBL = count_PLBL + 1
        elif (grp_slice['accountType'][i]=='RL') and (grp_slice['DPD60P3Y_flag'][i]==1):
            count_RL = count_RL + 1
        elif (grp_slice['accountType'][i]=='SCC') and (grp_slice['DPD60P3Y_flag'][i]==1):
            count_SCC = count_SCC + 1
        elif (grp_slice['accountType'][i]=='SEL') and (grp_slice['DPD60P3Y_flag'][i]==1):
            count_SEL = count_SEL + 1
            
    count_list_AL.append(count_AL)
    count_list_BL.append(count_BL)
    count_list_CC.append(count_CC)
    count_list_CD.append(count_CD)
    count_list_CV.append(count_CV)
    count_list_GL.append(count_GL)
    count_list_HL.append(count_HL)
    count_list_LAS.append(count_LAS)
    count_list_MFBL.append(count_MFBL)
    count_list_MFHL.append(count_MFHL)
    count_list_MFOT.append(count_MFOT)
    count_list_OTH.append(count_OTH)
    count_list_PL.append(count_PL)
    count_list_PLBL.append(count_PLBL)
    count_list_RL.append(count_RL)
    count_list_SCC.append(count_SCC)
    count_list_SEL.append(count_SEL)
    
    count_AL = 0
    count_BL = 0
    count_CC = 0
    count_CD = 0
    count_CV = 0
    count_GL = 0
    count_HL = 0
    count_LAS = 0
    count_MFBL = 0
    count_MFHL = 0
    count_MFOT = 0
    count_OTH = 0
    count_PL = 0
    count_PLBL = 0
    count_RL = 0
    count_SCC = 0
    count_SEL = 0
    
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['accountType'][i]=='unknown'):
            DPD60P3Y_AL.append('unknown')
            DPD60P3Y_BL.append('unknown')
            DPD60P3Y_CC.append('unknown')
            DPD60P3Y_CD.append('unknown')
            DPD60P3Y_CV.append('unknown')
            DPD60P3Y_GL.append('unknown')
            DPD60P3Y_HL.append('unknown')
            DPD60P3Y_LAS.append('unknown')
            DPD60P3Y_MFBL.append('unknown')
            DPD60P3Y_MFHL.append('unknown')
            DPD60P3Y_MFOT.append('unknown')
            DPD60P3Y_OTH.append('unknown')
            DPD60P3Y_PL.append('unknown')
            DPD60P3Y_PLBL.append('unknown')
            DPD60P3Y_RL.append('unknown')
            DPD60P3Y_SCC.append('unknown')
            DPD60P3Y_SEL.append('unknown')
        else:
            DPD60P3Y_AL.append(count_list_AL[x])
            DPD60P3Y_BL.append(count_list_BL[x])
            DPD60P3Y_CC.append(count_list_CC[x])
            DPD60P3Y_CD.append(count_list_CD[x])
            DPD60P3Y_CV.append(count_list_CV[x])
            DPD60P3Y_GL.append(count_list_GL[x])
            DPD60P3Y_HL.append(count_list_HL[x])
            DPD60P3Y_LAS.append(count_list_LAS[x])
            DPD60P3Y_MFBL.append(count_list_MFBL[x])
            DPD60P3Y_MFHL.append(count_list_MFHL[x])
            DPD60P3Y_MFOT.append(count_list_MFOT[x])
            DPD60P3Y_OTH.append(count_list_OTH[x])
            DPD60P3Y_PL.append(count_list_PL[x])
            DPD60P3Y_PLBL.append(count_list_PLBL[x])
            DPD60P3Y_RL.append(count_list_RL[x])
            DPD60P3Y_SCC.append(count_list_SCC[x])
            DPD60P3Y_SEL.append(count_list_SEL[x])
            
df['DPD60P3Y_AL'] = pd.Series(DPD60P3Y_AL).values
df['DPD60P3Y_BL'] = pd.Series(DPD60P3Y_BL).values
df['DPD60P3Y_CC'] = pd.Series(DPD60P3Y_CC).values
df['DPD60P3Y_CD'] = pd.Series(DPD60P3Y_CD).values
df['DPD60P3Y_CV'] = pd.Series(DPD60P3Y_CV).values
df['DPD60P3Y_GL'] = pd.Series(DPD60P3Y_GL).values
df['DPD60P3Y_HL'] = pd.Series(DPD60P3Y_HL).values
df['DPD60P3Y_LAS'] = pd.Series(DPD60P3Y_LAS).values
df['DPD60P3Y_MFBL'] = pd.Series(DPD60P3Y_MFBL).values
df['DPD60P3Y_MFHL'] = pd.Series(DPD60P3Y_MFHL).values
df['DPD60P3Y_MFOT'] = pd.Series(DPD60P3Y_MFOT).values
df['DPD60P3Y_OTH'] = pd.Series(DPD60P3Y_OTH).values
df['DPD60P3Y_PL'] = pd.Series(DPD60P3Y_PL).values
df['DPD60P3Y_PLBL'] = pd.Series(DPD60P3Y_PLBL).values
df['DPD60P3Y_RL'] = pd.Series(DPD60P3Y_RL).values
df['DPD60P3Y_SCC'] = pd.Series(DPD60P3Y_SCC).values
df['DPD60P3Y_SEL'] = pd.Series(DPD60P3Y_SEL).values

# %% [raw]
# d = df[['ID','DPD60P3Y_GL','DPD60P3Y_flag','accountType']]
# d[d['DPD60P3Y_flag']!=0].head(60)

# %% [markdown]
# ### Code for DPD90P3Y_P

# %% [markdown]
# - DPD 90 in last 3 year productwise
# - For an applicant, Count of all loans where DPD90P3Y_flag =1 per product

# %%
DPD90P3Y_AL = list()
DPD90P3Y_BL = list()
DPD90P3Y_CC = list()
DPD90P3Y_CD = list()
DPD90P3Y_CV = list()
DPD90P3Y_GL = list()
DPD90P3Y_HL = list()
DPD90P3Y_LAS = list()
DPD90P3Y_MFBL = list()
DPD90P3Y_MFHL = list()
DPD90P3Y_MFOT = list()
DPD90P3Y_OTH = list()
DPD90P3Y_PL = list()
DPD90P3Y_PLBL = list()
DPD90P3Y_RL = list()
DPD90P3Y_SCC = list()
DPD90P3Y_SEL = list()

count_list_AL = list()
count_list_BL = list()
count_list_CC = list()
count_list_CD = list()
count_list_CV = list()
count_list_GL = list()
count_list_HL = list()
count_list_LAS = list()
count_list_MFBL = list()
count_list_MFHL = list()
count_list_MFOT = list()
count_list_OTH = list()
count_list_PL = list()
count_list_PLBL = list()
count_list_RL = list()
count_list_SCC = list()
count_list_SEL = list()

count_AL = 0
count_BL = 0
count_CC = 0
count_CD = 0
count_CV = 0
count_GL = 0
count_HL = 0
count_LAS = 0
count_MFBL = 0
count_MFHL = 0
count_MFOT = 0
count_OTH = 0
count_PL = 0 
count_PLBL = 0
count_RL = 0
count_SCC = 0
count_SEL = 0

grp_df = df.groupby('ID')

for x in range(0, len(unq_id_list)):
    grp_slice = grp_df.get_group(unq_id_list[x])
    #print(grp_slice)
    grp_slice.reset_index(drop=True, inplace=True)
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['accountType'][i]=='unknown'):
            continue
        elif (grp_slice['accountType'][i]=='AL') and (grp_slice['DPD90P3Y_flag'][i]==1):
            count_AL = count_AL + 1
        elif (grp_slice['accountType'][i]=='BL') and (grp_slice['DPD90P3Y_flag'][i]==1):
            count_BL = count_BL + 1
        elif (grp_slice['accountType'][i]=='CC') and (grp_slice['DPD90P3Y_flag'][i]==1):
            count_CC = count_CC + 1
        elif (grp_slice['accountType'][i]=='CD') and (grp_slice['DPD90P3Y_flag'][i]==1):
            count_CD = count_CD + 1
        elif (grp_slice['accountType'][i]=='CV') and (grp_slice['DPD90P3Y_flag'][i]==1):
            count_CV = count_CV + 1
        elif (grp_slice['accountType'][i]=='GL') and (grp_slice['DPD90P3Y_flag'][i]==1):
            count_GL = count_GL + 1
        elif (grp_slice['accountType'][i]=='HL') and (grp_slice['DPD90P3Y_flag'][i]==1):
            count_HL = count_HL + 1
        elif (grp_slice['accountType'][i]=='LAS') and (grp_slice['DPD90P3Y_flag'][i]==1):
            count_LAS = count_LAS + 1
        elif (grp_slice['accountType'][i]=='MFBL') and (grp_slice['DPD90P3Y_flag'][i]==1):
            count_MFBL = count_MFBL + 1
        elif (grp_slice['accountType'][i]=='MFHL') and (grp_slice['DPD90P3Y_flag'][i]==1):
            count_MFHL = count_MFHL + 1
        elif (grp_slice['accountType'][i]=='MFOT') and (grp_slice['DPD90P3Y_flag'][i]==1):
            count_MFOT = count_MFOT + 1
        elif (grp_slice['accountType'][i]=='OTH') and (grp_slice['DPD90P3Y_flag'][i]==1):
            count_OTH = count_OTH + 1
        elif (grp_slice['accountType'][i]=='PL') and (grp_slice['DPD90P3Y_flag'][i]==1):
            count_PL = count_PL + 1
        elif (grp_slice['accountType'][i]=='PLBL') and (grp_slice['DPD90P3Y_flag'][i]==1):
            count_PLBL = count_PLBL + 1
        elif (grp_slice['accountType'][i]=='RL') and (grp_slice['DPD90P3Y_flag'][i]==1):
            count_RL = count_RL + 1
        elif (grp_slice['accountType'][i]=='SCC') and (grp_slice['DPD90P3Y_flag'][i]==1):
            count_SCC = count_SCC + 1
        elif (grp_slice['accountType'][i]=='SEL') and (grp_slice['DPD90P3Y_flag'][i]==1):
            count_SEL = count_SEL + 1
            
    count_list_AL.append(count_AL)
    count_list_BL.append(count_BL)
    count_list_CC.append(count_CC)
    count_list_CD.append(count_CD)
    count_list_CV.append(count_CV)
    count_list_GL.append(count_GL)
    count_list_HL.append(count_HL)
    count_list_LAS.append(count_LAS)
    count_list_MFBL.append(count_MFBL)
    count_list_MFHL.append(count_MFHL)
    count_list_MFOT.append(count_MFOT)
    count_list_OTH.append(count_OTH)
    count_list_PL.append(count_PL)
    count_list_PLBL.append(count_PLBL)
    count_list_RL.append(count_RL)
    count_list_SCC.append(count_SCC)
    count_list_SEL.append(count_SEL)
    
    count_AL = 0
    count_BL = 0
    count_CC = 0
    count_CD = 0
    count_CV = 0
    count_GL = 0
    count_HL = 0
    count_LAS = 0
    count_MFBL = 0
    count_MFHL = 0
    count_MFOT = 0
    count_OTH = 0
    count_PL = 0
    count_PLBL = 0
    count_RL = 0
    count_SCC = 0
    count_SEL = 0
    
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['accountType'][i]=='unknown'):
            DPD90P3Y_AL.append('unknown')
            DPD90P3Y_BL.append('unknown')
            DPD90P3Y_CC.append('unknown')
            DPD90P3Y_CD.append('unknown')
            DPD90P3Y_CV.append('unknown')
            DPD90P3Y_GL.append('unknown')
            DPD90P3Y_HL.append('unknown')
            DPD90P3Y_LAS.append('unknown')
            DPD90P3Y_MFBL.append('unknown')
            DPD90P3Y_MFHL.append('unknown')
            DPD90P3Y_MFOT.append('unknown')
            DPD90P3Y_OTH.append('unknown')
            DPD90P3Y_PL.append('unknown')
            DPD90P3Y_PLBL.append('unknown')
            DPD90P3Y_RL.append('unknown')
            DPD90P3Y_SCC.append('unknown')
            DPD90P3Y_SEL.append('unknown')
        else:
            DPD90P3Y_AL.append(count_list_AL[x])
            DPD90P3Y_BL.append(count_list_BL[x])
            DPD90P3Y_CC.append(count_list_CC[x])
            DPD90P3Y_CD.append(count_list_CD[x])
            DPD90P3Y_CV.append(count_list_CV[x])
            DPD90P3Y_GL.append(count_list_GL[x])
            DPD90P3Y_HL.append(count_list_HL[x])
            DPD90P3Y_LAS.append(count_list_LAS[x])
            DPD90P3Y_MFBL.append(count_list_MFBL[x])
            DPD90P3Y_MFHL.append(count_list_MFHL[x])
            DPD90P3Y_MFOT.append(count_list_MFOT[x])
            DPD90P3Y_OTH.append(count_list_OTH[x])
            DPD90P3Y_PL.append(count_list_PL[x])
            DPD90P3Y_PLBL.append(count_list_PLBL[x])
            DPD90P3Y_RL.append(count_list_RL[x])
            DPD90P3Y_SCC.append(count_list_SCC[x])
            DPD90P3Y_SEL.append(count_list_SEL[x])
            
df['DPD90P3Y_AL'] = pd.Series(DPD90P3Y_AL).values
df['DPD90P3Y_BL'] = pd.Series(DPD90P3Y_BL).values
df['DPD90P3Y_CC'] = pd.Series(DPD90P3Y_CC).values
df['DPD90P3Y_CD'] = pd.Series(DPD90P3Y_CD).values
df['DPD90P3Y_CV'] = pd.Series(DPD90P3Y_CV).values
df['DPD90P3Y_GL'] = pd.Series(DPD90P3Y_GL).values
df['DPD90P3Y_HL'] = pd.Series(DPD90P3Y_HL).values
df['DPD90P3Y_LAS'] = pd.Series(DPD90P3Y_LAS).values
df['DPD90P3Y_MFBL'] = pd.Series(DPD90P3Y_MFBL).values
df['DPD90P3Y_MFHL'] = pd.Series(DPD90P3Y_MFHL).values
df['DPD90P3Y_MFOT'] = pd.Series(DPD90P3Y_MFOT).values
df['DPD90P3Y_OTH'] = pd.Series(DPD90P3Y_OTH).values
df['DPD90P3Y_PL'] = pd.Series(DPD90P3Y_PL).values
df['DPD90P3Y_PLBL'] = pd.Series(DPD90P3Y_PLBL).values
df['DPD90P3Y_RL'] = pd.Series(DPD90P3Y_RL).values
df['DPD90P3Y_SCC'] = pd.Series(DPD90P3Y_SCC).values
df['DPD90P3Y_SEL'] = pd.Series(DPD90P3Y_SEL).values

# %% [raw]
# d = df[['ID','DPD90P3Y_GL','DPD90P3Y_flag','accountType']]
# d[d['DPD90P3Y_flag']!=0].head(60)

# %% [markdown]
# <a id='STD_flags'></a>
# ### Code for STD flags

# %%
std_last1_mon = list()
std_last3_mon_diff = list()
std_last3_mon = list()
std_last6_mon_diff = list()
std_last6_mon = list()
std_last1_yr_diff = list()
std_last1_yr = list()
std_last2_yr_diff = list()
std_last2_yr = list()
std_last3_yr_diff = list()
std_last3_yr = list()
matching = list()


for x in range(0,df.shape[0]):
    if (df['mo_diff_ld_drc'][x]==-1):
        std_last1_mon.append('unknown')
    elif (df['mo_diff_ld_drc'][x]==1) and (df['payHistComp'][x][0]=='STD'):
        std_last1_mon.append(1)
    else:
        std_last1_mon.append(0)
        
    if (df['mo_diff_ld_drc'][x]==-1):
        std_last3_mon_diff.append('unknown')
    elif (df['mo_diff_ld_drc'][x]>1) and (df['mo_diff_ld_drc'][x]<4):
        std_last3_mon_diff.append(1)
    else:
        std_last3_mon_diff.append(0)
    
    if (df['mo_diff_ld_drc'][x]==-1):
        std_last6_mon_diff.append('unknown')
    elif (df['mo_diff_ld_drc'][x]>1) and (df['mo_diff_ld_drc'][x]<7):
        std_last6_mon_diff.append(1)
    else:
        std_last6_mon_diff.append(0)
    
    if (df['mo_diff_ld_drc'][x]==-1):
        std_last1_yr_diff.append('unknown')
    elif (df['mo_diff_ld_drc'][x]>1) and (df['mo_diff_ld_drc'][x]<13):
        std_last1_yr_diff.append(1)
    else:
        std_last1_yr_diff.append(0)

    if (df['mo_diff_ld_drc'][x]==-1):
        std_last2_yr_diff.append('unknown')
    elif (df['mo_diff_ld_drc'][x]>1) and (df['mo_diff_ld_drc'][x]<25):
        std_last2_yr_diff.append(1)
    else:
        std_last2_yr_diff.append(0)

    if (df['mo_diff_ld_drc'][x]==-1):
        std_last3_yr_diff.append('unknown')
    elif (df['mo_diff_ld_drc'][x]>1) and (df['mo_diff_ld_drc'][x]<37):
        std_last3_yr_diff.append(1)
    else:
        std_last3_yr_diff.append(0)
              
df['std_last3_mon_diff'] = pd.Series(std_last3_mon_diff).values
df['std_last6_mon_diff'] = pd.Series(std_last6_mon_diff).values
df['std_last1_yr_diff'] = pd.Series(std_last1_yr_diff).values
df['std_last2_yr_diff'] = pd.Series(std_last2_yr_diff).values
df['std_last3_yr_diff'] = pd.Series(std_last3_yr_diff).values

for x in range(0, df.shape[0]):
    if (df['std_last3_mon_diff'][x]=='unknown'):
        std_last3_mon.append('unknown')
    elif (df['std_last3_mon_diff'][x]==1):
        for i in range(0, 3-df['mo_diff_ld_drc'][x]):
            #print(i)
            matching.append(df['payHistComp'][x][i])
        if any('STD' in s for s in matching):
            std_last3_mon.append(1)
        else:
            std_last3_mon.append(0)
        #print(matching)    
        matching = list()
    else:
        std_last3_mon.append(0)

    if (df['std_last6_mon_diff'][x]=='unknown'):
        std_last6_mon.append('unknown')
    elif (df['std_last6_mon_diff'][x]==1):
        for i in range(0, 6-df['mo_diff_ld_drc'][x]):
            #print(i)
            matching.append(df['payHistComp'][x][i])
        if any('STD' in s for s in matching):
            std_last6_mon.append(1)
        else:
            std_last6_mon.append(0)
        #print(matching)    
        matching = list()
    else:
        std_last6_mon.append(0)

    if (df['std_last1_yr_diff'][x]=='unknown'):
        std_last1_yr.append('unknown')
    elif (df['std_last1_yr_diff'][x]==1) and (len(df['payHistComp'][x])>=12):
        for i in range(0, 12-df['mo_diff_ld_drc'][x]):
            #print(i)
            matching.append(df['payHistComp'][x][i])
        if any('STD' in s for s in matching):
            std_last1_yr.append(1)
        else:
            std_last1_yr.append(0)
        #print(matching)    
        matching = list()
    else:
        std_last1_yr.append(0)
    
    if (df['std_last2_yr_diff'][x]=='unknown'):
        std_last2_yr.append('unknown')
    elif (df['std_last2_yr_diff'][x]==1) and (len(df['payHistComp'][x])>=24):
        for i in range(0, 24-df['mo_diff_ld_drc'][x]):
            #print(i)
            matching.append(df['payHistComp'][x][i])
        if any('STD' in s for s in matching):
            std_last2_yr.append(1)
        else:
            std_last2_yr.append(0)
        #print(matching)    
        matching = list()
    else:
        std_last2_yr.append(0)
    
    if (df['std_last3_yr_diff'][x]=='unknown'):
        std_last3_yr.append('unknown')
    elif (df['std_last3_yr_diff'][x]==1) and (len(df['payHistComp'][x])==36):
        for i in range(0, 36-df['mo_diff_ld_drc'][x]):
            #print(i)
            matching.append(df['payHistComp'][x][i])
        if any('STD' in s for s in matching):
            std_last3_yr.append(1)
        else:
            std_last3_yr.append(0)
        #print(matching)    
        matching = list()
    else:
        std_last3_yr.append(0)

df['STD1M_flag'] = pd.Series(std_last1_mon).values
#print(df['STD1M_flag'].value_counts()) 

df['STD3M_flag'] = pd.Series(std_last3_mon).values
#print(df['STD3M_flag'].value_counts())
   
df['STD6M_flag'] = pd.Series(std_last6_mon).values
#print(df['STD6M_flag'].value_counts())
   
df['STD1Y_flag'] = pd.Series(std_last1_yr).values
#print(df['STD1Y_flag'].value_counts())
   
df['STD2Y_flag'] = pd.Series(std_last2_yr).values
#print(df['STD2Y_flag'].value_counts())

df['STD3Y_flag'] = pd.Series(std_last3_yr).values
#print(df['STD3Y_flag'].value_counts())

# %% [raw]
# piece = list()
#
# std_last1_mon = list()
# std_last3_mon = list()
# std_last6_mon = list()
# std_last1_yr = list()
# std_last2_yr = list()
# std_last3_yr = list()
#
# count = 0
#
# for value in df['paymentHistComp'].astype('str'):
#     #print(value)
#
#     chunks, chunk_size = len(value), 3
#     for i in range(0, chunks, chunk_size):
#         piece.append(value[i:i+chunk_size])
#     #print(piece)
#     #print(len(piece))
#
#     if ('STD' in piece[0]):
#         #print(piece)
#         for x in piece:
#             if x == 'STD':
#                 count = count + 1
#                 #print(count)
#             else:
#                 break
#         if count >= 1:
#             #print('1mo')
#             std_last1_mon.append(1)
#             if count >= 3:
#                 #print('3mo')
#                 std_last3_mon.append(1)
#                 if count >= 6:
#                     #print('6mo')
#                     std_last6_mon.append(1)
#                     if count >= 12:
#                         #print('1yr')
#                         std_last1_yr.append(1)
#                         if count >= 24:
#                             #print('2yr')
#                             std_last2_yr.append(1)
#                             if count >= 36:
#                                 #print('3yr')
#                                 std_last3_yr.append(1)
#                             else:
#                                 std_last3_yr.append(0)
#                         else:
#                             std_last2_yr.append(0)
#                             std_last3_yr.append(0)
#                     else:
#                         std_last1_yr.append(0)
#                         std_last2_yr.append(0)
#                         std_last3_yr.append(0)
#                 else:
#                     std_last6_mon.append(0)
#                     std_last1_yr.append(0)
#                     std_last2_yr.append(0)
#                     std_last3_yr.append(0)
#             else:
#                 std_last3_mon.append(0)
#                 std_last6_mon.append(0)
#                 std_last1_yr.append(0)
#                 std_last2_yr.append(0)
#                 std_last3_yr.append(0)
#         else:
#             std_last1_mon.append(0)
#             std_last3_mon.append(0)
#             std_last6_mon.append(0)
#             std_last1_yr.append(0)
#             std_last2_yr.append(0)
#             std_last3_yr.append(0)
#     else:
#         std_last1_mon.append(0)
#         std_last3_mon.append(0)
#         std_last6_mon.append(0)
#         std_last1_yr.append(0)
#         std_last2_yr.append(0)
#         std_last3_yr.append(0)
#
#     count = 0
#     piece = list()
#
# df['STD1M_flag'] = pd.Series(std_last1_mon).values
# df['STD3M_flag'] = pd.Series(std_last3_mon).values
# df['STD6M_flag'] = pd.Series(std_last6_mon).values
# df['STD1Y_flag'] = pd.Series(std_last1_yr).values
# df['STD2Y_flag'] = pd.Series(std_last2_yr).values
# df['STD3Y_flag'] = pd.Series(std_last3_yr).values

# %% [markdown]
# <a id='STD_num'></a>
# ### Code for STD (Numerical)

# %% [markdown]
# - For an applicant, Count of all loans where STD1M_flag =1
# - For an applicant, Count of all loans where STD3M_flag =1
# - For an applicant, Count of all loans where STD6M_flag =1
# - For an applicant, Count of all loans where STD1Y_flag =1
# - For an applicant, Count of all loans where STD2Y_flag =1
# - For an applicant, Count of all loans where STD3Y_flag =1

# %%
STD1M = list()
count_list_1m = list()
count_1m = 0

STD3M = list()
count_list_3m = list()
count_3m = 0

STD6M = list()
count_list_6m = list()
count_6m = 0

STD1Y = list()
count_list_1y = list()
count_1y = 0

STD2Y = list()
count_list_2y = list()
count_2y = 0

STD3Y = list()
count_list_3y = list()
count_3y = 0

grp_df = df.groupby('ID')

for x in range(0, len(unq_id_list)):
    grp_slice = grp_df.get_group(unq_id_list[x])
    #print(grp_slice)
    grp_slice.reset_index(drop=True, inplace=True)
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['STD1M_flag'][i]==1) or (grp_slice['STD1M_flag'][i]==0):
            count_1m = count_1m + grp_slice['STD1M_flag'][i]
        
        if (grp_slice['STD3M_flag'][i]==1) or (grp_slice['STD3M_flag'][i]==0):
            count_3m = count_3m + grp_slice['STD3M_flag'][i]

        if (grp_slice['STD6M_flag'][i]==1) or (grp_slice['STD6M_flag'][i]==0):
            count_6m = count_6m + grp_slice['STD6M_flag'][i]

        if (grp_slice['STD1Y_flag'][i]==1) or (grp_slice['STD1Y_flag'][i]==0):
            count_1y = count_1y + grp_slice['STD1Y_flag'][i]

        if (grp_slice['STD2Y_flag'][i]==1) or (grp_slice['STD2Y_flag'][i]==0):
            count_2y = count_2y + grp_slice['STD2Y_flag'][i]

        if (grp_slice['STD3Y_flag'][i]==1) or (grp_slice['STD3Y_flag'][i]==0):
            count_3y = count_3y + grp_slice['STD3Y_flag'][i]


    count_list_1m.append(count_1m)
    count_1m = 0
    count_list_3m.append(count_3m)
    count_3m = 0
    count_list_6m.append(count_6m)
    count_6m = 0
    count_list_1y.append(count_1y)
    count_1y = 0
    count_list_2y.append(count_2y)
    count_2y = 0
    count_list_3y.append(count_3y)
    count_3y = 0

    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['STD1M_flag'][i]==1) or (grp_slice['STD1M_flag'][i]==0):
            STD1M.append(count_list_1m[x])
        else:
            STD1M.append('unknown')

        if (grp_slice['STD3M_flag'][i]==1) or (grp_slice['STD3M_flag'][i]==0):
            STD3M.append(count_list_3m[x])
        else:
            STD3M.append('unknown')
        
        if (grp_slice['STD6M_flag'][i]==1) or (grp_slice['STD6M_flag'][i]==0):
            STD6M.append(count_list_6m[x])
        else:
            STD6M.append('unknown')

        if (grp_slice['STD1Y_flag'][i]==1) or (grp_slice['STD1Y_flag'][i]==0):
            STD1Y.append(count_list_1y[x])
        else:
            STD1Y.append('unknown')

        if (grp_slice['STD2Y_flag'][i]==1) or (grp_slice['STD2Y_flag'][i]==0):
            STD2Y.append(count_list_2y[x])
        else:
            STD2Y.append('unknown')
        
        if (grp_slice['STD3Y_flag'][i]==1) or (grp_slice['STD3Y_flag'][i]==0):
            STD3Y.append(count_list_3y[x])
        else:
            STD3Y.append('unknown')
            
df['STD1M'] = pd.Series(STD1M).values
df['STD3M'] = pd.Series(STD3M).values
df['STD6M'] = pd.Series(STD6M).values
df['STD1Y'] = pd.Series(STD1Y).values
df['STD2Y'] = pd.Series(STD2Y).values
df['STD3Y'] = pd.Series(STD3Y).values
#print(df['STD3Y'].value_counts())

# %% [markdown]
# ### Code for STD1M_P

# %% [markdown]
# - STD in last 1 month productwise
# - For an applicant, Count of all loans where STD1M_flag =1 per product

# %%
STD1M_AL = list()
STD1M_BL = list()
STD1M_CC = list()
STD1M_CD = list()
STD1M_CV = list()
STD1M_GL = list()
STD1M_HL = list()
STD1M_LAS = list()
STD1M_MFBL = list()
STD1M_MFHL = list()
STD1M_MFOT = list()
STD1M_OTH = list()
STD1M_PL = list()
STD1M_PLBL = list()
STD1M_RL = list()
STD1M_SCC = list()
STD1M_SEL = list()

count_list_AL = list()
count_list_BL = list()
count_list_CC = list()
count_list_CD = list()
count_list_CV = list()
count_list_GL = list()
count_list_HL = list()
count_list_LAS = list()
count_list_MFBL = list()
count_list_MFHL = list()
count_list_MFOT = list()
count_list_OTH = list()
count_list_PL = list()
count_list_PLBL = list()
count_list_RL = list()
count_list_SCC = list()
count_list_SEL = list()

count_AL = 0
count_BL = 0
count_CC = 0
count_CD = 0
count_CV = 0
count_GL = 0
count_HL = 0
count_LAS = 0
count_MFBL = 0
count_MFHL = 0
count_MFOT = 0
count_OTH = 0
count_PL = 0 
count_PLBL = 0
count_RL = 0
count_SCC = 0
count_SEL = 0

grp_df = df.groupby('ID')

for x in range(0, len(unq_id_list)):
    grp_slice = grp_df.get_group(unq_id_list[x])
    #print(grp_slice)
    grp_slice.reset_index(drop=True, inplace=True)
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['accountType'][i]=='unknown'):
            continue
        elif (grp_slice['accountType'][i]=='AL') and (grp_slice['STD1M_flag'][i]==1):
            count_AL = count_AL + 1
        elif (grp_slice['accountType'][i]=='BL') and (grp_slice['STD1M_flag'][i]==1):
            count_BL = count_BL + 1
        elif (grp_slice['accountType'][i]=='CC') and (grp_slice['STD1M_flag'][i]==1):
            count_CC = count_CC + 1
        elif (grp_slice['accountType'][i]=='CD') and (grp_slice['STD1M_flag'][i]==1):
            count_CD = count_CD + 1
        elif (grp_slice['accountType'][i]=='CV') and (grp_slice['STD1M_flag'][i]==1):
            count_CV = count_CV + 1
        elif (grp_slice['accountType'][i]=='GL') and (grp_slice['STD1M_flag'][i]==1):
            count_GL = count_GL + 1
        elif (grp_slice['accountType'][i]=='HL') and (grp_slice['STD1M_flag'][i]==1):
            count_HL = count_HL + 1
        elif (grp_slice['accountType'][i]=='LAS') and (grp_slice['STD1M_flag'][i]==1):
            count_LAS = count_LAS + 1
        elif (grp_slice['accountType'][i]=='MFBL') and (grp_slice['STD1M_flag'][i]==1):
            count_MFBL = count_MFBL + 1
        elif (grp_slice['accountType'][i]=='MFHL') and (grp_slice['STD1M_flag'][i]==1):
            count_MFHL = count_MFHL + 1
        elif (grp_slice['accountType'][i]=='MFOT') and (grp_slice['STD1M_flag'][i]==1):
            count_MFOT = count_MFOT + 1
        elif (grp_slice['accountType'][i]=='OTH') and (grp_slice['STD1M_flag'][i]==1):
            count_OTH = count_OTH + 1
        elif (grp_slice['accountType'][i]=='PL') and (grp_slice['STD1M_flag'][i]==1):
            count_PL = count_PL + 1
        elif (grp_slice['accountType'][i]=='PLBL') and (grp_slice['STD1M_flag'][i]==1):
            count_PLBL = count_PLBL + 1
        elif (grp_slice['accountType'][i]=='RL') and (grp_slice['STD1M_flag'][i]==1):
            count_RL = count_RL + 1
        elif (grp_slice['accountType'][i]=='SCC') and (grp_slice['STD1M_flag'][i]==1):
            count_SCC = count_SCC + 1
        elif (grp_slice['accountType'][i]=='SEL') and (grp_slice['STD1M_flag'][i]==1):
            count_SEL = count_SEL + 1
            
    count_list_AL.append(count_AL)
    count_list_BL.append(count_BL)
    count_list_CC.append(count_CC)
    count_list_CD.append(count_CD)
    count_list_CV.append(count_CV)
    count_list_GL.append(count_GL)
    count_list_HL.append(count_HL)
    count_list_LAS.append(count_LAS)
    count_list_MFBL.append(count_MFBL)
    count_list_MFHL.append(count_MFHL)
    count_list_MFOT.append(count_MFOT)
    count_list_OTH.append(count_OTH)
    count_list_PL.append(count_PL)
    count_list_PLBL.append(count_PLBL)
    count_list_RL.append(count_RL)
    count_list_SCC.append(count_SCC)
    count_list_SEL.append(count_SEL)
    
    count_AL = 0
    count_BL = 0
    count_CC = 0
    count_CD = 0
    count_CV = 0
    count_GL = 0
    count_HL = 0
    count_LAS = 0
    count_MFBL = 0
    count_MFHL = 0
    count_MFOT = 0
    count_OTH = 0
    count_PL = 0
    count_PLBL = 0
    count_RL = 0
    count_SCC = 0
    count_SEL = 0
    
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['accountType'][i]=='unknown'):
            STD1M_AL.append('unknown')
            STD1M_BL.append('unknown')
            STD1M_CC.append('unknown')
            STD1M_CD.append('unknown')
            STD1M_CV.append('unknown')
            STD1M_GL.append('unknown')
            STD1M_HL.append('unknown')
            STD1M_LAS.append('unknown')
            STD1M_MFBL.append('unknown')
            STD1M_MFHL.append('unknown')
            STD1M_MFOT.append('unknown')
            STD1M_OTH.append('unknown')
            STD1M_PL.append('unknown')
            STD1M_PLBL.append('unknown')
            STD1M_RL.append('unknown')
            STD1M_SCC.append('unknown')
            STD1M_SEL.append('unknown')
        else:
            STD1M_AL.append(count_list_AL[x])
            STD1M_BL.append(count_list_BL[x])
            STD1M_CC.append(count_list_CC[x])
            STD1M_CD.append(count_list_CD[x])
            STD1M_CV.append(count_list_CV[x])
            STD1M_GL.append(count_list_GL[x])
            STD1M_HL.append(count_list_HL[x])
            STD1M_LAS.append(count_list_LAS[x])
            STD1M_MFBL.append(count_list_MFBL[x])
            STD1M_MFHL.append(count_list_MFHL[x])
            STD1M_MFOT.append(count_list_MFOT[x])
            STD1M_OTH.append(count_list_OTH[x])
            STD1M_PL.append(count_list_PL[x])
            STD1M_PLBL.append(count_list_PLBL[x])
            STD1M_RL.append(count_list_RL[x])
            STD1M_SCC.append(count_list_SCC[x])
            STD1M_SEL.append(count_list_SEL[x])
            
df['STD1M_AL'] = pd.Series(STD1M_AL).values
df['STD1M_BL'] = pd.Series(STD1M_BL).values
df['STD1M_CC'] = pd.Series(STD1M_CC).values
df['STD1M_CD'] = pd.Series(STD1M_CD).values
df['STD1M_CV'] = pd.Series(STD1M_CV).values
df['STD1M_GL'] = pd.Series(STD1M_GL).values
df['STD1M_HL'] = pd.Series(STD1M_HL).values
df['STD1M_LAS'] = pd.Series(STD1M_LAS).values
df['STD1M_MFBL'] = pd.Series(STD1M_MFBL).values
df['STD1M_MFHL'] = pd.Series(STD1M_MFHL).values
df['STD1M_MFOT'] = pd.Series(STD1M_MFOT).values
df['STD1M_OTH'] = pd.Series(STD1M_OTH).values
df['STD1M_PL'] = pd.Series(STD1M_PL).values
df['STD1M_PLBL'] = pd.Series(STD1M_PLBL).values
df['STD1M_RL'] = pd.Series(STD1M_RL).values
df['STD1M_SCC'] = pd.Series(STD1M_SCC).values
df['STD1M_SEL'] = pd.Series(STD1M_SEL).values

# %% [raw]
# d = df[['ID','STD1M_GL','STD1M_flag','accountType']]
# d[d['STD1M_flag']!=0].head(60)

# %% [markdown]
# ### Code for STD3M_P

# %% [markdown]
# - STD in last 3 month productwise

# %%
STD3M_AL = list()
STD3M_BL = list()
STD3M_CC = list()
STD3M_CD = list()
STD3M_CV = list()
STD3M_GL = list()
STD3M_HL = list()
STD3M_LAS = list()
STD3M_MFBL = list()
STD3M_MFHL = list()
STD3M_MFOT = list()
STD3M_OTH = list()
STD3M_PL = list()
STD3M_PLBL = list()
STD3M_RL = list()
STD3M_SCC = list()
STD3M_SEL = list()

count_list_AL = list()
count_list_BL = list()
count_list_CC = list()
count_list_CD = list()
count_list_CV = list()
count_list_GL = list()
count_list_HL = list()
count_list_LAS = list()
count_list_MFBL = list()
count_list_MFHL = list()
count_list_MFOT = list()
count_list_OTH = list()
count_list_PL = list()
count_list_PLBL = list()
count_list_RL = list()
count_list_SCC = list()
count_list_SEL = list()

count_AL = 0
count_BL = 0
count_CC = 0
count_CD = 0
count_CV = 0
count_GL = 0
count_HL = 0
count_LAS = 0
count_MFBL = 0
count_MFHL = 0
count_MFOT = 0
count_OTH = 0
count_PL = 0 
count_PLBL = 0
count_RL = 0
count_SCC = 0
count_SEL = 0

grp_df = df.groupby('ID')

for x in range(0, len(unq_id_list)):
    grp_slice = grp_df.get_group(unq_id_list[x])
    #print(grp_slice)
    grp_slice.reset_index(drop=True, inplace=True)
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['accountType'][i]=='unknown'):
            continue
        elif (grp_slice['accountType'][i]=='AL') and (grp_slice['STD3M_flag'][i]==1):
            count_AL = count_AL + 1
        elif (grp_slice['accountType'][i]=='BL') and (grp_slice['STD3M_flag'][i]==1):
            count_BL = count_BL + 1
        elif (grp_slice['accountType'][i]=='CC') and (grp_slice['STD3M_flag'][i]==1):
            count_CC = count_CC + 1
        elif (grp_slice['accountType'][i]=='CD') and (grp_slice['STD3M_flag'][i]==1):
            count_CD = count_CD + 1
        elif (grp_slice['accountType'][i]=='CV') and (grp_slice['STD3M_flag'][i]==1):
            count_CV = count_CV + 1
        elif (grp_slice['accountType'][i]=='GL') and (grp_slice['STD3M_flag'][i]==1):
            count_GL = count_GL + 1
        elif (grp_slice['accountType'][i]=='HL') and (grp_slice['STD3M_flag'][i]==1):
            count_HL = count_HL + 1
        elif (grp_slice['accountType'][i]=='LAS') and (grp_slice['STD3M_flag'][i]==1):
            count_LAS = count_LAS + 1
        elif (grp_slice['accountType'][i]=='MFBL') and (grp_slice['STD3M_flag'][i]==1):
            count_MFBL = count_MFBL + 1
        elif (grp_slice['accountType'][i]=='MFHL') and (grp_slice['STD3M_flag'][i]==1):
            count_MFHL = count_MFHL + 1
        elif (grp_slice['accountType'][i]=='MFOT') and (grp_slice['STD3M_flag'][i]==1):
            count_MFOT = count_MFOT + 1
        elif (grp_slice['accountType'][i]=='OTH') and (grp_slice['STD3M_flag'][i]==1):
            count_OTH = count_OTH + 1
        elif (grp_slice['accountType'][i]=='PL') and (grp_slice['STD3M_flag'][i]==1):
            count_PL = count_PL + 1
        elif (grp_slice['accountType'][i]=='PLBL') and (grp_slice['STD3M_flag'][i]==1):
            count_PLBL = count_PLBL + 1
        elif (grp_slice['accountType'][i]=='RL') and (grp_slice['STD3M_flag'][i]==1):
            count_RL = count_RL + 1
        elif (grp_slice['accountType'][i]=='SCC') and (grp_slice['STD3M_flag'][i]==1):
            count_SCC = count_SCC + 1
        elif (grp_slice['accountType'][i]=='SEL') and (grp_slice['STD3M_flag'][i]==1):
            count_SEL = count_SEL + 1
            
    count_list_AL.append(count_AL)
    count_list_BL.append(count_BL)
    count_list_CC.append(count_CC)
    count_list_CD.append(count_CD)
    count_list_CV.append(count_CV)
    count_list_GL.append(count_GL)
    count_list_HL.append(count_HL)
    count_list_LAS.append(count_LAS)
    count_list_MFBL.append(count_MFBL)
    count_list_MFHL.append(count_MFHL)
    count_list_MFOT.append(count_MFOT)
    count_list_OTH.append(count_OTH)
    count_list_PL.append(count_PL)
    count_list_PLBL.append(count_PLBL)
    count_list_RL.append(count_RL)
    count_list_SCC.append(count_SCC)
    count_list_SEL.append(count_SEL)
    
    count_AL = 0
    count_BL = 0
    count_CC = 0
    count_CD = 0
    count_CV = 0
    count_GL = 0
    count_HL = 0
    count_LAS = 0
    count_MFBL = 0
    count_MFHL = 0
    count_MFOT = 0
    count_OTH = 0
    count_PL = 0
    count_PLBL = 0
    count_RL = 0
    count_SCC = 0
    count_SEL = 0
    
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['accountType'][i]=='unknown'):
            STD3M_AL.append('unknown')
            STD3M_BL.append('unknown')
            STD3M_CC.append('unknown')
            STD3M_CD.append('unknown')
            STD3M_CV.append('unknown')
            STD3M_GL.append('unknown')
            STD3M_HL.append('unknown')
            STD3M_LAS.append('unknown')
            STD3M_MFBL.append('unknown')
            STD3M_MFHL.append('unknown')
            STD3M_MFOT.append('unknown')
            STD3M_OTH.append('unknown')
            STD3M_PL.append('unknown')
            STD3M_PLBL.append('unknown')
            STD3M_RL.append('unknown')
            STD3M_SCC.append('unknown')
            STD3M_SEL.append('unknown')
        else:
            STD3M_AL.append(count_list_AL[x])
            STD3M_BL.append(count_list_BL[x])
            STD3M_CC.append(count_list_CC[x])
            STD3M_CD.append(count_list_CD[x])
            STD3M_CV.append(count_list_CV[x])
            STD3M_GL.append(count_list_GL[x])
            STD3M_HL.append(count_list_HL[x])
            STD3M_LAS.append(count_list_LAS[x])
            STD3M_MFBL.append(count_list_MFBL[x])
            STD3M_MFHL.append(count_list_MFHL[x])
            STD3M_MFOT.append(count_list_MFOT[x])
            STD3M_OTH.append(count_list_OTH[x])
            STD3M_PL.append(count_list_PL[x])
            STD3M_PLBL.append(count_list_PLBL[x])
            STD3M_RL.append(count_list_RL[x])
            STD3M_SCC.append(count_list_SCC[x])
            STD3M_SEL.append(count_list_SEL[x])
            
df['STD3M_AL'] = pd.Series(STD3M_AL).values
df['STD3M_BL'] = pd.Series(STD3M_BL).values
df['STD3M_CC'] = pd.Series(STD3M_CC).values
df['STD3M_CD'] = pd.Series(STD3M_CD).values
df['STD3M_CV'] = pd.Series(STD3M_CV).values
df['STD3M_GL'] = pd.Series(STD3M_GL).values
df['STD3M_HL'] = pd.Series(STD3M_HL).values
df['STD3M_LAS'] = pd.Series(STD3M_LAS).values
df['STD3M_MFBL'] = pd.Series(STD3M_MFBL).values
df['STD3M_MFHL'] = pd.Series(STD3M_MFHL).values
df['STD3M_MFOT'] = pd.Series(STD3M_MFOT).values
df['STD3M_OTH'] = pd.Series(STD3M_OTH).values
df['STD3M_PL'] = pd.Series(STD3M_PL).values
df['STD3M_PLBL'] = pd.Series(STD3M_PLBL).values
df['STD3M_RL'] = pd.Series(STD3M_RL).values
df['STD3M_SCC'] = pd.Series(STD3M_SCC).values
df['STD3M_SEL'] = pd.Series(STD3M_SEL).values

# %% [raw]
# d = df[['ID','STD3M_GL','STD3M_flag','accountType']]
# d[d['STD3M_flag']!=0].head(60)

# %% [markdown]
# ### Code for STD6M_P
# - STD in last 6 month productwise

# %%
STD6M_AL = list()
STD6M_BL = list()
STD6M_CC = list()
STD6M_CD = list()
STD6M_CV = list()
STD6M_GL = list()
STD6M_HL = list()
STD6M_LAS = list()
STD6M_MFBL = list()
STD6M_MFHL = list()
STD6M_MFOT = list()
STD6M_OTH = list()
STD6M_PL = list()
STD6M_PLBL = list()
STD6M_RL = list()
STD6M_SCC = list()
STD6M_SEL = list()

count_list_AL = list()
count_list_BL = list()
count_list_CC = list()
count_list_CD = list()
count_list_CV = list()
count_list_GL = list()
count_list_HL = list()
count_list_LAS = list()
count_list_MFBL = list()
count_list_MFHL = list()
count_list_MFOT = list()
count_list_OTH = list()
count_list_PL = list()
count_list_PLBL = list()
count_list_RL = list()
count_list_SCC = list()
count_list_SEL = list()

count_AL = 0
count_BL = 0
count_CC = 0
count_CD = 0
count_CV = 0
count_GL = 0
count_HL = 0
count_LAS = 0
count_MFBL = 0
count_MFHL = 0
count_MFOT = 0
count_OTH = 0
count_PL = 0 
count_PLBL = 0
count_RL = 0
count_SCC = 0
count_SEL = 0

grp_df = df.groupby('ID')

for x in range(0, len(unq_id_list)):
    grp_slice = grp_df.get_group(unq_id_list[x])
    #print(grp_slice)
    grp_slice.reset_index(drop=True, inplace=True)
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['accountType'][i]=='unknown'):
            continue
        elif (grp_slice['accountType'][i]=='AL') and (grp_slice['STD6M_flag'][i]==1):
            count_AL = count_AL + 1
        elif (grp_slice['accountType'][i]=='BL') and (grp_slice['STD6M_flag'][i]==1):
            count_BL = count_BL + 1
        elif (grp_slice['accountType'][i]=='CC') and (grp_slice['STD6M_flag'][i]==1):
            count_CC = count_CC + 1
        elif (grp_slice['accountType'][i]=='CD') and (grp_slice['STD6M_flag'][i]==1):
            count_CD = count_CD + 1
        elif (grp_slice['accountType'][i]=='CV') and (grp_slice['STD6M_flag'][i]==1):
            count_CV = count_CV + 1
        elif (grp_slice['accountType'][i]=='GL') and (grp_slice['STD6M_flag'][i]==1):
            count_GL = count_GL + 1
        elif (grp_slice['accountType'][i]=='HL') and (grp_slice['STD6M_flag'][i]==1):
            count_HL = count_HL + 1
        elif (grp_slice['accountType'][i]=='LAS') and (grp_slice['STD6M_flag'][i]==1):
            count_LAS = count_LAS + 1
        elif (grp_slice['accountType'][i]=='MFBL') and (grp_slice['STD6M_flag'][i]==1):
            count_MFBL = count_MFBL + 1
        elif (grp_slice['accountType'][i]=='MFHL') and (grp_slice['STD6M_flag'][i]==1):
            count_MFHL = count_MFHL + 1
        elif (grp_slice['accountType'][i]=='MFOT') and (grp_slice['STD6M_flag'][i]==1):
            count_MFOT = count_MFOT + 1
        elif (grp_slice['accountType'][i]=='OTH') and (grp_slice['STD6M_flag'][i]==1):
            count_OTH = count_OTH + 1
        elif (grp_slice['accountType'][i]=='PL') and (grp_slice['STD6M_flag'][i]==1):
            count_PL = count_PL + 1
        elif (grp_slice['accountType'][i]=='PLBL') and (grp_slice['STD6M_flag'][i]==1):
            count_PLBL = count_PLBL + 1
        elif (grp_slice['accountType'][i]=='RL') and (grp_slice['STD6M_flag'][i]==1):
            count_RL = count_RL + 1
        elif (grp_slice['accountType'][i]=='SCC') and (grp_slice['STD6M_flag'][i]==1):
            count_SCC = count_SCC + 1
        elif (grp_slice['accountType'][i]=='SEL') and (grp_slice['STD6M_flag'][i]==1):
            count_SEL = count_SEL + 1
            
    count_list_AL.append(count_AL)
    count_list_BL.append(count_BL)
    count_list_CC.append(count_CC)
    count_list_CD.append(count_CD)
    count_list_CV.append(count_CV)
    count_list_GL.append(count_GL)
    count_list_HL.append(count_HL)
    count_list_LAS.append(count_LAS)
    count_list_MFBL.append(count_MFBL)
    count_list_MFHL.append(count_MFHL)
    count_list_MFOT.append(count_MFOT)
    count_list_OTH.append(count_OTH)
    count_list_PL.append(count_PL)
    count_list_PLBL.append(count_PLBL)
    count_list_RL.append(count_RL)
    count_list_SCC.append(count_SCC)
    count_list_SEL.append(count_SEL)
    
    count_AL = 0
    count_BL = 0
    count_CC = 0
    count_CD = 0
    count_CV = 0
    count_GL = 0
    count_HL = 0
    count_LAS = 0
    count_MFBL = 0
    count_MFHL = 0
    count_MFOT = 0
    count_OTH = 0
    count_PL = 0
    count_PLBL = 0
    count_RL = 0
    count_SCC = 0
    count_SEL = 0
    
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['accountType'][i]=='unknown'):
            STD6M_AL.append('unknown')
            STD6M_BL.append('unknown')
            STD6M_CC.append('unknown')
            STD6M_CD.append('unknown')
            STD6M_CV.append('unknown')
            STD6M_GL.append('unknown')
            STD6M_HL.append('unknown')
            STD6M_LAS.append('unknown')
            STD6M_MFBL.append('unknown')
            STD6M_MFHL.append('unknown')
            STD6M_MFOT.append('unknown')
            STD6M_OTH.append('unknown')
            STD6M_PL.append('unknown')
            STD6M_PLBL.append('unknown')
            STD6M_RL.append('unknown')
            STD6M_SCC.append('unknown')
            STD6M_SEL.append('unknown')
        else:
            STD6M_AL.append(count_list_AL[x])
            STD6M_BL.append(count_list_BL[x])
            STD6M_CC.append(count_list_CC[x])
            STD6M_CD.append(count_list_CD[x])
            STD6M_CV.append(count_list_CV[x])
            STD6M_GL.append(count_list_GL[x])
            STD6M_HL.append(count_list_HL[x])
            STD6M_LAS.append(count_list_LAS[x])
            STD6M_MFBL.append(count_list_MFBL[x])
            STD6M_MFHL.append(count_list_MFHL[x])
            STD6M_MFOT.append(count_list_MFOT[x])
            STD6M_OTH.append(count_list_OTH[x])
            STD6M_PL.append(count_list_PL[x])
            STD6M_PLBL.append(count_list_PLBL[x])
            STD6M_RL.append(count_list_RL[x])
            STD6M_SCC.append(count_list_SCC[x])
            STD6M_SEL.append(count_list_SEL[x])
            
df['STD6M_AL'] = pd.Series(STD6M_AL).values
df['STD6M_BL'] = pd.Series(STD6M_BL).values
df['STD6M_CC'] = pd.Series(STD6M_CC).values
df['STD6M_CD'] = pd.Series(STD6M_CD).values
df['STD6M_CV'] = pd.Series(STD6M_CV).values
df['STD6M_GL'] = pd.Series(STD6M_GL).values
df['STD6M_HL'] = pd.Series(STD6M_HL).values
df['STD6M_LAS'] = pd.Series(STD6M_LAS).values
df['STD6M_MFBL'] = pd.Series(STD6M_MFBL).values
df['STD6M_MFHL'] = pd.Series(STD6M_MFHL).values
df['STD6M_MFOT'] = pd.Series(STD6M_MFOT).values
df['STD6M_OTH'] = pd.Series(STD6M_OTH).values
df['STD6M_PL'] = pd.Series(STD6M_PL).values
df['STD6M_PLBL'] = pd.Series(STD6M_PLBL).values
df['STD6M_RL'] = pd.Series(STD6M_RL).values
df['STD6M_SCC'] = pd.Series(STD6M_SCC).values
df['STD6M_SEL'] = pd.Series(STD6M_SEL).values

# %% [raw]
# d = df[['ID','STD6M_GL','STD6M_flag','accountType']]
# d[d['STD6M_flag']!=0].head(60)

# %% [markdown]
# ### Code for STD1Y_P
# - STD in last 1 year productwise

# %%
STD1Y_AL = list()
STD1Y_BL = list()
STD1Y_CC = list()
STD1Y_CD = list()
STD1Y_CV = list()
STD1Y_GL = list()
STD1Y_HL = list()
STD1Y_LAS = list()
STD1Y_MFBL = list()
STD1Y_MFHL = list()
STD1Y_MFOT = list()
STD1Y_OTH = list()
STD1Y_PL = list()
STD1Y_PLBL = list()
STD1Y_RL = list()
STD1Y_SCC = list()
STD1Y_SEL = list()

count_list_AL = list()
count_list_BL = list()
count_list_CC = list()
count_list_CD = list()
count_list_CV = list()
count_list_GL = list()
count_list_HL = list()
count_list_LAS = list()
count_list_MFBL = list()
count_list_MFHL = list()
count_list_MFOT = list()
count_list_OTH = list()
count_list_PL = list()
count_list_PLBL = list()
count_list_RL = list()
count_list_SCC = list()
count_list_SEL = list()

count_AL = 0
count_BL = 0
count_CC = 0
count_CD = 0
count_CV = 0
count_GL = 0
count_HL = 0
count_LAS = 0
count_MFBL = 0
count_MFHL = 0
count_MFOT = 0
count_OTH = 0
count_PL = 0 
count_PLBL = 0
count_RL = 0
count_SCC = 0
count_SEL = 0

grp_df = df.groupby('ID')

for x in range(0, len(unq_id_list)):
    grp_slice = grp_df.get_group(unq_id_list[x])
    #print(grp_slice)
    grp_slice.reset_index(drop=True, inplace=True)
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['accountType'][i]=='unknown'):
            continue
        elif (grp_slice['accountType'][i]=='AL') and (grp_slice['STD1Y_flag'][i]==1):
            count_AL = count_AL + 1
        elif (grp_slice['accountType'][i]=='BL') and (grp_slice['STD1Y_flag'][i]==1):
            count_BL = count_BL + 1
        elif (grp_slice['accountType'][i]=='CC') and (grp_slice['STD1Y_flag'][i]==1):
            count_CC = count_CC + 1
        elif (grp_slice['accountType'][i]=='CD') and (grp_slice['STD1Y_flag'][i]==1):
            count_CD = count_CD + 1
        elif (grp_slice['accountType'][i]=='CV') and (grp_slice['STD1Y_flag'][i]==1):
            count_CV = count_CV + 1
        elif (grp_slice['accountType'][i]=='GL') and (grp_slice['STD1Y_flag'][i]==1):
            count_GL = count_GL + 1
        elif (grp_slice['accountType'][i]=='HL') and (grp_slice['STD1Y_flag'][i]==1):
            count_HL = count_HL + 1
        elif (grp_slice['accountType'][i]=='LAS') and (grp_slice['STD1Y_flag'][i]==1):
            count_LAS = count_LAS + 1
        elif (grp_slice['accountType'][i]=='MFBL') and (grp_slice['STD1Y_flag'][i]==1):
            count_MFBL = count_MFBL + 1
        elif (grp_slice['accountType'][i]=='MFHL') and (grp_slice['STD1Y_flag'][i]==1):
            count_MFHL = count_MFHL + 1
        elif (grp_slice['accountType'][i]=='MFOT') and (grp_slice['STD1Y_flag'][i]==1):
            count_MFOT = count_MFOT + 1
        elif (grp_slice['accountType'][i]=='OTH') and (grp_slice['STD1Y_flag'][i]==1):
            count_OTH = count_OTH + 1
        elif (grp_slice['accountType'][i]=='PL') and (grp_slice['STD1Y_flag'][i]==1):
            count_PL = count_PL + 1
        elif (grp_slice['accountType'][i]=='PLBL') and (grp_slice['STD1Y_flag'][i]==1):
            count_PLBL = count_PLBL + 1
        elif (grp_slice['accountType'][i]=='RL') and (grp_slice['STD1Y_flag'][i]==1):
            count_RL = count_RL + 1
        elif (grp_slice['accountType'][i]=='SCC') and (grp_slice['STD1Y_flag'][i]==1):
            count_SCC = count_SCC + 1
        elif (grp_slice['accountType'][i]=='SEL') and (grp_slice['STD1Y_flag'][i]==1):
            count_SEL = count_SEL + 1
            
    count_list_AL.append(count_AL)
    count_list_BL.append(count_BL)
    count_list_CC.append(count_CC)
    count_list_CD.append(count_CD)
    count_list_CV.append(count_CV)
    count_list_GL.append(count_GL)
    count_list_HL.append(count_HL)
    count_list_LAS.append(count_LAS)
    count_list_MFBL.append(count_MFBL)
    count_list_MFHL.append(count_MFHL)
    count_list_MFOT.append(count_MFOT)
    count_list_OTH.append(count_OTH)
    count_list_PL.append(count_PL)
    count_list_PLBL.append(count_PLBL)
    count_list_RL.append(count_RL)
    count_list_SCC.append(count_SCC)
    count_list_SEL.append(count_SEL)
    
    count_AL = 0
    count_BL = 0
    count_CC = 0
    count_CD = 0
    count_CV = 0
    count_GL = 0
    count_HL = 0
    count_LAS = 0
    count_MFBL = 0
    count_MFHL = 0
    count_MFOT = 0
    count_OTH = 0
    count_PL = 0
    count_PLBL = 0
    count_RL = 0
    count_SCC = 0
    count_SEL = 0
    
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['accountType'][i]=='unknown'):
            STD1Y_AL.append('unknown')
            STD1Y_BL.append('unknown')
            STD1Y_CC.append('unknown')
            STD1Y_CD.append('unknown')
            STD1Y_CV.append('unknown')
            STD1Y_GL.append('unknown')
            STD1Y_HL.append('unknown')
            STD1Y_LAS.append('unknown')
            STD1Y_MFBL.append('unknown')
            STD1Y_MFHL.append('unknown')
            STD1Y_MFOT.append('unknown')
            STD1Y_OTH.append('unknown')
            STD1Y_PL.append('unknown')
            STD1Y_PLBL.append('unknown')
            STD1Y_RL.append('unknown')
            STD1Y_SCC.append('unknown')
            STD1Y_SEL.append('unknown')
        else:
            STD1Y_AL.append(count_list_AL[x])
            STD1Y_BL.append(count_list_BL[x])
            STD1Y_CC.append(count_list_CC[x])
            STD1Y_CD.append(count_list_CD[x])
            STD1Y_CV.append(count_list_CV[x])
            STD1Y_GL.append(count_list_GL[x])
            STD1Y_HL.append(count_list_HL[x])
            STD1Y_LAS.append(count_list_LAS[x])
            STD1Y_MFBL.append(count_list_MFBL[x])
            STD1Y_MFHL.append(count_list_MFHL[x])
            STD1Y_MFOT.append(count_list_MFOT[x])
            STD1Y_OTH.append(count_list_OTH[x])
            STD1Y_PL.append(count_list_PL[x])
            STD1Y_PLBL.append(count_list_PLBL[x])
            STD1Y_RL.append(count_list_RL[x])
            STD1Y_SCC.append(count_list_SCC[x])
            STD1Y_SEL.append(count_list_SEL[x])
            
df['STD1Y_AL'] = pd.Series(STD1Y_AL).values
df['STD1Y_BL'] = pd.Series(STD1Y_BL).values
df['STD1Y_CC'] = pd.Series(STD1Y_CC).values
df['STD1Y_CD'] = pd.Series(STD1Y_CD).values
df['STD1Y_CV'] = pd.Series(STD1Y_CV).values
df['STD1Y_GL'] = pd.Series(STD1Y_GL).values
df['STD1Y_HL'] = pd.Series(STD1Y_HL).values
df['STD1Y_LAS'] = pd.Series(STD1Y_LAS).values
df['STD1Y_MFBL'] = pd.Series(STD1Y_MFBL).values
df['STD1Y_MFHL'] = pd.Series(STD1Y_MFHL).values
df['STD1Y_MFOT'] = pd.Series(STD1Y_MFOT).values
df['STD1Y_OTH'] = pd.Series(STD1Y_OTH).values
df['STD1Y_PL'] = pd.Series(STD1Y_PL).values
df['STD1Y_PLBL'] = pd.Series(STD1Y_PLBL).values
df['STD1Y_RL'] = pd.Series(STD1Y_RL).values
df['STD1Y_SCC'] = pd.Series(STD1Y_SCC).values
df['STD1Y_SEL'] = pd.Series(STD1Y_SEL).values

# %% [raw]
# d = df[['ID','STD1Y_GL','STD1Y_flag','accountType']]
# d[d['STD1Y_flag']!=0].head(60)

# %% [markdown]
# ### Code for STD2Y_P
# - STD in last 2 year productwise

# %%
STD2Y_AL = list()
STD2Y_BL = list()
STD2Y_CC = list()
STD2Y_CD = list()
STD2Y_CV = list()
STD2Y_GL = list()
STD2Y_HL = list()
STD2Y_LAS = list()
STD2Y_MFBL = list()
STD2Y_MFHL = list()
STD2Y_MFOT = list()
STD2Y_OTH = list()
STD2Y_PL = list()
STD2Y_PLBL = list()
STD2Y_RL = list()
STD2Y_SCC = list()
STD2Y_SEL = list()

count_list_AL = list()
count_list_BL = list()
count_list_CC = list()
count_list_CD = list()
count_list_CV = list()
count_list_GL = list()
count_list_HL = list()
count_list_LAS = list()
count_list_MFBL = list()
count_list_MFHL = list()
count_list_MFOT = list()
count_list_OTH = list()
count_list_PL = list()
count_list_PLBL = list()
count_list_RL = list()
count_list_SCC = list()
count_list_SEL = list()

count_AL = 0
count_BL = 0
count_CC = 0
count_CD = 0
count_CV = 0
count_GL = 0
count_HL = 0
count_LAS = 0
count_MFBL = 0
count_MFHL = 0
count_MFOT = 0
count_OTH = 0
count_PL = 0 
count_PLBL = 0
count_RL = 0
count_SCC = 0
count_SEL = 0

grp_df = df.groupby('ID')

for x in range(0, len(unq_id_list)):
    grp_slice = grp_df.get_group(unq_id_list[x])
    #print(grp_slice)
    grp_slice.reset_index(drop=True, inplace=True)
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['accountType'][i]=='unknown'):
            continue
        elif (grp_slice['accountType'][i]=='AL') and (grp_slice['STD2Y_flag'][i]==1):
            count_AL = count_AL + 1
        elif (grp_slice['accountType'][i]=='BL') and (grp_slice['STD2Y_flag'][i]==1):
            count_BL = count_BL + 1
        elif (grp_slice['accountType'][i]=='CC') and (grp_slice['STD2Y_flag'][i]==1):
            count_CC = count_CC + 1
        elif (grp_slice['accountType'][i]=='CD') and (grp_slice['STD2Y_flag'][i]==1):
            count_CD = count_CD + 1
        elif (grp_slice['accountType'][i]=='CV') and (grp_slice['STD2Y_flag'][i]==1):
            count_CV = count_CV + 1
        elif (grp_slice['accountType'][i]=='GL') and (grp_slice['STD2Y_flag'][i]==1):
            count_GL = count_GL + 1
        elif (grp_slice['accountType'][i]=='HL') and (grp_slice['STD2Y_flag'][i]==1):
            count_HL = count_HL + 1
        elif (grp_slice['accountType'][i]=='LAS') and (grp_slice['STD2Y_flag'][i]==1):
            count_LAS = count_LAS + 1
        elif (grp_slice['accountType'][i]=='MFBL') and (grp_slice['STD2Y_flag'][i]==1):
            count_MFBL = count_MFBL + 1
        elif (grp_slice['accountType'][i]=='MFHL') and (grp_slice['STD2Y_flag'][i]==1):
            count_MFHL = count_MFHL + 1
        elif (grp_slice['accountType'][i]=='MFOT') and (grp_slice['STD2Y_flag'][i]==1):
            count_MFOT = count_MFOT + 1
        elif (grp_slice['accountType'][i]=='OTH') and (grp_slice['STD2Y_flag'][i]==1):
            count_OTH = count_OTH + 1
        elif (grp_slice['accountType'][i]=='PL') and (grp_slice['STD2Y_flag'][i]==1):
            count_PL = count_PL + 1
        elif (grp_slice['accountType'][i]=='PLBL') and (grp_slice['STD2Y_flag'][i]==1):
            count_PLBL = count_PLBL + 1
        elif (grp_slice['accountType'][i]=='RL') and (grp_slice['STD2Y_flag'][i]==1):
            count_RL = count_RL + 1
        elif (grp_slice['accountType'][i]=='SCC') and (grp_slice['STD2Y_flag'][i]==1):
            count_SCC = count_SCC + 1
        elif (grp_slice['accountType'][i]=='SEL') and (grp_slice['STD2Y_flag'][i]==1):
            count_SEL = count_SEL + 1
            
    count_list_AL.append(count_AL)
    count_list_BL.append(count_BL)
    count_list_CC.append(count_CC)
    count_list_CD.append(count_CD)
    count_list_CV.append(count_CV)
    count_list_GL.append(count_GL)
    count_list_HL.append(count_HL)
    count_list_LAS.append(count_LAS)
    count_list_MFBL.append(count_MFBL)
    count_list_MFHL.append(count_MFHL)
    count_list_MFOT.append(count_MFOT)
    count_list_OTH.append(count_OTH)
    count_list_PL.append(count_PL)
    count_list_PLBL.append(count_PLBL)
    count_list_RL.append(count_RL)
    count_list_SCC.append(count_SCC)
    count_list_SEL.append(count_SEL)
    
    count_AL = 0
    count_BL = 0
    count_CC = 0
    count_CD = 0
    count_CV = 0
    count_GL = 0
    count_HL = 0
    count_LAS = 0
    count_MFBL = 0
    count_MFHL = 0
    count_MFOT = 0
    count_OTH = 0
    count_PL = 0
    count_PLBL = 0
    count_RL = 0
    count_SCC = 0
    count_SEL = 0
    
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['accountType'][i]=='unknown'):
            STD2Y_AL.append('unknown')
            STD2Y_BL.append('unknown')
            STD2Y_CC.append('unknown')
            STD2Y_CD.append('unknown')
            STD2Y_CV.append('unknown')
            STD2Y_GL.append('unknown')
            STD2Y_HL.append('unknown')
            STD2Y_LAS.append('unknown')
            STD2Y_MFBL.append('unknown')
            STD2Y_MFHL.append('unknown')
            STD2Y_MFOT.append('unknown')
            STD2Y_OTH.append('unknown')
            STD2Y_PL.append('unknown')
            STD2Y_PLBL.append('unknown')
            STD2Y_RL.append('unknown')
            STD2Y_SCC.append('unknown')
            STD2Y_SEL.append('unknown')
        else:
            STD2Y_AL.append(count_list_AL[x])
            STD2Y_BL.append(count_list_BL[x])
            STD2Y_CC.append(count_list_CC[x])
            STD2Y_CD.append(count_list_CD[x])
            STD2Y_CV.append(count_list_CV[x])
            STD2Y_GL.append(count_list_GL[x])
            STD2Y_HL.append(count_list_HL[x])
            STD2Y_LAS.append(count_list_LAS[x])
            STD2Y_MFBL.append(count_list_MFBL[x])
            STD2Y_MFHL.append(count_list_MFHL[x])
            STD2Y_MFOT.append(count_list_MFOT[x])
            STD2Y_OTH.append(count_list_OTH[x])
            STD2Y_PL.append(count_list_PL[x])
            STD2Y_PLBL.append(count_list_PLBL[x])
            STD2Y_RL.append(count_list_RL[x])
            STD2Y_SCC.append(count_list_SCC[x])
            STD2Y_SEL.append(count_list_SEL[x])
            
df['STD2Y_AL'] = pd.Series(STD2Y_AL).values
df['STD2Y_BL'] = pd.Series(STD2Y_BL).values
df['STD2Y_CC'] = pd.Series(STD2Y_CC).values
df['STD2Y_CD'] = pd.Series(STD2Y_CD).values
df['STD2Y_CV'] = pd.Series(STD2Y_CV).values
df['STD2Y_GL'] = pd.Series(STD2Y_GL).values
df['STD2Y_HL'] = pd.Series(STD2Y_HL).values
df['STD2Y_LAS'] = pd.Series(STD2Y_LAS).values
df['STD2Y_MFBL'] = pd.Series(STD2Y_MFBL).values
df['STD2Y_MFHL'] = pd.Series(STD2Y_MFHL).values
df['STD2Y_MFOT'] = pd.Series(STD2Y_MFOT).values
df['STD2Y_OTH'] = pd.Series(STD2Y_OTH).values
df['STD2Y_PL'] = pd.Series(STD2Y_PL).values
df['STD2Y_PLBL'] = pd.Series(STD2Y_PLBL).values
df['STD2Y_RL'] = pd.Series(STD2Y_RL).values
df['STD2Y_SCC'] = pd.Series(STD2Y_SCC).values
df['STD2Y_SEL'] = pd.Series(STD2Y_SEL).values

# %% [raw]
# d = df[['ID','STD2Y_GL','STD2Y_flag','accountType']]
# d[d['STD2Y_flag']!=0].head(60)

# %% [markdown]
# ### Code for STD3Y_P
# - STD in last 3 year productwise

# %%
STD3Y_AL = list()
STD3Y_BL = list()
STD3Y_CC = list()
STD3Y_CD = list()
STD3Y_CV = list()
STD3Y_GL = list()
STD3Y_HL = list()
STD3Y_LAS = list()
STD3Y_MFBL = list()
STD3Y_MFHL = list()
STD3Y_MFOT = list()
STD3Y_OTH = list()
STD3Y_PL = list()
STD3Y_PLBL = list()
STD3Y_RL = list()
STD3Y_SCC = list()
STD3Y_SEL = list()

count_list_AL = list()
count_list_BL = list()
count_list_CC = list()
count_list_CD = list()
count_list_CV = list()
count_list_GL = list()
count_list_HL = list()
count_list_LAS = list()
count_list_MFBL = list()
count_list_MFHL = list()
count_list_MFOT = list()
count_list_OTH = list()
count_list_PL = list()
count_list_PLBL = list()
count_list_RL = list()
count_list_SCC = list()
count_list_SEL = list()

count_AL = 0
count_BL = 0
count_CC = 0
count_CD = 0
count_CV = 0
count_GL = 0
count_HL = 0
count_LAS = 0
count_MFBL = 0
count_MFHL = 0
count_MFOT = 0
count_OTH = 0
count_PL = 0 
count_PLBL = 0
count_RL = 0
count_SCC = 0
count_SEL = 0

grp_df = df.groupby('ID')

for x in range(0, len(unq_id_list)):
    grp_slice = grp_df.get_group(unq_id_list[x])
    #print(grp_slice)
    grp_slice.reset_index(drop=True, inplace=True)
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['accountType'][i]=='unknown'):
            continue
        elif (grp_slice['accountType'][i]=='AL') and (grp_slice['STD3Y_flag'][i]==1):
            count_AL = count_AL + 1
        elif (grp_slice['accountType'][i]=='BL') and (grp_slice['STD3Y_flag'][i]==1):
            count_BL = count_BL + 1
        elif (grp_slice['accountType'][i]=='CC') and (grp_slice['STD3Y_flag'][i]==1):
            count_CC = count_CC + 1
        elif (grp_slice['accountType'][i]=='CD') and (grp_slice['STD3Y_flag'][i]==1):
            count_CD = count_CD + 1
        elif (grp_slice['accountType'][i]=='CV') and (grp_slice['STD3Y_flag'][i]==1):
            count_CV = count_CV + 1
        elif (grp_slice['accountType'][i]=='GL') and (grp_slice['STD3Y_flag'][i]==1):
            count_GL = count_GL + 1
        elif (grp_slice['accountType'][i]=='HL') and (grp_slice['STD3Y_flag'][i]==1):
            count_HL = count_HL + 1
        elif (grp_slice['accountType'][i]=='LAS') and (grp_slice['STD3Y_flag'][i]==1):
            count_LAS = count_LAS + 1
        elif (grp_slice['accountType'][i]=='MFBL') and (grp_slice['STD3Y_flag'][i]==1):
            count_MFBL = count_MFBL + 1
        elif (grp_slice['accountType'][i]=='MFHL') and (grp_slice['STD3Y_flag'][i]==1):
            count_MFHL = count_MFHL + 1
        elif (grp_slice['accountType'][i]=='MFOT') and (grp_slice['STD3Y_flag'][i]==1):
            count_MFOT = count_MFOT + 1
        elif (grp_slice['accountType'][i]=='OTH') and (grp_slice['STD3Y_flag'][i]==1):
            count_OTH = count_OTH + 1
        elif (grp_slice['accountType'][i]=='PL') and (grp_slice['STD3Y_flag'][i]==1):
            count_PL = count_PL + 1
        elif (grp_slice['accountType'][i]=='PLBL') and (grp_slice['STD3Y_flag'][i]==1):
            count_PLBL = count_PLBL + 1
        elif (grp_slice['accountType'][i]=='RL') and (grp_slice['STD3Y_flag'][i]==1):
            count_RL = count_RL + 1
        elif (grp_slice['accountType'][i]=='SCC') and (grp_slice['STD3Y_flag'][i]==1):
            count_SCC = count_SCC + 1
        elif (grp_slice['accountType'][i]=='SEL') and (grp_slice['STD3Y_flag'][i]==1):
            count_SEL = count_SEL + 1
            
    count_list_AL.append(count_AL)
    count_list_BL.append(count_BL)
    count_list_CC.append(count_CC)
    count_list_CD.append(count_CD)
    count_list_CV.append(count_CV)
    count_list_GL.append(count_GL)
    count_list_HL.append(count_HL)
    count_list_LAS.append(count_LAS)
    count_list_MFBL.append(count_MFBL)
    count_list_MFHL.append(count_MFHL)
    count_list_MFOT.append(count_MFOT)
    count_list_OTH.append(count_OTH)
    count_list_PL.append(count_PL)
    count_list_PLBL.append(count_PLBL)
    count_list_RL.append(count_RL)
    count_list_SCC.append(count_SCC)
    count_list_SEL.append(count_SEL)
    
    count_AL = 0
    count_BL = 0
    count_CC = 0
    count_CD = 0
    count_CV = 0
    count_GL = 0
    count_HL = 0
    count_LAS = 0
    count_MFBL = 0
    count_MFHL = 0
    count_MFOT = 0
    count_OTH = 0
    count_PL = 0
    count_PLBL = 0
    count_RL = 0
    count_SCC = 0
    count_SEL = 0
    
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['accountType'][i]=='unknown'):
            STD3Y_AL.append('unknown')
            STD3Y_BL.append('unknown')
            STD3Y_CC.append('unknown')
            STD3Y_CD.append('unknown')
            STD3Y_CV.append('unknown')
            STD3Y_GL.append('unknown')
            STD3Y_HL.append('unknown')
            STD3Y_LAS.append('unknown')
            STD3Y_MFBL.append('unknown')
            STD3Y_MFHL.append('unknown')
            STD3Y_MFOT.append('unknown')
            STD3Y_OTH.append('unknown')
            STD3Y_PL.append('unknown')
            STD3Y_PLBL.append('unknown')
            STD3Y_RL.append('unknown')
            STD3Y_SCC.append('unknown')
            STD3Y_SEL.append('unknown')
        else:
            STD3Y_AL.append(count_list_AL[x])
            STD3Y_BL.append(count_list_BL[x])
            STD3Y_CC.append(count_list_CC[x])
            STD3Y_CD.append(count_list_CD[x])
            STD3Y_CV.append(count_list_CV[x])
            STD3Y_GL.append(count_list_GL[x])
            STD3Y_HL.append(count_list_HL[x])
            STD3Y_LAS.append(count_list_LAS[x])
            STD3Y_MFBL.append(count_list_MFBL[x])
            STD3Y_MFHL.append(count_list_MFHL[x])
            STD3Y_MFOT.append(count_list_MFOT[x])
            STD3Y_OTH.append(count_list_OTH[x])
            STD3Y_PL.append(count_list_PL[x])
            STD3Y_PLBL.append(count_list_PLBL[x])
            STD3Y_RL.append(count_list_RL[x])
            STD3Y_SCC.append(count_list_SCC[x])
            STD3Y_SEL.append(count_list_SEL[x])
            
df['STD3Y_AL'] = pd.Series(STD3Y_AL).values
df['STD3Y_BL'] = pd.Series(STD3Y_BL).values
df['STD3Y_CC'] = pd.Series(STD3Y_CC).values
df['STD3Y_CD'] = pd.Series(STD3Y_CD).values
df['STD3Y_CV'] = pd.Series(STD3Y_CV).values
df['STD3Y_GL'] = pd.Series(STD3Y_GL).values
df['STD3Y_HL'] = pd.Series(STD3Y_HL).values
df['STD3Y_LAS'] = pd.Series(STD3Y_LAS).values
df['STD3Y_MFBL'] = pd.Series(STD3Y_MFBL).values
df['STD3Y_MFHL'] = pd.Series(STD3Y_MFHL).values
df['STD3Y_MFOT'] = pd.Series(STD3Y_MFOT).values
df['STD3Y_OTH'] = pd.Series(STD3Y_OTH).values
df['STD3Y_PL'] = pd.Series(STD3Y_PL).values
df['STD3Y_PLBL'] = pd.Series(STD3Y_PLBL).values
df['STD3Y_RL'] = pd.Series(STD3Y_RL).values
df['STD3Y_SCC'] = pd.Series(STD3Y_SCC).values
df['STD3Y_SEL'] = pd.Series(STD3Y_SEL).values

# %% [raw]
# d = df[['ID','STD3Y_GL','STD3Y_flag','accountType']]
# d[d['STD3Y_flag']!=0].head(60)

# %% [markdown]
# <a id='SUB_flags'></a>
# ### Code for SUB flags

# %%
sub_last1_mon = list()
sub_last3_mon_diff = list()
sub_last3_mon = list()
sub_last6_mon_diff = list()
sub_last6_mon = list()
sub_last1_yr_diff = list()
sub_last1_yr = list()
sub_last2_yr_diff = list()
sub_last2_yr = list()
sub_last3_yr_diff = list()
sub_last3_yr = list()
matching = list()


for x in range(0,df.shape[0]):
    if (df['mo_diff_ld_drc'][x]==-1):
        sub_last1_mon.append('unknown')
    elif (df['mo_diff_ld_drc'][x]==1) and (df['payHistComp'][x][0]=='SUB'):
        sub_last1_mon.append(1)
    else:
        sub_last1_mon.append(0)
        
    if (df['mo_diff_ld_drc'][x]==-1):
        sub_last3_mon_diff.append('unknown')
    elif (df['mo_diff_ld_drc'][x]>1) and (df['mo_diff_ld_drc'][x]<4):
        sub_last3_mon_diff.append(1)
    else:
        sub_last3_mon_diff.append(0)
    
    if (df['mo_diff_ld_drc'][x]==-1):
        sub_last6_mon_diff.append('unknown')
    elif (df['mo_diff_ld_drc'][x]>1) and (df['mo_diff_ld_drc'][x]<7):
        sub_last6_mon_diff.append(1)
    else:
        sub_last6_mon_diff.append(0)
    
    if (df['mo_diff_ld_drc'][x]==-1):
        sub_last1_yr_diff.append('unknown')
    elif (df['mo_diff_ld_drc'][x]>1) and (df['mo_diff_ld_drc'][x]<13):
        sub_last1_yr_diff.append(1)
    else:
        sub_last1_yr_diff.append(0)

    if (df['mo_diff_ld_drc'][x]==-1):
        sub_last2_yr_diff.append('unknown')
    elif (df['mo_diff_ld_drc'][x]>1) and (df['mo_diff_ld_drc'][x]<25):
        sub_last2_yr_diff.append(1)
    else:
        sub_last2_yr_diff.append(0)

    if (df['mo_diff_ld_drc'][x]==-1):
        sub_last3_yr_diff.append('unknown')
    elif (df['mo_diff_ld_drc'][x]>1) and (df['mo_diff_ld_drc'][x]<37):
        sub_last3_yr_diff.append(1)
    else:
        sub_last3_yr_diff.append(0)
              
df['sub_last3_mon_diff'] = pd.Series(sub_last3_mon_diff).values
df['sub_last6_mon_diff'] = pd.Series(sub_last6_mon_diff).values
df['sub_last1_yr_diff'] = pd.Series(sub_last1_yr_diff).values
df['sub_last2_yr_diff'] = pd.Series(sub_last2_yr_diff).values
df['sub_last3_yr_diff'] = pd.Series(sub_last3_yr_diff).values

for x in range(0, df.shape[0]):
    if (df['sub_last3_mon_diff'][x]=='unknown'):
        sub_last3_mon.append('unknown')
    elif (df['sub_last3_mon_diff'][x]==1):
        for i in range(0, 3-df['mo_diff_ld_drc'][x]):
            #print(i)
            matching.append(df['payHistComp'][x][i])
        if any('SUB' in s for s in matching):
            sub_last3_mon.append(1)
        else:
            sub_last3_mon.append(0)
        #print(matching)    
        matching = list()
    else:
        sub_last3_mon.append(0)

    if (df['sub_last6_mon_diff'][x]=='unknown'):
        sub_last6_mon.append('unknown')
    elif (df['sub_last6_mon_diff'][x]==1):
        for i in range(0, 6-df['mo_diff_ld_drc'][x]):
            #print(i)
            matching.append(df['payHistComp'][x][i])
        if any('SUB' in s for s in matching):
            sub_last6_mon.append(1)
        else:
            sub_last6_mon.append(0)
        #print(matching)    
        matching = list()
    else:
        sub_last6_mon.append(0)

    if (df['sub_last1_yr_diff'][x]=='unknown'):
        sub_last1_yr.append('unknown')
    elif (df['sub_last1_yr_diff'][x]==1) and (len(df['payHistComp'][x])>=12):
        for i in range(0, 12-df['mo_diff_ld_drc'][x]):
            #print(i)
            matching.append(df['payHistComp'][x][i])
        if any('SUB' in s for s in matching):
            sub_last1_yr.append(1)
        else:
            sub_last1_yr.append(0)
        #print(matching)    
        matching = list()
    else:
        sub_last1_yr.append(0)
    
    if (df['sub_last2_yr_diff'][x]=='unknown'):
        sub_last2_yr.append('unknown')
    elif (df['sub_last2_yr_diff'][x]==1) and (len(df['payHistComp'][x])>=24):
        for i in range(0, 24-df['mo_diff_ld_drc'][x]):
            #print(i)
            matching.append(df['payHistComp'][x][i])
        if any('SUB' in s for s in matching):
            sub_last2_yr.append(1)
        else:
            sub_last2_yr.append(0)
        #print(matching)    
        matching = list()
    else:
        sub_last2_yr.append(0)
    
    if (df['sub_last3_yr_diff'][x]=='unknown'):
        sub_last3_yr.append('unknown')
    elif (df['sub_last3_yr_diff'][x]==1) and (len(df['payHistComp'][x])==36):
        for i in range(0, 36-df['mo_diff_ld_drc'][x]):
            #print(i)
            matching.append(df['payHistComp'][x][i])
        if any('SUB' in s for s in matching):
            sub_last3_yr.append(1)
        else:
            sub_last3_yr.append(0)
        #print(matching)    
        matching = list()
    else:
        sub_last3_yr.append(0)

df['SUB1M_flag'] = pd.Series(sub_last1_mon).values
#print(df['SUB1M_flag'].value_counts()) 

df['SUB3M_flag'] = pd.Series(sub_last3_mon).values
#print(df['SUB3M_flag'].value_counts())
   
df['SUB6M_flag'] = pd.Series(sub_last6_mon).values
#print(df['SUB6M_flag'].value_counts())
   
df['SUB1Y_flag'] = pd.Series(sub_last1_yr).values
#print(df['SUB1Y_flag'].value_counts())
   
df['SUB2Y_flag'] = pd.Series(sub_last2_yr).values
#print(df['SUB2Y_flag'].value_counts())

df['SUB3Y_flag'] = pd.Series(sub_last3_yr).values
#print(df['SUB3Y_flag'].value_counts())

# %% [raw]
# piece = list()
#
# sub_last1_mon = list()
# sub_last3_mon = list()
# sub_last6_mon = list()
# sub_last1_yr = list()
# sub_last2_yr = list()
# sub_last3_yr = list()
#
# count = 0
#
# for value in df['paymentHistComp'].astype('str'):
#     #print(value)
#
#     chunks, chunk_size = len(value), 3
#     for i in range(0, chunks, chunk_size):
#         piece.append(value[i:i+chunk_size])
#     #print(piece)
#     #print(len(piece))
#
#     if ('SUB' in piece[0]):
#         #print(piece)
#         for x in piece:
#             if x == 'SUB':
#                 count = count + 1
#                 #print(count)
#             else:
#                 break
#         if count >= 1:
#             #print('1mo')
#             sub_last1_mon.append(1)
#             if count >= 3:
#                 #print('3mo')
#                 sub_last3_mon.append(1)
#                 if count >= 6:
#                     #print('6mo')
#                     sub_last6_mon.append(1)
#                     if count >= 12:
#                         #print('1yr')
#                         sub_last1_yr.append(1)
#                         if count >= 24:
#                             #print('2yr')
#                             sub_last2_yr.append(1)
#                             if count >= 36:
#                                 #print('3yr')
#                                 sub_last3_yr.append(1)
#                             else:
#                                 sub_last3_yr.append(0)
#                         else:
#                             sub_last2_yr.append(0)
#                             sub_last3_yr.append(0)
#                     else:
#                         sub_last1_yr.append(0)
#                         sub_last2_yr.append(0)
#                         sub_last3_yr.append(0)
#                 else:
#                     sub_last6_mon.append(0)
#                     sub_last1_yr.append(0)
#                     sub_last2_yr.append(0)
#                     sub_last3_yr.append(0)
#             else:
#                 sub_last3_mon.append(0)
#                 sub_last6_mon.append(0)
#                 sub_last1_yr.append(0)
#                 sub_last2_yr.append(0)
#                 sub_last3_yr.append(0)
#         else:
#             sub_last1_mon.append(0)
#             sub_last3_mon.append(0)
#             sub_last6_mon.append(0)
#             sub_last1_yr.append(0)
#             sub_last2_yr.append(0)
#             sub_last3_yr.append(0)
#     else:
#         sub_last1_mon.append(0)
#         sub_last3_mon.append(0)
#         sub_last6_mon.append(0)
#         sub_last1_yr.append(0)
#         sub_last2_yr.append(0)
#         sub_last3_yr.append(0)
#
#     count = 0
#     piece = list()
#
# df['SUB1M_flag'] = pd.Series(sub_last1_mon).values
# df['SUB3M_flag'] = pd.Series(sub_last3_mon).values
# df['SUB6M_flag'] = pd.Series(sub_last6_mon).values
# df['SUB1Y_flag'] = pd.Series(sub_last1_yr).values
# df['SUB2Y_flag'] = pd.Series(sub_last2_yr).values
# df['SUB3Y_flag'] = pd.Series(sub_last3_yr).values

# %% [markdown]
# <a id='SUB_num'></a>
# ### Code for SUB (numerical)

# %% [markdown]
# - For an applicant, Count of all loans where SUB1M_flag =1
# - For an applicant, Count of all loans where SUB3M_flag =1
# - For an applicant, Count of all loans where SUB6M_flag =1
# - For an applicant, Count of all loans where SUB1Y_flag =1
# - For an applicant, Count of all loans where SUB2Y_flag =1
# - For an applicant, Count of all loans where SUB3Y_flag =1

# %%
SUB1M = list()
count_list_1m = list()
count_1m = 0

SUB3M = list()
count_list_3m = list()
count_3m = 0

SUB6M = list()
count_list_6m = list()
count_6m = 0

SUB1Y = list()
count_list_1y = list()
count_1y = 0

SUB2Y = list()
count_list_2y = list()
count_2y = 0

SUB3Y = list()
count_list_3y = list()
count_3y = 0

grp_df = df.groupby('ID')

for x in range(0, len(unq_id_list)):
    grp_slice = grp_df.get_group(unq_id_list[x])
    #print(grp_slice)
    grp_slice.reset_index(drop=True, inplace=True)
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['SUB1M_flag'][i]==1) or (grp_slice['SUB1M_flag'][i]==0):
            count_1m = count_1m + grp_slice['SUB1M_flag'][i]
        
        if (grp_slice['SUB3M_flag'][i]==1) or (grp_slice['SUB3M_flag'][i]==0):
            count_3m = count_3m + grp_slice['SUB3M_flag'][i]

        if (grp_slice['SUB6M_flag'][i]==1) or (grp_slice['SUB6M_flag'][i]==0):
            count_6m = count_6m + grp_slice['SUB6M_flag'][i]

        if (grp_slice['SUB1Y_flag'][i]==1) or (grp_slice['SUB1Y_flag'][i]==0):
            count_1y = count_1y + grp_slice['SUB1Y_flag'][i]

        if (grp_slice['SUB2Y_flag'][i]==1) or (grp_slice['SUB2Y_flag'][i]==0):
            count_2y = count_2y + grp_slice['SUB2Y_flag'][i]

        if (grp_slice['SUB3Y_flag'][i]==1) or (grp_slice['SUB3Y_flag'][i]==0):
            count_3y = count_3y + grp_slice['SUB3Y_flag'][i]


    count_list_1m.append(count_1m)
    count_1m = 0
    count_list_3m.append(count_3m)
    count_3m = 0
    count_list_6m.append(count_6m)
    count_6m = 0
    count_list_1y.append(count_1y)
    count_1y = 0
    count_list_2y.append(count_2y)
    count_2y = 0
    count_list_3y.append(count_3y)
    count_3y = 0

    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['SUB1M_flag'][i]==1) or (grp_slice['SUB1M_flag'][i]==0):
            SUB1M.append(count_list_1m[x])
        else:
            SUB1M.append('unknown')

        if (grp_slice['SUB3M_flag'][i]==1) or (grp_slice['SUB3M_flag'][i]==0):
            SUB3M.append(count_list_3m[x])
        else:
            SUB3M.append('unknown')
        
        if (grp_slice['SUB6M_flag'][i]==1) or (grp_slice['SUB6M_flag'][i]==0):
            SUB6M.append(count_list_6m[x])
        else:
            SUB6M.append('unknown')

        if (grp_slice['SUB1Y_flag'][i]==1) or (grp_slice['SUB1Y_flag'][i]==0):
            SUB1Y.append(count_list_1y[x])
        else:
            SUB1Y.append('unknown')

        if (grp_slice['SUB2Y_flag'][i]==1) or (grp_slice['SUB2Y_flag'][i]==0):
            SUB2Y.append(count_list_2y[x])
        else:
            SUB2Y.append('unknown')
        
        if (grp_slice['SUB3Y_flag'][i]==1) or (grp_slice['SUB3Y_flag'][i]==0):
            SUB3Y.append(count_list_3y[x])
        else:
            SUB3Y.append('unknown')
            
df['SUB1M'] = pd.Series(SUB1M).values
df['SUB3M'] = pd.Series(SUB3M).values
df['SUB6M'] = pd.Series(SUB6M).values
df['SUB1Y'] = pd.Series(SUB1Y).values
df['SUB2Y'] = pd.Series(SUB2Y).values
df['SUB3Y'] = pd.Series(SUB3Y).values
#print(df['SUB3Y'].value_counts())

# %% [raw]
# df['SUB1M'].value_counts()

# %% [markdown]
# ### Code for SUB1M_P
# - SUB in last 1 month productwise

# %%
SUB1M_AL = list()
SUB1M_BL = list()
SUB1M_CC = list()
SUB1M_CD = list()
SUB1M_CV = list()
SUB1M_GL = list()
SUB1M_HL = list()
SUB1M_LAS = list()
SUB1M_MFBL = list()
SUB1M_MFHL = list()
SUB1M_MFOT = list()
SUB1M_OTH = list()
SUB1M_PL = list()
SUB1M_PLBL = list()
SUB1M_RL = list()
SUB1M_SCC = list()
SUB1M_SEL = list()

count_list_AL = list()
count_list_BL = list()
count_list_CC = list()
count_list_CD = list()
count_list_CV = list()
count_list_GL = list()
count_list_HL = list()
count_list_LAS = list()
count_list_MFBL = list()
count_list_MFHL = list()
count_list_MFOT = list()
count_list_OTH = list()
count_list_PL = list()
count_list_PLBL = list()
count_list_RL = list()
count_list_SCC = list()
count_list_SEL = list()

count_AL = 0
count_BL = 0
count_CC = 0
count_CD = 0
count_CV = 0
count_GL = 0
count_HL = 0
count_LAS = 0
count_MFBL = 0
count_MFHL = 0
count_MFOT = 0
count_OTH = 0
count_PL = 0 
count_PLBL = 0
count_RL = 0
count_SCC = 0
count_SEL = 0

grp_df = df.groupby('ID')

for x in range(0, len(unq_id_list)):
    grp_slice = grp_df.get_group(unq_id_list[x])
    #print(grp_slice)
    grp_slice.reset_index(drop=True, inplace=True)
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['accountType'][i]=='unknown'):
            continue
        elif (grp_slice['accountType'][i]=='AL') and (grp_slice['SUB1M_flag'][i]==1):
            count_AL = count_AL + 1
        elif (grp_slice['accountType'][i]=='BL') and (grp_slice['SUB1M_flag'][i]==1):
            count_BL = count_BL + 1
        elif (grp_slice['accountType'][i]=='CC') and (grp_slice['SUB1M_flag'][i]==1):
            count_CC = count_CC + 1
        elif (grp_slice['accountType'][i]=='CD') and (grp_slice['SUB1M_flag'][i]==1):
            count_CD = count_CD + 1
        elif (grp_slice['accountType'][i]=='CV') and (grp_slice['SUB1M_flag'][i]==1):
            count_CV = count_CV + 1
        elif (grp_slice['accountType'][i]=='GL') and (grp_slice['SUB1M_flag'][i]==1):
            count_GL = count_GL + 1
        elif (grp_slice['accountType'][i]=='HL') and (grp_slice['SUB1M_flag'][i]==1):
            count_HL = count_HL + 1
        elif (grp_slice['accountType'][i]=='LAS') and (grp_slice['SUB1M_flag'][i]==1):
            count_LAS = count_LAS + 1
        elif (grp_slice['accountType'][i]=='MFBL') and (grp_slice['SUB1M_flag'][i]==1):
            count_MFBL = count_MFBL + 1
        elif (grp_slice['accountType'][i]=='MFHL') and (grp_slice['SUB1M_flag'][i]==1):
            count_MFHL = count_MFHL + 1
        elif (grp_slice['accountType'][i]=='MFOT') and (grp_slice['SUB1M_flag'][i]==1):
            count_MFOT = count_MFOT + 1
        elif (grp_slice['accountType'][i]=='OTH') and (grp_slice['SUB1M_flag'][i]==1):
            count_OTH = count_OTH + 1
        elif (grp_slice['accountType'][i]=='PL') and (grp_slice['SUB1M_flag'][i]==1):
            count_PL = count_PL + 1
        elif (grp_slice['accountType'][i]=='PLBL') and (grp_slice['SUB1M_flag'][i]==1):
            count_PLBL = count_PLBL + 1
        elif (grp_slice['accountType'][i]=='RL') and (grp_slice['SUB1M_flag'][i]==1):
            count_RL = count_RL + 1
        elif (grp_slice['accountType'][i]=='SCC') and (grp_slice['SUB1M_flag'][i]==1):
            count_SCC = count_SCC + 1
        elif (grp_slice['accountType'][i]=='SEL') and (grp_slice['SUB1M_flag'][i]==1):
            count_SEL = count_SEL + 1
            
    count_list_AL.append(count_AL)
    count_list_BL.append(count_BL)
    count_list_CC.append(count_CC)
    count_list_CD.append(count_CD)
    count_list_CV.append(count_CV)
    count_list_GL.append(count_GL)
    count_list_HL.append(count_HL)
    count_list_LAS.append(count_LAS)
    count_list_MFBL.append(count_MFBL)
    count_list_MFHL.append(count_MFHL)
    count_list_MFOT.append(count_MFOT)
    count_list_OTH.append(count_OTH)
    count_list_PL.append(count_PL)
    count_list_PLBL.append(count_PLBL)
    count_list_RL.append(count_RL)
    count_list_SCC.append(count_SCC)
    count_list_SEL.append(count_SEL)
    
    count_AL = 0
    count_BL = 0
    count_CC = 0
    count_CD = 0
    count_CV = 0
    count_GL = 0
    count_HL = 0
    count_LAS = 0
    count_MFBL = 0
    count_MFHL = 0
    count_MFOT = 0
    count_OTH = 0
    count_PL = 0
    count_PLBL = 0
    count_RL = 0
    count_SCC = 0
    count_SEL = 0
    
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['accountType'][i]=='unknown'):
            SUB1M_AL.append('unknown')
            SUB1M_BL.append('unknown')
            SUB1M_CC.append('unknown')
            SUB1M_CD.append('unknown')
            SUB1M_CV.append('unknown')
            SUB1M_GL.append('unknown')
            SUB1M_HL.append('unknown')
            SUB1M_LAS.append('unknown')
            SUB1M_MFBL.append('unknown')
            SUB1M_MFHL.append('unknown')
            SUB1M_MFOT.append('unknown')
            SUB1M_OTH.append('unknown')
            SUB1M_PL.append('unknown')
            SUB1M_PLBL.append('unknown')
            SUB1M_RL.append('unknown')
            SUB1M_SCC.append('unknown')
            SUB1M_SEL.append('unknown')
        else:
            SUB1M_AL.append(count_list_AL[x])
            SUB1M_BL.append(count_list_BL[x])
            SUB1M_CC.append(count_list_CC[x])
            SUB1M_CD.append(count_list_CD[x])
            SUB1M_CV.append(count_list_CV[x])
            SUB1M_GL.append(count_list_GL[x])
            SUB1M_HL.append(count_list_HL[x])
            SUB1M_LAS.append(count_list_LAS[x])
            SUB1M_MFBL.append(count_list_MFBL[x])
            SUB1M_MFHL.append(count_list_MFHL[x])
            SUB1M_MFOT.append(count_list_MFOT[x])
            SUB1M_OTH.append(count_list_OTH[x])
            SUB1M_PL.append(count_list_PL[x])
            SUB1M_PLBL.append(count_list_PLBL[x])
            SUB1M_RL.append(count_list_RL[x])
            SUB1M_SCC.append(count_list_SCC[x])
            SUB1M_SEL.append(count_list_SEL[x])
            
df['SUB1M_AL'] = pd.Series(SUB1M_AL).values
df['SUB1M_BL'] = pd.Series(SUB1M_BL).values
df['SUB1M_CC'] = pd.Series(SUB1M_CC).values
df['SUB1M_CD'] = pd.Series(SUB1M_CD).values
df['SUB1M_CV'] = pd.Series(SUB1M_CV).values
df['SUB1M_GL'] = pd.Series(SUB1M_GL).values
df['SUB1M_HL'] = pd.Series(SUB1M_HL).values
df['SUB1M_LAS'] = pd.Series(SUB1M_LAS).values
df['SUB1M_MFBL'] = pd.Series(SUB1M_MFBL).values
df['SUB1M_MFHL'] = pd.Series(SUB1M_MFHL).values
df['SUB1M_MFOT'] = pd.Series(SUB1M_MFOT).values
df['SUB1M_OTH'] = pd.Series(SUB1M_OTH).values
df['SUB1M_PL'] = pd.Series(SUB1M_PL).values
df['SUB1M_PLBL'] = pd.Series(SUB1M_PLBL).values
df['SUB1M_RL'] = pd.Series(SUB1M_RL).values
df['SUB1M_SCC'] = pd.Series(SUB1M_SCC).values
df['SUB1M_SEL'] = pd.Series(SUB1M_SEL).values

# %% [raw]
# d = df[['ID','SUB1M_GL','SUB1M_flag','accountType']]
# d[d['SUB1M_flag']!=0].head(60)

# %% [markdown]
# ### Code for SUB3M_P
# - SUB in last 3 month productwise

# %%
SUB3M_AL = list()
SUB3M_BL = list()
SUB3M_CC = list()
SUB3M_CD = list()
SUB3M_CV = list()
SUB3M_GL = list()
SUB3M_HL = list()
SUB3M_LAS = list()
SUB3M_MFBL = list()
SUB3M_MFHL = list()
SUB3M_MFOT = list()
SUB3M_OTH = list()
SUB3M_PL = list()
SUB3M_PLBL = list()
SUB3M_RL = list()
SUB3M_SCC = list()
SUB3M_SEL = list()

count_list_AL = list()
count_list_BL = list()
count_list_CC = list()
count_list_CD = list()
count_list_CV = list()
count_list_GL = list()
count_list_HL = list()
count_list_LAS = list()
count_list_MFBL = list()
count_list_MFHL = list()
count_list_MFOT = list()
count_list_OTH = list()
count_list_PL = list()
count_list_PLBL = list()
count_list_RL = list()
count_list_SCC = list()
count_list_SEL = list()

count_AL = 0
count_BL = 0
count_CC = 0
count_CD = 0
count_CV = 0
count_GL = 0
count_HL = 0
count_LAS = 0
count_MFBL = 0
count_MFHL = 0
count_MFOT = 0
count_OTH = 0
count_PL = 0 
count_PLBL = 0
count_RL = 0
count_SCC = 0
count_SEL = 0

grp_df = df.groupby('ID')

for x in range(0, len(unq_id_list)):
    grp_slice = grp_df.get_group(unq_id_list[x])
    #print(grp_slice)
    grp_slice.reset_index(drop=True, inplace=True)
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['accountType'][i]=='unknown'):
            continue
        elif (grp_slice['accountType'][i]=='AL') and (grp_slice['SUB3M_flag'][i]==1):
            count_AL = count_AL + 1
        elif (grp_slice['accountType'][i]=='BL') and (grp_slice['SUB3M_flag'][i]==1):
            count_BL = count_BL + 1
        elif (grp_slice['accountType'][i]=='CC') and (grp_slice['SUB3M_flag'][i]==1):
            count_CC = count_CC + 1
        elif (grp_slice['accountType'][i]=='CD') and (grp_slice['SUB3M_flag'][i]==1):
            count_CD = count_CD + 1
        elif (grp_slice['accountType'][i]=='CV') and (grp_slice['SUB3M_flag'][i]==1):
            count_CV = count_CV + 1
        elif (grp_slice['accountType'][i]=='GL') and (grp_slice['SUB3M_flag'][i]==1):
            count_GL = count_GL + 1
        elif (grp_slice['accountType'][i]=='HL') and (grp_slice['SUB3M_flag'][i]==1):
            count_HL = count_HL + 1
        elif (grp_slice['accountType'][i]=='LAS') and (grp_slice['SUB3M_flag'][i]==1):
            count_LAS = count_LAS + 1
        elif (grp_slice['accountType'][i]=='MFBL') and (grp_slice['SUB3M_flag'][i]==1):
            count_MFBL = count_MFBL + 1
        elif (grp_slice['accountType'][i]=='MFHL') and (grp_slice['SUB3M_flag'][i]==1):
            count_MFHL = count_MFHL + 1
        elif (grp_slice['accountType'][i]=='MFOT') and (grp_slice['SUB3M_flag'][i]==1):
            count_MFOT = count_MFOT + 1
        elif (grp_slice['accountType'][i]=='OTH') and (grp_slice['SUB3M_flag'][i]==1):
            count_OTH = count_OTH + 1
        elif (grp_slice['accountType'][i]=='PL') and (grp_slice['SUB3M_flag'][i]==1):
            count_PL = count_PL + 1
        elif (grp_slice['accountType'][i]=='PLBL') and (grp_slice['SUB3M_flag'][i]==1):
            count_PLBL = count_PLBL + 1
        elif (grp_slice['accountType'][i]=='RL') and (grp_slice['SUB3M_flag'][i]==1):
            count_RL = count_RL + 1
        elif (grp_slice['accountType'][i]=='SCC') and (grp_slice['SUB3M_flag'][i]==1):
            count_SCC = count_SCC + 1
        elif (grp_slice['accountType'][i]=='SEL') and (grp_slice['SUB3M_flag'][i]==1):
            count_SEL = count_SEL + 1
            
    count_list_AL.append(count_AL)
    count_list_BL.append(count_BL)
    count_list_CC.append(count_CC)
    count_list_CD.append(count_CD)
    count_list_CV.append(count_CV)
    count_list_GL.append(count_GL)
    count_list_HL.append(count_HL)
    count_list_LAS.append(count_LAS)
    count_list_MFBL.append(count_MFBL)
    count_list_MFHL.append(count_MFHL)
    count_list_MFOT.append(count_MFOT)
    count_list_OTH.append(count_OTH)
    count_list_PL.append(count_PL)
    count_list_PLBL.append(count_PLBL)
    count_list_RL.append(count_RL)
    count_list_SCC.append(count_SCC)
    count_list_SEL.append(count_SEL)
    
    count_AL = 0
    count_BL = 0
    count_CC = 0
    count_CD = 0
    count_CV = 0
    count_GL = 0
    count_HL = 0
    count_LAS = 0
    count_MFBL = 0
    count_MFHL = 0
    count_MFOT = 0
    count_OTH = 0
    count_PL = 0
    count_PLBL = 0
    count_RL = 0
    count_SCC = 0
    count_SEL = 0
    
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['accountType'][i]=='unknown'):
            SUB3M_AL.append('unknown')
            SUB3M_BL.append('unknown')
            SUB3M_CC.append('unknown')
            SUB3M_CD.append('unknown')
            SUB3M_CV.append('unknown')
            SUB3M_GL.append('unknown')
            SUB3M_HL.append('unknown')
            SUB3M_LAS.append('unknown')
            SUB3M_MFBL.append('unknown')
            SUB3M_MFHL.append('unknown')
            SUB3M_MFOT.append('unknown')
            SUB3M_OTH.append('unknown')
            SUB3M_PL.append('unknown')
            SUB3M_PLBL.append('unknown')
            SUB3M_RL.append('unknown')
            SUB3M_SCC.append('unknown')
            SUB3M_SEL.append('unknown')
        else:
            SUB3M_AL.append(count_list_AL[x])
            SUB3M_BL.append(count_list_BL[x])
            SUB3M_CC.append(count_list_CC[x])
            SUB3M_CD.append(count_list_CD[x])
            SUB3M_CV.append(count_list_CV[x])
            SUB3M_GL.append(count_list_GL[x])
            SUB3M_HL.append(count_list_HL[x])
            SUB3M_LAS.append(count_list_LAS[x])
            SUB3M_MFBL.append(count_list_MFBL[x])
            SUB3M_MFHL.append(count_list_MFHL[x])
            SUB3M_MFOT.append(count_list_MFOT[x])
            SUB3M_OTH.append(count_list_OTH[x])
            SUB3M_PL.append(count_list_PL[x])
            SUB3M_PLBL.append(count_list_PLBL[x])
            SUB3M_RL.append(count_list_RL[x])
            SUB3M_SCC.append(count_list_SCC[x])
            SUB3M_SEL.append(count_list_SEL[x])
            
df['SUB3M_AL'] = pd.Series(SUB3M_AL).values
df['SUB3M_BL'] = pd.Series(SUB3M_BL).values
df['SUB3M_CC'] = pd.Series(SUB3M_CC).values
df['SUB3M_CD'] = pd.Series(SUB3M_CD).values
df['SUB3M_CV'] = pd.Series(SUB3M_CV).values
df['SUB3M_GL'] = pd.Series(SUB3M_GL).values
df['SUB3M_HL'] = pd.Series(SUB3M_HL).values
df['SUB3M_LAS'] = pd.Series(SUB3M_LAS).values
df['SUB3M_MFBL'] = pd.Series(SUB3M_MFBL).values
df['SUB3M_MFHL'] = pd.Series(SUB3M_MFHL).values
df['SUB3M_MFOT'] = pd.Series(SUB3M_MFOT).values
df['SUB3M_OTH'] = pd.Series(SUB3M_OTH).values
df['SUB3M_PL'] = pd.Series(SUB3M_PL).values
df['SUB3M_PLBL'] = pd.Series(SUB3M_PLBL).values
df['SUB3M_RL'] = pd.Series(SUB3M_RL).values
df['SUB3M_SCC'] = pd.Series(SUB3M_SCC).values
df['SUB3M_SEL'] = pd.Series(SUB3M_SEL).values

# %% [raw]
# d = df[['ID','SUB3M_GL','SUB3M_flag','accountType']]
# d[d['SUB3M_flag']!=0].head(60)

# %% [markdown]
# ### Code for SUB6M_P
# - SUB in last 6 month productwise

# %%
SUB6M_AL = list()
SUB6M_BL = list()
SUB6M_CC = list()
SUB6M_CD = list()
SUB6M_CV = list()
SUB6M_GL = list()
SUB6M_HL = list()
SUB6M_LAS = list()
SUB6M_MFBL = list()
SUB6M_MFHL = list()
SUB6M_MFOT = list()
SUB6M_OTH = list()
SUB6M_PL = list()
SUB6M_PLBL = list()
SUB6M_RL = list()
SUB6M_SCC = list()
SUB6M_SEL = list()

count_list_AL = list()
count_list_BL = list()
count_list_CC = list()
count_list_CD = list()
count_list_CV = list()
count_list_GL = list()
count_list_HL = list()
count_list_LAS = list()
count_list_MFBL = list()
count_list_MFHL = list()
count_list_MFOT = list()
count_list_OTH = list()
count_list_PL = list()
count_list_PLBL = list()
count_list_RL = list()
count_list_SCC = list()
count_list_SEL = list()

count_AL = 0
count_BL = 0
count_CC = 0
count_CD = 0
count_CV = 0
count_GL = 0
count_HL = 0
count_LAS = 0
count_MFBL = 0
count_MFHL = 0
count_MFOT = 0
count_OTH = 0
count_PL = 0 
count_PLBL = 0
count_RL = 0
count_SCC = 0
count_SEL = 0

grp_df = df.groupby('ID')

for x in range(0, len(unq_id_list)):
    grp_slice = grp_df.get_group(unq_id_list[x])
    #print(grp_slice)
    grp_slice.reset_index(drop=True, inplace=True)
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['accountType'][i]=='unknown'):
            continue
        elif (grp_slice['accountType'][i]=='AL') and (grp_slice['SUB6M_flag'][i]==1):
            count_AL = count_AL + 1
        elif (grp_slice['accountType'][i]=='BL') and (grp_slice['SUB6M_flag'][i]==1):
            count_BL = count_BL + 1
        elif (grp_slice['accountType'][i]=='CC') and (grp_slice['SUB6M_flag'][i]==1):
            count_CC = count_CC + 1
        elif (grp_slice['accountType'][i]=='CD') and (grp_slice['SUB6M_flag'][i]==1):
            count_CD = count_CD + 1
        elif (grp_slice['accountType'][i]=='CV') and (grp_slice['SUB6M_flag'][i]==1):
            count_CV = count_CV + 1
        elif (grp_slice['accountType'][i]=='GL') and (grp_slice['SUB6M_flag'][i]==1):
            count_GL = count_GL + 1
        elif (grp_slice['accountType'][i]=='HL') and (grp_slice['SUB6M_flag'][i]==1):
            count_HL = count_HL + 1
        elif (grp_slice['accountType'][i]=='LAS') and (grp_slice['SUB6M_flag'][i]==1):
            count_LAS = count_LAS + 1
        elif (grp_slice['accountType'][i]=='MFBL') and (grp_slice['SUB6M_flag'][i]==1):
            count_MFBL = count_MFBL + 1
        elif (grp_slice['accountType'][i]=='MFHL') and (grp_slice['SUB6M_flag'][i]==1):
            count_MFHL = count_MFHL + 1
        elif (grp_slice['accountType'][i]=='MFOT') and (grp_slice['SUB6M_flag'][i]==1):
            count_MFOT = count_MFOT + 1
        elif (grp_slice['accountType'][i]=='OTH') and (grp_slice['SUB6M_flag'][i]==1):
            count_OTH = count_OTH + 1
        elif (grp_slice['accountType'][i]=='PL') and (grp_slice['SUB6M_flag'][i]==1):
            count_PL = count_PL + 1
        elif (grp_slice['accountType'][i]=='PLBL') and (grp_slice['SUB6M_flag'][i]==1):
            count_PLBL = count_PLBL + 1
        elif (grp_slice['accountType'][i]=='RL') and (grp_slice['SUB6M_flag'][i]==1):
            count_RL = count_RL + 1
        elif (grp_slice['accountType'][i]=='SCC') and (grp_slice['SUB6M_flag'][i]==1):
            count_SCC = count_SCC + 1
        elif (grp_slice['accountType'][i]=='SEL') and (grp_slice['SUB6M_flag'][i]==1):
            count_SEL = count_SEL + 1
            
    count_list_AL.append(count_AL)
    count_list_BL.append(count_BL)
    count_list_CC.append(count_CC)
    count_list_CD.append(count_CD)
    count_list_CV.append(count_CV)
    count_list_GL.append(count_GL)
    count_list_HL.append(count_HL)
    count_list_LAS.append(count_LAS)
    count_list_MFBL.append(count_MFBL)
    count_list_MFHL.append(count_MFHL)
    count_list_MFOT.append(count_MFOT)
    count_list_OTH.append(count_OTH)
    count_list_PL.append(count_PL)
    count_list_PLBL.append(count_PLBL)
    count_list_RL.append(count_RL)
    count_list_SCC.append(count_SCC)
    count_list_SEL.append(count_SEL)
    
    count_AL = 0
    count_BL = 0
    count_CC = 0
    count_CD = 0
    count_CV = 0
    count_GL = 0
    count_HL = 0
    count_LAS = 0
    count_MFBL = 0
    count_MFHL = 0
    count_MFOT = 0
    count_OTH = 0
    count_PL = 0
    count_PLBL = 0
    count_RL = 0
    count_SCC = 0
    count_SEL = 0
    
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['accountType'][i]=='unknown'):
            SUB6M_AL.append('unknown')
            SUB6M_BL.append('unknown')
            SUB6M_CC.append('unknown')
            SUB6M_CD.append('unknown')
            SUB6M_CV.append('unknown')
            SUB6M_GL.append('unknown')
            SUB6M_HL.append('unknown')
            SUB6M_LAS.append('unknown')
            SUB6M_MFBL.append('unknown')
            SUB6M_MFHL.append('unknown')
            SUB6M_MFOT.append('unknown')
            SUB6M_OTH.append('unknown')
            SUB6M_PL.append('unknown')
            SUB6M_PLBL.append('unknown')
            SUB6M_RL.append('unknown')
            SUB6M_SCC.append('unknown')
            SUB6M_SEL.append('unknown')
        else:
            SUB6M_AL.append(count_list_AL[x])
            SUB6M_BL.append(count_list_BL[x])
            SUB6M_CC.append(count_list_CC[x])
            SUB6M_CD.append(count_list_CD[x])
            SUB6M_CV.append(count_list_CV[x])
            SUB6M_GL.append(count_list_GL[x])
            SUB6M_HL.append(count_list_HL[x])
            SUB6M_LAS.append(count_list_LAS[x])
            SUB6M_MFBL.append(count_list_MFBL[x])
            SUB6M_MFHL.append(count_list_MFHL[x])
            SUB6M_MFOT.append(count_list_MFOT[x])
            SUB6M_OTH.append(count_list_OTH[x])
            SUB6M_PL.append(count_list_PL[x])
            SUB6M_PLBL.append(count_list_PLBL[x])
            SUB6M_RL.append(count_list_RL[x])
            SUB6M_SCC.append(count_list_SCC[x])
            SUB6M_SEL.append(count_list_SEL[x])
            
df['SUB6M_AL'] = pd.Series(SUB6M_AL).values
df['SUB6M_BL'] = pd.Series(SUB6M_BL).values
df['SUB6M_CC'] = pd.Series(SUB6M_CC).values
df['SUB6M_CD'] = pd.Series(SUB6M_CD).values
df['SUB6M_CV'] = pd.Series(SUB6M_CV).values
df['SUB6M_GL'] = pd.Series(SUB6M_GL).values
df['SUB6M_HL'] = pd.Series(SUB6M_HL).values
df['SUB6M_LAS'] = pd.Series(SUB6M_LAS).values
df['SUB6M_MFBL'] = pd.Series(SUB6M_MFBL).values
df['SUB6M_MFHL'] = pd.Series(SUB6M_MFHL).values
df['SUB6M_MFOT'] = pd.Series(SUB6M_MFOT).values
df['SUB6M_OTH'] = pd.Series(SUB6M_OTH).values
df['SUB6M_PL'] = pd.Series(SUB6M_PL).values
df['SUB6M_PLBL'] = pd.Series(SUB6M_PLBL).values
df['SUB6M_RL'] = pd.Series(SUB6M_RL).values
df['SUB6M_SCC'] = pd.Series(SUB6M_SCC).values
df['SUB6M_SEL'] = pd.Series(SUB6M_SEL).values

# %% [raw]
# d = df[['ID','SUB6M_GL','SUB6M_flag','accountType']]
# d[d['SUB6M_flag']!=0].head(60)

# %% [markdown]
# ### Code for SUB1Y_P
# - SUB in last 1 year productwise

# %%
SUB1Y_AL = list()
SUB1Y_BL = list()
SUB1Y_CC = list()
SUB1Y_CD = list()
SUB1Y_CV = list()
SUB1Y_GL = list()
SUB1Y_HL = list()
SUB1Y_LAS = list()
SUB1Y_MFBL = list()
SUB1Y_MFHL = list()
SUB1Y_MFOT = list()
SUB1Y_OTH = list()
SUB1Y_PL = list()
SUB1Y_PLBL = list()
SUB1Y_RL = list()
SUB1Y_SCC = list()
SUB1Y_SEL = list()

count_list_AL = list()
count_list_BL = list()
count_list_CC = list()
count_list_CD = list()
count_list_CV = list()
count_list_GL = list()
count_list_HL = list()
count_list_LAS = list()
count_list_MFBL = list()
count_list_MFHL = list()
count_list_MFOT = list()
count_list_OTH = list()
count_list_PL = list()
count_list_PLBL = list()
count_list_RL = list()
count_list_SCC = list()
count_list_SEL = list()

count_AL = 0
count_BL = 0
count_CC = 0
count_CD = 0
count_CV = 0
count_GL = 0
count_HL = 0
count_LAS = 0
count_MFBL = 0
count_MFHL = 0
count_MFOT = 0
count_OTH = 0
count_PL = 0 
count_PLBL = 0
count_RL = 0
count_SCC = 0
count_SEL = 0

grp_df = df.groupby('ID')

for x in range(0, len(unq_id_list)):
    grp_slice = grp_df.get_group(unq_id_list[x])
    #print(grp_slice)
    grp_slice.reset_index(drop=True, inplace=True)
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['accountType'][i]=='unknown'):
            continue
        elif (grp_slice['accountType'][i]=='AL') and (grp_slice['SUB1Y_flag'][i]==1):
            count_AL = count_AL + 1
        elif (grp_slice['accountType'][i]=='BL') and (grp_slice['SUB1Y_flag'][i]==1):
            count_BL = count_BL + 1
        elif (grp_slice['accountType'][i]=='CC') and (grp_slice['SUB1Y_flag'][i]==1):
            count_CC = count_CC + 1
        elif (grp_slice['accountType'][i]=='CD') and (grp_slice['SUB1Y_flag'][i]==1):
            count_CD = count_CD + 1
        elif (grp_slice['accountType'][i]=='CV') and (grp_slice['SUB1Y_flag'][i]==1):
            count_CV = count_CV + 1
        elif (grp_slice['accountType'][i]=='GL') and (grp_slice['SUB1Y_flag'][i]==1):
            count_GL = count_GL + 1
        elif (grp_slice['accountType'][i]=='HL') and (grp_slice['SUB1Y_flag'][i]==1):
            count_HL = count_HL + 1
        elif (grp_slice['accountType'][i]=='LAS') and (grp_slice['SUB1Y_flag'][i]==1):
            count_LAS = count_LAS + 1
        elif (grp_slice['accountType'][i]=='MFBL') and (grp_slice['SUB1Y_flag'][i]==1):
            count_MFBL = count_MFBL + 1
        elif (grp_slice['accountType'][i]=='MFHL') and (grp_slice['SUB1Y_flag'][i]==1):
            count_MFHL = count_MFHL + 1
        elif (grp_slice['accountType'][i]=='MFOT') and (grp_slice['SUB1Y_flag'][i]==1):
            count_MFOT = count_MFOT + 1
        elif (grp_slice['accountType'][i]=='OTH') and (grp_slice['SUB1Y_flag'][i]==1):
            count_OTH = count_OTH + 1
        elif (grp_slice['accountType'][i]=='PL') and (grp_slice['SUB1Y_flag'][i]==1):
            count_PL = count_PL + 1
        elif (grp_slice['accountType'][i]=='PLBL') and (grp_slice['SUB1Y_flag'][i]==1):
            count_PLBL = count_PLBL + 1
        elif (grp_slice['accountType'][i]=='RL') and (grp_slice['SUB1Y_flag'][i]==1):
            count_RL = count_RL + 1
        elif (grp_slice['accountType'][i]=='SCC') and (grp_slice['SUB1Y_flag'][i]==1):
            count_SCC = count_SCC + 1
        elif (grp_slice['accountType'][i]=='SEL') and (grp_slice['SUB1Y_flag'][i]==1):
            count_SEL = count_SEL + 1
            
    count_list_AL.append(count_AL)
    count_list_BL.append(count_BL)
    count_list_CC.append(count_CC)
    count_list_CD.append(count_CD)
    count_list_CV.append(count_CV)
    count_list_GL.append(count_GL)
    count_list_HL.append(count_HL)
    count_list_LAS.append(count_LAS)
    count_list_MFBL.append(count_MFBL)
    count_list_MFHL.append(count_MFHL)
    count_list_MFOT.append(count_MFOT)
    count_list_OTH.append(count_OTH)
    count_list_PL.append(count_PL)
    count_list_PLBL.append(count_PLBL)
    count_list_RL.append(count_RL)
    count_list_SCC.append(count_SCC)
    count_list_SEL.append(count_SEL)
    
    count_AL = 0
    count_BL = 0
    count_CC = 0
    count_CD = 0
    count_CV = 0
    count_GL = 0
    count_HL = 0
    count_LAS = 0
    count_MFBL = 0
    count_MFHL = 0
    count_MFOT = 0
    count_OTH = 0
    count_PL = 0
    count_PLBL = 0
    count_RL = 0
    count_SCC = 0
    count_SEL = 0
    
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['accountType'][i]=='unknown'):
            SUB1Y_AL.append('unknown')
            SUB1Y_BL.append('unknown')
            SUB1Y_CC.append('unknown')
            SUB1Y_CD.append('unknown')
            SUB1Y_CV.append('unknown')
            SUB1Y_GL.append('unknown')
            SUB1Y_HL.append('unknown')
            SUB1Y_LAS.append('unknown')
            SUB1Y_MFBL.append('unknown')
            SUB1Y_MFHL.append('unknown')
            SUB1Y_MFOT.append('unknown')
            SUB1Y_OTH.append('unknown')
            SUB1Y_PL.append('unknown')
            SUB1Y_PLBL.append('unknown')
            SUB1Y_RL.append('unknown')
            SUB1Y_SCC.append('unknown')
            SUB1Y_SEL.append('unknown')
        else:
            SUB1Y_AL.append(count_list_AL[x])
            SUB1Y_BL.append(count_list_BL[x])
            SUB1Y_CC.append(count_list_CC[x])
            SUB1Y_CD.append(count_list_CD[x])
            SUB1Y_CV.append(count_list_CV[x])
            SUB1Y_GL.append(count_list_GL[x])
            SUB1Y_HL.append(count_list_HL[x])
            SUB1Y_LAS.append(count_list_LAS[x])
            SUB1Y_MFBL.append(count_list_MFBL[x])
            SUB1Y_MFHL.append(count_list_MFHL[x])
            SUB1Y_MFOT.append(count_list_MFOT[x])
            SUB1Y_OTH.append(count_list_OTH[x])
            SUB1Y_PL.append(count_list_PL[x])
            SUB1Y_PLBL.append(count_list_PLBL[x])
            SUB1Y_RL.append(count_list_RL[x])
            SUB1Y_SCC.append(count_list_SCC[x])
            SUB1Y_SEL.append(count_list_SEL[x])
            
df['SUB1Y_AL'] = pd.Series(SUB1Y_AL).values
df['SUB1Y_BL'] = pd.Series(SUB1Y_BL).values
df['SUB1Y_CC'] = pd.Series(SUB1Y_CC).values
df['SUB1Y_CD'] = pd.Series(SUB1Y_CD).values
df['SUB1Y_CV'] = pd.Series(SUB1Y_CV).values
df['SUB1Y_GL'] = pd.Series(SUB1Y_GL).values
df['SUB1Y_HL'] = pd.Series(SUB1Y_HL).values
df['SUB1Y_LAS'] = pd.Series(SUB1Y_LAS).values
df['SUB1Y_MFBL'] = pd.Series(SUB1Y_MFBL).values
df['SUB1Y_MFHL'] = pd.Series(SUB1Y_MFHL).values
df['SUB1Y_MFOT'] = pd.Series(SUB1Y_MFOT).values
df['SUB1Y_OTH'] = pd.Series(SUB1Y_OTH).values
df['SUB1Y_PL'] = pd.Series(SUB1Y_PL).values
df['SUB1Y_PLBL'] = pd.Series(SUB1Y_PLBL).values
df['SUB1Y_RL'] = pd.Series(SUB1Y_RL).values
df['SUB1Y_SCC'] = pd.Series(SUB1Y_SCC).values
df['SUB1Y_SEL'] = pd.Series(SUB1Y_SEL).values

# %% [raw]
# d = df[['ID','SUB1Y_GL','SUB1Y_flag','accountType']]
# d[d['SUB1Y_flag']!=0].head(60)

# %% [markdown]
# ### Code for SUB2Y_P
# - SUB in last 2 year productwise

# %%
SUB2Y_AL = list()
SUB2Y_BL = list()
SUB2Y_CC = list()
SUB2Y_CD = list()
SUB2Y_CV = list()
SUB2Y_GL = list()
SUB2Y_HL = list()
SUB2Y_LAS = list()
SUB2Y_MFBL = list()
SUB2Y_MFHL = list()
SUB2Y_MFOT = list()
SUB2Y_OTH = list()
SUB2Y_PL = list()
SUB2Y_PLBL = list()
SUB2Y_RL = list()
SUB2Y_SCC = list()
SUB2Y_SEL = list()

count_list_AL = list()
count_list_BL = list()
count_list_CC = list()
count_list_CD = list()
count_list_CV = list()
count_list_GL = list()
count_list_HL = list()
count_list_LAS = list()
count_list_MFBL = list()
count_list_MFHL = list()
count_list_MFOT = list()
count_list_OTH = list()
count_list_PL = list()
count_list_PLBL = list()
count_list_RL = list()
count_list_SCC = list()
count_list_SEL = list()

count_AL = 0
count_BL = 0
count_CC = 0
count_CD = 0
count_CV = 0
count_GL = 0
count_HL = 0
count_LAS = 0
count_MFBL = 0
count_MFHL = 0
count_MFOT = 0
count_OTH = 0
count_PL = 0 
count_PLBL = 0
count_RL = 0
count_SCC = 0
count_SEL = 0

grp_df = df.groupby('ID')

for x in range(0, len(unq_id_list)):
    grp_slice = grp_df.get_group(unq_id_list[x])
    #print(grp_slice)
    grp_slice.reset_index(drop=True, inplace=True)
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['accountType'][i]=='unknown'):
            continue
        elif (grp_slice['accountType'][i]=='AL') and (grp_slice['SUB2Y_flag'][i]==1):
            count_AL = count_AL + 1
        elif (grp_slice['accountType'][i]=='BL') and (grp_slice['SUB2Y_flag'][i]==1):
            count_BL = count_BL + 1
        elif (grp_slice['accountType'][i]=='CC') and (grp_slice['SUB2Y_flag'][i]==1):
            count_CC = count_CC + 1
        elif (grp_slice['accountType'][i]=='CD') and (grp_slice['SUB2Y_flag'][i]==1):
            count_CD = count_CD + 1
        elif (grp_slice['accountType'][i]=='CV') and (grp_slice['SUB2Y_flag'][i]==1):
            count_CV = count_CV + 1
        elif (grp_slice['accountType'][i]=='GL') and (grp_slice['SUB2Y_flag'][i]==1):
            count_GL = count_GL + 1
        elif (grp_slice['accountType'][i]=='HL') and (grp_slice['SUB2Y_flag'][i]==1):
            count_HL = count_HL + 1
        elif (grp_slice['accountType'][i]=='LAS') and (grp_slice['SUB2Y_flag'][i]==1):
            count_LAS = count_LAS + 1
        elif (grp_slice['accountType'][i]=='MFBL') and (grp_slice['SUB2Y_flag'][i]==1):
            count_MFBL = count_MFBL + 1
        elif (grp_slice['accountType'][i]=='MFHL') and (grp_slice['SUB2Y_flag'][i]==1):
            count_MFHL = count_MFHL + 1
        elif (grp_slice['accountType'][i]=='MFOT') and (grp_slice['SUB2Y_flag'][i]==1):
            count_MFOT = count_MFOT + 1
        elif (grp_slice['accountType'][i]=='OTH') and (grp_slice['SUB2Y_flag'][i]==1):
            count_OTH = count_OTH + 1
        elif (grp_slice['accountType'][i]=='PL') and (grp_slice['SUB2Y_flag'][i]==1):
            count_PL = count_PL + 1
        elif (grp_slice['accountType'][i]=='PLBL') and (grp_slice['SUB2Y_flag'][i]==1):
            count_PLBL = count_PLBL + 1
        elif (grp_slice['accountType'][i]=='RL') and (grp_slice['SUB2Y_flag'][i]==1):
            count_RL = count_RL + 1
        elif (grp_slice['accountType'][i]=='SCC') and (grp_slice['SUB2Y_flag'][i]==1):
            count_SCC = count_SCC + 1
        elif (grp_slice['accountType'][i]=='SEL') and (grp_slice['SUB2Y_flag'][i]==1):
            count_SEL = count_SEL + 1
            
    count_list_AL.append(count_AL)
    count_list_BL.append(count_BL)
    count_list_CC.append(count_CC)
    count_list_CD.append(count_CD)
    count_list_CV.append(count_CV)
    count_list_GL.append(count_GL)
    count_list_HL.append(count_HL)
    count_list_LAS.append(count_LAS)
    count_list_MFBL.append(count_MFBL)
    count_list_MFHL.append(count_MFHL)
    count_list_MFOT.append(count_MFOT)
    count_list_OTH.append(count_OTH)
    count_list_PL.append(count_PL)
    count_list_PLBL.append(count_PLBL)
    count_list_RL.append(count_RL)
    count_list_SCC.append(count_SCC)
    count_list_SEL.append(count_SEL)
    
    count_AL = 0
    count_BL = 0
    count_CC = 0
    count_CD = 0
    count_CV = 0
    count_GL = 0
    count_HL = 0
    count_LAS = 0
    count_MFBL = 0
    count_MFHL = 0
    count_MFOT = 0
    count_OTH = 0
    count_PL = 0
    count_PLBL = 0
    count_RL = 0
    count_SCC = 0
    count_SEL = 0
    
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['accountType'][i]=='unknown'):
            SUB2Y_AL.append('unknown')
            SUB2Y_BL.append('unknown')
            SUB2Y_CC.append('unknown')
            SUB2Y_CD.append('unknown')
            SUB2Y_CV.append('unknown')
            SUB2Y_GL.append('unknown')
            SUB2Y_HL.append('unknown')
            SUB2Y_LAS.append('unknown')
            SUB2Y_MFBL.append('unknown')
            SUB2Y_MFHL.append('unknown')
            SUB2Y_MFOT.append('unknown')
            SUB2Y_OTH.append('unknown')
            SUB2Y_PL.append('unknown')
            SUB2Y_PLBL.append('unknown')
            SUB2Y_RL.append('unknown')
            SUB2Y_SCC.append('unknown')
            SUB2Y_SEL.append('unknown')
        else:
            SUB2Y_AL.append(count_list_AL[x])
            SUB2Y_BL.append(count_list_BL[x])
            SUB2Y_CC.append(count_list_CC[x])
            SUB2Y_CD.append(count_list_CD[x])
            SUB2Y_CV.append(count_list_CV[x])
            SUB2Y_GL.append(count_list_GL[x])
            SUB2Y_HL.append(count_list_HL[x])
            SUB2Y_LAS.append(count_list_LAS[x])
            SUB2Y_MFBL.append(count_list_MFBL[x])
            SUB2Y_MFHL.append(count_list_MFHL[x])
            SUB2Y_MFOT.append(count_list_MFOT[x])
            SUB2Y_OTH.append(count_list_OTH[x])
            SUB2Y_PL.append(count_list_PL[x])
            SUB2Y_PLBL.append(count_list_PLBL[x])
            SUB2Y_RL.append(count_list_RL[x])
            SUB2Y_SCC.append(count_list_SCC[x])
            SUB2Y_SEL.append(count_list_SEL[x])
            
df['SUB2Y_AL'] = pd.Series(SUB2Y_AL).values
df['SUB2Y_BL'] = pd.Series(SUB2Y_BL).values
df['SUB2Y_CC'] = pd.Series(SUB2Y_CC).values
df['SUB2Y_CD'] = pd.Series(SUB2Y_CD).values
df['SUB2Y_CV'] = pd.Series(SUB2Y_CV).values
df['SUB2Y_GL'] = pd.Series(SUB2Y_GL).values
df['SUB2Y_HL'] = pd.Series(SUB2Y_HL).values
df['SUB2Y_LAS'] = pd.Series(SUB2Y_LAS).values
df['SUB2Y_MFBL'] = pd.Series(SUB2Y_MFBL).values
df['SUB2Y_MFHL'] = pd.Series(SUB2Y_MFHL).values
df['SUB2Y_MFOT'] = pd.Series(SUB2Y_MFOT).values
df['SUB2Y_OTH'] = pd.Series(SUB2Y_OTH).values
df['SUB2Y_PL'] = pd.Series(SUB2Y_PL).values
df['SUB2Y_PLBL'] = pd.Series(SUB2Y_PLBL).values
df['SUB2Y_RL'] = pd.Series(SUB2Y_RL).values
df['SUB2Y_SCC'] = pd.Series(SUB2Y_SCC).values
df['SUB2Y_SEL'] = pd.Series(SUB2Y_SEL).values

# %% [raw]
# d = df[['ID','SUB2Y_GL','SUB2Y_flag','accountType']]
# d[d['SUB2Y_flag']!=0].head(60)

# %% [markdown]
# ### Code for SUB3Y_P
# - SUB in last 3 year productwise

# %%
SUB3Y_AL = list()
SUB3Y_BL = list()
SUB3Y_CC = list()
SUB3Y_CD = list()
SUB3Y_CV = list()
SUB3Y_GL = list()
SUB3Y_HL = list()
SUB3Y_LAS = list()
SUB3Y_MFBL = list()
SUB3Y_MFHL = list()
SUB3Y_MFOT = list()
SUB3Y_OTH = list()
SUB3Y_PL = list()
SUB3Y_PLBL = list()
SUB3Y_RL = list()
SUB3Y_SCC = list()
SUB3Y_SEL = list()

count_list_AL = list()
count_list_BL = list()
count_list_CC = list()
count_list_CD = list()
count_list_CV = list()
count_list_GL = list()
count_list_HL = list()
count_list_LAS = list()
count_list_MFBL = list()
count_list_MFHL = list()
count_list_MFOT = list()
count_list_OTH = list()
count_list_PL = list()
count_list_PLBL = list()
count_list_RL = list()
count_list_SCC = list()
count_list_SEL = list()

count_AL = 0
count_BL = 0
count_CC = 0
count_CD = 0
count_CV = 0
count_GL = 0
count_HL = 0
count_LAS = 0
count_MFBL = 0
count_MFHL = 0
count_MFOT = 0
count_OTH = 0
count_PL = 0 
count_PLBL = 0
count_RL = 0
count_SCC = 0
count_SEL = 0

grp_df = df.groupby('ID')

for x in range(0, len(unq_id_list)):
    grp_slice = grp_df.get_group(unq_id_list[x])
    #print(grp_slice)
    grp_slice.reset_index(drop=True, inplace=True)
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['accountType'][i]=='unknown'):
            continue
        elif (grp_slice['accountType'][i]=='AL') and (grp_slice['SUB3Y_flag'][i]==1):
            count_AL = count_AL + 1
        elif (grp_slice['accountType'][i]=='BL') and (grp_slice['SUB3Y_flag'][i]==1):
            count_BL = count_BL + 1
        elif (grp_slice['accountType'][i]=='CC') and (grp_slice['SUB3Y_flag'][i]==1):
            count_CC = count_CC + 1
        elif (grp_slice['accountType'][i]=='CD') and (grp_slice['SUB3Y_flag'][i]==1):
            count_CD = count_CD + 1
        elif (grp_slice['accountType'][i]=='CV') and (grp_slice['SUB3Y_flag'][i]==1):
            count_CV = count_CV + 1
        elif (grp_slice['accountType'][i]=='GL') and (grp_slice['SUB3Y_flag'][i]==1):
            count_GL = count_GL + 1
        elif (grp_slice['accountType'][i]=='HL') and (grp_slice['SUB3Y_flag'][i]==1):
            count_HL = count_HL + 1
        elif (grp_slice['accountType'][i]=='LAS') and (grp_slice['SUB3Y_flag'][i]==1):
            count_LAS = count_LAS + 1
        elif (grp_slice['accountType'][i]=='MFBL') and (grp_slice['SUB3Y_flag'][i]==1):
            count_MFBL = count_MFBL + 1
        elif (grp_slice['accountType'][i]=='MFHL') and (grp_slice['SUB3Y_flag'][i]==1):
            count_MFHL = count_MFHL + 1
        elif (grp_slice['accountType'][i]=='MFOT') and (grp_slice['SUB3Y_flag'][i]==1):
            count_MFOT = count_MFOT + 1
        elif (grp_slice['accountType'][i]=='OTH') and (grp_slice['SUB3Y_flag'][i]==1):
            count_OTH = count_OTH + 1
        elif (grp_slice['accountType'][i]=='PL') and (grp_slice['SUB3Y_flag'][i]==1):
            count_PL = count_PL + 1
        elif (grp_slice['accountType'][i]=='PLBL') and (grp_slice['SUB3Y_flag'][i]==1):
            count_PLBL = count_PLBL + 1
        elif (grp_slice['accountType'][i]=='RL') and (grp_slice['SUB3Y_flag'][i]==1):
            count_RL = count_RL + 1
        elif (grp_slice['accountType'][i]=='SCC') and (grp_slice['SUB3Y_flag'][i]==1):
            count_SCC = count_SCC + 1
        elif (grp_slice['accountType'][i]=='SEL') and (grp_slice['SUB3Y_flag'][i]==1):
            count_SEL = count_SEL + 1
            
    count_list_AL.append(count_AL)
    count_list_BL.append(count_BL)
    count_list_CC.append(count_CC)
    count_list_CD.append(count_CD)
    count_list_CV.append(count_CV)
    count_list_GL.append(count_GL)
    count_list_HL.append(count_HL)
    count_list_LAS.append(count_LAS)
    count_list_MFBL.append(count_MFBL)
    count_list_MFHL.append(count_MFHL)
    count_list_MFOT.append(count_MFOT)
    count_list_OTH.append(count_OTH)
    count_list_PL.append(count_PL)
    count_list_PLBL.append(count_PLBL)
    count_list_RL.append(count_RL)
    count_list_SCC.append(count_SCC)
    count_list_SEL.append(count_SEL)
    
    count_AL = 0
    count_BL = 0
    count_CC = 0
    count_CD = 0
    count_CV = 0
    count_GL = 0
    count_HL = 0
    count_LAS = 0
    count_MFBL = 0
    count_MFHL = 0
    count_MFOT = 0
    count_OTH = 0
    count_PL = 0
    count_PLBL = 0
    count_RL = 0
    count_SCC = 0
    count_SEL = 0
    
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['accountType'][i]=='unknown'):
            SUB3Y_AL.append('unknown')
            SUB3Y_BL.append('unknown')
            SUB3Y_CC.append('unknown')
            SUB3Y_CD.append('unknown')
            SUB3Y_CV.append('unknown')
            SUB3Y_GL.append('unknown')
            SUB3Y_HL.append('unknown')
            SUB3Y_LAS.append('unknown')
            SUB3Y_MFBL.append('unknown')
            SUB3Y_MFHL.append('unknown')
            SUB3Y_MFOT.append('unknown')
            SUB3Y_OTH.append('unknown')
            SUB3Y_PL.append('unknown')
            SUB3Y_PLBL.append('unknown')
            SUB3Y_RL.append('unknown')
            SUB3Y_SCC.append('unknown')
            SUB3Y_SEL.append('unknown')
        else:
            SUB3Y_AL.append(count_list_AL[x])
            SUB3Y_BL.append(count_list_BL[x])
            SUB3Y_CC.append(count_list_CC[x])
            SUB3Y_CD.append(count_list_CD[x])
            SUB3Y_CV.append(count_list_CV[x])
            SUB3Y_GL.append(count_list_GL[x])
            SUB3Y_HL.append(count_list_HL[x])
            SUB3Y_LAS.append(count_list_LAS[x])
            SUB3Y_MFBL.append(count_list_MFBL[x])
            SUB3Y_MFHL.append(count_list_MFHL[x])
            SUB3Y_MFOT.append(count_list_MFOT[x])
            SUB3Y_OTH.append(count_list_OTH[x])
            SUB3Y_PL.append(count_list_PL[x])
            SUB3Y_PLBL.append(count_list_PLBL[x])
            SUB3Y_RL.append(count_list_RL[x])
            SUB3Y_SCC.append(count_list_SCC[x])
            SUB3Y_SEL.append(count_list_SEL[x])
            
df['SUB3Y_AL'] = pd.Series(SUB3Y_AL).values
df['SUB3Y_BL'] = pd.Series(SUB3Y_BL).values
df['SUB3Y_CC'] = pd.Series(SUB3Y_CC).values
df['SUB3Y_CD'] = pd.Series(SUB3Y_CD).values
df['SUB3Y_CV'] = pd.Series(SUB3Y_CV).values
df['SUB3Y_GL'] = pd.Series(SUB3Y_GL).values
df['SUB3Y_HL'] = pd.Series(SUB3Y_HL).values
df['SUB3Y_LAS'] = pd.Series(SUB3Y_LAS).values
df['SUB3Y_MFBL'] = pd.Series(SUB3Y_MFBL).values
df['SUB3Y_MFHL'] = pd.Series(SUB3Y_MFHL).values
df['SUB3Y_MFOT'] = pd.Series(SUB3Y_MFOT).values
df['SUB3Y_OTH'] = pd.Series(SUB3Y_OTH).values
df['SUB3Y_PL'] = pd.Series(SUB3Y_PL).values
df['SUB3Y_PLBL'] = pd.Series(SUB3Y_PLBL).values
df['SUB3Y_RL'] = pd.Series(SUB3Y_RL).values
df['SUB3Y_SCC'] = pd.Series(SUB3Y_SCC).values
df['SUB3Y_SEL'] = pd.Series(SUB3Y_SEL).values

# %% [raw]
# d = df[['ID','SUB3Y_GL','SUB3Y_flag','accountType']]
# d[d['SUB3Y_flag']!=0].head(60)

# %% [markdown]
# <a id='DBT_flags'></a>
# ### Code for DBT flags

# %%
dbt_last1_mon = list()
dbt_last3_mon_diff = list()
dbt_last3_mon = list()
dbt_last6_mon_diff = list()
dbt_last6_mon = list()
dbt_last1_yr_diff = list()
dbt_last1_yr = list()
dbt_last2_yr_diff = list()
dbt_last2_yr = list()
dbt_last3_yr_diff = list()
dbt_last3_yr = list()
matching = list()


for x in range(0,df.shape[0]):
    if (df['mo_diff_ld_drc'][x]==-1):
        dbt_last1_mon.append('unknown')
    elif (df['mo_diff_ld_drc'][x]==1) and (df['payHistComp'][x][0]=='DBT'):
        dbt_last1_mon.append(1)
    else:
        dbt_last1_mon.append(0)
        
    if (df['mo_diff_ld_drc'][x]==-1):
        dbt_last3_mon_diff.append('unknown')
    elif (df['mo_diff_ld_drc'][x]>1) and (df['mo_diff_ld_drc'][x]<4):
        dbt_last3_mon_diff.append(1)
    else:
        dbt_last3_mon_diff.append(0)
    
    if (df['mo_diff_ld_drc'][x]==-1):
        dbt_last6_mon_diff.append('unknown')
    elif (df['mo_diff_ld_drc'][x]>1) and (df['mo_diff_ld_drc'][x]<7):
        dbt_last6_mon_diff.append(1)
    else:
        dbt_last6_mon_diff.append(0)
    
    if (df['mo_diff_ld_drc'][x]==-1):
        dbt_last1_yr_diff.append('unknown')
    elif (df['mo_diff_ld_drc'][x]>1) and (df['mo_diff_ld_drc'][x]<13):
        dbt_last1_yr_diff.append(1)
    else:
        dbt_last1_yr_diff.append(0)

    if (df['mo_diff_ld_drc'][x]==-1):
        dbt_last2_yr_diff.append('unknown')
    elif (df['mo_diff_ld_drc'][x]>1) and (df['mo_diff_ld_drc'][x]<25):
        dbt_last2_yr_diff.append(1)
    else:
        dbt_last2_yr_diff.append(0)

    if (df['mo_diff_ld_drc'][x]==-1):
        dbt_last3_yr_diff.append('unknown')
    elif (df['mo_diff_ld_drc'][x]>1) and (df['mo_diff_ld_drc'][x]<37):
        dbt_last3_yr_diff.append(1)
    else:
        dbt_last3_yr_diff.append(0)
              
df['dbt_last3_mon_diff'] = pd.Series(dbt_last3_mon_diff).values
df['dbt_last6_mon_diff'] = pd.Series(dbt_last6_mon_diff).values
df['dbt_last1_yr_diff'] = pd.Series(dbt_last1_yr_diff).values
df['dbt_last2_yr_diff'] = pd.Series(dbt_last2_yr_diff).values
df['dbt_last3_yr_diff'] = pd.Series(dbt_last3_yr_diff).values

for x in range(0, df.shape[0]):
    if (df['dbt_last3_mon_diff'][x]=='unknown'):
        dbt_last3_mon.append('unknown')
    elif (df['dbt_last3_mon_diff'][x]==1):
        for i in range(0, 3-df['mo_diff_ld_drc'][x]):
            #print(i)
            matching.append(df['payHistComp'][x][i])
        if any('DBT' in s for s in matching):
            dbt_last3_mon.append(1)
        else:
            dbt_last3_mon.append(0)
        #print(matching)    
        matching = list()
    else:
        dbt_last3_mon.append(0)

    if (df['dbt_last6_mon_diff'][x]=='unknown'):
        dbt_last6_mon.append('unknown')
    elif (df['dbt_last6_mon_diff'][x]==1):
        for i in range(0, 6-df['mo_diff_ld_drc'][x]):
            #print(i)
            matching.append(df['payHistComp'][x][i])
        if any('DBT' in s for s in matching):
            dbt_last6_mon.append(1)
        else:
            dbt_last6_mon.append(0)
        #print(matching)    
        matching = list()
    else:
        dbt_last6_mon.append(0)

    if (df['dbt_last1_yr_diff'][x]=='unknown'):
        dbt_last1_yr.append('unknown')
    elif (df['dbt_last1_yr_diff'][x]==1) and (len(df['payHistComp'][x])>=12):
        for i in range(0, 12-df['mo_diff_ld_drc'][x]):
            #print(i)
            matching.append(df['payHistComp'][x][i])
        if any('DBT' in s for s in matching):
            dbt_last1_yr.append(1)
        else:
            dbt_last1_yr.append(0)
        #print(matching)    
        matching = list()
    else:
        dbt_last1_yr.append(0)
    
    if (df['dbt_last2_yr_diff'][x]=='unknown'):
        dbt_last2_yr.append('unknown')
    elif (df['dbt_last2_yr_diff'][x]==1) and (len(df['payHistComp'][x])>=24):
        for i in range(0, 24-df['mo_diff_ld_drc'][x]):
            #print(i)
            matching.append(df['payHistComp'][x][i])
        if any('DBT' in s for s in matching):
            dbt_last2_yr.append(1)
        else:
            dbt_last2_yr.append(0)
        #print(matching)    
        matching = list()
    else:
        dbt_last2_yr.append(0)
    
    if (df['dbt_last3_yr_diff'][x]=='unknown'):
        dbt_last3_yr.append('unknown')
    elif (df['dbt_last3_yr_diff'][x]==1) and (len(df['payHistComp'][x])==36):
        for i in range(0, 36-df['mo_diff_ld_drc'][x]):
            #print(i)
            matching.append(df['payHistComp'][x][i])
        if any('DBT' in s for s in matching):
            dbt_last3_yr.append(1)
        else:
            dbt_last3_yr.append(0)
        #print(matching)    
        matching = list()
    else:
        dbt_last3_yr.append(0)

df['DBT1M_flag'] = pd.Series(dbt_last1_mon).values
#print(df['DBT1M_flag'].value_counts()) 

df['DBT3M_flag'] = pd.Series(dbt_last3_mon).values
#print(df['DBT3M_flag'].value_counts())
   
df['DBT6M_flag'] = pd.Series(dbt_last6_mon).values
#print(df['DBT6M_flag'].value_counts())
   
df['DBT1Y_flag'] = pd.Series(dbt_last1_yr).values
#print(df['DBT1Y_flag'].value_counts())
   
df['DBT2Y_flag'] = pd.Series(dbt_last2_yr).values
#print(df['DBT2Y_flag'].value_counts())

df['DBT3Y_flag'] = pd.Series(dbt_last3_yr).values
#print(df['DBT3Y_flag'].value_counts())

# %% [raw]
# piece = list()
#
# dbt_last1_mon = list()
# dbt_last3_mon = list()
# dbt_last6_mon = list()
# dbt_last1_yr = list()
# dbt_last2_yr = list()
# dbt_last3_yr = list()
#
# count = 0
#
# for value in df['paymentHistComp'].astype('str'):
#     #print(value)
#
#     chunks, chunk_size = len(value), 3
#     for i in range(0, chunks, chunk_size):
#         piece.append(value[i:i+chunk_size])
#     #print(piece)
#     #print(len(piece))
#
#     if ('DBT' in piece[0]):
#         #print(piece)
#         for x in piece:
#             if x == 'DBT':
#                 count = count + 1
#                 #print(count)
#             else:
#                 break
#         if count >= 1:
#             #print('1mo')
#             dbt_last1_mon.append(1)
#             if count >= 3:
#                 #print('3mo')
#                 dbt_last3_mon.append(1)
#                 if count >= 6:
#                     #print('6mo')
#                     dbt_last6_mon.append(1)
#                     if count >= 12:
#                         #print('1yr')
#                         dbt_last1_yr.append(1)
#                         if count >= 24:
#                             #print('2yr')
#                             dbt_last2_yr.append(1)
#                             if count >= 36:
#                                 #print('3yr')
#                                 dbt_last3_yr.append(1)
#                             else:
#                                 dbt_last3_yr.append(0)
#                         else:
#                             dbt_last2_yr.append(0)
#                             dbt_last3_yr.append(0)
#                     else:
#                         dbt_last1_yr.append(0)
#                         dbt_last2_yr.append(0)
#                         dbt_last3_yr.append(0)
#                 else:
#                     dbt_last6_mon.append(0)
#                     dbt_last1_yr.append(0)
#                     dbt_last2_yr.append(0)
#                     dbt_last3_yr.append(0)
#             else:
#                 dbt_last3_mon.append(0)
#                 dbt_last6_mon.append(0)
#                 dbt_last1_yr.append(0)
#                 dbt_last2_yr.append(0)
#                 dbt_last3_yr.append(0)
#         else:
#             dbt_last1_mon.append(0)
#             dbt_last3_mon.append(0)
#             dbt_last6_mon.append(0)
#             dbt_last1_yr.append(0)
#             dbt_last2_yr.append(0)
#             dbt_last3_yr.append(0)
#     else:
#         dbt_last1_mon.append(0)
#         dbt_last3_mon.append(0)
#         dbt_last6_mon.append(0)
#         dbt_last1_yr.append(0)
#         dbt_last2_yr.append(0)
#         dbt_last3_yr.append(0)
#
#     count = 0
#     piece = list()
#
# df['DBT1M_flag'] = pd.Series(dbt_last1_mon).values
# df['DBT3M_flag'] = pd.Series(dbt_last3_mon).values
# df['DBT6M_flag'] = pd.Series(dbt_last6_mon).values
# df['DBT1Y_flag'] = pd.Series(dbt_last1_yr).values
# df['DBT2Y_flag'] = pd.Series(dbt_last2_yr).values
# df['DBT3Y_flag'] = pd.Series(dbt_last3_yr).values

# %% [markdown]
# <a id='DBT_num'></a>
# ### Code for DBT (numerical)

# %% [markdown]
# - For an applicant, Count of all loans where DBT1M_flag =1
# - For an applicant, Count of all loans where DBT3M_flag =1
# - For an applicant, Count of all loans where DBT6M_flag =1
# - For an applicant, Count of all loans where DBT1Y_flag =1
# - For an applicant, Count of all loans where DBT2Y_flag =1
# - For an applicant, Count of all loans where DBT3Y_flag =1

# %%
DBT1M = list()
count_list_1m = list()
count_1m = 0

DBT3M = list()
count_list_3m = list()
count_3m = 0

DBT6M = list()
count_list_6m = list()
count_6m = 0

DBT1Y = list()
count_list_1y = list()
count_1y = 0

DBT2Y = list()
count_list_2y = list()
count_2y = 0

DBT3Y = list()
count_list_3y = list()
count_3y = 0

grp_df = df.groupby('ID')

for x in range(0, len(unq_id_list)):
    grp_slice = grp_df.get_group(unq_id_list[x])
    #print(grp_slice)
    grp_slice.reset_index(drop=True, inplace=True)
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['DBT1M_flag'][i]==1) or (grp_slice['DBT1M_flag'][i]==0):
            count_1m = count_1m + grp_slice['DBT1M_flag'][i]
        
        if (grp_slice['DBT3M_flag'][i]==1) or (grp_slice['DBT3M_flag'][i]==0):
            count_3m = count_3m + grp_slice['DBT3M_flag'][i]

        if (grp_slice['DBT6M_flag'][i]==1) or (grp_slice['DBT6M_flag'][i]==0):
            count_6m = count_6m + grp_slice['DBT6M_flag'][i]

        if (grp_slice['DBT1Y_flag'][i]==1) or (grp_slice['DBT1Y_flag'][i]==0):
            count_1y = count_1y + grp_slice['DBT1Y_flag'][i]

        if (grp_slice['DBT2Y_flag'][i]==1) or (grp_slice['DBT2Y_flag'][i]==0):
            count_2y = count_2y + grp_slice['DBT2Y_flag'][i]

        if (grp_slice['DBT3Y_flag'][i]==1) or (grp_slice['DBT3Y_flag'][i]==0):
            count_3y = count_3y + grp_slice['DBT3Y_flag'][i]


    count_list_1m.append(count_1m)
    count_1m = 0
    count_list_3m.append(count_3m)
    count_3m = 0
    count_list_6m.append(count_6m)
    count_6m = 0
    count_list_1y.append(count_1y)
    count_1y = 0
    count_list_2y.append(count_2y)
    count_2y = 0
    count_list_3y.append(count_3y)
    count_3y = 0

    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['DBT1M_flag'][i]==1) or (grp_slice['DBT1M_flag'][i]==0):
            DBT1M.append(count_list_1m[x])
        else:
            DBT1M.append('unknown')

        if (grp_slice['DBT3M_flag'][i]==1) or (grp_slice['DBT3M_flag'][i]==0):
            DBT3M.append(count_list_3m[x])
        else:
            DBT3M.append('unknown')
        
        if (grp_slice['DBT6M_flag'][i]==1) or (grp_slice['DBT6M_flag'][i]==0):
            DBT6M.append(count_list_6m[x])
        else:
            DBT6M.append('unknown')

        if (grp_slice['DBT1Y_flag'][i]==1) or (grp_slice['DBT1Y_flag'][i]==0):
            DBT1Y.append(count_list_1y[x])
        else:
            DBT1Y.append('unknown')

        if (grp_slice['DBT2Y_flag'][i]==1) or (grp_slice['DBT2Y_flag'][i]==0):
            DBT2Y.append(count_list_2y[x])
        else:
            DBT2Y.append('unknown')
        
        if (grp_slice['DBT3Y_flag'][i]==1) or (grp_slice['DBT3Y_flag'][i]==0):
            DBT3Y.append(count_list_3y[x])
        else:
            DBT3Y.append('unknown')
            
df['DBT1M'] = pd.Series(DBT1M).values
df['DBT3M'] = pd.Series(DBT3M).values
df['DBT6M'] = pd.Series(DBT6M).values
df['DBT1Y'] = pd.Series(DBT1Y).values
df['DBT2Y'] = pd.Series(DBT2Y).values
df['DBT3Y'] = pd.Series(DBT3Y).values
#print(df['DBT3Y'].value_counts())

# %% [markdown]
# ### Code for DBT1M_P
# - DBT in last 1 month productwise

# %%
DBT1M_AL = list()
DBT1M_BL = list()
DBT1M_CC = list()
DBT1M_CD = list()
DBT1M_CV = list()
DBT1M_GL = list()
DBT1M_HL = list()
DBT1M_LAS = list()
DBT1M_MFBL = list()
DBT1M_MFHL = list()
DBT1M_MFOT = list()
DBT1M_OTH = list()
DBT1M_PL = list()
DBT1M_PLBL = list()
DBT1M_RL = list()
DBT1M_SCC = list()
DBT1M_SEL = list()

count_list_AL = list()
count_list_BL = list()
count_list_CC = list()
count_list_CD = list()
count_list_CV = list()
count_list_GL = list()
count_list_HL = list()
count_list_LAS = list()
count_list_MFBL = list()
count_list_MFHL = list()
count_list_MFOT = list()
count_list_OTH = list()
count_list_PL = list()
count_list_PLBL = list()
count_list_RL = list()
count_list_SCC = list()
count_list_SEL = list()

count_AL = 0
count_BL = 0
count_CC = 0
count_CD = 0
count_CV = 0
count_GL = 0
count_HL = 0
count_LAS = 0
count_MFBL = 0
count_MFHL = 0
count_MFOT = 0
count_OTH = 0
count_PL = 0 
count_PLBL = 0
count_RL = 0
count_SCC = 0
count_SEL = 0

grp_df = df.groupby('ID')

for x in range(0, len(unq_id_list)):
    grp_slice = grp_df.get_group(unq_id_list[x])
    #print(grp_slice)
    grp_slice.reset_index(drop=True, inplace=True)
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['accountType'][i]=='unknown'):
            continue
        elif (grp_slice['accountType'][i]=='AL') and (grp_slice['DBT1M_flag'][i]==1):
            count_AL = count_AL + 1
        elif (grp_slice['accountType'][i]=='BL') and (grp_slice['DBT1M_flag'][i]==1):
            count_BL = count_BL + 1
        elif (grp_slice['accountType'][i]=='CC') and (grp_slice['DBT1M_flag'][i]==1):
            count_CC = count_CC + 1
        elif (grp_slice['accountType'][i]=='CD') and (grp_slice['DBT1M_flag'][i]==1):
            count_CD = count_CD + 1
        elif (grp_slice['accountType'][i]=='CV') and (grp_slice['DBT1M_flag'][i]==1):
            count_CV = count_CV + 1
        elif (grp_slice['accountType'][i]=='GL') and (grp_slice['DBT1M_flag'][i]==1):
            count_GL = count_GL + 1
        elif (grp_slice['accountType'][i]=='HL') and (grp_slice['DBT1M_flag'][i]==1):
            count_HL = count_HL + 1
        elif (grp_slice['accountType'][i]=='LAS') and (grp_slice['DBT1M_flag'][i]==1):
            count_LAS = count_LAS + 1
        elif (grp_slice['accountType'][i]=='MFBL') and (grp_slice['DBT1M_flag'][i]==1):
            count_MFBL = count_MFBL + 1
        elif (grp_slice['accountType'][i]=='MFHL') and (grp_slice['DBT1M_flag'][i]==1):
            count_MFHL = count_MFHL + 1
        elif (grp_slice['accountType'][i]=='MFOT') and (grp_slice['DBT1M_flag'][i]==1):
            count_MFOT = count_MFOT + 1
        elif (grp_slice['accountType'][i]=='OTH') and (grp_slice['DBT1M_flag'][i]==1):
            count_OTH = count_OTH + 1
        elif (grp_slice['accountType'][i]=='PL') and (grp_slice['DBT1M_flag'][i]==1):
            count_PL = count_PL + 1
        elif (grp_slice['accountType'][i]=='PLBL') and (grp_slice['DBT1M_flag'][i]==1):
            count_PLBL = count_PLBL + 1
        elif (grp_slice['accountType'][i]=='RL') and (grp_slice['DBT1M_flag'][i]==1):
            count_RL = count_RL + 1
        elif (grp_slice['accountType'][i]=='SCC') and (grp_slice['DBT1M_flag'][i]==1):
            count_SCC = count_SCC + 1
        elif (grp_slice['accountType'][i]=='SEL') and (grp_slice['DBT1M_flag'][i]==1):
            count_SEL = count_SEL + 1
            
    count_list_AL.append(count_AL)
    count_list_BL.append(count_BL)
    count_list_CC.append(count_CC)
    count_list_CD.append(count_CD)
    count_list_CV.append(count_CV)
    count_list_GL.append(count_GL)
    count_list_HL.append(count_HL)
    count_list_LAS.append(count_LAS)
    count_list_MFBL.append(count_MFBL)
    count_list_MFHL.append(count_MFHL)
    count_list_MFOT.append(count_MFOT)
    count_list_OTH.append(count_OTH)
    count_list_PL.append(count_PL)
    count_list_PLBL.append(count_PLBL)
    count_list_RL.append(count_RL)
    count_list_SCC.append(count_SCC)
    count_list_SEL.append(count_SEL)
    
    count_AL = 0
    count_BL = 0
    count_CC = 0
    count_CD = 0
    count_CV = 0
    count_GL = 0
    count_HL = 0
    count_LAS = 0
    count_MFBL = 0
    count_MFHL = 0
    count_MFOT = 0
    count_OTH = 0
    count_PL = 0
    count_PLBL = 0
    count_RL = 0
    count_SCC = 0
    count_SEL = 0
    
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['accountType'][i]=='unknown'):
            DBT1M_AL.append('unknown')
            DBT1M_BL.append('unknown')
            DBT1M_CC.append('unknown')
            DBT1M_CD.append('unknown')
            DBT1M_CV.append('unknown')
            DBT1M_GL.append('unknown')
            DBT1M_HL.append('unknown')
            DBT1M_LAS.append('unknown')
            DBT1M_MFBL.append('unknown')
            DBT1M_MFHL.append('unknown')
            DBT1M_MFOT.append('unknown')
            DBT1M_OTH.append('unknown')
            DBT1M_PL.append('unknown')
            DBT1M_PLBL.append('unknown')
            DBT1M_RL.append('unknown')
            DBT1M_SCC.append('unknown')
            DBT1M_SEL.append('unknown')
        else:
            DBT1M_AL.append(count_list_AL[x])
            DBT1M_BL.append(count_list_BL[x])
            DBT1M_CC.append(count_list_CC[x])
            DBT1M_CD.append(count_list_CD[x])
            DBT1M_CV.append(count_list_CV[x])
            DBT1M_GL.append(count_list_GL[x])
            DBT1M_HL.append(count_list_HL[x])
            DBT1M_LAS.append(count_list_LAS[x])
            DBT1M_MFBL.append(count_list_MFBL[x])
            DBT1M_MFHL.append(count_list_MFHL[x])
            DBT1M_MFOT.append(count_list_MFOT[x])
            DBT1M_OTH.append(count_list_OTH[x])
            DBT1M_PL.append(count_list_PL[x])
            DBT1M_PLBL.append(count_list_PLBL[x])
            DBT1M_RL.append(count_list_RL[x])
            DBT1M_SCC.append(count_list_SCC[x])
            DBT1M_SEL.append(count_list_SEL[x])
            
df['DBT1M_AL'] = pd.Series(DBT1M_AL).values
df['DBT1M_BL'] = pd.Series(DBT1M_BL).values
df['DBT1M_CC'] = pd.Series(DBT1M_CC).values
df['DBT1M_CD'] = pd.Series(DBT1M_CD).values
df['DBT1M_CV'] = pd.Series(DBT1M_CV).values
df['DBT1M_GL'] = pd.Series(DBT1M_GL).values
df['DBT1M_HL'] = pd.Series(DBT1M_HL).values
df['DBT1M_LAS'] = pd.Series(DBT1M_LAS).values
df['DBT1M_MFBL'] = pd.Series(DBT1M_MFBL).values
df['DBT1M_MFHL'] = pd.Series(DBT1M_MFHL).values
df['DBT1M_MFOT'] = pd.Series(DBT1M_MFOT).values
df['DBT1M_OTH'] = pd.Series(DBT1M_OTH).values
df['DBT1M_PL'] = pd.Series(DBT1M_PL).values
df['DBT1M_PLBL'] = pd.Series(DBT1M_PLBL).values
df['DBT1M_RL'] = pd.Series(DBT1M_RL).values
df['DBT1M_SCC'] = pd.Series(DBT1M_SCC).values
df['DBT1M_SEL'] = pd.Series(DBT1M_SEL).values

# %% [raw]
# d = df[['ID','DBT1M_GL','DBT1M_flag','accountType']]
# d[d['DBT1M_flag']!=0].head(60)

# %% [markdown]
# ### Code for DBT3M_P
# - DBT in last 3 month productwise

# %%
DBT3M_AL = list()
DBT3M_BL = list()
DBT3M_CC = list()
DBT3M_CD = list()
DBT3M_CV = list()
DBT3M_GL = list()
DBT3M_HL = list()
DBT3M_LAS = list()
DBT3M_MFBL = list()
DBT3M_MFHL = list()
DBT3M_MFOT = list()
DBT3M_OTH = list()
DBT3M_PL = list()
DBT3M_PLBL = list()
DBT3M_RL = list()
DBT3M_SCC = list()
DBT3M_SEL = list()

count_list_AL = list()
count_list_BL = list()
count_list_CC = list()
count_list_CD = list()
count_list_CV = list()
count_list_GL = list()
count_list_HL = list()
count_list_LAS = list()
count_list_MFBL = list()
count_list_MFHL = list()
count_list_MFOT = list()
count_list_OTH = list()
count_list_PL = list()
count_list_PLBL = list()
count_list_RL = list()
count_list_SCC = list()
count_list_SEL = list()

count_AL = 0
count_BL = 0
count_CC = 0
count_CD = 0
count_CV = 0
count_GL = 0
count_HL = 0
count_LAS = 0
count_MFBL = 0
count_MFHL = 0
count_MFOT = 0
count_OTH = 0
count_PL = 0 
count_PLBL = 0
count_RL = 0
count_SCC = 0
count_SEL = 0

grp_df = df.groupby('ID')

for x in range(0, len(unq_id_list)):
    grp_slice = grp_df.get_group(unq_id_list[x])
    #print(grp_slice)
    grp_slice.reset_index(drop=True, inplace=True)
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['accountType'][i]=='unknown'):
            continue
        elif (grp_slice['accountType'][i]=='AL') and (grp_slice['DBT3M_flag'][i]==1):
            count_AL = count_AL + 1
        elif (grp_slice['accountType'][i]=='BL') and (grp_slice['DBT3M_flag'][i]==1):
            count_BL = count_BL + 1
        elif (grp_slice['accountType'][i]=='CC') and (grp_slice['DBT3M_flag'][i]==1):
            count_CC = count_CC + 1
        elif (grp_slice['accountType'][i]=='CD') and (grp_slice['DBT3M_flag'][i]==1):
            count_CD = count_CD + 1
        elif (grp_slice['accountType'][i]=='CV') and (grp_slice['DBT3M_flag'][i]==1):
            count_CV = count_CV + 1
        elif (grp_slice['accountType'][i]=='GL') and (grp_slice['DBT3M_flag'][i]==1):
            count_GL = count_GL + 1
        elif (grp_slice['accountType'][i]=='HL') and (grp_slice['DBT3M_flag'][i]==1):
            count_HL = count_HL + 1
        elif (grp_slice['accountType'][i]=='LAS') and (grp_slice['DBT3M_flag'][i]==1):
            count_LAS = count_LAS + 1
        elif (grp_slice['accountType'][i]=='MFBL') and (grp_slice['DBT3M_flag'][i]==1):
            count_MFBL = count_MFBL + 1
        elif (grp_slice['accountType'][i]=='MFHL') and (grp_slice['DBT3M_flag'][i]==1):
            count_MFHL = count_MFHL + 1
        elif (grp_slice['accountType'][i]=='MFOT') and (grp_slice['DBT3M_flag'][i]==1):
            count_MFOT = count_MFOT + 1
        elif (grp_slice['accountType'][i]=='OTH') and (grp_slice['DBT3M_flag'][i]==1):
            count_OTH = count_OTH + 1
        elif (grp_slice['accountType'][i]=='PL') and (grp_slice['DBT3M_flag'][i]==1):
            count_PL = count_PL + 1
        elif (grp_slice['accountType'][i]=='PLBL') and (grp_slice['DBT3M_flag'][i]==1):
            count_PLBL = count_PLBL + 1
        elif (grp_slice['accountType'][i]=='RL') and (grp_slice['DBT3M_flag'][i]==1):
            count_RL = count_RL + 1
        elif (grp_slice['accountType'][i]=='SCC') and (grp_slice['DBT3M_flag'][i]==1):
            count_SCC = count_SCC + 1
        elif (grp_slice['accountType'][i]=='SEL') and (grp_slice['DBT3M_flag'][i]==1):
            count_SEL = count_SEL + 1
            
    count_list_AL.append(count_AL)
    count_list_BL.append(count_BL)
    count_list_CC.append(count_CC)
    count_list_CD.append(count_CD)
    count_list_CV.append(count_CV)
    count_list_GL.append(count_GL)
    count_list_HL.append(count_HL)
    count_list_LAS.append(count_LAS)
    count_list_MFBL.append(count_MFBL)
    count_list_MFHL.append(count_MFHL)
    count_list_MFOT.append(count_MFOT)
    count_list_OTH.append(count_OTH)
    count_list_PL.append(count_PL)
    count_list_PLBL.append(count_PLBL)
    count_list_RL.append(count_RL)
    count_list_SCC.append(count_SCC)
    count_list_SEL.append(count_SEL)
    
    count_AL = 0
    count_BL = 0
    count_CC = 0
    count_CD = 0
    count_CV = 0
    count_GL = 0
    count_HL = 0
    count_LAS = 0
    count_MFBL = 0
    count_MFHL = 0
    count_MFOT = 0
    count_OTH = 0
    count_PL = 0
    count_PLBL = 0
    count_RL = 0
    count_SCC = 0
    count_SEL = 0
    
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['accountType'][i]=='unknown'):
            DBT3M_AL.append('unknown')
            DBT3M_BL.append('unknown')
            DBT3M_CC.append('unknown')
            DBT3M_CD.append('unknown')
            DBT3M_CV.append('unknown')
            DBT3M_GL.append('unknown')
            DBT3M_HL.append('unknown')
            DBT3M_LAS.append('unknown')
            DBT3M_MFBL.append('unknown')
            DBT3M_MFHL.append('unknown')
            DBT3M_MFOT.append('unknown')
            DBT3M_OTH.append('unknown')
            DBT3M_PL.append('unknown')
            DBT3M_PLBL.append('unknown')
            DBT3M_RL.append('unknown')
            DBT3M_SCC.append('unknown')
            DBT3M_SEL.append('unknown')
        else:
            DBT3M_AL.append(count_list_AL[x])
            DBT3M_BL.append(count_list_BL[x])
            DBT3M_CC.append(count_list_CC[x])
            DBT3M_CD.append(count_list_CD[x])
            DBT3M_CV.append(count_list_CV[x])
            DBT3M_GL.append(count_list_GL[x])
            DBT3M_HL.append(count_list_HL[x])
            DBT3M_LAS.append(count_list_LAS[x])
            DBT3M_MFBL.append(count_list_MFBL[x])
            DBT3M_MFHL.append(count_list_MFHL[x])
            DBT3M_MFOT.append(count_list_MFOT[x])
            DBT3M_OTH.append(count_list_OTH[x])
            DBT3M_PL.append(count_list_PL[x])
            DBT3M_PLBL.append(count_list_PLBL[x])
            DBT3M_RL.append(count_list_RL[x])
            DBT3M_SCC.append(count_list_SCC[x])
            DBT3M_SEL.append(count_list_SEL[x])
            
df['DBT3M_AL'] = pd.Series(DBT3M_AL).values
df['DBT3M_BL'] = pd.Series(DBT3M_BL).values
df['DBT3M_CC'] = pd.Series(DBT3M_CC).values
df['DBT3M_CD'] = pd.Series(DBT3M_CD).values
df['DBT3M_CV'] = pd.Series(DBT3M_CV).values
df['DBT3M_GL'] = pd.Series(DBT3M_GL).values
df['DBT3M_HL'] = pd.Series(DBT3M_HL).values
df['DBT3M_LAS'] = pd.Series(DBT3M_LAS).values
df['DBT3M_MFBL'] = pd.Series(DBT3M_MFBL).values
df['DBT3M_MFHL'] = pd.Series(DBT3M_MFHL).values
df['DBT3M_MFOT'] = pd.Series(DBT3M_MFOT).values
df['DBT3M_OTH'] = pd.Series(DBT3M_OTH).values
df['DBT3M_PL'] = pd.Series(DBT3M_PL).values
df['DBT3M_PLBL'] = pd.Series(DBT3M_PLBL).values
df['DBT3M_RL'] = pd.Series(DBT3M_RL).values
df['DBT3M_SCC'] = pd.Series(DBT3M_SCC).values
df['DBT3M_SEL'] = pd.Series(DBT3M_SEL).values

# %% [raw]
# d = df[['ID','DBT3M_GL','DBT3M_flag','accountType']]
# d[d['DBT3M_flag']!=0].head(60)

# %% [markdown]
# ### Code for DBT6M_P
# - DBT in last 6 month productwise

# %%
DBT6M_AL = list()
DBT6M_BL = list()
DBT6M_CC = list()
DBT6M_CD = list()
DBT6M_CV = list()
DBT6M_GL = list()
DBT6M_HL = list()
DBT6M_LAS = list()
DBT6M_MFBL = list()
DBT6M_MFHL = list()
DBT6M_MFOT = list()
DBT6M_OTH = list()
DBT6M_PL = list()
DBT6M_PLBL = list()
DBT6M_RL = list()
DBT6M_SCC = list()
DBT6M_SEL = list()

count_list_AL = list()
count_list_BL = list()
count_list_CC = list()
count_list_CD = list()
count_list_CV = list()
count_list_GL = list()
count_list_HL = list()
count_list_LAS = list()
count_list_MFBL = list()
count_list_MFHL = list()
count_list_MFOT = list()
count_list_OTH = list()
count_list_PL = list()
count_list_PLBL = list()
count_list_RL = list()
count_list_SCC = list()
count_list_SEL = list()

count_AL = 0
count_BL = 0
count_CC = 0
count_CD = 0
count_CV = 0
count_GL = 0
count_HL = 0
count_LAS = 0
count_MFBL = 0
count_MFHL = 0
count_MFOT = 0
count_OTH = 0
count_PL = 0 
count_PLBL = 0
count_RL = 0
count_SCC = 0
count_SEL = 0

grp_df = df.groupby('ID')

for x in range(0, len(unq_id_list)):
    grp_slice = grp_df.get_group(unq_id_list[x])
    #print(grp_slice)
    grp_slice.reset_index(drop=True, inplace=True)
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['accountType'][i]=='unknown'):
            continue
        elif (grp_slice['accountType'][i]=='AL') and (grp_slice['DBT6M_flag'][i]==1):
            count_AL = count_AL + 1
        elif (grp_slice['accountType'][i]=='BL') and (grp_slice['DBT6M_flag'][i]==1):
            count_BL = count_BL + 1
        elif (grp_slice['accountType'][i]=='CC') and (grp_slice['DBT6M_flag'][i]==1):
            count_CC = count_CC + 1
        elif (grp_slice['accountType'][i]=='CD') and (grp_slice['DBT6M_flag'][i]==1):
            count_CD = count_CD + 1
        elif (grp_slice['accountType'][i]=='CV') and (grp_slice['DBT6M_flag'][i]==1):
            count_CV = count_CV + 1
        elif (grp_slice['accountType'][i]=='GL') and (grp_slice['DBT6M_flag'][i]==1):
            count_GL = count_GL + 1
        elif (grp_slice['accountType'][i]=='HL') and (grp_slice['DBT6M_flag'][i]==1):
            count_HL = count_HL + 1
        elif (grp_slice['accountType'][i]=='LAS') and (grp_slice['DBT6M_flag'][i]==1):
            count_LAS = count_LAS + 1
        elif (grp_slice['accountType'][i]=='MFBL') and (grp_slice['DBT6M_flag'][i]==1):
            count_MFBL = count_MFBL + 1
        elif (grp_slice['accountType'][i]=='MFHL') and (grp_slice['DBT6M_flag'][i]==1):
            count_MFHL = count_MFHL + 1
        elif (grp_slice['accountType'][i]=='MFOT') and (grp_slice['DBT6M_flag'][i]==1):
            count_MFOT = count_MFOT + 1
        elif (grp_slice['accountType'][i]=='OTH') and (grp_slice['DBT6M_flag'][i]==1):
            count_OTH = count_OTH + 1
        elif (grp_slice['accountType'][i]=='PL') and (grp_slice['DBT6M_flag'][i]==1):
            count_PL = count_PL + 1
        elif (grp_slice['accountType'][i]=='PLBL') and (grp_slice['DBT6M_flag'][i]==1):
            count_PLBL = count_PLBL + 1
        elif (grp_slice['accountType'][i]=='RL') and (grp_slice['DBT6M_flag'][i]==1):
            count_RL = count_RL + 1
        elif (grp_slice['accountType'][i]=='SCC') and (grp_slice['DBT6M_flag'][i]==1):
            count_SCC = count_SCC + 1
        elif (grp_slice['accountType'][i]=='SEL') and (grp_slice['DBT6M_flag'][i]==1):
            count_SEL = count_SEL + 1
            
    count_list_AL.append(count_AL)
    count_list_BL.append(count_BL)
    count_list_CC.append(count_CC)
    count_list_CD.append(count_CD)
    count_list_CV.append(count_CV)
    count_list_GL.append(count_GL)
    count_list_HL.append(count_HL)
    count_list_LAS.append(count_LAS)
    count_list_MFBL.append(count_MFBL)
    count_list_MFHL.append(count_MFHL)
    count_list_MFOT.append(count_MFOT)
    count_list_OTH.append(count_OTH)
    count_list_PL.append(count_PL)
    count_list_PLBL.append(count_PLBL)
    count_list_RL.append(count_RL)
    count_list_SCC.append(count_SCC)
    count_list_SEL.append(count_SEL)
    
    count_AL = 0
    count_BL = 0
    count_CC = 0
    count_CD = 0
    count_CV = 0
    count_GL = 0
    count_HL = 0
    count_LAS = 0
    count_MFBL = 0
    count_MFHL = 0
    count_MFOT = 0
    count_OTH = 0
    count_PL = 0
    count_PLBL = 0
    count_RL = 0
    count_SCC = 0
    count_SEL = 0
    
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['accountType'][i]=='unknown'):
            DBT6M_AL.append('unknown')
            DBT6M_BL.append('unknown')
            DBT6M_CC.append('unknown')
            DBT6M_CD.append('unknown')
            DBT6M_CV.append('unknown')
            DBT6M_GL.append('unknown')
            DBT6M_HL.append('unknown')
            DBT6M_LAS.append('unknown')
            DBT6M_MFBL.append('unknown')
            DBT6M_MFHL.append('unknown')
            DBT6M_MFOT.append('unknown')
            DBT6M_OTH.append('unknown')
            DBT6M_PL.append('unknown')
            DBT6M_PLBL.append('unknown')
            DBT6M_RL.append('unknown')
            DBT6M_SCC.append('unknown')
            DBT6M_SEL.append('unknown')
        else:
            DBT6M_AL.append(count_list_AL[x])
            DBT6M_BL.append(count_list_BL[x])
            DBT6M_CC.append(count_list_CC[x])
            DBT6M_CD.append(count_list_CD[x])
            DBT6M_CV.append(count_list_CV[x])
            DBT6M_GL.append(count_list_GL[x])
            DBT6M_HL.append(count_list_HL[x])
            DBT6M_LAS.append(count_list_LAS[x])
            DBT6M_MFBL.append(count_list_MFBL[x])
            DBT6M_MFHL.append(count_list_MFHL[x])
            DBT6M_MFOT.append(count_list_MFOT[x])
            DBT6M_OTH.append(count_list_OTH[x])
            DBT6M_PL.append(count_list_PL[x])
            DBT6M_PLBL.append(count_list_PLBL[x])
            DBT6M_RL.append(count_list_RL[x])
            DBT6M_SCC.append(count_list_SCC[x])
            DBT6M_SEL.append(count_list_SEL[x])
            
df['DBT6M_AL'] = pd.Series(DBT6M_AL).values
df['DBT6M_BL'] = pd.Series(DBT6M_BL).values
df['DBT6M_CC'] = pd.Series(DBT6M_CC).values
df['DBT6M_CD'] = pd.Series(DBT6M_CD).values
df['DBT6M_CV'] = pd.Series(DBT6M_CV).values
df['DBT6M_GL'] = pd.Series(DBT6M_GL).values
df['DBT6M_HL'] = pd.Series(DBT6M_HL).values
df['DBT6M_LAS'] = pd.Series(DBT6M_LAS).values
df['DBT6M_MFBL'] = pd.Series(DBT6M_MFBL).values
df['DBT6M_MFHL'] = pd.Series(DBT6M_MFHL).values
df['DBT6M_MFOT'] = pd.Series(DBT6M_MFOT).values
df['DBT6M_OTH'] = pd.Series(DBT6M_OTH).values
df['DBT6M_PL'] = pd.Series(DBT6M_PL).values
df['DBT6M_PLBL'] = pd.Series(DBT6M_PLBL).values
df['DBT6M_RL'] = pd.Series(DBT6M_RL).values
df['DBT6M_SCC'] = pd.Series(DBT6M_SCC).values
df['DBT6M_SEL'] = pd.Series(DBT6M_SEL).values

# %% [raw]
# d = df[['ID','DBT6M_GL','DBT6M_flag','accountType']]
# d[d['DBT6M_flag']!=0].head(60)

# %% [markdown]
# ### Code for DBT1Y_P
# - DBT in last 1 year productwise

# %%
DBT1Y_AL = list()
DBT1Y_BL = list()
DBT1Y_CC = list()
DBT1Y_CD = list()
DBT1Y_CV = list()
DBT1Y_GL = list()
DBT1Y_HL = list()
DBT1Y_LAS = list()
DBT1Y_MFBL = list()
DBT1Y_MFHL = list()
DBT1Y_MFOT = list()
DBT1Y_OTH = list()
DBT1Y_PL = list()
DBT1Y_PLBL = list()
DBT1Y_RL = list()
DBT1Y_SCC = list()
DBT1Y_SEL = list()

count_list_AL = list()
count_list_BL = list()
count_list_CC = list()
count_list_CD = list()
count_list_CV = list()
count_list_GL = list()
count_list_HL = list()
count_list_LAS = list()
count_list_MFBL = list()
count_list_MFHL = list()
count_list_MFOT = list()
count_list_OTH = list()
count_list_PL = list()
count_list_PLBL = list()
count_list_RL = list()
count_list_SCC = list()
count_list_SEL = list()

count_AL = 0
count_BL = 0
count_CC = 0
count_CD = 0
count_CV = 0
count_GL = 0
count_HL = 0
count_LAS = 0
count_MFBL = 0
count_MFHL = 0
count_MFOT = 0
count_OTH = 0
count_PL = 0 
count_PLBL = 0
count_RL = 0
count_SCC = 0
count_SEL = 0

grp_df = df.groupby('ID')

for x in range(0, len(unq_id_list)):
    grp_slice = grp_df.get_group(unq_id_list[x])
    #print(grp_slice)
    grp_slice.reset_index(drop=True, inplace=True)
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['accountType'][i]=='unknown'):
            continue
        elif (grp_slice['accountType'][i]=='AL') and (grp_slice['DBT1Y_flag'][i]==1):
            count_AL = count_AL + 1
        elif (grp_slice['accountType'][i]=='BL') and (grp_slice['DBT1Y_flag'][i]==1):
            count_BL = count_BL + 1
        elif (grp_slice['accountType'][i]=='CC') and (grp_slice['DBT1Y_flag'][i]==1):
            count_CC = count_CC + 1
        elif (grp_slice['accountType'][i]=='CD') and (grp_slice['DBT1Y_flag'][i]==1):
            count_CD = count_CD + 1
        elif (grp_slice['accountType'][i]=='CV') and (grp_slice['DBT1Y_flag'][i]==1):
            count_CV = count_CV + 1
        elif (grp_slice['accountType'][i]=='GL') and (grp_slice['DBT1Y_flag'][i]==1):
            count_GL = count_GL + 1
        elif (grp_slice['accountType'][i]=='HL') and (grp_slice['DBT1Y_flag'][i]==1):
            count_HL = count_HL + 1
        elif (grp_slice['accountType'][i]=='LAS') and (grp_slice['DBT1Y_flag'][i]==1):
            count_LAS = count_LAS + 1
        elif (grp_slice['accountType'][i]=='MFBL') and (grp_slice['DBT1Y_flag'][i]==1):
            count_MFBL = count_MFBL + 1
        elif (grp_slice['accountType'][i]=='MFHL') and (grp_slice['DBT1Y_flag'][i]==1):
            count_MFHL = count_MFHL + 1
        elif (grp_slice['accountType'][i]=='MFOT') and (grp_slice['DBT1Y_flag'][i]==1):
            count_MFOT = count_MFOT + 1
        elif (grp_slice['accountType'][i]=='OTH') and (grp_slice['DBT1Y_flag'][i]==1):
            count_OTH = count_OTH + 1
        elif (grp_slice['accountType'][i]=='PL') and (grp_slice['DBT1Y_flag'][i]==1):
            count_PL = count_PL + 1
        elif (grp_slice['accountType'][i]=='PLBL') and (grp_slice['DBT1Y_flag'][i]==1):
            count_PLBL = count_PLBL + 1
        elif (grp_slice['accountType'][i]=='RL') and (grp_slice['DBT1Y_flag'][i]==1):
            count_RL = count_RL + 1
        elif (grp_slice['accountType'][i]=='SCC') and (grp_slice['DBT1Y_flag'][i]==1):
            count_SCC = count_SCC + 1
        elif (grp_slice['accountType'][i]=='SEL') and (grp_slice['DBT1Y_flag'][i]==1):
            count_SEL = count_SEL + 1
            
    count_list_AL.append(count_AL)
    count_list_BL.append(count_BL)
    count_list_CC.append(count_CC)
    count_list_CD.append(count_CD)
    count_list_CV.append(count_CV)
    count_list_GL.append(count_GL)
    count_list_HL.append(count_HL)
    count_list_LAS.append(count_LAS)
    count_list_MFBL.append(count_MFBL)
    count_list_MFHL.append(count_MFHL)
    count_list_MFOT.append(count_MFOT)
    count_list_OTH.append(count_OTH)
    count_list_PL.append(count_PL)
    count_list_PLBL.append(count_PLBL)
    count_list_RL.append(count_RL)
    count_list_SCC.append(count_SCC)
    count_list_SEL.append(count_SEL)
    
    count_AL = 0
    count_BL = 0
    count_CC = 0
    count_CD = 0
    count_CV = 0
    count_GL = 0
    count_HL = 0
    count_LAS = 0
    count_MFBL = 0
    count_MFHL = 0
    count_MFOT = 0
    count_OTH = 0
    count_PL = 0
    count_PLBL = 0
    count_RL = 0
    count_SCC = 0
    count_SEL = 0
    
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['accountType'][i]=='unknown'):
            DBT1Y_AL.append('unknown')
            DBT1Y_BL.append('unknown')
            DBT1Y_CC.append('unknown')
            DBT1Y_CD.append('unknown')
            DBT1Y_CV.append('unknown')
            DBT1Y_GL.append('unknown')
            DBT1Y_HL.append('unknown')
            DBT1Y_LAS.append('unknown')
            DBT1Y_MFBL.append('unknown')
            DBT1Y_MFHL.append('unknown')
            DBT1Y_MFOT.append('unknown')
            DBT1Y_OTH.append('unknown')
            DBT1Y_PL.append('unknown')
            DBT1Y_PLBL.append('unknown')
            DBT1Y_RL.append('unknown')
            DBT1Y_SCC.append('unknown')
            DBT1Y_SEL.append('unknown')
        else:
            DBT1Y_AL.append(count_list_AL[x])
            DBT1Y_BL.append(count_list_BL[x])
            DBT1Y_CC.append(count_list_CC[x])
            DBT1Y_CD.append(count_list_CD[x])
            DBT1Y_CV.append(count_list_CV[x])
            DBT1Y_GL.append(count_list_GL[x])
            DBT1Y_HL.append(count_list_HL[x])
            DBT1Y_LAS.append(count_list_LAS[x])
            DBT1Y_MFBL.append(count_list_MFBL[x])
            DBT1Y_MFHL.append(count_list_MFHL[x])
            DBT1Y_MFOT.append(count_list_MFOT[x])
            DBT1Y_OTH.append(count_list_OTH[x])
            DBT1Y_PL.append(count_list_PL[x])
            DBT1Y_PLBL.append(count_list_PLBL[x])
            DBT1Y_RL.append(count_list_RL[x])
            DBT1Y_SCC.append(count_list_SCC[x])
            DBT1Y_SEL.append(count_list_SEL[x])
            
df['DBT1Y_AL'] = pd.Series(DBT1Y_AL).values
df['DBT1Y_BL'] = pd.Series(DBT1Y_BL).values
df['DBT1Y_CC'] = pd.Series(DBT1Y_CC).values
df['DBT1Y_CD'] = pd.Series(DBT1Y_CD).values
df['DBT1Y_CV'] = pd.Series(DBT1Y_CV).values
df['DBT1Y_GL'] = pd.Series(DBT1Y_GL).values
df['DBT1Y_HL'] = pd.Series(DBT1Y_HL).values
df['DBT1Y_LAS'] = pd.Series(DBT1Y_LAS).values
df['DBT1Y_MFBL'] = pd.Series(DBT1Y_MFBL).values
df['DBT1Y_MFHL'] = pd.Series(DBT1Y_MFHL).values
df['DBT1Y_MFOT'] = pd.Series(DBT1Y_MFOT).values
df['DBT1Y_OTH'] = pd.Series(DBT1Y_OTH).values
df['DBT1Y_PL'] = pd.Series(DBT1Y_PL).values
df['DBT1Y_PLBL'] = pd.Series(DBT1Y_PLBL).values
df['DBT1Y_RL'] = pd.Series(DBT1Y_RL).values
df['DBT1Y_SCC'] = pd.Series(DBT1Y_SCC).values
df['DBT1Y_SEL'] = pd.Series(DBT1Y_SEL).values

# %% [raw]
# d = df[['ID','DBT1Y_GL','DBT1Y_flag','accountType']]
# d[d['DBT1Y_flag']!=0].head(60)

# %% [markdown]
# ### Code for DBT2Y_P
# - DBT in last 2 year productwise

# %%
DBT2Y_AL = list()
DBT2Y_BL = list()
DBT2Y_CC = list()
DBT2Y_CD = list()
DBT2Y_CV = list()
DBT2Y_GL = list()
DBT2Y_HL = list()
DBT2Y_LAS = list()
DBT2Y_MFBL = list()
DBT2Y_MFHL = list()
DBT2Y_MFOT = list()
DBT2Y_OTH = list()
DBT2Y_PL = list()
DBT2Y_PLBL = list()
DBT2Y_RL = list()
DBT2Y_SCC = list()
DBT2Y_SEL = list()

count_list_AL = list()
count_list_BL = list()
count_list_CC = list()
count_list_CD = list()
count_list_CV = list()
count_list_GL = list()
count_list_HL = list()
count_list_LAS = list()
count_list_MFBL = list()
count_list_MFHL = list()
count_list_MFOT = list()
count_list_OTH = list()
count_list_PL = list()
count_list_PLBL = list()
count_list_RL = list()
count_list_SCC = list()
count_list_SEL = list()

count_AL = 0
count_BL = 0
count_CC = 0
count_CD = 0
count_CV = 0
count_GL = 0
count_HL = 0
count_LAS = 0
count_MFBL = 0
count_MFHL = 0
count_MFOT = 0
count_OTH = 0
count_PL = 0 
count_PLBL = 0
count_RL = 0
count_SCC = 0
count_SEL = 0

grp_df = df.groupby('ID')

for x in range(0, len(unq_id_list)):
    grp_slice = grp_df.get_group(unq_id_list[x])
    #print(grp_slice)
    grp_slice.reset_index(drop=True, inplace=True)
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['accountType'][i]=='unknown'):
            continue
        elif (grp_slice['accountType'][i]=='AL') and (grp_slice['DBT2Y_flag'][i]==1):
            count_AL = count_AL + 1
        elif (grp_slice['accountType'][i]=='BL') and (grp_slice['DBT2Y_flag'][i]==1):
            count_BL = count_BL + 1
        elif (grp_slice['accountType'][i]=='CC') and (grp_slice['DBT2Y_flag'][i]==1):
            count_CC = count_CC + 1
        elif (grp_slice['accountType'][i]=='CD') and (grp_slice['DBT2Y_flag'][i]==1):
            count_CD = count_CD + 1
        elif (grp_slice['accountType'][i]=='CV') and (grp_slice['DBT2Y_flag'][i]==1):
            count_CV = count_CV + 1
        elif (grp_slice['accountType'][i]=='GL') and (grp_slice['DBT2Y_flag'][i]==1):
            count_GL = count_GL + 1
        elif (grp_slice['accountType'][i]=='HL') and (grp_slice['DBT2Y_flag'][i]==1):
            count_HL = count_HL + 1
        elif (grp_slice['accountType'][i]=='LAS') and (grp_slice['DBT2Y_flag'][i]==1):
            count_LAS = count_LAS + 1
        elif (grp_slice['accountType'][i]=='MFBL') and (grp_slice['DBT2Y_flag'][i]==1):
            count_MFBL = count_MFBL + 1
        elif (grp_slice['accountType'][i]=='MFHL') and (grp_slice['DBT2Y_flag'][i]==1):
            count_MFHL = count_MFHL + 1
        elif (grp_slice['accountType'][i]=='MFOT') and (grp_slice['DBT2Y_flag'][i]==1):
            count_MFOT = count_MFOT + 1
        elif (grp_slice['accountType'][i]=='OTH') and (grp_slice['DBT2Y_flag'][i]==1):
            count_OTH = count_OTH + 1
        elif (grp_slice['accountType'][i]=='PL') and (grp_slice['DBT2Y_flag'][i]==1):
            count_PL = count_PL + 1
        elif (grp_slice['accountType'][i]=='PLBL') and (grp_slice['DBT2Y_flag'][i]==1):
            count_PLBL = count_PLBL + 1
        elif (grp_slice['accountType'][i]=='RL') and (grp_slice['DBT2Y_flag'][i]==1):
            count_RL = count_RL + 1
        elif (grp_slice['accountType'][i]=='SCC') and (grp_slice['DBT2Y_flag'][i]==1):
            count_SCC = count_SCC + 1
        elif (grp_slice['accountType'][i]=='SEL') and (grp_slice['DBT2Y_flag'][i]==1):
            count_SEL = count_SEL + 1
            
    count_list_AL.append(count_AL)
    count_list_BL.append(count_BL)
    count_list_CC.append(count_CC)
    count_list_CD.append(count_CD)
    count_list_CV.append(count_CV)
    count_list_GL.append(count_GL)
    count_list_HL.append(count_HL)
    count_list_LAS.append(count_LAS)
    count_list_MFBL.append(count_MFBL)
    count_list_MFHL.append(count_MFHL)
    count_list_MFOT.append(count_MFOT)
    count_list_OTH.append(count_OTH)
    count_list_PL.append(count_PL)
    count_list_PLBL.append(count_PLBL)
    count_list_RL.append(count_RL)
    count_list_SCC.append(count_SCC)
    count_list_SEL.append(count_SEL)
    
    count_AL = 0
    count_BL = 0
    count_CC = 0
    count_CD = 0
    count_CV = 0
    count_GL = 0
    count_HL = 0
    count_LAS = 0
    count_MFBL = 0
    count_MFHL = 0
    count_MFOT = 0
    count_OTH = 0
    count_PL = 0
    count_PLBL = 0
    count_RL = 0
    count_SCC = 0
    count_SEL = 0
    
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['accountType'][i]=='unknown'):
            DBT2Y_AL.append('unknown')
            DBT2Y_BL.append('unknown')
            DBT2Y_CC.append('unknown')
            DBT2Y_CD.append('unknown')
            DBT2Y_CV.append('unknown')
            DBT2Y_GL.append('unknown')
            DBT2Y_HL.append('unknown')
            DBT2Y_LAS.append('unknown')
            DBT2Y_MFBL.append('unknown')
            DBT2Y_MFHL.append('unknown')
            DBT2Y_MFOT.append('unknown')
            DBT2Y_OTH.append('unknown')
            DBT2Y_PL.append('unknown')
            DBT2Y_PLBL.append('unknown')
            DBT2Y_RL.append('unknown')
            DBT2Y_SCC.append('unknown')
            DBT2Y_SEL.append('unknown')
        else:
            DBT2Y_AL.append(count_list_AL[x])
            DBT2Y_BL.append(count_list_BL[x])
            DBT2Y_CC.append(count_list_CC[x])
            DBT2Y_CD.append(count_list_CD[x])
            DBT2Y_CV.append(count_list_CV[x])
            DBT2Y_GL.append(count_list_GL[x])
            DBT2Y_HL.append(count_list_HL[x])
            DBT2Y_LAS.append(count_list_LAS[x])
            DBT2Y_MFBL.append(count_list_MFBL[x])
            DBT2Y_MFHL.append(count_list_MFHL[x])
            DBT2Y_MFOT.append(count_list_MFOT[x])
            DBT2Y_OTH.append(count_list_OTH[x])
            DBT2Y_PL.append(count_list_PL[x])
            DBT2Y_PLBL.append(count_list_PLBL[x])
            DBT2Y_RL.append(count_list_RL[x])
            DBT2Y_SCC.append(count_list_SCC[x])
            DBT2Y_SEL.append(count_list_SEL[x])
            
df['DBT2Y_AL'] = pd.Series(DBT2Y_AL).values
df['DBT2Y_BL'] = pd.Series(DBT2Y_BL).values
df['DBT2Y_CC'] = pd.Series(DBT2Y_CC).values
df['DBT2Y_CD'] = pd.Series(DBT2Y_CD).values
df['DBT2Y_CV'] = pd.Series(DBT2Y_CV).values
df['DBT2Y_GL'] = pd.Series(DBT2Y_GL).values
df['DBT2Y_HL'] = pd.Series(DBT2Y_HL).values
df['DBT2Y_LAS'] = pd.Series(DBT2Y_LAS).values
df['DBT2Y_MFBL'] = pd.Series(DBT2Y_MFBL).values
df['DBT2Y_MFHL'] = pd.Series(DBT2Y_MFHL).values
df['DBT2Y_MFOT'] = pd.Series(DBT2Y_MFOT).values
df['DBT2Y_OTH'] = pd.Series(DBT2Y_OTH).values
df['DBT2Y_PL'] = pd.Series(DBT2Y_PL).values
df['DBT2Y_PLBL'] = pd.Series(DBT2Y_PLBL).values
df['DBT2Y_RL'] = pd.Series(DBT2Y_RL).values
df['DBT2Y_SCC'] = pd.Series(DBT2Y_SCC).values
df['DBT2Y_SEL'] = pd.Series(DBT2Y_SEL).values

# %% [raw]
# d = df[['ID','DBT2Y_GL','DBT2Y_flag','accountType']]
# d[d['DBT2Y_flag']!=0].head(60)

# %% [markdown]
# ### Code for DBT3Y_P
# - DBT in last 3 year productwise

# %%
DBT3Y_AL = list()
DBT3Y_BL = list()
DBT3Y_CC = list()
DBT3Y_CD = list()
DBT3Y_CV = list()
DBT3Y_GL = list()
DBT3Y_HL = list()
DBT3Y_LAS = list()
DBT3Y_MFBL = list()
DBT3Y_MFHL = list()
DBT3Y_MFOT = list()
DBT3Y_OTH = list()
DBT3Y_PL = list()
DBT3Y_PLBL = list()
DBT3Y_RL = list()
DBT3Y_SCC = list()
DBT3Y_SEL = list()

count_list_AL = list()
count_list_BL = list()
count_list_CC = list()
count_list_CD = list()
count_list_CV = list()
count_list_GL = list()
count_list_HL = list()
count_list_LAS = list()
count_list_MFBL = list()
count_list_MFHL = list()
count_list_MFOT = list()
count_list_OTH = list()
count_list_PL = list()
count_list_PLBL = list()
count_list_RL = list()
count_list_SCC = list()
count_list_SEL = list()

count_AL = 0
count_BL = 0
count_CC = 0
count_CD = 0
count_CV = 0
count_GL = 0
count_HL = 0
count_LAS = 0
count_MFBL = 0
count_MFHL = 0
count_MFOT = 0
count_OTH = 0
count_PL = 0 
count_PLBL = 0
count_RL = 0
count_SCC = 0
count_SEL = 0

grp_df = df.groupby('ID')

for x in range(0, len(unq_id_list)):
    grp_slice = grp_df.get_group(unq_id_list[x])
    #print(grp_slice)
    grp_slice.reset_index(drop=True, inplace=True)
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['accountType'][i]=='unknown'):
            continue
        elif (grp_slice['accountType'][i]=='AL') and (grp_slice['DBT3Y_flag'][i]==1):
            count_AL = count_AL + 1
        elif (grp_slice['accountType'][i]=='BL') and (grp_slice['DBT3Y_flag'][i]==1):
            count_BL = count_BL + 1
        elif (grp_slice['accountType'][i]=='CC') and (grp_slice['DBT3Y_flag'][i]==1):
            count_CC = count_CC + 1
        elif (grp_slice['accountType'][i]=='CD') and (grp_slice['DBT3Y_flag'][i]==1):
            count_CD = count_CD + 1
        elif (grp_slice['accountType'][i]=='CV') and (grp_slice['DBT3Y_flag'][i]==1):
            count_CV = count_CV + 1
        elif (grp_slice['accountType'][i]=='GL') and (grp_slice['DBT3Y_flag'][i]==1):
            count_GL = count_GL + 1
        elif (grp_slice['accountType'][i]=='HL') and (grp_slice['DBT3Y_flag'][i]==1):
            count_HL = count_HL + 1
        elif (grp_slice['accountType'][i]=='LAS') and (grp_slice['DBT3Y_flag'][i]==1):
            count_LAS = count_LAS + 1
        elif (grp_slice['accountType'][i]=='MFBL') and (grp_slice['DBT3Y_flag'][i]==1):
            count_MFBL = count_MFBL + 1
        elif (grp_slice['accountType'][i]=='MFHL') and (grp_slice['DBT3Y_flag'][i]==1):
            count_MFHL = count_MFHL + 1
        elif (grp_slice['accountType'][i]=='MFOT') and (grp_slice['DBT3Y_flag'][i]==1):
            count_MFOT = count_MFOT + 1
        elif (grp_slice['accountType'][i]=='OTH') and (grp_slice['DBT3Y_flag'][i]==1):
            count_OTH = count_OTH + 1
        elif (grp_slice['accountType'][i]=='PL') and (grp_slice['DBT3Y_flag'][i]==1):
            count_PL = count_PL + 1
        elif (grp_slice['accountType'][i]=='PLBL') and (grp_slice['DBT3Y_flag'][i]==1):
            count_PLBL = count_PLBL + 1
        elif (grp_slice['accountType'][i]=='RL') and (grp_slice['DBT3Y_flag'][i]==1):
            count_RL = count_RL + 1
        elif (grp_slice['accountType'][i]=='SCC') and (grp_slice['DBT3Y_flag'][i]==1):
            count_SCC = count_SCC + 1
        elif (grp_slice['accountType'][i]=='SEL') and (grp_slice['DBT3Y_flag'][i]==1):
            count_SEL = count_SEL + 1
            
    count_list_AL.append(count_AL)
    count_list_BL.append(count_BL)
    count_list_CC.append(count_CC)
    count_list_CD.append(count_CD)
    count_list_CV.append(count_CV)
    count_list_GL.append(count_GL)
    count_list_HL.append(count_HL)
    count_list_LAS.append(count_LAS)
    count_list_MFBL.append(count_MFBL)
    count_list_MFHL.append(count_MFHL)
    count_list_MFOT.append(count_MFOT)
    count_list_OTH.append(count_OTH)
    count_list_PL.append(count_PL)
    count_list_PLBL.append(count_PLBL)
    count_list_RL.append(count_RL)
    count_list_SCC.append(count_SCC)
    count_list_SEL.append(count_SEL)
    
    count_AL = 0
    count_BL = 0
    count_CC = 0
    count_CD = 0
    count_CV = 0
    count_GL = 0
    count_HL = 0
    count_LAS = 0
    count_MFBL = 0
    count_MFHL = 0
    count_MFOT = 0
    count_OTH = 0
    count_PL = 0
    count_PLBL = 0
    count_RL = 0
    count_SCC = 0
    count_SEL = 0
    
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['accountType'][i]=='unknown'):
            DBT3Y_AL.append('unknown')
            DBT3Y_BL.append('unknown')
            DBT3Y_CC.append('unknown')
            DBT3Y_CD.append('unknown')
            DBT3Y_CV.append('unknown')
            DBT3Y_GL.append('unknown')
            DBT3Y_HL.append('unknown')
            DBT3Y_LAS.append('unknown')
            DBT3Y_MFBL.append('unknown')
            DBT3Y_MFHL.append('unknown')
            DBT3Y_MFOT.append('unknown')
            DBT3Y_OTH.append('unknown')
            DBT3Y_PL.append('unknown')
            DBT3Y_PLBL.append('unknown')
            DBT3Y_RL.append('unknown')
            DBT3Y_SCC.append('unknown')
            DBT3Y_SEL.append('unknown')
        else:
            DBT3Y_AL.append(count_list_AL[x])
            DBT3Y_BL.append(count_list_BL[x])
            DBT3Y_CC.append(count_list_CC[x])
            DBT3Y_CD.append(count_list_CD[x])
            DBT3Y_CV.append(count_list_CV[x])
            DBT3Y_GL.append(count_list_GL[x])
            DBT3Y_HL.append(count_list_HL[x])
            DBT3Y_LAS.append(count_list_LAS[x])
            DBT3Y_MFBL.append(count_list_MFBL[x])
            DBT3Y_MFHL.append(count_list_MFHL[x])
            DBT3Y_MFOT.append(count_list_MFOT[x])
            DBT3Y_OTH.append(count_list_OTH[x])
            DBT3Y_PL.append(count_list_PL[x])
            DBT3Y_PLBL.append(count_list_PLBL[x])
            DBT3Y_RL.append(count_list_RL[x])
            DBT3Y_SCC.append(count_list_SCC[x])
            DBT3Y_SEL.append(count_list_SEL[x])
            
df['DBT3Y_AL'] = pd.Series(DBT3Y_AL).values
df['DBT3Y_BL'] = pd.Series(DBT3Y_BL).values
df['DBT3Y_CC'] = pd.Series(DBT3Y_CC).values
df['DBT3Y_CD'] = pd.Series(DBT3Y_CD).values
df['DBT3Y_CV'] = pd.Series(DBT3Y_CV).values
df['DBT3Y_GL'] = pd.Series(DBT3Y_GL).values
df['DBT3Y_HL'] = pd.Series(DBT3Y_HL).values
df['DBT3Y_LAS'] = pd.Series(DBT3Y_LAS).values
df['DBT3Y_MFBL'] = pd.Series(DBT3Y_MFBL).values
df['DBT3Y_MFHL'] = pd.Series(DBT3Y_MFHL).values
df['DBT3Y_MFOT'] = pd.Series(DBT3Y_MFOT).values
df['DBT3Y_OTH'] = pd.Series(DBT3Y_OTH).values
df['DBT3Y_PL'] = pd.Series(DBT3Y_PL).values
df['DBT3Y_PLBL'] = pd.Series(DBT3Y_PLBL).values
df['DBT3Y_RL'] = pd.Series(DBT3Y_RL).values
df['DBT3Y_SCC'] = pd.Series(DBT3Y_SCC).values
df['DBT3Y_SEL'] = pd.Series(DBT3Y_SEL).values

# %% [raw]
# d = df[['ID','DBT3Y_GL','DBT3Y_flag','accountType']]
# d[d['DBT3Y_flag']!=0].head(60)

# %% [markdown]
# <a id='LOS_flags'></a>
# ### Code for LOS flags

# %%
los_last1_mon = list()
los_last3_mon_diff = list()
los_last3_mon = list()
los_last6_mon_diff = list()
los_last6_mon = list()
los_last1_yr_diff = list()
los_last1_yr = list()
los_last2_yr_diff = list()
los_last2_yr = list()
los_last3_yr_diff = list()
los_last3_yr = list()
matching = list()


for x in range(0,df.shape[0]):
    if (df['mo_diff_ld_drc'][x]==-1):
        los_last1_mon.append('unknown')
    elif (df['mo_diff_ld_drc'][x]==1) and (df['payHistComp'][x][0]=='LOS'):
        los_last1_mon.append(1)
    else:
        los_last1_mon.append(0)
        
    if (df['mo_diff_ld_drc'][x]==-1):
        los_last3_mon_diff.append('unknown')
    elif (df['mo_diff_ld_drc'][x]>1) and (df['mo_diff_ld_drc'][x]<4):
        los_last3_mon_diff.append(1)
    else:
        los_last3_mon_diff.append(0)
    
    if (df['mo_diff_ld_drc'][x]==-1):
        los_last6_mon_diff.append('unknown')
    elif (df['mo_diff_ld_drc'][x]>1) and (df['mo_diff_ld_drc'][x]<7):
        los_last6_mon_diff.append(1)
    else:
        los_last6_mon_diff.append(0)
    
    if (df['mo_diff_ld_drc'][x]==-1):
        los_last1_yr_diff.append('unknown')
    elif (df['mo_diff_ld_drc'][x]>1) and (df['mo_diff_ld_drc'][x]<13):
        los_last1_yr_diff.append(1)
    else:
        los_last1_yr_diff.append(0)

    if (df['mo_diff_ld_drc'][x]==-1):
        los_last2_yr_diff.append('unknown')
    elif (df['mo_diff_ld_drc'][x]>1) and (df['mo_diff_ld_drc'][x]<25):
        los_last2_yr_diff.append(1)
    else:
        los_last2_yr_diff.append(0)

    if (df['mo_diff_ld_drc'][x]==-1):
        los_last3_yr_diff.append('unknown')
    elif (df['mo_diff_ld_drc'][x]>1) and (df['mo_diff_ld_drc'][x]<37):
        los_last3_yr_diff.append(1)
    else:
        los_last3_yr_diff.append(0)
              
df['los_last3_mon_diff'] = pd.Series(los_last3_mon_diff).values
df['los_last6_mon_diff'] = pd.Series(los_last6_mon_diff).values
df['los_last1_yr_diff'] = pd.Series(los_last1_yr_diff).values
df['los_last2_yr_diff'] = pd.Series(los_last2_yr_diff).values
df['los_last3_yr_diff'] = pd.Series(los_last3_yr_diff).values

for x in range(0, df.shape[0]):
    if (df['los_last3_mon_diff'][x]=='unknown'):
        los_last3_mon.append('unknown')
    elif (df['los_last3_mon_diff'][x]==1):
        for i in range(0, 3-df['mo_diff_ld_drc'][x]):
            #print(i)
            matching.append(df['payHistComp'][x][i])
        if any('LOS' in s for s in matching):
            los_last3_mon.append(1)
        else:
            los_last3_mon.append(0)
        #print(matching)    
        matching = list()
    else:
        los_last3_mon.append(0)

    if (df['los_last6_mon_diff'][x]=='unknown'):
        los_last6_mon.append('unknown')
    elif (df['los_last6_mon_diff'][x]==1):
        for i in range(0, 6-df['mo_diff_ld_drc'][x]):
            #print(i)
            matching.append(df['payHistComp'][x][i])
        if any('LOS' in s for s in matching):
            los_last6_mon.append(1)
        else:
            los_last6_mon.append(0)
        #print(matching)    
        matching = list()
    else:
        los_last6_mon.append(0)

    if (df['los_last1_yr_diff'][x]=='unknown'):
        los_last1_yr.append('unknown')
    elif (df['los_last1_yr_diff'][x]==1) and (len(df['payHistComp'][x])>=12):
        for i in range(0, 12-df['mo_diff_ld_drc'][x]):
            #print(i)
            matching.append(df['payHistComp'][x][i])
        if any('LOS' in s for s in matching):
            los_last1_yr.append(1)
        else:
            los_last1_yr.append(0)
        #print(matching)    
        matching = list()
    else:
        los_last1_yr.append(0)
    
    if (df['los_last2_yr_diff'][x]=='unknown'):
        los_last2_yr.append('unknown')
    elif (df['los_last2_yr_diff'][x]==1) and (len(df['payHistComp'][x])>=24):
        for i in range(0, 24-df['mo_diff_ld_drc'][x]):
            #print(i)
            matching.append(df['payHistComp'][x][i])
        if any('LOS' in s for s in matching):
            los_last2_yr.append(1)
        else:
            los_last2_yr.append(0)
        #print(matching)    
        matching = list()
    else:
        los_last2_yr.append(0)
    
    if (df['los_last3_yr_diff'][x]=='unknown'):
        los_last3_yr.append('unknown')
    elif (df['los_last3_yr_diff'][x]==1) and (len(df['payHistComp'][x])==36):
        for i in range(0, 36-df['mo_diff_ld_drc'][x]):
            #print(i)
            matching.append(df['payHistComp'][x][i])
        if any('LOS' in s for s in matching):
            los_last3_yr.append(1)
        else:
            los_last3_yr.append(0)
        #print(matching)    
        matching = list()
    else:
        los_last3_yr.append(0)

df['LOS1M_flag'] = pd.Series(los_last1_mon).values
#print(df['LOS1M_flag'].value_counts()) 

df['LOS3M_flag'] = pd.Series(los_last3_mon).values
#print(df['LOS3M_flag'].value_counts())
   
df['LOS6M_flag'] = pd.Series(los_last6_mon).values
#print(df['LOS6M_flag'].value_counts())
   
df['LOS1Y_flag'] = pd.Series(los_last1_yr).values
#print(df['LOS1Y_flag'].value_counts())
   
df['LOS2Y_flag'] = pd.Series(los_last2_yr).values
#print(df['LOS2Y_flag'].value_counts())

df['LOS3Y_flag'] = pd.Series(los_last3_yr).values
#print(df['LOS3Y_flag'].value_counts())

# %% [raw]
# piece = list()
#
# los_last1_mon = list()
# los_last3_mon = list()
# los_last6_mon = list()
# los_last1_yr = list()
# los_last2_yr = list()
# los_last3_yr = list()
#
# count = 0
#
# for value in df['paymentHistComp'].astype('str'):
#     #print(value)
#
#     chunks, chunk_size = len(value), 3
#     for i in range(0, chunks, chunk_size):
#         piece.append(value[i:i+chunk_size])
#     #print(piece)
#     #print(len(piece))
#
#     if ('LSS' in piece[0]):
#         #print(piece)
#         for x in piece:
#             if x == 'LSS':
#                 count = count + 1
#                 #print(count)
#             else:
#                 break
#         if count >= 1:
#             #print('1mo')
#             los_last1_mon.append(1)
#             if count >= 3:
#                 #print('3mo')
#                 los_last3_mon.append(1)
#                 if count >= 6:
#                     #print('6mo')
#                     los_last6_mon.append(1)
#                     if count >= 12:
#                         #print('1yr')
#                         los_last1_yr.append(1)
#                         if count >= 24:
#                             #print('2yr')
#                             los_last2_yr.append(1)
#                             if count >= 36:
#                                 #print('3yr')
#                                 los_last3_yr.append(1)
#                             else:
#                                 los_last3_yr.append(0)
#                         else:
#                             los_last2_yr.append(0)
#                             los_last3_yr.append(0)
#                     else:
#                         los_last1_yr.append(0)
#                         los_last2_yr.append(0)
#                         los_last3_yr.append(0)
#                 else:
#                     los_last6_mon.append(0)
#                     los_last1_yr.append(0)
#                     los_last2_yr.append(0)
#                     los_last3_yr.append(0)
#             else:
#                 los_last3_mon.append(0)
#                 los_last6_mon.append(0)
#                 los_last1_yr.append(0)
#                 los_last2_yr.append(0)
#                 los_last3_yr.append(0)
#         else:
#             los_last1_mon.append(0)
#             los_last3_mon.append(0)
#             los_last6_mon.append(0)
#             los_last1_yr.append(0)
#             los_last2_yr.append(0)
#             los_last3_yr.append(0)
#     else:
#         los_last1_mon.append(0)
#         los_last3_mon.append(0)
#         los_last6_mon.append(0)
#         los_last1_yr.append(0)
#         los_last2_yr.append(0)
#         los_last3_yr.append(0)
#
#     count = 0
#     piece = list()
#
# df['LOS1M_flag'] = pd.Series(los_last1_mon).values
# df['LOS3M_flag'] = pd.Series(los_last3_mon).values
# df['LOS6M_flag'] = pd.Series(los_last6_mon).values
# df['LOS1Y_flag'] = pd.Series(los_last1_yr).values
# df['LOS2Y_flag'] = pd.Series(los_last2_yr).values
# df['LOS3Y_flag'] = pd.Series(los_last3_yr).values

# %% [markdown]
# <a id='LOS_num'></a>
# ### Code for LOS (numerical)

# %% [markdown]
# - For an applicant, Count of all loans where LOS1M_flag =1
# - For an applicant, Count of all loans where LOS3M_flag =1
# - For an applicant, Count of all loans where LOS6M_flag =1
# - For an applicant, Count of all loans where LOS1Y_flag =1
# - For an applicant, Count of all loans where LOS2Y_flag =1
# - For an applicant, Count of all loans where LOS3Y_flag =1

# %%
LOS1M = list()
count_list_1m = list()
count_1m = 0

LOS3M = list()
count_list_3m = list()
count_3m = 0

LOS6M = list()
count_list_6m = list()
count_6m = 0

LOS1Y = list()
count_list_1y = list()
count_1y = 0

LOS2Y = list()
count_list_2y = list()
count_2y = 0

LOS3Y = list()
count_list_3y = list()
count_3y = 0

grp_df = df.groupby('ID')

for x in range(0, len(unq_id_list)):
    grp_slice = grp_df.get_group(unq_id_list[x])
    #print(grp_slice)
    grp_slice.reset_index(drop=True, inplace=True)
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['LOS1M_flag'][i]==1) or (grp_slice['LOS1M_flag'][i]==0):
            count_1m = count_1m + grp_slice['LOS1M_flag'][i]
        
        if (grp_slice['LOS3M_flag'][i]==1) or (grp_slice['LOS3M_flag'][i]==0):
            count_3m = count_3m + grp_slice['LOS3M_flag'][i]

        if (grp_slice['LOS6M_flag'][i]==1) or (grp_slice['LOS6M_flag'][i]==0):
            count_6m = count_6m + grp_slice['LOS6M_flag'][i]

        if (grp_slice['LOS1Y_flag'][i]==1) or (grp_slice['LOS1Y_flag'][i]==0):
            count_1y = count_1y + grp_slice['LOS1Y_flag'][i]

        if (grp_slice['LOS2Y_flag'][i]==1) or (grp_slice['LOS2Y_flag'][i]==0):
            count_2y = count_2y + grp_slice['LOS2Y_flag'][i]

        if (grp_slice['LOS3Y_flag'][i]==1) or (grp_slice['LOS3Y_flag'][i]==0):
            count_3y = count_3y + grp_slice['LOS3Y_flag'][i]


    count_list_1m.append(count_1m)
    count_1m = 0
    count_list_3m.append(count_3m)
    count_3m = 0
    count_list_6m.append(count_6m)
    count_6m = 0
    count_list_1y.append(count_1y)
    count_1y = 0
    count_list_2y.append(count_2y)
    count_2y = 0
    count_list_3y.append(count_3y)
    count_3y = 0

    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['LOS1M_flag'][i]==1) or (grp_slice['LOS1M_flag'][i]==0):
            LOS1M.append(count_list_1m[x])
        else:
            LOS1M.append('unknown')

        if (grp_slice['LOS3M_flag'][i]==1) or (grp_slice['LOS3M_flag'][i]==0):
            LOS3M.append(count_list_3m[x])
        else:
            LOS3M.append('unknown')
        
        if (grp_slice['LOS6M_flag'][i]==1) or (grp_slice['LOS6M_flag'][i]==0):
            LOS6M.append(count_list_6m[x])
        else:
            LOS6M.append('unknown')

        if (grp_slice['LOS1Y_flag'][i]==1) or (grp_slice['LOS1Y_flag'][i]==0):
            LOS1Y.append(count_list_1y[x])
        else:
            LOS1Y.append('unknown')

        if (grp_slice['LOS2Y_flag'][i]==1) or (grp_slice['LOS2Y_flag'][i]==0):
            LOS2Y.append(count_list_2y[x])
        else:
            LOS2Y.append('unknown')
        
        if (grp_slice['LOS3Y_flag'][i]==1) or (grp_slice['LOS3Y_flag'][i]==0):
            LOS3Y.append(count_list_3y[x])
        else:
            LOS3Y.append('unknown')
            
df['LOS1M'] = pd.Series(LOS1M).values
df['LOS3M'] = pd.Series(LOS3M).values
df['LOS6M'] = pd.Series(LOS6M).values
df['LOS1Y'] = pd.Series(LOS1Y).values
df['LOS2Y'] = pd.Series(LOS2Y).values
df['LOS3Y'] = pd.Series(LOS3Y).values
#print(df['LOS1M'].value_counts())

# %% [markdown]
# ### Code for LOS1M_P
# - LOS in last 1 month productwise

# %%
LOS1M_AL = list()
LOS1M_BL = list()
LOS1M_CC = list()
LOS1M_CD = list()
LOS1M_CV = list()
LOS1M_GL = list()
LOS1M_HL = list()
LOS1M_LAS = list()
LOS1M_MFBL = list()
LOS1M_MFHL = list()
LOS1M_MFOT = list()
LOS1M_OTH = list()
LOS1M_PL = list()
LOS1M_PLBL = list()
LOS1M_RL = list()
LOS1M_SCC = list()
LOS1M_SEL = list()

count_list_AL = list()
count_list_BL = list()
count_list_CC = list()
count_list_CD = list()
count_list_CV = list()
count_list_GL = list()
count_list_HL = list()
count_list_LAS = list()
count_list_MFBL = list()
count_list_MFHL = list()
count_list_MFOT = list()
count_list_OTH = list()
count_list_PL = list()
count_list_PLBL = list()
count_list_RL = list()
count_list_SCC = list()
count_list_SEL = list()

count_AL = 0
count_BL = 0
count_CC = 0
count_CD = 0
count_CV = 0
count_GL = 0
count_HL = 0
count_LAS = 0
count_MFBL = 0
count_MFHL = 0
count_MFOT = 0
count_OTH = 0
count_PL = 0 
count_PLBL = 0
count_RL = 0
count_SCC = 0
count_SEL = 0

grp_df = df.groupby('ID')

for x in range(0, len(unq_id_list)):
    grp_slice = grp_df.get_group(unq_id_list[x])
    #print(grp_slice)
    grp_slice.reset_index(drop=True, inplace=True)
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['accountType'][i]=='unknown'):
            continue
        elif (grp_slice['accountType'][i]=='AL') and (grp_slice['LOS1M_flag'][i]==1):
            count_AL = count_AL + 1
        elif (grp_slice['accountType'][i]=='BL') and (grp_slice['LOS1M_flag'][i]==1):
            count_BL = count_BL + 1
        elif (grp_slice['accountType'][i]=='CC') and (grp_slice['LOS1M_flag'][i]==1):
            count_CC = count_CC + 1
        elif (grp_slice['accountType'][i]=='CD') and (grp_slice['LOS1M_flag'][i]==1):
            count_CD = count_CD + 1
        elif (grp_slice['accountType'][i]=='CV') and (grp_slice['LOS1M_flag'][i]==1):
            count_CV = count_CV + 1
        elif (grp_slice['accountType'][i]=='GL') and (grp_slice['LOS1M_flag'][i]==1):
            count_GL = count_GL + 1
        elif (grp_slice['accountType'][i]=='HL') and (grp_slice['LOS1M_flag'][i]==1):
            count_HL = count_HL + 1
        elif (grp_slice['accountType'][i]=='LAS') and (grp_slice['LOS1M_flag'][i]==1):
            count_LAS = count_LAS + 1
        elif (grp_slice['accountType'][i]=='MFBL') and (grp_slice['LOS1M_flag'][i]==1):
            count_MFBL = count_MFBL + 1
        elif (grp_slice['accountType'][i]=='MFHL') and (grp_slice['LOS1M_flag'][i]==1):
            count_MFHL = count_MFHL + 1
        elif (grp_slice['accountType'][i]=='MFOT') and (grp_slice['LOS1M_flag'][i]==1):
            count_MFOT = count_MFOT + 1
        elif (grp_slice['accountType'][i]=='OTH') and (grp_slice['LOS1M_flag'][i]==1):
            count_OTH = count_OTH + 1
        elif (grp_slice['accountType'][i]=='PL') and (grp_slice['LOS1M_flag'][i]==1):
            count_PL = count_PL + 1
        elif (grp_slice['accountType'][i]=='PLBL') and (grp_slice['LOS1M_flag'][i]==1):
            count_PLBL = count_PLBL + 1
        elif (grp_slice['accountType'][i]=='RL') and (grp_slice['LOS1M_flag'][i]==1):
            count_RL = count_RL + 1
        elif (grp_slice['accountType'][i]=='SCC') and (grp_slice['LOS1M_flag'][i]==1):
            count_SCC = count_SCC + 1
        elif (grp_slice['accountType'][i]=='SEL') and (grp_slice['LOS1M_flag'][i]==1):
            count_SEL = count_SEL + 1
            
    count_list_AL.append(count_AL)
    count_list_BL.append(count_BL)
    count_list_CC.append(count_CC)
    count_list_CD.append(count_CD)
    count_list_CV.append(count_CV)
    count_list_GL.append(count_GL)
    count_list_HL.append(count_HL)
    count_list_LAS.append(count_LAS)
    count_list_MFBL.append(count_MFBL)
    count_list_MFHL.append(count_MFHL)
    count_list_MFOT.append(count_MFOT)
    count_list_OTH.append(count_OTH)
    count_list_PL.append(count_PL)
    count_list_PLBL.append(count_PLBL)
    count_list_RL.append(count_RL)
    count_list_SCC.append(count_SCC)
    count_list_SEL.append(count_SEL)
    
    count_AL = 0
    count_BL = 0
    count_CC = 0
    count_CD = 0
    count_CV = 0
    count_GL = 0
    count_HL = 0
    count_LAS = 0
    count_MFBL = 0
    count_MFHL = 0
    count_MFOT = 0
    count_OTH = 0
    count_PL = 0
    count_PLBL = 0
    count_RL = 0
    count_SCC = 0
    count_SEL = 0
    
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['accountType'][i]=='unknown'):
            LOS1M_AL.append('unknown')
            LOS1M_BL.append('unknown')
            LOS1M_CC.append('unknown')
            LOS1M_CD.append('unknown')
            LOS1M_CV.append('unknown')
            LOS1M_GL.append('unknown')
            LOS1M_HL.append('unknown')
            LOS1M_LAS.append('unknown')
            LOS1M_MFBL.append('unknown')
            LOS1M_MFHL.append('unknown')
            LOS1M_MFOT.append('unknown')
            LOS1M_OTH.append('unknown')
            LOS1M_PL.append('unknown')
            LOS1M_PLBL.append('unknown')
            LOS1M_RL.append('unknown')
            LOS1M_SCC.append('unknown')
            LOS1M_SEL.append('unknown')
        else:
            LOS1M_AL.append(count_list_AL[x])
            LOS1M_BL.append(count_list_BL[x])
            LOS1M_CC.append(count_list_CC[x])
            LOS1M_CD.append(count_list_CD[x])
            LOS1M_CV.append(count_list_CV[x])
            LOS1M_GL.append(count_list_GL[x])
            LOS1M_HL.append(count_list_HL[x])
            LOS1M_LAS.append(count_list_LAS[x])
            LOS1M_MFBL.append(count_list_MFBL[x])
            LOS1M_MFHL.append(count_list_MFHL[x])
            LOS1M_MFOT.append(count_list_MFOT[x])
            LOS1M_OTH.append(count_list_OTH[x])
            LOS1M_PL.append(count_list_PL[x])
            LOS1M_PLBL.append(count_list_PLBL[x])
            LOS1M_RL.append(count_list_RL[x])
            LOS1M_SCC.append(count_list_SCC[x])
            LOS1M_SEL.append(count_list_SEL[x])
            
df['LOS1M_AL'] = pd.Series(LOS1M_AL).values
df['LOS1M_BL'] = pd.Series(LOS1M_BL).values
df['LOS1M_CC'] = pd.Series(LOS1M_CC).values
df['LOS1M_CD'] = pd.Series(LOS1M_CD).values
df['LOS1M_CV'] = pd.Series(LOS1M_CV).values
df['LOS1M_GL'] = pd.Series(LOS1M_GL).values
df['LOS1M_HL'] = pd.Series(LOS1M_HL).values
df['LOS1M_LAS'] = pd.Series(LOS1M_LAS).values
df['LOS1M_MFBL'] = pd.Series(LOS1M_MFBL).values
df['LOS1M_MFHL'] = pd.Series(LOS1M_MFHL).values
df['LOS1M_MFOT'] = pd.Series(LOS1M_MFOT).values
df['LOS1M_OTH'] = pd.Series(LOS1M_OTH).values
df['LOS1M_PL'] = pd.Series(LOS1M_PL).values
df['LOS1M_PLBL'] = pd.Series(LOS1M_PLBL).values
df['LOS1M_RL'] = pd.Series(LOS1M_RL).values
df['LOS1M_SCC'] = pd.Series(LOS1M_SCC).values
df['LOS1M_SEL'] = pd.Series(LOS1M_SEL).values

# %% [raw]
# d = df[['ID','LOS1M_GL','LOS1M_flag','accountType']]
# d[d['LOS1M_flag']!=0].head(60)

# %% [markdown]
# ### Code for LOS3M_P
# - LOS in last 3 month productwise

# %%
LOS3M_AL = list()
LOS3M_BL = list()
LOS3M_CC = list()
LOS3M_CD = list()
LOS3M_CV = list()
LOS3M_GL = list()
LOS3M_HL = list()
LOS3M_LAS = list()
LOS3M_MFBL = list()
LOS3M_MFHL = list()
LOS3M_MFOT = list()
LOS3M_OTH = list()
LOS3M_PL = list()
LOS3M_PLBL = list()
LOS3M_RL = list()
LOS3M_SCC = list()
LOS3M_SEL = list()

count_list_AL = list()
count_list_BL = list()
count_list_CC = list()
count_list_CD = list()
count_list_CV = list()
count_list_GL = list()
count_list_HL = list()
count_list_LAS = list()
count_list_MFBL = list()
count_list_MFHL = list()
count_list_MFOT = list()
count_list_OTH = list()
count_list_PL = list()
count_list_PLBL = list()
count_list_RL = list()
count_list_SCC = list()
count_list_SEL = list()

count_AL = 0
count_BL = 0
count_CC = 0
count_CD = 0
count_CV = 0
count_GL = 0
count_HL = 0
count_LAS = 0
count_MFBL = 0
count_MFHL = 0
count_MFOT = 0
count_OTH = 0
count_PL = 0 
count_PLBL = 0
count_RL = 0
count_SCC = 0
count_SEL = 0

grp_df = df.groupby('ID')

for x in range(0, len(unq_id_list)):
    grp_slice = grp_df.get_group(unq_id_list[x])
    #print(grp_slice)
    grp_slice.reset_index(drop=True, inplace=True)
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['accountType'][i]=='unknown'):
            continue
        elif (grp_slice['accountType'][i]=='AL') and (grp_slice['LOS3M_flag'][i]==1):
            count_AL = count_AL + 1
        elif (grp_slice['accountType'][i]=='BL') and (grp_slice['LOS3M_flag'][i]==1):
            count_BL = count_BL + 1
        elif (grp_slice['accountType'][i]=='CC') and (grp_slice['LOS3M_flag'][i]==1):
            count_CC = count_CC + 1
        elif (grp_slice['accountType'][i]=='CD') and (grp_slice['LOS3M_flag'][i]==1):
            count_CD = count_CD + 1
        elif (grp_slice['accountType'][i]=='CV') and (grp_slice['LOS3M_flag'][i]==1):
            count_CV = count_CV + 1
        elif (grp_slice['accountType'][i]=='GL') and (grp_slice['LOS3M_flag'][i]==1):
            count_GL = count_GL + 1
        elif (grp_slice['accountType'][i]=='HL') and (grp_slice['LOS3M_flag'][i]==1):
            count_HL = count_HL + 1
        elif (grp_slice['accountType'][i]=='LAS') and (grp_slice['LOS3M_flag'][i]==1):
            count_LAS = count_LAS + 1
        elif (grp_slice['accountType'][i]=='MFBL') and (grp_slice['LOS3M_flag'][i]==1):
            count_MFBL = count_MFBL + 1
        elif (grp_slice['accountType'][i]=='MFHL') and (grp_slice['LOS3M_flag'][i]==1):
            count_MFHL = count_MFHL + 1
        elif (grp_slice['accountType'][i]=='MFOT') and (grp_slice['LOS3M_flag'][i]==1):
            count_MFOT = count_MFOT + 1
        elif (grp_slice['accountType'][i]=='OTH') and (grp_slice['LOS3M_flag'][i]==1):
            count_OTH = count_OTH + 1
        elif (grp_slice['accountType'][i]=='PL') and (grp_slice['LOS3M_flag'][i]==1):
            count_PL = count_PL + 1
        elif (grp_slice['accountType'][i]=='PLBL') and (grp_slice['LOS3M_flag'][i]==1):
            count_PLBL = count_PLBL + 1
        elif (grp_slice['accountType'][i]=='RL') and (grp_slice['LOS3M_flag'][i]==1):
            count_RL = count_RL + 1
        elif (grp_slice['accountType'][i]=='SCC') and (grp_slice['LOS3M_flag'][i]==1):
            count_SCC = count_SCC + 1
        elif (grp_slice['accountType'][i]=='SEL') and (grp_slice['LOS3M_flag'][i]==1):
            count_SEL = count_SEL + 1
            
    count_list_AL.append(count_AL)
    count_list_BL.append(count_BL)
    count_list_CC.append(count_CC)
    count_list_CD.append(count_CD)
    count_list_CV.append(count_CV)
    count_list_GL.append(count_GL)
    count_list_HL.append(count_HL)
    count_list_LAS.append(count_LAS)
    count_list_MFBL.append(count_MFBL)
    count_list_MFHL.append(count_MFHL)
    count_list_MFOT.append(count_MFOT)
    count_list_OTH.append(count_OTH)
    count_list_PL.append(count_PL)
    count_list_PLBL.append(count_PLBL)
    count_list_RL.append(count_RL)
    count_list_SCC.append(count_SCC)
    count_list_SEL.append(count_SEL)
    
    count_AL = 0
    count_BL = 0
    count_CC = 0
    count_CD = 0
    count_CV = 0
    count_GL = 0
    count_HL = 0
    count_LAS = 0
    count_MFBL = 0
    count_MFHL = 0
    count_MFOT = 0
    count_OTH = 0
    count_PL = 0
    count_PLBL = 0
    count_RL = 0
    count_SCC = 0
    count_SEL = 0
    
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['accountType'][i]=='unknown'):
            LOS3M_AL.append('unknown')
            LOS3M_BL.append('unknown')
            LOS3M_CC.append('unknown')
            LOS3M_CD.append('unknown')
            LOS3M_CV.append('unknown')
            LOS3M_GL.append('unknown')
            LOS3M_HL.append('unknown')
            LOS3M_LAS.append('unknown')
            LOS3M_MFBL.append('unknown')
            LOS3M_MFHL.append('unknown')
            LOS3M_MFOT.append('unknown')
            LOS3M_OTH.append('unknown')
            LOS3M_PL.append('unknown')
            LOS3M_PLBL.append('unknown')
            LOS3M_RL.append('unknown')
            LOS3M_SCC.append('unknown')
            LOS3M_SEL.append('unknown')
        else:
            LOS3M_AL.append(count_list_AL[x])
            LOS3M_BL.append(count_list_BL[x])
            LOS3M_CC.append(count_list_CC[x])
            LOS3M_CD.append(count_list_CD[x])
            LOS3M_CV.append(count_list_CV[x])
            LOS3M_GL.append(count_list_GL[x])
            LOS3M_HL.append(count_list_HL[x])
            LOS3M_LAS.append(count_list_LAS[x])
            LOS3M_MFBL.append(count_list_MFBL[x])
            LOS3M_MFHL.append(count_list_MFHL[x])
            LOS3M_MFOT.append(count_list_MFOT[x])
            LOS3M_OTH.append(count_list_OTH[x])
            LOS3M_PL.append(count_list_PL[x])
            LOS3M_PLBL.append(count_list_PLBL[x])
            LOS3M_RL.append(count_list_RL[x])
            LOS3M_SCC.append(count_list_SCC[x])
            LOS3M_SEL.append(count_list_SEL[x])
            
df['LOS3M_AL'] = pd.Series(LOS3M_AL).values
df['LOS3M_BL'] = pd.Series(LOS3M_BL).values
df['LOS3M_CC'] = pd.Series(LOS3M_CC).values
df['LOS3M_CD'] = pd.Series(LOS3M_CD).values
df['LOS3M_CV'] = pd.Series(LOS3M_CV).values
df['LOS3M_GL'] = pd.Series(LOS3M_GL).values
df['LOS3M_HL'] = pd.Series(LOS3M_HL).values
df['LOS3M_LAS'] = pd.Series(LOS3M_LAS).values
df['LOS3M_MFBL'] = pd.Series(LOS3M_MFBL).values
df['LOS3M_MFHL'] = pd.Series(LOS3M_MFHL).values
df['LOS3M_MFOT'] = pd.Series(LOS3M_MFOT).values
df['LOS3M_OTH'] = pd.Series(LOS3M_OTH).values
df['LOS3M_PL'] = pd.Series(LOS3M_PL).values
df['LOS3M_PLBL'] = pd.Series(LOS3M_PLBL).values
df['LOS3M_RL'] = pd.Series(LOS3M_RL).values
df['LOS3M_SCC'] = pd.Series(LOS3M_SCC).values
df['LOS3M_SEL'] = pd.Series(LOS3M_SEL).values

# %% [raw]
# d = df[['ID','LOS3M_GL','LOS3M_flag','accountType']]
# d[d['LOS3M_flag']!=0].head(60)

# %% [markdown]
# ### Code for LOS6M_P
# - LOS in last 6 month productwise

# %%
LOS6M_AL = list()
LOS6M_BL = list()
LOS6M_CC = list()
LOS6M_CD = list()
LOS6M_CV = list()
LOS6M_GL = list()
LOS6M_HL = list()
LOS6M_LAS = list()
LOS6M_MFBL = list()
LOS6M_MFHL = list()
LOS6M_MFOT = list()
LOS6M_OTH = list()
LOS6M_PL = list()
LOS6M_PLBL = list()
LOS6M_RL = list()
LOS6M_SCC = list()
LOS6M_SEL = list()

count_list_AL = list()
count_list_BL = list()
count_list_CC = list()
count_list_CD = list()
count_list_CV = list()
count_list_GL = list()
count_list_HL = list()
count_list_LAS = list()
count_list_MFBL = list()
count_list_MFHL = list()
count_list_MFOT = list()
count_list_OTH = list()
count_list_PL = list()
count_list_PLBL = list()
count_list_RL = list()
count_list_SCC = list()
count_list_SEL = list()

count_AL = 0
count_BL = 0
count_CC = 0
count_CD = 0
count_CV = 0
count_GL = 0
count_HL = 0
count_LAS = 0
count_MFBL = 0
count_MFHL = 0
count_MFOT = 0
count_OTH = 0
count_PL = 0 
count_PLBL = 0
count_RL = 0
count_SCC = 0
count_SEL = 0

grp_df = df.groupby('ID')

for x in range(0, len(unq_id_list)):
    grp_slice = grp_df.get_group(unq_id_list[x])
    #print(grp_slice)
    grp_slice.reset_index(drop=True, inplace=True)
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['accountType'][i]=='unknown'):
            continue
        elif (grp_slice['accountType'][i]=='AL') and (grp_slice['LOS6M_flag'][i]==1):
            count_AL = count_AL + 1
        elif (grp_slice['accountType'][i]=='BL') and (grp_slice['LOS6M_flag'][i]==1):
            count_BL = count_BL + 1
        elif (grp_slice['accountType'][i]=='CC') and (grp_slice['LOS6M_flag'][i]==1):
            count_CC = count_CC + 1
        elif (grp_slice['accountType'][i]=='CD') and (grp_slice['LOS6M_flag'][i]==1):
            count_CD = count_CD + 1
        elif (grp_slice['accountType'][i]=='CV') and (grp_slice['LOS6M_flag'][i]==1):
            count_CV = count_CV + 1
        elif (grp_slice['accountType'][i]=='GL') and (grp_slice['LOS6M_flag'][i]==1):
            count_GL = count_GL + 1
        elif (grp_slice['accountType'][i]=='HL') and (grp_slice['LOS6M_flag'][i]==1):
            count_HL = count_HL + 1
        elif (grp_slice['accountType'][i]=='LAS') and (grp_slice['LOS6M_flag'][i]==1):
            count_LAS = count_LAS + 1
        elif (grp_slice['accountType'][i]=='MFBL') and (grp_slice['LOS6M_flag'][i]==1):
            count_MFBL = count_MFBL + 1
        elif (grp_slice['accountType'][i]=='MFHL') and (grp_slice['LOS6M_flag'][i]==1):
            count_MFHL = count_MFHL + 1
        elif (grp_slice['accountType'][i]=='MFOT') and (grp_slice['LOS6M_flag'][i]==1):
            count_MFOT = count_MFOT + 1
        elif (grp_slice['accountType'][i]=='OTH') and (grp_slice['LOS6M_flag'][i]==1):
            count_OTH = count_OTH + 1
        elif (grp_slice['accountType'][i]=='PL') and (grp_slice['LOS6M_flag'][i]==1):
            count_PL = count_PL + 1
        elif (grp_slice['accountType'][i]=='PLBL') and (grp_slice['LOS6M_flag'][i]==1):
            count_PLBL = count_PLBL + 1
        elif (grp_slice['accountType'][i]=='RL') and (grp_slice['LOS6M_flag'][i]==1):
            count_RL = count_RL + 1
        elif (grp_slice['accountType'][i]=='SCC') and (grp_slice['LOS6M_flag'][i]==1):
            count_SCC = count_SCC + 1
        elif (grp_slice['accountType'][i]=='SEL') and (grp_slice['LOS6M_flag'][i]==1):
            count_SEL = count_SEL + 1
            
    count_list_AL.append(count_AL)
    count_list_BL.append(count_BL)
    count_list_CC.append(count_CC)
    count_list_CD.append(count_CD)
    count_list_CV.append(count_CV)
    count_list_GL.append(count_GL)
    count_list_HL.append(count_HL)
    count_list_LAS.append(count_LAS)
    count_list_MFBL.append(count_MFBL)
    count_list_MFHL.append(count_MFHL)
    count_list_MFOT.append(count_MFOT)
    count_list_OTH.append(count_OTH)
    count_list_PL.append(count_PL)
    count_list_PLBL.append(count_PLBL)
    count_list_RL.append(count_RL)
    count_list_SCC.append(count_SCC)
    count_list_SEL.append(count_SEL)
    
    count_AL = 0
    count_BL = 0
    count_CC = 0
    count_CD = 0
    count_CV = 0
    count_GL = 0
    count_HL = 0
    count_LAS = 0
    count_MFBL = 0
    count_MFHL = 0
    count_MFOT = 0
    count_OTH = 0
    count_PL = 0
    count_PLBL = 0
    count_RL = 0
    count_SCC = 0
    count_SEL = 0
    
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['accountType'][i]=='unknown'):
            LOS6M_AL.append('unknown')
            LOS6M_BL.append('unknown')
            LOS6M_CC.append('unknown')
            LOS6M_CD.append('unknown')
            LOS6M_CV.append('unknown')
            LOS6M_GL.append('unknown')
            LOS6M_HL.append('unknown')
            LOS6M_LAS.append('unknown')
            LOS6M_MFBL.append('unknown')
            LOS6M_MFHL.append('unknown')
            LOS6M_MFOT.append('unknown')
            LOS6M_OTH.append('unknown')
            LOS6M_PL.append('unknown')
            LOS6M_PLBL.append('unknown')
            LOS6M_RL.append('unknown')
            LOS6M_SCC.append('unknown')
            LOS6M_SEL.append('unknown')
        else:
            LOS6M_AL.append(count_list_AL[x])
            LOS6M_BL.append(count_list_BL[x])
            LOS6M_CC.append(count_list_CC[x])
            LOS6M_CD.append(count_list_CD[x])
            LOS6M_CV.append(count_list_CV[x])
            LOS6M_GL.append(count_list_GL[x])
            LOS6M_HL.append(count_list_HL[x])
            LOS6M_LAS.append(count_list_LAS[x])
            LOS6M_MFBL.append(count_list_MFBL[x])
            LOS6M_MFHL.append(count_list_MFHL[x])
            LOS6M_MFOT.append(count_list_MFOT[x])
            LOS6M_OTH.append(count_list_OTH[x])
            LOS6M_PL.append(count_list_PL[x])
            LOS6M_PLBL.append(count_list_PLBL[x])
            LOS6M_RL.append(count_list_RL[x])
            LOS6M_SCC.append(count_list_SCC[x])
            LOS6M_SEL.append(count_list_SEL[x])
            
df['LOS6M_AL'] = pd.Series(LOS6M_AL).values
df['LOS6M_BL'] = pd.Series(LOS6M_BL).values
df['LOS6M_CC'] = pd.Series(LOS6M_CC).values
df['LOS6M_CD'] = pd.Series(LOS6M_CD).values
df['LOS6M_CV'] = pd.Series(LOS6M_CV).values
df['LOS6M_GL'] = pd.Series(LOS6M_GL).values
df['LOS6M_HL'] = pd.Series(LOS6M_HL).values
df['LOS6M_LAS'] = pd.Series(LOS6M_LAS).values
df['LOS6M_MFBL'] = pd.Series(LOS6M_MFBL).values
df['LOS6M_MFHL'] = pd.Series(LOS6M_MFHL).values
df['LOS6M_MFOT'] = pd.Series(LOS6M_MFOT).values
df['LOS6M_OTH'] = pd.Series(LOS6M_OTH).values
df['LOS6M_PL'] = pd.Series(LOS6M_PL).values
df['LOS6M_PLBL'] = pd.Series(LOS6M_PLBL).values
df['LOS6M_RL'] = pd.Series(LOS6M_RL).values
df['LOS6M_SCC'] = pd.Series(LOS6M_SCC).values
df['LOS6M_SEL'] = pd.Series(LOS6M_SEL).values

# %% [raw]
# d = df[['ID','LOS6M_GL','LOS6M_flag','accountType']]
# d[d['LOS6M_flag']!=0].head(60)

# %% [markdown]
# ### Code for LOS1Y_P
# - LOS in last 1 year productwise

# %%
LOS1Y_AL = list()
LOS1Y_BL = list()
LOS1Y_CC = list()
LOS1Y_CD = list()
LOS1Y_CV = list()
LOS1Y_GL = list()
LOS1Y_HL = list()
LOS1Y_LAS = list()
LOS1Y_MFBL = list()
LOS1Y_MFHL = list()
LOS1Y_MFOT = list()
LOS1Y_OTH = list()
LOS1Y_PL = list()
LOS1Y_PLBL = list()
LOS1Y_RL = list()
LOS1Y_SCC = list()
LOS1Y_SEL = list()

count_list_AL = list()
count_list_BL = list()
count_list_CC = list()
count_list_CD = list()
count_list_CV = list()
count_list_GL = list()
count_list_HL = list()
count_list_LAS = list()
count_list_MFBL = list()
count_list_MFHL = list()
count_list_MFOT = list()
count_list_OTH = list()
count_list_PL = list()
count_list_PLBL = list()
count_list_RL = list()
count_list_SCC = list()
count_list_SEL = list()

count_AL = 0
count_BL = 0
count_CC = 0
count_CD = 0
count_CV = 0
count_GL = 0
count_HL = 0
count_LAS = 0
count_MFBL = 0
count_MFHL = 0
count_MFOT = 0
count_OTH = 0
count_PL = 0 
count_PLBL = 0
count_RL = 0
count_SCC = 0
count_SEL = 0

grp_df = df.groupby('ID')

for x in range(0, len(unq_id_list)):
    grp_slice = grp_df.get_group(unq_id_list[x])
    #print(grp_slice)
    grp_slice.reset_index(drop=True, inplace=True)
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['accountType'][i]=='unknown'):
            continue
        elif (grp_slice['accountType'][i]=='AL') and (grp_slice['LOS1Y_flag'][i]==1):
            count_AL = count_AL + 1
        elif (grp_slice['accountType'][i]=='BL') and (grp_slice['LOS1Y_flag'][i]==1):
            count_BL = count_BL + 1
        elif (grp_slice['accountType'][i]=='CC') and (grp_slice['LOS1Y_flag'][i]==1):
            count_CC = count_CC + 1
        elif (grp_slice['accountType'][i]=='CD') and (grp_slice['LOS1Y_flag'][i]==1):
            count_CD = count_CD + 1
        elif (grp_slice['accountType'][i]=='CV') and (grp_slice['LOS1Y_flag'][i]==1):
            count_CV = count_CV + 1
        elif (grp_slice['accountType'][i]=='GL') and (grp_slice['LOS1Y_flag'][i]==1):
            count_GL = count_GL + 1
        elif (grp_slice['accountType'][i]=='HL') and (grp_slice['LOS1Y_flag'][i]==1):
            count_HL = count_HL + 1
        elif (grp_slice['accountType'][i]=='LAS') and (grp_slice['LOS1Y_flag'][i]==1):
            count_LAS = count_LAS + 1
        elif (grp_slice['accountType'][i]=='MFBL') and (grp_slice['LOS1Y_flag'][i]==1):
            count_MFBL = count_MFBL + 1
        elif (grp_slice['accountType'][i]=='MFHL') and (grp_slice['LOS1Y_flag'][i]==1):
            count_MFHL = count_MFHL + 1
        elif (grp_slice['accountType'][i]=='MFOT') and (grp_slice['LOS1Y_flag'][i]==1):
            count_MFOT = count_MFOT + 1
        elif (grp_slice['accountType'][i]=='OTH') and (grp_slice['LOS1Y_flag'][i]==1):
            count_OTH = count_OTH + 1
        elif (grp_slice['accountType'][i]=='PL') and (grp_slice['LOS1Y_flag'][i]==1):
            count_PL = count_PL + 1
        elif (grp_slice['accountType'][i]=='PLBL') and (grp_slice['LOS1Y_flag'][i]==1):
            count_PLBL = count_PLBL + 1
        elif (grp_slice['accountType'][i]=='RL') and (grp_slice['LOS1Y_flag'][i]==1):
            count_RL = count_RL + 1
        elif (grp_slice['accountType'][i]=='SCC') and (grp_slice['LOS1Y_flag'][i]==1):
            count_SCC = count_SCC + 1
        elif (grp_slice['accountType'][i]=='SEL') and (grp_slice['LOS1Y_flag'][i]==1):
            count_SEL = count_SEL + 1
            
    count_list_AL.append(count_AL)
    count_list_BL.append(count_BL)
    count_list_CC.append(count_CC)
    count_list_CD.append(count_CD)
    count_list_CV.append(count_CV)
    count_list_GL.append(count_GL)
    count_list_HL.append(count_HL)
    count_list_LAS.append(count_LAS)
    count_list_MFBL.append(count_MFBL)
    count_list_MFHL.append(count_MFHL)
    count_list_MFOT.append(count_MFOT)
    count_list_OTH.append(count_OTH)
    count_list_PL.append(count_PL)
    count_list_PLBL.append(count_PLBL)
    count_list_RL.append(count_RL)
    count_list_SCC.append(count_SCC)
    count_list_SEL.append(count_SEL)
    
    count_AL = 0
    count_BL = 0
    count_CC = 0
    count_CD = 0
    count_CV = 0
    count_GL = 0
    count_HL = 0
    count_LAS = 0
    count_MFBL = 0
    count_MFHL = 0
    count_MFOT = 0
    count_OTH = 0
    count_PL = 0
    count_PLBL = 0
    count_RL = 0
    count_SCC = 0
    count_SEL = 0
    
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['accountType'][i]=='unknown'):
            LOS1Y_AL.append('unknown')
            LOS1Y_BL.append('unknown')
            LOS1Y_CC.append('unknown')
            LOS1Y_CD.append('unknown')
            LOS1Y_CV.append('unknown')
            LOS1Y_GL.append('unknown')
            LOS1Y_HL.append('unknown')
            LOS1Y_LAS.append('unknown')
            LOS1Y_MFBL.append('unknown')
            LOS1Y_MFHL.append('unknown')
            LOS1Y_MFOT.append('unknown')
            LOS1Y_OTH.append('unknown')
            LOS1Y_PL.append('unknown')
            LOS1Y_PLBL.append('unknown')
            LOS1Y_RL.append('unknown')
            LOS1Y_SCC.append('unknown')
            LOS1Y_SEL.append('unknown')
        else:
            LOS1Y_AL.append(count_list_AL[x])
            LOS1Y_BL.append(count_list_BL[x])
            LOS1Y_CC.append(count_list_CC[x])
            LOS1Y_CD.append(count_list_CD[x])
            LOS1Y_CV.append(count_list_CV[x])
            LOS1Y_GL.append(count_list_GL[x])
            LOS1Y_HL.append(count_list_HL[x])
            LOS1Y_LAS.append(count_list_LAS[x])
            LOS1Y_MFBL.append(count_list_MFBL[x])
            LOS1Y_MFHL.append(count_list_MFHL[x])
            LOS1Y_MFOT.append(count_list_MFOT[x])
            LOS1Y_OTH.append(count_list_OTH[x])
            LOS1Y_PL.append(count_list_PL[x])
            LOS1Y_PLBL.append(count_list_PLBL[x])
            LOS1Y_RL.append(count_list_RL[x])
            LOS1Y_SCC.append(count_list_SCC[x])
            LOS1Y_SEL.append(count_list_SEL[x])
            
df['LOS1Y_AL'] = pd.Series(LOS1Y_AL).values
df['LOS1Y_BL'] = pd.Series(LOS1Y_BL).values
df['LOS1Y_CC'] = pd.Series(LOS1Y_CC).values
df['LOS1Y_CD'] = pd.Series(LOS1Y_CD).values
df['LOS1Y_CV'] = pd.Series(LOS1Y_CV).values
df['LOS1Y_GL'] = pd.Series(LOS1Y_GL).values
df['LOS1Y_HL'] = pd.Series(LOS1Y_HL).values
df['LOS1Y_LAS'] = pd.Series(LOS1Y_LAS).values
df['LOS1Y_MFBL'] = pd.Series(LOS1Y_MFBL).values
df['LOS1Y_MFHL'] = pd.Series(LOS1Y_MFHL).values
df['LOS1Y_MFOT'] = pd.Series(LOS1Y_MFOT).values
df['LOS1Y_OTH'] = pd.Series(LOS1Y_OTH).values
df['LOS1Y_PL'] = pd.Series(LOS1Y_PL).values
df['LOS1Y_PLBL'] = pd.Series(LOS1Y_PLBL).values
df['LOS1Y_RL'] = pd.Series(LOS1Y_RL).values
df['LOS1Y_SCC'] = pd.Series(LOS1Y_SCC).values
df['LOS1Y_SEL'] = pd.Series(LOS1Y_SEL).values

# %% [raw]
# d = df[['ID','LOS1Y_GL','LOS1Y_flag','accountType']]
# d[d['LOS1Y_flag']!=0].head(60)

# %% [markdown]
# ### Code for LOS2Y_P
# - LOS in last 2 year productwise

# %%
LOS2Y_AL = list()
LOS2Y_BL = list()
LOS2Y_CC = list()
LOS2Y_CD = list()
LOS2Y_CV = list()
LOS2Y_GL = list()
LOS2Y_HL = list()
LOS2Y_LAS = list()
LOS2Y_MFBL = list()
LOS2Y_MFHL = list()
LOS2Y_MFOT = list()
LOS2Y_OTH = list()
LOS2Y_PL = list()
LOS2Y_PLBL = list()
LOS2Y_RL = list()
LOS2Y_SCC = list()
LOS2Y_SEL = list()

count_list_AL = list()
count_list_BL = list()
count_list_CC = list()
count_list_CD = list()
count_list_CV = list()
count_list_GL = list()
count_list_HL = list()
count_list_LAS = list()
count_list_MFBL = list()
count_list_MFHL = list()
count_list_MFOT = list()
count_list_OTH = list()
count_list_PL = list()
count_list_PLBL = list()
count_list_RL = list()
count_list_SCC = list()
count_list_SEL = list()

count_AL = 0
count_BL = 0
count_CC = 0
count_CD = 0
count_CV = 0
count_GL = 0
count_HL = 0
count_LAS = 0
count_MFBL = 0
count_MFHL = 0
count_MFOT = 0
count_OTH = 0
count_PL = 0 
count_PLBL = 0
count_RL = 0
count_SCC = 0
count_SEL = 0

grp_df = df.groupby('ID')

for x in range(0, len(unq_id_list)):
    grp_slice = grp_df.get_group(unq_id_list[x])
    #print(grp_slice)
    grp_slice.reset_index(drop=True, inplace=True)
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['accountType'][i]=='unknown'):
            continue
        elif (grp_slice['accountType'][i]=='AL') and (grp_slice['LOS2Y_flag'][i]==1):
            count_AL = count_AL + 1
        elif (grp_slice['accountType'][i]=='BL') and (grp_slice['LOS2Y_flag'][i]==1):
            count_BL = count_BL + 1
        elif (grp_slice['accountType'][i]=='CC') and (grp_slice['LOS2Y_flag'][i]==1):
            count_CC = count_CC + 1
        elif (grp_slice['accountType'][i]=='CD') and (grp_slice['LOS2Y_flag'][i]==1):
            count_CD = count_CD + 1
        elif (grp_slice['accountType'][i]=='CV') and (grp_slice['LOS2Y_flag'][i]==1):
            count_CV = count_CV + 1
        elif (grp_slice['accountType'][i]=='GL') and (grp_slice['LOS2Y_flag'][i]==1):
            count_GL = count_GL + 1
        elif (grp_slice['accountType'][i]=='HL') and (grp_slice['LOS2Y_flag'][i]==1):
            count_HL = count_HL + 1
        elif (grp_slice['accountType'][i]=='LAS') and (grp_slice['LOS2Y_flag'][i]==1):
            count_LAS = count_LAS + 1
        elif (grp_slice['accountType'][i]=='MFBL') and (grp_slice['LOS2Y_flag'][i]==1):
            count_MFBL = count_MFBL + 1
        elif (grp_slice['accountType'][i]=='MFHL') and (grp_slice['LOS2Y_flag'][i]==1):
            count_MFHL = count_MFHL + 1
        elif (grp_slice['accountType'][i]=='MFOT') and (grp_slice['LOS2Y_flag'][i]==1):
            count_MFOT = count_MFOT + 1
        elif (grp_slice['accountType'][i]=='OTH') and (grp_slice['LOS2Y_flag'][i]==1):
            count_OTH = count_OTH + 1
        elif (grp_slice['accountType'][i]=='PL') and (grp_slice['LOS2Y_flag'][i]==1):
            count_PL = count_PL + 1
        elif (grp_slice['accountType'][i]=='PLBL') and (grp_slice['LOS2Y_flag'][i]==1):
            count_PLBL = count_PLBL + 1
        elif (grp_slice['accountType'][i]=='RL') and (grp_slice['LOS2Y_flag'][i]==1):
            count_RL = count_RL + 1
        elif (grp_slice['accountType'][i]=='SCC') and (grp_slice['LOS2Y_flag'][i]==1):
            count_SCC = count_SCC + 1
        elif (grp_slice['accountType'][i]=='SEL') and (grp_slice['LOS2Y_flag'][i]==1):
            count_SEL = count_SEL + 1
            
    count_list_AL.append(count_AL)
    count_list_BL.append(count_BL)
    count_list_CC.append(count_CC)
    count_list_CD.append(count_CD)
    count_list_CV.append(count_CV)
    count_list_GL.append(count_GL)
    count_list_HL.append(count_HL)
    count_list_LAS.append(count_LAS)
    count_list_MFBL.append(count_MFBL)
    count_list_MFHL.append(count_MFHL)
    count_list_MFOT.append(count_MFOT)
    count_list_OTH.append(count_OTH)
    count_list_PL.append(count_PL)
    count_list_PLBL.append(count_PLBL)
    count_list_RL.append(count_RL)
    count_list_SCC.append(count_SCC)
    count_list_SEL.append(count_SEL)
    
    count_AL = 0
    count_BL = 0
    count_CC = 0
    count_CD = 0
    count_CV = 0
    count_GL = 0
    count_HL = 0
    count_LAS = 0
    count_MFBL = 0
    count_MFHL = 0
    count_MFOT = 0
    count_OTH = 0
    count_PL = 0
    count_PLBL = 0
    count_RL = 0
    count_SCC = 0
    count_SEL = 0
    
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['accountType'][i]=='unknown'):
            LOS2Y_AL.append('unknown')
            LOS2Y_BL.append('unknown')
            LOS2Y_CC.append('unknown')
            LOS2Y_CD.append('unknown')
            LOS2Y_CV.append('unknown')
            LOS2Y_GL.append('unknown')
            LOS2Y_HL.append('unknown')
            LOS2Y_LAS.append('unknown')
            LOS2Y_MFBL.append('unknown')
            LOS2Y_MFHL.append('unknown')
            LOS2Y_MFOT.append('unknown')
            LOS2Y_OTH.append('unknown')
            LOS2Y_PL.append('unknown')
            LOS2Y_PLBL.append('unknown')
            LOS2Y_RL.append('unknown')
            LOS2Y_SCC.append('unknown')
            LOS2Y_SEL.append('unknown')
        else:
            LOS2Y_AL.append(count_list_AL[x])
            LOS2Y_BL.append(count_list_BL[x])
            LOS2Y_CC.append(count_list_CC[x])
            LOS2Y_CD.append(count_list_CD[x])
            LOS2Y_CV.append(count_list_CV[x])
            LOS2Y_GL.append(count_list_GL[x])
            LOS2Y_HL.append(count_list_HL[x])
            LOS2Y_LAS.append(count_list_LAS[x])
            LOS2Y_MFBL.append(count_list_MFBL[x])
            LOS2Y_MFHL.append(count_list_MFHL[x])
            LOS2Y_MFOT.append(count_list_MFOT[x])
            LOS2Y_OTH.append(count_list_OTH[x])
            LOS2Y_PL.append(count_list_PL[x])
            LOS2Y_PLBL.append(count_list_PLBL[x])
            LOS2Y_RL.append(count_list_RL[x])
            LOS2Y_SCC.append(count_list_SCC[x])
            LOS2Y_SEL.append(count_list_SEL[x])
            
df['LOS2Y_AL'] = pd.Series(LOS2Y_AL).values
df['LOS2Y_BL'] = pd.Series(LOS2Y_BL).values
df['LOS2Y_CC'] = pd.Series(LOS2Y_CC).values
df['LOS2Y_CD'] = pd.Series(LOS2Y_CD).values
df['LOS2Y_CV'] = pd.Series(LOS2Y_CV).values
df['LOS2Y_GL'] = pd.Series(LOS2Y_GL).values
df['LOS2Y_HL'] = pd.Series(LOS2Y_HL).values
df['LOS2Y_LAS'] = pd.Series(LOS2Y_LAS).values
df['LOS2Y_MFBL'] = pd.Series(LOS2Y_MFBL).values
df['LOS2Y_MFHL'] = pd.Series(LOS2Y_MFHL).values
df['LOS2Y_MFOT'] = pd.Series(LOS2Y_MFOT).values
df['LOS2Y_OTH'] = pd.Series(LOS2Y_OTH).values
df['LOS2Y_PL'] = pd.Series(LOS2Y_PL).values
df['LOS2Y_PLBL'] = pd.Series(LOS2Y_PLBL).values
df['LOS2Y_RL'] = pd.Series(LOS2Y_RL).values
df['LOS2Y_SCC'] = pd.Series(LOS2Y_SCC).values
df['LOS2Y_SEL'] = pd.Series(LOS2Y_SEL).values

# %% [raw]
# d = df[['ID','LOS2Y_GL','LOS2Y_flag','accountType']]
# d[d['LOS2Y_flag']!=0].head(60)

# %% [markdown]
# ### Code for LOS3Y_P
# - LOS in last 3 year productwise

# %%
LOS3Y_AL = list()
LOS3Y_BL = list()
LOS3Y_CC = list()
LOS3Y_CD = list()
LOS3Y_CV = list()
LOS3Y_GL = list()
LOS3Y_HL = list()
LOS3Y_LAS = list()
LOS3Y_MFBL = list()
LOS3Y_MFHL = list()
LOS3Y_MFOT = list()
LOS3Y_OTH = list()
LOS3Y_PL = list()
LOS3Y_PLBL = list()
LOS3Y_RL = list()
LOS3Y_SCC = list()
LOS3Y_SEL = list()

count_list_AL = list()
count_list_BL = list()
count_list_CC = list()
count_list_CD = list()
count_list_CV = list()
count_list_GL = list()
count_list_HL = list()
count_list_LAS = list()
count_list_MFBL = list()
count_list_MFHL = list()
count_list_MFOT = list()
count_list_OTH = list()
count_list_PL = list()
count_list_PLBL = list()
count_list_RL = list()
count_list_SCC = list()
count_list_SEL = list()

count_AL = 0
count_BL = 0
count_CC = 0
count_CD = 0
count_CV = 0
count_GL = 0
count_HL = 0
count_LAS = 0
count_MFBL = 0
count_MFHL = 0
count_MFOT = 0
count_OTH = 0
count_PL = 0 
count_PLBL = 0
count_RL = 0
count_SCC = 0
count_SEL = 0

grp_df = df.groupby('ID')

for x in range(0, len(unq_id_list)):
    grp_slice = grp_df.get_group(unq_id_list[x])
    #print(grp_slice)
    grp_slice.reset_index(drop=True, inplace=True)
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['accountType'][i]=='unknown'):
            continue
        elif (grp_slice['accountType'][i]=='AL') and (grp_slice['LOS3Y_flag'][i]==1):
            count_AL = count_AL + 1
        elif (grp_slice['accountType'][i]=='BL') and (grp_slice['LOS3Y_flag'][i]==1):
            count_BL = count_BL + 1
        elif (grp_slice['accountType'][i]=='CC') and (grp_slice['LOS3Y_flag'][i]==1):
            count_CC = count_CC + 1
        elif (grp_slice['accountType'][i]=='CD') and (grp_slice['LOS3Y_flag'][i]==1):
            count_CD = count_CD + 1
        elif (grp_slice['accountType'][i]=='CV') and (grp_slice['LOS3Y_flag'][i]==1):
            count_CV = count_CV + 1
        elif (grp_slice['accountType'][i]=='GL') and (grp_slice['LOS3Y_flag'][i]==1):
            count_GL = count_GL + 1
        elif (grp_slice['accountType'][i]=='HL') and (grp_slice['LOS3Y_flag'][i]==1):
            count_HL = count_HL + 1
        elif (grp_slice['accountType'][i]=='LAS') and (grp_slice['LOS3Y_flag'][i]==1):
            count_LAS = count_LAS + 1
        elif (grp_slice['accountType'][i]=='MFBL') and (grp_slice['LOS3Y_flag'][i]==1):
            count_MFBL = count_MFBL + 1
        elif (grp_slice['accountType'][i]=='MFHL') and (grp_slice['LOS3Y_flag'][i]==1):
            count_MFHL = count_MFHL + 1
        elif (grp_slice['accountType'][i]=='MFOT') and (grp_slice['LOS3Y_flag'][i]==1):
            count_MFOT = count_MFOT + 1
        elif (grp_slice['accountType'][i]=='OTH') and (grp_slice['LOS3Y_flag'][i]==1):
            count_OTH = count_OTH + 1
        elif (grp_slice['accountType'][i]=='PL') and (grp_slice['LOS3Y_flag'][i]==1):
            count_PL = count_PL + 1
        elif (grp_slice['accountType'][i]=='PLBL') and (grp_slice['LOS3Y_flag'][i]==1):
            count_PLBL = count_PLBL + 1
        elif (grp_slice['accountType'][i]=='RL') and (grp_slice['LOS3Y_flag'][i]==1):
            count_RL = count_RL + 1
        elif (grp_slice['accountType'][i]=='SCC') and (grp_slice['LOS3Y_flag'][i]==1):
            count_SCC = count_SCC + 1
        elif (grp_slice['accountType'][i]=='SEL') and (grp_slice['LOS3Y_flag'][i]==1):
            count_SEL = count_SEL + 1
            
    count_list_AL.append(count_AL)
    count_list_BL.append(count_BL)
    count_list_CC.append(count_CC)
    count_list_CD.append(count_CD)
    count_list_CV.append(count_CV)
    count_list_GL.append(count_GL)
    count_list_HL.append(count_HL)
    count_list_LAS.append(count_LAS)
    count_list_MFBL.append(count_MFBL)
    count_list_MFHL.append(count_MFHL)
    count_list_MFOT.append(count_MFOT)
    count_list_OTH.append(count_OTH)
    count_list_PL.append(count_PL)
    count_list_PLBL.append(count_PLBL)
    count_list_RL.append(count_RL)
    count_list_SCC.append(count_SCC)
    count_list_SEL.append(count_SEL)
    
    count_AL = 0
    count_BL = 0
    count_CC = 0
    count_CD = 0
    count_CV = 0
    count_GL = 0
    count_HL = 0
    count_LAS = 0
    count_MFBL = 0
    count_MFHL = 0
    count_MFOT = 0
    count_OTH = 0
    count_PL = 0
    count_PLBL = 0
    count_RL = 0
    count_SCC = 0
    count_SEL = 0
    
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['accountType'][i]=='unknown'):
            LOS3Y_AL.append('unknown')
            LOS3Y_BL.append('unknown')
            LOS3Y_CC.append('unknown')
            LOS3Y_CD.append('unknown')
            LOS3Y_CV.append('unknown')
            LOS3Y_GL.append('unknown')
            LOS3Y_HL.append('unknown')
            LOS3Y_LAS.append('unknown')
            LOS3Y_MFBL.append('unknown')
            LOS3Y_MFHL.append('unknown')
            LOS3Y_MFOT.append('unknown')
            LOS3Y_OTH.append('unknown')
            LOS3Y_PL.append('unknown')
            LOS3Y_PLBL.append('unknown')
            LOS3Y_RL.append('unknown')
            LOS3Y_SCC.append('unknown')
            LOS3Y_SEL.append('unknown')
        else:
            LOS3Y_AL.append(count_list_AL[x])
            LOS3Y_BL.append(count_list_BL[x])
            LOS3Y_CC.append(count_list_CC[x])
            LOS3Y_CD.append(count_list_CD[x])
            LOS3Y_CV.append(count_list_CV[x])
            LOS3Y_GL.append(count_list_GL[x])
            LOS3Y_HL.append(count_list_HL[x])
            LOS3Y_LAS.append(count_list_LAS[x])
            LOS3Y_MFBL.append(count_list_MFBL[x])
            LOS3Y_MFHL.append(count_list_MFHL[x])
            LOS3Y_MFOT.append(count_list_MFOT[x])
            LOS3Y_OTH.append(count_list_OTH[x])
            LOS3Y_PL.append(count_list_PL[x])
            LOS3Y_PLBL.append(count_list_PLBL[x])
            LOS3Y_RL.append(count_list_RL[x])
            LOS3Y_SCC.append(count_list_SCC[x])
            LOS3Y_SEL.append(count_list_SEL[x])
            
df['LOS3Y_AL'] = pd.Series(LOS3Y_AL).values
df['LOS3Y_BL'] = pd.Series(LOS3Y_BL).values
df['LOS3Y_CC'] = pd.Series(LOS3Y_CC).values
df['LOS3Y_CD'] = pd.Series(LOS3Y_CD).values
df['LOS3Y_CV'] = pd.Series(LOS3Y_CV).values
df['LOS3Y_GL'] = pd.Series(LOS3Y_GL).values
df['LOS3Y_HL'] = pd.Series(LOS3Y_HL).values
df['LOS3Y_LAS'] = pd.Series(LOS3Y_LAS).values
df['LOS3Y_MFBL'] = pd.Series(LOS3Y_MFBL).values
df['LOS3Y_MFHL'] = pd.Series(LOS3Y_MFHL).values
df['LOS3Y_MFOT'] = pd.Series(LOS3Y_MFOT).values
df['LOS3Y_OTH'] = pd.Series(LOS3Y_OTH).values
df['LOS3Y_PL'] = pd.Series(LOS3Y_PL).values
df['LOS3Y_PLBL'] = pd.Series(LOS3Y_PLBL).values
df['LOS3Y_RL'] = pd.Series(LOS3Y_RL).values
df['LOS3Y_SCC'] = pd.Series(LOS3Y_SCC).values
df['LOS3Y_SEL'] = pd.Series(LOS3Y_SEL).values

# %% [raw]
# d = df[['ID','LOS3Y_GL','LOS3Y_flag','accountType']]
# d[d['LOS3Y_flag']!=0].head(60)

# %% [markdown]
# <a id='XXX_flags'></a>
# ### Code for XXX flags

# %%
xxx_last1_mon = list()
xxx_last3_mon_diff = list()
xxx_last3_mon = list()
xxx_last6_mon_diff = list()
xxx_last6_mon = list()
xxx_last1_yr_diff = list()
xxx_last1_yr = list()
xxx_last2_yr_diff = list()
xxx_last2_yr = list()
xxx_last3_yr_diff = list()
xxx_last3_yr = list()
matching = list()


for x in range(0,df.shape[0]):
    if (df['mo_diff_ld_drc'][x]==-1):
        xxx_last1_mon.append('unknown')
    elif (df['mo_diff_ld_drc'][x]==1) and (df['payHistComp'][x][0]=='XXX'):
        xxx_last1_mon.append(1)
    else:
        xxx_last1_mon.append(0)
        
    if (df['mo_diff_ld_drc'][x]==-1):
        xxx_last3_mon_diff.append('unknown')
    elif (df['mo_diff_ld_drc'][x]>1) and (df['mo_diff_ld_drc'][x]<4):
        xxx_last3_mon_diff.append(1)
    else:
        xxx_last3_mon_diff.append(0)
    
    if (df['mo_diff_ld_drc'][x]==-1):
        xxx_last6_mon_diff.append('unknown')
    elif (df['mo_diff_ld_drc'][x]>1) and (df['mo_diff_ld_drc'][x]<7):
        xxx_last6_mon_diff.append(1)
    else:
        xxx_last6_mon_diff.append(0)
    
    if (df['mo_diff_ld_drc'][x]==-1):
        xxx_last1_yr_diff.append('unknown')
    elif (df['mo_diff_ld_drc'][x]>1) and (df['mo_diff_ld_drc'][x]<13):
        xxx_last1_yr_diff.append(1)
    else:
        xxx_last1_yr_diff.append(0)

    if (df['mo_diff_ld_drc'][x]==-1):
        xxx_last2_yr_diff.append('unknown')
    elif (df['mo_diff_ld_drc'][x]>1) and (df['mo_diff_ld_drc'][x]<25):
        xxx_last2_yr_diff.append(1)
    else:
        xxx_last2_yr_diff.append(0)

    if (df['mo_diff_ld_drc'][x]==-1):
        xxx_last3_yr_diff.append('unknown')
    elif (df['mo_diff_ld_drc'][x]>1) and (df['mo_diff_ld_drc'][x]<37):
        xxx_last3_yr_diff.append(1)
    else:
        xxx_last3_yr_diff.append(0)
              
df['xxx_last3_mon_diff'] = pd.Series(xxx_last3_mon_diff).values
df['xxx_last6_mon_diff'] = pd.Series(xxx_last6_mon_diff).values
df['xxx_last1_yr_diff'] = pd.Series(xxx_last1_yr_diff).values
df['xxx_last2_yr_diff'] = pd.Series(xxx_last2_yr_diff).values
df['xxx_last3_yr_diff'] = pd.Series(xxx_last3_yr_diff).values

for x in range(0, df.shape[0]):
    if (df['xxx_last3_mon_diff'][x]=='unknown'):
        xxx_last3_mon.append('unknown')
    elif (df['xxx_last3_mon_diff'][x]==1):
        for i in range(0, 3-df['mo_diff_ld_drc'][x]):
            #print(i)
            matching.append(df['payHistComp'][x][i])
        if any('XXX' in s for s in matching):
            xxx_last3_mon.append(1)
        else:
            xxx_last3_mon.append(0)
        #print(matching)    
        matching = list()
    else:
        xxx_last3_mon.append(0)

    if (df['xxx_last6_mon_diff'][x]=='unknown'):
        xxx_last6_mon.append('unknown')
    elif (df['xxx_last6_mon_diff'][x]==1):
        for i in range(0, 6-df['mo_diff_ld_drc'][x]):
            #print(i)
            matching.append(df['payHistComp'][x][i])
        if any('XXX' in s for s in matching):
            xxx_last6_mon.append(1)
        else:
            xxx_last6_mon.append(0)
        #print(matching)    
        matching = list()
    else:
        xxx_last6_mon.append(0)

    if (df['xxx_last1_yr_diff'][x]=='unknown'):
        xxx_last1_yr.append('unknown')
    elif (df['xxx_last1_yr_diff'][x]==1) and (len(df['payHistComp'][x])>=12):
        for i in range(0, 12-df['mo_diff_ld_drc'][x]):
            #print(i)
            matching.append(df['payHistComp'][x][i])
        if any('XXX' in s for s in matching):
            xxx_last1_yr.append(1)
        else:
            xxx_last1_yr.append(0)
        #print(matching)    
        matching = list()
    else:
        xxx_last1_yr.append(0)
    
    if (df['xxx_last2_yr_diff'][x]=='unknown'):
        xxx_last2_yr.append('unknown')
    elif (df['xxx_last2_yr_diff'][x]==1) and (len(df['payHistComp'][x])>=24):
        for i in range(0, 24-df['mo_diff_ld_drc'][x]):
            #print(i)
            matching.append(df['payHistComp'][x][i])
        if any('XXX' in s for s in matching):
            xxx_last2_yr.append(1)
        else:
            xxx_last2_yr.append(0)
        #print(matching)    
        matching = list()
    else:
        xxx_last2_yr.append(0)
    
    if (df['xxx_last3_yr_diff'][x]=='unknown'):
        xxx_last3_yr.append('unknown')
    elif (df['xxx_last3_yr_diff'][x]==1) and (len(df['payHistComp'][x])==36):
        for i in range(0, 36-df['mo_diff_ld_drc'][x]):
            #print(i)
            matching.append(df['payHistComp'][x][i])
        if any('XXX' in s for s in matching):
            xxx_last3_yr.append(1)
        else:
            xxx_last3_yr.append(0)
        #print(matching)    
        matching = list()
    else:
        xxx_last3_yr.append(0)

df['XXX1M_flag'] = pd.Series(xxx_last1_mon).values
#print(df['XXX1M_flag'].value_counts()) 

df['XXX3M_flag'] = pd.Series(xxx_last3_mon).values
#print(df['XXX3M_flag'].value_counts())
   
df['XXX6M_flag'] = pd.Series(xxx_last6_mon).values
#print(df['XXX6M_flag'].value_counts())
   
df['XXX1Y_flag'] = pd.Series(xxx_last1_yr).values
#print(df['XXX1Y_flag'].value_counts())
   
df['XXX2Y_flag'] = pd.Series(xxx_last2_yr).values
#print(df['XXX2Y_flag'].value_counts())

df['XXX3Y_flag'] = pd.Series(xxx_last3_yr).values
#print(df['XXX3Y_flag'].value_counts())

# %% [raw]
# piece = list()
#
# xxx_last1_mon = list()
# xxx_last3_mon = list()
# xxx_last6_mon = list()
# xxx_last1_yr = list()
# xxx_last2_yr = list()
# xxx_last3_yr = list()
#
# count = 0
#
# for value in df['paymentHistComp'].astype('str'):
#     #print(value)
#
#     chunks, chunk_size = len(value), 3
#     for i in range(0, chunks, chunk_size):
#         piece.append(value[i:i+chunk_size])
#     #print(piece)
#     #print(len(piece))
#
#     if ('XXX' in piece[0]):
#         #print(piece)
#         for x in piece:
#             if x == 'XXX':
#                 count = count + 1
#                 #print(count)
#             else:
#                 break
#         if count >= 1:
#             #print('1mo')
#             xxx_last1_mon.append(1)
#             if count >= 3:
#                 #print('3mo')
#                 xxx_last3_mon.append(1)
#                 if count >= 6:
#                     #print('6mo')
#                     xxx_last6_mon.append(1)
#                     if count >= 12:
#                         #print('1yr')
#                         xxx_last1_yr.append(1)
#                         if count >= 24:
#                             #print('2yr')
#                             xxx_last2_yr.append(1)
#                             if count >= 36:
#                                 #print('3yr')
#                                 xxx_last3_yr.append(1)
#                             else:
#                                 xxx_last3_yr.append(0)
#                         else:
#                             xxx_last2_yr.append(0)
#                             xxx_last3_yr.append(0)
#                     else:
#                         xxx_last1_yr.append(0)
#                         xxx_last2_yr.append(0)
#                         xxx_last3_yr.append(0)
#                 else:
#                     xxx_last6_mon.append(0)
#                     xxx_last1_yr.append(0)
#                     xxx_last2_yr.append(0)
#                     xxx_last3_yr.append(0)
#             else:
#                 xxx_last3_mon.append(0)
#                 xxx_last6_mon.append(0)
#                 xxx_last1_yr.append(0)
#                 xxx_last2_yr.append(0)
#                 xxx_last3_yr.append(0)
#         else:
#             xxx_last1_mon.append(0)
#             xxx_last3_mon.append(0)
#             xxx_last6_mon.append(0)
#             xxx_last1_yr.append(0)
#             xxx_last2_yr.append(0)
#             xxx_last3_yr.append(0)
#     else:
#         xxx_last1_mon.append(0)
#         xxx_last3_mon.append(0)
#         xxx_last6_mon.append(0)
#         xxx_last1_yr.append(0)
#         xxx_last2_yr.append(0)
#         xxx_last3_yr.append(0)
#
#     count = 0
#     piece = list()
#
# df['XXX1M_flag'] = pd.Series(xxx_last1_mon).values
# df['XXX3M_flag'] = pd.Series(xxx_last3_mon).values
# df['XXX6M_flag'] = pd.Series(xxx_last6_mon).values
# df['XXX1Y_flag'] = pd.Series(xxx_last1_yr).values
# df['XXX2Y_flag'] = pd.Series(xxx_last2_yr).values
# df['XXX3Y_flag'] = pd.Series(xxx_last3_yr).values

# %% [markdown]
# <a id='XXX_num'></a>
# ### Code for XXX (numerical)

# %% [markdown]
# - For an applicant, Count of all loans where XXX1M_flag =1
# - For an applicant, Count of all loans where XXX3M_flag =1
# - For an applicant, Count of all loans where XXX6M_flag =1
# - For an applicant, Count of all loans where XXX1Y_flag =1
# - For an applicant, Count of all loans where XXX2Y_flag =1
# - For an applicant, Count of all loans where XXX3Y_flag =1

# %%
XXX1M = list()
count_list_1m = list()
count_1m = 0

XXX3M = list()
count_list_3m = list()
count_3m = 0

XXX6M = list()
count_list_6m = list()
count_6m = 0

XXX1Y = list()
count_list_1y = list()
count_1y = 0

XXX2Y = list()
count_list_2y = list()
count_2y = 0

XXX3Y = list()
count_list_3y = list()
count_3y = 0

grp_df = df.groupby('ID')

for x in range(0, len(unq_id_list)):
    grp_slice = grp_df.get_group(unq_id_list[x])
    #print(grp_slice)
    grp_slice.reset_index(drop=True, inplace=True)
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['XXX1M_flag'][i]==1) or (grp_slice['XXX1M_flag'][i]==0):
            count_1m = count_1m + grp_slice['XXX1M_flag'][i]
        
        if (grp_slice['XXX3M_flag'][i]==1) or (grp_slice['XXX3M_flag'][i]==0):
            count_3m = count_3m + grp_slice['XXX3M_flag'][i]

        if (grp_slice['XXX6M_flag'][i]==1) or (grp_slice['XXX6M_flag'][i]==0):
            count_6m = count_6m + grp_slice['XXX6M_flag'][i]

        if (grp_slice['XXX1Y_flag'][i]==1) or (grp_slice['XXX1Y_flag'][i]==0):
            count_1y = count_1y + grp_slice['XXX1Y_flag'][i]

        if (grp_slice['XXX2Y_flag'][i]==1) or (grp_slice['XXX2Y_flag'][i]==0):
            count_2y = count_2y + grp_slice['XXX2Y_flag'][i]

        if (grp_slice['XXX3Y_flag'][i]==1) or (grp_slice['XXX3Y_flag'][i]==0):
            count_3y = count_3y + grp_slice['XXX3Y_flag'][i]


    count_list_1m.append(count_1m)
    count_1m = 0
    count_list_3m.append(count_3m)
    count_3m = 0
    count_list_6m.append(count_6m)
    count_6m = 0
    count_list_1y.append(count_1y)
    count_1y = 0
    count_list_2y.append(count_2y)
    count_2y = 0
    count_list_3y.append(count_3y)
    count_3y = 0

    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['XXX1M_flag'][i]==1) or (grp_slice['XXX1M_flag'][i]==0):
            XXX1M.append(count_list_1m[x])
        else:
            XXX1M.append('unknown')

        if (grp_slice['XXX3M_flag'][i]==1) or (grp_slice['XXX3M_flag'][i]==0):
            XXX3M.append(count_list_3m[x])
        else:
            XXX3M.append('unknown')
        
        if (grp_slice['XXX6M_flag'][i]==1) or (grp_slice['XXX6M_flag'][i]==0):
            XXX6M.append(count_list_6m[x])
        else:
            XXX6M.append('unknown')

        if (grp_slice['XXX1Y_flag'][i]==1) or (grp_slice['XXX1Y_flag'][i]==0):
            XXX1Y.append(count_list_1y[x])
        else:
            XXX1Y.append('unknown')

        if (grp_slice['XXX2Y_flag'][i]==1) or (grp_slice['XXX2Y_flag'][i]==0):
            XXX2Y.append(count_list_2y[x])
        else:
            XXX2Y.append('unknown')
        
        if (grp_slice['XXX3Y_flag'][i]==1) or (grp_slice['XXX3Y_flag'][i]==0):
            XXX3Y.append(count_list_3y[x])
        else:
            XXX3Y.append('unknown')
            
df['XXX1M'] = pd.Series(XXX1M).values
df['XXX3M'] = pd.Series(XXX3M).values
df['XXX6M'] = pd.Series(XXX6M).values
df['XXX1Y'] = pd.Series(XXX1Y).values
df['XXX2Y'] = pd.Series(XXX2Y).values
df['XXX3Y'] = pd.Series(XXX3Y).values
#print(df['XXX3Y'].value_counts())

# %% [markdown]
# ### Code for XXX1M_P
# - XXX in last 1 month productwise

# %%
XXX1M_AL = list()
XXX1M_BL = list()
XXX1M_CC = list()
XXX1M_CD = list()
XXX1M_CV = list()
XXX1M_GL = list()
XXX1M_HL = list()
XXX1M_LAS = list()
XXX1M_MFBL = list()
XXX1M_MFHL = list()
XXX1M_MFOT = list()
XXX1M_OTH = list()
XXX1M_PL = list()
XXX1M_PLBL = list()
XXX1M_RL = list()
XXX1M_SCC = list()
XXX1M_SEL = list()

count_list_AL = list()
count_list_BL = list()
count_list_CC = list()
count_list_CD = list()
count_list_CV = list()
count_list_GL = list()
count_list_HL = list()
count_list_LAS = list()
count_list_MFBL = list()
count_list_MFHL = list()
count_list_MFOT = list()
count_list_OTH = list()
count_list_PL = list()
count_list_PLBL = list()
count_list_RL = list()
count_list_SCC = list()
count_list_SEL = list()

count_AL = 0
count_BL = 0
count_CC = 0
count_CD = 0
count_CV = 0
count_GL = 0
count_HL = 0
count_LAS = 0
count_MFBL = 0
count_MFHL = 0
count_MFOT = 0
count_OTH = 0
count_PL = 0 
count_PLBL = 0
count_RL = 0
count_SCC = 0
count_SEL = 0

grp_df = df.groupby('ID')

for x in range(0, len(unq_id_list)):
    grp_slice = grp_df.get_group(unq_id_list[x])
    #print(grp_slice)
    grp_slice.reset_index(drop=True, inplace=True)
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['accountType'][i]=='unknown'):
            continue
        elif (grp_slice['accountType'][i]=='AL') and (grp_slice['XXX1M_flag'][i]==1):
            count_AL = count_AL + 1
        elif (grp_slice['accountType'][i]=='BL') and (grp_slice['XXX1M_flag'][i]==1):
            count_BL = count_BL + 1
        elif (grp_slice['accountType'][i]=='CC') and (grp_slice['XXX1M_flag'][i]==1):
            count_CC = count_CC + 1
        elif (grp_slice['accountType'][i]=='CD') and (grp_slice['XXX1M_flag'][i]==1):
            count_CD = count_CD + 1
        elif (grp_slice['accountType'][i]=='CV') and (grp_slice['XXX1M_flag'][i]==1):
            count_CV = count_CV + 1
        elif (grp_slice['accountType'][i]=='GL') and (grp_slice['XXX1M_flag'][i]==1):
            count_GL = count_GL + 1
        elif (grp_slice['accountType'][i]=='HL') and (grp_slice['XXX1M_flag'][i]==1):
            count_HL = count_HL + 1
        elif (grp_slice['accountType'][i]=='LAS') and (grp_slice['XXX1M_flag'][i]==1):
            count_LAS = count_LAS + 1
        elif (grp_slice['accountType'][i]=='MFBL') and (grp_slice['XXX1M_flag'][i]==1):
            count_MFBL = count_MFBL + 1
        elif (grp_slice['accountType'][i]=='MFHL') and (grp_slice['XXX1M_flag'][i]==1):
            count_MFHL = count_MFHL + 1
        elif (grp_slice['accountType'][i]=='MFOT') and (grp_slice['XXX1M_flag'][i]==1):
            count_MFOT = count_MFOT + 1
        elif (grp_slice['accountType'][i]=='OTH') and (grp_slice['XXX1M_flag'][i]==1):
            count_OTH = count_OTH + 1
        elif (grp_slice['accountType'][i]=='PL') and (grp_slice['XXX1M_flag'][i]==1):
            count_PL = count_PL + 1
        elif (grp_slice['accountType'][i]=='PLBL') and (grp_slice['XXX1M_flag'][i]==1):
            count_PLBL = count_PLBL + 1
        elif (grp_slice['accountType'][i]=='RL') and (grp_slice['XXX1M_flag'][i]==1):
            count_RL = count_RL + 1
        elif (grp_slice['accountType'][i]=='SCC') and (grp_slice['XXX1M_flag'][i]==1):
            count_SCC = count_SCC + 1
        elif (grp_slice['accountType'][i]=='SEL') and (grp_slice['XXX1M_flag'][i]==1):
            count_SEL = count_SEL + 1
            
    count_list_AL.append(count_AL)
    count_list_BL.append(count_BL)
    count_list_CC.append(count_CC)
    count_list_CD.append(count_CD)
    count_list_CV.append(count_CV)
    count_list_GL.append(count_GL)
    count_list_HL.append(count_HL)
    count_list_LAS.append(count_LAS)
    count_list_MFBL.append(count_MFBL)
    count_list_MFHL.append(count_MFHL)
    count_list_MFOT.append(count_MFOT)
    count_list_OTH.append(count_OTH)
    count_list_PL.append(count_PL)
    count_list_PLBL.append(count_PLBL)
    count_list_RL.append(count_RL)
    count_list_SCC.append(count_SCC)
    count_list_SEL.append(count_SEL)
    
    count_AL = 0
    count_BL = 0
    count_CC = 0
    count_CD = 0
    count_CV = 0
    count_GL = 0
    count_HL = 0
    count_LAS = 0
    count_MFBL = 0
    count_MFHL = 0
    count_MFOT = 0
    count_OTH = 0
    count_PL = 0
    count_PLBL = 0
    count_RL = 0
    count_SCC = 0
    count_SEL = 0
    
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['accountType'][i]=='unknown'):
            XXX1M_AL.append('unknown')
            XXX1M_BL.append('unknown')
            XXX1M_CC.append('unknown')
            XXX1M_CD.append('unknown')
            XXX1M_CV.append('unknown')
            XXX1M_GL.append('unknown')
            XXX1M_HL.append('unknown')
            XXX1M_LAS.append('unknown')
            XXX1M_MFBL.append('unknown')
            XXX1M_MFHL.append('unknown')
            XXX1M_MFOT.append('unknown')
            XXX1M_OTH.append('unknown')
            XXX1M_PL.append('unknown')
            XXX1M_PLBL.append('unknown')
            XXX1M_RL.append('unknown')
            XXX1M_SCC.append('unknown')
            XXX1M_SEL.append('unknown')
        else:
            XXX1M_AL.append(count_list_AL[x])
            XXX1M_BL.append(count_list_BL[x])
            XXX1M_CC.append(count_list_CC[x])
            XXX1M_CD.append(count_list_CD[x])
            XXX1M_CV.append(count_list_CV[x])
            XXX1M_GL.append(count_list_GL[x])
            XXX1M_HL.append(count_list_HL[x])
            XXX1M_LAS.append(count_list_LAS[x])
            XXX1M_MFBL.append(count_list_MFBL[x])
            XXX1M_MFHL.append(count_list_MFHL[x])
            XXX1M_MFOT.append(count_list_MFOT[x])
            XXX1M_OTH.append(count_list_OTH[x])
            XXX1M_PL.append(count_list_PL[x])
            XXX1M_PLBL.append(count_list_PLBL[x])
            XXX1M_RL.append(count_list_RL[x])
            XXX1M_SCC.append(count_list_SCC[x])
            XXX1M_SEL.append(count_list_SEL[x])
            
df['XXX1M_AL'] = pd.Series(XXX1M_AL).values
df['XXX1M_BL'] = pd.Series(XXX1M_BL).values
df['XXX1M_CC'] = pd.Series(XXX1M_CC).values
df['XXX1M_CD'] = pd.Series(XXX1M_CD).values
df['XXX1M_CV'] = pd.Series(XXX1M_CV).values
df['XXX1M_GL'] = pd.Series(XXX1M_GL).values
df['XXX1M_HL'] = pd.Series(XXX1M_HL).values
df['XXX1M_LAS'] = pd.Series(XXX1M_LAS).values
df['XXX1M_MFBL'] = pd.Series(XXX1M_MFBL).values
df['XXX1M_MFHL'] = pd.Series(XXX1M_MFHL).values
df['XXX1M_MFOT'] = pd.Series(XXX1M_MFOT).values
df['XXX1M_OTH'] = pd.Series(XXX1M_OTH).values
df['XXX1M_PL'] = pd.Series(XXX1M_PL).values
df['XXX1M_PLBL'] = pd.Series(XXX1M_PLBL).values
df['XXX1M_RL'] = pd.Series(XXX1M_RL).values
df['XXX1M_SCC'] = pd.Series(XXX1M_SCC).values
df['XXX1M_SEL'] = pd.Series(XXX1M_SEL).values

# %% [raw]
# d = df[['ID','XXX1M_GL','XXX1M_flag','accountType']]
# d[d['XXX1M_flag']!=0].head(60)

# %% [markdown]
# ### Code for XXX3M_P
# - XXX in last 3 month productwise

# %%
XXX3M_AL = list()
XXX3M_BL = list()
XXX3M_CC = list()
XXX3M_CD = list()
XXX3M_CV = list()
XXX3M_GL = list()
XXX3M_HL = list()
XXX3M_LAS = list()
XXX3M_MFBL = list()
XXX3M_MFHL = list()
XXX3M_MFOT = list()
XXX3M_OTH = list()
XXX3M_PL = list()
XXX3M_PLBL = list()
XXX3M_RL = list()
XXX3M_SCC = list()
XXX3M_SEL = list()

count_list_AL = list()
count_list_BL = list()
count_list_CC = list()
count_list_CD = list()
count_list_CV = list()
count_list_GL = list()
count_list_HL = list()
count_list_LAS = list()
count_list_MFBL = list()
count_list_MFHL = list()
count_list_MFOT = list()
count_list_OTH = list()
count_list_PL = list()
count_list_PLBL = list()
count_list_RL = list()
count_list_SCC = list()
count_list_SEL = list()

count_AL = 0
count_BL = 0
count_CC = 0
count_CD = 0
count_CV = 0
count_GL = 0
count_HL = 0
count_LAS = 0
count_MFBL = 0
count_MFHL = 0
count_MFOT = 0
count_OTH = 0
count_PL = 0 
count_PLBL = 0
count_RL = 0
count_SCC = 0
count_SEL = 0

grp_df = df.groupby('ID')

for x in range(0, len(unq_id_list)):
    grp_slice = grp_df.get_group(unq_id_list[x])
    #print(grp_slice)
    grp_slice.reset_index(drop=True, inplace=True)
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['accountType'][i]=='unknown'):
            continue
        elif (grp_slice['accountType'][i]=='AL') and (grp_slice['XXX3M_flag'][i]==1):
            count_AL = count_AL + 1
        elif (grp_slice['accountType'][i]=='BL') and (grp_slice['XXX3M_flag'][i]==1):
            count_BL = count_BL + 1
        elif (grp_slice['accountType'][i]=='CC') and (grp_slice['XXX3M_flag'][i]==1):
            count_CC = count_CC + 1
        elif (grp_slice['accountType'][i]=='CD') and (grp_slice['XXX3M_flag'][i]==1):
            count_CD = count_CD + 1
        elif (grp_slice['accountType'][i]=='CV') and (grp_slice['XXX3M_flag'][i]==1):
            count_CV = count_CV + 1
        elif (grp_slice['accountType'][i]=='GL') and (grp_slice['XXX3M_flag'][i]==1):
            count_GL = count_GL + 1
        elif (grp_slice['accountType'][i]=='HL') and (grp_slice['XXX3M_flag'][i]==1):
            count_HL = count_HL + 1
        elif (grp_slice['accountType'][i]=='LAS') and (grp_slice['XXX3M_flag'][i]==1):
            count_LAS = count_LAS + 1
        elif (grp_slice['accountType'][i]=='MFBL') and (grp_slice['XXX3M_flag'][i]==1):
            count_MFBL = count_MFBL + 1
        elif (grp_slice['accountType'][i]=='MFHL') and (grp_slice['XXX3M_flag'][i]==1):
            count_MFHL = count_MFHL + 1
        elif (grp_slice['accountType'][i]=='MFOT') and (grp_slice['XXX3M_flag'][i]==1):
            count_MFOT = count_MFOT + 1
        elif (grp_slice['accountType'][i]=='OTH') and (grp_slice['XXX3M_flag'][i]==1):
            count_OTH = count_OTH + 1
        elif (grp_slice['accountType'][i]=='PL') and (grp_slice['XXX3M_flag'][i]==1):
            count_PL = count_PL + 1
        elif (grp_slice['accountType'][i]=='PLBL') and (grp_slice['XXX3M_flag'][i]==1):
            count_PLBL = count_PLBL + 1
        elif (grp_slice['accountType'][i]=='RL') and (grp_slice['XXX3M_flag'][i]==1):
            count_RL = count_RL + 1
        elif (grp_slice['accountType'][i]=='SCC') and (grp_slice['XXX3M_flag'][i]==1):
            count_SCC = count_SCC + 1
        elif (grp_slice['accountType'][i]=='SEL') and (grp_slice['XXX3M_flag'][i]==1):
            count_SEL = count_SEL + 1
            
    count_list_AL.append(count_AL)
    count_list_BL.append(count_BL)
    count_list_CC.append(count_CC)
    count_list_CD.append(count_CD)
    count_list_CV.append(count_CV)
    count_list_GL.append(count_GL)
    count_list_HL.append(count_HL)
    count_list_LAS.append(count_LAS)
    count_list_MFBL.append(count_MFBL)
    count_list_MFHL.append(count_MFHL)
    count_list_MFOT.append(count_MFOT)
    count_list_OTH.append(count_OTH)
    count_list_PL.append(count_PL)
    count_list_PLBL.append(count_PLBL)
    count_list_RL.append(count_RL)
    count_list_SCC.append(count_SCC)
    count_list_SEL.append(count_SEL)
    
    count_AL = 0
    count_BL = 0
    count_CC = 0
    count_CD = 0
    count_CV = 0
    count_GL = 0
    count_HL = 0
    count_LAS = 0
    count_MFBL = 0
    count_MFHL = 0
    count_MFOT = 0
    count_OTH = 0
    count_PL = 0
    count_PLBL = 0
    count_RL = 0
    count_SCC = 0
    count_SEL = 0
    
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['accountType'][i]=='unknown'):
            XXX3M_AL.append('unknown')
            XXX3M_BL.append('unknown')
            XXX3M_CC.append('unknown')
            XXX3M_CD.append('unknown')
            XXX3M_CV.append('unknown')
            XXX3M_GL.append('unknown')
            XXX3M_HL.append('unknown')
            XXX3M_LAS.append('unknown')
            XXX3M_MFBL.append('unknown')
            XXX3M_MFHL.append('unknown')
            XXX3M_MFOT.append('unknown')
            XXX3M_OTH.append('unknown')
            XXX3M_PL.append('unknown')
            XXX3M_PLBL.append('unknown')
            XXX3M_RL.append('unknown')
            XXX3M_SCC.append('unknown')
            XXX3M_SEL.append('unknown')
        else:
            XXX3M_AL.append(count_list_AL[x])
            XXX3M_BL.append(count_list_BL[x])
            XXX3M_CC.append(count_list_CC[x])
            XXX3M_CD.append(count_list_CD[x])
            XXX3M_CV.append(count_list_CV[x])
            XXX3M_GL.append(count_list_GL[x])
            XXX3M_HL.append(count_list_HL[x])
            XXX3M_LAS.append(count_list_LAS[x])
            XXX3M_MFBL.append(count_list_MFBL[x])
            XXX3M_MFHL.append(count_list_MFHL[x])
            XXX3M_MFOT.append(count_list_MFOT[x])
            XXX3M_OTH.append(count_list_OTH[x])
            XXX3M_PL.append(count_list_PL[x])
            XXX3M_PLBL.append(count_list_PLBL[x])
            XXX3M_RL.append(count_list_RL[x])
            XXX3M_SCC.append(count_list_SCC[x])
            XXX3M_SEL.append(count_list_SEL[x])
            
df['XXX3M_AL'] = pd.Series(XXX3M_AL).values
df['XXX3M_BL'] = pd.Series(XXX3M_BL).values
df['XXX3M_CC'] = pd.Series(XXX3M_CC).values
df['XXX3M_CD'] = pd.Series(XXX3M_CD).values
df['XXX3M_CV'] = pd.Series(XXX3M_CV).values
df['XXX3M_GL'] = pd.Series(XXX3M_GL).values
df['XXX3M_HL'] = pd.Series(XXX3M_HL).values
df['XXX3M_LAS'] = pd.Series(XXX3M_LAS).values
df['XXX3M_MFBL'] = pd.Series(XXX3M_MFBL).values
df['XXX3M_MFHL'] = pd.Series(XXX3M_MFHL).values
df['XXX3M_MFOT'] = pd.Series(XXX3M_MFOT).values
df['XXX3M_OTH'] = pd.Series(XXX3M_OTH).values
df['XXX3M_PL'] = pd.Series(XXX3M_PL).values
df['XXX3M_PLBL'] = pd.Series(XXX3M_PLBL).values
df['XXX3M_RL'] = pd.Series(XXX3M_RL).values
df['XXX3M_SCC'] = pd.Series(XXX3M_SCC).values
df['XXX3M_SEL'] = pd.Series(XXX3M_SEL).values

# %% [raw]
# d = df[['ID','XXX3M_GL','XXX3M_flag','accountType']]
# d[d['XXX3M_flag']!=0].head(60)

# %% [markdown]
# ### Code for XXX6M_P
# - XXX in last 6 month productwise

# %%
XXX6M_AL = list()
XXX6M_BL = list()
XXX6M_CC = list()
XXX6M_CD = list()
XXX6M_CV = list()
XXX6M_GL = list()
XXX6M_HL = list()
XXX6M_LAS = list()
XXX6M_MFBL = list()
XXX6M_MFHL = list()
XXX6M_MFOT = list()
XXX6M_OTH = list()
XXX6M_PL = list()
XXX6M_PLBL = list()
XXX6M_RL = list()
XXX6M_SCC = list()
XXX6M_SEL = list()

count_list_AL = list()
count_list_BL = list()
count_list_CC = list()
count_list_CD = list()
count_list_CV = list()
count_list_GL = list()
count_list_HL = list()
count_list_LAS = list()
count_list_MFBL = list()
count_list_MFHL = list()
count_list_MFOT = list()
count_list_OTH = list()
count_list_PL = list()
count_list_PLBL = list()
count_list_RL = list()
count_list_SCC = list()
count_list_SEL = list()

count_AL = 0
count_BL = 0
count_CC = 0
count_CD = 0
count_CV = 0
count_GL = 0
count_HL = 0
count_LAS = 0
count_MFBL = 0
count_MFHL = 0
count_MFOT = 0
count_OTH = 0
count_PL = 0 
count_PLBL = 0
count_RL = 0
count_SCC = 0
count_SEL = 0

grp_df = df.groupby('ID')

for x in range(0, len(unq_id_list)):
    grp_slice = grp_df.get_group(unq_id_list[x])
    #print(grp_slice)
    grp_slice.reset_index(drop=True, inplace=True)
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['accountType'][i]=='unknown'):
            continue
        elif (grp_slice['accountType'][i]=='AL') and (grp_slice['XXX6M_flag'][i]==1):
            count_AL = count_AL + 1
        elif (grp_slice['accountType'][i]=='BL') and (grp_slice['XXX6M_flag'][i]==1):
            count_BL = count_BL + 1
        elif (grp_slice['accountType'][i]=='CC') and (grp_slice['XXX6M_flag'][i]==1):
            count_CC = count_CC + 1
        elif (grp_slice['accountType'][i]=='CD') and (grp_slice['XXX6M_flag'][i]==1):
            count_CD = count_CD + 1
        elif (grp_slice['accountType'][i]=='CV') and (grp_slice['XXX6M_flag'][i]==1):
            count_CV = count_CV + 1
        elif (grp_slice['accountType'][i]=='GL') and (grp_slice['XXX6M_flag'][i]==1):
            count_GL = count_GL + 1
        elif (grp_slice['accountType'][i]=='HL') and (grp_slice['XXX6M_flag'][i]==1):
            count_HL = count_HL + 1
        elif (grp_slice['accountType'][i]=='LAS') and (grp_slice['XXX6M_flag'][i]==1):
            count_LAS = count_LAS + 1
        elif (grp_slice['accountType'][i]=='MFBL') and (grp_slice['XXX6M_flag'][i]==1):
            count_MFBL = count_MFBL + 1
        elif (grp_slice['accountType'][i]=='MFHL') and (grp_slice['XXX6M_flag'][i]==1):
            count_MFHL = count_MFHL + 1
        elif (grp_slice['accountType'][i]=='MFOT') and (grp_slice['XXX6M_flag'][i]==1):
            count_MFOT = count_MFOT + 1
        elif (grp_slice['accountType'][i]=='OTH') and (grp_slice['XXX6M_flag'][i]==1):
            count_OTH = count_OTH + 1
        elif (grp_slice['accountType'][i]=='PL') and (grp_slice['XXX6M_flag'][i]==1):
            count_PL = count_PL + 1
        elif (grp_slice['accountType'][i]=='PLBL') and (grp_slice['XXX6M_flag'][i]==1):
            count_PLBL = count_PLBL + 1
        elif (grp_slice['accountType'][i]=='RL') and (grp_slice['XXX6M_flag'][i]==1):
            count_RL = count_RL + 1
        elif (grp_slice['accountType'][i]=='SCC') and (grp_slice['XXX6M_flag'][i]==1):
            count_SCC = count_SCC + 1
        elif (grp_slice['accountType'][i]=='SEL') and (grp_slice['XXX6M_flag'][i]==1):
            count_SEL = count_SEL + 1
            
    count_list_AL.append(count_AL)
    count_list_BL.append(count_BL)
    count_list_CC.append(count_CC)
    count_list_CD.append(count_CD)
    count_list_CV.append(count_CV)
    count_list_GL.append(count_GL)
    count_list_HL.append(count_HL)
    count_list_LAS.append(count_LAS)
    count_list_MFBL.append(count_MFBL)
    count_list_MFHL.append(count_MFHL)
    count_list_MFOT.append(count_MFOT)
    count_list_OTH.append(count_OTH)
    count_list_PL.append(count_PL)
    count_list_PLBL.append(count_PLBL)
    count_list_RL.append(count_RL)
    count_list_SCC.append(count_SCC)
    count_list_SEL.append(count_SEL)
    
    count_AL = 0
    count_BL = 0
    count_CC = 0
    count_CD = 0
    count_CV = 0
    count_GL = 0
    count_HL = 0
    count_LAS = 0
    count_MFBL = 0
    count_MFHL = 0
    count_MFOT = 0
    count_OTH = 0
    count_PL = 0
    count_PLBL = 0
    count_RL = 0
    count_SCC = 0
    count_SEL = 0
    
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['accountType'][i]=='unknown'):
            XXX6M_AL.append('unknown')
            XXX6M_BL.append('unknown')
            XXX6M_CC.append('unknown')
            XXX6M_CD.append('unknown')
            XXX6M_CV.append('unknown')
            XXX6M_GL.append('unknown')
            XXX6M_HL.append('unknown')
            XXX6M_LAS.append('unknown')
            XXX6M_MFBL.append('unknown')
            XXX6M_MFHL.append('unknown')
            XXX6M_MFOT.append('unknown')
            XXX6M_OTH.append('unknown')
            XXX6M_PL.append('unknown')
            XXX6M_PLBL.append('unknown')
            XXX6M_RL.append('unknown')
            XXX6M_SCC.append('unknown')
            XXX6M_SEL.append('unknown')
        else:
            XXX6M_AL.append(count_list_AL[x])
            XXX6M_BL.append(count_list_BL[x])
            XXX6M_CC.append(count_list_CC[x])
            XXX6M_CD.append(count_list_CD[x])
            XXX6M_CV.append(count_list_CV[x])
            XXX6M_GL.append(count_list_GL[x])
            XXX6M_HL.append(count_list_HL[x])
            XXX6M_LAS.append(count_list_LAS[x])
            XXX6M_MFBL.append(count_list_MFBL[x])
            XXX6M_MFHL.append(count_list_MFHL[x])
            XXX6M_MFOT.append(count_list_MFOT[x])
            XXX6M_OTH.append(count_list_OTH[x])
            XXX6M_PL.append(count_list_PL[x])
            XXX6M_PLBL.append(count_list_PLBL[x])
            XXX6M_RL.append(count_list_RL[x])
            XXX6M_SCC.append(count_list_SCC[x])
            XXX6M_SEL.append(count_list_SEL[x])
            
df['XXX6M_AL'] = pd.Series(XXX6M_AL).values
df['XXX6M_BL'] = pd.Series(XXX6M_BL).values
df['XXX6M_CC'] = pd.Series(XXX6M_CC).values
df['XXX6M_CD'] = pd.Series(XXX6M_CD).values
df['XXX6M_CV'] = pd.Series(XXX6M_CV).values
df['XXX6M_GL'] = pd.Series(XXX6M_GL).values
df['XXX6M_HL'] = pd.Series(XXX6M_HL).values
df['XXX6M_LAS'] = pd.Series(XXX6M_LAS).values
df['XXX6M_MFBL'] = pd.Series(XXX6M_MFBL).values
df['XXX6M_MFHL'] = pd.Series(XXX6M_MFHL).values
df['XXX6M_MFOT'] = pd.Series(XXX6M_MFOT).values
df['XXX6M_OTH'] = pd.Series(XXX6M_OTH).values
df['XXX6M_PL'] = pd.Series(XXX6M_PL).values
df['XXX6M_PLBL'] = pd.Series(XXX6M_PLBL).values
df['XXX6M_RL'] = pd.Series(XXX6M_RL).values
df['XXX6M_SCC'] = pd.Series(XXX6M_SCC).values
df['XXX6M_SEL'] = pd.Series(XXX6M_SEL).values

# %% [raw]
# d = df[['ID','XXX6M_GL','XXX6M_flag','accountType']]
# d[d['XXX6M_flag']!=0].head(60)

# %% [markdown]
# ### Code for XXX1Y_P
# - XXX in last 1 year productwise

# %%
XXX1Y_AL = list()
XXX1Y_BL = list()
XXX1Y_CC = list()
XXX1Y_CD = list()
XXX1Y_CV = list()
XXX1Y_GL = list()
XXX1Y_HL = list()
XXX1Y_LAS = list()
XXX1Y_MFBL = list()
XXX1Y_MFHL = list()
XXX1Y_MFOT = list()
XXX1Y_OTH = list()
XXX1Y_PL = list()
XXX1Y_PLBL = list()
XXX1Y_RL = list()
XXX1Y_SCC = list()
XXX1Y_SEL = list()

count_list_AL = list()
count_list_BL = list()
count_list_CC = list()
count_list_CD = list()
count_list_CV = list()
count_list_GL = list()
count_list_HL = list()
count_list_LAS = list()
count_list_MFBL = list()
count_list_MFHL = list()
count_list_MFOT = list()
count_list_OTH = list()
count_list_PL = list()
count_list_PLBL = list()
count_list_RL = list()
count_list_SCC = list()
count_list_SEL = list()

count_AL = 0
count_BL = 0
count_CC = 0
count_CD = 0
count_CV = 0
count_GL = 0
count_HL = 0
count_LAS = 0
count_MFBL = 0
count_MFHL = 0
count_MFOT = 0
count_OTH = 0
count_PL = 0 
count_PLBL = 0
count_RL = 0
count_SCC = 0
count_SEL = 0

grp_df = df.groupby('ID')

for x in range(0, len(unq_id_list)):
    grp_slice = grp_df.get_group(unq_id_list[x])
    #print(grp_slice)
    grp_slice.reset_index(drop=True, inplace=True)
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['accountType'][i]=='unknown'):
            continue
        elif (grp_slice['accountType'][i]=='AL') and (grp_slice['XXX1Y_flag'][i]==1):
            count_AL = count_AL + 1
        elif (grp_slice['accountType'][i]=='BL') and (grp_slice['XXX1Y_flag'][i]==1):
            count_BL = count_BL + 1
        elif (grp_slice['accountType'][i]=='CC') and (grp_slice['XXX1Y_flag'][i]==1):
            count_CC = count_CC + 1
        elif (grp_slice['accountType'][i]=='CD') and (grp_slice['XXX1Y_flag'][i]==1):
            count_CD = count_CD + 1
        elif (grp_slice['accountType'][i]=='CV') and (grp_slice['XXX1Y_flag'][i]==1):
            count_CV = count_CV + 1
        elif (grp_slice['accountType'][i]=='GL') and (grp_slice['XXX1Y_flag'][i]==1):
            count_GL = count_GL + 1
        elif (grp_slice['accountType'][i]=='HL') and (grp_slice['XXX1Y_flag'][i]==1):
            count_HL = count_HL + 1
        elif (grp_slice['accountType'][i]=='LAS') and (grp_slice['XXX1Y_flag'][i]==1):
            count_LAS = count_LAS + 1
        elif (grp_slice['accountType'][i]=='MFBL') and (grp_slice['XXX1Y_flag'][i]==1):
            count_MFBL = count_MFBL + 1
        elif (grp_slice['accountType'][i]=='MFHL') and (grp_slice['XXX1Y_flag'][i]==1):
            count_MFHL = count_MFHL + 1
        elif (grp_slice['accountType'][i]=='MFOT') and (grp_slice['XXX1Y_flag'][i]==1):
            count_MFOT = count_MFOT + 1
        elif (grp_slice['accountType'][i]=='OTH') and (grp_slice['XXX1Y_flag'][i]==1):
            count_OTH = count_OTH + 1
        elif (grp_slice['accountType'][i]=='PL') and (grp_slice['XXX1Y_flag'][i]==1):
            count_PL = count_PL + 1
        elif (grp_slice['accountType'][i]=='PLBL') and (grp_slice['XXX1Y_flag'][i]==1):
            count_PLBL = count_PLBL + 1
        elif (grp_slice['accountType'][i]=='RL') and (grp_slice['XXX1Y_flag'][i]==1):
            count_RL = count_RL + 1
        elif (grp_slice['accountType'][i]=='SCC') and (grp_slice['XXX1Y_flag'][i]==1):
            count_SCC = count_SCC + 1
        elif (grp_slice['accountType'][i]=='SEL') and (grp_slice['XXX1Y_flag'][i]==1):
            count_SEL = count_SEL + 1
            
    count_list_AL.append(count_AL)
    count_list_BL.append(count_BL)
    count_list_CC.append(count_CC)
    count_list_CD.append(count_CD)
    count_list_CV.append(count_CV)
    count_list_GL.append(count_GL)
    count_list_HL.append(count_HL)
    count_list_LAS.append(count_LAS)
    count_list_MFBL.append(count_MFBL)
    count_list_MFHL.append(count_MFHL)
    count_list_MFOT.append(count_MFOT)
    count_list_OTH.append(count_OTH)
    count_list_PL.append(count_PL)
    count_list_PLBL.append(count_PLBL)
    count_list_RL.append(count_RL)
    count_list_SCC.append(count_SCC)
    count_list_SEL.append(count_SEL)
    
    count_AL = 0
    count_BL = 0
    count_CC = 0
    count_CD = 0
    count_CV = 0
    count_GL = 0
    count_HL = 0
    count_LAS = 0
    count_MFBL = 0
    count_MFHL = 0
    count_MFOT = 0
    count_OTH = 0
    count_PL = 0
    count_PLBL = 0
    count_RL = 0
    count_SCC = 0
    count_SEL = 0
    
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['accountType'][i]=='unknown'):
            XXX1Y_AL.append('unknown')
            XXX1Y_BL.append('unknown')
            XXX1Y_CC.append('unknown')
            XXX1Y_CD.append('unknown')
            XXX1Y_CV.append('unknown')
            XXX1Y_GL.append('unknown')
            XXX1Y_HL.append('unknown')
            XXX1Y_LAS.append('unknown')
            XXX1Y_MFBL.append('unknown')
            XXX1Y_MFHL.append('unknown')
            XXX1Y_MFOT.append('unknown')
            XXX1Y_OTH.append('unknown')
            XXX1Y_PL.append('unknown')
            XXX1Y_PLBL.append('unknown')
            XXX1Y_RL.append('unknown')
            XXX1Y_SCC.append('unknown')
            XXX1Y_SEL.append('unknown')
        else:
            XXX1Y_AL.append(count_list_AL[x])
            XXX1Y_BL.append(count_list_BL[x])
            XXX1Y_CC.append(count_list_CC[x])
            XXX1Y_CD.append(count_list_CD[x])
            XXX1Y_CV.append(count_list_CV[x])
            XXX1Y_GL.append(count_list_GL[x])
            XXX1Y_HL.append(count_list_HL[x])
            XXX1Y_LAS.append(count_list_LAS[x])
            XXX1Y_MFBL.append(count_list_MFBL[x])
            XXX1Y_MFHL.append(count_list_MFHL[x])
            XXX1Y_MFOT.append(count_list_MFOT[x])
            XXX1Y_OTH.append(count_list_OTH[x])
            XXX1Y_PL.append(count_list_PL[x])
            XXX1Y_PLBL.append(count_list_PLBL[x])
            XXX1Y_RL.append(count_list_RL[x])
            XXX1Y_SCC.append(count_list_SCC[x])
            XXX1Y_SEL.append(count_list_SEL[x])
            
df['XXX1Y_AL'] = pd.Series(XXX1Y_AL).values
df['XXX1Y_BL'] = pd.Series(XXX1Y_BL).values
df['XXX1Y_CC'] = pd.Series(XXX1Y_CC).values
df['XXX1Y_CD'] = pd.Series(XXX1Y_CD).values
df['XXX1Y_CV'] = pd.Series(XXX1Y_CV).values
df['XXX1Y_GL'] = pd.Series(XXX1Y_GL).values
df['XXX1Y_HL'] = pd.Series(XXX1Y_HL).values
df['XXX1Y_LAS'] = pd.Series(XXX1Y_LAS).values
df['XXX1Y_MFBL'] = pd.Series(XXX1Y_MFBL).values
df['XXX1Y_MFHL'] = pd.Series(XXX1Y_MFHL).values
df['XXX1Y_MFOT'] = pd.Series(XXX1Y_MFOT).values
df['XXX1Y_OTH'] = pd.Series(XXX1Y_OTH).values
df['XXX1Y_PL'] = pd.Series(XXX1Y_PL).values
df['XXX1Y_PLBL'] = pd.Series(XXX1Y_PLBL).values
df['XXX1Y_RL'] = pd.Series(XXX1Y_RL).values
df['XXX1Y_SCC'] = pd.Series(XXX1Y_SCC).values
df['XXX1Y_SEL'] = pd.Series(XXX1Y_SEL).values
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/envs/ml_env/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'XXX1Y_flag'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-222-374d99496113> in <module>
#      62         if (grp_slice['accountType'][i]=='unknown'):
#      63             continue
# ---> 64         elif (grp_slice['accountType'][i]=='AL') and (grp_slice['XXX1Y_flag'][i]==1):
#      65             count_AL = count_AL + 1
#      66         elif (grp_slice['accountType'][i]=='BL') and (grp_slice['XXX1Y_flag'][i]==1):
#
# ~/anaconda3/envs/ml_env/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2900             if self.columns.nlevels > 1:
#    2901                 return self._getitem_multilevel(key)
# -> 2902             indexer = self.columns.get_loc(key)
#    2903             if is_integer(indexer):
#    2904                 indexer = [indexer]
#
# ~/anaconda3/envs/ml_env/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
# -> 2897                 raise KeyError(key) from err
#    2898
#    2899         if tolerance is not None:
#
# KeyError: 'XXX1Y_flag'

# %% [raw]
# d = df[['ID','XXX1Y_GL','XXX1Y_flag','accountType']]
# d[d['XXX1Y_flag']!=0].head(60)

# %% [markdown]
# ### Code for XXX2Y_P
# - XXX in last 2 year productwise

# %%
XXX2Y_AL = list()
XXX2Y_BL = list()
XXX2Y_CC = list()
XXX2Y_CD = list()
XXX2Y_CV = list()
XXX2Y_GL = list()
XXX2Y_HL = list()
XXX2Y_LAS = list()
XXX2Y_MFBL = list()
XXX2Y_MFHL = list()
XXX2Y_MFOT = list()
XXX2Y_OTH = list()
XXX2Y_PL = list()
XXX2Y_PLBL = list()
XXX2Y_RL = list()
XXX2Y_SCC = list()
XXX2Y_SEL = list()

count_list_AL = list()
count_list_BL = list()
count_list_CC = list()
count_list_CD = list()
count_list_CV = list()
count_list_GL = list()
count_list_HL = list()
count_list_LAS = list()
count_list_MFBL = list()
count_list_MFHL = list()
count_list_MFOT = list()
count_list_OTH = list()
count_list_PL = list()
count_list_PLBL = list()
count_list_RL = list()
count_list_SCC = list()
count_list_SEL = list()

count_AL = 0
count_BL = 0
count_CC = 0
count_CD = 0
count_CV = 0
count_GL = 0
count_HL = 0
count_LAS = 0
count_MFBL = 0
count_MFHL = 0
count_MFOT = 0
count_OTH = 0
count_PL = 0 
count_PLBL = 0
count_RL = 0
count_SCC = 0
count_SEL = 0

grp_df = df.groupby('ID')

for x in range(0, len(unq_id_list)):
    grp_slice = grp_df.get_group(unq_id_list[x])
    #print(grp_slice)
    grp_slice.reset_index(drop=True, inplace=True)
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['accountType'][i]=='unknown'):
            continue
        elif (grp_slice['accountType'][i]=='AL') and (grp_slice['XXX2Y_flag'][i]==1):
            count_AL = count_AL + 1
        elif (grp_slice['accountType'][i]=='BL') and (grp_slice['XXX2Y_flag'][i]==1):
            count_BL = count_BL + 1
        elif (grp_slice['accountType'][i]=='CC') and (grp_slice['XXX2Y_flag'][i]==1):
            count_CC = count_CC + 1
        elif (grp_slice['accountType'][i]=='CD') and (grp_slice['XXX2Y_flag'][i]==1):
            count_CD = count_CD + 1
        elif (grp_slice['accountType'][i]=='CV') and (grp_slice['XXX2Y_flag'][i]==1):
            count_CV = count_CV + 1
        elif (grp_slice['accountType'][i]=='GL') and (grp_slice['XXX2Y_flag'][i]==1):
            count_GL = count_GL + 1
        elif (grp_slice['accountType'][i]=='HL') and (grp_slice['XXX2Y_flag'][i]==1):
            count_HL = count_HL + 1
        elif (grp_slice['accountType'][i]=='LAS') and (grp_slice['XXX2Y_flag'][i]==1):
            count_LAS = count_LAS + 1
        elif (grp_slice['accountType'][i]=='MFBL') and (grp_slice['XXX2Y_flag'][i]==1):
            count_MFBL = count_MFBL + 1
        elif (grp_slice['accountType'][i]=='MFHL') and (grp_slice['XXX2Y_flag'][i]==1):
            count_MFHL = count_MFHL + 1
        elif (grp_slice['accountType'][i]=='MFOT') and (grp_slice['XXX2Y_flag'][i]==1):
            count_MFOT = count_MFOT + 1
        elif (grp_slice['accountType'][i]=='OTH') and (grp_slice['XXX2Y_flag'][i]==1):
            count_OTH = count_OTH + 1
        elif (grp_slice['accountType'][i]=='PL') and (grp_slice['XXX2Y_flag'][i]==1):
            count_PL = count_PL + 1
        elif (grp_slice['accountType'][i]=='PLBL') and (grp_slice['XXX2Y_flag'][i]==1):
            count_PLBL = count_PLBL + 1
        elif (grp_slice['accountType'][i]=='RL') and (grp_slice['XXX2Y_flag'][i]==1):
            count_RL = count_RL + 1
        elif (grp_slice['accountType'][i]=='SCC') and (grp_slice['XXX2Y_flag'][i]==1):
            count_SCC = count_SCC + 1
        elif (grp_slice['accountType'][i]=='SEL') and (grp_slice['XXX2Y_flag'][i]==1):
            count_SEL = count_SEL + 1
            
    count_list_AL.append(count_AL)
    count_list_BL.append(count_BL)
    count_list_CC.append(count_CC)
    count_list_CD.append(count_CD)
    count_list_CV.append(count_CV)
    count_list_GL.append(count_GL)
    count_list_HL.append(count_HL)
    count_list_LAS.append(count_LAS)
    count_list_MFBL.append(count_MFBL)
    count_list_MFHL.append(count_MFHL)
    count_list_MFOT.append(count_MFOT)
    count_list_OTH.append(count_OTH)
    count_list_PL.append(count_PL)
    count_list_PLBL.append(count_PLBL)
    count_list_RL.append(count_RL)
    count_list_SCC.append(count_SCC)
    count_list_SEL.append(count_SEL)
    
    count_AL = 0
    count_BL = 0
    count_CC = 0
    count_CD = 0
    count_CV = 0
    count_GL = 0
    count_HL = 0
    count_LAS = 0
    count_MFBL = 0
    count_MFHL = 0
    count_MFOT = 0
    count_OTH = 0
    count_PL = 0
    count_PLBL = 0
    count_RL = 0
    count_SCC = 0
    count_SEL = 0
    
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['accountType'][i]=='unknown'):
            XXX2Y_AL.append('unknown')
            XXX2Y_BL.append('unknown')
            XXX2Y_CC.append('unknown')
            XXX2Y_CD.append('unknown')
            XXX2Y_CV.append('unknown')
            XXX2Y_GL.append('unknown')
            XXX2Y_HL.append('unknown')
            XXX2Y_LAS.append('unknown')
            XXX2Y_MFBL.append('unknown')
            XXX2Y_MFHL.append('unknown')
            XXX2Y_MFOT.append('unknown')
            XXX2Y_OTH.append('unknown')
            XXX2Y_PL.append('unknown')
            XXX2Y_PLBL.append('unknown')
            XXX2Y_RL.append('unknown')
            XXX2Y_SCC.append('unknown')
            XXX2Y_SEL.append('unknown')
        else:
            XXX2Y_AL.append(count_list_AL[x])
            XXX2Y_BL.append(count_list_BL[x])
            XXX2Y_CC.append(count_list_CC[x])
            XXX2Y_CD.append(count_list_CD[x])
            XXX2Y_CV.append(count_list_CV[x])
            XXX2Y_GL.append(count_list_GL[x])
            XXX2Y_HL.append(count_list_HL[x])
            XXX2Y_LAS.append(count_list_LAS[x])
            XXX2Y_MFBL.append(count_list_MFBL[x])
            XXX2Y_MFHL.append(count_list_MFHL[x])
            XXX2Y_MFOT.append(count_list_MFOT[x])
            XXX2Y_OTH.append(count_list_OTH[x])
            XXX2Y_PL.append(count_list_PL[x])
            XXX2Y_PLBL.append(count_list_PLBL[x])
            XXX2Y_RL.append(count_list_RL[x])
            XXX2Y_SCC.append(count_list_SCC[x])
            XXX2Y_SEL.append(count_list_SEL[x])
            
df['XXX2Y_AL'] = pd.Series(XXX2Y_AL).values
df['XXX2Y_BL'] = pd.Series(XXX2Y_BL).values
df['XXX2Y_CC'] = pd.Series(XXX2Y_CC).values
df['XXX2Y_CD'] = pd.Series(XXX2Y_CD).values
df['XXX2Y_CV'] = pd.Series(XXX2Y_CV).values
df['XXX2Y_GL'] = pd.Series(XXX2Y_GL).values
df['XXX2Y_HL'] = pd.Series(XXX2Y_HL).values
df['XXX2Y_LAS'] = pd.Series(XXX2Y_LAS).values
df['XXX2Y_MFBL'] = pd.Series(XXX2Y_MFBL).values
df['XXX2Y_MFHL'] = pd.Series(XXX2Y_MFHL).values
df['XXX2Y_MFOT'] = pd.Series(XXX2Y_MFOT).values
df['XXX2Y_OTH'] = pd.Series(XXX2Y_OTH).values
df['XXX2Y_PL'] = pd.Series(XXX2Y_PL).values
df['XXX2Y_PLBL'] = pd.Series(XXX2Y_PLBL).values
df['XXX2Y_RL'] = pd.Series(XXX2Y_RL).values
df['XXX2Y_SCC'] = pd.Series(XXX2Y_SCC).values
df['XXX2Y_SEL'] = pd.Series(XXX2Y_SEL).values
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/envs/ml_env/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'XXX2Y_flag'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-223-e6ca66300d11> in <module>
#      62         if (grp_slice['accountType'][i]=='unknown'):
#      63             continue
# ---> 64         elif (grp_slice['accountType'][i]=='AL') and (grp_slice['XXX2Y_flag'][i]==1):
#      65             count_AL = count_AL + 1
#      66         elif (grp_slice['accountType'][i]=='BL') and (grp_slice['XXX2Y_flag'][i]==1):
#
# ~/anaconda3/envs/ml_env/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2900             if self.columns.nlevels > 1:
#    2901                 return self._getitem_multilevel(key)
# -> 2902             indexer = self.columns.get_loc(key)
#    2903             if is_integer(indexer):
#    2904                 indexer = [indexer]
#
# ~/anaconda3/envs/ml_env/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
# -> 2897                 raise KeyError(key) from err
#    2898
#    2899         if tolerance is not None:
#
# KeyError: 'XXX2Y_flag'

# %% [raw]
# d = df[['ID','XXX2Y_GL','XXX2Y_flag','accountType']]
# d[d['XXX2Y_flag']!=0].head(60)

# %% [markdown]
# ### Code for XXX3Y_P
# - XXX in last 3 year productwise

# %%
XXX3Y_AL = list()
XXX3Y_BL = list()
XXX3Y_CC = list()
XXX3Y_CD = list()
XXX3Y_CV = list()
XXX3Y_GL = list()
XXX3Y_HL = list()
XXX3Y_LAS = list()
XXX3Y_MFBL = list()
XXX3Y_MFHL = list()
XXX3Y_MFOT = list()
XXX3Y_OTH = list()
XXX3Y_PL = list()
XXX3Y_PLBL = list()
XXX3Y_RL = list()
XXX3Y_SCC = list()
XXX3Y_SEL = list()

count_list_AL = list()
count_list_BL = list()
count_list_CC = list()
count_list_CD = list()
count_list_CV = list()
count_list_GL = list()
count_list_HL = list()
count_list_LAS = list()
count_list_MFBL = list()
count_list_MFHL = list()
count_list_MFOT = list()
count_list_OTH = list()
count_list_PL = list()
count_list_PLBL = list()
count_list_RL = list()
count_list_SCC = list()
count_list_SEL = list()

count_AL = 0
count_BL = 0
count_CC = 0
count_CD = 0
count_CV = 0
count_GL = 0
count_HL = 0
count_LAS = 0
count_MFBL = 0
count_MFHL = 0
count_MFOT = 0
count_OTH = 0
count_PL = 0 
count_PLBL = 0
count_RL = 0
count_SCC = 0
count_SEL = 0

grp_df = df.groupby('ID')

for x in range(0, len(unq_id_list)):
    grp_slice = grp_df.get_group(unq_id_list[x])
    #print(grp_slice)
    grp_slice.reset_index(drop=True, inplace=True)
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['accountType'][i]=='unknown'):
            continue
        elif (grp_slice['accountType'][i]=='AL') and (grp_slice['XXX3Y_flag'][i]==1):
            count_AL = count_AL + 1
        elif (grp_slice['accountType'][i]=='BL') and (grp_slice['XXX3Y_flag'][i]==1):
            count_BL = count_BL + 1
        elif (grp_slice['accountType'][i]=='CC') and (grp_slice['XXX3Y_flag'][i]==1):
            count_CC = count_CC + 1
        elif (grp_slice['accountType'][i]=='CD') and (grp_slice['XXX3Y_flag'][i]==1):
            count_CD = count_CD + 1
        elif (grp_slice['accountType'][i]=='CV') and (grp_slice['XXX3Y_flag'][i]==1):
            count_CV = count_CV + 1
        elif (grp_slice['accountType'][i]=='GL') and (grp_slice['XXX3Y_flag'][i]==1):
            count_GL = count_GL + 1
        elif (grp_slice['accountType'][i]=='HL') and (grp_slice['XXX3Y_flag'][i]==1):
            count_HL = count_HL + 1
        elif (grp_slice['accountType'][i]=='LAS') and (grp_slice['XXX3Y_flag'][i]==1):
            count_LAS = count_LAS + 1
        elif (grp_slice['accountType'][i]=='MFBL') and (grp_slice['XXX3Y_flag'][i]==1):
            count_MFBL = count_MFBL + 1
        elif (grp_slice['accountType'][i]=='MFHL') and (grp_slice['XXX3Y_flag'][i]==1):
            count_MFHL = count_MFHL + 1
        elif (grp_slice['accountType'][i]=='MFOT') and (grp_slice['XXX3Y_flag'][i]==1):
            count_MFOT = count_MFOT + 1
        elif (grp_slice['accountType'][i]=='OTH') and (grp_slice['XXX3Y_flag'][i]==1):
            count_OTH = count_OTH + 1
        elif (grp_slice['accountType'][i]=='PL') and (grp_slice['XXX3Y_flag'][i]==1):
            count_PL = count_PL + 1
        elif (grp_slice['accountType'][i]=='PLBL') and (grp_slice['XXX3Y_flag'][i]==1):
            count_PLBL = count_PLBL + 1
        elif (grp_slice['accountType'][i]=='RL') and (grp_slice['XXX3Y_flag'][i]==1):
            count_RL = count_RL + 1
        elif (grp_slice['accountType'][i]=='SCC') and (grp_slice['XXX3Y_flag'][i]==1):
            count_SCC = count_SCC + 1
        elif (grp_slice['accountType'][i]=='SEL') and (grp_slice['XXX3Y_flag'][i]==1):
            count_SEL = count_SEL + 1
            
    count_list_AL.append(count_AL)
    count_list_BL.append(count_BL)
    count_list_CC.append(count_CC)
    count_list_CD.append(count_CD)
    count_list_CV.append(count_CV)
    count_list_GL.append(count_GL)
    count_list_HL.append(count_HL)
    count_list_LAS.append(count_LAS)
    count_list_MFBL.append(count_MFBL)
    count_list_MFHL.append(count_MFHL)
    count_list_MFOT.append(count_MFOT)
    count_list_OTH.append(count_OTH)
    count_list_PL.append(count_PL)
    count_list_PLBL.append(count_PLBL)
    count_list_RL.append(count_RL)
    count_list_SCC.append(count_SCC)
    count_list_SEL.append(count_SEL)
    
    count_AL = 0
    count_BL = 0
    count_CC = 0
    count_CD = 0
    count_CV = 0
    count_GL = 0
    count_HL = 0
    count_LAS = 0
    count_MFBL = 0
    count_MFHL = 0
    count_MFOT = 0
    count_OTH = 0
    count_PL = 0
    count_PLBL = 0
    count_RL = 0
    count_SCC = 0
    count_SEL = 0
    
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['accountType'][i]=='unknown'):
            XXX3Y_AL.append('unknown')
            XXX3Y_BL.append('unknown')
            XXX3Y_CC.append('unknown')
            XXX3Y_CD.append('unknown')
            XXX3Y_CV.append('unknown')
            XXX3Y_GL.append('unknown')
            XXX3Y_HL.append('unknown')
            XXX3Y_LAS.append('unknown')
            XXX3Y_MFBL.append('unknown')
            XXX3Y_MFHL.append('unknown')
            XXX3Y_MFOT.append('unknown')
            XXX3Y_OTH.append('unknown')
            XXX3Y_PL.append('unknown')
            XXX3Y_PLBL.append('unknown')
            XXX3Y_RL.append('unknown')
            XXX3Y_SCC.append('unknown')
            XXX3Y_SEL.append('unknown')
        else:
            XXX3Y_AL.append(count_list_AL[x])
            XXX3Y_BL.append(count_list_BL[x])
            XXX3Y_CC.append(count_list_CC[x])
            XXX3Y_CD.append(count_list_CD[x])
            XXX3Y_CV.append(count_list_CV[x])
            XXX3Y_GL.append(count_list_GL[x])
            XXX3Y_HL.append(count_list_HL[x])
            XXX3Y_LAS.append(count_list_LAS[x])
            XXX3Y_MFBL.append(count_list_MFBL[x])
            XXX3Y_MFHL.append(count_list_MFHL[x])
            XXX3Y_MFOT.append(count_list_MFOT[x])
            XXX3Y_OTH.append(count_list_OTH[x])
            XXX3Y_PL.append(count_list_PL[x])
            XXX3Y_PLBL.append(count_list_PLBL[x])
            XXX3Y_RL.append(count_list_RL[x])
            XXX3Y_SCC.append(count_list_SCC[x])
            XXX3Y_SEL.append(count_list_SEL[x])
            
df['XXX3Y_AL'] = pd.Series(XXX3Y_AL).values
df['XXX3Y_BL'] = pd.Series(XXX3Y_BL).values
df['XXX3Y_CC'] = pd.Series(XXX3Y_CC).values
df['XXX3Y_CD'] = pd.Series(XXX3Y_CD).values
df['XXX3Y_CV'] = pd.Series(XXX3Y_CV).values
df['XXX3Y_GL'] = pd.Series(XXX3Y_GL).values
df['XXX3Y_HL'] = pd.Series(XXX3Y_HL).values
df['XXX3Y_LAS'] = pd.Series(XXX3Y_LAS).values
df['XXX3Y_MFBL'] = pd.Series(XXX3Y_MFBL).values
df['XXX3Y_MFHL'] = pd.Series(XXX3Y_MFHL).values
df['XXX3Y_MFOT'] = pd.Series(XXX3Y_MFOT).values
df['XXX3Y_OTH'] = pd.Series(XXX3Y_OTH).values
df['XXX3Y_PL'] = pd.Series(XXX3Y_PL).values
df['XXX3Y_PLBL'] = pd.Series(XXX3Y_PLBL).values
df['XXX3Y_RL'] = pd.Series(XXX3Y_RL).values
df['XXX3Y_SCC'] = pd.Series(XXX3Y_SCC).values
df['XXX3Y_SEL'] = pd.Series(XXX3Y_SEL).values
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/envs/ml_env/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'XXX3Y_flag'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-224-7f65875c06d7> in <module>
#      62         if (grp_slice['accountType'][i]=='unknown'):
#      63             continue
# ---> 64         elif (grp_slice['accountType'][i]=='AL') and (grp_slice['XXX3Y_flag'][i]==1):
#      65             count_AL = count_AL + 1
#      66         elif (grp_slice['accountType'][i]=='BL') and (grp_slice['XXX3Y_flag'][i]==1):
#
# ~/anaconda3/envs/ml_env/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2900             if self.columns.nlevels > 1:
#    2901                 return self._getitem_multilevel(key)
# -> 2902             indexer = self.columns.get_loc(key)
#    2903             if is_integer(indexer):
#    2904                 indexer = [indexer]
#
# ~/anaconda3/envs/ml_env/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
# -> 2897                 raise KeyError(key) from err
#    2898
#    2899         if tolerance is not None:
#
# KeyError: 'XXX3Y_flag'

# %% [raw]
# d = df[['ID','XXX3Y_PL','XXX3Y_flag','accountType']]
# d[d['XXX3Y_flag']!=0].head(60)

# %%
df.shape
# Out:
# (4462, 142)

# %% [markdown]
# <a id='SMA_flags'></a>
# ### Code for SMA flags

# %% [raw]
# df.to_csv('cibil_test2.csv')

# %%
sma_last1_mon = list()
sma_last3_mon_diff = list()
sma_last3_mon = list()
sma_last6_mon_diff = list()
sma_last6_mon = list()
sma_last1_yr_diff = list()
sma_last1_yr = list()
sma_last2_yr_diff = list()
sma_last2_yr = list()
sma_last3_yr_diff = list()
sma_last3_yr = list()
matching = list()


for x in range(0,df.shape[0]):
    if (df['mo_diff_ld_drc'][x]==-1):
        sma_last1_mon.append('unknown')
    elif (df['mo_diff_ld_drc'][x]==1) and (df['payHistComp'][x][0]=='SMA'):
        sma_last1_mon.append(1)
    else:
        sma_last1_mon.append(0)
        
    if (df['mo_diff_ld_drc'][x]==-1):
        sma_last3_mon_diff.append('unknown')
    elif (df['mo_diff_ld_drc'][x]>1) and (df['mo_diff_ld_drc'][x]<4):
        sma_last3_mon_diff.append(1)
    else:
        sma_last3_mon_diff.append(0)
    
    if (df['mo_diff_ld_drc'][x]==-1):
        sma_last6_mon_diff.append('unknown')
    elif (df['mo_diff_ld_drc'][x]>1) and (df['mo_diff_ld_drc'][x]<7):
        sma_last6_mon_diff.append(1)
    else:
        sma_last6_mon_diff.append(0)
    
    if (df['mo_diff_ld_drc'][x]==-1):
        sma_last1_yr_diff.append('unknown')
    elif (df['mo_diff_ld_drc'][x]>1) and (df['mo_diff_ld_drc'][x]<13):
        sma_last1_yr_diff.append(1)
    else:
        sma_last1_yr_diff.append(0)

    if (df['mo_diff_ld_drc'][x]==-1):
        sma_last2_yr_diff.append('unknown')
    elif (df['mo_diff_ld_drc'][x]>1) and (df['mo_diff_ld_drc'][x]<25):
        sma_last2_yr_diff.append(1)
    else:
        sma_last2_yr_diff.append(0)

    if (df['mo_diff_ld_drc'][x]==-1):
        sma_last3_yr_diff.append('unknown')
    elif (df['mo_diff_ld_drc'][x]>1) and (df['mo_diff_ld_drc'][x]<37):
        sma_last3_yr_diff.append(1)
    else:
        sma_last3_yr_diff.append(0)
              
df['sma_last3_mon_diff'] = pd.Series(sma_last3_mon_diff).values
df['sma_last6_mon_diff'] = pd.Series(sma_last6_mon_diff).values
df['sma_last1_yr_diff'] = pd.Series(sma_last1_yr_diff).values
df['sma_last2_yr_diff'] = pd.Series(sma_last2_yr_diff).values
df['sma_last3_yr_diff'] = pd.Series(sma_last3_yr_diff).values

for x in range(0, df.shape[0]):
    if (df['sma_last3_mon_diff'][x]=='unknown'):
        sma_last3_mon.append('unknown')
    elif (df['sma_last3_mon_diff'][x]==1):
        for i in range(0, 3-df['mo_diff_ld_drc'][x]):
            #print(i)
            matching.append(df['payHistComp'][x][i])
        if any('SMA' in s for s in matching):
            sma_last3_mon.append(1)
        else:
            sma_last3_mon.append(0)
        #print(matching)    
        matching = list()
    else:
        sma_last3_mon.append(0)

    if (df['sma_last6_mon_diff'][x]=='unknown'):
        sma_last6_mon.append('unknown')
    elif (df['sma_last6_mon_diff'][x]==1):
        for i in range(0, 6-df['mo_diff_ld_drc'][x]):
            #print(i)
            matching.append(df['payHistComp'][x][i])
        if any('SMA' in s for s in matching):
            sma_last6_mon.append(1)
        else:
            sma_last6_mon.append(0)
        #print(matching)    
        matching = list()
    else:
        sma_last6_mon.append(0)

    if (df['sma_last1_yr_diff'][x]=='unknown'):
        sma_last1_yr.append('unknown')
    elif (df['sma_last1_yr_diff'][x]==1) and (len(df['payHistComp'][x])>=12):
        for i in range(0, 12-df['mo_diff_ld_drc'][x]):
            #print(i)
            matching.append(df['payHistComp'][x][i])
        if any('SMA' in s for s in matching):
            sma_last1_yr.append(1)
        else:
            sma_last1_yr.append(0)
        #print(matching)    
        matching = list()
    else:
        sma_last1_yr.append(0)
    
    if (df['sma_last2_yr_diff'][x]=='unknown'):
        sma_last2_yr.append('unknown')
    elif (df['sma_last2_yr_diff'][x]==1) and (len(df['payHistComp'][x])>=24):
        for i in range(0, 24-df['mo_diff_ld_drc'][x]):
            #print(i)
            matching.append(df['payHistComp'][x][i])
        if any('SMA' in s for s in matching):
            sma_last2_yr.append(1)
        else:
            sma_last2_yr.append(0)
        #print(matching)    
        matching = list()
    else:
        sma_last2_yr.append(0)
    
    if (df['sma_last3_yr_diff'][x]=='unknown'):
        sma_last3_yr.append('unknown')
    elif (df['sma_last3_yr_diff'][x]==1) and (len(df['payHistComp'][x])==36):
        for i in range(0, 36-df['mo_diff_ld_drc'][x]):
            #print(i)
            matching.append(df['payHistComp'][x][i])
        if any('SMA' in s for s in matching):
            sma_last3_yr.append(1)
        else:
            sma_last3_yr.append(0)
        #print(matching)    
        matching = list()
    else:
        sma_last3_yr.append(0)

df['SMA1M_flag'] = pd.Series(sma_last1_mon).values
#print(df['SMA1M_flag'].value_counts()) 

df['SMA3M_flag'] = pd.Series(sma_last3_mon).values
#print(df['SMA3M_flag'].value_counts())
   
df['SMA6M_flag'] = pd.Series(sma_last6_mon).values
#print(df['SMA6M_flag'].value_counts())
   
df['SMA1Y_flag'] = pd.Series(sma_last1_yr).values
#print(df['SMA1Y_flag'].value_counts())
   
df['SMA2Y_flag'] = pd.Series(sma_last2_yr).values
#print(df['SMA2Y_flag'].value_counts())

df['SMA3Y_flag'] = pd.Series(sma_last3_yr).values
#print(df['SMA3Y_flag'].value_counts())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/envs/ml_env/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'mo_diff_ld_drc'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-226-d8d033f26a68> in <module>
#      14
#      15 for x in range(0,df.shape[0]):
# ---> 16     if (df['mo_diff_ld_drc'][x]==-1):
#      17         sma_last1_mon.append('unknown')
#      18     elif (df['mo_diff_ld_drc'][x]==1) and (df['payHistComp'][x][0]=='SMA'):
#
# ~/anaconda3/envs/ml_env/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2900             if self.columns.nlevels > 1:
#    2901                 return self._getitem_multilevel(key)
# -> 2902             indexer = self.columns.get_loc(key)
#    2903             if is_integer(indexer):
#    2904                 indexer = [indexer]
#
# ~/anaconda3/envs/ml_env/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
# -> 2897                 raise KeyError(key) from err
#    2898
#    2899         if tolerance is not None:
#
# KeyError: 'mo_diff_ld_drc'

# %% [raw]
# sma_last1_mon = list()
# sma_last3_mon_diff = list()
# sma_last3_mon = list()
# sma_last6_mon_diff = list()
# sma_last6_mon = list()
# sma_last1_yr_diff = list()
# sma_last1_yr = list()
# sma_last2_yr_diff = list()
# sma_last2_yr = list()
# sma_last3_yr_diff = list()
# sma_last3_yr = list()
# matching = list()
#
#
# for x in range(0,df.shape[0]):
#     if (df['mo_diff_ld_drc'][x]==-1):
#         sma_last1_mon.append('unknown')
#     elif (df['mo_diff_ld_drc'][x]==1) and (df['payHistComp'][x][0]=='031'):
#         sma_last1_mon.append(1)
#     else:
#         sma_last1_mon.append(0)
#
#     if (df['mo_diff_ld_drc'][x]==-1):
#         sma_last3_mon_diff.append('unknown')
#     elif (df['mo_diff_ld_drc'][x]>1) and (df['mo_diff_ld_drc'][x]<4):
#         sma_last3_mon_diff.append(1)
#     else:
#         sma_last3_mon_diff.append(0)
#
#     if (df['mo_diff_ld_drc'][x]==-1):
#         sma_last6_mon_diff.append('unknown')
#     elif (df['mo_diff_ld_drc'][x]>1) and (df['mo_diff_ld_drc'][x]<7):
#         sma_last6_mon_diff.append(1)
#     else:
#         sma_last6_mon_diff.append(0)
#
#     if (df['mo_diff_ld_drc'][x]==-1):
#         sma_last1_yr_diff.append('unknown')
#     elif (df['mo_diff_ld_drc'][x]>1) and (df['mo_diff_ld_drc'][x]<13):
#         sma_last1_yr_diff.append(1)
#     else:
#         sma_last1_yr_diff.append(0)
#
#     if (df['mo_diff_ld_drc'][x]==-1):
#         sma_last2_yr_diff.append('unknown')
#     elif (df['mo_diff_ld_drc'][x]>1) and (df['mo_diff_ld_drc'][x]<25):
#         sma_last2_yr_diff.append(1)
#     else:
#         sma_last2_yr_diff.append(0)
#
#     if (df['mo_diff_ld_drc'][x]==-1):
#         sma_last3_yr_diff.append('unknown')
#     elif (df['mo_diff_ld_drc'][x]>1) and (df['mo_diff_ld_drc'][x]<37):
#         sma_last3_yr_diff.append(1)
#     else:
#         sma_last3_yr_diff.append(0)
#
# df['sma_last1_mon'] = pd.Series(sma_last1_mon).values
# #print(df['sma_last1_mon'].value_counts())
# df['sma_last3_mon_diff'] = pd.Series(sma_last3_mon_diff).values
# df['sma_last6_mon_diff'] = pd.Series(sma_last6_mon_diff).values
# df['sma_last1_yr_diff'] = pd.Series(sma_last1_yr_diff).values
# df['sma_last2_yr_diff'] = pd.Series(sma_last2_yr_diff).values
# df['sma_last3_yr_diff'] = pd.Series(sma_last3_yr_diff).values
#
# for x in range(0, df.shape[0]):
#     if (df['sma_last3_mon_diff'][x]=='unknown'):
#         sma_last3_mon.append('unknown')
#     elif (df['sma_last3_mon_diff'][x]==1):
#         for i in range(0, 3-df['mo_diff_ld_drc'][x]):
#             #print(i)
#             matching.append(df['payHistComp'][x][i])
#         if any("031" in s for s in matching):
#             sma_last3_mon.append(1)
#         else:
#             sma_last3_mon.append(0)
#         #print(matching)
#         matching = list()
#     else:
#         sma_last3_mon.append(0)
#
#     if (df['sma_last6_mon_diff'][x]=='unknown'):
#         sma_last6_mon.append('unknown')
#     elif (df['sma_last6_mon_diff'][x]==1):
#         for i in range(0, 6-df['mo_diff_ld_drc'][x]):
#             #print(i)
#             matching.append(df['payHistComp'][x][i])
#         if any("031" in s for s in matching):
#             sma_last6_mon.append(1)
#         else:
#             sma_last6_mon.append(0)
#         #print(matching)
#         matching = list()
#     else:
#         sma_last6_mon.append(0)
#
#     if (df['sma_last1_yr_diff'][x]=='unknown'):
#         sma_last1_yr.append('unknown')
#     elif (df['sma_last1_yr_diff'][x]==1) and (len(df['payHistComp'][x])>=12):
#         for i in range(0, 12-df['mo_diff_ld_drc'][x]):
#             #print(i)
#             matching.append(df['payHistComp'][x][i])
#         if any("031" in s for s in matching):
#             sma_last1_yr.append(1)
#         else:
#             sma_last1_yr.append(0)
#         #print(matching)
#         matching = list()
#     else:
#         sma_last1_yr.append(0)
#
#     if (df['sma_last2_yr_diff'][x]=='unknown'):
#         sma_last2_yr.append('unknown')
#     elif (df['sma_last2_yr_diff'][x]==1) and (len(df['payHistComp'][x])>=24):
#         for i in range(0, 24-df['mo_diff_ld_drc'][x]):
#             #print(i)
#             matching.append(df['payHistComp'][x][i])
#         if any("031" in s for s in matching):
#             sma_last2_yr.append(1)
#         else:
#             sma_last2_yr.append(0)
#         #print(matching)
#         matching = list()
#     else:
#         sma_last2_yr.append(0)
#
#     if (df['sma_last3_yr_diff'][x]=='unknown'):
#         sma_last3_yr.append('unknown')
#     elif (df['sma_last3_yr_diff'][x]==1) and (len(df['payHistComp'][x])==36):
#         for i in range(0, 36-df['mo_diff_ld_drc'][x]):
#             #print(i)
#             matching.append(df['payHistComp'][x][i])
#         if any("031" in s for s in matching):
#             sma_last3_yr.append(1)
#         else:
#             sma_last3_yr.append(0)
#         #print(matching)
#         matching = list()
#     else:
#         sma_last3_yr.append(0)
#
# df['SMA1M_flag'] = pd.Series(sma_last1_mon).values
# #print(df['SMA1M_flag'].value_counts())
#
# df['SMA3M_flag'] = pd.Series(sma_last3_mon).values
# #print(df['SMA3M_flag'].value_counts())
#
# df['SMA6M_flag'] = pd.Series(sma_last6_mon).values
# #print(df['SMA6M_flag'].value_counts())
#
# df['SMA1Y_flag'] = pd.Series(sma_last1_yr).values
# #print(df['SMA1Y_flag'].value_counts())
#
# df['SMA2Y_flag'] = pd.Series(sma_last2_yr).values
# #print(df['SMA2Y_flag'].value_counts())
#
# df['SMA3Y_flag'] = pd.Series(sma_last3_yr).values
# #print(df['SMA3Y_flag'].value_counts())

# %% [raw]
# a = df[df['sma_last3_yr']==1][['ID','payHistComp','sma_last3_yr']]
# print(a['payHistComp'][1329])

# %% [markdown]
# <a id='SMA_num'></a>
# ### Code for SMA (numerical)
# - SMA in last 1 month
# - SMA in last 3 month
# - SMA in last 6 month
# - SMA in last 1 year
# - SMA in last 2 year
# - SMA in last 3 year

# %%
SMA1M = list()
count_list_1m = list()
count_1m = 0

SMA3M = list()
count_list_3m = list()
count_3m = 0

SMA6M = list()
count_list_6m = list()
count_6m = 0

SMA1Y = list()
count_list_1y = list()
count_1y = 0

SMA2Y = list()
count_list_2y = list()
count_2y = 0

SMA3Y = list()
count_list_3y = list()
count_3y = 0

grp_df = df.groupby('ID')

for x in range(0, len(unq_id_list)):
    grp_slice = grp_df.get_group(unq_id_list[x])
    #print(grp_slice)
    grp_slice.reset_index(drop=True, inplace=True)
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['SMA1M_flag'][i]==1) or (grp_slice['SMA1M_flag'][i]==0):
            count_1m = count_1m + grp_slice['SMA1M_flag'][i]
        
        if (grp_slice['SMA3M_flag'][i]==1) or (grp_slice['SMA3M_flag'][i]==0):
            count_3m = count_3m + grp_slice['SMA3M_flag'][i]

        if (grp_slice['SMA6M_flag'][i]==1) or (grp_slice['SMA6M_flag'][i]==0):
            count_6m = count_6m + grp_slice['SMA6M_flag'][i]

        if (grp_slice['SMA1Y_flag'][i]==1) or (grp_slice['SMA1Y_flag'][i]==0):
            count_1y = count_1y + grp_slice['SMA1Y_flag'][i]

        if (grp_slice['SMA2Y_flag'][i]==1) or (grp_slice['SMA2Y_flag'][i]==0):
            count_2y = count_2y + grp_slice['SMA2Y_flag'][i]

        if (grp_slice['SMA3Y_flag'][i]==1) or (grp_slice['SMA3Y_flag'][i]==0):
            count_3y = count_3y + grp_slice['SMA3Y_flag'][i]


    count_list_1m.append(count_1m)
    count_1m = 0
    count_list_3m.append(count_3m)
    count_3m = 0
    count_list_6m.append(count_6m)
    count_6m = 0
    count_list_1y.append(count_1y)
    count_1y = 0
    count_list_2y.append(count_2y)
    count_2y = 0
    count_list_3y.append(count_3y)
    count_3y = 0

    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['SMA1M_flag'][i]==1) or (grp_slice['SMA1M_flag'][i]==0):
            SMA1M.append(count_list_1m[x])
        else:
            SMA1M.append('unknown')

        if (grp_slice['SMA3M_flag'][i]==1) or (grp_slice['SMA3M_flag'][i]==0):
            SMA3M.append(count_list_3m[x])
        else:
            SMA3M.append('unknown')
        
        if (grp_slice['SMA6M_flag'][i]==1) or (grp_slice['SMA6M_flag'][i]==0):
            SMA6M.append(count_list_6m[x])
        else:
            SMA6M.append('unknown')

        if (grp_slice['SMA1Y_flag'][i]==1) or (grp_slice['SMA1Y_flag'][i]==0):
            SMA1Y.append(count_list_1y[x])
        else:
            SMA1Y.append('unknown')

        if (grp_slice['SMA2Y_flag'][i]==1) or (grp_slice['SMA2Y_flag'][i]==0):
            SMA2Y.append(count_list_2y[x])
        else:
            SMA2Y.append('unknown')
        
        if (grp_slice['SMA3Y_flag'][i]==1) or (grp_slice['SMA3Y_flag'][i]==0):
            SMA3Y.append(count_list_3y[x])
        else:
            SMA3Y.append('unknown')
            
df['SMA1M'] = pd.Series(SMA1M).values
df['SMA3M'] = pd.Series(SMA3M).values
df['SMA6M'] = pd.Series(SMA6M).values
df['SMA1Y'] = pd.Series(SMA1Y).values
df['SMA2Y'] = pd.Series(SMA2Y).values
df['SMA3Y'] = pd.Series(SMA3Y).values
#print(df['SMA3Y'].value_counts())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/envs/ml_env/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'SMA1M_flag'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-227-559f856d0c92> in <module>
#      30     grp_slice.reset_index(drop=True, inplace=True)
#      31     for i in range(0, grp_slice.shape[0]):
# ---> 32         if (grp_slice['SMA1M_flag'][i]==1) or (grp_slice['SMA1M_flag'][i]==0):
#      33             count_1m = count_1m + grp_slice['SMA1M_flag'][i]
#      34
#
# ~/anaconda3/envs/ml_env/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2900             if self.columns.nlevels > 1:
#    2901                 return self._getitem_multilevel(key)
# -> 2902             indexer = self.columns.get_loc(key)
#    2903             if is_integer(indexer):
#    2904                 indexer = [indexer]
#
# ~/anaconda3/envs/ml_env/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
# -> 2897                 raise KeyError(key) from err
#    2898
#    2899         if tolerance is not None:
#
# KeyError: 'SMA1M_flag'

# %% [markdown]
# ### Code for SMA1M_P
# - SMA in last 1 month productwise

# %%
SMA1M_AL = list()
SMA1M_BL = list()
SMA1M_CC = list()
SMA1M_CD = list()
SMA1M_CV = list()
SMA1M_GL = list()
SMA1M_HL = list()
SMA1M_LAS = list()
SMA1M_MFBL = list()
SMA1M_MFHL = list()
SMA1M_MFOT = list()
SMA1M_OTH = list()
SMA1M_PL = list()
SMA1M_PLBL = list()
SMA1M_RL = list()
SMA1M_SCC = list()
SMA1M_SEL = list()

count_list_AL = list()
count_list_BL = list()
count_list_CC = list()
count_list_CD = list()
count_list_CV = list()
count_list_GL = list()
count_list_HL = list()
count_list_LAS = list()
count_list_MFBL = list()
count_list_MFHL = list()
count_list_MFOT = list()
count_list_OTH = list()
count_list_PL = list()
count_list_PLBL = list()
count_list_RL = list()
count_list_SCC = list()
count_list_SEL = list()

count_AL = 0
count_BL = 0
count_CC = 0
count_CD = 0
count_CV = 0
count_GL = 0
count_HL = 0
count_LAS = 0
count_MFBL = 0
count_MFHL = 0
count_MFOT = 0
count_OTH = 0
count_PL = 0 
count_PLBL = 0
count_RL = 0
count_SCC = 0
count_SEL = 0

grp_df = df.groupby('ID')

for x in range(0, len(unq_id_list)):
    grp_slice = grp_df.get_group(unq_id_list[x])
    #print(grp_slice)
    grp_slice.reset_index(drop=True, inplace=True)
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['accountType'][i]=='unknown'):
            continue
        elif (grp_slice['accountType'][i]=='AL') and (grp_slice['SMA1M_flag'][i]==1):
            count_AL = count_AL + 1
        elif (grp_slice['accountType'][i]=='BL') and (grp_slice['SMA1M_flag'][i]==1):
            count_BL = count_BL + 1
        elif (grp_slice['accountType'][i]=='CC') and (grp_slice['SMA1M_flag'][i]==1):
            count_CC = count_CC + 1
        elif (grp_slice['accountType'][i]=='CD') and (grp_slice['SMA1M_flag'][i]==1):
            count_CD = count_CD + 1
        elif (grp_slice['accountType'][i]=='CV') and (grp_slice['SMA1M_flag'][i]==1):
            count_CV = count_CV + 1
        elif (grp_slice['accountType'][i]=='GL') and (grp_slice['SMA1M_flag'][i]==1):
            count_GL = count_GL + 1
        elif (grp_slice['accountType'][i]=='HL') and (grp_slice['SMA1M_flag'][i]==1):
            count_HL = count_HL + 1
        elif (grp_slice['accountType'][i]=='LAS') and (grp_slice['SMA1M_flag'][i]==1):
            count_LAS = count_LAS + 1
        elif (grp_slice['accountType'][i]=='MFBL') and (grp_slice['SMA1M_flag'][i]==1):
            count_MFBL = count_MFBL + 1
        elif (grp_slice['accountType'][i]=='MFHL') and (grp_slice['SMA1M_flag'][i]==1):
            count_MFHL = count_MFHL + 1
        elif (grp_slice['accountType'][i]=='MFOT') and (grp_slice['SMA1M_flag'][i]==1):
            count_MFOT = count_MFOT + 1
        elif (grp_slice['accountType'][i]=='OTH') and (grp_slice['SMA1M_flag'][i]==1):
            count_OTH = count_OTH + 1
        elif (grp_slice['accountType'][i]=='PL') and (grp_slice['SMA1M_flag'][i]==1):
            count_PL = count_PL + 1
        elif (grp_slice['accountType'][i]=='PLBL') and (grp_slice['SMA1M_flag'][i]==1):
            count_PLBL = count_PLBL + 1
        elif (grp_slice['accountType'][i]=='RL') and (grp_slice['SMA1M_flag'][i]==1):
            count_RL = count_RL + 1
        elif (grp_slice['accountType'][i]=='SCC') and (grp_slice['SMA1M_flag'][i]==1):
            count_SCC = count_SCC + 1
        elif (grp_slice['accountType'][i]=='SEL') and (grp_slice['SMA1M_flag'][i]==1):
            count_SEL = count_SEL + 1
            
    count_list_AL.append(count_AL)
    count_list_BL.append(count_BL)
    count_list_CC.append(count_CC)
    count_list_CD.append(count_CD)
    count_list_CV.append(count_CV)
    count_list_GL.append(count_GL)
    count_list_HL.append(count_HL)
    count_list_LAS.append(count_LAS)
    count_list_MFBL.append(count_MFBL)
    count_list_MFHL.append(count_MFHL)
    count_list_MFOT.append(count_MFOT)
    count_list_OTH.append(count_OTH)
    count_list_PL.append(count_PL)
    count_list_PLBL.append(count_PLBL)
    count_list_RL.append(count_RL)
    count_list_SCC.append(count_SCC)
    count_list_SEL.append(count_SEL)
    
    count_AL = 0
    count_BL = 0
    count_CC = 0
    count_CD = 0
    count_CV = 0
    count_GL = 0
    count_HL = 0
    count_LAS = 0
    count_MFBL = 0
    count_MFHL = 0
    count_MFOT = 0
    count_OTH = 0
    count_PL = 0
    count_PLBL = 0
    count_RL = 0
    count_SCC = 0
    count_SEL = 0
    
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['accountType'][i]=='unknown'):
            SMA1M_AL.append('unknown')
            SMA1M_BL.append('unknown')
            SMA1M_CC.append('unknown')
            SMA1M_CD.append('unknown')
            SMA1M_CV.append('unknown')
            SMA1M_GL.append('unknown')
            SMA1M_HL.append('unknown')
            SMA1M_LAS.append('unknown')
            SMA1M_MFBL.append('unknown')
            SMA1M_MFHL.append('unknown')
            SMA1M_MFOT.append('unknown')
            SMA1M_OTH.append('unknown')
            SMA1M_PL.append('unknown')
            SMA1M_PLBL.append('unknown')
            SMA1M_RL.append('unknown')
            SMA1M_SCC.append('unknown')
            SMA1M_SEL.append('unknown')
        else:
            SMA1M_AL.append(count_list_AL[x])
            SMA1M_BL.append(count_list_BL[x])
            SMA1M_CC.append(count_list_CC[x])
            SMA1M_CD.append(count_list_CD[x])
            SMA1M_CV.append(count_list_CV[x])
            SMA1M_GL.append(count_list_GL[x])
            SMA1M_HL.append(count_list_HL[x])
            SMA1M_LAS.append(count_list_LAS[x])
            SMA1M_MFBL.append(count_list_MFBL[x])
            SMA1M_MFHL.append(count_list_MFHL[x])
            SMA1M_MFOT.append(count_list_MFOT[x])
            SMA1M_OTH.append(count_list_OTH[x])
            SMA1M_PL.append(count_list_PL[x])
            SMA1M_PLBL.append(count_list_PLBL[x])
            SMA1M_RL.append(count_list_RL[x])
            SMA1M_SCC.append(count_list_SCC[x])
            SMA1M_SEL.append(count_list_SEL[x])
            
df['SMA1M_AL'] = pd.Series(SMA1M_AL).values
df['SMA1M_BL'] = pd.Series(SMA1M_BL).values
df['SMA1M_CC'] = pd.Series(SMA1M_CC).values
df['SMA1M_CD'] = pd.Series(SMA1M_CD).values
df['SMA1M_CV'] = pd.Series(SMA1M_CV).values
df['SMA1M_GL'] = pd.Series(SMA1M_GL).values
df['SMA1M_HL'] = pd.Series(SMA1M_HL).values
df['SMA1M_LAS'] = pd.Series(SMA1M_LAS).values
df['SMA1M_MFBL'] = pd.Series(SMA1M_MFBL).values
df['SMA1M_MFHL'] = pd.Series(SMA1M_MFHL).values
df['SMA1M_MFOT'] = pd.Series(SMA1M_MFOT).values
df['SMA1M_OTH'] = pd.Series(SMA1M_OTH).values
df['SMA1M_PL'] = pd.Series(SMA1M_PL).values
df['SMA1M_PLBL'] = pd.Series(SMA1M_PLBL).values
df['SMA1M_RL'] = pd.Series(SMA1M_RL).values
df['SMA1M_SCC'] = pd.Series(SMA1M_SCC).values
df['SMA1M_SEL'] = pd.Series(SMA1M_SEL).values

# %% [raw]
# d = df[['ID','SMA1M_GL','SMA1M_flag','accountType']]
# d[d['SMA1M_flag']!='unknown'].head(60)

# %% [markdown]
# ### Code for SMA3M_P
# - SMA in last 3 month productwise

# %%
SMA3M_AL = list()
SMA3M_BL = list()
SMA3M_CC = list()
SMA3M_CD = list()
SMA3M_CV = list()
SMA3M_GL = list()
SMA3M_HL = list()
SMA3M_LAS = list()
SMA3M_MFBL = list()
SMA3M_MFHL = list()
SMA3M_MFOT = list()
SMA3M_OTH = list()
SMA3M_PL = list()
SMA3M_PLBL = list()
SMA3M_RL = list()
SMA3M_SCC = list()
SMA3M_SEL = list()

count_list_AL = list()
count_list_BL = list()
count_list_CC = list()
count_list_CD = list()
count_list_CV = list()
count_list_GL = list()
count_list_HL = list()
count_list_LAS = list()
count_list_MFBL = list()
count_list_MFHL = list()
count_list_MFOT = list()
count_list_OTH = list()
count_list_PL = list()
count_list_PLBL = list()
count_list_RL = list()
count_list_SCC = list()
count_list_SEL = list()

count_AL = 0
count_BL = 0
count_CC = 0
count_CD = 0
count_CV = 0
count_GL = 0
count_HL = 0
count_LAS = 0
count_MFBL = 0
count_MFHL = 0
count_MFOT = 0
count_OTH = 0
count_PL = 0 
count_PLBL = 0
count_RL = 0
count_SCC = 0
count_SEL = 0

grp_df = df.groupby('ID')

for x in range(0, len(unq_id_list)):
    grp_slice = grp_df.get_group(unq_id_list[x])
    #print(grp_slice)
    grp_slice.reset_index(drop=True, inplace=True)
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['accountType'][i]=='unknown'):
            continue
        elif (grp_slice['accountType'][i]=='AL') and (grp_slice['SMA3M_flag'][i]==1):
            count_AL = count_AL + 1
        elif (grp_slice['accountType'][i]=='BL') and (grp_slice['SMA3M_flag'][i]==1):
            count_BL = count_BL + 1
        elif (grp_slice['accountType'][i]=='CC') and (grp_slice['SMA3M_flag'][i]==1):
            count_CC = count_CC + 1
        elif (grp_slice['accountType'][i]=='CD') and (grp_slice['SMA3M_flag'][i]==1):
            count_CD = count_CD + 1
        elif (grp_slice['accountType'][i]=='CV') and (grp_slice['SMA3M_flag'][i]==1):
            count_CV = count_CV + 1
        elif (grp_slice['accountType'][i]=='GL') and (grp_slice['SMA3M_flag'][i]==1):
            count_GL = count_GL + 1
        elif (grp_slice['accountType'][i]=='HL') and (grp_slice['SMA3M_flag'][i]==1):
            count_HL = count_HL + 1
        elif (grp_slice['accountType'][i]=='LAS') and (grp_slice['SMA3M_flag'][i]==1):
            count_LAS = count_LAS + 1
        elif (grp_slice['accountType'][i]=='MFBL') and (grp_slice['SMA3M_flag'][i]==1):
            count_MFBL = count_MFBL + 1
        elif (grp_slice['accountType'][i]=='MFHL') and (grp_slice['SMA3M_flag'][i]==1):
            count_MFHL = count_MFHL + 1
        elif (grp_slice['accountType'][i]=='MFOT') and (grp_slice['SMA3M_flag'][i]==1):
            count_MFOT = count_MFOT + 1
        elif (grp_slice['accountType'][i]=='OTH') and (grp_slice['SMA3M_flag'][i]==1):
            count_OTH = count_OTH + 1
        elif (grp_slice['accountType'][i]=='PL') and (grp_slice['SMA3M_flag'][i]==1):
            count_PL = count_PL + 1
        elif (grp_slice['accountType'][i]=='PLBL') and (grp_slice['SMA3M_flag'][i]==1):
            count_PLBL = count_PLBL + 1
        elif (grp_slice['accountType'][i]=='RL') and (grp_slice['SMA3M_flag'][i]==1):
            count_RL = count_RL + 1
        elif (grp_slice['accountType'][i]=='SCC') and (grp_slice['SMA3M_flag'][i]==1):
            count_SCC = count_SCC + 1
        elif (grp_slice['accountType'][i]=='SEL') and (grp_slice['SMA3M_flag'][i]==1):
            count_SEL = count_SEL + 1
            
    count_list_AL.append(count_AL)
    count_list_BL.append(count_BL)
    count_list_CC.append(count_CC)
    count_list_CD.append(count_CD)
    count_list_CV.append(count_CV)
    count_list_GL.append(count_GL)
    count_list_HL.append(count_HL)
    count_list_LAS.append(count_LAS)
    count_list_MFBL.append(count_MFBL)
    count_list_MFHL.append(count_MFHL)
    count_list_MFOT.append(count_MFOT)
    count_list_OTH.append(count_OTH)
    count_list_PL.append(count_PL)
    count_list_PLBL.append(count_PLBL)
    count_list_RL.append(count_RL)
    count_list_SCC.append(count_SCC)
    count_list_SEL.append(count_SEL)
    
    count_AL = 0
    count_BL = 0
    count_CC = 0
    count_CD = 0
    count_CV = 0
    count_GL = 0
    count_HL = 0
    count_LAS = 0
    count_MFBL = 0
    count_MFHL = 0
    count_MFOT = 0
    count_OTH = 0
    count_PL = 0
    count_PLBL = 0
    count_RL = 0
    count_SCC = 0
    count_SEL = 0
    
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['accountType'][i]=='unknown'):
            SMA3M_AL.append('unknown')
            SMA3M_BL.append('unknown')
            SMA3M_CC.append('unknown')
            SMA3M_CD.append('unknown')
            SMA3M_CV.append('unknown')
            SMA3M_GL.append('unknown')
            SMA3M_HL.append('unknown')
            SMA3M_LAS.append('unknown')
            SMA3M_MFBL.append('unknown')
            SMA3M_MFHL.append('unknown')
            SMA3M_MFOT.append('unknown')
            SMA3M_OTH.append('unknown')
            SMA3M_PL.append('unknown')
            SMA3M_PLBL.append('unknown')
            SMA3M_RL.append('unknown')
            SMA3M_SCC.append('unknown')
            SMA3M_SEL.append('unknown')
        else:
            SMA3M_AL.append(count_list_AL[x])
            SMA3M_BL.append(count_list_BL[x])
            SMA3M_CC.append(count_list_CC[x])
            SMA3M_CD.append(count_list_CD[x])
            SMA3M_CV.append(count_list_CV[x])
            SMA3M_GL.append(count_list_GL[x])
            SMA3M_HL.append(count_list_HL[x])
            SMA3M_LAS.append(count_list_LAS[x])
            SMA3M_MFBL.append(count_list_MFBL[x])
            SMA3M_MFHL.append(count_list_MFHL[x])
            SMA3M_MFOT.append(count_list_MFOT[x])
            SMA3M_OTH.append(count_list_OTH[x])
            SMA3M_PL.append(count_list_PL[x])
            SMA3M_PLBL.append(count_list_PLBL[x])
            SMA3M_RL.append(count_list_RL[x])
            SMA3M_SCC.append(count_list_SCC[x])
            SMA3M_SEL.append(count_list_SEL[x])
            
df['SMA3M_AL'] = pd.Series(SMA3M_AL).values
df['SMA3M_BL'] = pd.Series(SMA3M_BL).values
df['SMA3M_CC'] = pd.Series(SMA3M_CC).values
df['SMA3M_CD'] = pd.Series(SMA3M_CD).values
df['SMA3M_CV'] = pd.Series(SMA3M_CV).values
df['SMA3M_GL'] = pd.Series(SMA3M_GL).values
df['SMA3M_HL'] = pd.Series(SMA3M_HL).values
df['SMA3M_LAS'] = pd.Series(SMA3M_LAS).values
df['SMA3M_MFBL'] = pd.Series(SMA3M_MFBL).values
df['SMA3M_MFHL'] = pd.Series(SMA3M_MFHL).values
df['SMA3M_MFOT'] = pd.Series(SMA3M_MFOT).values
df['SMA3M_OTH'] = pd.Series(SMA3M_OTH).values
df['SMA3M_PL'] = pd.Series(SMA3M_PL).values
df['SMA3M_PLBL'] = pd.Series(SMA3M_PLBL).values
df['SMA3M_RL'] = pd.Series(SMA3M_RL).values
df['SMA3M_SCC'] = pd.Series(SMA3M_SCC).values
df['SMA3M_SEL'] = pd.Series(SMA3M_SEL).values
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/envs/ml_env/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'SMA3M_flag'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-228-6d42cd80e6e8> in <module>
#      62         if (grp_slice['accountType'][i]=='unknown'):
#      63             continue
# ---> 64         elif (grp_slice['accountType'][i]=='AL') and (grp_slice['SMA3M_flag'][i]==1):
#      65             count_AL = count_AL + 1
#      66         elif (grp_slice['accountType'][i]=='BL') and (grp_slice['SMA3M_flag'][i]==1):
#
# ~/anaconda3/envs/ml_env/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2900             if self.columns.nlevels > 1:
#    2901                 return self._getitem_multilevel(key)
# -> 2902             indexer = self.columns.get_loc(key)
#    2903             if is_integer(indexer):
#    2904                 indexer = [indexer]
#
# ~/anaconda3/envs/ml_env/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
# -> 2897                 raise KeyError(key) from err
#    2898
#    2899         if tolerance is not None:
#
# KeyError: 'SMA3M_flag'

# %% [raw]
# d = df[['ID','SMA3M_GL','SMA3M_flag','accountType']]
# d[d['SMA3M_flag']!=0].head(60)

# %% [markdown]
# ### Code for SMA6M_P
# - SMA in last 6 month productwise

# %%
SMA6M_AL = list()
SMA6M_BL = list()
SMA6M_CC = list()
SMA6M_CD = list()
SMA6M_CV = list()
SMA6M_GL = list()
SMA6M_HL = list()
SMA6M_LAS = list()
SMA6M_MFBL = list()
SMA6M_MFHL = list()
SMA6M_MFOT = list()
SMA6M_OTH = list()
SMA6M_PL = list()
SMA6M_PLBL = list()
SMA6M_RL = list()
SMA6M_SCC = list()
SMA6M_SEL = list()

count_list_AL = list()
count_list_BL = list()
count_list_CC = list()
count_list_CD = list()
count_list_CV = list()
count_list_GL = list()
count_list_HL = list()
count_list_LAS = list()
count_list_MFBL = list()
count_list_MFHL = list()
count_list_MFOT = list()
count_list_OTH = list()
count_list_PL = list()
count_list_PLBL = list()
count_list_RL = list()
count_list_SCC = list()
count_list_SEL = list()

count_AL = 0
count_BL = 0
count_CC = 0
count_CD = 0
count_CV = 0
count_GL = 0
count_HL = 0
count_LAS = 0
count_MFBL = 0
count_MFHL = 0
count_MFOT = 0
count_OTH = 0
count_PL = 0 
count_PLBL = 0
count_RL = 0
count_SCC = 0
count_SEL = 0

grp_df = df.groupby('ID')

for x in range(0, len(unq_id_list)):
    grp_slice = grp_df.get_group(unq_id_list[x])
    #print(grp_slice)
    grp_slice.reset_index(drop=True, inplace=True)
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['accountType'][i]=='unknown'):
            continue
        elif (grp_slice['accountType'][i]=='AL') and (grp_slice['SMA6M_flag'][i]==1):
            count_AL = count_AL + 1
        elif (grp_slice['accountType'][i]=='BL') and (grp_slice['SMA6M_flag'][i]==1):
            count_BL = count_BL + 1
        elif (grp_slice['accountType'][i]=='CC') and (grp_slice['SMA6M_flag'][i]==1):
            count_CC = count_CC + 1
        elif (grp_slice['accountType'][i]=='CD') and (grp_slice['SMA6M_flag'][i]==1):
            count_CD = count_CD + 1
        elif (grp_slice['accountType'][i]=='CV') and (grp_slice['SMA6M_flag'][i]==1):
            count_CV = count_CV + 1
        elif (grp_slice['accountType'][i]=='GL') and (grp_slice['SMA6M_flag'][i]==1):
            count_GL = count_GL + 1
        elif (grp_slice['accountType'][i]=='HL') and (grp_slice['SMA6M_flag'][i]==1):
            count_HL = count_HL + 1
        elif (grp_slice['accountType'][i]=='LAS') and (grp_slice['SMA6M_flag'][i]==1):
            count_LAS = count_LAS + 1
        elif (grp_slice['accountType'][i]=='MFBL') and (grp_slice['SMA6M_flag'][i]==1):
            count_MFBL = count_MFBL + 1
        elif (grp_slice['accountType'][i]=='MFHL') and (grp_slice['SMA6M_flag'][i]==1):
            count_MFHL = count_MFHL + 1
        elif (grp_slice['accountType'][i]=='MFOT') and (grp_slice['SMA6M_flag'][i]==1):
            count_MFOT = count_MFOT + 1
        elif (grp_slice['accountType'][i]=='OTH') and (grp_slice['SMA6M_flag'][i]==1):
            count_OTH = count_OTH + 1
        elif (grp_slice['accountType'][i]=='PL') and (grp_slice['SMA6M_flag'][i]==1):
            count_PL = count_PL + 1
        elif (grp_slice['accountType'][i]=='PLBL') and (grp_slice['SMA6M_flag'][i]==1):
            count_PLBL = count_PLBL + 1
        elif (grp_slice['accountType'][i]=='RL') and (grp_slice['SMA6M_flag'][i]==1):
            count_RL = count_RL + 1
        elif (grp_slice['accountType'][i]=='SCC') and (grp_slice['SMA6M_flag'][i]==1):
            count_SCC = count_SCC + 1
        elif (grp_slice['accountType'][i]=='SEL') and (grp_slice['SMA6M_flag'][i]==1):
            count_SEL = count_SEL + 1
            
    count_list_AL.append(count_AL)
    count_list_BL.append(count_BL)
    count_list_CC.append(count_CC)
    count_list_CD.append(count_CD)
    count_list_CV.append(count_CV)
    count_list_GL.append(count_GL)
    count_list_HL.append(count_HL)
    count_list_LAS.append(count_LAS)
    count_list_MFBL.append(count_MFBL)
    count_list_MFHL.append(count_MFHL)
    count_list_MFOT.append(count_MFOT)
    count_list_OTH.append(count_OTH)
    count_list_PL.append(count_PL)
    count_list_PLBL.append(count_PLBL)
    count_list_RL.append(count_RL)
    count_list_SCC.append(count_SCC)
    count_list_SEL.append(count_SEL)
    
    count_AL = 0
    count_BL = 0
    count_CC = 0
    count_CD = 0
    count_CV = 0
    count_GL = 0
    count_HL = 0
    count_LAS = 0
    count_MFBL = 0
    count_MFHL = 0
    count_MFOT = 0
    count_OTH = 0
    count_PL = 0
    count_PLBL = 0
    count_RL = 0
    count_SCC = 0
    count_SEL = 0
    
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['accountType'][i]=='unknown'):
            SMA6M_AL.append('unknown')
            SMA6M_BL.append('unknown')
            SMA6M_CC.append('unknown')
            SMA6M_CD.append('unknown')
            SMA6M_CV.append('unknown')
            SMA6M_GL.append('unknown')
            SMA6M_HL.append('unknown')
            SMA6M_LAS.append('unknown')
            SMA6M_MFBL.append('unknown')
            SMA6M_MFHL.append('unknown')
            SMA6M_MFOT.append('unknown')
            SMA6M_OTH.append('unknown')
            SMA6M_PL.append('unknown')
            SMA6M_PLBL.append('unknown')
            SMA6M_RL.append('unknown')
            SMA6M_SCC.append('unknown')
            SMA6M_SEL.append('unknown')
        else:
            SMA6M_AL.append(count_list_AL[x])
            SMA6M_BL.append(count_list_BL[x])
            SMA6M_CC.append(count_list_CC[x])
            SMA6M_CD.append(count_list_CD[x])
            SMA6M_CV.append(count_list_CV[x])
            SMA6M_GL.append(count_list_GL[x])
            SMA6M_HL.append(count_list_HL[x])
            SMA6M_LAS.append(count_list_LAS[x])
            SMA6M_MFBL.append(count_list_MFBL[x])
            SMA6M_MFHL.append(count_list_MFHL[x])
            SMA6M_MFOT.append(count_list_MFOT[x])
            SMA6M_OTH.append(count_list_OTH[x])
            SMA6M_PL.append(count_list_PL[x])
            SMA6M_PLBL.append(count_list_PLBL[x])
            SMA6M_RL.append(count_list_RL[x])
            SMA6M_SCC.append(count_list_SCC[x])
            SMA6M_SEL.append(count_list_SEL[x])
            
df['SMA6M_AL'] = pd.Series(SMA6M_AL).values
df['SMA6M_BL'] = pd.Series(SMA6M_BL).values
df['SMA6M_CC'] = pd.Series(SMA6M_CC).values
df['SMA6M_CD'] = pd.Series(SMA6M_CD).values
df['SMA6M_CV'] = pd.Series(SMA6M_CV).values
df['SMA6M_GL'] = pd.Series(SMA6M_GL).values
df['SMA6M_HL'] = pd.Series(SMA6M_HL).values
df['SMA6M_LAS'] = pd.Series(SMA6M_LAS).values
df['SMA6M_MFBL'] = pd.Series(SMA6M_MFBL).values
df['SMA6M_MFHL'] = pd.Series(SMA6M_MFHL).values
df['SMA6M_MFOT'] = pd.Series(SMA6M_MFOT).values
df['SMA6M_OTH'] = pd.Series(SMA6M_OTH).values
df['SMA6M_PL'] = pd.Series(SMA6M_PL).values
df['SMA6M_PLBL'] = pd.Series(SMA6M_PLBL).values
df['SMA6M_RL'] = pd.Series(SMA6M_RL).values
df['SMA6M_SCC'] = pd.Series(SMA6M_SCC).values
df['SMA6M_SEL'] = pd.Series(SMA6M_SEL).values
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/envs/ml_env/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'SMA6M_flag'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-229-92edbaa07e25> in <module>
#      62         if (grp_slice['accountType'][i]=='unknown'):
#      63             continue
# ---> 64         elif (grp_slice['accountType'][i]=='AL') and (grp_slice['SMA6M_flag'][i]==1):
#      65             count_AL = count_AL + 1
#      66         elif (grp_slice['accountType'][i]=='BL') and (grp_slice['SMA6M_flag'][i]==1):
#
# ~/anaconda3/envs/ml_env/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2900             if self.columns.nlevels > 1:
#    2901                 return self._getitem_multilevel(key)
# -> 2902             indexer = self.columns.get_loc(key)
#    2903             if is_integer(indexer):
#    2904                 indexer = [indexer]
#
# ~/anaconda3/envs/ml_env/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
# -> 2897                 raise KeyError(key) from err
#    2898
#    2899         if tolerance is not None:
#
# KeyError: 'SMA6M_flag'

# %% [raw]
# d = df[['ID','SMA6M_GL','SMA6M_flag','accountType']]
# d[d['SMA6M_flag']!=0].head(60)

# %% [markdown]
# ### Code for SMA1Y_P
# - SMA in last 1 year productwise

# %%
SMA1Y_AL = list()
SMA1Y_BL = list()
SMA1Y_CC = list()
SMA1Y_CD = list()
SMA1Y_CV = list()
SMA1Y_GL = list()
SMA1Y_HL = list()
SMA1Y_LAS = list()
SMA1Y_MFBL = list()
SMA1Y_MFHL = list()
SMA1Y_MFOT = list()
SMA1Y_OTH = list()
SMA1Y_PL = list()
SMA1Y_PLBL = list()
SMA1Y_RL = list()
SMA1Y_SCC = list()
SMA1Y_SEL = list()

count_list_AL = list()
count_list_BL = list()
count_list_CC = list()
count_list_CD = list()
count_list_CV = list()
count_list_GL = list()
count_list_HL = list()
count_list_LAS = list()
count_list_MFBL = list()
count_list_MFHL = list()
count_list_MFOT = list()
count_list_OTH = list()
count_list_PL = list()
count_list_PLBL = list()
count_list_RL = list()
count_list_SCC = list()
count_list_SEL = list()

count_AL = 0
count_BL = 0
count_CC = 0
count_CD = 0
count_CV = 0
count_GL = 0
count_HL = 0
count_LAS = 0
count_MFBL = 0
count_MFHL = 0
count_MFOT = 0
count_OTH = 0
count_PL = 0 
count_PLBL = 0
count_RL = 0
count_SCC = 0
count_SEL = 0

grp_df = df.groupby('ID')

for x in range(0, len(unq_id_list)):
    grp_slice = grp_df.get_group(unq_id_list[x])
    #print(grp_slice)
    grp_slice.reset_index(drop=True, inplace=True)
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['accountType'][i]=='unknown'):
            continue
        elif (grp_slice['accountType'][i]=='AL') and (grp_slice['SMA1Y_flag'][i]==1):
            count_AL = count_AL + 1
        elif (grp_slice['accountType'][i]=='BL') and (grp_slice['SMA1Y_flag'][i]==1):
            count_BL = count_BL + 1
        elif (grp_slice['accountType'][i]=='CC') and (grp_slice['SMA1Y_flag'][i]==1):
            count_CC = count_CC + 1
        elif (grp_slice['accountType'][i]=='CD') and (grp_slice['SMA1Y_flag'][i]==1):
            count_CD = count_CD + 1
        elif (grp_slice['accountType'][i]=='CV') and (grp_slice['SMA1Y_flag'][i]==1):
            count_CV = count_CV + 1
        elif (grp_slice['accountType'][i]=='GL') and (grp_slice['SMA1Y_flag'][i]==1):
            count_GL = count_GL + 1
        elif (grp_slice['accountType'][i]=='HL') and (grp_slice['SMA1Y_flag'][i]==1):
            count_HL = count_HL + 1
        elif (grp_slice['accountType'][i]=='LAS') and (grp_slice['SMA1Y_flag'][i]==1):
            count_LAS = count_LAS + 1
        elif (grp_slice['accountType'][i]=='MFBL') and (grp_slice['SMA1Y_flag'][i]==1):
            count_MFBL = count_MFBL + 1
        elif (grp_slice['accountType'][i]=='MFHL') and (grp_slice['SMA1Y_flag'][i]==1):
            count_MFHL = count_MFHL + 1
        elif (grp_slice['accountType'][i]=='MFOT') and (grp_slice['SMA1Y_flag'][i]==1):
            count_MFOT = count_MFOT + 1
        elif (grp_slice['accountType'][i]=='OTH') and (grp_slice['SMA1Y_flag'][i]==1):
            count_OTH = count_OTH + 1
        elif (grp_slice['accountType'][i]=='PL') and (grp_slice['SMA1Y_flag'][i]==1):
            count_PL = count_PL + 1
        elif (grp_slice['accountType'][i]=='PLBL') and (grp_slice['SMA1Y_flag'][i]==1):
            count_PLBL = count_PLBL + 1
        elif (grp_slice['accountType'][i]=='RL') and (grp_slice['SMA1Y_flag'][i]==1):
            count_RL = count_RL + 1
        elif (grp_slice['accountType'][i]=='SCC') and (grp_slice['SMA1Y_flag'][i]==1):
            count_SCC = count_SCC + 1
        elif (grp_slice['accountType'][i]=='SEL') and (grp_slice['SMA1Y_flag'][i]==1):
            count_SEL = count_SEL + 1
            
    count_list_AL.append(count_AL)
    count_list_BL.append(count_BL)
    count_list_CC.append(count_CC)
    count_list_CD.append(count_CD)
    count_list_CV.append(count_CV)
    count_list_GL.append(count_GL)
    count_list_HL.append(count_HL)
    count_list_LAS.append(count_LAS)
    count_list_MFBL.append(count_MFBL)
    count_list_MFHL.append(count_MFHL)
    count_list_MFOT.append(count_MFOT)
    count_list_OTH.append(count_OTH)
    count_list_PL.append(count_PL)
    count_list_PLBL.append(count_PLBL)
    count_list_RL.append(count_RL)
    count_list_SCC.append(count_SCC)
    count_list_SEL.append(count_SEL)
    
    count_AL = 0
    count_BL = 0
    count_CC = 0
    count_CD = 0
    count_CV = 0
    count_GL = 0
    count_HL = 0
    count_LAS = 0
    count_MFBL = 0
    count_MFHL = 0
    count_MFOT = 0
    count_OTH = 0
    count_PL = 0
    count_PLBL = 0
    count_RL = 0
    count_SCC = 0
    count_SEL = 0
    
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['accountType'][i]=='unknown'):
            SMA1Y_AL.append('unknown')
            SMA1Y_BL.append('unknown')
            SMA1Y_CC.append('unknown')
            SMA1Y_CD.append('unknown')
            SMA1Y_CV.append('unknown')
            SMA1Y_GL.append('unknown')
            SMA1Y_HL.append('unknown')
            SMA1Y_LAS.append('unknown')
            SMA1Y_MFBL.append('unknown')
            SMA1Y_MFHL.append('unknown')
            SMA1Y_MFOT.append('unknown')
            SMA1Y_OTH.append('unknown')
            SMA1Y_PL.append('unknown')
            SMA1Y_PLBL.append('unknown')
            SMA1Y_RL.append('unknown')
            SMA1Y_SCC.append('unknown')
            SMA1Y_SEL.append('unknown')
        else:
            SMA1Y_AL.append(count_list_AL[x])
            SMA1Y_BL.append(count_list_BL[x])
            SMA1Y_CC.append(count_list_CC[x])
            SMA1Y_CD.append(count_list_CD[x])
            SMA1Y_CV.append(count_list_CV[x])
            SMA1Y_GL.append(count_list_GL[x])
            SMA1Y_HL.append(count_list_HL[x])
            SMA1Y_LAS.append(count_list_LAS[x])
            SMA1Y_MFBL.append(count_list_MFBL[x])
            SMA1Y_MFHL.append(count_list_MFHL[x])
            SMA1Y_MFOT.append(count_list_MFOT[x])
            SMA1Y_OTH.append(count_list_OTH[x])
            SMA1Y_PL.append(count_list_PL[x])
            SMA1Y_PLBL.append(count_list_PLBL[x])
            SMA1Y_RL.append(count_list_RL[x])
            SMA1Y_SCC.append(count_list_SCC[x])
            SMA1Y_SEL.append(count_list_SEL[x])
            
df['SMA1Y_AL'] = pd.Series(SMA1Y_AL).values
df['SMA1Y_BL'] = pd.Series(SMA1Y_BL).values
df['SMA1Y_CC'] = pd.Series(SMA1Y_CC).values
df['SMA1Y_CD'] = pd.Series(SMA1Y_CD).values
df['SMA1Y_CV'] = pd.Series(SMA1Y_CV).values
df['SMA1Y_GL'] = pd.Series(SMA1Y_GL).values
df['SMA1Y_HL'] = pd.Series(SMA1Y_HL).values
df['SMA1Y_LAS'] = pd.Series(SMA1Y_LAS).values
df['SMA1Y_MFBL'] = pd.Series(SMA1Y_MFBL).values
df['SMA1Y_MFHL'] = pd.Series(SMA1Y_MFHL).values
df['SMA1Y_MFOT'] = pd.Series(SMA1Y_MFOT).values
df['SMA1Y_OTH'] = pd.Series(SMA1Y_OTH).values
df['SMA1Y_PL'] = pd.Series(SMA1Y_PL).values
df['SMA1Y_PLBL'] = pd.Series(SMA1Y_PLBL).values
df['SMA1Y_RL'] = pd.Series(SMA1Y_RL).values
df['SMA1Y_SCC'] = pd.Series(SMA1Y_SCC).values
df['SMA1Y_SEL'] = pd.Series(SMA1Y_SEL).values
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/envs/ml_env/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'SMA1Y_flag'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-230-41cdbc97c92a> in <module>
#      62         if (grp_slice['accountType'][i]=='unknown'):
#      63             continue
# ---> 64         elif (grp_slice['accountType'][i]=='AL') and (grp_slice['SMA1Y_flag'][i]==1):
#      65             count_AL = count_AL + 1
#      66         elif (grp_slice['accountType'][i]=='BL') and (grp_slice['SMA1Y_flag'][i]==1):
#
# ~/anaconda3/envs/ml_env/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2900             if self.columns.nlevels > 1:
#    2901                 return self._getitem_multilevel(key)
# -> 2902             indexer = self.columns.get_loc(key)
#    2903             if is_integer(indexer):
#    2904                 indexer = [indexer]
#
# ~/anaconda3/envs/ml_env/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
# -> 2897                 raise KeyError(key) from err
#    2898
#    2899         if tolerance is not None:
#
# KeyError: 'SMA1Y_flag'

# %% [raw]
# d = df[['ID','SMA1Y_GL','SMA1Y_flag','accountType']]
# d[d['SMA1Y_flag']!=0].head(60)

# %% [markdown]
# ### Code for SMA2Y_P
# - SMA in last 2 year productwise

# %%
SMA2Y_AL = list()
SMA2Y_BL = list()
SMA2Y_CC = list()
SMA2Y_CD = list()
SMA2Y_CV = list()
SMA2Y_GL = list()
SMA2Y_HL = list()
SMA2Y_LAS = list()
SMA2Y_MFBL = list()
SMA2Y_MFHL = list()
SMA2Y_MFOT = list()
SMA2Y_OTH = list()
SMA2Y_PL = list()
SMA2Y_PLBL = list()
SMA2Y_RL = list()
SMA2Y_SCC = list()
SMA2Y_SEL = list()

count_list_AL = list()
count_list_BL = list()
count_list_CC = list()
count_list_CD = list()
count_list_CV = list()
count_list_GL = list()
count_list_HL = list()
count_list_LAS = list()
count_list_MFBL = list()
count_list_MFHL = list()
count_list_MFOT = list()
count_list_OTH = list()
count_list_PL = list()
count_list_PLBL = list()
count_list_RL = list()
count_list_SCC = list()
count_list_SEL = list()

count_AL = 0
count_BL = 0
count_CC = 0
count_CD = 0
count_CV = 0
count_GL = 0
count_HL = 0
count_LAS = 0
count_MFBL = 0
count_MFHL = 0
count_MFOT = 0
count_OTH = 0
count_PL = 0 
count_PLBL = 0
count_RL = 0
count_SCC = 0
count_SEL = 0

grp_df = df.groupby('ID')

for x in range(0, len(unq_id_list)):
    grp_slice = grp_df.get_group(unq_id_list[x])
    #print(grp_slice)
    grp_slice.reset_index(drop=True, inplace=True)
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['accountType'][i]=='unknown'):
            continue
        elif (grp_slice['accountType'][i]=='AL') and (grp_slice['SMA2Y_flag'][i]==1):
            count_AL = count_AL + 1
        elif (grp_slice['accountType'][i]=='BL') and (grp_slice['SMA2Y_flag'][i]==1):
            count_BL = count_BL + 1
        elif (grp_slice['accountType'][i]=='CC') and (grp_slice['SMA2Y_flag'][i]==1):
            count_CC = count_CC + 1
        elif (grp_slice['accountType'][i]=='CD') and (grp_slice['SMA2Y_flag'][i]==1):
            count_CD = count_CD + 1
        elif (grp_slice['accountType'][i]=='CV') and (grp_slice['SMA2Y_flag'][i]==1):
            count_CV = count_CV + 1
        elif (grp_slice['accountType'][i]=='GL') and (grp_slice['SMA2Y_flag'][i]==1):
            count_GL = count_GL + 1
        elif (grp_slice['accountType'][i]=='HL') and (grp_slice['SMA2Y_flag'][i]==1):
            count_HL = count_HL + 1
        elif (grp_slice['accountType'][i]=='LAS') and (grp_slice['SMA2Y_flag'][i]==1):
            count_LAS = count_LAS + 1
        elif (grp_slice['accountType'][i]=='MFBL') and (grp_slice['SMA2Y_flag'][i]==1):
            count_MFBL = count_MFBL + 1
        elif (grp_slice['accountType'][i]=='MFHL') and (grp_slice['SMA2Y_flag'][i]==1):
            count_MFHL = count_MFHL + 1
        elif (grp_slice['accountType'][i]=='MFOT') and (grp_slice['SMA2Y_flag'][i]==1):
            count_MFOT = count_MFOT + 1
        elif (grp_slice['accountType'][i]=='OTH') and (grp_slice['SMA2Y_flag'][i]==1):
            count_OTH = count_OTH + 1
        elif (grp_slice['accountType'][i]=='PL') and (grp_slice['SMA2Y_flag'][i]==1):
            count_PL = count_PL + 1
        elif (grp_slice['accountType'][i]=='PLBL') and (grp_slice['SMA2Y_flag'][i]==1):
            count_PLBL = count_PLBL + 1
        elif (grp_slice['accountType'][i]=='RL') and (grp_slice['SMA2Y_flag'][i]==1):
            count_RL = count_RL + 1
        elif (grp_slice['accountType'][i]=='SCC') and (grp_slice['SMA2Y_flag'][i]==1):
            count_SCC = count_SCC + 1
        elif (grp_slice['accountType'][i]=='SEL') and (grp_slice['SMA2Y_flag'][i]==1):
            count_SEL = count_SEL + 1
            
    count_list_AL.append(count_AL)
    count_list_BL.append(count_BL)
    count_list_CC.append(count_CC)
    count_list_CD.append(count_CD)
    count_list_CV.append(count_CV)
    count_list_GL.append(count_GL)
    count_list_HL.append(count_HL)
    count_list_LAS.append(count_LAS)
    count_list_MFBL.append(count_MFBL)
    count_list_MFHL.append(count_MFHL)
    count_list_MFOT.append(count_MFOT)
    count_list_OTH.append(count_OTH)
    count_list_PL.append(count_PL)
    count_list_PLBL.append(count_PLBL)
    count_list_RL.append(count_RL)
    count_list_SCC.append(count_SCC)
    count_list_SEL.append(count_SEL)
    
    count_AL = 0
    count_BL = 0
    count_CC = 0
    count_CD = 0
    count_CV = 0
    count_GL = 0
    count_HL = 0
    count_LAS = 0
    count_MFBL = 0
    count_MFHL = 0
    count_MFOT = 0
    count_OTH = 0
    count_PL = 0
    count_PLBL = 0
    count_RL = 0
    count_SCC = 0
    count_SEL = 0
    
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['accountType'][i]=='unknown'):
            SMA2Y_AL.append('unknown')
            SMA2Y_BL.append('unknown')
            SMA2Y_CC.append('unknown')
            SMA2Y_CD.append('unknown')
            SMA2Y_CV.append('unknown')
            SMA2Y_GL.append('unknown')
            SMA2Y_HL.append('unknown')
            SMA2Y_LAS.append('unknown')
            SMA2Y_MFBL.append('unknown')
            SMA2Y_MFHL.append('unknown')
            SMA2Y_MFOT.append('unknown')
            SMA2Y_OTH.append('unknown')
            SMA2Y_PL.append('unknown')
            SMA2Y_PLBL.append('unknown')
            SMA2Y_RL.append('unknown')
            SMA2Y_SCC.append('unknown')
            SMA2Y_SEL.append('unknown')
        else:
            SMA2Y_AL.append(count_list_AL[x])
            SMA2Y_BL.append(count_list_BL[x])
            SMA2Y_CC.append(count_list_CC[x])
            SMA2Y_CD.append(count_list_CD[x])
            SMA2Y_CV.append(count_list_CV[x])
            SMA2Y_GL.append(count_list_GL[x])
            SMA2Y_HL.append(count_list_HL[x])
            SMA2Y_LAS.append(count_list_LAS[x])
            SMA2Y_MFBL.append(count_list_MFBL[x])
            SMA2Y_MFHL.append(count_list_MFHL[x])
            SMA2Y_MFOT.append(count_list_MFOT[x])
            SMA2Y_OTH.append(count_list_OTH[x])
            SMA2Y_PL.append(count_list_PL[x])
            SMA2Y_PLBL.append(count_list_PLBL[x])
            SMA2Y_RL.append(count_list_RL[x])
            SMA2Y_SCC.append(count_list_SCC[x])
            SMA2Y_SEL.append(count_list_SEL[x])
            
df['SMA2Y_AL'] = pd.Series(SMA2Y_AL).values
df['SMA2Y_BL'] = pd.Series(SMA2Y_BL).values
df['SMA2Y_CC'] = pd.Series(SMA2Y_CC).values
df['SMA2Y_CD'] = pd.Series(SMA2Y_CD).values
df['SMA2Y_CV'] = pd.Series(SMA2Y_CV).values
df['SMA2Y_GL'] = pd.Series(SMA2Y_GL).values
df['SMA2Y_HL'] = pd.Series(SMA2Y_HL).values
df['SMA2Y_LAS'] = pd.Series(SMA2Y_LAS).values
df['SMA2Y_MFBL'] = pd.Series(SMA2Y_MFBL).values
df['SMA2Y_MFHL'] = pd.Series(SMA2Y_MFHL).values
df['SMA2Y_MFOT'] = pd.Series(SMA2Y_MFOT).values
df['SMA2Y_OTH'] = pd.Series(SMA2Y_OTH).values
df['SMA2Y_PL'] = pd.Series(SMA2Y_PL).values
df['SMA2Y_PLBL'] = pd.Series(SMA2Y_PLBL).values
df['SMA2Y_RL'] = pd.Series(SMA2Y_RL).values
df['SMA2Y_SCC'] = pd.Series(SMA2Y_SCC).values
df['SMA2Y_SEL'] = pd.Series(SMA2Y_SEL).values
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/envs/ml_env/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'SMA2Y_flag'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-231-bb21ed241a35> in <module>
#      62         if (grp_slice['accountType'][i]=='unknown'):
#      63             continue
# ---> 64         elif (grp_slice['accountType'][i]=='AL') and (grp_slice['SMA2Y_flag'][i]==1):
#      65             count_AL = count_AL + 1
#      66         elif (grp_slice['accountType'][i]=='BL') and (grp_slice['SMA2Y_flag'][i]==1):
#
# ~/anaconda3/envs/ml_env/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2900             if self.columns.nlevels > 1:
#    2901                 return self._getitem_multilevel(key)
# -> 2902             indexer = self.columns.get_loc(key)
#    2903             if is_integer(indexer):
#    2904                 indexer = [indexer]
#
# ~/anaconda3/envs/ml_env/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
# -> 2897                 raise KeyError(key) from err
#    2898
#    2899         if tolerance is not None:
#
# KeyError: 'SMA2Y_flag'

# %% [raw]
# d = df[['ID','SMA2Y_GL','SMA2Y_flag','accountType']]
# d[d['SMA2Y_flag']!=0].head(60)

# %% [markdown]
# ### Code for SMA3Y_P
# - SMA in last 3 year productwise

# %%
SMA3Y_AL = list()
SMA3Y_BL = list()
SMA3Y_CC = list()
SMA3Y_CD = list()
SMA3Y_CV = list()
SMA3Y_GL = list()
SMA3Y_HL = list()
SMA3Y_LAS = list()
SMA3Y_MFBL = list()
SMA3Y_MFHL = list()
SMA3Y_MFOT = list()
SMA3Y_OTH = list()
SMA3Y_PL = list()
SMA3Y_PLBL = list()
SMA3Y_RL = list()
SMA3Y_SCC = list()
SMA3Y_SEL = list()

count_list_AL = list()
count_list_BL = list()
count_list_CC = list()
count_list_CD = list()
count_list_CV = list()
count_list_GL = list()
count_list_HL = list()
count_list_LAS = list()
count_list_MFBL = list()
count_list_MFHL = list()
count_list_MFOT = list()
count_list_OTH = list()
count_list_PL = list()
count_list_PLBL = list()
count_list_RL = list()
count_list_SCC = list()
count_list_SEL = list()

count_AL = 0
count_BL = 0
count_CC = 0
count_CD = 0
count_CV = 0
count_GL = 0
count_HL = 0
count_LAS = 0
count_MFBL = 0
count_MFHL = 0
count_MFOT = 0
count_OTH = 0
count_PL = 0 
count_PLBL = 0
count_RL = 0
count_SCC = 0
count_SEL = 0

grp_df = df.groupby('ID')

for x in range(0, len(unq_id_list)):
    grp_slice = grp_df.get_group(unq_id_list[x])
    #print(grp_slice)
    grp_slice.reset_index(drop=True, inplace=True)
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['accountType'][i]=='unknown'):
            continue
        elif (grp_slice['accountType'][i]=='AL') and (grp_slice['SMA3Y_flag'][i]==1):
            count_AL = count_AL + 1
        elif (grp_slice['accountType'][i]=='BL') and (grp_slice['SMA3Y_flag'][i]==1):
            count_BL = count_BL + 1
        elif (grp_slice['accountType'][i]=='CC') and (grp_slice['SMA3Y_flag'][i]==1):
            count_CC = count_CC + 1
        elif (grp_slice['accountType'][i]=='CD') and (grp_slice['SMA3Y_flag'][i]==1):
            count_CD = count_CD + 1
        elif (grp_slice['accountType'][i]=='CV') and (grp_slice['SMA3Y_flag'][i]==1):
            count_CV = count_CV + 1
        elif (grp_slice['accountType'][i]=='GL') and (grp_slice['SMA3Y_flag'][i]==1):
            count_GL = count_GL + 1
        elif (grp_slice['accountType'][i]=='HL') and (grp_slice['SMA3Y_flag'][i]==1):
            count_HL = count_HL + 1
        elif (grp_slice['accountType'][i]=='LAS') and (grp_slice['SMA3Y_flag'][i]==1):
            count_LAS = count_LAS + 1
        elif (grp_slice['accountType'][i]=='MFBL') and (grp_slice['SMA3Y_flag'][i]==1):
            count_MFBL = count_MFBL + 1
        elif (grp_slice['accountType'][i]=='MFHL') and (grp_slice['SMA3Y_flag'][i]==1):
            count_MFHL = count_MFHL + 1
        elif (grp_slice['accountType'][i]=='MFOT') and (grp_slice['SMA3Y_flag'][i]==1):
            count_MFOT = count_MFOT + 1
        elif (grp_slice['accountType'][i]=='OTH') and (grp_slice['SMA3Y_flag'][i]==1):
            count_OTH = count_OTH + 1
        elif (grp_slice['accountType'][i]=='PL') and (grp_slice['SMA3Y_flag'][i]==1):
            count_PL = count_PL + 1
        elif (grp_slice['accountType'][i]=='PLBL') and (grp_slice['SMA3Y_flag'][i]==1):
            count_PLBL = count_PLBL + 1
        elif (grp_slice['accountType'][i]=='RL') and (grp_slice['SMA3Y_flag'][i]==1):
            count_RL = count_RL + 1
        elif (grp_slice['accountType'][i]=='SCC') and (grp_slice['SMA3Y_flag'][i]==1):
            count_SCC = count_SCC + 1
        elif (grp_slice['accountType'][i]=='SEL') and (grp_slice['SMA3Y_flag'][i]==1):
            count_SEL = count_SEL + 1
            
    count_list_AL.append(count_AL)
    count_list_BL.append(count_BL)
    count_list_CC.append(count_CC)
    count_list_CD.append(count_CD)
    count_list_CV.append(count_CV)
    count_list_GL.append(count_GL)
    count_list_HL.append(count_HL)
    count_list_LAS.append(count_LAS)
    count_list_MFBL.append(count_MFBL)
    count_list_MFHL.append(count_MFHL)
    count_list_MFOT.append(count_MFOT)
    count_list_OTH.append(count_OTH)
    count_list_PL.append(count_PL)
    count_list_PLBL.append(count_PLBL)
    count_list_RL.append(count_RL)
    count_list_SCC.append(count_SCC)
    count_list_SEL.append(count_SEL)
    
    count_AL = 0
    count_BL = 0
    count_CC = 0
    count_CD = 0
    count_CV = 0
    count_GL = 0
    count_HL = 0
    count_LAS = 0
    count_MFBL = 0
    count_MFHL = 0
    count_MFOT = 0
    count_OTH = 0
    count_PL = 0
    count_PLBL = 0
    count_RL = 0
    count_SCC = 0
    count_SEL = 0
    
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['accountType'][i]=='unknown'):
            SMA3Y_AL.append('unknown')
            SMA3Y_BL.append('unknown')
            SMA3Y_CC.append('unknown')
            SMA3Y_CD.append('unknown')
            SMA3Y_CV.append('unknown')
            SMA3Y_GL.append('unknown')
            SMA3Y_HL.append('unknown')
            SMA3Y_LAS.append('unknown')
            SMA3Y_MFBL.append('unknown')
            SMA3Y_MFHL.append('unknown')
            SMA3Y_MFOT.append('unknown')
            SMA3Y_OTH.append('unknown')
            SMA3Y_PL.append('unknown')
            SMA3Y_PLBL.append('unknown')
            SMA3Y_RL.append('unknown')
            SMA3Y_SCC.append('unknown')
            SMA3Y_SEL.append('unknown')
        else:
            SMA3Y_AL.append(count_list_AL[x])
            SMA3Y_BL.append(count_list_BL[x])
            SMA3Y_CC.append(count_list_CC[x])
            SMA3Y_CD.append(count_list_CD[x])
            SMA3Y_CV.append(count_list_CV[x])
            SMA3Y_GL.append(count_list_GL[x])
            SMA3Y_HL.append(count_list_HL[x])
            SMA3Y_LAS.append(count_list_LAS[x])
            SMA3Y_MFBL.append(count_list_MFBL[x])
            SMA3Y_MFHL.append(count_list_MFHL[x])
            SMA3Y_MFOT.append(count_list_MFOT[x])
            SMA3Y_OTH.append(count_list_OTH[x])
            SMA3Y_PL.append(count_list_PL[x])
            SMA3Y_PLBL.append(count_list_PLBL[x])
            SMA3Y_RL.append(count_list_RL[x])
            SMA3Y_SCC.append(count_list_SCC[x])
            SMA3Y_SEL.append(count_list_SEL[x])
            
df['SMA3Y_AL'] = pd.Series(SMA3Y_AL).values
df['SMA3Y_BL'] = pd.Series(SMA3Y_BL).values
df['SMA3Y_CC'] = pd.Series(SMA3Y_CC).values
df['SMA3Y_CD'] = pd.Series(SMA3Y_CD).values
df['SMA3Y_CV'] = pd.Series(SMA3Y_CV).values
df['SMA3Y_GL'] = pd.Series(SMA3Y_GL).values
df['SMA3Y_HL'] = pd.Series(SMA3Y_HL).values
df['SMA3Y_LAS'] = pd.Series(SMA3Y_LAS).values
df['SMA3Y_MFBL'] = pd.Series(SMA3Y_MFBL).values
df['SMA3Y_MFHL'] = pd.Series(SMA3Y_MFHL).values
df['SMA3Y_MFOT'] = pd.Series(SMA3Y_MFOT).values
df['SMA3Y_OTH'] = pd.Series(SMA3Y_OTH).values
df['SMA3Y_PL'] = pd.Series(SMA3Y_PL).values
df['SMA3Y_PLBL'] = pd.Series(SMA3Y_PLBL).values
df['SMA3Y_RL'] = pd.Series(SMA3Y_RL).values
df['SMA3Y_SCC'] = pd.Series(SMA3Y_SCC).values
df['SMA3Y_SEL'] = pd.Series(SMA3Y_SEL).values
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/envs/ml_env/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'SMA3Y_flag'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-232-7d30628cd120> in <module>
#      62         if (grp_slice['accountType'][i]=='unknown'):
#      63             continue
# ---> 64         elif (grp_slice['accountType'][i]=='AL') and (grp_slice['SMA3Y_flag'][i]==1):
#      65             count_AL = count_AL + 1
#      66         elif (grp_slice['accountType'][i]=='BL') and (grp_slice['SMA3Y_flag'][i]==1):
#
# ~/anaconda3/envs/ml_env/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2900             if self.columns.nlevels > 1:
#    2901                 return self._getitem_multilevel(key)
# -> 2902             indexer = self.columns.get_loc(key)
#    2903             if is_integer(indexer):
#    2904                 indexer = [indexer]
#
# ~/anaconda3/envs/ml_env/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
# -> 2897                 raise KeyError(key) from err
#    2898
#    2899         if tolerance is not None:
#
# KeyError: 'SMA3Y_flag'

# %% [raw]
# d = df[['ID','SMA3Y_PL','SMA3Y_flag','accountType']]
# d[d['SMA3Y_flag']!=0].head(60)

# %%
df.shape
# Out:
# (4462, 142)

# %% [markdown]
# <a id='Ever_DPD_flags'></a>
# ### Ever_DPD flags
# - DPD30P1M_flag == 1 OR DPD60P1M_flag==1 OR DPD90P1M_flag==1 OR SMA1M_flag ==1 OR SUB1M_flag OR DBT1M_flag ==1 OR LOS1M_flag ==1

# %%
Ever_DPD1M_flag = list()
Ever_DPD3M_flag = list()
Ever_DPD6M_flag = list()
Ever_DPD1Y_flag = list()
Ever_DPD2Y_flag = list()
Ever_DPD3Y_flag = list()

for x in range(0, df.shape[0]):
    if (df['DPD30P1M_flag'][x] == 'unknown') and (df['DPD60P1M_flag'][x] == 'unknown') and (df['DPD90P1M_flag'][x] == 'unknown') and (df['SMA1M_flag'][x] == 'unknown') and (df['SUB1M_flag'][x] == 'unknown') and (df['DBT1M_flag'][x] == 'unknown') and (df['LOS1M_flag'][x] == 'unknown'):
        Ever_DPD1M_flag.append('unknown')
    elif (df['DPD30P1M_flag'][x] == 1) or (df['DPD60P1M_flag'][x] == 1) or (df['DPD90P1M_flag'][x] == 1) or (df['SMA1M_flag'][x] == 1) or (df['SUB1M_flag'][x] == 1) or (df['DBT1M_flag'][x] == 1) or (df['LOS1M_flag'][x] == 1):
        Ever_DPD1M_flag.append(1)
    else:
        Ever_DPD1M_flag.append(0)
        
    if (df['DPD30P3M_flag'][x] == 'unknown') and (df['DPD60P3M_flag'][x] == 'unknown') and (df['DPD90P3M_flag'][x] == 'unknown') and (df['SMA3M_flag'][x] == 'unknown') and (df['SUB3M_flag'][x] == 'unknown') and (df['DBT3M_flag'][x] == 'unknown') and (df['LOS3M_flag'][x] == 'unknown'):
        Ever_DPD3M_flag.append('unknown')
    elif (df['DPD30P3M_flag'][x] == 1) or (df['DPD60P3M_flag'][x] == 1) or (df['DPD90P3M_flag'][x] == 1) or (df['SMA3M_flag'][x] == 1) or (df['SUB3M_flag'][x] == 1) or (df['DBT3M_flag'][x] == 1) or (df['LOS3M_flag'][x] == 1):
        Ever_DPD3M_flag.append(1)
    else:
        Ever_DPD3M_flag.append(0)    
        
    if (df['DPD30P6M_flag'][x] == 'unknown') and (df['DPD60P6M_flag'][x] == 'unknown') and (df['DPD90P6M_flag'][x] == 'unknown') and (df['SMA6M_flag'][x] == 'unknown') and (df['SUB6M_flag'][x] == 'unknown') and (df['DBT6M_flag'][x] == 'unknown') and (df['LOS6M_flag'][x] == 'unknown'):        
        Ever_DPD6M_flag.append('unknown')
    elif (df['DPD30P6M_flag'][x] == 1) or (df['DPD60P6M_flag'][x] == 1) or (df['DPD90P6M_flag'][x] == 1) or (df['SMA6M_flag'][x] == 1) or (df['SUB6M_flag'][x] == 1) or (df['DBT6M_flag'][x] == 1) or (df['LOS6M_flag'][x] == 1):
        Ever_DPD6M_flag.append(1)
    else:
        Ever_DPD6M_flag.append(0)    
        
    if (df['DPD30P1Y_flag'][x] == 'unknown') and (df['DPD60P1Y_flag'][x] == 'unknown') and (df['DPD90P1Y_flag'][x] == 'unknown') and (df['SMA1Y_flag'][x] == 'unknown') and (df['SUB1Y_flag'][x] == 'unknown') and (df['DBT1Y_flag'][x] == 'unknown') and (df['LOS1Y_flag'][x] == 'unknown'):
        Ever_DPD1Y_flag.append('unknown')
    elif (df['DPD30P1Y_flag'][x] == 1) or (df['DPD60P1Y_flag'][x] == 1) or (df['DPD90P1Y_flag'][x] == 1) or (df['SMA1Y_flag'][x] == 1) or (df['SUB1Y_flag'][x] == 1) or (df['DBT1Y_flag'][x] == 1) or (df['LOS1Y_flag'][x] == 1):
        Ever_DPD1Y_flag.append(1)
    else:
        Ever_DPD1Y_flag.append(0)    
        
    if (df['DPD30P2Y_flag'][x] == 'unknown') and (df['DPD60P2Y_flag'][x] == 'unknown') and (df['DPD90P2Y_flag'][x] == 'unknown') and (df['SMA2Y_flag'][x] == 'unknown') and (df['SUB2Y_flag'][x] == 'unknown') and (df['DBT2Y_flag'][x] == 'unknown') and (df['LOS2Y_flag'][x] == 'unknown'):
        Ever_DPD2Y_flag.append('unknown')
    elif (df['DPD30P2Y_flag'][x] == 1) or (df['DPD60P2Y_flag'][x] == 1) or (df['DPD90P2Y_flag'][x] == 1) or (df['SMA2Y_flag'][x] == 1) or (df['SUB2Y_flag'][x] == 1) or (df['DBT2Y_flag'][x] == 1) or (df['LOS2Y_flag'][x] == 1):
        Ever_DPD2Y_flag.append(1)
    else:
        Ever_DPD2Y_flag.append(0)    
        
    if (df['DPD30P3Y_flag'][x] == 'unknown') and (df['DPD60P3Y_flag'][x] == 'unknown') and (df['DPD90P3Y_flag'][x] == 'unknown') and (df['SMA3Y_flag'][x] == 'unknown') and (df['SUB3Y_flag'][x] == 'unknown') and (df['DBT3Y_flag'][x] == 'unknown') and (df['LOS3Y_flag'][x] == 'unknown'):
        Ever_DPD3Y_flag.append('unknown')
    elif (df['DPD30P3Y_flag'][x] == 1) or (df['DPD60P3Y_flag'][x] == 1) or (df['DPD90P3Y_flag'][x] == 1) or (df['SMA3Y_flag'][x] == 1) or (df['SUB3Y_flag'][x] == 1) or (df['DBT3Y_flag'][x] == 1) or (df['LOS3Y_flag'][x] == 1):
        Ever_DPD3Y_flag.append(1)
    else:
        Ever_DPD3Y_flag.append(0) 

df['Ever_DPD1M_flag'] = pd.Series(Ever_DPD1M_flag).values
df['Ever_DPD3M_flag'] = pd.Series(Ever_DPD3M_flag).values
df['Ever_DPD6M_flag'] = pd.Series(Ever_DPD6M_flag).values
df['Ever_DPD1Y_flag'] = pd.Series(Ever_DPD1Y_flag).values
df['Ever_DPD2Y_flag'] = pd.Series(Ever_DPD2Y_flag).values
df['Ever_DPD3Y_flag'] = pd.Series(Ever_DPD3Y_flag).values
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/envs/ml_env/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'DPD30P1M_flag'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-234-bc497fc6e09d> in <module>
#       7
#       8 for x in range(0, df.shape[0]):
# ----> 9     if (df['DPD30P1M_flag'][x] == 'unknown') and (df['DPD60P1M_flag'][x] == 'unknown') and (df['DPD90P1M_flag'][x] == 'unknown') and (df['SMA1M_flag'][x] == 'unknown') and (df['SUB1M_flag'][x] == 'unknown') and (df['DBT1M_flag'][x] == 'unknown') and (df['LOS1M_flag'][x] == 'unknown'):
#      10         Ever_DPD1M_flag.append('unknown')
#      11     elif (df['DPD30P1M_flag'][x] == 1) or (df['DPD60P1M_flag'][x] == 1) or (df['DPD90P1M_flag'][x] == 1) or (df['SMA1M_flag'][x] == 1) or (df['SUB1M_flag'][x] == 1) or (df['DBT1M_flag'][x] == 1) or (df['LOS1M_flag'][x] == 1):
#
# ~/anaconda3/envs/ml_env/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2900             if self.columns.nlevels > 1:
#    2901                 return self._getitem_multilevel(key)
# -> 2902             indexer = self.columns.get_loc(key)
#    2903             if is_integer(indexer):
#    2904                 indexer = [indexer]
#
# ~/anaconda3/envs/ml_env/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
# -> 2897                 raise KeyError(key) from err
#    2898
#    2899         if tolerance is not None:
#
# KeyError: 'DPD30P1M_flag'

# %% [raw]
# a = df[['ID','Ever_DPD1M_flag','Ever_DPD3M_flag','DPD30P1M_flag','DPD30P3M_flag']]
# a[a['DPD30P1M_flag']==1]

# %% [markdown]
# <a id='Ever_DPD_prod'></a>
# ### Ever_DPD_prod
#
# - For an applicant, Count all loans where DPD30P1M_flag == 1 OR DPD60P1M_flag==1 OR DPD90P1M_flag==1 OR SMA1M_flag ==1 OR SUB1M_flag OR DBT1M_flag ==1 OR LOS1M_flag ==1  per product

# %%
Ever_DPD1M_AL = list()
Ever_DPD1M_BL = list()
Ever_DPD1M_CC = list()
Ever_DPD1M_CD = list()
Ever_DPD1M_CV = list()
Ever_DPD1M_GL = list()
Ever_DPD1M_HL = list()
Ever_DPD1M_LAS = list()
Ever_DPD1M_MFBL = list()
Ever_DPD1M_MFHL = list()
Ever_DPD1M_MFOT = list()
Ever_DPD1M_OTH = list()
Ever_DPD1M_PL = list()
Ever_DPD1M_PLBL = list()
Ever_DPD1M_RL = list()
Ever_DPD1M_SCC = list()
Ever_DPD1M_SEL = list()

count_list_AL = list()
count_list_BL = list()
count_list_CC = list()
count_list_CD = list()
count_list_CV = list()
count_list_GL = list()
count_list_HL = list()
count_list_LAS = list()
count_list_MFBL = list()
count_list_MFHL = list()
count_list_MFOT = list()
count_list_OTH = list()
count_list_PL = list()
count_list_PLBL = list()
count_list_RL = list()
count_list_SCC = list()
count_list_SEL = list()

count_AL = 0
count_BL = 0
count_CC = 0
count_CD = 0
count_CV = 0
count_GL = 0
count_HL = 0
count_LAS = 0
count_MFBL = 0
count_MFHL = 0
count_MFOT = 0
count_OTH = 0
count_PL = 0
count_PLBL = 0
count_RL = 0
count_SCC = 0
count_SEL = 0

grp_df = df.groupby('ID')

for x in range(0, len(unq_id_list)):
    grp_slice = grp_df.get_group(unq_id_list[x])
    # print(grp_slice)
    grp_slice.reset_index(drop=True, inplace=True)
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['accountType'][i] == 'unknown'):
            continue
        elif (grp_slice['accountType'][i] == 'AL') and (grp_slice['Ever_DPD1M_flag'][i] == 1):
            count_AL = count_AL + 1
        elif (grp_slice['accountType'][i] == 'BL') and (grp_slice['Ever_DPD1M_flag'][i] == 1):
            count_BL = count_BL + 1
        elif (grp_slice['accountType'][i] == 'CC') and (grp_slice['Ever_DPD1M_flag'][i] == 1):
            count_CC = count_CC + 1
        elif (grp_slice['accountType'][i] == 'CD') and (grp_slice['Ever_DPD1M_flag'][i] == 1):
            count_CD = count_CD + 1
        elif (grp_slice['accountType'][i] == 'CV') and (grp_slice['Ever_DPD1M_flag'][i] == 1):
            count_CV = count_CV + 1
        elif (grp_slice['accountType'][i] == 'GL') and (grp_slice['Ever_DPD1M_flag'][i] == 1):
            count_GL = count_GL + 1
        elif (grp_slice['accountType'][i] == 'HL') and (grp_slice['Ever_DPD1M_flag'][i] == 1):
            count_HL = count_HL + 1
        elif (grp_slice['accountType'][i] == 'LAS') and (grp_slice['Ever_DPD1M_flag'][i] == 1):
            count_LAS = count_LAS + 1
        elif (grp_slice['accountType'][i] == 'MFBL') and (grp_slice['Ever_DPD1M_flag'][i] == 1):
            count_MFBL = count_MFBL + 1
        elif (grp_slice['accountType'][i] == 'MFHL') and (grp_slice['Ever_DPD1M_flag'][i] == 1):
            count_MFHL = count_MFHL + 1
        elif (grp_slice['accountType'][i] == 'MFOT') and (grp_slice['Ever_DPD1M_flag'][i] == 1):
            count_MFOT = count_MFOT + 1
        elif (grp_slice['accountType'][i] == 'OTH') and (grp_slice['Ever_DPD1M_flag'][i] == 1):
            count_OTH = count_OTH + 1
        elif (grp_slice['accountType'][i] == 'PL') and (grp_slice['Ever_DPD1M_flag'][i] == 1):
            count_PL = count_PL + 1
        elif (grp_slice['accountType'][i] == 'PLBL') and (grp_slice['Ever_DPD1M_flag'][i] == 1):
            count_PLBL = count_PLBL + 1
        elif (grp_slice['accountType'][i] == 'RL') and (grp_slice['Ever_DPD1M_flag'][i] == 1):
            count_RL = count_RL + 1
        elif (grp_slice['accountType'][i] == 'SCC') and (grp_slice['Ever_DPD1M_flag'][i] == 1):
            count_SCC = count_SCC + 1
        elif (grp_slice['accountType'][i] == 'SEL') and (grp_slice['Ever_DPD1M_flag'][i] == 1):
            count_SEL = count_SEL + 1

    count_list_AL.append(count_AL)
    count_list_BL.append(count_BL)
    count_list_CC.append(count_CC)
    count_list_CD.append(count_CD)
    count_list_CV.append(count_CV)
    count_list_GL.append(count_GL)
    count_list_HL.append(count_HL)
    count_list_LAS.append(count_LAS)
    count_list_MFBL.append(count_MFBL)
    count_list_MFHL.append(count_MFHL)
    count_list_MFOT.append(count_MFOT)
    count_list_OTH.append(count_OTH)
    count_list_PL.append(count_PL)
    count_list_PLBL.append(count_PLBL)
    count_list_RL.append(count_RL)
    count_list_SCC.append(count_SCC)
    count_list_SEL.append(count_SEL)

    count_AL = 0
    count_BL = 0
    count_CC = 0
    count_CD = 0
    count_CV = 0
    count_GL = 0
    count_HL = 0
    count_LAS = 0
    count_MFBL = 0
    count_MFHL = 0
    count_MFOT = 0
    count_OTH = 0
    count_PL = 0
    count_PLBL = 0
    count_RL = 0
    count_SCC = 0
    count_SEL = 0

    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['accountType'][i] == 'unknown'):
            Ever_DPD1M_AL.append('unknown')
            Ever_DPD1M_BL.append('unknown')
            Ever_DPD1M_CC.append('unknown')
            Ever_DPD1M_CD.append('unknown')
            Ever_DPD1M_CV.append('unknown')
            Ever_DPD1M_GL.append('unknown')
            Ever_DPD1M_HL.append('unknown')
            Ever_DPD1M_LAS.append('unknown')
            Ever_DPD1M_MFBL.append('unknown')
            Ever_DPD1M_MFHL.append('unknown')
            Ever_DPD1M_MFOT.append('unknown')
            Ever_DPD1M_OTH.append('unknown')
            Ever_DPD1M_PL.append('unknown')
            Ever_DPD1M_PLBL.append('unknown')
            Ever_DPD1M_RL.append('unknown')
            Ever_DPD1M_SCC.append('unknown')
            Ever_DPD1M_SEL.append('unknown')
        else:
            Ever_DPD1M_AL.append(count_list_AL[x])
            Ever_DPD1M_BL.append(count_list_BL[x])
            Ever_DPD1M_CC.append(count_list_CC[x])
            Ever_DPD1M_CD.append(count_list_CD[x])
            Ever_DPD1M_CV.append(count_list_CV[x])
            Ever_DPD1M_GL.append(count_list_GL[x])
            Ever_DPD1M_HL.append(count_list_HL[x])
            Ever_DPD1M_LAS.append(count_list_LAS[x])
            Ever_DPD1M_MFBL.append(count_list_MFBL[x])
            Ever_DPD1M_MFHL.append(count_list_MFHL[x])
            Ever_DPD1M_MFOT.append(count_list_MFOT[x])
            Ever_DPD1M_OTH.append(count_list_OTH[x])
            Ever_DPD1M_PL.append(count_list_PL[x])
            Ever_DPD1M_PLBL.append(count_list_PLBL[x])
            Ever_DPD1M_RL.append(count_list_RL[x])
            Ever_DPD1M_SCC.append(count_list_SCC[x])
            Ever_DPD1M_SEL.append(count_list_SEL[x])

df['Ever_DPD1M_AL'] = pd.Series(Ever_DPD1M_AL).values
df['Ever_DPD1M_BL'] = pd.Series(Ever_DPD1M_BL).values
df['Ever_DPD1M_CC'] = pd.Series(Ever_DPD1M_CC).values
df['Ever_DPD1M_CD'] = pd.Series(Ever_DPD1M_CD).values
df['Ever_DPD1M_CV'] = pd.Series(Ever_DPD1M_CV).values
df['Ever_DPD1M_GL'] = pd.Series(Ever_DPD1M_GL).values
df['Ever_DPD1M_HL'] = pd.Series(Ever_DPD1M_HL).values
df['Ever_DPD1M_LAS'] = pd.Series(Ever_DPD1M_LAS).values
df['Ever_DPD1M_MFBL'] = pd.Series(Ever_DPD1M_MFBL).values
df['Ever_DPD1M_MFHL'] = pd.Series(Ever_DPD1M_MFHL).values
df['Ever_DPD1M_MFOT'] = pd.Series(Ever_DPD1M_MFOT).values
df['Ever_DPD1M_OTH'] = pd.Series(Ever_DPD1M_OTH).values
df['Ever_DPD1M_PL'] = pd.Series(Ever_DPD1M_PL).values
df['Ever_DPD1M_PLBL'] = pd.Series(Ever_DPD1M_PLBL).values
df['Ever_DPD1M_RL'] = pd.Series(Ever_DPD1M_RL).values
df['Ever_DPD1M_SCC'] = pd.Series(Ever_DPD1M_SCC).values
df['Ever_DPD1M_SEL'] = pd.Series(Ever_DPD1M_SEL).values
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/envs/ml_env/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Ever_DPD1M_flag'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-235-e9ca60fb8549> in <module>
#      62         if (grp_slice['accountType'][i] == 'unknown'):
#      63             continue
# ---> 64         elif (grp_slice['accountType'][i] == 'AL') and (grp_slice['Ever_DPD1M_flag'][i] == 1):
#      65             count_AL = count_AL + 1
#      66         elif (grp_slice['accountType'][i] == 'BL') and (grp_slice['Ever_DPD1M_flag'][i] == 1):
#
# ~/anaconda3/envs/ml_env/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2900             if self.columns.nlevels > 1:
#    2901                 return self._getitem_multilevel(key)
# -> 2902             indexer = self.columns.get_loc(key)
#    2903             if is_integer(indexer):
#    2904                 indexer = [indexer]
#
# ~/anaconda3/envs/ml_env/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
# -> 2897                 raise KeyError(key) from err
#    2898
#    2899         if tolerance is not None:
#
# KeyError: 'Ever_DPD1M_flag'

# %%
Ever_DPD3M_AL = list()
Ever_DPD3M_BL = list()
Ever_DPD3M_CC = list()
Ever_DPD3M_CD = list()
Ever_DPD3M_CV = list()
Ever_DPD3M_GL = list()
Ever_DPD3M_HL = list()
Ever_DPD3M_LAS = list()
Ever_DPD3M_MFBL = list()
Ever_DPD3M_MFHL = list()
Ever_DPD3M_MFOT = list()
Ever_DPD3M_OTH = list()
Ever_DPD3M_PL = list()
Ever_DPD3M_PLBL = list()
Ever_DPD3M_RL = list()
Ever_DPD3M_SCC = list()
Ever_DPD3M_SEL = list()

count_list_AL = list()
count_list_BL = list()
count_list_CC = list()
count_list_CD = list()
count_list_CV = list()
count_list_GL = list()
count_list_HL = list()
count_list_LAS = list()
count_list_MFBL = list()
count_list_MFHL = list()
count_list_MFOT = list()
count_list_OTH = list()
count_list_PL = list()
count_list_PLBL = list()
count_list_RL = list()
count_list_SCC = list()
count_list_SEL = list()

count_AL = 0
count_BL = 0
count_CC = 0
count_CD = 0
count_CV = 0
count_GL = 0
count_HL = 0
count_LAS = 0
count_MFBL = 0
count_MFHL = 0
count_MFOT = 0
count_OTH = 0
count_PL = 0
count_PLBL = 0
count_RL = 0
count_SCC = 0
count_SEL = 0

grp_df = df.groupby('ID')

for x in range(0, len(unq_id_list)):
    grp_slice = grp_df.get_group(unq_id_list[x])
    # print(grp_slice)
    grp_slice.reset_index(drop=True, inplace=True)
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['accountType'][i] == 'unknown'):
            continue
        elif (grp_slice['accountType'][i] == 'AL') and (grp_slice['Ever_DPD3M_flag'][i] == 1):
            count_AL = count_AL + 1
        elif (grp_slice['accountType'][i] == 'BL') and (grp_slice['Ever_DPD3M_flag'][i] == 1):
            count_BL = count_BL + 1
        elif (grp_slice['accountType'][i] == 'CC') and (grp_slice['Ever_DPD3M_flag'][i] == 1):
            count_CC = count_CC + 1
        elif (grp_slice['accountType'][i] == 'CD') and (grp_slice['Ever_DPD3M_flag'][i] == 1):
            count_CD = count_CD + 1
        elif (grp_slice['accountType'][i] == 'CV') and (grp_slice['Ever_DPD3M_flag'][i] == 1):
            count_CV = count_CV + 1
        elif (grp_slice['accountType'][i] == 'GL') and (grp_slice['Ever_DPD3M_flag'][i] == 1):
            count_GL = count_GL + 1
        elif (grp_slice['accountType'][i] == 'HL') and (grp_slice['Ever_DPD3M_flag'][i] == 1):
            count_HL = count_HL + 1
        elif (grp_slice['accountType'][i] == 'LAS') and (grp_slice['Ever_DPD3M_flag'][i] == 1):
            count_LAS = count_LAS + 1
        elif (grp_slice['accountType'][i] == 'MFBL') and (grp_slice['Ever_DPD3M_flag'][i] == 1):
            count_MFBL = count_MFBL + 1
        elif (grp_slice['accountType'][i] == 'MFHL') and (grp_slice['Ever_DPD3M_flag'][i] == 1):
            count_MFHL = count_MFHL + 1
        elif (grp_slice['accountType'][i] == 'MFOT') and (grp_slice['Ever_DPD3M_flag'][i] == 1):
            count_MFOT = count_MFOT + 1
        elif (grp_slice['accountType'][i] == 'OTH') and (grp_slice['Ever_DPD3M_flag'][i] == 1):
            count_OTH = count_OTH + 1
        elif (grp_slice['accountType'][i] == 'PL') and (grp_slice['Ever_DPD3M_flag'][i] == 1):
            count_PL = count_PL + 1
        elif (grp_slice['accountType'][i] == 'PLBL') and (grp_slice['Ever_DPD3M_flag'][i] == 1):
            count_PLBL = count_PLBL + 1
        elif (grp_slice['accountType'][i] == 'RL') and (grp_slice['Ever_DPD3M_flag'][i] == 1):
            count_RL = count_RL + 1
        elif (grp_slice['accountType'][i] == 'SCC') and (grp_slice['Ever_DPD3M_flag'][i] == 1):
            count_SCC = count_SCC + 1
        elif (grp_slice['accountType'][i] == 'SEL') and (grp_slice['Ever_DPD3M_flag'][i] == 1):
            count_SEL = count_SEL + 1

    count_list_AL.append(count_AL)
    count_list_BL.append(count_BL)
    count_list_CC.append(count_CC)
    count_list_CD.append(count_CD)
    count_list_CV.append(count_CV)
    count_list_GL.append(count_GL)
    count_list_HL.append(count_HL)
    count_list_LAS.append(count_LAS)
    count_list_MFBL.append(count_MFBL)
    count_list_MFHL.append(count_MFHL)
    count_list_MFOT.append(count_MFOT)
    count_list_OTH.append(count_OTH)
    count_list_PL.append(count_PL)
    count_list_PLBL.append(count_PLBL)
    count_list_RL.append(count_RL)
    count_list_SCC.append(count_SCC)
    count_list_SEL.append(count_SEL)

    count_AL = 0
    count_BL = 0
    count_CC = 0
    count_CD = 0
    count_CV = 0
    count_GL = 0
    count_HL = 0
    count_LAS = 0
    count_MFBL = 0
    count_MFHL = 0
    count_MFOT = 0
    count_OTH = 0
    count_PL = 0
    count_PLBL = 0
    count_RL = 0
    count_SCC = 0
    count_SEL = 0

    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['accountType'][i] == 'unknown'):
            Ever_DPD3M_AL.append('unknown')
            Ever_DPD3M_BL.append('unknown')
            Ever_DPD3M_CC.append('unknown')
            Ever_DPD3M_CD.append('unknown')
            Ever_DPD3M_CV.append('unknown')
            Ever_DPD3M_GL.append('unknown')
            Ever_DPD3M_HL.append('unknown')
            Ever_DPD3M_LAS.append('unknown')
            Ever_DPD3M_MFBL.append('unknown')
            Ever_DPD3M_MFHL.append('unknown')
            Ever_DPD3M_MFOT.append('unknown')
            Ever_DPD3M_OTH.append('unknown')
            Ever_DPD3M_PL.append('unknown')
            Ever_DPD3M_PLBL.append('unknown')
            Ever_DPD3M_RL.append('unknown')
            Ever_DPD3M_SCC.append('unknown')
            Ever_DPD3M_SEL.append('unknown')
        else:
            Ever_DPD3M_AL.append(count_list_AL[x])
            Ever_DPD3M_BL.append(count_list_BL[x])
            Ever_DPD3M_CC.append(count_list_CC[x])
            Ever_DPD3M_CD.append(count_list_CD[x])
            Ever_DPD3M_CV.append(count_list_CV[x])
            Ever_DPD3M_GL.append(count_list_GL[x])
            Ever_DPD3M_HL.append(count_list_HL[x])
            Ever_DPD3M_LAS.append(count_list_LAS[x])
            Ever_DPD3M_MFBL.append(count_list_MFBL[x])
            Ever_DPD3M_MFHL.append(count_list_MFHL[x])
            Ever_DPD3M_MFOT.append(count_list_MFOT[x])
            Ever_DPD3M_OTH.append(count_list_OTH[x])
            Ever_DPD3M_PL.append(count_list_PL[x])
            Ever_DPD3M_PLBL.append(count_list_PLBL[x])
            Ever_DPD3M_RL.append(count_list_RL[x])
            Ever_DPD3M_SCC.append(count_list_SCC[x])
            Ever_DPD3M_SEL.append(count_list_SEL[x])

df['Ever_DPD3M_AL'] = pd.Series(Ever_DPD3M_AL).values
df['Ever_DPD3M_BL'] = pd.Series(Ever_DPD3M_BL).values
df['Ever_DPD3M_CC'] = pd.Series(Ever_DPD3M_CC).values
df['Ever_DPD3M_CD'] = pd.Series(Ever_DPD3M_CD).values
df['Ever_DPD3M_CV'] = pd.Series(Ever_DPD3M_CV).values
df['Ever_DPD3M_GL'] = pd.Series(Ever_DPD3M_GL).values
df['Ever_DPD3M_HL'] = pd.Series(Ever_DPD3M_HL).values
df['Ever_DPD3M_LAS'] = pd.Series(Ever_DPD3M_LAS).values
df['Ever_DPD3M_MFBL'] = pd.Series(Ever_DPD3M_MFBL).values
df['Ever_DPD3M_MFHL'] = pd.Series(Ever_DPD3M_MFHL).values
df['Ever_DPD3M_MFOT'] = pd.Series(Ever_DPD3M_MFOT).values
df['Ever_DPD3M_OTH'] = pd.Series(Ever_DPD3M_OTH).values
df['Ever_DPD3M_PL'] = pd.Series(Ever_DPD3M_PL).values
df['Ever_DPD3M_PLBL'] = pd.Series(Ever_DPD3M_PLBL).values
df['Ever_DPD3M_RL'] = pd.Series(Ever_DPD3M_RL).values
df['Ever_DPD3M_SCC'] = pd.Series(Ever_DPD3M_SCC).values
df['Ever_DPD3M_SEL'] = pd.Series(Ever_DPD3M_SEL).values

# %%
Ever_DPD6M_AL = list()
Ever_DPD6M_BL = list()
Ever_DPD6M_CC = list()
Ever_DPD6M_CD = list()
Ever_DPD6M_CV = list()
Ever_DPD6M_GL = list()
Ever_DPD6M_HL = list()
Ever_DPD6M_LAS = list()
Ever_DPD6M_MFBL = list()
Ever_DPD6M_MFHL = list()
Ever_DPD6M_MFOT = list()
Ever_DPD6M_OTH = list()
Ever_DPD6M_PL = list()
Ever_DPD6M_PLBL = list()
Ever_DPD6M_RL = list()
Ever_DPD6M_SCC = list()
Ever_DPD6M_SEL = list()

count_list_AL = list()
count_list_BL = list()
count_list_CC = list()
count_list_CD = list()
count_list_CV = list()
count_list_GL = list()
count_list_HL = list()
count_list_LAS = list()
count_list_MFBL = list()
count_list_MFHL = list()
count_list_MFOT = list()
count_list_OTH = list()
count_list_PL = list()
count_list_PLBL = list()
count_list_RL = list()
count_list_SCC = list()
count_list_SEL = list()

count_AL = 0
count_BL = 0
count_CC = 0
count_CD = 0
count_CV = 0
count_GL = 0
count_HL = 0
count_LAS = 0
count_MFBL = 0
count_MFHL = 0
count_MFOT = 0
count_OTH = 0
count_PL = 0
count_PLBL = 0
count_RL = 0
count_SCC = 0
count_SEL = 0

grp_df = df.groupby('ID')

for x in range(0, len(unq_id_list)):
    grp_slice = grp_df.get_group(unq_id_list[x])
    # print(grp_slice)
    grp_slice.reset_index(drop=True, inplace=True)
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['accountType'][i] == 'unknown'):
            continue
        elif (grp_slice['accountType'][i] == 'AL') and (grp_slice['Ever_DPD6M_flag'][i] == 1):
            count_AL = count_AL + 1
        elif (grp_slice['accountType'][i] == 'BL') and (grp_slice['Ever_DPD6M_flag'][i] == 1):
            count_BL = count_BL + 1
        elif (grp_slice['accountType'][i] == 'CC') and (grp_slice['Ever_DPD6M_flag'][i] == 1):
            count_CC = count_CC + 1
        elif (grp_slice['accountType'][i] == 'CD') and (grp_slice['Ever_DPD6M_flag'][i] == 1):
            count_CD = count_CD + 1
        elif (grp_slice['accountType'][i] == 'CV') and (grp_slice['Ever_DPD6M_flag'][i] == 1):
            count_CV = count_CV + 1
        elif (grp_slice['accountType'][i] == 'GL') and (grp_slice['Ever_DPD6M_flag'][i] == 1):
            count_GL = count_GL + 1
        elif (grp_slice['accountType'][i] == 'HL') and (grp_slice['Ever_DPD6M_flag'][i] == 1):
            count_HL = count_HL + 1
        elif (grp_slice['accountType'][i] == 'LAS') and (grp_slice['Ever_DPD6M_flag'][i] == 1):
            count_LAS = count_LAS + 1
        elif (grp_slice['accountType'][i] == 'MFBL') and (grp_slice['Ever_DPD6M_flag'][i] == 1):
            count_MFBL = count_MFBL + 1
        elif (grp_slice['accountType'][i] == 'MFHL') and (grp_slice['Ever_DPD6M_flag'][i] == 1):
            count_MFHL = count_MFHL + 1
        elif (grp_slice['accountType'][i] == 'MFOT') and (grp_slice['Ever_DPD6M_flag'][i] == 1):
            count_MFOT = count_MFOT + 1
        elif (grp_slice['accountType'][i] == 'OTH') and (grp_slice['Ever_DPD6M_flag'][i] == 1):
            count_OTH = count_OTH + 1
        elif (grp_slice['accountType'][i] == 'PL') and (grp_slice['Ever_DPD6M_flag'][i] == 1):
            count_PL = count_PL + 1
        elif (grp_slice['accountType'][i] == 'PLBL') and (grp_slice['Ever_DPD6M_flag'][i] == 1):
            count_PLBL = count_PLBL + 1
        elif (grp_slice['accountType'][i] == 'RL') and (grp_slice['Ever_DPD6M_flag'][i] == 1):
            count_RL = count_RL + 1
        elif (grp_slice['accountType'][i] == 'SCC') and (grp_slice['Ever_DPD6M_flag'][i] == 1):
            count_SCC = count_SCC + 1
        elif (grp_slice['accountType'][i] == 'SEL') and (grp_slice['Ever_DPD6M_flag'][i] == 1):
            count_SEL = count_SEL + 1

    count_list_AL.append(count_AL)
    count_list_BL.append(count_BL)
    count_list_CC.append(count_CC)
    count_list_CD.append(count_CD)
    count_list_CV.append(count_CV)
    count_list_GL.append(count_GL)
    count_list_HL.append(count_HL)
    count_list_LAS.append(count_LAS)
    count_list_MFBL.append(count_MFBL)
    count_list_MFHL.append(count_MFHL)
    count_list_MFOT.append(count_MFOT)
    count_list_OTH.append(count_OTH)
    count_list_PL.append(count_PL)
    count_list_PLBL.append(count_PLBL)
    count_list_RL.append(count_RL)
    count_list_SCC.append(count_SCC)
    count_list_SEL.append(count_SEL)

    count_AL = 0
    count_BL = 0
    count_CC = 0
    count_CD = 0
    count_CV = 0
    count_GL = 0
    count_HL = 0
    count_LAS = 0
    count_MFBL = 0
    count_MFHL = 0
    count_MFOT = 0
    count_OTH = 0
    count_PL = 0
    count_PLBL = 0
    count_RL = 0
    count_SCC = 0
    count_SEL = 0

    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['accountType'][i] == 'unknown'):
            Ever_DPD6M_AL.append('unknown')
            Ever_DPD6M_BL.append('unknown')
            Ever_DPD6M_CC.append('unknown')
            Ever_DPD6M_CD.append('unknown')
            Ever_DPD6M_CV.append('unknown')
            Ever_DPD6M_GL.append('unknown')
            Ever_DPD6M_HL.append('unknown')
            Ever_DPD6M_LAS.append('unknown')
            Ever_DPD6M_MFBL.append('unknown')
            Ever_DPD6M_MFHL.append('unknown')
            Ever_DPD6M_MFOT.append('unknown')
            Ever_DPD6M_OTH.append('unknown')
            Ever_DPD6M_PL.append('unknown')
            Ever_DPD6M_PLBL.append('unknown')
            Ever_DPD6M_RL.append('unknown')
            Ever_DPD6M_SCC.append('unknown')
            Ever_DPD6M_SEL.append('unknown')
        else:
            Ever_DPD6M_AL.append(count_list_AL[x])
            Ever_DPD6M_BL.append(count_list_BL[x])
            Ever_DPD6M_CC.append(count_list_CC[x])
            Ever_DPD6M_CD.append(count_list_CD[x])
            Ever_DPD6M_CV.append(count_list_CV[x])
            Ever_DPD6M_GL.append(count_list_GL[x])
            Ever_DPD6M_HL.append(count_list_HL[x])
            Ever_DPD6M_LAS.append(count_list_LAS[x])
            Ever_DPD6M_MFBL.append(count_list_MFBL[x])
            Ever_DPD6M_MFHL.append(count_list_MFHL[x])
            Ever_DPD6M_MFOT.append(count_list_MFOT[x])
            Ever_DPD6M_OTH.append(count_list_OTH[x])
            Ever_DPD6M_PL.append(count_list_PL[x])
            Ever_DPD6M_PLBL.append(count_list_PLBL[x])
            Ever_DPD6M_RL.append(count_list_RL[x])
            Ever_DPD6M_SCC.append(count_list_SCC[x])
            Ever_DPD6M_SEL.append(count_list_SEL[x])

df['Ever_DPD6M_AL'] = pd.Series(Ever_DPD6M_AL).values
df['Ever_DPD6M_BL'] = pd.Series(Ever_DPD6M_BL).values
df['Ever_DPD6M_CC'] = pd.Series(Ever_DPD6M_CC).values
df['Ever_DPD6M_CD'] = pd.Series(Ever_DPD6M_CD).values
df['Ever_DPD6M_CV'] = pd.Series(Ever_DPD6M_CV).values
df['Ever_DPD6M_GL'] = pd.Series(Ever_DPD6M_GL).values
df['Ever_DPD6M_HL'] = pd.Series(Ever_DPD6M_HL).values
df['Ever_DPD6M_LAS'] = pd.Series(Ever_DPD6M_LAS).values
df['Ever_DPD6M_MFBL'] = pd.Series(Ever_DPD6M_MFBL).values
df['Ever_DPD6M_MFHL'] = pd.Series(Ever_DPD6M_MFHL).values
df['Ever_DPD6M_MFOT'] = pd.Series(Ever_DPD6M_MFOT).values
df['Ever_DPD6M_OTH'] = pd.Series(Ever_DPD6M_OTH).values
df['Ever_DPD6M_PL'] = pd.Series(Ever_DPD6M_PL).values
df['Ever_DPD6M_PLBL'] = pd.Series(Ever_DPD6M_PLBL).values
df['Ever_DPD6M_RL'] = pd.Series(Ever_DPD6M_RL).values
df['Ever_DPD6M_SCC'] = pd.Series(Ever_DPD6M_SCC).values
df['Ever_DPD6M_SEL'] = pd.Series(Ever_DPD6M_SEL).values

# %%
Ever_DPD1Y_AL = list()
Ever_DPD1Y_BL = list()
Ever_DPD1Y_CC = list()
Ever_DPD1Y_CD = list()
Ever_DPD1Y_CV = list()
Ever_DPD1Y_GL = list()
Ever_DPD1Y_HL = list()
Ever_DPD1Y_LAS = list()
Ever_DPD1Y_MFBL = list()
Ever_DPD1Y_MFHL = list()
Ever_DPD1Y_MFOT = list()
Ever_DPD1Y_OTH = list()
Ever_DPD1Y_PL = list()
Ever_DPD1Y_PLBL = list()
Ever_DPD1Y_RL = list()
Ever_DPD1Y_SCC = list()
Ever_DPD1Y_SEL = list()

count_list_AL = list()
count_list_BL = list()
count_list_CC = list()
count_list_CD = list()
count_list_CV = list()
count_list_GL = list()
count_list_HL = list()
count_list_LAS = list()
count_list_MFBL = list()
count_list_MFHL = list()
count_list_MFOT = list()
count_list_OTH = list()
count_list_PL = list()
count_list_PLBL = list()
count_list_RL = list()
count_list_SCC = list()
count_list_SEL = list()

count_AL = 0
count_BL = 0
count_CC = 0
count_CD = 0
count_CV = 0
count_GL = 0
count_HL = 0
count_LAS = 0
count_MFBL = 0
count_MFHL = 0
count_MFOT = 0
count_OTH = 0
count_PL = 0
count_PLBL = 0
count_RL = 0
count_SCC = 0
count_SEL = 0

grp_df = df.groupby('ID')

for x in range(0, len(unq_id_list)):
    grp_slice = grp_df.get_group(unq_id_list[x])
    # print(grp_slice)
    grp_slice.reset_index(drop=True, inplace=True)
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['accountType'][i] == 'unknown'):
            continue
        elif (grp_slice['accountType'][i] == 'AL') and (grp_slice['Ever_DPD1Y_flag'][i] == 1):
            count_AL = count_AL + 1
        elif (grp_slice['accountType'][i] == 'BL') and (grp_slice['Ever_DPD1Y_flag'][i] == 1):
            count_BL = count_BL + 1
        elif (grp_slice['accountType'][i] == 'CC') and (grp_slice['Ever_DPD1Y_flag'][i] == 1):
            count_CC = count_CC + 1
        elif (grp_slice['accountType'][i] == 'CD') and (grp_slice['Ever_DPD1Y_flag'][i] == 1):
            count_CD = count_CD + 1
        elif (grp_slice['accountType'][i] == 'CV') and (grp_slice['Ever_DPD1Y_flag'][i] == 1):
            count_CV = count_CV + 1
        elif (grp_slice['accountType'][i] == 'GL') and (grp_slice['Ever_DPD1Y_flag'][i] == 1):
            count_GL = count_GL + 1
        elif (grp_slice['accountType'][i] == 'HL') and (grp_slice['Ever_DPD1Y_flag'][i] == 1):
            count_HL = count_HL + 1
        elif (grp_slice['accountType'][i] == 'LAS') and (grp_slice['Ever_DPD1Y_flag'][i] == 1):
            count_LAS = count_LAS + 1
        elif (grp_slice['accountType'][i] == 'MFBL') and (grp_slice['Ever_DPD1Y_flag'][i] == 1):
            count_MFBL = count_MFBL + 1
        elif (grp_slice['accountType'][i] == 'MFHL') and (grp_slice['Ever_DPD1Y_flag'][i] == 1):
            count_MFHL = count_MFHL + 1
        elif (grp_slice['accountType'][i] == 'MFOT') and (grp_slice['Ever_DPD1Y_flag'][i] == 1):
            count_MFOT = count_MFOT + 1
        elif (grp_slice['accountType'][i] == 'OTH') and (grp_slice['Ever_DPD1Y_flag'][i] == 1):
            count_OTH = count_OTH + 1
        elif (grp_slice['accountType'][i] == 'PL') and (grp_slice['Ever_DPD1Y_flag'][i] == 1):
            count_PL = count_PL + 1
        elif (grp_slice['accountType'][i] == 'PLBL') and (grp_slice['Ever_DPD1Y_flag'][i] == 1):
            count_PLBL = count_PLBL + 1
        elif (grp_slice['accountType'][i] == 'RL') and (grp_slice['Ever_DPD1Y_flag'][i] == 1):
            count_RL = count_RL + 1
        elif (grp_slice['accountType'][i] == 'SCC') and (grp_slice['Ever_DPD1Y_flag'][i] == 1):
            count_SCC = count_SCC + 1
        elif (grp_slice['accountType'][i] == 'SEL') and (grp_slice['Ever_DPD1Y_flag'][i] == 1):
            count_SEL = count_SEL + 1

    count_list_AL.append(count_AL)
    count_list_BL.append(count_BL)
    count_list_CC.append(count_CC)
    count_list_CD.append(count_CD)
    count_list_CV.append(count_CV)
    count_list_GL.append(count_GL)
    count_list_HL.append(count_HL)
    count_list_LAS.append(count_LAS)
    count_list_MFBL.append(count_MFBL)
    count_list_MFHL.append(count_MFHL)
    count_list_MFOT.append(count_MFOT)
    count_list_OTH.append(count_OTH)
    count_list_PL.append(count_PL)
    count_list_PLBL.append(count_PLBL)
    count_list_RL.append(count_RL)
    count_list_SCC.append(count_SCC)
    count_list_SEL.append(count_SEL)

    count_AL = 0
    count_BL = 0
    count_CC = 0
    count_CD = 0
    count_CV = 0
    count_GL = 0
    count_HL = 0
    count_LAS = 0
    count_MFBL = 0
    count_MFHL = 0
    count_MFOT = 0
    count_OTH = 0
    count_PL = 0
    count_PLBL = 0
    count_RL = 0
    count_SCC = 0
    count_SEL = 0

    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['accountType'][i] == 'unknown'):
            Ever_DPD1Y_AL.append('unknown')
            Ever_DPD1Y_BL.append('unknown')
            Ever_DPD1Y_CC.append('unknown')
            Ever_DPD1Y_CD.append('unknown')
            Ever_DPD1Y_CV.append('unknown')
            Ever_DPD1Y_GL.append('unknown')
            Ever_DPD1Y_HL.append('unknown')
            Ever_DPD1Y_LAS.append('unknown')
            Ever_DPD1Y_MFBL.append('unknown')
            Ever_DPD1Y_MFHL.append('unknown')
            Ever_DPD1Y_MFOT.append('unknown')
            Ever_DPD1Y_OTH.append('unknown')
            Ever_DPD1Y_PL.append('unknown')
            Ever_DPD1Y_PLBL.append('unknown')
            Ever_DPD1Y_RL.append('unknown')
            Ever_DPD1Y_SCC.append('unknown')
            Ever_DPD1Y_SEL.append('unknown')
        else:
            Ever_DPD1Y_AL.append(count_list_AL[x])
            Ever_DPD1Y_BL.append(count_list_BL[x])
            Ever_DPD1Y_CC.append(count_list_CC[x])
            Ever_DPD1Y_CD.append(count_list_CD[x])
            Ever_DPD1Y_CV.append(count_list_CV[x])
            Ever_DPD1Y_GL.append(count_list_GL[x])
            Ever_DPD1Y_HL.append(count_list_HL[x])
            Ever_DPD1Y_LAS.append(count_list_LAS[x])
            Ever_DPD1Y_MFBL.append(count_list_MFBL[x])
            Ever_DPD1Y_MFHL.append(count_list_MFHL[x])
            Ever_DPD1Y_MFOT.append(count_list_MFOT[x])
            Ever_DPD1Y_OTH.append(count_list_OTH[x])
            Ever_DPD1Y_PL.append(count_list_PL[x])
            Ever_DPD1Y_PLBL.append(count_list_PLBL[x])
            Ever_DPD1Y_RL.append(count_list_RL[x])
            Ever_DPD1Y_SCC.append(count_list_SCC[x])
            Ever_DPD1Y_SEL.append(count_list_SEL[x])

df['Ever_DPD1Y_AL'] = pd.Series(Ever_DPD1Y_AL).values
df['Ever_DPD1Y_BL'] = pd.Series(Ever_DPD1Y_BL).values
df['Ever_DPD1Y_CC'] = pd.Series(Ever_DPD1Y_CC).values
df['Ever_DPD1Y_CD'] = pd.Series(Ever_DPD1Y_CD).values
df['Ever_DPD1Y_CV'] = pd.Series(Ever_DPD1Y_CV).values
df['Ever_DPD1Y_GL'] = pd.Series(Ever_DPD1Y_GL).values
df['Ever_DPD1Y_HL'] = pd.Series(Ever_DPD1Y_HL).values
df['Ever_DPD1Y_LAS'] = pd.Series(Ever_DPD1Y_LAS).values
df['Ever_DPD1Y_MFBL'] = pd.Series(Ever_DPD1Y_MFBL).values
df['Ever_DPD1Y_MFHL'] = pd.Series(Ever_DPD1Y_MFHL).values
df['Ever_DPD1Y_MFOT'] = pd.Series(Ever_DPD1Y_MFOT).values
df['Ever_DPD1Y_OTH'] = pd.Series(Ever_DPD1Y_OTH).values
df['Ever_DPD1Y_PL'] = pd.Series(Ever_DPD1Y_PL).values
df['Ever_DPD1Y_PLBL'] = pd.Series(Ever_DPD1Y_PLBL).values
df['Ever_DPD1Y_RL'] = pd.Series(Ever_DPD1Y_RL).values
df['Ever_DPD1Y_SCC'] = pd.Series(Ever_DPD1Y_SCC).values
df['Ever_DPD1Y_SEL'] = pd.Series(Ever_DPD1Y_SEL).values
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/envs/ml_env/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Ever_DPD1Y_flag'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-238-7d0b0b4b9181> in <module>
#      62         if (grp_slice['accountType'][i] == 'unknown'):
#      63             continue
# ---> 64         elif (grp_slice['accountType'][i] == 'AL') and (grp_slice['Ever_DPD1Y_flag'][i] == 1):
#      65             count_AL = count_AL + 1
#      66         elif (grp_slice['accountType'][i] == 'BL') and (grp_slice['Ever_DPD1Y_flag'][i] == 1):
#
# ~/anaconda3/envs/ml_env/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2900             if self.columns.nlevels > 1:
#    2901                 return self._getitem_multilevel(key)
# -> 2902             indexer = self.columns.get_loc(key)
#    2903             if is_integer(indexer):
#    2904                 indexer = [indexer]
#
# ~/anaconda3/envs/ml_env/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
# -> 2897                 raise KeyError(key) from err
#    2898
#    2899         if tolerance is not None:
#
# KeyError: 'Ever_DPD1Y_flag'

# %%
Ever_DPD2Y_AL = list()
Ever_DPD2Y_BL = list()
Ever_DPD2Y_CC = list()
Ever_DPD2Y_CD = list()
Ever_DPD2Y_CV = list()
Ever_DPD2Y_GL = list()
Ever_DPD2Y_HL = list()
Ever_DPD2Y_LAS = list()
Ever_DPD2Y_MFBL = list()
Ever_DPD2Y_MFHL = list()
Ever_DPD2Y_MFOT = list()
Ever_DPD2Y_OTH = list()
Ever_DPD2Y_PL = list()
Ever_DPD2Y_PLBL = list()
Ever_DPD2Y_RL = list()
Ever_DPD2Y_SCC = list()
Ever_DPD2Y_SEL = list()

count_list_AL = list()
count_list_BL = list()
count_list_CC = list()
count_list_CD = list()
count_list_CV = list()
count_list_GL = list()
count_list_HL = list()
count_list_LAS = list()
count_list_MFBL = list()
count_list_MFHL = list()
count_list_MFOT = list()
count_list_OTH = list()
count_list_PL = list()
count_list_PLBL = list()
count_list_RL = list()
count_list_SCC = list()
count_list_SEL = list()

count_AL = 0
count_BL = 0
count_CC = 0
count_CD = 0
count_CV = 0
count_GL = 0
count_HL = 0
count_LAS = 0
count_MFBL = 0
count_MFHL = 0
count_MFOT = 0
count_OTH = 0
count_PL = 0
count_PLBL = 0
count_RL = 0
count_SCC = 0
count_SEL = 0

grp_df = df.groupby('ID')

for x in range(0, len(unq_id_list)):
    grp_slice = grp_df.get_group(unq_id_list[x])
    # print(grp_slice)
    grp_slice.reset_index(drop=True, inplace=True)
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['accountType'][i] == 'unknown'):
            continue
        elif (grp_slice['accountType'][i] == 'AL') and (grp_slice['Ever_DPD2Y_flag'][i] == 1):
            count_AL = count_AL + 1
        elif (grp_slice['accountType'][i] == 'BL') and (grp_slice['Ever_DPD2Y_flag'][i] == 1):
            count_BL = count_BL + 1
        elif (grp_slice['accountType'][i] == 'CC') and (grp_slice['Ever_DPD2Y_flag'][i] == 1):
            count_CC = count_CC + 1
        elif (grp_slice['accountType'][i] == 'CD') and (grp_slice['Ever_DPD2Y_flag'][i] == 1):
            count_CD = count_CD + 1
        elif (grp_slice['accountType'][i] == 'CV') and (grp_slice['Ever_DPD2Y_flag'][i] == 1):
            count_CV = count_CV + 1
        elif (grp_slice['accountType'][i] == 'GL') and (grp_slice['Ever_DPD2Y_flag'][i] == 1):
            count_GL = count_GL + 1
        elif (grp_slice['accountType'][i] == 'HL') and (grp_slice['Ever_DPD2Y_flag'][i] == 1):
            count_HL = count_HL + 1
        elif (grp_slice['accountType'][i] == 'LAS') and (grp_slice['Ever_DPD2Y_flag'][i] == 1):
            count_LAS = count_LAS + 1
        elif (grp_slice['accountType'][i] == 'MFBL') and (grp_slice['Ever_DPD2Y_flag'][i] == 1):
            count_MFBL = count_MFBL + 1
        elif (grp_slice['accountType'][i] == 'MFHL') and (grp_slice['Ever_DPD2Y_flag'][i] == 1):
            count_MFHL = count_MFHL + 1
        elif (grp_slice['accountType'][i] == 'MFOT') and (grp_slice['Ever_DPD2Y_flag'][i] == 1):
            count_MFOT = count_MFOT + 1
        elif (grp_slice['accountType'][i] == 'OTH') and (grp_slice['Ever_DPD2Y_flag'][i] == 1):
            count_OTH = count_OTH + 1
        elif (grp_slice['accountType'][i] == 'PL') and (grp_slice['Ever_DPD2Y_flag'][i] == 1):
            count_PL = count_PL + 1
        elif (grp_slice['accountType'][i] == 'PLBL') and (grp_slice['Ever_DPD2Y_flag'][i] == 1):
            count_PLBL = count_PLBL + 1
        elif (grp_slice['accountType'][i] == 'RL') and (grp_slice['Ever_DPD2Y_flag'][i] == 1):
            count_RL = count_RL + 1
        elif (grp_slice['accountType'][i] == 'SCC') and (grp_slice['Ever_DPD2Y_flag'][i] == 1):
            count_SCC = count_SCC + 1
        elif (grp_slice['accountType'][i] == 'SEL') and (grp_slice['Ever_DPD2Y_flag'][i] == 1):
            count_SEL = count_SEL + 1

    count_list_AL.append(count_AL)
    count_list_BL.append(count_BL)
    count_list_CC.append(count_CC)
    count_list_CD.append(count_CD)
    count_list_CV.append(count_CV)
    count_list_GL.append(count_GL)
    count_list_HL.append(count_HL)
    count_list_LAS.append(count_LAS)
    count_list_MFBL.append(count_MFBL)
    count_list_MFHL.append(count_MFHL)
    count_list_MFOT.append(count_MFOT)
    count_list_OTH.append(count_OTH)
    count_list_PL.append(count_PL)
    count_list_PLBL.append(count_PLBL)
    count_list_RL.append(count_RL)
    count_list_SCC.append(count_SCC)
    count_list_SEL.append(count_SEL)

    count_AL = 0
    count_BL = 0
    count_CC = 0
    count_CD = 0
    count_CV = 0
    count_GL = 0
    count_HL = 0
    count_LAS = 0
    count_MFBL = 0
    count_MFHL = 0
    count_MFOT = 0
    count_OTH = 0
    count_PL = 0
    count_PLBL = 0
    count_RL = 0
    count_SCC = 0
    count_SEL = 0

    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['accountType'][i] == 'unknown'):
            Ever_DPD2Y_AL.append('unknown')
            Ever_DPD2Y_BL.append('unknown')
            Ever_DPD2Y_CC.append('unknown')
            Ever_DPD2Y_CD.append('unknown')
            Ever_DPD2Y_CV.append('unknown')
            Ever_DPD2Y_GL.append('unknown')
            Ever_DPD2Y_HL.append('unknown')
            Ever_DPD2Y_LAS.append('unknown')
            Ever_DPD2Y_MFBL.append('unknown')
            Ever_DPD2Y_MFHL.append('unknown')
            Ever_DPD2Y_MFOT.append('unknown')
            Ever_DPD2Y_OTH.append('unknown')
            Ever_DPD2Y_PL.append('unknown')
            Ever_DPD2Y_PLBL.append('unknown')
            Ever_DPD2Y_RL.append('unknown')
            Ever_DPD2Y_SCC.append('unknown')
            Ever_DPD2Y_SEL.append('unknown')
        else:
            Ever_DPD2Y_AL.append(count_list_AL[x])
            Ever_DPD2Y_BL.append(count_list_BL[x])
            Ever_DPD2Y_CC.append(count_list_CC[x])
            Ever_DPD2Y_CD.append(count_list_CD[x])
            Ever_DPD2Y_CV.append(count_list_CV[x])
            Ever_DPD2Y_GL.append(count_list_GL[x])
            Ever_DPD2Y_HL.append(count_list_HL[x])
            Ever_DPD2Y_LAS.append(count_list_LAS[x])
            Ever_DPD2Y_MFBL.append(count_list_MFBL[x])
            Ever_DPD2Y_MFHL.append(count_list_MFHL[x])
            Ever_DPD2Y_MFOT.append(count_list_MFOT[x])
            Ever_DPD2Y_OTH.append(count_list_OTH[x])
            Ever_DPD2Y_PL.append(count_list_PL[x])
            Ever_DPD2Y_PLBL.append(count_list_PLBL[x])
            Ever_DPD2Y_RL.append(count_list_RL[x])
            Ever_DPD2Y_SCC.append(count_list_SCC[x])
            Ever_DPD2Y_SEL.append(count_list_SEL[x])

df['Ever_DPD2Y_AL'] = pd.Series(Ever_DPD2Y_AL).values
df['Ever_DPD2Y_BL'] = pd.Series(Ever_DPD2Y_BL).values
df['Ever_DPD2Y_CC'] = pd.Series(Ever_DPD2Y_CC).values
df['Ever_DPD2Y_CD'] = pd.Series(Ever_DPD2Y_CD).values
df['Ever_DPD2Y_CV'] = pd.Series(Ever_DPD2Y_CV).values
df['Ever_DPD2Y_GL'] = pd.Series(Ever_DPD2Y_GL).values
df['Ever_DPD2Y_HL'] = pd.Series(Ever_DPD2Y_HL).values
df['Ever_DPD2Y_LAS'] = pd.Series(Ever_DPD2Y_LAS).values
df['Ever_DPD2Y_MFBL'] = pd.Series(Ever_DPD2Y_MFBL).values
df['Ever_DPD2Y_MFHL'] = pd.Series(Ever_DPD2Y_MFHL).values
df['Ever_DPD2Y_MFOT'] = pd.Series(Ever_DPD2Y_MFOT).values
df['Ever_DPD2Y_OTH'] = pd.Series(Ever_DPD2Y_OTH).values
df['Ever_DPD2Y_PL'] = pd.Series(Ever_DPD2Y_PL).values
df['Ever_DPD2Y_PLBL'] = pd.Series(Ever_DPD2Y_PLBL).values
df['Ever_DPD2Y_RL'] = pd.Series(Ever_DPD2Y_RL).values
df['Ever_DPD2Y_SCC'] = pd.Series(Ever_DPD2Y_SCC).values
df['Ever_DPD2Y_SEL'] = pd.Series(Ever_DPD2Y_SEL).values
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/envs/ml_env/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Ever_DPD2Y_flag'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-236-a07279adb72e> in <module>
#      62         if (grp_slice['accountType'][i] == 'unknown'):
#      63             continue
# ---> 64         elif (grp_slice['accountType'][i] == 'AL') and (grp_slice['Ever_DPD2Y_flag'][i] == 1):
#      65             count_AL = count_AL + 1
#      66         elif (grp_slice['accountType'][i] == 'BL') and (grp_slice['Ever_DPD2Y_flag'][i] == 1):
#
# ~/anaconda3/envs/ml_env/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2900             if self.columns.nlevels > 1:
#    2901                 return self._getitem_multilevel(key)
# -> 2902             indexer = self.columns.get_loc(key)
#    2903             if is_integer(indexer):
#    2904                 indexer = [indexer]
#
# ~/anaconda3/envs/ml_env/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
# -> 2897                 raise KeyError(key) from err
#    2898
#    2899         if tolerance is not None:
#
# KeyError: 'Ever_DPD2Y_flag'

# %%
Ever_DPD3Y_AL = list()
Ever_DPD3Y_BL = list()
Ever_DPD3Y_CC = list()
Ever_DPD3Y_CD = list()
Ever_DPD3Y_CV = list()
Ever_DPD3Y_GL = list()
Ever_DPD3Y_HL = list()
Ever_DPD3Y_LAS = list()
Ever_DPD3Y_MFBL = list()
Ever_DPD3Y_MFHL = list()
Ever_DPD3Y_MFOT = list()
Ever_DPD3Y_OTH = list()
Ever_DPD3Y_PL = list()
Ever_DPD3Y_PLBL = list()
Ever_DPD3Y_RL = list()
Ever_DPD3Y_SCC = list()
Ever_DPD3Y_SEL = list()

count_list_AL = list()
count_list_BL = list()
count_list_CC = list()
count_list_CD = list()
count_list_CV = list()
count_list_GL = list()
count_list_HL = list()
count_list_LAS = list()
count_list_MFBL = list()
count_list_MFHL = list()
count_list_MFOT = list()
count_list_OTH = list()
count_list_PL = list()
count_list_PLBL = list()
count_list_RL = list()
count_list_SCC = list()
count_list_SEL = list()

count_AL = 0
count_BL = 0
count_CC = 0
count_CD = 0
count_CV = 0
count_GL = 0
count_HL = 0
count_LAS = 0
count_MFBL = 0
count_MFHL = 0
count_MFOT = 0
count_OTH = 0
count_PL = 0
count_PLBL = 0
count_RL = 0
count_SCC = 0
count_SEL = 0

grp_df = df.groupby('ID')

for x in range(0, len(unq_id_list)):
    grp_slice = grp_df.get_group(unq_id_list[x])
    # print(grp_slice)
    grp_slice.reset_index(drop=True, inplace=True)
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['accountType'][i] == 'unknown'):
            continue
        elif (grp_slice['accountType'][i] == 'AL') and (grp_slice['Ever_DPD3Y_flag'][i] == 1):
            count_AL = count_AL + 1
        elif (grp_slice['accountType'][i] == 'BL') and (grp_slice['Ever_DPD3Y_flag'][i] == 1):
            count_BL = count_BL + 1
        elif (grp_slice['accountType'][i] == 'CC') and (grp_slice['Ever_DPD3Y_flag'][i] == 1):
            count_CC = count_CC + 1
        elif (grp_slice['accountType'][i] == 'CD') and (grp_slice['Ever_DPD3Y_flag'][i] == 1):
            count_CD = count_CD + 1
        elif (grp_slice['accountType'][i] == 'CV') and (grp_slice['Ever_DPD3Y_flag'][i] == 1):
            count_CV = count_CV + 1
        elif (grp_slice['accountType'][i] == 'GL') and (grp_slice['Ever_DPD3Y_flag'][i] == 1):
            count_GL = count_GL + 1
        elif (grp_slice['accountType'][i] == 'HL') and (grp_slice['Ever_DPD3Y_flag'][i] == 1):
            count_HL = count_HL + 1
        elif (grp_slice['accountType'][i] == 'LAS') and (grp_slice['Ever_DPD3Y_flag'][i] == 1):
            count_LAS = count_LAS + 1
        elif (grp_slice['accountType'][i] == 'MFBL') and (grp_slice['Ever_DPD3Y_flag'][i] == 1):
            count_MFBL = count_MFBL + 1
        elif (grp_slice['accountType'][i] == 'MFHL') and (grp_slice['Ever_DPD3Y_flag'][i] == 1):
            count_MFHL = count_MFHL + 1
        elif (grp_slice['accountType'][i] == 'MFOT') and (grp_slice['Ever_DPD3Y_flag'][i] == 1):
            count_MFOT = count_MFOT + 1
        elif (grp_slice['accountType'][i] == 'OTH') and (grp_slice['Ever_DPD3Y_flag'][i] == 1):
            count_OTH = count_OTH + 1
        elif (grp_slice['accountType'][i] == 'PL') and (grp_slice['Ever_DPD3Y_flag'][i] == 1):
            count_PL = count_PL + 1
        elif (grp_slice['accountType'][i] == 'PLBL') and (grp_slice['Ever_DPD3Y_flag'][i] == 1):
            count_PLBL = count_PLBL + 1
        elif (grp_slice['accountType'][i] == 'RL') and (grp_slice['Ever_DPD3Y_flag'][i] == 1):
            count_RL = count_RL + 1
        elif (grp_slice['accountType'][i] == 'SCC') and (grp_slice['Ever_DPD3Y_flag'][i] == 1):
            count_SCC = count_SCC + 1
        elif (grp_slice['accountType'][i] == 'SEL') and (grp_slice['Ever_DPD3Y_flag'][i] == 1):
            count_SEL = count_SEL + 1

    count_list_AL.append(count_AL)
    count_list_BL.append(count_BL)
    count_list_CC.append(count_CC)
    count_list_CD.append(count_CD)
    count_list_CV.append(count_CV)
    count_list_GL.append(count_GL)
    count_list_HL.append(count_HL)
    count_list_LAS.append(count_LAS)
    count_list_MFBL.append(count_MFBL)
    count_list_MFHL.append(count_MFHL)
    count_list_MFOT.append(count_MFOT)
    count_list_OTH.append(count_OTH)
    count_list_PL.append(count_PL)
    count_list_PLBL.append(count_PLBL)
    count_list_RL.append(count_RL)
    count_list_SCC.append(count_SCC)
    count_list_SEL.append(count_SEL)

    count_AL = 0
    count_BL = 0
    count_CC = 0
    count_CD = 0
    count_CV = 0
    count_GL = 0
    count_HL = 0
    count_LAS = 0
    count_MFBL = 0
    count_MFHL = 0
    count_MFOT = 0
    count_OTH = 0
    count_PL = 0
    count_PLBL = 0
    count_RL = 0
    count_SCC = 0
    count_SEL = 0

    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['accountType'][i] == 'unknown'):
            Ever_DPD3Y_AL.append('unknown')
            Ever_DPD3Y_BL.append('unknown')
            Ever_DPD3Y_CC.append('unknown')
            Ever_DPD3Y_CD.append('unknown')
            Ever_DPD3Y_CV.append('unknown')
            Ever_DPD3Y_GL.append('unknown')
            Ever_DPD3Y_HL.append('unknown')
            Ever_DPD3Y_LAS.append('unknown')
            Ever_DPD3Y_MFBL.append('unknown')
            Ever_DPD3Y_MFHL.append('unknown')
            Ever_DPD3Y_MFOT.append('unknown')
            Ever_DPD3Y_OTH.append('unknown')
            Ever_DPD3Y_PL.append('unknown')
            Ever_DPD3Y_PLBL.append('unknown')
            Ever_DPD3Y_RL.append('unknown')
            Ever_DPD3Y_SCC.append('unknown')
            Ever_DPD3Y_SEL.append('unknown')
        else:
            Ever_DPD3Y_AL.append(count_list_AL[x])
            Ever_DPD3Y_BL.append(count_list_BL[x])
            Ever_DPD3Y_CC.append(count_list_CC[x])
            Ever_DPD3Y_CD.append(count_list_CD[x])
            Ever_DPD3Y_CV.append(count_list_CV[x])
            Ever_DPD3Y_GL.append(count_list_GL[x])
            Ever_DPD3Y_HL.append(count_list_HL[x])
            Ever_DPD3Y_LAS.append(count_list_LAS[x])
            Ever_DPD3Y_MFBL.append(count_list_MFBL[x])
            Ever_DPD3Y_MFHL.append(count_list_MFHL[x])
            Ever_DPD3Y_MFOT.append(count_list_MFOT[x])
            Ever_DPD3Y_OTH.append(count_list_OTH[x])
            Ever_DPD3Y_PL.append(count_list_PL[x])
            Ever_DPD3Y_PLBL.append(count_list_PLBL[x])
            Ever_DPD3Y_RL.append(count_list_RL[x])
            Ever_DPD3Y_SCC.append(count_list_SCC[x])
            Ever_DPD3Y_SEL.append(count_list_SEL[x])

df['Ever_DPD3Y_AL'] = pd.Series(Ever_DPD3Y_AL).values
df['Ever_DPD3Y_BL'] = pd.Series(Ever_DPD3Y_BL).values
df['Ever_DPD3Y_CC'] = pd.Series(Ever_DPD3Y_CC).values
df['Ever_DPD3Y_CD'] = pd.Series(Ever_DPD3Y_CD).values
df['Ever_DPD3Y_CV'] = pd.Series(Ever_DPD3Y_CV).values
df['Ever_DPD3Y_GL'] = pd.Series(Ever_DPD3Y_GL).values
df['Ever_DPD3Y_HL'] = pd.Series(Ever_DPD3Y_HL).values
df['Ever_DPD3Y_LAS'] = pd.Series(Ever_DPD3Y_LAS).values
df['Ever_DPD3Y_MFBL'] = pd.Series(Ever_DPD3Y_MFBL).values
df['Ever_DPD3Y_MFHL'] = pd.Series(Ever_DPD3Y_MFHL).values
df['Ever_DPD3Y_MFOT'] = pd.Series(Ever_DPD3Y_MFOT).values
df['Ever_DPD3Y_OTH'] = pd.Series(Ever_DPD3Y_OTH).values
df['Ever_DPD3Y_PL'] = pd.Series(Ever_DPD3Y_PL).values
df['Ever_DPD3Y_PLBL'] = pd.Series(Ever_DPD3Y_PLBL).values
df['Ever_DPD3Y_RL'] = pd.Series(Ever_DPD3Y_RL).values
df['Ever_DPD3Y_SCC'] = pd.Series(Ever_DPD3Y_SCC).values
df['Ever_DPD3Y_SEL'] = pd.Series(Ever_DPD3Y_SEL).values

# %%
df.shape

# %% [markdown]
# <a id='Ever_DPD_Sec_L'></a>
# ### Ever_DPD_Sec_L
# - Count of applicants where product is secured and DPD1M_flag = 1 for all live loans
# - Count of applicants where product is secured and DPD3M_flag = 1 for all live loans
# - Count of applicants where product is secured and DPD6M_flag = 1 for all live loans
# - Count of applicants where product is secured and DPD1Y_flag = 1 for all live loans

# %%
DPD1M_flag = list()
DPD3M_flag = list()
DPD6M_flag = list()
DPD1Y_flag = list()

for x in range(0, df.shape[0]):
    if (df['DPD30P1M_flag'][x]==1) or (df['DPD60P1M_flag'][x]==1) or (df['DPD90P1M_flag'][x]==1):
        DPD1M_flag.append(1)
    elif (df['DPD30P1M_flag'][x]=='unknown') or (df['DPD60P1M_flag'][x]=='unknown') or (df['DPD90P1M_flag'][x]=='unknown'):
        DPD1M_flag.append('unknown')
    else:
        DPD1M_flag.append(0)
        
    if (df['DPD30P3M_flag'][x]==1) or (df['DPD60P3M_flag'][x]==1) or (df['DPD90P3M_flag'][x]==1):
        DPD3M_flag.append(1)
    elif (df['DPD30P3M_flag'][x]=='unknown') or (df['DPD60P3M_flag'][x]=='unknown') or (df['DPD90P3M_flag'][x]=='unknown'):
        DPD3M_flag.append('unknown')
    else:
        DPD3M_flag.append(0)
        
    if (df['DPD30P6M_flag'][x]==1) or (df['DPD60P6M_flag'][x]==1) or (df['DPD90P6M_flag'][x]==1):
        DPD6M_flag.append(1)
    elif (df['DPD30P6M_flag'][x]=='unknown') or (df['DPD60P6M_flag'][x]=='unknown') or (df['DPD90P6M_flag'][x]=='unknown'):
        DPD6M_flag.append('unknown')
    else:
        DPD6M_flag.append(0)

    if (df['DPD30P1Y_flag'][x]==1) or (df['DPD60P1Y_flag'][x]==1) or (df['DPD90P1Y_flag'][x]==1):
        DPD1Y_flag.append(1)
    elif (df['DPD30P1Y_flag'][x]=='unknown') or (df['DPD60P1Y_flag'][x]=='unknown') or (df['DPD90P1Y_flag'][x]=='unknown'):
        DPD1Y_flag.append('unknown')
    else:
        DPD1Y_flag.append(0)

df['DPD1M_flag'] = pd.Series(DPD1M_flag).values        
df['DPD3M_flag'] = pd.Series(DPD3M_flag).values
df['DPD6M_flag'] = pd.Series(DPD6M_flag).values
df['DPD1Y_flag'] = pd.Series(DPD1Y_flag).values

#print(len(DPD1M_flag))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/envs/ml_env/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'DPD30P1M_flag'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-237-1d574d226aa4> in <module>
#       5
#       6 for x in range(0, df.shape[0]):
# ----> 7     if (df['DPD30P1M_flag'][x]==1) or (df['DPD60P1M_flag'][x]==1) or (df['DPD90P1M_flag'][x]==1):
#       8         DPD1M_flag.append(1)
#       9     elif (df['DPD30P1M_flag'][x]=='unknown') or (df['DPD60P1M_flag'][x]=='unknown') or (df['DPD90P1M_flag'][x]=='unknown'):
#
# ~/anaconda3/envs/ml_env/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2900             if self.columns.nlevels > 1:
#    2901                 return self._getitem_multilevel(key)
# -> 2902             indexer = self.columns.get_loc(key)
#    2903             if is_integer(indexer):
#    2904                 indexer = [indexer]
#
# ~/anaconda3/envs/ml_env/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
# -> 2897                 raise KeyError(key) from err
#    2898
#    2899         if tolerance is not None:
#
# KeyError: 'DPD30P1M_flag'

# %%
Ever_DPD_Sec_L_1mnth_flag = list()
Ever_DPD_Sec_L_3mnth_flag = list()
Ever_DPD_Sec_L_6mnth_flag = list()
Ever_DPD_Sec_L_1yr_flag = list()

accountTypeSec = [1,2,3,4,7,11,13,15,16,17,31,32,33,34,42,43,44,50,54,58,59,0,98]

for x in range(0, df.shape[0]):
    if (df['accountType'][x] in accountTypeSec) and (df['DPD1M_flag'][x]==1) and (df['dateClosed'][x]=='unknown'):
        Ever_DPD_Sec_L_1mnth_flag.append(1)
    elif (df['accountType'][x]=='unknown') and (df['DPD1M_flag'][x]=='unknown'):
        Ever_DPD_Sec_L_1mnth_flag.append('unknown')
    else:
        Ever_DPD_Sec_L_1mnth_flag.append(0)
    
    if (df['accountType'][x] in accountTypeSec) and (df['DPD3M_flag'][x]==1) and (df['dateClosed'][x]=='unknown'):
        Ever_DPD_Sec_L_3mnth_flag.append(1)
    elif (df['accountType'][x]=='unknown') and (df['DPD3M_flag'][x]=='unknown'):
        Ever_DPD_Sec_L_3mnth_flag.append('unknown')
    else:
        Ever_DPD_Sec_L_3mnth_flag.append(0)
    
    if (df['accountType'][x] in accountTypeSec) and (df['DPD6M_flag'][x]==1) and (df['dateClosed'][x]=='unknown'):
        Ever_DPD_Sec_L_6mnth_flag.append(1)
    elif (df['accountType'][x]=='unknown') and (df['DPD6M_flag'][x]=='unknown'):
        Ever_DPD_Sec_L_6mnth_flag.append('unknown')
    else:
        Ever_DPD_Sec_L_6mnth_flag.append(0)
    
    if (df['accountType'][x] in accountTypeSec) and (df['DPD1Y_flag'][x]==1) and (df['dateClosed'][x]=='unknown'):
        Ever_DPD_Sec_L_1yr_flag.append(1)
    elif (df['accountType'][x]=='unknown') and (df['DPD1Y_flag'][x]=='unknown'):
        Ever_DPD_Sec_L_1yr_flag.append('unknown')
    else:
        Ever_DPD_Sec_L_1yr_flag.append(0)
        
df['Ever_DPD_Sec_L_1mnth_flag'] = pd.Series(Ever_DPD_Sec_L_1mnth_flag).values        
df['Ever_DPD_Sec_L_3mnth_flag'] = pd.Series(Ever_DPD_Sec_L_3mnth_flag).values
df['Ever_DPD_Sec_L_6mnth_flag'] = pd.Series(Ever_DPD_Sec_L_6mnth_flag).values
df['Ever_DPD_Sec_L_1yr_flag'] = pd.Series(Ever_DPD_Sec_L_1yr_flag).values    

#print(len(Ever_DPD_Sec_L_1mnth_flag))

# %%
start_time = time.time()    #You can use time.clock() also

Ever_DPD_Sec_L_1mnth = list()
count_list_1m = list()
count_1m = 0

Ever_DPD_Sec_L_3mnth = list()
count_list_3m = list()
count_3m = 0

Ever_DPD_Sec_L_6mnth = list()
count_list_6m = list()
count_6m = 0

Ever_DPD_Sec_L_1yr = list()
count_list_1y = list()
count_1y = 0

grp_df = df.groupby('ID')

for x in range(0, len(unq_id_list)):
    grp_slice = grp_df.get_group(unq_id_list[x])
    #print(grp_slice)
    grp_slice.reset_index(drop=True, inplace=True)
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['Ever_DPD_Sec_L_1mnth_flag'][i]==1) or (grp_slice['Ever_DPD_Sec_L_1mnth_flag'][i]==0):
            count_1m = count_1m + grp_slice['Ever_DPD_Sec_L_1mnth_flag'][i]
        
        if (grp_slice['Ever_DPD_Sec_L_3mnth_flag'][i]==1) or (grp_slice['Ever_DPD_Sec_L_3mnth_flag'][i]==0):
            count_3m = count_3m + grp_slice['Ever_DPD_Sec_L_3mnth_flag'][i]

        if (grp_slice['Ever_DPD_Sec_L_6mnth_flag'][i]==1) or (grp_slice['Ever_DPD_Sec_L_6mnth_flag'][i]==0):
            count_6m = count_6m + grp_slice['Ever_DPD_Sec_L_6mnth_flag'][i]

        if (grp_slice['Ever_DPD_Sec_L_1yr_flag'][i]==1) or (grp_slice['Ever_DPD_Sec_L_1yr_flag'][i]==0):
            count_1y = count_1y + grp_slice['Ever_DPD_Sec_L_1yr_flag'][i]

    count_list_1m.append(count_1m)
    count_1m = 0
    count_list_3m.append(count_3m)
    count_3m = 0
    count_list_6m.append(count_6m)
    count_6m = 0
    count_list_1y.append(count_1y)
    count_1y = 0

    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['Ever_DPD_Sec_L_1mnth_flag'][i]==1) or (grp_slice['Ever_DPD_Sec_L_1mnth_flag'][i]==0):
            Ever_DPD_Sec_L_1mnth.append(count_list_1m[x])
        else:
            Ever_DPD_Sec_L_1mnth.append('unknown')

        if (grp_slice['Ever_DPD_Sec_L_3mnth_flag'][i]==1) or (grp_slice['Ever_DPD_Sec_L_3mnth_flag'][i]==0):
            Ever_DPD_Sec_L_3mnth.append(count_list_3m[x])
        else:
            Ever_DPD_Sec_L_3mnth.append('unknown')

        if (grp_slice['Ever_DPD_Sec_L_6mnth_flag'][i]==1) or (grp_slice['Ever_DPD_Sec_L_6mnth_flag'][i]==0):
            Ever_DPD_Sec_L_6mnth.append(count_list_6m[x])
        else:
            Ever_DPD_Sec_L_6mnth.append('unknown')

        if (grp_slice['Ever_DPD_Sec_L_1yr_flag'][i]==1) or (grp_slice['Ever_DPD_Sec_L_1yr_flag'][i]==0):
            Ever_DPD_Sec_L_1yr.append(count_list_6m[x])
        else:
            Ever_DPD_Sec_L_1yr.append('unknown')
            
df['Ever_DPD_Sec_L_1mnth'] = pd.Series(Ever_DPD_Sec_L_1mnth).values
df['Ever_DPD_Sec_L_3mnth'] = pd.Series(Ever_DPD_Sec_L_3mnth).values
df['Ever_DPD_Sec_L_6mnth'] = pd.Series(Ever_DPD_Sec_L_6mnth).values
df['Ever_DPD_Sec_L_1yr'] = pd.Series(Ever_DPD_Sec_L_1yr).values

print("%s seconds" % (time.time() - start_time))

# %%
df.shape

# %% [markdown]
# <a id='Ever_DPD_UnsecwoRLCC_L'></a>
# ### Ever_DPD_UnsecwoRLCC_L
# - Count of applicants where product is unsecured and DPD1M_flag = 1 for all live loans
# - Count of applicants where product is unsecured and DPD3M_flag = 1 for all live loans
# - Count of applicants where product is unsecured and DPD6M_flag = 1 for all live loans
# - Count of applicants where product is unsecured and DPD1Y_flag = 1 for all live loans

# %%
Ever_DPD_UnsecwoRLCC_L_1mnth_flag = list()
Ever_DPD_UnsecwoRLCC_L_3mnth_flag = list()
Ever_DPD_UnsecwoRLCC_L_6mnth_flag = list()
Ever_DPD_UnsecwoRLCC_L_1yr_flag = list()

accountTypeUnsec = [5,6,8,9,10,12,14,35,36,37,38,39,40,41,51,52,53,55,56,57,61,99]

for x in range(0, df.shape[0]):
    if (df['accountType'][x] in accountTypeUnsec) and (df['DPD1M_flag'][x] == 1) and (df['dateClosed'][x] == 'unknown'):
        Ever_DPD_UnsecwoRLCC_L_1mnth_flag.append(1)
    elif (df['accountType'][x] == 'unknown') and (df['DPD1M_flag'][x] == 'unknown'):
        Ever_DPD_UnsecwoRLCC_L_1mnth_flag.append('unknown')
    else:
        Ever_DPD_UnsecwoRLCC_L_1mnth_flag.append(0)

    if (df['accountType'][x] in accountTypeUnsec) and (df['DPD3M_flag'][x] == 1) and (df['dateClosed'][x] == 'unknown'):
        Ever_DPD_UnsecwoRLCC_L_3mnth_flag.append(1)
    elif (df['accountType'][x] == 'unknown') and (df['DPD3M_flag'][x] == 'unknown'):
        Ever_DPD_UnsecwoRLCC_L_3mnth_flag.append('unknown')
    else:
        Ever_DPD_UnsecwoRLCC_L_3mnth_flag.append(0)

    if (df['accountType'][x] in accountTypeUnsec) and (df['DPD6M_flag'][x] == 1) and (df['dateClosed'][x] == 'unknown'):
        Ever_DPD_UnsecwoRLCC_L_6mnth_flag.append(1)
    elif (df['accountType'][x] == 'unknown') and (df['DPD6M_flag'][x] == 'unknown'):
        Ever_DPD_UnsecwoRLCC_L_6mnth_flag.append('unknown')
    else:
        Ever_DPD_UnsecwoRLCC_L_6mnth_flag.append(0)

    if (df['accountType'][x] in accountTypeUnsec) and (df['DPD1Y_flag'][x] == 1) and (df['dateClosed'][x] == 'unknown'):
        Ever_DPD_UnsecwoRLCC_L_1yr_flag.append(1)
    elif (df['accountType'][x] == 'unknown') and (df['DPD1Y_flag'][x] == 'unknown'):
        Ever_DPD_UnsecwoRLCC_L_1yr_flag.append('unknown')
    else:
        Ever_DPD_UnsecwoRLCC_L_1yr_flag.append(0)

df['Ever_DPD_UnsecwoRLCC_L_1mnth_flag'] = pd.Series(Ever_DPD_UnsecwoRLCC_L_1mnth_flag).values
df['Ever_DPD_UnsecwoRLCC_L_3mnth_flag'] = pd.Series(Ever_DPD_UnsecwoRLCC_L_3mnth_flag).values
df['Ever_DPD_UnsecwoRLCC_L_6mnth_flag'] = pd.Series(Ever_DPD_UnsecwoRLCC_L_6mnth_flag).values
df['Ever_DPD_UnsecwoRLCC_L_1yr_flag'] = pd.Series(Ever_DPD_UnsecwoRLCC_L_1yr_flag).values

# print(len(Ever_DPD_UnsecwoRLCC_L_1mnth_flag))

# %%
Ever_DPD_UnsecwoRLCC_L_1mnth = list()
count_list_1m = list()
count_1m = 0

Ever_DPD_UnsecwoRLCC_L_3mnth = list()
count_list_3m = list()
count_3m = 0

Ever_DPD_UnsecwoRLCC_L_6mnth = list()
count_list_6m = list()
count_6m = 0

Ever_DPD_UnsecwoRLCC_L_1yr = list()
count_list_1y = list()
count_1y = 0

grp_df = df.groupby('ID')

for x in range(0, len(unq_id_list)):
    grp_slice = grp_df.get_group(unq_id_list[x])
    #print(grp_slice)
    grp_slice.reset_index(drop=True, inplace=True)
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['Ever_DPD_UnsecwoRLCC_L_1mnth_flag'][i]==1) or (grp_slice['Ever_DPD_UnsecwoRLCC_L_1mnth_flag'][i]==0):
            count_1m = count_1m + grp_slice['Ever_DPD_UnsecwoRLCC_L_1mnth_flag'][i]
        
        if (grp_slice['Ever_DPD_UnsecwoRLCC_L_3mnth_flag'][i]==1) or (grp_slice['Ever_DPD_UnsecwoRLCC_L_3mnth_flag'][i]==0):
            count_3m = count_3m + grp_slice['Ever_DPD_UnsecwoRLCC_L_3mnth_flag'][i]

        if (grp_slice['Ever_DPD_UnsecwoRLCC_L_6mnth_flag'][i]==1) or (grp_slice['Ever_DPD_UnsecwoRLCC_L_6mnth_flag'][i]==0):
            count_6m = count_6m + grp_slice['Ever_DPD_UnsecwoRLCC_L_6mnth_flag'][i]

        if (grp_slice['Ever_DPD_UnsecwoRLCC_L_1yr_flag'][i]==1) or (grp_slice['Ever_DPD_UnsecwoRLCC_L_1yr_flag'][i]==0):
            count_1y = count_1y + grp_slice['Ever_DPD_UnsecwoRLCC_L_1yr_flag'][i]

    count_list_1m.append(count_1m)
    count_1m = 0
    count_list_3m.append(count_3m)
    count_3m = 0
    count_list_6m.append(count_6m)
    count_6m = 0
    count_list_1y.append(count_1y)
    count_1y = 0

    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['Ever_DPD_UnsecwoRLCC_L_1mnth_flag'][i]==1) or (grp_slice['Ever_DPD_UnsecwoRLCC_L_1mnth_flag'][i]==0):
            Ever_DPD_UnsecwoRLCC_L_1mnth.append(count_list_1m[x])
        else:
            Ever_DPD_UnsecwoRLCC_L_1mnth.append('unknown')

        if (grp_slice['Ever_DPD_UnsecwoRLCC_L_3mnth_flag'][i]==1) or (grp_slice['Ever_DPD_UnsecwoRLCC_L_3mnth_flag'][i]==0):
            Ever_DPD_UnsecwoRLCC_L_3mnth.append(count_list_3m[x])
        else:
            Ever_DPD_UnsecwoRLCC_L_3mnth.append('unknown')

        if (grp_slice['Ever_DPD_UnsecwoRLCC_L_6mnth_flag'][i]==1) or (grp_slice['Ever_DPD_UnsecwoRLCC_L_6mnth_flag'][i]==0):
            Ever_DPD_UnsecwoRLCC_L_6mnth.append(count_list_6m[x])
        else:
            Ever_DPD_UnsecwoRLCC_L_6mnth.append('unknown')

        if (grp_slice['Ever_DPD_UnsecwoRLCC_L_1yr_flag'][i]==1) or (grp_slice['Ever_DPD_UnsecwoRLCC_L_1yr_flag'][i]==0):
            Ever_DPD_UnsecwoRLCC_L_1yr.append(count_list_6m[x])
        else:
            Ever_DPD_UnsecwoRLCC_L_1yr.append('unknown')
            
df['Ever_DPD_UnsecwoRLCC_L_1mnth'] = pd.Series(Ever_DPD_UnsecwoRLCC_L_1mnth).values
df['Ever_DPD_UnsecwoRLCC_L_3mnth'] = pd.Series(Ever_DPD_UnsecwoRLCC_L_3mnth).values
df['Ever_DPD_UnsecwoRLCC_L_6mnth'] = pd.Series(Ever_DPD_UnsecwoRLCC_L_6mnth).values
df['Ever_DPD_UnsecwoRLCC_L_1yr'] = pd.Series(Ever_DPD_UnsecwoRLCC_L_1yr).values

# %%
df.shape

# %% [markdown]
# <a id='writeOff_restructured'></a>
# ### Code for writeOff and restructured

# %% [markdown]
# **writeOff**
# - Indicates that the account is written off and/ or settled
# - If Written-off and Settled Status not equals (00,01), then 1 else 0

# %% [markdown]
# **restructured**
# - Indicates that the account is restructured
# - If Written-off and Settled Status equals (00,01), then 1 else 0

# %%
df['writtenOffAndSettledStatus'].fillna('unknown', inplace=True)

# %%
df['writtenOffAndSettledStatus'].value_counts()

# %%
start_time = time.time()

writeOff = list()
restructured = list()

for value in df['writtenOffAndSettledStatus']:
    # print(value)
    if (value == 0) or (value == 1):
        # print(value)
        restructured.append(1)
    elif (value == 'unknown'):
        restructured.append('unknown')
    else:
        restructured.append(0)

    if (value!=0) and (value!=1) and (value!='unknown'):
        #print(value)
        writeOff.append(1)
    elif (value=='unknown'):
        writeOff.append('unknown')
    else:
        writeOff.append(0)

df['writeOff'] = pd.Series(writeOff).values
df['restructured'] = pd.Series(restructured).values

#print(df['writeOff'].value_counts())
#print(df['restructured'].value_counts())

print("%s seconds" % (time.time() - start_time))

# %% [markdown]
# ### Code for writeOff_CNT and restructured_CNT

# %% [markdown]
# **writeOff_CNT**
# - Count of all the written off and/ or settled accounts for the applicant<br>
# - Sum(wo_set_flg) for the applicant

# %% [markdown]
# **restructured_CNT**
# - Count of all the restructured accounts for the applicant
# - Sum(res_flg) for the applicant

# %%
writeOff_CNT = list()
count_list_wo = list()
count_wo = 0

restructured_CNT = list()
count_list_re = list()
count_re = 0

grp_df = df.groupby('ID')

for x in range(0, len(unq_id_list)):
    grp_slice = grp_df.get_group(unq_id_list[x])
    # print(grp_slice)
    grp_slice.reset_index(drop=True, inplace=True)
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['writeOff'][i] == 1) or (grp_slice['writeOff'][i] == 0):
            count_wo = count_wo + grp_slice['writeOff'][i]
        else:
            continue

        if (grp_slice['restructured'][i] == 1) or (grp_slice['restructured'][i] == 0):
            count_re = count_re + grp_slice['restructured'][i]
        else:
            continue

    count_list_wo.append(count_wo)
    count_wo = 0

    count_list_re.append(count_re)
    count_re = 0

    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['writeOff'][i] == 1) or (grp_slice['writeOff'][i] == 0):
            writeOff_CNT.append(count_list_wo[x])
        else:
            writeOff_CNT.append('unknown')

        if (grp_slice['restructured'][i] == 1) or (grp_slice['restructured'][i] == 0):
            restructured_CNT.append(count_list_re[x])
        else:
            restructured_CNT.append('unknown')

df['writeOff_CNT'] = pd.Series(writeOff_CNT).values
df['restructured_CNT'] = pd.Series(restructured_CNT).values

#print(df['writeOff_CNT'].value_counts())
#print(df['restructured_CNT'].value_counts())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/envs/ml_env/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'writeOff'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-239-03c166487b93> in <module>
#      14     grp_slice.reset_index(drop=True, inplace=True)
#      15     for i in range(0, grp_slice.shape[0]):
# ---> 16         if (grp_slice['writeOff'][i] == 1) or (grp_slice['writeOff'][i] == 0):
#      17             count_wo = count_wo + grp_slice['writeOff'][i]
#      18         else:
#
# ~/anaconda3/envs/ml_env/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2900             if self.columns.nlevels > 1:
#    2901                 return self._getitem_multilevel(key)
# -> 2902             indexer = self.columns.get_loc(key)
#    2903             if is_integer(indexer):
#    2904                 indexer = [indexer]
#
# ~/anaconda3/envs/ml_env/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
# -> 2897                 raise KeyError(key) from err
#    2898
#    2899         if tolerance is not None:
#
# KeyError: 'writeOff'

# %% [markdown]
# ### Code for writeOff_CNT_P

# %% [markdown]
# - Count of all the written off and/ or settled accounts for the applicant per product
# - Sum(wo_set_flg) for the applicant per product

# %%
bureau_accType_dict = {0: "OTH", 1: "AL", 2: "HL", 3: "HL", 4: "LAS", 5: "PL", 6: "CD",
                      7: "GL", 8: "PL", 9: "SEL", 10: "CC", 11: "HL", 12: "RL",
                      13: "AL", 14: "RL", 15: "LAS", 16: "CV", 17: "CV", 
                      31: "CC", 32: "AL", 33: "CV", 34: "CV", 35: "SCC", 36: "SCC",
                      37: "PL", 38: "RL", 39: "BL", 40: "MFBL", 41: "MFPL", 42: "MFHL",
                      43: "MFOT", 44: "HL", 50: "BL", 51: "BL", 52: "PLBL", 53: "PLBL",
                      54: "PLBL", 55: "RL", 56: "PLRLBL", 57: "PLRLBL", 58: "PLRLBL",
                      59: "BL", 61: "BL", 98: "SEC", 99: "UNSEC"}

# %%
df = df.replace({"accountType": bureau_accType_dict})

df['accountType'].fillna('unknown', inplace=True)

# %% [raw]
# d = df[['ID','writeOff','writeOff_CNT','accountType']]
# d[d['writeOff']!='unknown'].head(10)

# %% [raw]
# df = pd.get_dummies(df, columns=['accountType'], drop_first=False)

# %% [raw]
# df[df.columns[47:]].head(2)

# %%
writeOff_CNT_AL = list()
writeOff_CNT_BL = list()
writeOff_CNT_CC = list()
writeOff_CNT_CD = list()
writeOff_CNT_CV = list()
writeOff_CNT_GL = list()
writeOff_CNT_HL = list()
writeOff_CNT_LAS = list()
writeOff_CNT_MFBL = list()
writeOff_CNT_MFHL = list()
writeOff_CNT_MFOT = list()
writeOff_CNT_OTH = list()
writeOff_CNT_PL = list()
writeOff_CNT_PLBL = list()
writeOff_CNT_RL = list()
writeOff_CNT_SCC = list()
writeOff_CNT_SEL = list()

count_list_AL = list()
count_list_BL = list()
count_list_CC = list()
count_list_CD = list()
count_list_CV = list()
count_list_GL = list()
count_list_HL = list()
count_list_LAS = list()
count_list_MFBL = list()
count_list_MFHL = list()
count_list_MFOT = list()
count_list_OTH = list()
count_list_PL = list()
count_list_PLBL = list()
count_list_RL = list()
count_list_SCC = list()
count_list_SEL = list()

count_AL = 0
count_BL = 0
count_CC = 0
count_CD = 0
count_CV = 0
count_GL = 0
count_HL = 0
count_LAS = 0
count_MFBL = 0
count_MFHL = 0
count_MFOT = 0
count_OTH = 0
count_PL = 0 
count_PLBL = 0
count_RL = 0
count_SCC = 0
count_SEL = 0

grp_df = df.groupby('ID')

for x in range(0, len(unq_id_list)):
    grp_slice = grp_df.get_group(unq_id_list[x])
    #print(grp_slice)
    grp_slice.reset_index(drop=True, inplace=True)
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['accountType'][i]=='unknown') or (grp_slice['writeOff'][i]=='unknown'):
            continue
        elif (grp_slice['accountType'][i]=='AL') and (grp_slice['writeOff'][i]==1):
            count_AL = count_AL + 1
        elif (grp_slice['accountType'][i]=='BL') and (grp_slice['writeOff'][i]==1):
            count_BL = count_BL + 1
        elif (grp_slice['accountType'][i]=='CC') and (grp_slice['writeOff'][i]==1):
            count_CC = count_CC + 1
        elif (grp_slice['accountType'][i]=='CD') and (grp_slice['writeOff'][i]==1):
            count_CD = count_CD + 1
        elif (grp_slice['accountType'][i]=='CV') and (grp_slice['writeOff'][i]==1):
            count_CV = count_CV + 1
        elif (grp_slice['accountType'][i]=='GL') and (grp_slice['writeOff'][i]==1):
            count_GL = count_GL + 1
        elif (grp_slice['accountType'][i]=='HL') and (grp_slice['writeOff'][i]==1):
            count_HL = count_HL + 1
        elif (grp_slice['accountType'][i]=='LAS') and (grp_slice['writeOff'][i]==1):
            count_LAS = count_LAS + 1
        elif (grp_slice['accountType'][i]=='MFBL') and (grp_slice['writeOff'][i]==1):
            count_MFBL = count_MFBL + 1
        elif (grp_slice['accountType'][i]=='MFHL') and (grp_slice['writeOff'][i]==1):
            count_MFHL = count_MFHL + 1
        elif (grp_slice['accountType'][i]=='MFOT') and (grp_slice['writeOff'][i]==1):
            count_MFOT = count_MFOT + 1
        elif (grp_slice['accountType'][i]=='OTH') and (grp_slice['writeOff'][i]==1):
            count_OTH = count_OTH + 1
        elif (grp_slice['accountType'][i]=='PL') and (grp_slice['writeOff'][i]==1):
            count_PL = count_PL + 1
        elif (grp_slice['accountType'][i]=='PLBL') and (grp_slice['writeOff'][i]==1):
            count_PLBL = count_PLBL + 1
        elif (grp_slice['accountType'][i]=='RL') and (grp_slice['writeOff'][i]==1):
            count_RL = count_RL + 1
        elif (grp_slice['accountType'][i]=='SCC') and (grp_slice['writeOff'][i]==1):
            count_SCC = count_SCC + 1
        elif (grp_slice['accountType'][i]=='SEL') and (grp_slice['writeOff'][i]==1):
            count_SEL = count_SEL + 1
            
    count_list_AL.append(count_AL)
    count_list_BL.append(count_BL)
    count_list_CC.append(count_CC)
    count_list_CD.append(count_CD)
    count_list_CV.append(count_CV)
    count_list_GL.append(count_GL)
    count_list_HL.append(count_HL)
    count_list_LAS.append(count_LAS)
    count_list_MFBL.append(count_MFBL)
    count_list_MFHL.append(count_MFHL)
    count_list_MFOT.append(count_MFOT)
    count_list_OTH.append(count_OTH)
    count_list_PL.append(count_PL)
    count_list_PLBL.append(count_PLBL)
    count_list_RL.append(count_RL)
    count_list_SCC.append(count_SCC)
    count_list_SEL.append(count_SEL)
    
    count_AL = 0
    count_BL = 0
    count_CC = 0
    count_CD = 0
    count_CV = 0
    count_GL = 0
    count_HL = 0
    count_LAS = 0
    count_MFBL = 0
    count_MFHL = 0
    count_MFOT = 0
    count_OTH = 0
    count_PL = 0
    count_PLBL = 0
    count_RL = 0
    count_SCC = 0
    count_SEL = 0
    
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['accountType'][i]=='unknown') or (grp_slice['writeOff'][i]=='unknown'):
            writeOff_CNT_AL.append('unknown')
            writeOff_CNT_BL.append('unknown')
            writeOff_CNT_CC.append('unknown')
            writeOff_CNT_CD.append('unknown')
            writeOff_CNT_CV.append('unknown')
            writeOff_CNT_GL.append('unknown')
            writeOff_CNT_HL.append('unknown')
            writeOff_CNT_LAS.append('unknown')
            writeOff_CNT_MFBL.append('unknown')
            writeOff_CNT_MFHL.append('unknown')
            writeOff_CNT_MFOT.append('unknown')
            writeOff_CNT_OTH.append('unknown')
            writeOff_CNT_PL.append('unknown')
            writeOff_CNT_PLBL.append('unknown')
            writeOff_CNT_RL.append('unknown')
            writeOff_CNT_SCC.append('unknown')
            writeOff_CNT_SEL.append('unknown')
        else:
            writeOff_CNT_AL.append(count_list_AL[x])
            writeOff_CNT_BL.append(count_list_BL[x])
            writeOff_CNT_CC.append(count_list_CC[x])
            writeOff_CNT_CD.append(count_list_CD[x])
            writeOff_CNT_CV.append(count_list_CV[x])
            writeOff_CNT_GL.append(count_list_GL[x])
            writeOff_CNT_HL.append(count_list_HL[x])
            writeOff_CNT_LAS.append(count_list_LAS[x])
            writeOff_CNT_MFBL.append(count_list_MFBL[x])
            writeOff_CNT_MFHL.append(count_list_MFHL[x])
            writeOff_CNT_MFOT.append(count_list_MFOT[x])
            writeOff_CNT_OTH.append(count_list_OTH[x])
            writeOff_CNT_PL.append(count_list_PL[x])
            writeOff_CNT_PLBL.append(count_list_PLBL[x])
            writeOff_CNT_RL.append(count_list_RL[x])
            writeOff_CNT_SCC.append(count_list_SCC[x])
            writeOff_CNT_SEL.append(count_list_SEL[x])
            
df['writeOff_CNT_AL'] = pd.Series(writeOff_CNT_AL).values
df['writeOff_CNT_BL'] = pd.Series(writeOff_CNT_BL).values
df['writeOff_CNT_CC'] = pd.Series(writeOff_CNT_CC).values
df['writeOff_CNT_CD'] = pd.Series(writeOff_CNT_CD).values
df['writeOff_CNT_CV'] = pd.Series(writeOff_CNT_CV).values
df['writeOff_CNT_GL'] = pd.Series(writeOff_CNT_GL).values
df['writeOff_CNT_HL'] = pd.Series(writeOff_CNT_HL).values
df['writeOff_CNT_LAS'] = pd.Series(writeOff_CNT_LAS).values
df['writeOff_CNT_MFBL'] = pd.Series(writeOff_CNT_MFBL).values
df['writeOff_CNT_MFHL'] = pd.Series(writeOff_CNT_MFHL).values
df['writeOff_CNT_MFOT'] = pd.Series(writeOff_CNT_MFOT).values
df['writeOff_CNT_OTH'] = pd.Series(writeOff_CNT_OTH).values
df['writeOff_CNT_PL'] = pd.Series(writeOff_CNT_PL).values
df['writeOff_CNT_PLBL'] = pd.Series(writeOff_CNT_PLBL).values
df['writeOff_CNT_RL'] = pd.Series(writeOff_CNT_RL).values
df['writeOff_CNT_SCC'] = pd.Series(writeOff_CNT_SCC).values
df['writeOff_CNT_SEL'] = pd.Series(writeOff_CNT_SEL).values
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/envs/ml_env/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'writeOff'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-240-b2235f502898> in <module>
#      60     grp_slice.reset_index(drop=True, inplace=True)
#      61     for i in range(0, grp_slice.shape[0]):
# ---> 62         if (grp_slice['accountType'][i]=='unknown') or (grp_slice['writeOff'][i]=='unknown'):
#      63             continue
#      64         elif (grp_slice['accountType'][i]=='AL') and (grp_slice['writeOff'][i]==1):
#
# ~/anaconda3/envs/ml_env/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2900             if self.columns.nlevels > 1:
#    2901                 return self._getitem_multilevel(key)
# -> 2902             indexer = self.columns.get_loc(key)
#    2903             if is_integer(indexer):
#    2904                 indexer = [indexer]
#
# ~/anaconda3/envs/ml_env/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
# -> 2897                 raise KeyError(key) from err
#    2898
#    2899         if tolerance is not None:
#
# KeyError: 'writeOff'

# %% [raw]
# d = df[['ID','writeOff','writeOff_CNT_AL','writeOff_CNT_BL','writeOff_CNT_CC','accountType']]
# d[d['writeOff']!='unknown'].head(10)

# %% [raw]
# df[df['writeOff_CNT_AL']==2][['ID','writeOff_CNT_AL','writeOff','accountType']]

# %% [markdown]
# ### Code for restructured_CNT_P

# %% [markdown]
# - Count of all the restructured accounts for the applicant per product
# - Sum(res_flg) for the applicant per product

# %%
restructured_CNT_AL = list()
restructured_CNT_BL = list()
restructured_CNT_CC = list()
restructured_CNT_CD = list()
restructured_CNT_CV = list()
restructured_CNT_GL = list()
restructured_CNT_HL = list()
restructured_CNT_LAS = list()
restructured_CNT_MFBL = list()
restructured_CNT_MFHL = list()
restructured_CNT_MFOT = list()
restructured_CNT_OTH = list()
restructured_CNT_PL = list()
restructured_CNT_PLBL = list()
restructured_CNT_RL = list()
restructured_CNT_SCC = list()
restructured_CNT_SEL = list()

count_list_AL = list()
count_list_BL = list()
count_list_CC = list()
count_list_CD = list()
count_list_CV = list()
count_list_GL = list()
count_list_HL = list()
count_list_LAS = list()
count_list_MFBL = list()
count_list_MFHL = list()
count_list_MFOT = list()
count_list_OTH = list()
count_list_PL = list()
count_list_PLBL = list()
count_list_RL = list()
count_list_SCC = list()
count_list_SEL = list()

count_AL = 0
count_BL = 0
count_CC = 0
count_CD = 0
count_CV = 0
count_GL = 0
count_HL = 0
count_LAS = 0
count_MFBL = 0
count_MFHL = 0
count_MFOT = 0
count_OTH = 0
count_PL = 0 
count_PLBL = 0
count_RL = 0
count_SCC = 0
count_SEL = 0

grp_df = df.groupby('ID')

for x in range(0, len(unq_id_list)):
    grp_slice = grp_df.get_group(unq_id_list[x])
    #print(grp_slice)
    grp_slice.reset_index(drop=True, inplace=True)
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['accountType'][i]=='unknown') or (grp_slice['restructured'][i]=='unknown'):
            continue
        elif (grp_slice['accountType'][i]=='AL') and (grp_slice['restructured'][i]==1):
            count_AL = count_AL + 1
        elif (grp_slice['accountType'][i]=='BL') and (grp_slice['restructured'][i]==1):
            count_BL = count_BL + 1
        elif (grp_slice['accountType'][i]=='CC') and (grp_slice['restructured'][i]==1):
            count_CC = count_CC + 1
        elif (grp_slice['accountType'][i]=='CD') and (grp_slice['restructured'][i]==1):
            count_CD = count_CD + 1
        elif (grp_slice['accountType'][i]=='CV') and (grp_slice['restructured'][i]==1):
            count_CV = count_CV + 1
        elif (grp_slice['accountType'][i]=='GL') and (grp_slice['restructured'][i]==1):
            count_GL = count_GL + 1
        elif (grp_slice['accountType'][i]=='HL') and (grp_slice['restructured'][i]==1):
            count_HL = count_HL + 1
        elif (grp_slice['accountType'][i]=='LAS') and (grp_slice['restructured'][i]==1):
            count_LAS = count_LAS + 1
        elif (grp_slice['accountType'][i]=='MFBL') and (grp_slice['restructured'][i]==1):
            count_MFBL = count_MFBL + 1
        elif (grp_slice['accountType'][i]=='MFHL') and (grp_slice['restructured'][i]==1):
            count_MFHL = count_MFHL + 1
        elif (grp_slice['accountType'][i]=='MFOT') and (grp_slice['restructured'][i]==1):
            count_MFOT = count_MFOT + 1
        elif (grp_slice['accountType'][i]=='OTH') and (grp_slice['restructured'][i]==1):
            count_OTH = count_OTH + 1
        elif (grp_slice['accountType'][i]=='PL') and (grp_slice['restructured'][i]==1):
            count_PL = count_PL + 1
        elif (grp_slice['accountType'][i]=='PLBL') and (grp_slice['restructured'][i]==1):
            count_PLBL = count_PLBL + 1
        elif (grp_slice['accountType'][i]=='RL') and (grp_slice['restructured'][i]==1):
            count_RL = count_RL + 1
        elif (grp_slice['accountType'][i]=='SCC') and (grp_slice['restructured'][i]==1):
            count_SCC = count_SCC + 1
        elif (grp_slice['accountType'][i]=='SEL') and (grp_slice['restructured'][i]==1):
            count_SEL = count_SEL + 1
            
    count_list_AL.append(count_AL)
    count_list_BL.append(count_BL)
    count_list_CC.append(count_CC)
    count_list_CD.append(count_CD)
    count_list_CV.append(count_CV)
    count_list_GL.append(count_GL)
    count_list_HL.append(count_HL)
    count_list_LAS.append(count_LAS)
    count_list_MFBL.append(count_MFBL)
    count_list_MFHL.append(count_MFHL)
    count_list_MFOT.append(count_MFOT)
    count_list_OTH.append(count_OTH)
    count_list_PL.append(count_PL)
    count_list_PLBL.append(count_PLBL)
    count_list_RL.append(count_RL)
    count_list_SCC.append(count_SCC)
    count_list_SEL.append(count_SEL)
    
    count_AL = 0
    count_BL = 0
    count_CC = 0
    count_CD = 0
    count_CV = 0
    count_GL = 0
    count_HL = 0
    count_LAS = 0
    count_MFBL = 0
    count_MFHL = 0
    count_MFOT = 0
    count_OTH = 0
    count_PL = 0
    count_PLBL = 0
    count_RL = 0
    count_SCC = 0
    count_SEL = 0
    
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['accountType'][i]=='unknown') or (grp_slice['restructured'][i]=='unknown'):
            restructured_CNT_AL.append('unknown')
            restructured_CNT_BL.append('unknown')
            restructured_CNT_CC.append('unknown')
            restructured_CNT_CD.append('unknown')
            restructured_CNT_CV.append('unknown')
            restructured_CNT_GL.append('unknown')
            restructured_CNT_HL.append('unknown')
            restructured_CNT_LAS.append('unknown')
            restructured_CNT_MFBL.append('unknown')
            restructured_CNT_MFHL.append('unknown')
            restructured_CNT_MFOT.append('unknown')
            restructured_CNT_OTH.append('unknown')
            restructured_CNT_PL.append('unknown')
            restructured_CNT_PLBL.append('unknown')
            restructured_CNT_RL.append('unknown')
            restructured_CNT_SCC.append('unknown')
            restructured_CNT_SEL.append('unknown')
        else:
            restructured_CNT_AL.append(count_list_AL[x])
            restructured_CNT_BL.append(count_list_BL[x])
            restructured_CNT_CC.append(count_list_CC[x])
            restructured_CNT_CD.append(count_list_CD[x])
            restructured_CNT_CV.append(count_list_CV[x])
            restructured_CNT_GL.append(count_list_GL[x])
            restructured_CNT_HL.append(count_list_HL[x])
            restructured_CNT_LAS.append(count_list_LAS[x])
            restructured_CNT_MFBL.append(count_list_MFBL[x])
            restructured_CNT_MFHL.append(count_list_MFHL[x])
            restructured_CNT_MFOT.append(count_list_MFOT[x])
            restructured_CNT_OTH.append(count_list_OTH[x])
            restructured_CNT_PL.append(count_list_PL[x])
            restructured_CNT_PLBL.append(count_list_PLBL[x])
            restructured_CNT_RL.append(count_list_RL[x])
            restructured_CNT_SCC.append(count_list_SCC[x])
            restructured_CNT_SEL.append(count_list_SEL[x])
            
df['restructured_CNT_AL'] = pd.Series(restructured_CNT_AL).values
df['restructured_CNT_BL'] = pd.Series(restructured_CNT_BL).values
df['restructured_CNT_CC'] = pd.Series(restructured_CNT_CC).values
df['restructured_CNT_CD'] = pd.Series(restructured_CNT_CD).values
df['restructured_CNT_CV'] = pd.Series(restructured_CNT_CV).values
df['restructured_CNT_GL'] = pd.Series(restructured_CNT_GL).values
df['restructured_CNT_HL'] = pd.Series(restructured_CNT_HL).values
df['restructured_CNT_LAS'] = pd.Series(restructured_CNT_LAS).values
df['restructured_CNT_MFBL'] = pd.Series(restructured_CNT_MFBL).values
df['restructured_CNT_MFHL'] = pd.Series(restructured_CNT_MFHL).values
df['restructured_CNT_MFOT'] = pd.Series(restructured_CNT_MFOT).values
df['restructured_CNT_OTH'] = pd.Series(restructured_CNT_OTH).values
df['restructured_CNT_PL'] = pd.Series(restructured_CNT_PL).values
df['restructured_CNT_PLBL'] = pd.Series(restructured_CNT_PLBL).values
df['restructured_CNT_RL'] = pd.Series(restructured_CNT_RL).values
df['restructured_CNT_SCC'] = pd.Series(restructured_CNT_SCC).values
df['restructured_CNT_SEL'] = pd.Series(restructured_CNT_SEL).values
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/envs/ml_env/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'restructured'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-241-518a38d3662f> in <module>
#      60     grp_slice.reset_index(drop=True, inplace=True)
#      61     for i in range(0, grp_slice.shape[0]):
# ---> 62         if (grp_slice['accountType'][i]=='unknown') or (grp_slice['restructured'][i]=='unknown'):
#      63             continue
#      64         elif (grp_slice['accountType'][i]=='AL') and (grp_slice['restructured'][i]==1):
#
# ~/anaconda3/envs/ml_env/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2900             if self.columns.nlevels > 1:
#    2901                 return self._getitem_multilevel(key)
# -> 2902             indexer = self.columns.get_loc(key)
#    2903             if is_integer(indexer):
#    2904                 indexer = [indexer]
#
# ~/anaconda3/envs/ml_env/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
# -> 2897                 raise KeyError(key) from err
#    2898
#    2899         if tolerance is not None:
#
# KeyError: 'restructured'

# %% [markdown]
# ### Code for writeOff_last3M_CNT

# %% [markdown]
# Count of accounts written off in recent 3 months<br>
# For an applicant, count all the accounts where wo_set_flag ==1 and difference between login date and datereportedorcertified <= 3 months

# %%
# since the json dump was for July 28th
df['loginDate'].value_counts()

# %%
month_diff = list()

for x in range(0, df.shape[0]):
    if (df['dateReportedAndCertified'][x]=='unknown'):
        month_diff.append('unknown')
    else:
        mo_diff = diff_month(df['loginDate'][x], df['dateReportedAndCertified'][x])
        month_diff.append(mo_diff)

df['month_diff'] = pd.Series(month_diff).values

# %% [raw]
# df['month_diff'].value_counts()

# %% [raw]
# df[['loginDate', 'dateReportedAndCertified', 'month_diff']].head()

# %%
writeOff_last3M_CNT = list()
count_list = list()
count = 0

grp_df = df.groupby('ID')

for x in range(0, len(unq_id_list)):
    grp_slice = grp_df.get_group(unq_id_list[x])
    #print(grp_slice)
    grp_slice.reset_index(drop=True, inplace=True)
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['month_diff'][i] == 'unknown') or (grp_slice['writeOff'][i]=='unknown'):
            continue
        elif (grp_slice['month_diff'][i]<=3) and (grp_slice['writeOff'][i]==1): 
            count = count + 1
            
    count_list.append(count)
    count = 0
    
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['month_diff'][i] == 'unknown') or (grp_slice['writeOff'][i]=='unknown'):
            writeOff_last3M_CNT.append('unknown')
        elif (grp_slice['month_diff'][i]<=3) and (grp_slice['writeOff'][i]==1):
            writeOff_last3M_CNT.append(count_list[x])
        else:
            writeOff_last3M_CNT.append(0)
            
df['writeOff_last3M_CNT'] = pd.Series(writeOff_last3M_CNT).values

#df.drop(['days_diff'], axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/envs/ml_env/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'month_diff'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-242-710db02824a0> in <module>
#      10     grp_slice.reset_index(drop=True, inplace=True)
#      11     for i in range(0, grp_slice.shape[0]):
# ---> 12         if (grp_slice['month_diff'][i] == 'unknown') or (grp_slice['writeOff'][i]=='unknown'):
#      13             continue
#      14         elif (grp_slice['month_diff'][i]<=3) and (grp_slice['writeOff'][i]==1):
#
# ~/anaconda3/envs/ml_env/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2900             if self.columns.nlevels > 1:
#    2901                 return self._getitem_multilevel(key)
# -> 2902             indexer = self.columns.get_loc(key)
#    2903             if is_integer(indexer):
#    2904                 indexer = [indexer]
#
# ~/anaconda3/envs/ml_env/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
# -> 2897                 raise KeyError(key) from err
#    2898
#    2899         if tolerance is not None:
#
# KeyError: 'month_diff'

# %%
df['writeOff_last3M_CNT'].value_counts()

# %% [markdown]
# ### Code for writeOff_last3M_CNT_P

# %% [markdown]
# - Count of accounts written off in recent 3 months per product
# - For an applicant, count all the accounts per product where wo_set_flag ==1 and difference between login date and datereportedorcertified <= 3 months

# %%
writeOff_last3M_CNT_AL = list()
writeOff_last3M_CNT_BL = list()
writeOff_last3M_CNT_CC = list()
writeOff_last3M_CNT_CD = list()
writeOff_last3M_CNT_CV = list()
writeOff_last3M_CNT_GL = list()
writeOff_last3M_CNT_HL = list()
writeOff_last3M_CNT_LAS = list()
writeOff_last3M_CNT_MFBL = list()
writeOff_last3M_CNT_MFHL = list()
writeOff_last3M_CNT_MFOT = list()
writeOff_last3M_CNT_OTH = list()
writeOff_last3M_CNT_PL = list()
writeOff_last3M_CNT_PLBL = list()
writeOff_last3M_CNT_RL = list()
writeOff_last3M_CNT_SCC = list()
writeOff_last3M_CNT_SEL = list()

count_list_AL = list()
count_list_BL = list()
count_list_CC = list()
count_list_CD = list()
count_list_CV = list()
count_list_GL = list()
count_list_HL = list()
count_list_LAS = list()
count_list_MFBL = list()
count_list_MFHL = list()
count_list_MFOT = list()
count_list_OTH = list()
count_list_PL = list()
count_list_PLBL = list()
count_list_RL = list()
count_list_SCC = list()
count_list_SEL = list()

count_AL = 0
count_BL = 0
count_CC = 0
count_CD = 0
count_CV = 0
count_GL = 0
count_HL = 0
count_LAS = 0
count_MFBL = 0
count_MFHL = 0
count_MFOT = 0
count_OTH = 0
count_PL = 0 
count_PLBL = 0
count_RL = 0
count_SCC = 0
count_SEL = 0

grp_df = df.groupby('ID')

for x in range(0, len(unq_id_list)):
    grp_slice = grp_df.get_group(unq_id_list[x])
    #print(grp_slice) 
    grp_slice.reset_index(drop=True, inplace=True)
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['accountType'][i]=='unknown') or (grp_slice['writeOff'][i]=='unknown') or (grp_slice['month_diff'][i]>3):
            continue
        elif (grp_slice['accountType'][i]=='AL') and (grp_slice['writeOff'][i]==1) and (grp_slice['month_diff'][i]<=3):
            count_AL = count_AL + 1
        elif (grp_slice['accountType'][i]=='BL') and (grp_slice['writeOff'][i]==1) and (grp_slice['month_diff'][i]<=3):
            count_BL = count_BL + 1
        elif (grp_slice['accountType'][i]=='CC') and (grp_slice['writeOff'][i]==1) and (grp_slice['month_diff'][i]<=3):
            count_CC = count_CC + 1
        elif (grp_slice['accountType'][i]=='CD') and (grp_slice['writeOff'][i]==1) and (grp_slice['month_diff'][i]<=3):
            count_CD = count_CD + 1
        elif (grp_slice['accountType'][i]=='CV') and (grp_slice['writeOff'][i]==1) and (grp_slice['month_diff'][i]<=3):
            count_CV = count_CV + 1
        elif (grp_slice['accountType'][i]=='GL') and (grp_slice['writeOff'][i]==1) and (grp_slice['month_diff'][i]<=3):
            count_GL = count_GL + 1
        elif (grp_slice['accountType'][i]=='HL') and (grp_slice['writeOff'][i]==1) and (grp_slice['month_diff'][i]<=3):
            count_HL = count_HL + 1
        elif (grp_slice['accountType'][i]=='LAS') and (grp_slice['writeOff'][i]==1) and (grp_slice['month_diff'][i]<=3):
            count_LAS = count_LAS + 1
        elif (grp_slice['accountType'][i]=='MFBL') and (grp_slice['writeOff'][i]==1) and (grp_slice['month_diff'][i]<=3):
            count_MFBL = count_MFBL + 1
        elif (grp_slice['accountType'][i]=='MFHL') and (grp_slice['writeOff'][i]==1) and (grp_slice['month_diff'][i]<=3):
            count_MFHL = count_MFHL + 1
        elif (grp_slice['accountType'][i]=='MFOT') and (grp_slice['writeOff'][i]==1) and (grp_slice['month_diff'][i]<=3):
            count_MFOT = count_MFOT + 1
        elif (grp_slice['accountType'][i]=='OTH') and (grp_slice['writeOff'][i]==1) and (grp_slice['month_diff'][i]<=3):
            count_OTH = count_OTH + 1
        elif (grp_slice['accountType'][i]=='PL') and (grp_slice['writeOff'][i]==1) and (grp_slice['month_diff'][i]<=3):
            count_PL = count_PL + 1
        elif (grp_slice['accountType'][i]=='PLBL') and (grp_slice['writeOff'][i]==1) and (grp_slice['month_diff'][i]<=3):
            count_PLBL = count_PLBL + 1
        elif (grp_slice['accountType'][i]=='RL') and (grp_slice['writeOff'][i]==1) and (grp_slice['month_diff'][i]<=3):
            count_RL = count_RL + 1
        elif (grp_slice['accountType'][i]=='SCC') and (grp_slice['writeOff'][i]==1) and (grp_slice['month_diff'][i]<=3):
            count_SCC = count_SCC + 1
        elif (grp_slice['accountType'][i]=='SEL') and (grp_slice['writeOff'][i]==1) and (grp_slice['month_diff'][i]<=3):
            count_SEL = count_SEL + 1
            
    count_list_AL.append(count_AL)
    count_list_BL.append(count_BL)
    count_list_CC.append(count_CC)
    count_list_CD.append(count_CD)
    count_list_CV.append(count_CV)
    count_list_GL.append(count_GL)
    count_list_HL.append(count_HL)
    count_list_LAS.append(count_LAS)
    count_list_MFBL.append(count_MFBL)
    count_list_MFHL.append(count_MFHL)
    count_list_MFOT.append(count_MFOT)
    count_list_OTH.append(count_OTH)
    count_list_PL.append(count_PL)
    count_list_PLBL.append(count_PLBL)
    count_list_RL.append(count_RL)
    count_list_SCC.append(count_SCC)
    count_list_SEL.append(count_SEL)
    
    count_AL = 0
    count_BL = 0
    count_CC = 0
    count_CD = 0
    count_CV = 0
    count_GL = 0
    count_HL = 0
    count_LAS = 0
    count_MFBL = 0
    count_MFHL = 0
    count_MFOT = 0
    count_OTH = 0
    count_PL = 0
    count_PLBL = 0
    count_RL = 0
    count_SCC = 0
    count_SEL = 0
    
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['accountType'][i]=='unknown') or (grp_slice['writeOff'][i]=='unknown'):
            writeOff_last3M_CNT_AL.append('unknown')
            writeOff_last3M_CNT_BL.append('unknown')
            writeOff_last3M_CNT_CC.append('unknown')
            writeOff_last3M_CNT_CD.append('unknown')
            writeOff_last3M_CNT_CV.append('unknown')
            writeOff_last3M_CNT_GL.append('unknown')
            writeOff_last3M_CNT_HL.append('unknown')
            writeOff_last3M_CNT_LAS.append('unknown')
            writeOff_last3M_CNT_MFBL.append('unknown')
            writeOff_last3M_CNT_MFHL.append('unknown')
            writeOff_last3M_CNT_MFOT.append('unknown')
            writeOff_last3M_CNT_OTH.append('unknown')
            writeOff_last3M_CNT_PL.append('unknown')
            writeOff_last3M_CNT_PLBL.append('unknown')
            writeOff_last3M_CNT_RL.append('unknown')
            writeOff_last3M_CNT_SCC.append('unknown')
            writeOff_last3M_CNT_SEL.append('unknown')
        elif (grp_slice['writeOff'][i]==1) and (grp_slice['month_diff'][i]<=3):
            writeOff_last3M_CNT_AL.append(count_list_AL[x])
            writeOff_last3M_CNT_BL.append(count_list_BL[x])
            writeOff_last3M_CNT_CC.append(count_list_CC[x])
            writeOff_last3M_CNT_CD.append(count_list_CD[x])
            writeOff_last3M_CNT_CV.append(count_list_CV[x])
            writeOff_last3M_CNT_GL.append(count_list_GL[x])
            writeOff_last3M_CNT_HL.append(count_list_HL[x])
            writeOff_last3M_CNT_LAS.append(count_list_LAS[x])
            writeOff_last3M_CNT_MFBL.append(count_list_MFBL[x])
            writeOff_last3M_CNT_MFHL.append(count_list_MFHL[x])
            writeOff_last3M_CNT_MFOT.append(count_list_MFOT[x])
            writeOff_last3M_CNT_OTH.append(count_list_OTH[x])
            writeOff_last3M_CNT_PL.append(count_list_PL[x])
            writeOff_last3M_CNT_PLBL.append(count_list_PLBL[x])
            writeOff_last3M_CNT_RL.append(count_list_RL[x])
            writeOff_last3M_CNT_SCC.append(count_list_SCC[x])
            writeOff_last3M_CNT_SEL.append(count_list_SEL[x])
        else:
            writeOff_last3M_CNT_AL.append(0)
            writeOff_last3M_CNT_BL.append(0)
            writeOff_last3M_CNT_CC.append(0)
            writeOff_last3M_CNT_CD.append(0)
            writeOff_last3M_CNT_CV.append(0)
            writeOff_last3M_CNT_GL.append(0)
            writeOff_last3M_CNT_HL.append(0)
            writeOff_last3M_CNT_LAS.append(0)
            writeOff_last3M_CNT_MFBL.append(0)
            writeOff_last3M_CNT_MFHL.append(0)
            writeOff_last3M_CNT_MFOT.append(0)
            writeOff_last3M_CNT_OTH.append(0)
            writeOff_last3M_CNT_PL.append(0)
            writeOff_last3M_CNT_PLBL.append(0)
            writeOff_last3M_CNT_RL.append(0)
            writeOff_last3M_CNT_SCC.append(0)
            writeOff_last3M_CNT_SEL.append(0)
            
df['writeOff_last3M_CNT_AL'] = pd.Series(writeOff_last3M_CNT_AL).values
df['writeOff_last3M_CNT_BL'] = pd.Series(writeOff_last3M_CNT_BL).values
df['writeOff_last3M_CNT_CC'] = pd.Series(writeOff_last3M_CNT_CC).values
df['writeOff_last3M_CNT_CD'] = pd.Series(writeOff_last3M_CNT_CD).values
df['writeOff_last3M_CNT_CV'] = pd.Series(writeOff_last3M_CNT_CV).values
df['writeOff_last3M_CNT_GL'] = pd.Series(writeOff_last3M_CNT_GL).values
df['writeOff_last3M_CNT_HL'] = pd.Series(writeOff_last3M_CNT_HL).values
df['writeOff_last3M_CNT_LAS'] = pd.Series(writeOff_last3M_CNT_LAS).values
df['writeOff_last3M_CNT_MFBL'] = pd.Series(writeOff_last3M_CNT_MFBL).values
df['writeOff_last3M_CNT_MFHL'] = pd.Series(writeOff_last3M_CNT_MFHL).values
df['writeOff_last3M_CNT_MFOT'] = pd.Series(writeOff_last3M_CNT_MFOT).values
df['writeOff_last3M_CNT_OTH'] = pd.Series(writeOff_last3M_CNT_OTH).values
df['writeOff_last3M_CNT_PL'] = pd.Series(writeOff_last3M_CNT_PL).values
df['writeOff_last3M_CNT_PLBL'] = pd.Series(writeOff_last3M_CNT_PLBL).values
df['writeOff_last3M_CNT_RL'] = pd.Series(writeOff_last3M_CNT_RL).values
df['writeOff_last3M_CNT_SCC'] = pd.Series(writeOff_last3M_CNT_SCC).values
df['writeOff_last3M_CNT_SEL'] = pd.Series(writeOff_last3M_CNT_SEL).values

# %% [raw]
# df['writeOff_last3M_CNT_CC'].value_counts()

# %% [raw]
# d = df[['ID','writeOff_last3M_CNT_GL','accountType','writeOff_last3M_CNT','writeOff', 'month_diff']]
# d[d['accountType']=='CC'][0:60]

# %% [markdown]
# ### Code for writeOff_last6M_CNT

# %% [markdown]
# Count of accounts written off in recent 6 months<br>
# For an applicant, count all the accounts where wo_set_flag ==1 and difference between login date and datereportedorcertified <= 6 months

# %%
writeOff_last6M_CNT = list()
count_list = list()
count = 0

grp_df = df.groupby('ID')

for x in range(0, len(unq_id_list)):
    grp_slice = grp_df.get_group(unq_id_list[x])
    #print(grp_slice)
    grp_slice.reset_index(drop=True, inplace=True)
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['month_diff'][i] == 'unknown') or (grp_slice['writeOff'][i]=='unknown'):
            continue
        elif (grp_slice['month_diff'][i]<=6) and (grp_slice['writeOff'][i]==1): 
            count = count + 1
            
    count_list.append(count)
    count = 0
    
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['month_diff'][i] == 'unknown') or (grp_slice['writeOff'][i]=='unknown'):
            writeOff_last6M_CNT.append('unknown')
        elif (grp_slice['month_diff'][i]<=6) and (grp_slice['writeOff'][i]==1):
            writeOff_last6M_CNT.append(count_list[x])
        else:
            writeOff_last6M_CNT.append(0)
            
df['writeOff_last6M_CNT'] = pd.Series(writeOff_last6M_CNT).values

#df.drop(['days_diff'], axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/envs/ml_env/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'month_diff'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-243-9177b467dc9e> in <module>
#      10     grp_slice.reset_index(drop=True, inplace=True)
#      11     for i in range(0, grp_slice.shape[0]):
# ---> 12         if (grp_slice['month_diff'][i] == 'unknown') or (grp_slice['writeOff'][i]=='unknown'):
#      13             continue
#      14         elif (grp_slice['month_diff'][i]<=6) and (grp_slice['writeOff'][i]==1):
#
# ~/anaconda3/envs/ml_env/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2900             if self.columns.nlevels > 1:
#    2901                 return self._getitem_multilevel(key)
# -> 2902             indexer = self.columns.get_loc(key)
#    2903             if is_integer(indexer):
#    2904                 indexer = [indexer]
#
# ~/anaconda3/envs/ml_env/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
# -> 2897                 raise KeyError(key) from err
#    2898
#    2899         if tolerance is not None:
#
# KeyError: 'month_diff'

# %%
df['writeOff_last6M_CNT'].value_counts()

# %% [raw]
# df.to_csv('file1.csv')

# %% [markdown]
# ### Code for writeOff_last6M_CNT_P

# %% [markdown]
# - Count of accounts written off in recent 6 months per product
# - For an applicant, count all the accounts per product where wo_set_flag ==1 and difference between login date and datereportedorcertified <= 6 months

# %%
writeOff_last6M_CNT_AL = list()
writeOff_last6M_CNT_BL = list()
writeOff_last6M_CNT_CC = list()
writeOff_last6M_CNT_CD = list()
writeOff_last6M_CNT_CV = list()
writeOff_last6M_CNT_GL = list()
writeOff_last6M_CNT_HL = list()
writeOff_last6M_CNT_LAS = list()
writeOff_last6M_CNT_MFBL = list()
writeOff_last6M_CNT_MFHL = list()
writeOff_last6M_CNT_MFOT = list()
writeOff_last6M_CNT_OTH = list()
writeOff_last6M_CNT_PL = list()
writeOff_last6M_CNT_PLBL = list()
writeOff_last6M_CNT_RL = list()
writeOff_last6M_CNT_SCC = list()
writeOff_last6M_CNT_SEL = list()

count_list_AL = list()
count_list_BL = list()
count_list_CC = list()
count_list_CD = list()
count_list_CV = list()
count_list_GL = list()
count_list_HL = list()
count_list_LAS = list()
count_list_MFBL = list()
count_list_MFHL = list()
count_list_MFOT = list()
count_list_OTH = list()
count_list_PL = list()
count_list_PLBL = list()
count_list_RL = list()
count_list_SCC = list()
count_list_SEL = list()

count_AL = 0
count_BL = 0
count_CC = 0
count_CD = 0
count_CV = 0
count_GL = 0
count_HL = 0
count_LAS = 0
count_MFBL = 0
count_MFHL = 0
count_MFOT = 0
count_OTH = 0
count_PL = 0 
count_PLBL = 0
count_RL = 0
count_SCC = 0
count_SEL = 0

grp_df = df.groupby('ID')

for x in range(0, len(unq_id_list)):
    grp_slice = grp_df.get_group(unq_id_list[x])
    #print(grp_slice) 
    grp_slice.reset_index(drop=True, inplace=True)
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['accountType'][i]=='unknown') or (grp_slice['writeOff'][i]=='unknown') or (grp_slice['month_diff'][i]>6):
            continue
        elif (grp_slice['accountType'][i]=='AL') and (grp_slice['writeOff'][i]==1) and (grp_slice['month_diff'][i]<=6):
            count_AL = count_AL + 1
        elif (grp_slice['accountType'][i]=='BL') and (grp_slice['writeOff'][i]==1) and (grp_slice['month_diff'][i]<=6):
            count_BL = count_BL + 1
        elif (grp_slice['accountType'][i]=='CC') and (grp_slice['writeOff'][i]==1) and (grp_slice['month_diff'][i]<=6):
            count_CC = count_CC + 1
        elif (grp_slice['accountType'][i]=='CD') and (grp_slice['writeOff'][i]==1) and (grp_slice['month_diff'][i]<=6):
            count_CD = count_CD + 1
        elif (grp_slice['accountType'][i]=='CV') and (grp_slice['writeOff'][i]==1) and (grp_slice['month_diff'][i]<=6):
            count_CV = count_CV + 1
        elif (grp_slice['accountType'][i]=='GL') and (grp_slice['writeOff'][i]==1) and (grp_slice['month_diff'][i]<=6):
            count_GL = count_GL + 1
        elif (grp_slice['accountType'][i]=='HL') and (grp_slice['writeOff'][i]==1) and (grp_slice['month_diff'][i]<=6):
            count_HL = count_HL + 1
        elif (grp_slice['accountType'][i]=='LAS') and (grp_slice['writeOff'][i]==1) and (grp_slice['month_diff'][i]<=6):
            count_LAS = count_LAS + 1
        elif (grp_slice['accountType'][i]=='MFBL') and (grp_slice['writeOff'][i]==1) and (grp_slice['month_diff'][i]<=6):
            count_MFBL = count_MFBL + 1
        elif (grp_slice['accountType'][i]=='MFHL') and (grp_slice['writeOff'][i]==1) and (grp_slice['month_diff'][i]<=6):
            count_MFHL = count_MFHL + 1
        elif (grp_slice['accountType'][i]=='MFOT') and (grp_slice['writeOff'][i]==1) and (grp_slice['month_diff'][i]<=6):
            count_MFOT = count_MFOT + 1
        elif (grp_slice['accountType'][i]=='OTH') and (grp_slice['writeOff'][i]==1) and (grp_slice['month_diff'][i]<=6):
            count_OTH = count_OTH + 1
        elif (grp_slice['accountType'][i]=='PL') and (grp_slice['writeOff'][i]==1) and (grp_slice['month_diff'][i]<=6):
            count_PL = count_PL + 1
        elif (grp_slice['accountType'][i]=='PLBL') and (grp_slice['writeOff'][i]==1) and (grp_slice['month_diff'][i]<=6):
            count_PLBL = count_PLBL + 1
        elif (grp_slice['accountType'][i]=='RL') and (grp_slice['writeOff'][i]==1) and (grp_slice['month_diff'][i]<=6):
            count_RL = count_RL + 1
        elif (grp_slice['accountType'][i]=='SCC') and (grp_slice['writeOff'][i]==1) and (grp_slice['month_diff'][i]<=6):
            count_SCC = count_SCC + 1
        elif (grp_slice['accountType'][i]=='SEL') and (grp_slice['writeOff'][i]==1) and (grp_slice['month_diff'][i]<=6):
            count_SEL = count_SEL + 1
            
    count_list_AL.append(count_AL)
    count_list_BL.append(count_BL)
    count_list_CC.append(count_CC)
    count_list_CD.append(count_CD)
    count_list_CV.append(count_CV)
    count_list_GL.append(count_GL)
    count_list_HL.append(count_HL)
    count_list_LAS.append(count_LAS)
    count_list_MFBL.append(count_MFBL)
    count_list_MFHL.append(count_MFHL)
    count_list_MFOT.append(count_MFOT)
    count_list_OTH.append(count_OTH)
    count_list_PL.append(count_PL)
    count_list_PLBL.append(count_PLBL)
    count_list_RL.append(count_RL)
    count_list_SCC.append(count_SCC)
    count_list_SEL.append(count_SEL)
    
    count_AL = 0
    count_BL = 0
    count_CC = 0
    count_CD = 0
    count_CV = 0
    count_GL = 0
    count_HL = 0
    count_LAS = 0
    count_MFBL = 0
    count_MFHL = 0
    count_MFOT = 0
    count_OTH = 0
    count_PL = 0
    count_PLBL = 0
    count_RL = 0
    count_SCC = 0
    count_SEL = 0
    
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['accountType'][i]=='unknown') or (grp_slice['writeOff'][i]=='unknown'):
            writeOff_last6M_CNT_AL.append('unknown')
            writeOff_last6M_CNT_BL.append('unknown')
            writeOff_last6M_CNT_CC.append('unknown')
            writeOff_last6M_CNT_CD.append('unknown')
            writeOff_last6M_CNT_CV.append('unknown')
            writeOff_last6M_CNT_GL.append('unknown')
            writeOff_last6M_CNT_HL.append('unknown')
            writeOff_last6M_CNT_LAS.append('unknown')
            writeOff_last6M_CNT_MFBL.append('unknown')
            writeOff_last6M_CNT_MFHL.append('unknown')
            writeOff_last6M_CNT_MFOT.append('unknown')
            writeOff_last6M_CNT_OTH.append('unknown')
            writeOff_last6M_CNT_PL.append('unknown')
            writeOff_last6M_CNT_PLBL.append('unknown')
            writeOff_last6M_CNT_RL.append('unknown')
            writeOff_last6M_CNT_SCC.append('unknown')
            writeOff_last6M_CNT_SEL.append('unknown')
        elif (grp_slice['writeOff'][i]==1) and (grp_slice['month_diff'][i]<=6):
            writeOff_last6M_CNT_AL.append(count_list_AL[x])
            writeOff_last6M_CNT_BL.append(count_list_BL[x])
            writeOff_last6M_CNT_CC.append(count_list_CC[x])
            writeOff_last6M_CNT_CD.append(count_list_CD[x])
            writeOff_last6M_CNT_CV.append(count_list_CV[x])
            writeOff_last6M_CNT_GL.append(count_list_GL[x])
            writeOff_last6M_CNT_HL.append(count_list_HL[x])
            writeOff_last6M_CNT_LAS.append(count_list_LAS[x])
            writeOff_last6M_CNT_MFBL.append(count_list_MFBL[x])
            writeOff_last6M_CNT_MFHL.append(count_list_MFHL[x])
            writeOff_last6M_CNT_MFOT.append(count_list_MFOT[x])
            writeOff_last6M_CNT_OTH.append(count_list_OTH[x])
            writeOff_last6M_CNT_PL.append(count_list_PL[x])
            writeOff_last6M_CNT_PLBL.append(count_list_PLBL[x])
            writeOff_last6M_CNT_RL.append(count_list_RL[x])
            writeOff_last6M_CNT_SCC.append(count_list_SCC[x])
            writeOff_last6M_CNT_SEL.append(count_list_SEL[x])
        else:
            writeOff_last6M_CNT_AL.append(0)
            writeOff_last6M_CNT_BL.append(0)
            writeOff_last6M_CNT_CC.append(0)
            writeOff_last6M_CNT_CD.append(0)
            writeOff_last6M_CNT_CV.append(0)
            writeOff_last6M_CNT_GL.append(0)
            writeOff_last6M_CNT_HL.append(0)
            writeOff_last6M_CNT_LAS.append(0)
            writeOff_last6M_CNT_MFBL.append(0)
            writeOff_last6M_CNT_MFHL.append(0)
            writeOff_last6M_CNT_MFOT.append(0)
            writeOff_last6M_CNT_OTH.append(0)
            writeOff_last6M_CNT_PL.append(0)
            writeOff_last6M_CNT_PLBL.append(0)
            writeOff_last6M_CNT_RL.append(0)
            writeOff_last6M_CNT_SCC.append(0)
            writeOff_last6M_CNT_SEL.append(0)
            
df['writeOff_last6M_CNT_AL'] = pd.Series(writeOff_last6M_CNT_AL).values
df['writeOff_last6M_CNT_BL'] = pd.Series(writeOff_last6M_CNT_BL).values
df['writeOff_last6M_CNT_CC'] = pd.Series(writeOff_last6M_CNT_CC).values
df['writeOff_last6M_CNT_CD'] = pd.Series(writeOff_last6M_CNT_CD).values
df['writeOff_last6M_CNT_CV'] = pd.Series(writeOff_last6M_CNT_CV).values
df['writeOff_last6M_CNT_GL'] = pd.Series(writeOff_last6M_CNT_GL).values
df['writeOff_last6M_CNT_HL'] = pd.Series(writeOff_last6M_CNT_HL).values
df['writeOff_last6M_CNT_LAS'] = pd.Series(writeOff_last6M_CNT_LAS).values
df['writeOff_last6M_CNT_MFBL'] = pd.Series(writeOff_last6M_CNT_MFBL).values
df['writeOff_last6M_CNT_MFHL'] = pd.Series(writeOff_last6M_CNT_MFHL).values
df['writeOff_last6M_CNT_MFOT'] = pd.Series(writeOff_last6M_CNT_MFOT).values
df['writeOff_last6M_CNT_OTH'] = pd.Series(writeOff_last6M_CNT_OTH).values
df['writeOff_last6M_CNT_PL'] = pd.Series(writeOff_last6M_CNT_PL).values
df['writeOff_last6M_CNT_PLBL'] = pd.Series(writeOff_last6M_CNT_PLBL).values
df['writeOff_last6M_CNT_RL'] = pd.Series(writeOff_last6M_CNT_RL).values
df['writeOff_last6M_CNT_SCC'] = pd.Series(writeOff_last6M_CNT_SCC).values
df['writeOff_last6M_CNT_SEL'] = pd.Series(writeOff_last6M_CNT_SEL).values
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/envs/ml_env/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'writeOff'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-244-f44a097022d2> in <module>
#      60     grp_slice.reset_index(drop=True, inplace=True)
#      61     for i in range(0, grp_slice.shape[0]):
# ---> 62         if (grp_slice['accountType'][i]=='unknown') or (grp_slice['writeOff'][i]=='unknown') or (grp_slice['month_diff'][i]>6):
#      63             continue
#      64         elif (grp_slice['accountType'][i]=='AL') and (grp_slice['writeOff'][i]==1) and (grp_slice['month_diff'][i]<=6):
#
# ~/anaconda3/envs/ml_env/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2900             if self.columns.nlevels > 1:
#    2901                 return self._getitem_multilevel(key)
# -> 2902             indexer = self.columns.get_loc(key)
#    2903             if is_integer(indexer):
#    2904                 indexer = [indexer]
#
# ~/anaconda3/envs/ml_env/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
# -> 2897                 raise KeyError(key) from err
#    2898
#    2899         if tolerance is not None:
#
# KeyError: 'writeOff'

# %% [raw]
# df['writeOff_last6M_CNT_CC'].value_counts()

# %% [raw]
# d = df[['ID','writeOff_last6M_CNT_CC','accountType','writeOff_last6M_CNT','writeOff', 'month_diff']]
# d[d['writeOff']==1][60:120]

# %% [markdown]
# ### Code for writeOff_last9M_CNT

# %% [markdown]
# Count of accounts written off in recent 9 months<br>
# For an applicant, count all the accounts where wo_set_flag ==1 and difference between login date and datereportedorcertified <= 9 months

# %%
writeOff_last9M_CNT = list()
count_list = list()
count = 0

grp_df = df.groupby('ID')

for x in range(0, len(unq_id_list)):
    grp_slice = grp_df.get_group(unq_id_list[x])
    #print(grp_slice)
    grp_slice.reset_index(drop=True, inplace=True)
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['month_diff'][i] == 'unknown') or (grp_slice['writeOff'][i]=='unknown'):
            continue
        elif (grp_slice['month_diff'][i]<=9) and (grp_slice['writeOff'][i]==1): 
            count = count + 1
            
    count_list.append(count)
    count = 0
    
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['month_diff'][i] == 'unknown') or (grp_slice['writeOff'][i]=='unknown'):
            writeOff_last9M_CNT.append('unknown')
        elif (grp_slice['month_diff'][i]<=9) and (grp_slice['writeOff'][i]==1):
            writeOff_last9M_CNT.append(count_list[x])
        else:
            writeOff_last9M_CNT.append(0)
            
df['writeOff_last9M_CNT'] = pd.Series(writeOff_last9M_CNT).values

#df.drop(['days_diff'], axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/envs/ml_env/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'month_diff'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-245-e4f6f09f1610> in <module>
#      10     grp_slice.reset_index(drop=True, inplace=True)
#      11     for i in range(0, grp_slice.shape[0]):
# ---> 12         if (grp_slice['month_diff'][i] == 'unknown') or (grp_slice['writeOff'][i]=='unknown'):
#      13             continue
#      14         elif (grp_slice['month_diff'][i]<=9) and (grp_slice['writeOff'][i]==1):
#
# ~/anaconda3/envs/ml_env/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2900             if self.columns.nlevels > 1:
#    2901                 return self._getitem_multilevel(key)
# -> 2902             indexer = self.columns.get_loc(key)
#    2903             if is_integer(indexer):
#    2904                 indexer = [indexer]
#
# ~/anaconda3/envs/ml_env/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
# -> 2897                 raise KeyError(key) from err
#    2898
#    2899         if tolerance is not None:
#
# KeyError: 'month_diff'

# %%
df['writeOff_last9M_CNT'].value_counts()

# %% [raw]
# d = df[['ID','accountType','writeOff_last9M_CNT','writeOff', 'month_diff']]
# d[d['writeOff']==1][0:60]

# %% [markdown]
# ### Code for writeOff_last9M_CNT_P

# %% [markdown]
# - Count of accounts written off in recent 9 months per product
# - For an applicant, count all the accounts per product where wo_set_flag ==1 and difference between login date and datereportedorcertified <= 9 months

# %%
writeOff_last9M_CNT_AL = list()
writeOff_last9M_CNT_BL = list()
writeOff_last9M_CNT_CC = list()
writeOff_last9M_CNT_CD = list()
writeOff_last9M_CNT_CV = list()
writeOff_last9M_CNT_GL = list()
writeOff_last9M_CNT_HL = list()
writeOff_last9M_CNT_LAS = list()
writeOff_last9M_CNT_MFBL = list()
writeOff_last9M_CNT_MFHL = list()
writeOff_last9M_CNT_MFOT = list()
writeOff_last9M_CNT_OTH = list()
writeOff_last9M_CNT_PL = list()
writeOff_last9M_CNT_PLBL = list()
writeOff_last9M_CNT_RL = list()
writeOff_last9M_CNT_SCC = list()
writeOff_last9M_CNT_SEL = list()

count_list_AL = list()
count_list_BL = list()
count_list_CC = list()
count_list_CD = list()
count_list_CV = list()
count_list_GL = list()
count_list_HL = list()
count_list_LAS = list()
count_list_MFBL = list()
count_list_MFHL = list()
count_list_MFOT = list()
count_list_OTH = list()
count_list_PL = list()
count_list_PLBL = list()
count_list_RL = list()
count_list_SCC = list()
count_list_SEL = list()

count_AL = 0
count_BL = 0
count_CC = 0
count_CD = 0
count_CV = 0
count_GL = 0
count_HL = 0
count_LAS = 0
count_MFBL = 0
count_MFHL = 0
count_MFOT = 0
count_OTH = 0
count_PL = 0 
count_PLBL = 0
count_RL = 0
count_SCC = 0
count_SEL = 0

grp_df = df.groupby('ID')

for x in range(0, len(unq_id_list)):
    grp_slice = grp_df.get_group(unq_id_list[x])
    #print(grp_slice) 
    grp_slice.reset_index(drop=True, inplace=True)
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['accountType'][i]=='unknown') or (grp_slice['writeOff'][i]=='unknown') or (grp_slice['month_diff'][i]>9):
            continue
        elif (grp_slice['accountType'][i]=='AL') and (grp_slice['writeOff'][i]==1) and (grp_slice['month_diff'][i]<=9):
            count_AL = count_AL + 1
        elif (grp_slice['accountType'][i]=='BL') and (grp_slice['writeOff'][i]==1) and (grp_slice['month_diff'][i]<=9):
            count_BL = count_BL + 1
        elif (grp_slice['accountType'][i]=='CC') and (grp_slice['writeOff'][i]==1) and (grp_slice['month_diff'][i]<=9):
            count_CC = count_CC + 1
        elif (grp_slice['accountType'][i]=='CD') and (grp_slice['writeOff'][i]==1) and (grp_slice['month_diff'][i]<=9):
            count_CD = count_CD + 1
        elif (grp_slice['accountType'][i]=='CV') and (grp_slice['writeOff'][i]==1) and (grp_slice['month_diff'][i]<=9):
            count_CV = count_CV + 1
        elif (grp_slice['accountType'][i]=='GL') and (grp_slice['writeOff'][i]==1) and (grp_slice['month_diff'][i]<=9):
            count_GL = count_GL + 1
        elif (grp_slice['accountType'][i]=='HL') and (grp_slice['writeOff'][i]==1) and (grp_slice['month_diff'][i]<=9):
            count_HL = count_HL + 1
        elif (grp_slice['accountType'][i]=='LAS') and (grp_slice['writeOff'][i]==1) and (grp_slice['month_diff'][i]<=9):
            count_LAS = count_LAS + 1
        elif (grp_slice['accountType'][i]=='MFBL') and (grp_slice['writeOff'][i]==1) and (grp_slice['month_diff'][i]<=9):
            count_MFBL = count_MFBL + 1
        elif (grp_slice['accountType'][i]=='MFHL') and (grp_slice['writeOff'][i]==1) and (grp_slice['month_diff'][i]<=9):
            count_MFHL = count_MFHL + 1
        elif (grp_slice['accountType'][i]=='MFOT') and (grp_slice['writeOff'][i]==1) and (grp_slice['month_diff'][i]<=9):
            count_MFOT = count_MFOT + 1
        elif (grp_slice['accountType'][i]=='OTH') and (grp_slice['writeOff'][i]==1) and (grp_slice['month_diff'][i]<=9):
            count_OTH = count_OTH + 1
        elif (grp_slice['accountType'][i]=='PL') and (grp_slice['writeOff'][i]==1) and (grp_slice['month_diff'][i]<=9):
            count_PL = count_PL + 1
        elif (grp_slice['accountType'][i]=='PLBL') and (grp_slice['writeOff'][i]==1) and (grp_slice['month_diff'][i]<=9):
            count_PLBL = count_PLBL + 1
        elif (grp_slice['accountType'][i]=='RL') and (grp_slice['writeOff'][i]==1) and (grp_slice['month_diff'][i]<=9):
            count_RL = count_RL + 1
        elif (grp_slice['accountType'][i]=='SCC') and (grp_slice['writeOff'][i]==1) and (grp_slice['month_diff'][i]<=9):
            count_SCC = count_SCC + 1
        elif (grp_slice['accountType'][i]=='SEL') and (grp_slice['writeOff'][i]==1) and (grp_slice['month_diff'][i]<=9):
            count_SEL = count_SEL + 1
            
    count_list_AL.append(count_AL)
    count_list_BL.append(count_BL)
    count_list_CC.append(count_CC)
    count_list_CD.append(count_CD)
    count_list_CV.append(count_CV)
    count_list_GL.append(count_GL)
    count_list_HL.append(count_HL)
    count_list_LAS.append(count_LAS)
    count_list_MFBL.append(count_MFBL)
    count_list_MFHL.append(count_MFHL)
    count_list_MFOT.append(count_MFOT)
    count_list_OTH.append(count_OTH)
    count_list_PL.append(count_PL)
    count_list_PLBL.append(count_PLBL)
    count_list_RL.append(count_RL)
    count_list_SCC.append(count_SCC)
    count_list_SEL.append(count_SEL)
    
    count_AL = 0
    count_BL = 0
    count_CC = 0
    count_CD = 0
    count_CV = 0
    count_GL = 0
    count_HL = 0
    count_LAS = 0
    count_MFBL = 0
    count_MFHL = 0
    count_MFOT = 0
    count_OTH = 0
    count_PL = 0
    count_PLBL = 0
    count_RL = 0
    count_SCC = 0
    count_SEL = 0
    
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['accountType'][i]=='unknown') or (grp_slice['writeOff'][i]=='unknown'):
            writeOff_last9M_CNT_AL.append('unknown')
            writeOff_last9M_CNT_BL.append('unknown')
            writeOff_last9M_CNT_CC.append('unknown')
            writeOff_last9M_CNT_CD.append('unknown')
            writeOff_last9M_CNT_CV.append('unknown')
            writeOff_last9M_CNT_GL.append('unknown')
            writeOff_last9M_CNT_HL.append('unknown')
            writeOff_last9M_CNT_LAS.append('unknown')
            writeOff_last9M_CNT_MFBL.append('unknown')
            writeOff_last9M_CNT_MFHL.append('unknown')
            writeOff_last9M_CNT_MFOT.append('unknown')
            writeOff_last9M_CNT_OTH.append('unknown')
            writeOff_last9M_CNT_PL.append('unknown')
            writeOff_last9M_CNT_PLBL.append('unknown')
            writeOff_last9M_CNT_RL.append('unknown')
            writeOff_last9M_CNT_SCC.append('unknown')
            writeOff_last9M_CNT_SEL.append('unknown')
        elif (grp_slice['writeOff'][i]==1) and (grp_slice['month_diff'][i]<=9):
            writeOff_last9M_CNT_AL.append(count_list_AL[x])
            writeOff_last9M_CNT_BL.append(count_list_BL[x])
            writeOff_last9M_CNT_CC.append(count_list_CC[x])
            writeOff_last9M_CNT_CD.append(count_list_CD[x])
            writeOff_last9M_CNT_CV.append(count_list_CV[x])
            writeOff_last9M_CNT_GL.append(count_list_GL[x])
            writeOff_last9M_CNT_HL.append(count_list_HL[x])
            writeOff_last9M_CNT_LAS.append(count_list_LAS[x])
            writeOff_last9M_CNT_MFBL.append(count_list_MFBL[x])
            writeOff_last9M_CNT_MFHL.append(count_list_MFHL[x])
            writeOff_last9M_CNT_MFOT.append(count_list_MFOT[x])
            writeOff_last9M_CNT_OTH.append(count_list_OTH[x])
            writeOff_last9M_CNT_PL.append(count_list_PL[x])
            writeOff_last9M_CNT_PLBL.append(count_list_PLBL[x])
            writeOff_last9M_CNT_RL.append(count_list_RL[x])
            writeOff_last9M_CNT_SCC.append(count_list_SCC[x])
            writeOff_last9M_CNT_SEL.append(count_list_SEL[x])
        else:
            writeOff_last9M_CNT_AL.append(0)
            writeOff_last9M_CNT_BL.append(0)
            writeOff_last9M_CNT_CC.append(0)
            writeOff_last9M_CNT_CD.append(0)
            writeOff_last9M_CNT_CV.append(0)
            writeOff_last9M_CNT_GL.append(0)
            writeOff_last9M_CNT_HL.append(0)
            writeOff_last9M_CNT_LAS.append(0)
            writeOff_last9M_CNT_MFBL.append(0)
            writeOff_last9M_CNT_MFHL.append(0)
            writeOff_last9M_CNT_MFOT.append(0)
            writeOff_last9M_CNT_OTH.append(0)
            writeOff_last9M_CNT_PL.append(0)
            writeOff_last9M_CNT_PLBL.append(0)
            writeOff_last9M_CNT_RL.append(0)
            writeOff_last9M_CNT_SCC.append(0)
            writeOff_last9M_CNT_SEL.append(0)
            
df['writeOff_last9M_CNT_AL'] = pd.Series(writeOff_last9M_CNT_AL).values
df['writeOff_last9M_CNT_BL'] = pd.Series(writeOff_last9M_CNT_BL).values
df['writeOff_last9M_CNT_CC'] = pd.Series(writeOff_last9M_CNT_CC).values
df['writeOff_last9M_CNT_CD'] = pd.Series(writeOff_last9M_CNT_CD).values
df['writeOff_last9M_CNT_CV'] = pd.Series(writeOff_last9M_CNT_CV).values
df['writeOff_last9M_CNT_GL'] = pd.Series(writeOff_last9M_CNT_GL).values
df['writeOff_last9M_CNT_HL'] = pd.Series(writeOff_last9M_CNT_HL).values
df['writeOff_last9M_CNT_LAS'] = pd.Series(writeOff_last9M_CNT_LAS).values
df['writeOff_last9M_CNT_MFBL'] = pd.Series(writeOff_last9M_CNT_MFBL).values
df['writeOff_last9M_CNT_MFHL'] = pd.Series(writeOff_last9M_CNT_MFHL).values
df['writeOff_last9M_CNT_MFOT'] = pd.Series(writeOff_last9M_CNT_MFOT).values
df['writeOff_last9M_CNT_OTH'] = pd.Series(writeOff_last9M_CNT_OTH).values
df['writeOff_last9M_CNT_PL'] = pd.Series(writeOff_last9M_CNT_PL).values
df['writeOff_last9M_CNT_PLBL'] = pd.Series(writeOff_last9M_CNT_PLBL).values
df['writeOff_last9M_CNT_RL'] = pd.Series(writeOff_last9M_CNT_RL).values
df['writeOff_last9M_CNT_SCC'] = pd.Series(writeOff_last9M_CNT_SCC).values
df['writeOff_last9M_CNT_SEL'] = pd.Series(writeOff_last9M_CNT_SEL).values

# %% [raw]
# d = df[['ID','writeOff_last9M_CNT_CD','accountType','writeOff_last9M_CNT','writeOff', 'month_diff']]
# d[d['writeOff']==1][0:60]

# %% [markdown]
# ### Code for writeOff_last1Y_CNT

# %% [markdown]
# Count of accounts written off in recent 1 year<br>
# For an applicant, count all the accounts where wo_set_flag ==1 and difference between login date and datereportedorcertified <= 1 year

# %%
writeOff_last1Y_CNT = list()
count_list = list()
count = 0

grp_df = df.groupby('ID')

for x in range(0, len(unq_id_list)):
    grp_slice = grp_df.get_group(unq_id_list[x])
    #print(grp_slice)
    grp_slice.reset_index(drop=True, inplace=True)
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['month_diff'][i] == 'unknown') or (grp_slice['writeOff'][i]=='unknown'):
            continue
        elif (grp_slice['month_diff'][i]<=12) and (grp_slice['writeOff'][i]==1): 
            count = count + 1
            
    count_list.append(count)
    count = 0
    
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['month_diff'][i] == 'unknown') or (grp_slice['writeOff'][i]=='unknown'):
            writeOff_last1Y_CNT.append('unknown')
        elif (grp_slice['month_diff'][i]<=12) and (grp_slice['writeOff'][i]==1):
            writeOff_last1Y_CNT.append(count_list[x])
        else:
            writeOff_last1Y_CNT.append(0)
            
df['writeOff_last1Y_CNT'] = pd.Series(writeOff_last1Y_CNT).values

#df.drop(['days_diff'], axis=1, inplace=True)

# %%
df['writeOff_last1Y_CNT'].value_counts()

# %% [raw]
# d = df[['ID','writeOff','writeOff_last1Y_CNT','month_diff']]
# d[d['writeOff']==1][0:60]

# %% [markdown]
# ### Code for writeOff_last1Y_CNT_P

# %% [markdown]
# - Count of accounts written off in recent 1 year per product
# - For an applicant, count all the accounts per product where wo_set_flag ==1 and difference between login date and datereportedorcertified <= 1 year

# %%
writeOff_last1Y_CNT_AL = list()
writeOff_last1Y_CNT_BL = list()
writeOff_last1Y_CNT_CC = list()
writeOff_last1Y_CNT_CD = list()
writeOff_last1Y_CNT_CV = list()
writeOff_last1Y_CNT_GL = list()
writeOff_last1Y_CNT_HL = list()
writeOff_last1Y_CNT_LAS = list()
writeOff_last1Y_CNT_MFBL = list()
writeOff_last1Y_CNT_MFHL = list()
writeOff_last1Y_CNT_MFOT = list()
writeOff_last1Y_CNT_OTH = list()
writeOff_last1Y_CNT_PL = list()
writeOff_last1Y_CNT_PLBL = list()
writeOff_last1Y_CNT_RL = list()
writeOff_last1Y_CNT_SCC = list()
writeOff_last1Y_CNT_SEL = list()

count_list_AL = list()
count_list_BL = list()
count_list_CC = list()
count_list_CD = list()
count_list_CV = list()
count_list_GL = list()
count_list_HL = list()
count_list_LAS = list()
count_list_MFBL = list()
count_list_MFHL = list()
count_list_MFOT = list()
count_list_OTH = list()
count_list_PL = list()
count_list_PLBL = list()
count_list_RL = list()
count_list_SCC = list()
count_list_SEL = list()

count_AL = 0
count_BL = 0
count_CC = 0
count_CD = 0
count_CV = 0
count_GL = 0
count_HL = 0
count_LAS = 0
count_MFBL = 0
count_MFHL = 0
count_MFOT = 0
count_OTH = 0
count_PL = 0 
count_PLBL = 0
count_RL = 0
count_SCC = 0
count_SEL = 0

grp_df = df.groupby('ID')

for x in range(0, len(unq_id_list)):
    grp_slice = grp_df.get_group(unq_id_list[x])
    #print(grp_slice) 
    grp_slice.reset_index(drop=True, inplace=True)
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['accountType'][i]=='unknown') or (grp_slice['writeOff'][i]=='unknown') or (grp_slice['month_diff'][i]>12):
            continue
        elif (grp_slice['accountType'][i]=='AL') and (grp_slice['writeOff'][i]==1) and (grp_slice['month_diff'][i]<=12):
            count_AL = count_AL + 1
        elif (grp_slice['accountType'][i]=='BL') and (grp_slice['writeOff'][i]==1) and (grp_slice['month_diff'][i]<=12):
            count_BL = count_BL + 1
        elif (grp_slice['accountType'][i]=='CC') and (grp_slice['writeOff'][i]==1) and (grp_slice['month_diff'][i]<=12):
            count_CC = count_CC + 1
        elif (grp_slice['accountType'][i]=='CD') and (grp_slice['writeOff'][i]==1) and (grp_slice['month_diff'][i]<=12):
            count_CD = count_CD + 1
        elif (grp_slice['accountType'][i]=='CV') and (grp_slice['writeOff'][i]==1) and (grp_slice['month_diff'][i]<=12):
            count_CV = count_CV + 1
        elif (grp_slice['accountType'][i]=='GL') and (grp_slice['writeOff'][i]==1) and (grp_slice['month_diff'][i]<=12):
            count_GL = count_GL + 1
        elif (grp_slice['accountType'][i]=='HL') and (grp_slice['writeOff'][i]==1) and (grp_slice['month_diff'][i]<=12):
            count_HL = count_HL + 1
        elif (grp_slice['accountType'][i]=='LAS') and (grp_slice['writeOff'][i]==1) and (grp_slice['month_diff'][i]<=12):
            count_LAS = count_LAS + 1
        elif (grp_slice['accountType'][i]=='MFBL') and (grp_slice['writeOff'][i]==1) and (grp_slice['month_diff'][i]<=12):
            count_MFBL = count_MFBL + 1
        elif (grp_slice['accountType'][i]=='MFHL') and (grp_slice['writeOff'][i]==1) and (grp_slice['month_diff'][i]<=12):
            count_MFHL = count_MFHL + 1
        elif (grp_slice['accountType'][i]=='MFOT') and (grp_slice['writeOff'][i]==1) and (grp_slice['month_diff'][i]<=12):
            count_MFOT = count_MFOT + 1
        elif (grp_slice['accountType'][i]=='OTH') and (grp_slice['writeOff'][i]==1) and (grp_slice['month_diff'][i]<=12):
            count_OTH = count_OTH + 1
        elif (grp_slice['accountType'][i]=='PL') and (grp_slice['writeOff'][i]==1) and (grp_slice['month_diff'][i]<=12):
            count_PL = count_PL + 1
        elif (grp_slice['accountType'][i]=='PLBL') and (grp_slice['writeOff'][i]==1) and (grp_slice['month_diff'][i]<=12):
            count_PLBL = count_PLBL + 1
        elif (grp_slice['accountType'][i]=='RL') and (grp_slice['writeOff'][i]==1) and (grp_slice['month_diff'][i]<=12):
            count_RL = count_RL + 1
        elif (grp_slice['accountType'][i]=='SCC') and (grp_slice['writeOff'][i]==1) and (grp_slice['month_diff'][i]<=12):
            count_SCC = count_SCC + 1
        elif (grp_slice['accountType'][i]=='SEL') and (grp_slice['writeOff'][i]==1) and (grp_slice['month_diff'][i]<=12):
            count_SEL = count_SEL + 1
            
    count_list_AL.append(count_AL)
    count_list_BL.append(count_BL)
    count_list_CC.append(count_CC)
    count_list_CD.append(count_CD)
    count_list_CV.append(count_CV)
    count_list_GL.append(count_GL)
    count_list_HL.append(count_HL)
    count_list_LAS.append(count_LAS)
    count_list_MFBL.append(count_MFBL)
    count_list_MFHL.append(count_MFHL)
    count_list_MFOT.append(count_MFOT)
    count_list_OTH.append(count_OTH)
    count_list_PL.append(count_PL)
    count_list_PLBL.append(count_PLBL)
    count_list_RL.append(count_RL)
    count_list_SCC.append(count_SCC)
    count_list_SEL.append(count_SEL)
    
    count_AL = 0
    count_BL = 0
    count_CC = 0
    count_CD = 0
    count_CV = 0
    count_GL = 0
    count_HL = 0
    count_LAS = 0
    count_MFBL = 0
    count_MFHL = 0
    count_MFOT = 0
    count_OTH = 0
    count_PL = 0
    count_PLBL = 0
    count_RL = 0
    count_SCC = 0
    count_SEL = 0
    
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['accountType'][i]=='unknown') or (grp_slice['writeOff'][i]=='unknown'):
            writeOff_last1Y_CNT_AL.append('unknown')
            writeOff_last1Y_CNT_BL.append('unknown')
            writeOff_last1Y_CNT_CC.append('unknown')
            writeOff_last1Y_CNT_CD.append('unknown')
            writeOff_last1Y_CNT_CV.append('unknown')
            writeOff_last1Y_CNT_GL.append('unknown')
            writeOff_last1Y_CNT_HL.append('unknown')
            writeOff_last1Y_CNT_LAS.append('unknown')
            writeOff_last1Y_CNT_MFBL.append('unknown')
            writeOff_last1Y_CNT_MFHL.append('unknown')
            writeOff_last1Y_CNT_MFOT.append('unknown')
            writeOff_last1Y_CNT_OTH.append('unknown')
            writeOff_last1Y_CNT_PL.append('unknown')
            writeOff_last1Y_CNT_PLBL.append('unknown')
            writeOff_last1Y_CNT_RL.append('unknown')
            writeOff_last1Y_CNT_SCC.append('unknown')
            writeOff_last1Y_CNT_SEL.append('unknown')
        elif (grp_slice['writeOff'][i]==1) and (grp_slice['month_diff'][i]<=12):
            writeOff_last1Y_CNT_AL.append(count_list_AL[x])
            writeOff_last1Y_CNT_BL.append(count_list_BL[x])
            writeOff_last1Y_CNT_CC.append(count_list_CC[x])
            writeOff_last1Y_CNT_CD.append(count_list_CD[x])
            writeOff_last1Y_CNT_CV.append(count_list_CV[x])
            writeOff_last1Y_CNT_GL.append(count_list_GL[x])
            writeOff_last1Y_CNT_HL.append(count_list_HL[x])
            writeOff_last1Y_CNT_LAS.append(count_list_LAS[x])
            writeOff_last1Y_CNT_MFBL.append(count_list_MFBL[x])
            writeOff_last1Y_CNT_MFHL.append(count_list_MFHL[x])
            writeOff_last1Y_CNT_MFOT.append(count_list_MFOT[x])
            writeOff_last1Y_CNT_OTH.append(count_list_OTH[x])
            writeOff_last1Y_CNT_PL.append(count_list_PL[x])
            writeOff_last1Y_CNT_PLBL.append(count_list_PLBL[x])
            writeOff_last1Y_CNT_RL.append(count_list_RL[x])
            writeOff_last1Y_CNT_SCC.append(count_list_SCC[x])
            writeOff_last1Y_CNT_SEL.append(count_list_SEL[x])
        else:
            writeOff_last1Y_CNT_AL.append(0)
            writeOff_last1Y_CNT_BL.append(0)
            writeOff_last1Y_CNT_CC.append(0)
            writeOff_last1Y_CNT_CD.append(0)
            writeOff_last1Y_CNT_CV.append(0)
            writeOff_last1Y_CNT_GL.append(0)
            writeOff_last1Y_CNT_HL.append(0)
            writeOff_last1Y_CNT_LAS.append(0)
            writeOff_last1Y_CNT_MFBL.append(0)
            writeOff_last1Y_CNT_MFHL.append(0)
            writeOff_last1Y_CNT_MFOT.append(0)
            writeOff_last1Y_CNT_OTH.append(0)
            writeOff_last1Y_CNT_PL.append(0)
            writeOff_last1Y_CNT_PLBL.append(0)
            writeOff_last1Y_CNT_RL.append(0)
            writeOff_last1Y_CNT_SCC.append(0)
            writeOff_last1Y_CNT_SEL.append(0)
            
df['writeOff_last1Y_CNT_AL'] = pd.Series(writeOff_last1Y_CNT_AL).values
df['writeOff_last1Y_CNT_BL'] = pd.Series(writeOff_last1Y_CNT_BL).values
df['writeOff_last1Y_CNT_CC'] = pd.Series(writeOff_last1Y_CNT_CC).values
df['writeOff_last1Y_CNT_CD'] = pd.Series(writeOff_last1Y_CNT_CD).values
df['writeOff_last1Y_CNT_CV'] = pd.Series(writeOff_last1Y_CNT_CV).values
df['writeOff_last1Y_CNT_GL'] = pd.Series(writeOff_last1Y_CNT_GL).values
df['writeOff_last1Y_CNT_HL'] = pd.Series(writeOff_last1Y_CNT_HL).values
df['writeOff_last1Y_CNT_LAS'] = pd.Series(writeOff_last1Y_CNT_LAS).values
df['writeOff_last1Y_CNT_MFBL'] = pd.Series(writeOff_last1Y_CNT_MFBL).values
df['writeOff_last1Y_CNT_MFHL'] = pd.Series(writeOff_last1Y_CNT_MFHL).values
df['writeOff_last1Y_CNT_MFOT'] = pd.Series(writeOff_last1Y_CNT_MFOT).values
df['writeOff_last1Y_CNT_OTH'] = pd.Series(writeOff_last1Y_CNT_OTH).values
df['writeOff_last1Y_CNT_PL'] = pd.Series(writeOff_last1Y_CNT_PL).values
df['writeOff_last1Y_CNT_PLBL'] = pd.Series(writeOff_last1Y_CNT_PLBL).values
df['writeOff_last1Y_CNT_RL'] = pd.Series(writeOff_last1Y_CNT_RL).values
df['writeOff_last1Y_CNT_SCC'] = pd.Series(writeOff_last1Y_CNT_SCC).values
df['writeOff_last1Y_CNT_SEL'] = pd.Series(writeOff_last1Y_CNT_SEL).values
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/envs/ml_env/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'writeOff'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-246-7d2c71a806e3> in <module>
#      60     grp_slice.reset_index(drop=True, inplace=True)
#      61     for i in range(0, grp_slice.shape[0]):
# ---> 62         if (grp_slice['accountType'][i]=='unknown') or (grp_slice['writeOff'][i]=='unknown') or (grp_slice['month_diff'][i]>12):
#      63             continue
#      64         elif (grp_slice['accountType'][i]=='AL') and (grp_slice['writeOff'][i]==1) and (grp_slice['month_diff'][i]<=12):
#
# ~/anaconda3/envs/ml_env/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2900             if self.columns.nlevels > 1:
#    2901                 return self._getitem_multilevel(key)
# -> 2902             indexer = self.columns.get_loc(key)
#    2903             if is_integer(indexer):
#    2904                 indexer = [indexer]
#
# ~/anaconda3/envs/ml_env/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
# -> 2897                 raise KeyError(key) from err
#    2898
#    2899         if tolerance is not None:
#
# KeyError: 'writeOff'

# %% [raw]
# d = df[['ID','writeOff_last1Y_CNT_PL','accountType','writeOff_last1Y_CNT','writeOff', 'month_diff']]
# d[d['writeOff']==1][0:60]

# %% [markdown]
# ### Code for writeOff_last2Y_CNT

# %% [markdown]
# Count of accounts written off in recent 2 year<br>
# For an applicant, count all the accounts where wo_set_flag ==1 and difference between login date and datereportedorcertified <= 2 years

# %%
writeOff_last2Y_CNT = list()
count_list = list()
count = 0

grp_df = df.groupby('ID')

for x in range(0, len(unq_id_list)):
    grp_slice = grp_df.get_group(unq_id_list[x])
    #print(grp_slice)
    grp_slice.reset_index(drop=True, inplace=True)
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['month_diff'][i] == 'unknown') or (grp_slice['writeOff'][i]=='unknown'):
            continue
        elif (grp_slice['month_diff'][i]<=24) and (grp_slice['writeOff'][i]==1): 
            count = count + 1
            
    count_list.append(count)
    count = 0
    
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['month_diff'][i] == 'unknown') or (grp_slice['writeOff'][i]=='unknown'):
            writeOff_last2Y_CNT.append('unknown')
        elif (grp_slice['month_diff'][i]<=24) and (grp_slice['writeOff'][i]==1):
            writeOff_last2Y_CNT.append(count_list[x])
        else:
            writeOff_last2Y_CNT.append(0)
            
df['writeOff_last2Y_CNT'] = pd.Series(writeOff_last2Y_CNT).values

#df.drop(['days_diff'], axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/envs/ml_env/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'month_diff'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-247-320a4cea4c9e> in <module>
#      10     grp_slice.reset_index(drop=True, inplace=True)
#      11     for i in range(0, grp_slice.shape[0]):
# ---> 12         if (grp_slice['month_diff'][i] == 'unknown') or (grp_slice['writeOff'][i]=='unknown'):
#      13             continue
#      14         elif (grp_slice['month_diff'][i]<=24) and (grp_slice['writeOff'][i]==1):
#
# ~/anaconda3/envs/ml_env/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2900             if self.columns.nlevels > 1:
#    2901                 return self._getitem_multilevel(key)
# -> 2902             indexer = self.columns.get_loc(key)
#    2903             if is_integer(indexer):
#    2904                 indexer = [indexer]
#
# ~/anaconda3/envs/ml_env/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
# -> 2897                 raise KeyError(key) from err
#    2898
#    2899         if tolerance is not None:
#
# KeyError: 'month_diff'

# %%
df['writeOff_last2Y_CNT'].value_counts()

# %% [markdown]
# ### Code for writeOff_last2Y_CNT_P

# %% [markdown]
# - Count of accounts written off in recent 2 year per product
# - For an applicant, count all the accounts per product where wo_set_flag ==1 and difference between login date and datereportedorcertified <= 2 years

# %%
writeOff_last2Y_CNT_AL = list()
writeOff_last2Y_CNT_BL = list()
writeOff_last2Y_CNT_CC = list()
writeOff_last2Y_CNT_CD = list()
writeOff_last2Y_CNT_CV = list()
writeOff_last2Y_CNT_GL = list()
writeOff_last2Y_CNT_HL = list()
writeOff_last2Y_CNT_LAS = list()
writeOff_last2Y_CNT_MFBL = list()
writeOff_last2Y_CNT_MFHL = list()
writeOff_last2Y_CNT_MFOT = list()
writeOff_last2Y_CNT_OTH = list()
writeOff_last2Y_CNT_PL = list()
writeOff_last2Y_CNT_PLBL = list()
writeOff_last2Y_CNT_RL = list()
writeOff_last2Y_CNT_SCC = list()
writeOff_last2Y_CNT_SEL = list()

count_list_AL = list()
count_list_BL = list()
count_list_CC = list()
count_list_CD = list()
count_list_CV = list()
count_list_GL = list()
count_list_HL = list()
count_list_LAS = list()
count_list_MFBL = list()
count_list_MFHL = list()
count_list_MFOT = list()
count_list_OTH = list()
count_list_PL = list()
count_list_PLBL = list()
count_list_RL = list()
count_list_SCC = list()
count_list_SEL = list()

count_AL = 0
count_BL = 0
count_CC = 0
count_CD = 0
count_CV = 0
count_GL = 0
count_HL = 0
count_LAS = 0
count_MFBL = 0
count_MFHL = 0
count_MFOT = 0
count_OTH = 0
count_PL = 0 
count_PLBL = 0
count_RL = 0
count_SCC = 0
count_SEL = 0

grp_df = df.groupby('ID')

for x in range(0, len(unq_id_list)):
    grp_slice = grp_df.get_group(unq_id_list[x])
    #print(grp_slice) 
    grp_slice.reset_index(drop=True, inplace=True)
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['accountType'][i]=='unknown') or (grp_slice['writeOff'][i]=='unknown') or (grp_slice['month_diff'][i]>24):
            continue
        elif (grp_slice['accountType'][i]=='AL') and (grp_slice['writeOff'][i]==1) and (grp_slice['month_diff'][i]<=24):
            count_AL = count_AL + 1
        elif (grp_slice['accountType'][i]=='BL') and (grp_slice['writeOff'][i]==1) and (grp_slice['month_diff'][i]<=24):
            count_BL = count_BL + 1
        elif (grp_slice['accountType'][i]=='CC') and (grp_slice['writeOff'][i]==1) and (grp_slice['month_diff'][i]<=24):
            count_CC = count_CC + 1
        elif (grp_slice['accountType'][i]=='CD') and (grp_slice['writeOff'][i]==1) and (grp_slice['month_diff'][i]<=24):
            count_CD = count_CD + 1
        elif (grp_slice['accountType'][i]=='CV') and (grp_slice['writeOff'][i]==1) and (grp_slice['month_diff'][i]<=24):
            count_CV = count_CV + 1
        elif (grp_slice['accountType'][i]=='GL') and (grp_slice['writeOff'][i]==1) and (grp_slice['month_diff'][i]<=24):
            count_GL = count_GL + 1
        elif (grp_slice['accountType'][i]=='HL') and (grp_slice['writeOff'][i]==1) and (grp_slice['month_diff'][i]<=24):
            count_HL = count_HL + 1
        elif (grp_slice['accountType'][i]=='LAS') and (grp_slice['writeOff'][i]==1) and (grp_slice['month_diff'][i]<=24):
            count_LAS = count_LAS + 1
        elif (grp_slice['accountType'][i]=='MFBL') and (grp_slice['writeOff'][i]==1) and (grp_slice['month_diff'][i]<=24):
            count_MFBL = count_MFBL + 1
        elif (grp_slice['accountType'][i]=='MFHL') and (grp_slice['writeOff'][i]==1) and (grp_slice['month_diff'][i]<=24):
            count_MFHL = count_MFHL + 1
        elif (grp_slice['accountType'][i]=='MFOT') and (grp_slice['writeOff'][i]==1) and (grp_slice['month_diff'][i]<=24):
            count_MFOT = count_MFOT + 1
        elif (grp_slice['accountType'][i]=='OTH') and (grp_slice['writeOff'][i]==1) and (grp_slice['month_diff'][i]<=24):
            count_OTH = count_OTH + 1
        elif (grp_slice['accountType'][i]=='PL') and (grp_slice['writeOff'][i]==1) and (grp_slice['month_diff'][i]<=24):
            count_PL = count_PL + 1
        elif (grp_slice['accountType'][i]=='PLBL') and (grp_slice['writeOff'][i]==1) and (grp_slice['month_diff'][i]<=24):
            count_PLBL = count_PLBL + 1
        elif (grp_slice['accountType'][i]=='RL') and (grp_slice['writeOff'][i]==1) and (grp_slice['month_diff'][i]<=24):
            count_RL = count_RL + 1
        elif (grp_slice['accountType'][i]=='SCC') and (grp_slice['writeOff'][i]==1) and (grp_slice['month_diff'][i]<=24):
            count_SCC = count_SCC + 1
        elif (grp_slice['accountType'][i]=='SEL') and (grp_slice['writeOff'][i]==1) and (grp_slice['month_diff'][i]<=24):
            count_SEL = count_SEL + 1
            
    count_list_AL.append(count_AL)
    count_list_BL.append(count_BL)
    count_list_CC.append(count_CC)
    count_list_CD.append(count_CD)
    count_list_CV.append(count_CV)
    count_list_GL.append(count_GL)
    count_list_HL.append(count_HL)
    count_list_LAS.append(count_LAS)
    count_list_MFBL.append(count_MFBL)
    count_list_MFHL.append(count_MFHL)
    count_list_MFOT.append(count_MFOT)
    count_list_OTH.append(count_OTH)
    count_list_PL.append(count_PL)
    count_list_PLBL.append(count_PLBL)
    count_list_RL.append(count_RL)
    count_list_SCC.append(count_SCC)
    count_list_SEL.append(count_SEL)
    
    count_AL = 0
    count_BL = 0
    count_CC = 0
    count_CD = 0
    count_CV = 0
    count_GL = 0
    count_HL = 0
    count_LAS = 0
    count_MFBL = 0
    count_MFHL = 0
    count_MFOT = 0
    count_OTH = 0
    count_PL = 0
    count_PLBL = 0
    count_RL = 0
    count_SCC = 0
    count_SEL = 0
    
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['accountType'][i]=='unknown') or (grp_slice['writeOff'][i]=='unknown'):
            writeOff_last2Y_CNT_AL.append('unknown')
            writeOff_last2Y_CNT_BL.append('unknown')
            writeOff_last2Y_CNT_CC.append('unknown')
            writeOff_last2Y_CNT_CD.append('unknown')
            writeOff_last2Y_CNT_CV.append('unknown')
            writeOff_last2Y_CNT_GL.append('unknown')
            writeOff_last2Y_CNT_HL.append('unknown')
            writeOff_last2Y_CNT_LAS.append('unknown')
            writeOff_last2Y_CNT_MFBL.append('unknown')
            writeOff_last2Y_CNT_MFHL.append('unknown')
            writeOff_last2Y_CNT_MFOT.append('unknown')
            writeOff_last2Y_CNT_OTH.append('unknown')
            writeOff_last2Y_CNT_PL.append('unknown')
            writeOff_last2Y_CNT_PLBL.append('unknown')
            writeOff_last2Y_CNT_RL.append('unknown')
            writeOff_last2Y_CNT_SCC.append('unknown')
            writeOff_last2Y_CNT_SEL.append('unknown')
        elif (grp_slice['writeOff'][i]==1) and (grp_slice['month_diff'][i]<=24):
            writeOff_last2Y_CNT_AL.append(count_list_AL[x])
            writeOff_last2Y_CNT_BL.append(count_list_BL[x])
            writeOff_last2Y_CNT_CC.append(count_list_CC[x])
            writeOff_last2Y_CNT_CD.append(count_list_CD[x])
            writeOff_last2Y_CNT_CV.append(count_list_CV[x])
            writeOff_last2Y_CNT_GL.append(count_list_GL[x])
            writeOff_last2Y_CNT_HL.append(count_list_HL[x])
            writeOff_last2Y_CNT_LAS.append(count_list_LAS[x])
            writeOff_last2Y_CNT_MFBL.append(count_list_MFBL[x])
            writeOff_last2Y_CNT_MFHL.append(count_list_MFHL[x])
            writeOff_last2Y_CNT_MFOT.append(count_list_MFOT[x])
            writeOff_last2Y_CNT_OTH.append(count_list_OTH[x])
            writeOff_last2Y_CNT_PL.append(count_list_PL[x])
            writeOff_last2Y_CNT_PLBL.append(count_list_PLBL[x])
            writeOff_last2Y_CNT_RL.append(count_list_RL[x])
            writeOff_last2Y_CNT_SCC.append(count_list_SCC[x])
            writeOff_last2Y_CNT_SEL.append(count_list_SEL[x])
        else:
            writeOff_last2Y_CNT_AL.append(0)
            writeOff_last2Y_CNT_BL.append(0)
            writeOff_last2Y_CNT_CC.append(0)
            writeOff_last2Y_CNT_CD.append(0)
            writeOff_last2Y_CNT_CV.append(0)
            writeOff_last2Y_CNT_GL.append(0)
            writeOff_last2Y_CNT_HL.append(0)
            writeOff_last2Y_CNT_LAS.append(0)
            writeOff_last2Y_CNT_MFBL.append(0)
            writeOff_last2Y_CNT_MFHL.append(0)
            writeOff_last2Y_CNT_MFOT.append(0)
            writeOff_last2Y_CNT_OTH.append(0)
            writeOff_last2Y_CNT_PL.append(0)
            writeOff_last2Y_CNT_PLBL.append(0)
            writeOff_last2Y_CNT_RL.append(0)
            writeOff_last2Y_CNT_SCC.append(0)
            writeOff_last2Y_CNT_SEL.append(0)
            
df['writeOff_last2Y_CNT_AL'] = pd.Series(writeOff_last2Y_CNT_AL).values
df['writeOff_last2Y_CNT_BL'] = pd.Series(writeOff_last2Y_CNT_BL).values
df['writeOff_last2Y_CNT_CC'] = pd.Series(writeOff_last2Y_CNT_CC).values
df['writeOff_last2Y_CNT_CD'] = pd.Series(writeOff_last2Y_CNT_CD).values
df['writeOff_last2Y_CNT_CV'] = pd.Series(writeOff_last2Y_CNT_CV).values
df['writeOff_last2Y_CNT_GL'] = pd.Series(writeOff_last2Y_CNT_GL).values
df['writeOff_last2Y_CNT_HL'] = pd.Series(writeOff_last2Y_CNT_HL).values
df['writeOff_last2Y_CNT_LAS'] = pd.Series(writeOff_last2Y_CNT_LAS).values
df['writeOff_last2Y_CNT_MFBL'] = pd.Series(writeOff_last2Y_CNT_MFBL).values
df['writeOff_last2Y_CNT_MFHL'] = pd.Series(writeOff_last2Y_CNT_MFHL).values
df['writeOff_last2Y_CNT_MFOT'] = pd.Series(writeOff_last2Y_CNT_MFOT).values
df['writeOff_last2Y_CNT_OTH'] = pd.Series(writeOff_last2Y_CNT_OTH).values
df['writeOff_last2Y_CNT_PL'] = pd.Series(writeOff_last2Y_CNT_PL).values
df['writeOff_last2Y_CNT_PLBL'] = pd.Series(writeOff_last2Y_CNT_PLBL).values
df['writeOff_last2Y_CNT_RL'] = pd.Series(writeOff_last2Y_CNT_RL).values
df['writeOff_last2Y_CNT_SCC'] = pd.Series(writeOff_last2Y_CNT_SCC).values
df['writeOff_last2Y_CNT_SEL'] = pd.Series(writeOff_last2Y_CNT_SEL).values
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/envs/ml_env/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'writeOff'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-248-6680d9914142> in <module>
#      60     grp_slice.reset_index(drop=True, inplace=True)
#      61     for i in range(0, grp_slice.shape[0]):
# ---> 62         if (grp_slice['accountType'][i]=='unknown') or (grp_slice['writeOff'][i]=='unknown') or (grp_slice['month_diff'][i]>24):
#      63             continue
#      64         elif (grp_slice['accountType'][i]=='AL') and (grp_slice['writeOff'][i]==1) and (grp_slice['month_diff'][i]<=24):
#
# ~/anaconda3/envs/ml_env/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2900             if self.columns.nlevels > 1:
#    2901                 return self._getitem_multilevel(key)
# -> 2902             indexer = self.columns.get_loc(key)
#    2903             if is_integer(indexer):
#    2904                 indexer = [indexer]
#
# ~/anaconda3/envs/ml_env/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
# -> 2897                 raise KeyError(key) from err
#    2898
#    2899         if tolerance is not None:
#
# KeyError: 'writeOff'

# %% [raw]
# d = df[['ID','writeOff_last2Y_CNT_CC','accountType','writeOff_last2Y_CNT','writeOff', 'month_diff']]
# d[d['writeOff']==1][0:60]

# %% [markdown]
# ### Code for writeOff_last3Y_CNT

# %% [markdown]
# Count of accounts written off in recent 3 year<br>
# For an applicant, count all the accounts where wo_set_flag ==1 and difference between login date and datereportedorcertified <= 3 years

# %%
writeOff_last3Y_CNT = list()
count_list = list()
count = 0

grp_df = df.groupby('ID')

for x in range(0, len(unq_id_list)):
    grp_slice = grp_df.get_group(unq_id_list[x])
    #print(grp_slice)
    grp_slice.reset_index(drop=True, inplace=True)
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['month_diff'][i] == 'unknown') or (grp_slice['writeOff'][i]=='unknown'):
            continue
        elif (grp_slice['month_diff'][i]<=36) and (grp_slice['writeOff'][i]==1): 
            count = count + grp_slice['writeOff'][i]
            
    count_list.append(count)
    count = 0
    
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['month_diff'][i] == 'unknown') or (grp_slice['writeOff'][i]=='unknown'):
            writeOff_last3Y_CNT.append('unknown')
        elif (grp_slice['month_diff'][i]<=36) and (grp_slice['writeOff'][i]==1):
            writeOff_last3Y_CNT.append(count_list[x])
        else:
            writeOff_last3Y_CNT.append(0)
            
df['writeOff_last3Y_CNT'] = pd.Series(writeOff_last3Y_CNT).values

#df.drop(['month_diff'], axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/envs/ml_env/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'month_diff'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-249-2051f8b15440> in <module>
#      10     grp_slice.reset_index(drop=True, inplace=True)
#      11     for i in range(0, grp_slice.shape[0]):
# ---> 12         if (grp_slice['month_diff'][i] == 'unknown') or (grp_slice['writeOff'][i]=='unknown'):
#      13             continue
#      14         elif (grp_slice['month_diff'][i]<=36) and (grp_slice['writeOff'][i]==1):
#
# ~/anaconda3/envs/ml_env/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2900             if self.columns.nlevels > 1:
#    2901                 return self._getitem_multilevel(key)
# -> 2902             indexer = self.columns.get_loc(key)
#    2903             if is_integer(indexer):
#    2904                 indexer = [indexer]
#
# ~/anaconda3/envs/ml_env/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
# -> 2897                 raise KeyError(key) from err
#    2898
#    2899         if tolerance is not None:
#
# KeyError: 'month_diff'

# %%
df['writeOff_last3Y_CNT'].value_counts()

# %% [markdown]
# ### Code for writeOff_last3Y_CNT_P

# %% [markdown]
# - Count of accounts written off in recent 3 years per product
# - For an applicant, count all the accounts per product where wo_set_flag ==1 and difference between login date and datereportedorcertified <= 3 years

# %%
writeOff_last3Y_CNT_AL = list()
writeOff_last3Y_CNT_BL = list()
writeOff_last3Y_CNT_CC = list()
writeOff_last3Y_CNT_CD = list()
writeOff_last3Y_CNT_CV = list()
writeOff_last3Y_CNT_GL = list()
writeOff_last3Y_CNT_HL = list()
writeOff_last3Y_CNT_LAS = list()
writeOff_last3Y_CNT_MFBL = list()
writeOff_last3Y_CNT_MFHL = list()
writeOff_last3Y_CNT_MFOT = list()
writeOff_last3Y_CNT_OTH = list()
writeOff_last3Y_CNT_PL = list()
writeOff_last3Y_CNT_PLBL = list()
writeOff_last3Y_CNT_RL = list()
writeOff_last3Y_CNT_SCC = list()
writeOff_last3Y_CNT_SEL = list()

count_list_AL = list()
count_list_BL = list()
count_list_CC = list()
count_list_CD = list()
count_list_CV = list()
count_list_GL = list()
count_list_HL = list()
count_list_LAS = list()
count_list_MFBL = list()
count_list_MFHL = list()
count_list_MFOT = list()
count_list_OTH = list()
count_list_PL = list()
count_list_PLBL = list()
count_list_RL = list()
count_list_SCC = list()
count_list_SEL = list()

count_AL = 0
count_BL = 0
count_CC = 0
count_CD = 0
count_CV = 0
count_GL = 0
count_HL = 0
count_LAS = 0
count_MFBL = 0
count_MFHL = 0
count_MFOT = 0
count_OTH = 0
count_PL = 0 
count_PLBL = 0
count_RL = 0
count_SCC = 0
count_SEL = 0

grp_df = df.groupby('ID')

for x in range(0, len(unq_id_list)):
    grp_slice = grp_df.get_group(unq_id_list[x])
    #print(grp_slice) 
    grp_slice.reset_index(drop=True, inplace=True)
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['accountType'][i]=='unknown') or (grp_slice['writeOff'][i]=='unknown') or (grp_slice['month_diff'][i]>36):
            continue
        elif (grp_slice['accountType'][i]=='AL') and (grp_slice['writeOff'][i]==1) and (grp_slice['month_diff'][i]<=36):
            count_AL = count_AL + 1
        elif (grp_slice['accountType'][i]=='BL') and (grp_slice['writeOff'][i]==1) and (grp_slice['month_diff'][i]<=36):
            count_BL = count_BL + 1
        elif (grp_slice['accountType'][i]=='CC') and (grp_slice['writeOff'][i]==1) and (grp_slice['month_diff'][i]<=36):
            count_CC = count_CC + 1
        elif (grp_slice['accountType'][i]=='CD') and (grp_slice['writeOff'][i]==1) and (grp_slice['month_diff'][i]<=36):
            count_CD = count_CD + 1
        elif (grp_slice['accountType'][i]=='CV') and (grp_slice['writeOff'][i]==1) and (grp_slice['month_diff'][i]<=36):
            count_CV = count_CV + 1
        elif (grp_slice['accountType'][i]=='GL') and (grp_slice['writeOff'][i]==1) and (grp_slice['month_diff'][i]<=36):
            count_GL = count_GL + 1
        elif (grp_slice['accountType'][i]=='HL') and (grp_slice['writeOff'][i]==1) and (grp_slice['month_diff'][i]<=36):
            count_HL = count_HL + 1
        elif (grp_slice['accountType'][i]=='LAS') and (grp_slice['writeOff'][i]==1) and (grp_slice['month_diff'][i]<=36):
            count_LAS = count_LAS + 1
        elif (grp_slice['accountType'][i]=='MFBL') and (grp_slice['writeOff'][i]==1) and (grp_slice['month_diff'][i]<=36):
            count_MFBL = count_MFBL + 1
        elif (grp_slice['accountType'][i]=='MFHL') and (grp_slice['writeOff'][i]==1) and (grp_slice['month_diff'][i]<=36):
            count_MFHL = count_MFHL + 1
        elif (grp_slice['accountType'][i]=='MFOT') and (grp_slice['writeOff'][i]==1) and (grp_slice['month_diff'][i]<=36):
            count_MFOT = count_MFOT + 1
        elif (grp_slice['accountType'][i]=='OTH') and (grp_slice['writeOff'][i]==1) and (grp_slice['month_diff'][i]<=36):
            count_OTH = count_OTH + 1
        elif (grp_slice['accountType'][i]=='PL') and (grp_slice['writeOff'][i]==1) and (grp_slice['month_diff'][i]<=36):
            count_PL = count_PL + 1
        elif (grp_slice['accountType'][i]=='PLBL') and (grp_slice['writeOff'][i]==1) and (grp_slice['month_diff'][i]<=36):
            count_PLBL = count_PLBL + 1
        elif (grp_slice['accountType'][i]=='RL') and (grp_slice['writeOff'][i]==1) and (grp_slice['month_diff'][i]<=36):
            count_RL = count_RL + 1
        elif (grp_slice['accountType'][i]=='SCC') and (grp_slice['writeOff'][i]==1) and (grp_slice['month_diff'][i]<=36):
            count_SCC = count_SCC + 1
        elif (grp_slice['accountType'][i]=='SEL') and (grp_slice['writeOff'][i]==1) and (grp_slice['month_diff'][i]<=36):
            count_SEL = count_SEL + 1
            
    count_list_AL.append(count_AL)
    count_list_BL.append(count_BL)
    count_list_CC.append(count_CC)
    count_list_CD.append(count_CD)
    count_list_CV.append(count_CV)
    count_list_GL.append(count_GL)
    count_list_HL.append(count_HL)
    count_list_LAS.append(count_LAS)
    count_list_MFBL.append(count_MFBL)
    count_list_MFHL.append(count_MFHL)
    count_list_MFOT.append(count_MFOT)
    count_list_OTH.append(count_OTH)
    count_list_PL.append(count_PL)
    count_list_PLBL.append(count_PLBL)
    count_list_RL.append(count_RL)
    count_list_SCC.append(count_SCC)
    count_list_SEL.append(count_SEL)
    
    count_AL = 0
    count_BL = 0
    count_CC = 0
    count_CD = 0
    count_CV = 0
    count_GL = 0
    count_HL = 0
    count_LAS = 0
    count_MFBL = 0
    count_MFHL = 0
    count_MFOT = 0
    count_OTH = 0
    count_PL = 0
    count_PLBL = 0
    count_RL = 0
    count_SCC = 0
    count_SEL = 0
    
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['accountType'][i]=='unknown') or (grp_slice['writeOff'][i]=='unknown'):
            writeOff_last3Y_CNT_AL.append('unknown')
            writeOff_last3Y_CNT_BL.append('unknown')
            writeOff_last3Y_CNT_CC.append('unknown')
            writeOff_last3Y_CNT_CD.append('unknown')
            writeOff_last3Y_CNT_CV.append('unknown')
            writeOff_last3Y_CNT_GL.append('unknown')
            writeOff_last3Y_CNT_HL.append('unknown')
            writeOff_last3Y_CNT_LAS.append('unknown')
            writeOff_last3Y_CNT_MFBL.append('unknown')
            writeOff_last3Y_CNT_MFHL.append('unknown')
            writeOff_last3Y_CNT_MFOT.append('unknown')
            writeOff_last3Y_CNT_OTH.append('unknown')
            writeOff_last3Y_CNT_PL.append('unknown')
            writeOff_last3Y_CNT_PLBL.append('unknown')
            writeOff_last3Y_CNT_RL.append('unknown')
            writeOff_last3Y_CNT_SCC.append('unknown')
            writeOff_last3Y_CNT_SEL.append('unknown')
        elif (grp_slice['writeOff'][i]==1) and (grp_slice['month_diff'][i]<=36):
            writeOff_last3Y_CNT_AL.append(count_list_AL[x])
            writeOff_last3Y_CNT_BL.append(count_list_BL[x])
            writeOff_last3Y_CNT_CC.append(count_list_CC[x])
            writeOff_last3Y_CNT_CD.append(count_list_CD[x])
            writeOff_last3Y_CNT_CV.append(count_list_CV[x])
            writeOff_last3Y_CNT_GL.append(count_list_GL[x])
            writeOff_last3Y_CNT_HL.append(count_list_HL[x])
            writeOff_last3Y_CNT_LAS.append(count_list_LAS[x])
            writeOff_last3Y_CNT_MFBL.append(count_list_MFBL[x])
            writeOff_last3Y_CNT_MFHL.append(count_list_MFHL[x])
            writeOff_last3Y_CNT_MFOT.append(count_list_MFOT[x])
            writeOff_last3Y_CNT_OTH.append(count_list_OTH[x])
            writeOff_last3Y_CNT_PL.append(count_list_PL[x])
            writeOff_last3Y_CNT_PLBL.append(count_list_PLBL[x])
            writeOff_last3Y_CNT_RL.append(count_list_RL[x])
            writeOff_last3Y_CNT_SCC.append(count_list_SCC[x])
            writeOff_last3Y_CNT_SEL.append(count_list_SEL[x])
        else:
            writeOff_last3Y_CNT_AL.append(0)
            writeOff_last3Y_CNT_BL.append(0)
            writeOff_last3Y_CNT_CC.append(0)
            writeOff_last3Y_CNT_CD.append(0)
            writeOff_last3Y_CNT_CV.append(0)
            writeOff_last3Y_CNT_GL.append(0)
            writeOff_last3Y_CNT_HL.append(0)
            writeOff_last3Y_CNT_LAS.append(0)
            writeOff_last3Y_CNT_MFBL.append(0)
            writeOff_last3Y_CNT_MFHL.append(0)
            writeOff_last3Y_CNT_MFOT.append(0)
            writeOff_last3Y_CNT_OTH.append(0)
            writeOff_last3Y_CNT_PL.append(0)
            writeOff_last3Y_CNT_PLBL.append(0)
            writeOff_last3Y_CNT_RL.append(0)
            writeOff_last3Y_CNT_SCC.append(0)
            writeOff_last3Y_CNT_SEL.append(0)
            
df['writeOff_last3Y_CNT_AL'] = pd.Series(writeOff_last3Y_CNT_AL).values
df['writeOff_last3Y_CNT_BL'] = pd.Series(writeOff_last3Y_CNT_BL).values
df['writeOff_last3Y_CNT_CC'] = pd.Series(writeOff_last3Y_CNT_CC).values
df['writeOff_last3Y_CNT_CD'] = pd.Series(writeOff_last3Y_CNT_CD).values
df['writeOff_last3Y_CNT_CV'] = pd.Series(writeOff_last3Y_CNT_CV).values
df['writeOff_last3Y_CNT_GL'] = pd.Series(writeOff_last3Y_CNT_GL).values
df['writeOff_last3Y_CNT_HL'] = pd.Series(writeOff_last3Y_CNT_HL).values
df['writeOff_last3Y_CNT_LAS'] = pd.Series(writeOff_last3Y_CNT_LAS).values
df['writeOff_last3Y_CNT_MFBL'] = pd.Series(writeOff_last3Y_CNT_MFBL).values
df['writeOff_last3Y_CNT_MFHL'] = pd.Series(writeOff_last3Y_CNT_MFHL).values
df['writeOff_last3Y_CNT_MFOT'] = pd.Series(writeOff_last3Y_CNT_MFOT).values
df['writeOff_last3Y_CNT_OTH'] = pd.Series(writeOff_last3Y_CNT_OTH).values
df['writeOff_last3Y_CNT_PL'] = pd.Series(writeOff_last3Y_CNT_PL).values
df['writeOff_last3Y_CNT_PLBL'] = pd.Series(writeOff_last3Y_CNT_PLBL).values
df['writeOff_last3Y_CNT_RL'] = pd.Series(writeOff_last3Y_CNT_RL).values
df['writeOff_last3Y_CNT_SCC'] = pd.Series(writeOff_last3Y_CNT_SCC).values
df['writeOff_last3Y_CNT_SEL'] = pd.Series(writeOff_last3Y_CNT_SEL).values
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/envs/ml_env/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'writeOff'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-250-f1874a30a1a6> in <module>
#      60     grp_slice.reset_index(drop=True, inplace=True)
#      61     for i in range(0, grp_slice.shape[0]):
# ---> 62         if (grp_slice['accountType'][i]=='unknown') or (grp_slice['writeOff'][i]=='unknown') or (grp_slice['month_diff'][i]>36):
#      63             continue
#      64         elif (grp_slice['accountType'][i]=='AL') and (grp_slice['writeOff'][i]==1) and (grp_slice['month_diff'][i]<=36):
#
# ~/anaconda3/envs/ml_env/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2900             if self.columns.nlevels > 1:
#    2901                 return self._getitem_multilevel(key)
# -> 2902             indexer = self.columns.get_loc(key)
#    2903             if is_integer(indexer):
#    2904                 indexer = [indexer]
#
# ~/anaconda3/envs/ml_env/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
# -> 2897                 raise KeyError(key) from err
#    2898
#    2899         if tolerance is not None:
#
# KeyError: 'writeOff'

# %% [raw]
# d = df[['ID','writeOff_last3Y_CNT_AL','accountType','writeOff_last3Y_CNT','writeOff', 'month_diff']]
# d[d['writeOff']==1][0:60]

# %% [markdown]
# ### Code for writeOff_last1Y_PLT1K_CNT

# %% [markdown]
# - Count of accounts written off or settled in recent 1 year and written off principal or settled amount is greater than 0 and <1000
# - For an applicant, count of accounts where wo_set_flag==1 and difference between login date and datereportedorcertified <=1 year and written off principal is not null and not equal to 0 and <1000, else if settled amount  is not null and not equal to 0 and <1000

# %%
df['writtenOffAmountPrincipal'].fillna('unknown', inplace=True)

# %%
writeOff_last1Y_PLT1K_CNT = list()
count_list = list()
count = 0

grp_df = df.groupby('ID')

for x in range(0, len(unq_id_list)):
    grp_slice = grp_df.get_group(unq_id_list[x])
    #print(grp_slice)
    grp_slice.reset_index(drop=True, inplace=True)
    #print(grp_slice.shape[0])
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['month_diff'][i]=='unknown') or (grp_slice['writeOff'][i]=='unknown') or (grp_slice['writtenOffAmountPrincipal'][i]=='unknown'):
            continue
        elif ((grp_slice['month_diff'][i]<=12) and (grp_slice['writeOff'][i]==1) and (grp_slice['writtenOffAmountPrincipal'][i]>=1000)):
            count = count + 1
            
    count_list.append(count)
    count = 0
    
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['month_diff'][i]=='unknown') or (grp_slice['writeOff'][i]=='unknown') or (grp_slice['writtenOffAmountPrincipal'][i]=='unknown'):
            writeOff_last1Y_PLT1K_CNT.append('unknown')
        elif ((grp_slice['month_diff'][i]<=12) and (grp_slice['writeOff'][i]==1) and (grp_slice['writtenOffAmountPrincipal'][i]>=1000)):
            writeOff_last1Y_PLT1K_CNT.append(count_list[x])
        else:
            writeOff_last1Y_PLT1K_CNT.append(0)
            
df['writeOff_last1Y_PLT1K_CNT'] = pd.Series(writeOff_last1Y_PLT1K_CNT).values
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/envs/ml_env/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'month_diff'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-252-4fe36a36faab> in <module>
#      11     #print(grp_slice.shape[0])
#      12     for i in range(0, grp_slice.shape[0]):
# ---> 13         if (grp_slice['month_diff'][i]=='unknown') or (grp_slice['writeOff'][i]=='unknown') or (grp_slice['writtenOffAmountPrincipal'][i]=='unknown'):
#      14             continue
#      15         elif ((grp_slice['month_diff'][i]<=12) and (grp_slice['writeOff'][i]==1) and (grp_slice['writtenOffAmountPrincipal'][i]>=1000)):
#
# ~/anaconda3/envs/ml_env/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2900             if self.columns.nlevels > 1:
#    2901                 return self._getitem_multilevel(key)
# -> 2902             indexer = self.columns.get_loc(key)
#    2903             if is_integer(indexer):
#    2904                 indexer = [indexer]
#
# ~/anaconda3/envs/ml_env/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
# -> 2897                 raise KeyError(key) from err
#    2898
#    2899         if tolerance is not None:
#
# KeyError: 'month_diff'

# %% [raw]
# a = df[['ID','writeOff_last1Y_PLT1K_CNT','month_diff','writeOff','writtenOffAmountPrincipal']]
# a[a['writeOff']==1].head(50)

# %%
df['writeOff_last1Y_PLT1K_CNT'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/envs/ml_env/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'writeOff_last1Y_PLT1K_CNT'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-253-c03c837ae0f9> in <module>
# ----> 1 df['writeOff_last1Y_PLT1K_CNT'].value_counts()
#
# ~/anaconda3/envs/ml_env/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2900             if self.columns.nlevels > 1:
#    2901                 return self._getitem_multilevel(key)
# -> 2902             indexer = self.columns.get_loc(key)
#    2903             if is_integer(indexer):
#    2904                 indexer = [indexer]
#
# ~/anaconda3/envs/ml_env/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
# -> 2897                 raise KeyError(key) from err
#    2898
#    2899         if tolerance is not None:
#
# KeyError: 'writeOff_last1Y_PLT1K_CNT'

# %% [raw]
# df[df['writeOff_last1Y_PLT1K_CNT']==1][['ID','writeOff_last1Y_PLT1K_CNT','month_diff','writeOff','writtenOffAmountPrincipal']]

# %% [raw]
# df[df['writeOff_last1Y_PLT1K_CNT']==2][['ID','writeOff_last1Y_PLT1K_CNT','month_diff','writeOff','writtenOffAmountPrincipal']]

# %% [markdown]
# ### Code for writeOff_last2Y_PLT1K_CNT

# %% [markdown]
# - Count of accounts written off or settled in recent 2 years and written off principal or settled amount is greater than 0 and <1000
# - For an applicant, count of accounts where wo_set_flag==1 and difference between login date and datereportedorcertified <=2 years and written off principal is not null and not equal to 0 and <1000, else if settled amount  is not null and not equal to 0 and <1000

# %%
writeOff_last2Y_PLT1K_CNT = list()
count_list = list()
count = 0

grp_df = df.groupby('ID')

for x in range(0, len(unq_id_list)):
    grp_slice = grp_df.get_group(unq_id_list[x])
    #print(grp_slice)
    grp_slice.reset_index(drop=True, inplace=True)
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['month_diff'][i]=='unknown') or (grp_slice['writeOff'][i]=='unknown') or (grp_slice['writtenOffAmountPrincipal'][i]=='unknown'):
            continue
        elif ((grp_slice['month_diff'][i]<=24) and (grp_slice['writeOff'][i]==1) and (grp_slice['writtenOffAmountPrincipal'][i]>=1000)):
            count = count + 1
            
    count_list.append(count)
    count = 0
    
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['month_diff'][i]=='unknown') or (grp_slice['writeOff'][i]=='unknown') or (grp_slice['writtenOffAmountPrincipal'][i]=='unknown'):
            writeOff_last2Y_PLT1K_CNT.append('unknown')
        elif ((grp_slice['month_diff'][i]<=24) and (grp_slice['writeOff'][i]==1) and (grp_slice['writtenOffAmountPrincipal'][i]>=1000)):
            writeOff_last2Y_PLT1K_CNT.append(count_list[x])
        else:
            writeOff_last2Y_PLT1K_CNT.append(0)
            
df['writeOff_last2Y_PLT1K_CNT'] = pd.Series(writeOff_last2Y_PLT1K_CNT).values
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/envs/ml_env/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'month_diff'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-254-7fe7e074de97> in <module>
#      10     grp_slice.reset_index(drop=True, inplace=True)
#      11     for i in range(0, grp_slice.shape[0]):
# ---> 12         if (grp_slice['month_diff'][i]=='unknown') or (grp_slice['writeOff'][i]=='unknown') or (grp_slice['writtenOffAmountPrincipal'][i]=='unknown'):
#      13             continue
#      14         elif ((grp_slice['month_diff'][i]<=24) and (grp_slice['writeOff'][i]==1) and (grp_slice['writtenOffAmountPrincipal'][i]>=1000)):
#
# ~/anaconda3/envs/ml_env/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2900             if self.columns.nlevels > 1:
#    2901                 return self._getitem_multilevel(key)
# -> 2902             indexer = self.columns.get_loc(key)
#    2903             if is_integer(indexer):
#    2904                 indexer = [indexer]
#
# ~/anaconda3/envs/ml_env/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
# -> 2897                 raise KeyError(key) from err
#    2898
#    2899         if tolerance is not None:
#
# KeyError: 'month_diff'

# %%
df['writeOff_last2Y_PLT1K_CNT'].value_counts()

# %% [raw]
# df[df['writeOff_last2Y_PLT1K_CNT']==1][['ID','writeOff_last2Y_PLT1K_CNT','month_diff','writeOff','writtenOffAmountPrincipal']]

# %% [markdown]
# ### Code for writeOff_last3Y_PLT1K_CNT

# %% [markdown]
# - Count of accounts written off or settled in recent 3 years and written off principal or settled amount is greater than 0 and <1000
# - For an applicant, count of accounts where wo_set_flag==1 and difference between login date and datereportedorcertified <=3 years and written off principal is not null and not equal to 0 and <1000, else if settled amount  is not null and not equal to 0 and <1000

# %%
writeOff_last3Y_PLT1K_CNT = list()
count_list = list()
count = 0

grp_df = df.groupby('ID')

for x in range(0, len(unq_id_list)):
    grp_slice = grp_df.get_group(unq_id_list[x])
    #print(grp_slice)
    grp_slice.reset_index(drop=True, inplace=True)
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['month_diff'][i]=='unknown') or (grp_slice['writeOff'][i]=='unknown') or (grp_slice['writtenOffAmountPrincipal'][i]=='unknown'):
            continue
        elif ((grp_slice['month_diff'][i]<=36) and (grp_slice['writeOff'][i]==1) and (grp_slice['writtenOffAmountPrincipal'][i]>=1000)):
            count = count + 1
            
    count_list.append(count)
    count = 0
    
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['month_diff'][i]=='unknown') or (grp_slice['writeOff'][i]=='unknown') or (grp_slice['writtenOffAmountPrincipal'][i]=='unknown'):
            writeOff_last3Y_PLT1K_CNT.append('unknown')
        elif ((grp_slice['month_diff'][i]<=36) and (grp_slice['writeOff'][i]==1) and (grp_slice['writtenOffAmountPrincipal'][i]>=1000)):
            writeOff_last3Y_PLT1K_CNT.append(count_list[x])
        else:
            writeOff_last3Y_PLT1K_CNT.append(0)
            
df['writeOff_last3Y_PLT1K_CNT'] = pd.Series(writeOff_last3Y_PLT1K_CNT).values
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/envs/ml_env/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'month_diff'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-255-2cd254da6927> in <module>
#      10     grp_slice.reset_index(drop=True, inplace=True)
#      11     for i in range(0, grp_slice.shape[0]):
# ---> 12         if (grp_slice['month_diff'][i]=='unknown') or (grp_slice['writeOff'][i]=='unknown') or (grp_slice['writtenOffAmountPrincipal'][i]=='unknown'):
#      13             continue
#      14         elif ((grp_slice['month_diff'][i]<=36) and (grp_slice['writeOff'][i]==1) and (grp_slice['writtenOffAmountPrincipal'][i]>=1000)):
#
# ~/anaconda3/envs/ml_env/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2900             if self.columns.nlevels > 1:
#    2901                 return self._getitem_multilevel(key)
# -> 2902             indexer = self.columns.get_loc(key)
#    2903             if is_integer(indexer):
#    2904                 indexer = [indexer]
#
# ~/anaconda3/envs/ml_env/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
# -> 2897                 raise KeyError(key) from err
#    2898
#    2899         if tolerance is not None:
#
# KeyError: 'month_diff'

# %%
df['writeOff_last3Y_PLT1K_CNT'].value_counts()

# %% [markdown]
# <a id='opened_last_CNT'></a>
# ### Code for opened_last3M_CNT

# %% [markdown]
# - Count of all the loans opened in recent 3 months
# - For an applicant, count of all loan accounts where difference between DateOpened and Login Date is <=3 months

# %%
df['dateOpenedOrDisbursed'].fillna('unknown', inplace=True)

# %%
mo_diff_do_ld = list()

for x in range(0, df.shape[0]):
    if (df['dateOpenedOrDisbursed'][x]=='unknown'):
        mo_diff_do_ld.append('unknown')
    else:
        mo_diff = diff_month(df['loginDate'][x], df['dateOpenedOrDisbursed'][x])
        mo_diff_do_ld.append(mo_diff)

df['mo_diff_do_ld'] = pd.Series(mo_diff_do_ld).values

# %%
opened_last3M_CNT = list()
count_list = list()
count = 0

grp_df = df.groupby('ID')

for x in range(0, len(unq_id_list)):
    grp_slice = grp_df.get_group(unq_id_list[x])
    #print(grp_slice)
    grp_slice.reset_index(drop=True, inplace=True)
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['mo_diff_do_ld'][i]=='unknown'):
            continue
        elif (grp_slice['mo_diff_do_ld'][i]<=3):
            count = count + 1
        else:
            continue
    count_list.append(count)
    count = 0
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['mo_diff_do_ld'][i]=='unknown'):
            opened_last3M_CNT.append('unknown')
        elif (grp_slice['mo_diff_do_ld'][i]<=3):
            opened_last3M_CNT.append(count_list[x])
        else:
            opened_last3M_CNT.append(0)
        
            
df['opened_last3M_CNT'] = pd.Series(opened_last3M_CNT).values

# %%
df['opened_last3M_CNT'].value_counts()
# Out:
# 0          3991
# unknown     337
# 1            58
# 2            30
# 3            21
# 18           18
# 7             7
# Name: opened_last3M_CNT, dtype: int64

# %% [markdown]
# ### Code for opened_last3M_CNT_P

# %% [markdown]
# - Count of all the loans opened in recent 3 months per product
# - For an applicant, count of all loan accounts where difference between DateOpened and Login Date is <=3 months per product

# %%
opened_last3M_CNT_AL = list()
opened_last3M_CNT_BL = list()
opened_last3M_CNT_CC = list()
opened_last3M_CNT_CD = list()
opened_last3M_CNT_CV = list()
opened_last3M_CNT_GL = list()
opened_last3M_CNT_HL = list()
opened_last3M_CNT_LAS = list()
opened_last3M_CNT_MFBL = list()
opened_last3M_CNT_MFHL = list()
opened_last3M_CNT_MFOT = list()
opened_last3M_CNT_OTH = list()
opened_last3M_CNT_PL = list()
opened_last3M_CNT_PLBL = list()
opened_last3M_CNT_RL = list()
opened_last3M_CNT_SCC = list()
opened_last3M_CNT_SEL = list()

count_list_AL = list()
count_list_BL = list()
count_list_CC = list()
count_list_CD = list()
count_list_CV = list()
count_list_GL = list()
count_list_HL = list()
count_list_LAS = list()
count_list_MFBL = list()
count_list_MFHL = list()
count_list_MFOT = list()
count_list_OTH = list()
count_list_PL = list()
count_list_PLBL = list()
count_list_RL = list()
count_list_SCC = list()
count_list_SEL = list()

count_AL = 0
count_BL = 0
count_CC = 0
count_CD = 0
count_CV = 0
count_GL = 0
count_HL = 0
count_LAS = 0
count_MFBL = 0
count_MFHL = 0
count_MFOT = 0
count_OTH = 0
count_PL = 0 
count_PLBL = 0
count_RL = 0
count_SCC = 0
count_SEL = 0

grp_df = df.groupby('ID')

for x in range(0, len(unq_id_list)):
    grp_slice = grp_df.get_group(unq_id_list[x])
    #print(grp_slice) 
    grp_slice.reset_index(drop=True, inplace=True)
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['mo_diff_do_ld'][i]=='unknown'):
            continue
        elif (grp_slice['accountType'][i]=='AL') and (grp_slice['mo_diff_do_ld'][i]<=3):
            count_AL = count_AL + 1
        elif (grp_slice['accountType'][i]=='BL') and (grp_slice['mo_diff_do_ld'][i]<=3):
            count_BL = count_BL + 1
        elif (grp_slice['accountType'][i]=='CC') and (grp_slice['mo_diff_do_ld'][i]<=3):
            count_CC = count_CC + 1
        elif (grp_slice['accountType'][i]=='CD') and (grp_slice['mo_diff_do_ld'][i]<=3):
            count_CD = count_CD + 1
        elif (grp_slice['accountType'][i]=='CV') and (grp_slice['mo_diff_do_ld'][i]<=3):
            count_CV = count_CV + 1
        elif (grp_slice['accountType'][i]=='GL') and (grp_slice['mo_diff_do_ld'][i]<=3):
            count_GL = count_GL + 1
        elif (grp_slice['accountType'][i]=='HL') and (grp_slice['mo_diff_do_ld'][i]<=3):
            count_HL = count_HL + 1
        elif (grp_slice['accountType'][i]=='LAS') and (grp_slice['mo_diff_do_ld'][i]<=3):
            count_LAS = count_LAS + 1
        elif (grp_slice['accountType'][i]=='MFBL') and (grp_slice['mo_diff_do_ld'][i]<=3):
            count_MFBL = count_MFBL + 1
        elif (grp_slice['accountType'][i]=='MFHL') and (grp_slice['mo_diff_do_ld'][i]<=3):
            count_MFHL = count_MFHL + 1
        elif (grp_slice['accountType'][i]=='MFOT') and (grp_slice['mo_diff_do_ld'][i]<=3):
            count_MFOT = count_MFOT + 1
        elif (grp_slice['accountType'][i]=='OTH') and (grp_slice['mo_diff_do_ld'][i]<=3):
            count_OTH = count_OTH + 1
        elif (grp_slice['accountType'][i]=='PL') and (grp_slice['mo_diff_do_ld'][i]<=3):
            count_PL = count_PL + 1
        elif (grp_slice['accountType'][i]=='PLBL') and (grp_slice['mo_diff_do_ld'][i]<=3):
            count_PLBL = count_PLBL + 1
        elif (grp_slice['accountType'][i]=='RL') and (grp_slice['mo_diff_do_ld'][i]<=3):
            count_RL = count_RL + 1
        elif (grp_slice['accountType'][i]=='SCC') and (grp_slice['mo_diff_do_ld'][i]<=3):
            count_SCC = count_SCC + 1
        elif (grp_slice['accountType'][i]=='SEL') and (grp_slice['mo_diff_do_ld'][i]<=3):
            count_SEL = count_SEL + 1
            
    count_list_AL.append(count_AL)
    count_list_BL.append(count_BL)
    count_list_CC.append(count_CC)
    count_list_CD.append(count_CD)
    count_list_CV.append(count_CV)
    count_list_GL.append(count_GL)
    count_list_HL.append(count_HL)
    count_list_LAS.append(count_LAS)
    count_list_MFBL.append(count_MFBL)
    count_list_MFHL.append(count_MFHL)
    count_list_MFOT.append(count_MFOT)
    count_list_OTH.append(count_OTH)
    count_list_PL.append(count_PL)
    count_list_PLBL.append(count_PLBL)
    count_list_RL.append(count_RL)
    count_list_SCC.append(count_SCC)
    count_list_SEL.append(count_SEL)
    
    count_AL = 0
    count_BL = 0
    count_CC = 0
    count_CD = 0
    count_CV = 0
    count_GL = 0
    count_HL = 0
    count_LAS = 0
    count_MFBL = 0
    count_MFHL = 0
    count_MFOT = 0
    count_OTH = 0
    count_PL = 0
    count_PLBL = 0
    count_RL = 0
    count_SCC = 0
    count_SEL = 0
    
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['mo_diff_do_ld'][i]=='unknown'):
            opened_last3M_CNT_AL.append('unknown')
            opened_last3M_CNT_BL.append('unknown')
            opened_last3M_CNT_CC.append('unknown')
            opened_last3M_CNT_CD.append('unknown')
            opened_last3M_CNT_CV.append('unknown')
            opened_last3M_CNT_GL.append('unknown')
            opened_last3M_CNT_HL.append('unknown')
            opened_last3M_CNT_LAS.append('unknown')
            opened_last3M_CNT_MFBL.append('unknown')
            opened_last3M_CNT_MFHL.append('unknown')
            opened_last3M_CNT_MFOT.append('unknown')
            opened_last3M_CNT_OTH.append('unknown')
            opened_last3M_CNT_PL.append('unknown')
            opened_last3M_CNT_PLBL.append('unknown')
            opened_last3M_CNT_RL.append('unknown')
            opened_last3M_CNT_SCC.append('unknown')
            opened_last3M_CNT_SEL.append('unknown')
        #elif (grp_slice['mo_diff_do_ld'][i]<=3):
        else:
            opened_last3M_CNT_AL.append(count_list_AL[x])
            opened_last3M_CNT_BL.append(count_list_BL[x])
            opened_last3M_CNT_CC.append(count_list_CC[x])
            opened_last3M_CNT_CD.append(count_list_CD[x])
            opened_last3M_CNT_CV.append(count_list_CV[x])
            opened_last3M_CNT_GL.append(count_list_GL[x])
            opened_last3M_CNT_HL.append(count_list_HL[x])
            opened_last3M_CNT_LAS.append(count_list_LAS[x])
            opened_last3M_CNT_MFBL.append(count_list_MFBL[x])
            opened_last3M_CNT_MFHL.append(count_list_MFHL[x])
            opened_last3M_CNT_MFOT.append(count_list_MFOT[x])
            opened_last3M_CNT_OTH.append(count_list_OTH[x])
            opened_last3M_CNT_PL.append(count_list_PL[x])
            opened_last3M_CNT_PLBL.append(count_list_PLBL[x])
            opened_last3M_CNT_RL.append(count_list_RL[x])
            opened_last3M_CNT_SCC.append(count_list_SCC[x])
            opened_last3M_CNT_SEL.append(count_list_SEL[x])
        '''else:
            opened_last3M_CNT_AL.append(0)
            opened_last3M_CNT_BL.append(0)
            opened_last3M_CNT_CC.append(0)
            opened_last3M_CNT_CD.append(0)
            opened_last3M_CNT_CV.append(0)
            opened_last3M_CNT_GL.append(0)
            opened_last3M_CNT_HL.append(0)
            opened_last3M_CNT_LAS.append(0)
            opened_last3M_CNT_MFBL.append(0)
            opened_last3M_CNT_MFHL.append(0)
            opened_last3M_CNT_MFOT.append(0)
            opened_last3M_CNT_OTH.append(0)
            opened_last3M_CNT_PL.append(0)
            opened_last3M_CNT_PLBL.append(0)
            opened_last3M_CNT_RL.append(0)
            opened_last3M_CNT_SCC.append(0)
            opened_last3M_CNT_SEL.append(0)'''
            
df['opened_last3M_CNT_AL'] = pd.Series(opened_last3M_CNT_AL).values
df['opened_last3M_CNT_BL'] = pd.Series(opened_last3M_CNT_BL).values
df['opened_last3M_CNT_CC'] = pd.Series(opened_last3M_CNT_CC).values
df['opened_last3M_CNT_CD'] = pd.Series(opened_last3M_CNT_CD).values
df['opened_last3M_CNT_CV'] = pd.Series(opened_last3M_CNT_CV).values
df['opened_last3M_CNT_GL'] = pd.Series(opened_last3M_CNT_GL).values
df['opened_last3M_CNT_HL'] = pd.Series(opened_last3M_CNT_HL).values
df['opened_last3M_CNT_LAS'] = pd.Series(opened_last3M_CNT_LAS).values
df['opened_last3M_CNT_MFBL'] = pd.Series(opened_last3M_CNT_MFBL).values
df['opened_last3M_CNT_MFHL'] = pd.Series(opened_last3M_CNT_MFHL).values
df['opened_last3M_CNT_MFOT'] = pd.Series(opened_last3M_CNT_MFOT).values
df['opened_last3M_CNT_OTH'] = pd.Series(opened_last3M_CNT_OTH).values
df['opened_last3M_CNT_PL'] = pd.Series(opened_last3M_CNT_PL).values
df['opened_last3M_CNT_PLBL'] = pd.Series(opened_last3M_CNT_PLBL).values
df['opened_last3M_CNT_RL'] = pd.Series(opened_last3M_CNT_RL).values
df['opened_last3M_CNT_SCC'] = pd.Series(opened_last3M_CNT_SCC).values
df['opened_last3M_CNT_SEL'] = pd.Series(opened_last3M_CNT_SEL).values

# %% [raw]
# d = df[['ID','opened_last3M_CNT_GL','mo_diff_do_ld','accountType']]
# d.head(10)

# %% [markdown]
# ### Code for opened_last6M_CNT

# %% [markdown]
# - Count of all the loans opened in recent 6 months
# - For an applicant, count of all loan accounts where difference between DateOpened and Login Date is <=6 months

# %%
opened_last6M_CNT = list()
count_list = list()
count = 0

grp_df = df.groupby('ID')

for x in range(0, len(unq_id_list)):
    grp_slice = grp_df.get_group(unq_id_list[x])
    #print(grp_slice)
    grp_slice.reset_index(drop=True, inplace=True)
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['mo_diff_do_ld'][i]=='unknown'):
            continue
        elif (grp_slice['mo_diff_do_ld'][i]<=6):
            count = count + 1
        else:
            continue
    count_list.append(count)
    count = 0
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['mo_diff_do_ld'][i]=='unknown'):
            opened_last6M_CNT.append('unknown')
        elif (grp_slice['mo_diff_do_ld'][i]<=6):
            opened_last6M_CNT.append(count_list[x])
        else:
            opened_last6M_CNT.append(0)
        
            
df['opened_last6M_CNT'] = pd.Series(opened_last6M_CNT).values

# %%
df['opened_last6M_CNT'].value_counts()
# Out:
# 0          3703
# unknown     337
# 1           130
# 2            88
# 3            57
# 6            30
# 29           29
# 5            25
# 4            24
# 13           13
# 11           11
# 8             8
# 7             7
# Name: opened_last6M_CNT, dtype: int64

# %% [markdown]
# ### Code for opened_last6M_CNT_P

# %% [markdown]
# - Count of all the loans opened in recent 6 months per product
# - For an applicant, count of all loan accounts where difference between DateOpened and Login Date is <=6 months per product

# %%
opened_last6M_CNT_AL = list()
opened_last6M_CNT_BL = list()
opened_last6M_CNT_CC = list()
opened_last6M_CNT_CD = list()
opened_last6M_CNT_CV = list()
opened_last6M_CNT_GL = list()
opened_last6M_CNT_HL = list()
opened_last6M_CNT_LAS = list()
opened_last6M_CNT_MFBL = list()
opened_last6M_CNT_MFHL = list()
opened_last6M_CNT_MFOT = list()
opened_last6M_CNT_OTH = list()
opened_last6M_CNT_PL = list()
opened_last6M_CNT_PLBL = list()
opened_last6M_CNT_RL = list()
opened_last6M_CNT_SCC = list()
opened_last6M_CNT_SEL = list()

count_list_AL = list()
count_list_BL = list()
count_list_CC = list()
count_list_CD = list()
count_list_CV = list()
count_list_GL = list()
count_list_HL = list()
count_list_LAS = list()
count_list_MFBL = list()
count_list_MFHL = list()
count_list_MFOT = list()
count_list_OTH = list()
count_list_PL = list()
count_list_PLBL = list()
count_list_RL = list()
count_list_SCC = list()
count_list_SEL = list()

count_AL = 0
count_BL = 0
count_CC = 0
count_CD = 0
count_CV = 0
count_GL = 0
count_HL = 0
count_LAS = 0
count_MFBL = 0
count_MFHL = 0
count_MFOT = 0
count_OTH = 0
count_PL = 0 
count_PLBL = 0
count_RL = 0
count_SCC = 0
count_SEL = 0

grp_df = df.groupby('ID')

for x in range(0, len(unq_id_list)):
    grp_slice = grp_df.get_group(unq_id_list[x])
    #print(grp_slice) 
    grp_slice.reset_index(drop=True, inplace=True)
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['mo_diff_do_ld'][i]=='unknown'):
            continue
        elif (grp_slice['accountType'][i]=='AL') and (grp_slice['mo_diff_do_ld'][i]<=6):
            count_AL = count_AL + 1
        elif (grp_slice['accountType'][i]=='BL') and (grp_slice['mo_diff_do_ld'][i]<=6):
            count_BL = count_BL + 1
        elif (grp_slice['accountType'][i]=='CC') and (grp_slice['mo_diff_do_ld'][i]<=6):
            count_CC = count_CC + 1
        elif (grp_slice['accountType'][i]=='CD') and (grp_slice['mo_diff_do_ld'][i]<=6):
            count_CD = count_CD + 1
        elif (grp_slice['accountType'][i]=='CV') and (grp_slice['mo_diff_do_ld'][i]<=6):
            count_CV = count_CV + 1
        elif (grp_slice['accountType'][i]=='GL') and (grp_slice['mo_diff_do_ld'][i]<=6):
            count_GL = count_GL + 1
        elif (grp_slice['accountType'][i]=='HL') and (grp_slice['mo_diff_do_ld'][i]<=6):
            count_HL = count_HL + 1
        elif (grp_slice['accountType'][i]=='LAS') and (grp_slice['mo_diff_do_ld'][i]<=6):
            count_LAS = count_LAS + 1
        elif (grp_slice['accountType'][i]=='MFBL') and (grp_slice['mo_diff_do_ld'][i]<=6):
            count_MFBL = count_MFBL + 1
        elif (grp_slice['accountType'][i]=='MFHL') and (grp_slice['mo_diff_do_ld'][i]<=6):
            count_MFHL = count_MFHL + 1
        elif (grp_slice['accountType'][i]=='MFOT') and (grp_slice['mo_diff_do_ld'][i]<=6):
            count_MFOT = count_MFOT + 1
        elif (grp_slice['accountType'][i]=='OTH') and (grp_slice['mo_diff_do_ld'][i]<=6):
            count_OTH = count_OTH + 1
        elif (grp_slice['accountType'][i]=='PL') and (grp_slice['mo_diff_do_ld'][i]<=6):
            count_PL = count_PL + 1
        elif (grp_slice['accountType'][i]=='PLBL') and (grp_slice['mo_diff_do_ld'][i]<=6):
            count_PLBL = count_PLBL + 1
        elif (grp_slice['accountType'][i]=='RL') and (grp_slice['mo_diff_do_ld'][i]<=6):
            count_RL = count_RL + 1
        elif (grp_slice['accountType'][i]=='SCC') and (grp_slice['mo_diff_do_ld'][i]<=6):
            count_SCC = count_SCC + 1
        elif (grp_slice['accountType'][i]=='SEL') and (grp_slice['mo_diff_do_ld'][i]<=6):
            count_SEL = count_SEL + 1
            
    count_list_AL.append(count_AL)
    count_list_BL.append(count_BL)
    count_list_CC.append(count_CC)
    count_list_CD.append(count_CD)
    count_list_CV.append(count_CV)
    count_list_GL.append(count_GL)
    count_list_HL.append(count_HL)
    count_list_LAS.append(count_LAS)
    count_list_MFBL.append(count_MFBL)
    count_list_MFHL.append(count_MFHL)
    count_list_MFOT.append(count_MFOT)
    count_list_OTH.append(count_OTH)
    count_list_PL.append(count_PL)
    count_list_PLBL.append(count_PLBL)
    count_list_RL.append(count_RL)
    count_list_SCC.append(count_SCC)
    count_list_SEL.append(count_SEL)
    
    count_AL = 0
    count_BL = 0
    count_CC = 0
    count_CD = 0
    count_CV = 0
    count_GL = 0
    count_HL = 0
    count_LAS = 0
    count_MFBL = 0
    count_MFHL = 0
    count_MFOT = 0
    count_OTH = 0
    count_PL = 0
    count_PLBL = 0
    count_RL = 0
    count_SCC = 0
    count_SEL = 0
    
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['mo_diff_do_ld'][i]=='unknown'):
            opened_last6M_CNT_AL.append('unknown')
            opened_last6M_CNT_BL.append('unknown')
            opened_last6M_CNT_CC.append('unknown')
            opened_last6M_CNT_CD.append('unknown')
            opened_last6M_CNT_CV.append('unknown')
            opened_last6M_CNT_GL.append('unknown')
            opened_last6M_CNT_HL.append('unknown')
            opened_last6M_CNT_LAS.append('unknown')
            opened_last6M_CNT_MFBL.append('unknown')
            opened_last6M_CNT_MFHL.append('unknown')
            opened_last6M_CNT_MFOT.append('unknown')
            opened_last6M_CNT_OTH.append('unknown')
            opened_last6M_CNT_PL.append('unknown')
            opened_last6M_CNT_PLBL.append('unknown')
            opened_last6M_CNT_RL.append('unknown')
            opened_last6M_CNT_SCC.append('unknown')
            opened_last6M_CNT_SEL.append('unknown')
        #elif (grp_slice['mo_diff_do_ld'][i]<=6):
        else:
            opened_last6M_CNT_AL.append(count_list_AL[x])
            opened_last6M_CNT_BL.append(count_list_BL[x])
            opened_last6M_CNT_CC.append(count_list_CC[x])
            opened_last6M_CNT_CD.append(count_list_CD[x])
            opened_last6M_CNT_CV.append(count_list_CV[x])
            opened_last6M_CNT_GL.append(count_list_GL[x])
            opened_last6M_CNT_HL.append(count_list_HL[x])
            opened_last6M_CNT_LAS.append(count_list_LAS[x])
            opened_last6M_CNT_MFBL.append(count_list_MFBL[x])
            opened_last6M_CNT_MFHL.append(count_list_MFHL[x])
            opened_last6M_CNT_MFOT.append(count_list_MFOT[x])
            opened_last6M_CNT_OTH.append(count_list_OTH[x])
            opened_last6M_CNT_PL.append(count_list_PL[x])
            opened_last6M_CNT_PLBL.append(count_list_PLBL[x])
            opened_last6M_CNT_RL.append(count_list_RL[x])
            opened_last6M_CNT_SCC.append(count_list_SCC[x])
            opened_last6M_CNT_SEL.append(count_list_SEL[x])
        '''else:
            opened_last6M_CNT_AL.append(0)
            opened_last6M_CNT_BL.append(0)
            opened_last6M_CNT_CC.append(0)
            opened_last6M_CNT_CD.append(0)
            opened_last6M_CNT_CV.append(0)
            opened_last6M_CNT_GL.append(0)
            opened_last6M_CNT_HL.append(0)
            opened_last6M_CNT_LAS.append(0)
            opened_last6M_CNT_MFBL.append(0)
            opened_last6M_CNT_MFHL.append(0)
            opened_last6M_CNT_MFOT.append(0)
            opened_last6M_CNT_OTH.append(0)
            opened_last6M_CNT_PL.append(0)
            opened_last6M_CNT_PLBL.append(0)
            opened_last6M_CNT_RL.append(0)
            opened_last6M_CNT_SCC.append(0)
            opened_last6M_CNT_SEL.append(0)'''
            
df['opened_last6M_CNT_AL'] = pd.Series(opened_last6M_CNT_AL).values
df['opened_last6M_CNT_BL'] = pd.Series(opened_last6M_CNT_BL).values
df['opened_last6M_CNT_CC'] = pd.Series(opened_last6M_CNT_CC).values
df['opened_last6M_CNT_CD'] = pd.Series(opened_last6M_CNT_CD).values
df['opened_last6M_CNT_CV'] = pd.Series(opened_last6M_CNT_CV).values
df['opened_last6M_CNT_GL'] = pd.Series(opened_last6M_CNT_GL).values
df['opened_last6M_CNT_HL'] = pd.Series(opened_last6M_CNT_HL).values
df['opened_last6M_CNT_LAS'] = pd.Series(opened_last6M_CNT_LAS).values
df['opened_last6M_CNT_MFBL'] = pd.Series(opened_last6M_CNT_MFBL).values
df['opened_last6M_CNT_MFHL'] = pd.Series(opened_last6M_CNT_MFHL).values
df['opened_last6M_CNT_MFOT'] = pd.Series(opened_last6M_CNT_MFOT).values
df['opened_last6M_CNT_OTH'] = pd.Series(opened_last6M_CNT_OTH).values
df['opened_last6M_CNT_PL'] = pd.Series(opened_last6M_CNT_PL).values
df['opened_last6M_CNT_PLBL'] = pd.Series(opened_last6M_CNT_PLBL).values
df['opened_last6M_CNT_RL'] = pd.Series(opened_last6M_CNT_RL).values
df['opened_last6M_CNT_SCC'] = pd.Series(opened_last6M_CNT_SCC).values
df['opened_last6M_CNT_SEL'] = pd.Series(opened_last6M_CNT_SEL).values

# %% [raw]
# d = df[['ID','opened_last6M_CNT_GL','mo_diff_do_ld','accountType']]
# d.head(10)

# %% [markdown]
# ### Code for opened_last9M_CNT

# %% [markdown]
# - Count of all the loans opened in recent 9 months
# - For an applicant, count of all loan accounts where difference between DateOpened and Login Date is <=9 months

# %%
opened_last9M_CNT = list()
count_list = list()
count = 0

grp_df = df.groupby('ID')

for x in range(0, len(unq_id_list)):
    grp_slice = grp_df.get_group(unq_id_list[x])
    #print(grp_slice)
    grp_slice.reset_index(drop=True, inplace=True)
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['mo_diff_do_ld'][i]=='unknown'):
            continue
        elif (grp_slice['mo_diff_do_ld'][i]<=9):
            count = count + 1
        else:
            continue
    count_list.append(count)
    count = 0
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['mo_diff_do_ld'][i]=='unknown'):
            opened_last9M_CNT.append('unknown')
        elif (grp_slice['mo_diff_do_ld'][i]<=9):
            opened_last9M_CNT.append(count_list[x])
        else:
            opened_last9M_CNT.append(0)
        
            
df['opened_last9M_CNT'] = pd.Series(opened_last9M_CNT).values

# %%
df['opened_last9M_CNT'].value_counts()
# Out:
# 0          3284
# unknown     337
# 1           158
# 2           110
# 4           108
# 3            87
# 7            84
# 5            55
# 6            42
# 13           39
# 33           33
# 8            32
# 10           20
# 20           20
# 18           18
# 14           14
# 12           12
# 9             9
# Name: opened_last9M_CNT, dtype: int64

# %% [markdown]
# ### Code for opened_last9M_CNT_P

# %% [markdown]
# - Count of all the loans opened in recent 9 months per product
# - For an applicant, count of all loan accounts where difference between DateOpened and Login Date is <=9 months per product

# %%
opened_last9M_CNT_AL = list()
opened_last9M_CNT_BL = list()
opened_last9M_CNT_CC = list()
opened_last9M_CNT_CD = list()
opened_last9M_CNT_CV = list()
opened_last9M_CNT_GL = list()
opened_last9M_CNT_HL = list()
opened_last9M_CNT_LAS = list()
opened_last9M_CNT_MFBL = list()
opened_last9M_CNT_MFHL = list()
opened_last9M_CNT_MFOT = list()
opened_last9M_CNT_OTH = list()
opened_last9M_CNT_PL = list()
opened_last9M_CNT_PLBL = list()
opened_last9M_CNT_RL = list()
opened_last9M_CNT_SCC = list()
opened_last9M_CNT_SEL = list()

count_list_AL = list()
count_list_BL = list()
count_list_CC = list()
count_list_CD = list()
count_list_CV = list()
count_list_GL = list()
count_list_HL = list()
count_list_LAS = list()
count_list_MFBL = list()
count_list_MFHL = list()
count_list_MFOT = list()
count_list_OTH = list()
count_list_PL = list()
count_list_PLBL = list()
count_list_RL = list()
count_list_SCC = list()
count_list_SEL = list()

count_AL = 0
count_BL = 0
count_CC = 0
count_CD = 0
count_CV = 0
count_GL = 0
count_HL = 0
count_LAS = 0
count_MFBL = 0
count_MFHL = 0
count_MFOT = 0
count_OTH = 0
count_PL = 0 
count_PLBL = 0
count_RL = 0
count_SCC = 0
count_SEL = 0

grp_df = df.groupby('ID')

for x in range(0, len(unq_id_list)):
    grp_slice = grp_df.get_group(unq_id_list[x])
    #print(grp_slice) 
    grp_slice.reset_index(drop=True, inplace=True)
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['mo_diff_do_ld'][i]=='unknown'):
            continue
        elif (grp_slice['accountType'][i]=='AL') and (grp_slice['mo_diff_do_ld'][i]<=9):
            count_AL = count_AL + 1
        elif (grp_slice['accountType'][i]=='BL') and (grp_slice['mo_diff_do_ld'][i]<=9):
            count_BL = count_BL + 1
        elif (grp_slice['accountType'][i]=='CC') and (grp_slice['mo_diff_do_ld'][i]<=9):
            count_CC = count_CC + 1
        elif (grp_slice['accountType'][i]=='CD') and (grp_slice['mo_diff_do_ld'][i]<=9):
            count_CD = count_CD + 1
        elif (grp_slice['accountType'][i]=='CV') and (grp_slice['mo_diff_do_ld'][i]<=9):
            count_CV = count_CV + 1
        elif (grp_slice['accountType'][i]=='GL') and (grp_slice['mo_diff_do_ld'][i]<=9):
            count_GL = count_GL + 1
        elif (grp_slice['accountType'][i]=='HL') and (grp_slice['mo_diff_do_ld'][i]<=9):
            count_HL = count_HL + 1
        elif (grp_slice['accountType'][i]=='LAS') and (grp_slice['mo_diff_do_ld'][i]<=9):
            count_LAS = count_LAS + 1
        elif (grp_slice['accountType'][i]=='MFBL') and (grp_slice['mo_diff_do_ld'][i]<=9):
            count_MFBL = count_MFBL + 1
        elif (grp_slice['accountType'][i]=='MFHL') and (grp_slice['mo_diff_do_ld'][i]<=9):
            count_MFHL = count_MFHL + 1
        elif (grp_slice['accountType'][i]=='MFOT') and (grp_slice['mo_diff_do_ld'][i]<=9):
            count_MFOT = count_MFOT + 1
        elif (grp_slice['accountType'][i]=='OTH') and (grp_slice['mo_diff_do_ld'][i]<=9):
            count_OTH = count_OTH + 1
        elif (grp_slice['accountType'][i]=='PL') and (grp_slice['mo_diff_do_ld'][i]<=9):
            count_PL = count_PL + 1
        elif (grp_slice['accountType'][i]=='PLBL') and (grp_slice['mo_diff_do_ld'][i]<=9):
            count_PLBL = count_PLBL + 1
        elif (grp_slice['accountType'][i]=='RL') and (grp_slice['mo_diff_do_ld'][i]<=9):
            count_RL = count_RL + 1
        elif (grp_slice['accountType'][i]=='SCC') and (grp_slice['mo_diff_do_ld'][i]<=9):
            count_SCC = count_SCC + 1
        elif (grp_slice['accountType'][i]=='SEL') and (grp_slice['mo_diff_do_ld'][i]<=9):
            count_SEL = count_SEL + 1
            
    count_list_AL.append(count_AL)
    count_list_BL.append(count_BL)
    count_list_CC.append(count_CC)
    count_list_CD.append(count_CD)
    count_list_CV.append(count_CV)
    count_list_GL.append(count_GL)
    count_list_HL.append(count_HL)
    count_list_LAS.append(count_LAS)
    count_list_MFBL.append(count_MFBL)
    count_list_MFHL.append(count_MFHL)
    count_list_MFOT.append(count_MFOT)
    count_list_OTH.append(count_OTH)
    count_list_PL.append(count_PL)
    count_list_PLBL.append(count_PLBL)
    count_list_RL.append(count_RL)
    count_list_SCC.append(count_SCC)
    count_list_SEL.append(count_SEL)
    
    count_AL = 0
    count_BL = 0
    count_CC = 0
    count_CD = 0
    count_CV = 0
    count_GL = 0
    count_HL = 0
    count_LAS = 0
    count_MFBL = 0
    count_MFHL = 0
    count_MFOT = 0
    count_OTH = 0
    count_PL = 0
    count_PLBL = 0
    count_RL = 0
    count_SCC = 0
    count_SEL = 0
    
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['mo_diff_do_ld'][i]=='unknown'):
            opened_last9M_CNT_AL.append('unknown')
            opened_last9M_CNT_BL.append('unknown')
            opened_last9M_CNT_CC.append('unknown')
            opened_last9M_CNT_CD.append('unknown')
            opened_last9M_CNT_CV.append('unknown')
            opened_last9M_CNT_GL.append('unknown')
            opened_last9M_CNT_HL.append('unknown')
            opened_last9M_CNT_LAS.append('unknown')
            opened_last9M_CNT_MFBL.append('unknown')
            opened_last9M_CNT_MFHL.append('unknown')
            opened_last9M_CNT_MFOT.append('unknown')
            opened_last9M_CNT_OTH.append('unknown')
            opened_last9M_CNT_PL.append('unknown')
            opened_last9M_CNT_PLBL.append('unknown')
            opened_last9M_CNT_RL.append('unknown')
            opened_last9M_CNT_SCC.append('unknown')
            opened_last9M_CNT_SEL.append('unknown')
        #elif (grp_slice['mo_diff_do_ld'][i]<=9):
        else:
            opened_last9M_CNT_AL.append(count_list_AL[x])
            opened_last9M_CNT_BL.append(count_list_BL[x])
            opened_last9M_CNT_CC.append(count_list_CC[x])
            opened_last9M_CNT_CD.append(count_list_CD[x])
            opened_last9M_CNT_CV.append(count_list_CV[x])
            opened_last9M_CNT_GL.append(count_list_GL[x])
            opened_last9M_CNT_HL.append(count_list_HL[x])
            opened_last9M_CNT_LAS.append(count_list_LAS[x])
            opened_last9M_CNT_MFBL.append(count_list_MFBL[x])
            opened_last9M_CNT_MFHL.append(count_list_MFHL[x])
            opened_last9M_CNT_MFOT.append(count_list_MFOT[x])
            opened_last9M_CNT_OTH.append(count_list_OTH[x])
            opened_last9M_CNT_PL.append(count_list_PL[x])
            opened_last9M_CNT_PLBL.append(count_list_PLBL[x])
            opened_last9M_CNT_RL.append(count_list_RL[x])
            opened_last9M_CNT_SCC.append(count_list_SCC[x])
            opened_last9M_CNT_SEL.append(count_list_SEL[x])
        '''else:
            opened_last9M_CNT_AL.append(0)
            opened_last9M_CNT_BL.append(0)
            opened_last9M_CNT_CC.append(0)
            opened_last9M_CNT_CD.append(0)
            opened_last9M_CNT_CV.append(0)
            opened_last9M_CNT_GL.append(0)
            opened_last9M_CNT_HL.append(0)
            opened_last9M_CNT_LAS.append(0)
            opened_last9M_CNT_MFBL.append(0)
            opened_last9M_CNT_MFHL.append(0)
            opened_last9M_CNT_MFOT.append(0)
            opened_last9M_CNT_OTH.append(0)
            opened_last9M_CNT_PL.append(0)
            opened_last9M_CNT_PLBL.append(0)
            opened_last9M_CNT_RL.append(0)
            opened_last9M_CNT_SCC.append(0)
            opened_last9M_CNT_SEL.append(0)'''
            
df['opened_last9M_CNT_AL'] = pd.Series(opened_last9M_CNT_AL).values
df['opened_last9M_CNT_BL'] = pd.Series(opened_last9M_CNT_BL).values
df['opened_last9M_CNT_CC'] = pd.Series(opened_last9M_CNT_CC).values
df['opened_last9M_CNT_CD'] = pd.Series(opened_last9M_CNT_CD).values
df['opened_last9M_CNT_CV'] = pd.Series(opened_last9M_CNT_CV).values
df['opened_last9M_CNT_GL'] = pd.Series(opened_last9M_CNT_GL).values
df['opened_last9M_CNT_HL'] = pd.Series(opened_last9M_CNT_HL).values
df['opened_last9M_CNT_LAS'] = pd.Series(opened_last9M_CNT_LAS).values
df['opened_last9M_CNT_MFBL'] = pd.Series(opened_last9M_CNT_MFBL).values
df['opened_last9M_CNT_MFHL'] = pd.Series(opened_last9M_CNT_MFHL).values
df['opened_last9M_CNT_MFOT'] = pd.Series(opened_last9M_CNT_MFOT).values
df['opened_last9M_CNT_OTH'] = pd.Series(opened_last9M_CNT_OTH).values
df['opened_last9M_CNT_PL'] = pd.Series(opened_last9M_CNT_PL).values
df['opened_last9M_CNT_PLBL'] = pd.Series(opened_last9M_CNT_PLBL).values
df['opened_last9M_CNT_RL'] = pd.Series(opened_last9M_CNT_RL).values
df['opened_last9M_CNT_SCC'] = pd.Series(opened_last9M_CNT_SCC).values
df['opened_last9M_CNT_SEL'] = pd.Series(opened_last9M_CNT_SEL).values

# %% [raw]
# d = df[['ID','opened_last9M_CNT_GL','mo_diff_do_ld','accountType']]
# d.head(10)

# %% [markdown]
# ### Code for opened_last1Y_CNT

# %% [markdown]
# - Count of all the loans opened in recent 1 year
# - For an applicant, count of all loan accounts where difference between DateOpened and Login Date is <=1 year

# %%
opened_last1Y_CNT = list()
count_list = list()
count = 0

grp_df = df.groupby('ID')

for x in range(0, len(unq_id_list)):
    grp_slice = grp_df.get_group(unq_id_list[x])
    #print(grp_slice)
    grp_slice.reset_index(drop=True, inplace=True)
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['mo_diff_do_ld'][i]=='unknown'):
            continue
        elif (grp_slice['mo_diff_do_ld'][i]<=12):
            count = count + 1
        else:
            continue
    count_list.append(count)
    count = 0
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['mo_diff_do_ld'][i]=='unknown'):
            opened_last1Y_CNT.append('unknown')
        elif (grp_slice['mo_diff_do_ld'][i]<=12):
            opened_last1Y_CNT.append(count_list[x])
        else:
            opened_last1Y_CNT.append(0)
        
            
df['opened_last1Y_CNT'] = pd.Series(opened_last1Y_CNT).values

# %% [raw]
# df['opened_last1Y_CNT'].value_counts()

# %% [markdown]
# ### Code for opened_last1Y_CNT_P

# %% [markdown]
# - Count of all the loans opened in recent 1 year per product
# - For an applicant, count of all loan accounts where difference between DateOpened and Login Date is <=1 year per product

# %%
opened_last1Y_CNT_AL = list()
opened_last1Y_CNT_BL = list()
opened_last1Y_CNT_CC = list()
opened_last1Y_CNT_CD = list()
opened_last1Y_CNT_CV = list()
opened_last1Y_CNT_GL = list()
opened_last1Y_CNT_HL = list()
opened_last1Y_CNT_LAS = list()
opened_last1Y_CNT_MFBL = list()
opened_last1Y_CNT_MFHL = list()
opened_last1Y_CNT_MFOT = list()
opened_last1Y_CNT_OTH = list()
opened_last1Y_CNT_PL = list()
opened_last1Y_CNT_PLBL = list()
opened_last1Y_CNT_RL = list()
opened_last1Y_CNT_SCC = list()
opened_last1Y_CNT_SEL = list()

count_list_AL = list()
count_list_BL = list()
count_list_CC = list()
count_list_CD = list()
count_list_CV = list()
count_list_GL = list()
count_list_HL = list()
count_list_LAS = list()
count_list_MFBL = list()
count_list_MFHL = list()
count_list_MFOT = list()
count_list_OTH = list()
count_list_PL = list()
count_list_PLBL = list()
count_list_RL = list()
count_list_SCC = list()
count_list_SEL = list()

count_AL = 0
count_BL = 0
count_CC = 0
count_CD = 0
count_CV = 0
count_GL = 0
count_HL = 0
count_LAS = 0
count_MFBL = 0
count_MFHL = 0
count_MFOT = 0
count_OTH = 0
count_PL = 0 
count_PLBL = 0
count_RL = 0
count_SCC = 0
count_SEL = 0

grp_df = df.groupby('ID')

for x in range(0, len(unq_id_list)):
    grp_slice = grp_df.get_group(unq_id_list[x])
    #print(grp_slice) 
    grp_slice.reset_index(drop=True, inplace=True)
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['mo_diff_do_ld'][i]=='unknown'):
            continue
        elif (grp_slice['accountType'][i]=='AL') and (grp_slice['mo_diff_do_ld'][i]<=12):
            count_AL = count_AL + 1
        elif (grp_slice['accountType'][i]=='BL') and (grp_slice['mo_diff_do_ld'][i]<=12):
            count_BL = count_BL + 1
        elif (grp_slice['accountType'][i]=='CC') and (grp_slice['mo_diff_do_ld'][i]<=12):
            count_CC = count_CC + 1
        elif (grp_slice['accountType'][i]=='CD') and (grp_slice['mo_diff_do_ld'][i]<=12):
            count_CD = count_CD + 1
        elif (grp_slice['accountType'][i]=='CV') and (grp_slice['mo_diff_do_ld'][i]<=12):
            count_CV = count_CV + 1
        elif (grp_slice['accountType'][i]=='GL') and (grp_slice['mo_diff_do_ld'][i]<=12):
            count_GL = count_GL + 1
        elif (grp_slice['accountType'][i]=='HL') and (grp_slice['mo_diff_do_ld'][i]<=12):
            count_HL = count_HL + 1
        elif (grp_slice['accountType'][i]=='LAS') and (grp_slice['mo_diff_do_ld'][i]<=12):
            count_LAS = count_LAS + 1
        elif (grp_slice['accountType'][i]=='MFBL') and (grp_slice['mo_diff_do_ld'][i]<=12):
            count_MFBL = count_MFBL + 1
        elif (grp_slice['accountType'][i]=='MFHL') and (grp_slice['mo_diff_do_ld'][i]<=12):
            count_MFHL = count_MFHL + 1
        elif (grp_slice['accountType'][i]=='MFOT') and (grp_slice['mo_diff_do_ld'][i]<=12):
            count_MFOT = count_MFOT + 1
        elif (grp_slice['accountType'][i]=='OTH') and (grp_slice['mo_diff_do_ld'][i]<=12):
            count_OTH = count_OTH + 1
        elif (grp_slice['accountType'][i]=='PL') and (grp_slice['mo_diff_do_ld'][i]<=12):
            count_PL = count_PL + 1
        elif (grp_slice['accountType'][i]=='PLBL') and (grp_slice['mo_diff_do_ld'][i]<=12):
            count_PLBL = count_PLBL + 1
        elif (grp_slice['accountType'][i]=='RL') and (grp_slice['mo_diff_do_ld'][i]<=12):
            count_RL = count_RL + 1
        elif (grp_slice['accountType'][i]=='SCC') and (grp_slice['mo_diff_do_ld'][i]<=12):
            count_SCC = count_SCC + 1
        elif (grp_slice['accountType'][i]=='SEL') and (grp_slice['mo_diff_do_ld'][i]<=12):
            count_SEL = count_SEL + 1
            
    count_list_AL.append(count_AL)
    count_list_BL.append(count_BL)
    count_list_CC.append(count_CC)
    count_list_CD.append(count_CD)
    count_list_CV.append(count_CV)
    count_list_GL.append(count_GL)
    count_list_HL.append(count_HL)
    count_list_LAS.append(count_LAS)
    count_list_MFBL.append(count_MFBL)
    count_list_MFHL.append(count_MFHL)
    count_list_MFOT.append(count_MFOT)
    count_list_OTH.append(count_OTH)
    count_list_PL.append(count_PL)
    count_list_PLBL.append(count_PLBL)
    count_list_RL.append(count_RL)
    count_list_SCC.append(count_SCC)
    count_list_SEL.append(count_SEL)
    
    count_AL = 0
    count_BL = 0
    count_CC = 0
    count_CD = 0
    count_CV = 0
    count_GL = 0
    count_HL = 0
    count_LAS = 0
    count_MFBL = 0
    count_MFHL = 0
    count_MFOT = 0
    count_OTH = 0
    count_PL = 0
    count_PLBL = 0
    count_RL = 0
    count_SCC = 0
    count_SEL = 0
    
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['mo_diff_do_ld'][i]=='unknown'):
            opened_last1Y_CNT_AL.append('unknown')
            opened_last1Y_CNT_BL.append('unknown')
            opened_last1Y_CNT_CC.append('unknown')
            opened_last1Y_CNT_CD.append('unknown')
            opened_last1Y_CNT_CV.append('unknown')
            opened_last1Y_CNT_GL.append('unknown')
            opened_last1Y_CNT_HL.append('unknown')
            opened_last1Y_CNT_LAS.append('unknown')
            opened_last1Y_CNT_MFBL.append('unknown')
            opened_last1Y_CNT_MFHL.append('unknown')
            opened_last1Y_CNT_MFOT.append('unknown')
            opened_last1Y_CNT_OTH.append('unknown')
            opened_last1Y_CNT_PL.append('unknown')
            opened_last1Y_CNT_PLBL.append('unknown')
            opened_last1Y_CNT_RL.append('unknown')
            opened_last1Y_CNT_SCC.append('unknown')
            opened_last1Y_CNT_SEL.append('unknown')
        #elif (grp_slice['mo_diff_do_ld'][i]<=12):
        else:
            opened_last1Y_CNT_AL.append(count_list_AL[x])
            opened_last1Y_CNT_BL.append(count_list_BL[x])
            opened_last1Y_CNT_CC.append(count_list_CC[x])
            opened_last1Y_CNT_CD.append(count_list_CD[x])
            opened_last1Y_CNT_CV.append(count_list_CV[x])
            opened_last1Y_CNT_GL.append(count_list_GL[x])
            opened_last1Y_CNT_HL.append(count_list_HL[x])
            opened_last1Y_CNT_LAS.append(count_list_LAS[x])
            opened_last1Y_CNT_MFBL.append(count_list_MFBL[x])
            opened_last1Y_CNT_MFHL.append(count_list_MFHL[x])
            opened_last1Y_CNT_MFOT.append(count_list_MFOT[x])
            opened_last1Y_CNT_OTH.append(count_list_OTH[x])
            opened_last1Y_CNT_PL.append(count_list_PL[x])
            opened_last1Y_CNT_PLBL.append(count_list_PLBL[x])
            opened_last1Y_CNT_RL.append(count_list_RL[x])
            opened_last1Y_CNT_SCC.append(count_list_SCC[x])
            opened_last1Y_CNT_SEL.append(count_list_SEL[x])
        '''else:
            opened_last1Y_CNT_AL.append(0)
            opened_last1Y_CNT_BL.append(0)
            opened_last1Y_CNT_CC.append(0)
            opened_last1Y_CNT_CD.append(0)
            opened_last1Y_CNT_CV.append(0)
            opened_last1Y_CNT_GL.append(0)
            opened_last1Y_CNT_HL.append(0)
            opened_last1Y_CNT_LAS.append(0)
            opened_last1Y_CNT_MFBL.append(0)
            opened_last1Y_CNT_MFHL.append(0)
            opened_last1Y_CNT_MFOT.append(0)
            opened_last1Y_CNT_OTH.append(0)
            opened_last1Y_CNT_PL.append(0)
            opened_last1Y_CNT_PLBL.append(0)
            opened_last1Y_CNT_RL.append(0)
            opened_last1Y_CNT_SCC.append(0)
            opened_last1Y_CNT_SEL.append(0)'''
            
df['opened_last1Y_CNT_AL'] = pd.Series(opened_last1Y_CNT_AL).values
df['opened_last1Y_CNT_BL'] = pd.Series(opened_last1Y_CNT_BL).values
df['opened_last1Y_CNT_CC'] = pd.Series(opened_last1Y_CNT_CC).values
df['opened_last1Y_CNT_CD'] = pd.Series(opened_last1Y_CNT_CD).values
df['opened_last1Y_CNT_CV'] = pd.Series(opened_last1Y_CNT_CV).values
df['opened_last1Y_CNT_GL'] = pd.Series(opened_last1Y_CNT_GL).values
df['opened_last1Y_CNT_HL'] = pd.Series(opened_last1Y_CNT_HL).values
df['opened_last1Y_CNT_LAS'] = pd.Series(opened_last1Y_CNT_LAS).values
df['opened_last1Y_CNT_MFBL'] = pd.Series(opened_last1Y_CNT_MFBL).values
df['opened_last1Y_CNT_MFHL'] = pd.Series(opened_last1Y_CNT_MFHL).values
df['opened_last1Y_CNT_MFOT'] = pd.Series(opened_last1Y_CNT_MFOT).values
df['opened_last1Y_CNT_OTH'] = pd.Series(opened_last1Y_CNT_OTH).values
df['opened_last1Y_CNT_PL'] = pd.Series(opened_last1Y_CNT_PL).values
df['opened_last1Y_CNT_PLBL'] = pd.Series(opened_last1Y_CNT_PLBL).values
df['opened_last1Y_CNT_RL'] = pd.Series(opened_last1Y_CNT_RL).values
df['opened_last1Y_CNT_SCC'] = pd.Series(opened_last1Y_CNT_SCC).values
df['opened_last1Y_CNT_SEL'] = pd.Series(opened_last1Y_CNT_SEL).values

# %% [raw]
# d = df[['ID','opened_last1Y_CNT_CD','mo_diff_do_ld','accountType']]
# d.head(10)

# %% [markdown]
# ### Code for opened_last2Y_CNT

# %% [markdown]
# - Count of all the loans opened in recent 2 years
# - For an applicant, count of all loan accounts where difference between DateOpened and Login Date is <=2 years

# %%
opened_last2Y_CNT = list()
count_list = list()
count = 0

grp_df = df.groupby('ID')

for x in range(0, len(unq_id_list)):
    grp_slice = grp_df.get_group(unq_id_list[x])
    #print(grp_slice)
    grp_slice.reset_index(drop=True, inplace=True)
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['mo_diff_do_ld'][i]=='unknown'):
            continue
        elif (grp_slice['mo_diff_do_ld'][i]<=24):
            count = count + 1
        else:
            continue
    count_list.append(count)
    count = 0
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['mo_diff_do_ld'][i]=='unknown'):
            opened_last2Y_CNT.append('unknown')
        elif (grp_slice['mo_diff_do_ld'][i]<=24):
            opened_last2Y_CNT.append(count_list[x])
        else:
            opened_last2Y_CNT.append(0)
        
            
df['opened_last2Y_CNT'] = pd.Series(opened_last2Y_CNT).values

# %% [raw]
# df['opened_last2Y_CNT'].value_counts()

# %% [markdown]
# ### Code for opened_last2Y_CNT_P

# %% [markdown]
# - Count of all the loans opened in recent 2 years per product
# - For an applicant, count of all loan accounts where difference between DateOpened and Login Date is <=2 years per product

# %%
opened_last2Y_CNT_AL = list()
opened_last2Y_CNT_BL = list()
opened_last2Y_CNT_CC = list()
opened_last2Y_CNT_CD = list()
opened_last2Y_CNT_CV = list()
opened_last2Y_CNT_GL = list()
opened_last2Y_CNT_HL = list()
opened_last2Y_CNT_LAS = list()
opened_last2Y_CNT_MFBL = list()
opened_last2Y_CNT_MFHL = list()
opened_last2Y_CNT_MFOT = list()
opened_last2Y_CNT_OTH = list()
opened_last2Y_CNT_PL = list()
opened_last2Y_CNT_PLBL = list()
opened_last2Y_CNT_RL = list()
opened_last2Y_CNT_SCC = list()
opened_last2Y_CNT_SEL = list()

count_list_AL = list()
count_list_BL = list()
count_list_CC = list()
count_list_CD = list()
count_list_CV = list()
count_list_GL = list()
count_list_HL = list()
count_list_LAS = list()
count_list_MFBL = list()
count_list_MFHL = list()
count_list_MFOT = list()
count_list_OTH = list()
count_list_PL = list()
count_list_PLBL = list()
count_list_RL = list()
count_list_SCC = list()
count_list_SEL = list()

count_AL = 0
count_BL = 0
count_CC = 0
count_CD = 0
count_CV = 0
count_GL = 0
count_HL = 0
count_LAS = 0
count_MFBL = 0
count_MFHL = 0
count_MFOT = 0
count_OTH = 0
count_PL = 0 
count_PLBL = 0
count_RL = 0
count_SCC = 0
count_SEL = 0

grp_df = df.groupby('ID')

for x in range(0, len(unq_id_list)):
    grp_slice = grp_df.get_group(unq_id_list[x])
    #print(grp_slice) 
    grp_slice.reset_index(drop=True, inplace=True)
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['mo_diff_do_ld'][i]=='unknown'):
            continue
        elif (grp_slice['accountType'][i]=='AL') and (grp_slice['mo_diff_do_ld'][i]<=24):
            count_AL = count_AL + 1
        elif (grp_slice['accountType'][i]=='BL') and (grp_slice['mo_diff_do_ld'][i]<=24):
            count_BL = count_BL + 1
        elif (grp_slice['accountType'][i]=='CC') and (grp_slice['mo_diff_do_ld'][i]<=24):
            count_CC = count_CC + 1
        elif (grp_slice['accountType'][i]=='CD') and (grp_slice['mo_diff_do_ld'][i]<=24):
            count_CD = count_CD + 1
        elif (grp_slice['accountType'][i]=='CV') and (grp_slice['mo_diff_do_ld'][i]<=24):
            count_CV = count_CV + 1
        elif (grp_slice['accountType'][i]=='GL') and (grp_slice['mo_diff_do_ld'][i]<=24):
            count_GL = count_GL + 1
        elif (grp_slice['accountType'][i]=='HL') and (grp_slice['mo_diff_do_ld'][i]<=24):
            count_HL = count_HL + 1
        elif (grp_slice['accountType'][i]=='LAS') and (grp_slice['mo_diff_do_ld'][i]<=24):
            count_LAS = count_LAS + 1
        elif (grp_slice['accountType'][i]=='MFBL') and (grp_slice['mo_diff_do_ld'][i]<=24):
            count_MFBL = count_MFBL + 1
        elif (grp_slice['accountType'][i]=='MFHL') and (grp_slice['mo_diff_do_ld'][i]<=24):
            count_MFHL = count_MFHL + 1
        elif (grp_slice['accountType'][i]=='MFOT') and (grp_slice['mo_diff_do_ld'][i]<=24):
            count_MFOT = count_MFOT + 1
        elif (grp_slice['accountType'][i]=='OTH') and (grp_slice['mo_diff_do_ld'][i]<=24):
            count_OTH = count_OTH + 1
        elif (grp_slice['accountType'][i]=='PL') and (grp_slice['mo_diff_do_ld'][i]<=24):
            count_PL = count_PL + 1
        elif (grp_slice['accountType'][i]=='PLBL') and (grp_slice['mo_diff_do_ld'][i]<=24):
            count_PLBL = count_PLBL + 1
        elif (grp_slice['accountType'][i]=='RL') and (grp_slice['mo_diff_do_ld'][i]<=24):
            count_RL = count_RL + 1
        elif (grp_slice['accountType'][i]=='SCC') and (grp_slice['mo_diff_do_ld'][i]<=24):
            count_SCC = count_SCC + 1
        elif (grp_slice['accountType'][i]=='SEL') and (grp_slice['mo_diff_do_ld'][i]<=24):
            count_SEL = count_SEL + 1
            
    count_list_AL.append(count_AL)
    count_list_BL.append(count_BL)
    count_list_CC.append(count_CC)
    count_list_CD.append(count_CD)
    count_list_CV.append(count_CV)
    count_list_GL.append(count_GL)
    count_list_HL.append(count_HL)
    count_list_LAS.append(count_LAS)
    count_list_MFBL.append(count_MFBL)
    count_list_MFHL.append(count_MFHL)
    count_list_MFOT.append(count_MFOT)
    count_list_OTH.append(count_OTH)
    count_list_PL.append(count_PL)
    count_list_PLBL.append(count_PLBL)
    count_list_RL.append(count_RL)
    count_list_SCC.append(count_SCC)
    count_list_SEL.append(count_SEL)
    
    count_AL = 0
    count_BL = 0
    count_CC = 0
    count_CD = 0
    count_CV = 0
    count_GL = 0
    count_HL = 0
    count_LAS = 0
    count_MFBL = 0
    count_MFHL = 0
    count_MFOT = 0
    count_OTH = 0
    count_PL = 0
    count_PLBL = 0
    count_RL = 0
    count_SCC = 0
    count_SEL = 0
    
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['mo_diff_do_ld'][i]=='unknown'):
            opened_last2Y_CNT_AL.append('unknown')
            opened_last2Y_CNT_BL.append('unknown')
            opened_last2Y_CNT_CC.append('unknown')
            opened_last2Y_CNT_CD.append('unknown')
            opened_last2Y_CNT_CV.append('unknown')
            opened_last2Y_CNT_GL.append('unknown')
            opened_last2Y_CNT_HL.append('unknown')
            opened_last2Y_CNT_LAS.append('unknown')
            opened_last2Y_CNT_MFBL.append('unknown')
            opened_last2Y_CNT_MFHL.append('unknown')
            opened_last2Y_CNT_MFOT.append('unknown')
            opened_last2Y_CNT_OTH.append('unknown')
            opened_last2Y_CNT_PL.append('unknown')
            opened_last2Y_CNT_PLBL.append('unknown')
            opened_last2Y_CNT_RL.append('unknown')
            opened_last2Y_CNT_SCC.append('unknown')
            opened_last2Y_CNT_SEL.append('unknown')
        #elif (grp_slice['mo_diff_do_ld'][i]<=24):
        else:
            opened_last2Y_CNT_AL.append(count_list_AL[x])
            opened_last2Y_CNT_BL.append(count_list_BL[x])
            opened_last2Y_CNT_CC.append(count_list_CC[x])
            opened_last2Y_CNT_CD.append(count_list_CD[x])
            opened_last2Y_CNT_CV.append(count_list_CV[x])
            opened_last2Y_CNT_GL.append(count_list_GL[x])
            opened_last2Y_CNT_HL.append(count_list_HL[x])
            opened_last2Y_CNT_LAS.append(count_list_LAS[x])
            opened_last2Y_CNT_MFBL.append(count_list_MFBL[x])
            opened_last2Y_CNT_MFHL.append(count_list_MFHL[x])
            opened_last2Y_CNT_MFOT.append(count_list_MFOT[x])
            opened_last2Y_CNT_OTH.append(count_list_OTH[x])
            opened_last2Y_CNT_PL.append(count_list_PL[x])
            opened_last2Y_CNT_PLBL.append(count_list_PLBL[x])
            opened_last2Y_CNT_RL.append(count_list_RL[x])
            opened_last2Y_CNT_SCC.append(count_list_SCC[x])
            opened_last2Y_CNT_SEL.append(count_list_SEL[x])
        '''else:
            opened_last2Y_CNT_AL.append(0)
            opened_last2Y_CNT_BL.append(0)
            opened_last2Y_CNT_CC.append(0)
            opened_last2Y_CNT_CD.append(0)
            opened_last2Y_CNT_CV.append(0)
            opened_last2Y_CNT_GL.append(0)
            opened_last2Y_CNT_HL.append(0)
            opened_last2Y_CNT_LAS.append(0)
            opened_last2Y_CNT_MFBL.append(0)
            opened_last2Y_CNT_MFHL.append(0)
            opened_last2Y_CNT_MFOT.append(0)
            opened_last2Y_CNT_OTH.append(0)
            opened_last2Y_CNT_PL.append(0)
            opened_last2Y_CNT_PLBL.append(0)
            opened_last2Y_CNT_RL.append(0)
            opened_last2Y_CNT_SCC.append(0)
            opened_last2Y_CNT_SEL.append(0)'''
            
df['opened_last2Y_CNT_AL'] = pd.Series(opened_last2Y_CNT_AL).values
df['opened_last2Y_CNT_BL'] = pd.Series(opened_last2Y_CNT_BL).values
df['opened_last2Y_CNT_CC'] = pd.Series(opened_last2Y_CNT_CC).values
df['opened_last2Y_CNT_CD'] = pd.Series(opened_last2Y_CNT_CD).values
df['opened_last2Y_CNT_CV'] = pd.Series(opened_last2Y_CNT_CV).values
df['opened_last2Y_CNT_GL'] = pd.Series(opened_last2Y_CNT_GL).values
df['opened_last2Y_CNT_HL'] = pd.Series(opened_last2Y_CNT_HL).values
df['opened_last2Y_CNT_LAS'] = pd.Series(opened_last2Y_CNT_LAS).values
df['opened_last2Y_CNT_MFBL'] = pd.Series(opened_last2Y_CNT_MFBL).values
df['opened_last2Y_CNT_MFHL'] = pd.Series(opened_last2Y_CNT_MFHL).values
df['opened_last2Y_CNT_MFOT'] = pd.Series(opened_last2Y_CNT_MFOT).values
df['opened_last2Y_CNT_OTH'] = pd.Series(opened_last2Y_CNT_OTH).values
df['opened_last2Y_CNT_PL'] = pd.Series(opened_last2Y_CNT_PL).values
df['opened_last2Y_CNT_PLBL'] = pd.Series(opened_last2Y_CNT_PLBL).values
df['opened_last2Y_CNT_RL'] = pd.Series(opened_last2Y_CNT_RL).values
df['opened_last2Y_CNT_SCC'] = pd.Series(opened_last2Y_CNT_SCC).values
df['opened_last2Y_CNT_SEL'] = pd.Series(opened_last2Y_CNT_SEL).values

# %% [raw]
# d = df[['ID','opened_last2Y_CNT_GL','mo_diff_do_ld','accountType']]
# d.head(10)

# %% [markdown]
# ### Code for opened_last3Y_CNT

# %% [markdown]
# - Count of all the loans opened in recent 3 years
# - For an applicant, count of all loan accounts where difference between DateOpened and Login Date is <=3 years

# %%
opened_last3Y_CNT = list()
count_list = list()
count = 0

grp_df = df.groupby('ID')

for x in range(0, len(unq_id_list)):
    grp_slice = grp_df.get_group(unq_id_list[x])
    #print(grp_slice)
    grp_slice.reset_index(drop=True, inplace=True)
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['mo_diff_do_ld'][i]=='unknown'):
            continue
        elif (grp_slice['mo_diff_do_ld'][i]<=36):
            count = count + 1
        else:
            continue
    count_list.append(count)
    count = 0
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['mo_diff_do_ld'][i]=='unknown'):
            opened_last3Y_CNT.append('unknown')
        elif (grp_slice['mo_diff_do_ld'][i]<=36):
            opened_last3Y_CNT.append(count_list[x])
        else:
            opened_last3Y_CNT.append(0)
        
            
df['opened_last3Y_CNT'] = pd.Series(opened_last3Y_CNT).values

# %% [raw]
# df['opened_last3Y_CNT'].value_counts()

# %% [markdown]
# ### Code for opened_last3Y_CNT_P

# %% [markdown]
# - Count of all the loans opened in recent 3 years per product
# - For an applicant, count of all loan accounts where difference between DateOpened and Login Date is <=3 years per product

# %%
opened_last3Y_CNT_AL = list()
opened_last3Y_CNT_BL = list()
opened_last3Y_CNT_CC = list()
opened_last3Y_CNT_CD = list()
opened_last3Y_CNT_CV = list()
opened_last3Y_CNT_GL = list()
opened_last3Y_CNT_HL = list()
opened_last3Y_CNT_LAS = list()
opened_last3Y_CNT_MFBL = list()
opened_last3Y_CNT_MFHL = list()
opened_last3Y_CNT_MFOT = list()
opened_last3Y_CNT_OTH = list()
opened_last3Y_CNT_PL = list()
opened_last3Y_CNT_PLBL = list()
opened_last3Y_CNT_RL = list()
opened_last3Y_CNT_SCC = list()
opened_last3Y_CNT_SEL = list()

count_list_AL = list()
count_list_BL = list()
count_list_CC = list()
count_list_CD = list()
count_list_CV = list()
count_list_GL = list()
count_list_HL = list()
count_list_LAS = list()
count_list_MFBL = list()
count_list_MFHL = list()
count_list_MFOT = list()
count_list_OTH = list()
count_list_PL = list()
count_list_PLBL = list()
count_list_RL = list()
count_list_SCC = list()
count_list_SEL = list()

count_AL = 0
count_BL = 0
count_CC = 0
count_CD = 0
count_CV = 0
count_GL = 0
count_HL = 0
count_LAS = 0
count_MFBL = 0
count_MFHL = 0
count_MFOT = 0
count_OTH = 0
count_PL = 0 
count_PLBL = 0
count_RL = 0
count_SCC = 0
count_SEL = 0

grp_df = df.groupby('ID')

for x in range(0, len(unq_id_list)):
    grp_slice = grp_df.get_group(unq_id_list[x])
    #print(grp_slice) 
    grp_slice.reset_index(drop=True, inplace=True)
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['mo_diff_do_ld'][i]=='unknown'):
            continue
        elif (grp_slice['accountType'][i]=='AL') and (grp_slice['mo_diff_do_ld'][i]<=36):
            count_AL = count_AL + 1
        elif (grp_slice['accountType'][i]=='BL') and (grp_slice['mo_diff_do_ld'][i]<=36):
            count_BL = count_BL + 1
        elif (grp_slice['accountType'][i]=='CC') and (grp_slice['mo_diff_do_ld'][i]<=36):
            count_CC = count_CC + 1
        elif (grp_slice['accountType'][i]=='CD') and (grp_slice['mo_diff_do_ld'][i]<=36):
            count_CD = count_CD + 1
        elif (grp_slice['accountType'][i]=='CV') and (grp_slice['mo_diff_do_ld'][i]<=36):
            count_CV = count_CV + 1
        elif (grp_slice['accountType'][i]=='GL') and (grp_slice['mo_diff_do_ld'][i]<=36):
            count_GL = count_GL + 1
        elif (grp_slice['accountType'][i]=='HL') and (grp_slice['mo_diff_do_ld'][i]<=36):
            count_HL = count_HL + 1
        elif (grp_slice['accountType'][i]=='LAS') and (grp_slice['mo_diff_do_ld'][i]<=36):
            count_LAS = count_LAS + 1
        elif (grp_slice['accountType'][i]=='MFBL') and (grp_slice['mo_diff_do_ld'][i]<=36):
            count_MFBL = count_MFBL + 1
        elif (grp_slice['accountType'][i]=='MFHL') and (grp_slice['mo_diff_do_ld'][i]<=36):
            count_MFHL = count_MFHL + 1
        elif (grp_slice['accountType'][i]=='MFOT') and (grp_slice['mo_diff_do_ld'][i]<=36):
            count_MFOT = count_MFOT + 1
        elif (grp_slice['accountType'][i]=='OTH') and (grp_slice['mo_diff_do_ld'][i]<=36):
            count_OTH = count_OTH + 1
        elif (grp_slice['accountType'][i]=='PL') and (grp_slice['mo_diff_do_ld'][i]<=36):
            count_PL = count_PL + 1
        elif (grp_slice['accountType'][i]=='PLBL') and (grp_slice['mo_diff_do_ld'][i]<=36):
            count_PLBL = count_PLBL + 1
        elif (grp_slice['accountType'][i]=='RL') and (grp_slice['mo_diff_do_ld'][i]<=36):
            count_RL = count_RL + 1
        elif (grp_slice['accountType'][i]=='SCC') and (grp_slice['mo_diff_do_ld'][i]<=36):
            count_SCC = count_SCC + 1
        elif (grp_slice['accountType'][i]=='SEL') and (grp_slice['mo_diff_do_ld'][i]<=36):
            count_SEL = count_SEL + 1
            
    count_list_AL.append(count_AL)
    count_list_BL.append(count_BL)
    count_list_CC.append(count_CC)
    count_list_CD.append(count_CD)
    count_list_CV.append(count_CV)
    count_list_GL.append(count_GL)
    count_list_HL.append(count_HL)
    count_list_LAS.append(count_LAS)
    count_list_MFBL.append(count_MFBL)
    count_list_MFHL.append(count_MFHL)
    count_list_MFOT.append(count_MFOT)
    count_list_OTH.append(count_OTH)
    count_list_PL.append(count_PL)
    count_list_PLBL.append(count_PLBL)
    count_list_RL.append(count_RL)
    count_list_SCC.append(count_SCC)
    count_list_SEL.append(count_SEL)
    
    count_AL = 0
    count_BL = 0
    count_CC = 0
    count_CD = 0
    count_CV = 0
    count_GL = 0
    count_HL = 0
    count_LAS = 0
    count_MFBL = 0
    count_MFHL = 0
    count_MFOT = 0
    count_OTH = 0
    count_PL = 0
    count_PLBL = 0
    count_RL = 0
    count_SCC = 0
    count_SEL = 0
    
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['mo_diff_do_ld'][i]=='unknown'):
            opened_last3Y_CNT_AL.append('unknown')
            opened_last3Y_CNT_BL.append('unknown')
            opened_last3Y_CNT_CC.append('unknown')
            opened_last3Y_CNT_CD.append('unknown')
            opened_last3Y_CNT_CV.append('unknown')
            opened_last3Y_CNT_GL.append('unknown')
            opened_last3Y_CNT_HL.append('unknown')
            opened_last3Y_CNT_LAS.append('unknown')
            opened_last3Y_CNT_MFBL.append('unknown')
            opened_last3Y_CNT_MFHL.append('unknown')
            opened_last3Y_CNT_MFOT.append('unknown')
            opened_last3Y_CNT_OTH.append('unknown')
            opened_last3Y_CNT_PL.append('unknown')
            opened_last3Y_CNT_PLBL.append('unknown')
            opened_last3Y_CNT_RL.append('unknown')
            opened_last3Y_CNT_SCC.append('unknown')
            opened_last3Y_CNT_SEL.append('unknown')
        #elif (grp_slice['mo_diff_do_ld'][i]<=36):
        else:
            opened_last3Y_CNT_AL.append(count_list_AL[x])
            opened_last3Y_CNT_BL.append(count_list_BL[x])
            opened_last3Y_CNT_CC.append(count_list_CC[x])
            opened_last3Y_CNT_CD.append(count_list_CD[x])
            opened_last3Y_CNT_CV.append(count_list_CV[x])
            opened_last3Y_CNT_GL.append(count_list_GL[x])
            opened_last3Y_CNT_HL.append(count_list_HL[x])
            opened_last3Y_CNT_LAS.append(count_list_LAS[x])
            opened_last3Y_CNT_MFBL.append(count_list_MFBL[x])
            opened_last3Y_CNT_MFHL.append(count_list_MFHL[x])
            opened_last3Y_CNT_MFOT.append(count_list_MFOT[x])
            opened_last3Y_CNT_OTH.append(count_list_OTH[x])
            opened_last3Y_CNT_PL.append(count_list_PL[x])
            opened_last3Y_CNT_PLBL.append(count_list_PLBL[x])
            opened_last3Y_CNT_RL.append(count_list_RL[x])
            opened_last3Y_CNT_SCC.append(count_list_SCC[x])
            opened_last3Y_CNT_SEL.append(count_list_SEL[x])
        '''else:
            opened_last3Y_CNT_AL.append(0)
            opened_last3Y_CNT_BL.append(0)
            opened_last3Y_CNT_CC.append(0)
            opened_last3Y_CNT_CD.append(0)
            opened_last3Y_CNT_CV.append(0)
            opened_last3Y_CNT_GL.append(0)
            opened_last3Y_CNT_HL.append(0)
            opened_last3Y_CNT_LAS.append(0)
            opened_last3Y_CNT_MFBL.append(0)
            opened_last3Y_CNT_MFHL.append(0)
            opened_last3Y_CNT_MFOT.append(0)
            opened_last3Y_CNT_OTH.append(0)
            opened_last3Y_CNT_PL.append(0)
            opened_last3Y_CNT_PLBL.append(0)
            opened_last3Y_CNT_RL.append(0)
            opened_last3Y_CNT_SCC.append(0)
            opened_last3Y_CNT_SEL.append(0)'''
            
df['opened_last3Y_CNT_AL'] = pd.Series(opened_last3Y_CNT_AL).values
df['opened_last3Y_CNT_BL'] = pd.Series(opened_last3Y_CNT_BL).values
df['opened_last3Y_CNT_CC'] = pd.Series(opened_last3Y_CNT_CC).values
df['opened_last3Y_CNT_CD'] = pd.Series(opened_last3Y_CNT_CD).values
df['opened_last3Y_CNT_CV'] = pd.Series(opened_last3Y_CNT_CV).values
df['opened_last3Y_CNT_GL'] = pd.Series(opened_last3Y_CNT_GL).values
df['opened_last3Y_CNT_HL'] = pd.Series(opened_last3Y_CNT_HL).values
df['opened_last3Y_CNT_LAS'] = pd.Series(opened_last3Y_CNT_LAS).values
df['opened_last3Y_CNT_MFBL'] = pd.Series(opened_last3Y_CNT_MFBL).values
df['opened_last3Y_CNT_MFHL'] = pd.Series(opened_last3Y_CNT_MFHL).values
df['opened_last3Y_CNT_MFOT'] = pd.Series(opened_last3Y_CNT_MFOT).values
df['opened_last3Y_CNT_OTH'] = pd.Series(opened_last3Y_CNT_OTH).values
df['opened_last3Y_CNT_PL'] = pd.Series(opened_last3Y_CNT_PL).values
df['opened_last3Y_CNT_PLBL'] = pd.Series(opened_last3Y_CNT_PLBL).values
df['opened_last3Y_CNT_RL'] = pd.Series(opened_last3Y_CNT_RL).values
df['opened_last3Y_CNT_SCC'] = pd.Series(opened_last3Y_CNT_SCC).values
df['opened_last3Y_CNT_SEL'] = pd.Series(opened_last3Y_CNT_SEL).values

# %% [raw]
# d = df[['ID','opened_last3Y_CNT_GL','mo_diff_do_ld','accountType']]
# d.head(10)

# %% [markdown]
# ### Code for opened_closed_last3M_P

# %% [markdown]
# - Ratio of all the loans closed to opened in recent 3 months per product
# - For an applicant, ratio of all loan accounts where difference between DateOpened and Login Date is <=3 months to all loan accounts where difference between DateClosed (not null) and Login Date is <=3 months per product

# %% [markdown]
# <a id='overdueAmount_sum_P'></a>
# ### overdueAmount_sum_P
# - Sum of Overdue amount per product

# %%
start_time = time.time()  # You can use time.clock() also

overdueAmount_sum_AL = list()
overdueAmount_sum_BL = list()
overdueAmount_sum_CC = list()
overdueAmount_sum_CD = list()
overdueAmount_sum_CV = list()
overdueAmount_sum_GL = list()
overdueAmount_sum_HL = list()
overdueAmount_sum_LAS = list()
overdueAmount_sum_MFBL = list()
overdueAmount_sum_MFHL = list()
overdueAmount_sum_MFOT = list()
overdueAmount_sum_OTH = list()
overdueAmount_sum_PL = list()
overdueAmount_sum_PLBL = list()
overdueAmount_sum_RL = list()
overdueAmount_sum_SCC = list()
overdueAmount_sum_SEL = list()

oa_list_AL = list()
oa_list_BL = list()
oa_list_CC = list()
oa_list_CD = list()
oa_list_CV = list()
oa_list_GL = list()
oa_list_HL = list()
oa_list_LAS = list()
oa_list_MFBL = list()
oa_list_MFHL = list()
oa_list_MFOT = list()
oa_list_OTH = list()
oa_list_PL = list()
oa_list_PLBL = list()
oa_list_RL = list()
oa_list_SCC = list()
oa_list_SEL = list()

oa_AL = 0
oa_BL = 0
oa_CC = 0
oa_CD = 0
oa_CV = 0
oa_GL = 0
oa_HL = 0
oa_LAS = 0
oa_MFBL = 0
oa_MFHL = 0
oa_MFOT = 0
oa_OTH = 0
oa_PL = 0
oa_PLBL = 0
oa_RL = 0
oa_SCC = 0
oa_SEL = 0

grp_df = df.groupby('ID')

for x in range(0, len(unq_id_list)):
    grp_slice = grp_df.get_group(unq_id_list[x])
    # print(grp_slice)
    grp_slice.reset_index(drop=True, inplace=True)
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['overdueAmount'][i] == 'unknown'):
            continue
        elif (grp_slice['accountType'][i] == 'AL'):
            oa_AL = oa_AL + (grp_slice['overdueAmount'][i])
        elif (grp_slice['accountType'][i] == 'BL'):
            oa_BL = oa_BL + (grp_slice['overdueAmount'][i])
        elif (grp_slice['accountType'][i] == 'CC'):
            oa_CC = oa_CC + (grp_slice['overdueAmount'][i])
        elif (grp_slice['accountType'][i] == 'CD'):
            oa_CD = oa_CD + (grp_slice['overdueAmount'][i])
        elif (grp_slice['accountType'][i] == 'CV'):
            oa_CV = oa_CV + (grp_slice['overdueAmount'][i])
        elif (grp_slice['accountType'][i] == 'GL'):
            oa_GL = oa_GL + (grp_slice['overdueAmount'][i])
        elif (grp_slice['accountType'][i] == 'HL'):
            oa_HL = oa_HL + (grp_slice['overdueAmount'][i])
        elif (grp_slice['accountType'][i] == 'LAS'):
            oa_LAS = oa_LAS + (grp_slice['overdueAmount'][i])
        elif (grp_slice['accountType'][i] == 'MFBL'):
            oa_MFBL = oa_MFBL + (grp_slice['overdueAmount'][i])
        elif (grp_slice['accountType'][i] == 'MFHL'):
            oa_MFHL = oa_MFHL + (grp_slice['overdueAmount'][i])
        elif (grp_slice['accountType'][i] == 'MFOT'):
            oa_MFOT = oa_MFOT + (grp_slice['overdueAmount'][i])
        elif (grp_slice['accountType'][i] == 'OTH'):
            oa_OTH = oa_OTH + (grp_slice['overdueAmount'][i])
        elif (grp_slice['accountType'][i] == 'PL'):
            oa_PL = oa_PL + (grp_slice['overdueAmount'][i])
        elif (grp_slice['accountType'][i] == 'PLBL'):
            oa_PLBL = oa_PLBL + (grp_slice['overdueAmount'][i])
        elif (grp_slice['accountType'][i] == 'RL'):
            oa_RL = oa_RL + (grp_slice['overdueAmount'][i])
        elif (grp_slice['accountType'][i] == 'SCC'):
            oa_SCC = oa_SCC + (grp_slice['overdueAmount'][i])
        elif (grp_slice['accountType'][i] == 'SEL'):
            oa_SEL = oa_SEL + (grp_slice['overdueAmount'][i])

    oa_list_AL.append(oa_AL)
    oa_list_BL.append(oa_BL)
    oa_list_CC.append(oa_CC)
    oa_list_CD.append(oa_CD)
    oa_list_CV.append(oa_CV)
    oa_list_GL.append(oa_GL)
    oa_list_HL.append(oa_HL)
    oa_list_LAS.append(oa_LAS)
    oa_list_MFBL.append(oa_MFBL)
    oa_list_MFHL.append(oa_MFHL)
    oa_list_MFOT.append(oa_MFOT)
    oa_list_OTH.append(oa_OTH)
    oa_list_PL.append(oa_PL)
    oa_list_PLBL.append(oa_PLBL)
    oa_list_RL.append(oa_RL)
    oa_list_SCC.append(oa_SCC)
    oa_list_SEL.append(oa_SEL)

    oa_AL = 0
    oa_BL = 0
    oa_CC = 0
    oa_CD = 0
    oa_CV = 0
    oa_GL = 0
    oa_HL = 0
    oa_LAS = 0
    oa_MFBL = 0
    oa_MFHL = 0
    oa_MFOT = 0
    oa_OTH = 0
    oa_PL = 0
    oa_PLBL = 0
    oa_RL = 0
    oa_SCC = 0
    oa_SEL = 0

    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['overdueAmount'][i] != 'unknown') and (grp_slice['accountType'][i] == 'AL'):
            overdueAmount_sum_AL.append(sum(oa_list_AL))
        else:
            overdueAmount_sum_AL.append('unknown')

        if (grp_slice['overdueAmount'][i] != 'unknown') and (grp_slice['accountType'][i] == 'BL'):
            overdueAmount_sum_BL.append(sum(oa_list_BL))
        else:
            overdueAmount_sum_BL.append('unknown')

        if (grp_slice['overdueAmount'][i] != 'unknown') and (grp_slice['accountType'][i] == 'CC'):
            overdueAmount_sum_CC.append(sum(oa_list_CC)) 
        else:
            overdueAmount_sum_CC.append('unknown')

        if (grp_slice['overdueAmount'][i] != 'unknown') and (grp_slice['accountType'][i] == 'CD'):
            overdueAmount_sum_CD.append(sum(oa_list_CD))
        else:
            overdueAmount_sum_CD.append('unknown') 

        if (grp_slice['overdueAmount'][i] != 'unknown') and (grp_slice['accountType'][i] == 'CV'):
            overdueAmount_sum_CV.append(sum(oa_list_CV))
        else:
            overdueAmount_sum_CV.append('unknown')

        if (grp_slice['overdueAmount'][i] != 'unknown') and (grp_slice['accountType'][i] == 'GL'):
            overdueAmount_sum_GL.append(sum(oa_list_GL)) 
        else:
            overdueAmount_sum_GL.append('unknown')

        if (grp_slice['overdueAmount'][i] != 'unknown') and (grp_slice['accountType'][i] == 'HL'):
            overdueAmount_sum_HL.append(sum(oa_list_HL)) 
        else:
            overdueAmount_sum_HL.append('unknown')

        if (grp_slice['overdueAmount'][i] != 'unknown') and (grp_slice['accountType'][i] == 'LAS'):
            overdueAmount_sum_LAS.append(sum(oa_list_LAS)) 
        else:
            overdueAmount_sum_LAS.append('unknown')

        if (grp_slice['overdueAmount'][i] != 'unknown') and (grp_slice['accountType'][i] == 'MFBL'):
            overdueAmount_sum_MFBL.append(sum(oa_list_MFBL)) 
        else:
            overdueAmount_sum_MFBL.append('unknown')

        if (grp_slice['overdueAmount'][i] != 'unknown') and (grp_slice['accountType'][i] == 'MFHL'):
            overdueAmount_sum_MFHL.append(sum(oa_list_MFHL)) 
        else:
            overdueAmount_sum_MFHL.append('unknown')

        if (grp_slice['overdueAmount'][i] != 'unknown') and (grp_slice['accountType'][i] == 'MFOT'):
            overdueAmount_sum_MFOT.append(sum(oa_list_MFOT)) 
        else:
            overdueAmount_sum_MFOT.append('unknown')

        if (grp_slice['overdueAmount'][i] != 'unknown') and (grp_slice['accountType'][i] == 'OTH'):
            overdueAmount_sum_OTH.append(sum(oa_list_OTH)) 
        else:
            overdueAmount_sum_OTH.append('unknown')

        if (grp_slice['overdueAmount'][i] != 'unknown') and (grp_slice['accountType'][i] == 'PL'):
            overdueAmount_sum_PL.append(sum(oa_list_PL)) 
        else:
            overdueAmount_sum_PL.append('unknown')

        if (grp_slice['overdueAmount'][i] != 'unknown') and (grp_slice['accountType'][i] == 'PLBL'):
            overdueAmount_sum_PLBL.append(sum(oa_list_PLBL)) 
        else:
            overdueAmount_sum_PLBL.append('unknown')

        if (grp_slice['overdueAmount'][i] != 'unknown') and (grp_slice['accountType'][i] == 'RL'):
            overdueAmount_sum_RL.append(sum(oa_list_RL)) 
        else:
            overdueAmount_sum_RL.append('unknown')

        if (grp_slice['overdueAmount'][i] != 'unknown') and (grp_slice['accountType'][i] == 'SCC'):
            overdueAmount_sum_SCC.append(sum(oa_list_SCC))
        else:
            overdueAmount_sum_SCC.append('unknown')

        if (grp_slice['overdueAmount'][i] != 'unknown') and (grp_slice['accountType'][i] == 'SEL'):
            overdueAmount_sum_SEL.append(sum(oa_list_SEL)) 
        else:
            overdueAmount_sum_SEL.append('unknown')

                
df['overdueAmount_sum_AL'] = pd.Series(overdueAmount_sum_AL).values
df['overdueAmount_sum_BL'] = pd.Series(overdueAmount_sum_BL).values
df['overdueAmount_sum_CC'] = pd.Series(overdueAmount_sum_CC).values
df['overdueAmount_sum_CD'] = pd.Series(overdueAmount_sum_CD).values
df['overdueAmount_sum_CV'] = pd.Series(overdueAmount_sum_CV).values
df['overdueAmount_sum_GL'] = pd.Series(overdueAmount_sum_GL).values
df['overdueAmount_sum_HL'] = pd.Series(overdueAmount_sum_HL).values
df['overdueAmount_sum_LAS'] = pd.Series(overdueAmount_sum_LAS).values
df['overdueAmount_sum_MFBL'] = pd.Series(overdueAmount_sum_MFBL).values
df['overdueAmount_sum_MFHL'] = pd.Series(overdueAmount_sum_MFHL).values
df['overdueAmount_sum_MFOT'] = pd.Series(overdueAmount_sum_MFOT).values
df['overdueAmount_sum_OTH'] = pd.Series(overdueAmount_sum_OTH).values
df['overdueAmount_sum_PL'] = pd.Series(overdueAmount_sum_PL).values
df['overdueAmount_sum_PLBL'] = pd.Series(overdueAmount_sum_PLBL).values
df['overdueAmount_sum_RL'] = pd.Series(overdueAmount_sum_RL).values
df['overdueAmount_sum_SCC'] = pd.Series(overdueAmount_sum_SCC).values
df['overdueAmount_sum_SEL'] = pd.Series(overdueAmount_sum_SEL).values

print("%s seconds" % (time.time() - start_time))
# Out:
# 2.6261279582977295 seconds

# %% [raw]
# a = df[['ID','overdueAmount_sum_AL','overdueAmount','accountType']]
# a.head(60)

# %% [markdown]
# <a id='Overdue_Current'></a>
# ### Code for Overdue_Current

# %% [markdown]
# - Ratio of overdue amt by current bal

# %% [markdown]
# **Overdue Amount** -> The amount past due as of the date
# reported in the Date Reported and
# Certified field.

# %%
df['overdueAmount'].fillna('unknown', inplace=True)

# %% [raw]
# df['overdueAmount'].value_counts()

# %%
Overdue_Current = list()

for x in range(0, df.shape[0]):
    if (df['overdueAmount'][x]=='unknown') or (df['currentBalance'][x]=='unknown') or (df['currentBalance'][x]==0):
        Overdue_Current.append('unknown')
    else:
        Overdue_Current.append(float(df['overdueAmount'][x])/float(df['currentBalance'][x]))

df['Overdue_Current'] = pd.Series(Overdue_Current).values

# %% [raw]
# a = df[['ID','Overdue_Current','overdueAmount','currentBalance']]
# a.head(60)

# %% [markdown]
# ### Code for Overdue_Current_P

# %% [markdown]
# - Ratio of overdue amt by current bal per product

# %%
start_time = time.time()  # You can use time.clock() also

Overdue_Current_AL = list()
Overdue_Current_BL = list()
Overdue_Current_CC = list()
Overdue_Current_CD = list()
Overdue_Current_CV = list()
Overdue_Current_GL = list()
Overdue_Current_HL = list()
Overdue_Current_LAS = list()
Overdue_Current_MFBL = list()
Overdue_Current_MFHL = list()
Overdue_Current_MFOT = list()
Overdue_Current_OTH = list()
Overdue_Current_PL = list()
Overdue_Current_PLBL = list()
Overdue_Current_RL = list()
Overdue_Current_SCC = list()
Overdue_Current_SEL = list()

grp_list_oa_AL = list()
grp_list_oa_BL = list()
grp_list_oa_CC = list()
grp_list_oa_CD = list()
grp_list_oa_CV = list()
grp_list_oa_GL = list()
grp_list_oa_HL = list()
grp_list_oa_LAS = list()
grp_list_oa_MFBL = list()
grp_list_oa_MFHL = list()
grp_list_oa_MFOT = list()
grp_list_oa_OTH = list()
grp_list_oa_PL = list()
grp_list_oa_PLBL = list()
grp_list_oa_RL = list()
grp_list_oa_SCC = list()
grp_list_oa_SEL = list()

grp_list_cb_AL = list()
grp_list_cb_BL = list()
grp_list_cb_CC = list()
grp_list_cb_CD = list()
grp_list_cb_CV = list()
grp_list_cb_GL = list()
grp_list_cb_HL = list()
grp_list_cb_LAS = list()
grp_list_cb_MFBL = list()
grp_list_cb_MFHL = list()
grp_list_cb_MFOT = list()
grp_list_cb_OTH = list()
grp_list_cb_PL = list()
grp_list_cb_PLBL = list()
grp_list_cb_RL = list()
grp_list_cb_SCC = list()
grp_list_cb_SEL = list()

grp_oa_AL = 0
grp_oa_BL = 0
grp_oa_CC = 0
grp_oa_CD = 0
grp_oa_CV = 0
grp_oa_GL = 0
grp_oa_HL = 0
grp_oa_LAS = 0
grp_oa_MFBL = 0
grp_oa_MFHL = 0
grp_oa_MFOT = 0
grp_oa_OTH = 0
grp_oa_PL = 0
grp_oa_PLBL = 0
grp_oa_RL = 0
grp_oa_SCC = 0
grp_oa_SEL = 0

grp_cb_AL = 0
grp_cb_BL = 0
grp_cb_CC = 0
grp_cb_CD = 0
grp_cb_CV = 0
grp_cb_GL = 0
grp_cb_HL = 0
grp_cb_LAS = 0
grp_cb_MFBL = 0
grp_cb_MFHL = 0
grp_cb_MFOT = 0
grp_cb_OTH = 0
grp_cb_PL = 0
grp_cb_PLBL = 0
grp_cb_RL = 0
grp_cb_SCC = 0
grp_cb_SEL = 0

grp_df = df.groupby('ID')

for x in range(0, len(unq_id_list)):
    grp_slice = grp_df.get_group(unq_id_list[x])
    # print(grp_slice)
    grp_slice.reset_index(drop=True, inplace=True)
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['overdueAmount'][i] == 'unknown') or (grp_slice['currentBalance'][i] == 'unknown') or (grp_slice['currentBalance'][i] == 0):
            continue
        elif (grp_slice['accountType'][i] == 'AL'):
            grp_oa_AL = float(grp_slice['overdueAmount'][i])
            grp_cb_AL = float(grp_slice['currentBalance'][i])
        elif (grp_slice['accountType'][i] == 'BL'):
            grp_oa_BL = float(grp_slice['overdueAmount'][i])
            grp_cb_BL = float(grp_slice['currentBalance'][i])
        elif (grp_slice['accountType'][i] == 'CC'):
            grp_oa_CC = float(grp_slice['overdueAmount'][i])
            grp_cb_CC = float(grp_slice['currentBalance'][i])
        elif (grp_slice['accountType'][i] == 'CD'):
            grp_oa_CD = float(grp_slice['overdueAmount'][i])
            grp_cb_CD = float(grp_slice['currentBalance'][i])
        elif (grp_slice['accountType'][i] == 'CV'):
            grp_oa_CV = float(grp_slice['overdueAmount'][i])
            grp_cb_CV = float(grp_slice['currentBalance'][i])
        elif (grp_slice['accountType'][i] == 'GL'):
            grp_oa_GL = float(grp_slice['overdueAmount'][i])
            grp_cb_GL = float(grp_slice['currentBalance'][i])
        elif (grp_slice['accountType'][i] == 'HL'):
            grp_oa_HL = float(grp_slice['overdueAmount'][i])
            grp_cb_HL = float(grp_slice['currentBalance'][i])
        elif (grp_slice['accountType'][i] == 'LAS'):
            grp_oa_LAS = float(grp_slice['overdueAmount'][i])
            grp_cb_LAS = float(grp_slice['currentBalance'][i])
        elif (grp_slice['accountType'][i] == 'MFBL'):
            grp_oa_MFBL = float(grp_slice['overdueAmount'][i])
            grp_cb_MFBL = float(grp_slice['currentBalance'][i])
        elif (grp_slice['accountType'][i] == 'MFHL'):
            grp_oa_MFHL = float(grp_slice['overdueAmount'][i])
            grp_cb_MFHL = float(grp_slice['currentBalance'][i])
        elif (grp_slice['accountType'][i] == 'MFOT'):
            grp_oa_MFOT = float(grp_slice['overdueAmount'][i])
            grp_cb_MFOT = float(grp_slice['currentBalance'][i])
        elif (grp_slice['accountType'][i] == 'OTH'):
            grp_oa_OTH = float(grp_slice['overdueAmount'][i])
            grp_cb_OTH = float(grp_slice['currentBalance'][i])
        elif (grp_slice['accountType'][i] == 'PL'):
            grp_oa_PL = float(grp_slice['overdueAmount'][i])
            grp_cb_PL = float(grp_slice['currentBalance'][i])
        elif (grp_slice['accountType'][i] == 'PLBL'):
            grp_oa_PLBL = float(grp_slice['overdueAmount'][i])
            grp_cb_PLBL = float(grp_slice['currentBalance'][i])
        elif (grp_slice['accountType'][i] == 'RL'):
            grp_oa_RL = float(grp_slice['overdueAmount'][i])
            grp_cb_RL = float(grp_slice['currentBalance'][i])
        elif (grp_slice['accountType'][i] == 'SCC'):
            grp_oa_SCC = float(grp_slice['overdueAmount'][i])
            grp_cb_SCC = float(grp_slice['currentBalance'][i])
        elif (grp_slice['accountType'][i] == 'SEL'):
            grp_oa_SEL = float(grp_slice['overdueAmount'][i])
            grp_cb_SEL = float(grp_slice['currentBalance'][i])

    grp_list_oa_AL.append(grp_oa_AL)
    grp_list_oa_BL.append(grp_oa_BL)
    grp_list_oa_CC.append(grp_oa_CC)
    grp_list_oa_CD.append(grp_oa_CD)
    grp_list_oa_CV.append(grp_oa_CV)
    grp_list_oa_GL.append(grp_oa_GL)
    grp_list_oa_HL.append(grp_oa_HL)
    grp_list_oa_LAS.append(grp_oa_LAS)
    grp_list_oa_MFBL.append(grp_oa_MFBL)
    grp_list_oa_MFHL.append(grp_oa_MFHL)
    grp_list_oa_MFOT.append(grp_oa_MFOT)
    grp_list_oa_OTH.append(grp_oa_OTH)
    grp_list_oa_PL.append(grp_oa_PL)
    grp_list_oa_PLBL.append(grp_oa_PLBL)
    grp_list_oa_RL.append(grp_oa_RL)
    grp_list_oa_SCC.append(grp_oa_SCC)
    grp_list_oa_SEL.append(grp_oa_SEL)

    grp_list_cb_AL.append(grp_cb_AL)
    grp_list_cb_BL.append(grp_cb_BL)
    grp_list_cb_CC.append(grp_cb_CC)
    grp_list_cb_CD.append(grp_cb_CD)
    grp_list_cb_CV.append(grp_cb_CV)
    grp_list_cb_GL.append(grp_cb_GL)
    grp_list_cb_HL.append(grp_cb_HL)
    grp_list_cb_LAS.append(grp_cb_LAS)
    grp_list_cb_MFBL.append(grp_cb_MFBL)
    grp_list_cb_MFHL.append(grp_cb_MFHL)
    grp_list_cb_MFOT.append(grp_cb_MFOT)
    grp_list_cb_OTH.append(grp_cb_OTH)
    grp_list_cb_PL.append(grp_cb_PL)
    grp_list_cb_PLBL.append(grp_cb_PLBL)
    grp_list_cb_RL.append(grp_cb_RL)
    grp_list_cb_SCC.append(grp_cb_SCC)
    grp_list_cb_SEL.append(grp_cb_SEL)

    grp_oa_AL = 0
    grp_oa_BL = 0
    grp_oa_CC = 0
    grp_oa_CD = 0
    grp_oa_CV = 0
    grp_oa_GL = 0
    grp_oa_HL = 0
    grp_oa_LAS = 0
    grp_oa_MFBL = 0
    grp_oa_MFHL = 0
    grp_oa_MFOT = 0
    grp_oa_OTH = 0
    grp_oa_PL = 0
    grp_oa_PLBL = 0
    grp_oa_RL = 0
    grp_oa_SCC = 0
    grp_oa_SEL = 0

    grp_cb_BL = 0
    grp_cb_CC = 0
    grp_cb_CD = 0
    grp_cb_CV = 0
    grp_cb_GL = 0
    grp_cb_HL = 0
    grp_cb_LAS = 0
    grp_cb_MFBL = 0
    grp_cb_MFHL = 0
    grp_cb_MFOT = 0
    grp_cb_OTH = 0
    grp_cb_PL = 0
    grp_cb_PLBL = 0
    grp_cb_RL = 0
    grp_cb_SCC = 0
    grp_cb_SEL = 0

    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['overdueAmount'][i] == 'unknown') or (grp_slice['currentBalance'][i] == 'unknown') or (sum(grp_list_cb_AL) == 0):
            Overdue_Current_AL.append('unknown')
        else:
            Overdue_Current_AL.append(
                sum(grp_list_oa_AL)/sum(grp_list_cb_AL))

        if (grp_slice['overdueAmount'][i] == 'unknown') or (grp_slice['currentBalance'][i] == 'unknown') or (sum(grp_list_cb_BL) == 0):
            Overdue_Current_BL.append('unknown')
        else:
            Overdue_Current_BL.append(
                sum(grp_list_oa_BL)/sum(grp_list_cb_BL))

        if (grp_slice['overdueAmount'][i] == 'unknown') or (grp_slice['currentBalance'][i] == 'unknown') or (sum(grp_list_cb_CC) == 0):
            Overdue_Current_CC.append('unknown')
        else:
            Overdue_Current_CC.append(
                sum(grp_list_oa_CC)/sum(grp_list_cb_CC))

        if (grp_slice['overdueAmount'][i] == 'unknown') or (grp_slice['currentBalance'][i] == 'unknown') or (sum(grp_list_cb_CD) == 0):
            Overdue_Current_CD.append('unknown')
        else:
            Overdue_Current_CD.append(
                sum(grp_list_oa_CD)/sum(grp_list_cb_CD))

        if (grp_slice['overdueAmount'][i] == 'unknown') or (grp_slice['currentBalance'][i] == 'unknown') or (sum(grp_list_cb_CV) == 0):
            Overdue_Current_CV.append('unknown')
        else:
            Overdue_Current_CV.append(
                sum(grp_list_oa_CV)/sum(grp_list_cb_CV))

        if (grp_slice['overdueAmount'][i] == 'unknown') or (grp_slice['currentBalance'][i] == 'unknown') or (sum(grp_list_cb_GL) == 0):
            Overdue_Current_GL.append('unknown')
        else:
            Overdue_Current_GL.append(
                sum(grp_list_oa_GL)/sum(grp_list_cb_GL))

        if (grp_slice['overdueAmount'][i] == 'unknown') or (grp_slice['currentBalance'][i] == 'unknown') or (sum(grp_list_cb_HL) == 0):
            Overdue_Current_HL.append('unknown')
        else:
            Overdue_Current_HL.append(
                sum(grp_list_oa_HL)/sum(grp_list_cb_HL))

        if (grp_slice['overdueAmount'][i] == 'unknown') or (grp_slice['currentBalance'][i] == 'unknown') or (sum(grp_list_cb_LAS) == 0):
            Overdue_Current_LAS.append('unknown')
        else:
            Overdue_Current_LAS.append(
                sum(grp_list_oa_LAS)/sum(grp_list_cb_LAS))

        if (grp_slice['overdueAmount'][i] == 'unknown') or (grp_slice['currentBalance'][i] == 'unknown') or (sum(grp_list_cb_MFBL) == 0):
            Overdue_Current_MFBL.append('unknown')
        else:
            Overdue_Current_MFBL.append(
                sum(grp_list_oa_MFBL)/sum(grp_list_cb_MFBL))

        if (grp_slice['overdueAmount'][i] == 'unknown') or (grp_slice['currentBalance'][i] == 'unknown') or (sum(grp_list_cb_MFHL) == 0):
            Overdue_Current_MFHL.append('unknown')
        else:
            Overdue_Current_MFHL.append(
                sum(grp_list_oa_MFHL)/sum(grp_list_cb_MFHL))

        if (grp_slice['overdueAmount'][i] == 'unknown') or (grp_slice['currentBalance'][i] == 'unknown') or (sum(grp_list_cb_MFOT) == 0):
            Overdue_Current_MFOT.append('unknown')
        else:
            Overdue_Current_MFOT.append(
                sum(grp_list_oa_MFOT)/sum(grp_list_cb_MFOT))

        if (grp_slice['overdueAmount'][i] == 'unknown') or (grp_slice['currentBalance'][i] == 'unknown') or (sum(grp_list_cb_OTH) == 0):
            Overdue_Current_OTH.append('unknown')
        else:
            Overdue_Current_OTH.append(
                sum(grp_list_oa_OTH)/sum(grp_list_cb_OTH))

        if (grp_slice['overdueAmount'][i] == 'unknown') or (grp_slice['currentBalance'][i] == 'unknown') or (sum(grp_list_cb_PL) == 0):
            Overdue_Current_PL.append('unknown')
        else:
            Overdue_Current_PL.append(
                sum(grp_list_oa_PL)/sum(grp_list_cb_PL))

        if (grp_slice['overdueAmount'][i] == 'unknown') or (grp_slice['currentBalance'][i] == 'unknown') or (sum(grp_list_cb_PLBL) == 0):
            Overdue_Current_PLBL.append('unknown')
        else:
            Overdue_Current_PLBL.append(
                sum(grp_list_oa_PLBL)/sum(grp_list_cb_PLBL))

        if (grp_slice['overdueAmount'][i] == 'unknown') or (grp_slice['currentBalance'][i] == 'unknown') or (sum(grp_list_cb_RL) == 0):
            Overdue_Current_RL.append('unknown')
        else:
            Overdue_Current_RL.append(
                sum(grp_list_oa_RL)/sum(grp_list_cb_RL))

        if (grp_slice['overdueAmount'][i] == 'unknown') or (grp_slice['currentBalance'][i] == 'unknown') or (sum(grp_list_cb_SCC) == 0):
            Overdue_Current_SCC.append('unknown')
        else:
            Overdue_Current_SCC.append(
                sum(grp_list_oa_SCC)/sum(grp_list_cb_SCC))

        if (grp_slice['overdueAmount'][i] == 'unknown') or (grp_slice['currentBalance'][i] == 'unknown') or (sum(grp_list_cb_SEL) == 0):
            Overdue_Current_SEL.append('unknown')
        else:
            Overdue_Current_SEL.append(
                sum(grp_list_oa_SEL)/sum(grp_list_cb_SEL))

df['Overdue_Current_AL'] = pd.Series(
    Overdue_Current_AL).values
df['Overdue_Current_BL'] = pd.Series(
    Overdue_Current_BL).values
df['Overdue_Current_CC'] = pd.Series(
    Overdue_Current_CC).values
df['Overdue_Current_CD'] = pd.Series(
    Overdue_Current_CD).values
df['Overdue_Current_CV'] = pd.Series(
    Overdue_Current_CV).values
df['Overdue_Current_GL'] = pd.Series(
    Overdue_Current_GL).values
df['Overdue_Current_HL'] = pd.Series(
    Overdue_Current_HL).values
df['Overdue_Current_LAS'] = pd.Series(
    Overdue_Current_LAS).values
df['Overdue_Current_MFBL'] = pd.Series(
    Overdue_Current_MFBL).values
df['Overdue_Current_MFHL'] = pd.Series(
    Overdue_Current_MFHL).values
df['Overdue_Current_MFOT'] = pd.Series(
    Overdue_Current_MFOT).values
df['Overdue_Current_OTH'] = pd.Series(
    Overdue_Current_OTH).values
df['Overdue_Current_PL'] = pd.Series(
    Overdue_Current_PL).values
df['Overdue_Current_PLBL'] = pd.Series(
    Overdue_Current_PLBL).values
df['Overdue_Current_RL'] = pd.Series(
    Overdue_Current_RL).values
df['Overdue_Current_SCC'] = pd.Series(
    Overdue_Current_SCC).values
df['Overdue_Current_SEL'] = pd.Series(
    Overdue_Current_SEL).values

print("%s seconds" % (time.time() - start_time))
# Out:
# 1.3298571109771729 seconds

# %% [raw]
# grp_list_oa_CD

# %% [raw]
# a = df[['ID','accountType','Overdue_Current_AL','overdueAmount','currentBalance']]
# a.head(60)

# %% [markdown]
# <a id='Overdue_Disbursed'></a>
# ### Code for Overdue_Disbursed

# %% [markdown]
# - Ratio of overdue amt by disbursed amt

# %% [markdown]
# **Disbursed Amount** -> Amount paid out to run a business, cash expenditures, dividend payments, or the amounts that a lawyer might have to pay out on a person's behalf in connection with a transaction.

# %%
Overdue_Disbursed = list()

for x in range(0, df.shape[0]):
    if (df['overdueAmount'][x]=='unknown') or (df['sanctionAmount'][x]=='unknown') or (df['sanctionAmount'][x]==0):
        Overdue_Disbursed.append('unknown')
    else:
        Overdue_Disbursed.append(float(df['overdueAmount'][x])/float(df['sanctionAmount'][x]))

df['Overdue_Disbursed'] = pd.Series(Overdue_Disbursed).values

# %% [raw]
# a = df[['ID','Overdue_Disbursed','overdueAmount','sanctionAmount']]
# a.head(60)

# %% [markdown]
# ### Code for Overdue_Disbursed_P
# - Ratio of overdue amt by disbursed amt per product

# %%
start_time = time.time()  # You can use time.clock() also

Overdue_Disbursed_AL = list()
Overdue_Disbursed_BL = list()
Overdue_Disbursed_CC = list()
Overdue_Disbursed_CD = list()
Overdue_Disbursed_CV = list()
Overdue_Disbursed_GL = list()
Overdue_Disbursed_HL = list()
Overdue_Disbursed_LAS = list()
Overdue_Disbursed_MFBL = list()
Overdue_Disbursed_MFHL = list()
Overdue_Disbursed_MFOT = list()
Overdue_Disbursed_OTH = list()
Overdue_Disbursed_PL = list()
Overdue_Disbursed_PLBL = list()
Overdue_Disbursed_RL = list()
Overdue_Disbursed_SCC = list()
Overdue_Disbursed_SEL = list()

grp_list_oa_AL = list()
grp_list_oa_BL = list()
grp_list_oa_CC = list()
grp_list_oa_CD = list()
grp_list_oa_CV = list()
grp_list_oa_GL = list()
grp_list_oa_HL = list()
grp_list_oa_LAS = list()
grp_list_oa_MFBL = list()
grp_list_oa_MFHL = list()
grp_list_oa_MFOT = list()
grp_list_oa_OTH = list()
grp_list_oa_PL = list()
grp_list_oa_PLBL = list()
grp_list_oa_RL = list()
grp_list_oa_SCC = list()
grp_list_oa_SEL = list()

grp_list_da_AL = list()
grp_list_da_BL = list()
grp_list_da_CC = list()
grp_list_da_CD = list()
grp_list_da_CV = list()
grp_list_da_GL = list()
grp_list_da_HL = list()
grp_list_da_LAS = list()
grp_list_da_MFBL = list()
grp_list_da_MFHL = list()
grp_list_da_MFOT = list()
grp_list_da_OTH = list()
grp_list_da_PL = list()
grp_list_da_PLBL = list()
grp_list_da_RL = list()
grp_list_da_SCC = list()
grp_list_da_SEL = list()

grp_oa_AL = 0
grp_oa_BL = 0
grp_oa_CC = 0
grp_oa_CD = 0
grp_oa_CV = 0
grp_oa_GL = 0
grp_oa_HL = 0
grp_oa_LAS = 0
grp_oa_MFBL = 0
grp_oa_MFHL = 0
grp_oa_MFOT = 0
grp_oa_OTH = 0
grp_oa_PL = 0
grp_oa_PLBL = 0
grp_oa_RL = 0
grp_oa_SCC = 0
grp_oa_SEL = 0

grp_da_AL = 0
grp_da_BL = 0
grp_da_CC = 0
grp_da_CD = 0
grp_da_CV = 0
grp_da_GL = 0
grp_da_HL = 0
grp_da_LAS = 0
grp_da_MFBL = 0
grp_da_MFHL = 0
grp_da_MFOT = 0
grp_da_OTH = 0
grp_da_PL = 0
grp_da_PLBL = 0
grp_da_RL = 0
grp_da_SCC = 0
grp_da_SEL = 0

grp_df = df.groupby('ID')

for x in range(0, len(unq_id_list)):
    grp_slice = grp_df.get_group(unq_id_list[x])
    # print(grp_slice)
    grp_slice.reset_index(drop=True, inplace=True)
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['overdueAmount'][i] == 'unknown') or (grp_slice['sanctionAmount'][i] == 'unknown') or (grp_slice['sanctionAmount'][i] == 0):
            continue
        elif (grp_slice['accountType'][i] == 'AL'):
            grp_oa_AL = float(grp_slice['overdueAmount'][i])
            grp_da_AL = float(grp_slice['sanctionAmount'][i])
        elif (grp_slice['accountType'][i] == 'BL'):
            grp_oa_BL = float(grp_slice['overdueAmount'][i])
            grp_da_BL = float(grp_slice['sanctionAmount'][i])
        elif (grp_slice['accountType'][i] == 'CC'):
            grp_oa_CC = float(grp_slice['overdueAmount'][i])
            grp_da_CC = float(grp_slice['sanctionAmount'][i])
        elif (grp_slice['accountType'][i] == 'CD'):
            grp_oa_CD = float(grp_slice['overdueAmount'][i])
            grp_da_CD = float(grp_slice['sanctionAmount'][i])
        elif (grp_slice['accountType'][i] == 'CV'):
            grp_oa_CV = float(grp_slice['overdueAmount'][i])
            grp_da_CV = float(grp_slice['sanctionAmount'][i])
        elif (grp_slice['accountType'][i] == 'GL'):
            grp_oa_GL = float(grp_slice['overdueAmount'][i])
            grp_da_GL = float(grp_slice['sanctionAmount'][i])
        elif (grp_slice['accountType'][i] == 'HL'):
            grp_oa_HL = float(grp_slice['overdueAmount'][i])
            grp_da_HL = float(grp_slice['sanctionAmount'][i])
        elif (grp_slice['accountType'][i] == 'LAS'):
            grp_oa_LAS = float(grp_slice['overdueAmount'][i])
            grp_da_LAS = float(grp_slice['sanctionAmount'][i])
        elif (grp_slice['accountType'][i] == 'MFBL'):
            grp_oa_MFBL = float(grp_slice['overdueAmount'][i])
            grp_da_MFBL = float(grp_slice['sanctionAmount'][i])
        elif (grp_slice['accountType'][i] == 'MFHL'):
            grp_oa_MFHL = float(grp_slice['overdueAmount'][i])
            grp_da_MFHL = float(grp_slice['sanctionAmount'][i])
        elif (grp_slice['accountType'][i] == 'MFOT'):
            grp_oa_MFOT = float(grp_slice['overdueAmount'][i])
            grp_da_MFOT = float(grp_slice['sanctionAmount'][i])
        elif (grp_slice['accountType'][i] == 'OTH'):
            grp_oa_OTH = float(grp_slice['overdueAmount'][i])
            grp_da_OTH = float(grp_slice['sanctionAmount'][i])
        elif (grp_slice['accountType'][i] == 'PL'):
            grp_oa_PL = float(grp_slice['overdueAmount'][i])
            grp_da_PL = float(grp_slice['sanctionAmount'][i])
        elif (grp_slice['accountType'][i] == 'PLBL'):
            grp_oa_PLBL = float(grp_slice['overdueAmount'][i])
            grp_da_PLBL = float(grp_slice['sanctionAmount'][i])
        elif (grp_slice['accountType'][i] == 'RL'):
            grp_oa_RL = float(grp_slice['overdueAmount'][i])
            grp_da_RL = float(grp_slice['sanctionAmount'][i])
        elif (grp_slice['accountType'][i] == 'SCC'):
            grp_oa_SCC = float(grp_slice['overdueAmount'][i])
            grp_da_SCC = float(grp_slice['sanctionAmount'][i])
        elif (grp_slice['accountType'][i] == 'SEL'):
            grp_oa_SEL = float(grp_slice['overdueAmount'][i])
            grp_da_SEL = float(grp_slice['sanctionAmount'][i])

    grp_list_oa_AL.append(grp_oa_AL)
    grp_list_oa_BL.append(grp_oa_BL)
    grp_list_oa_CC.append(grp_oa_CC)
    grp_list_oa_CD.append(grp_oa_CD)
    grp_list_oa_CV.append(grp_oa_CV)
    grp_list_oa_GL.append(grp_oa_GL)
    grp_list_oa_HL.append(grp_oa_HL)
    grp_list_oa_LAS.append(grp_oa_LAS)
    grp_list_oa_MFBL.append(grp_oa_MFBL)
    grp_list_oa_MFHL.append(grp_oa_MFHL)
    grp_list_oa_MFOT.append(grp_oa_MFOT)
    grp_list_oa_OTH.append(grp_oa_OTH)
    grp_list_oa_PL.append(grp_oa_PL)
    grp_list_oa_PLBL.append(grp_oa_PLBL)
    grp_list_oa_RL.append(grp_oa_RL)
    grp_list_oa_SCC.append(grp_oa_SCC)
    grp_list_oa_SEL.append(grp_oa_SEL)

    grp_list_da_AL.append(grp_da_AL)
    grp_list_da_BL.append(grp_da_BL)
    grp_list_da_CC.append(grp_da_CC)
    grp_list_da_CD.append(grp_da_CD)
    grp_list_da_CV.append(grp_da_CV)
    grp_list_da_GL.append(grp_da_GL)
    grp_list_da_HL.append(grp_da_HL)
    grp_list_da_LAS.append(grp_da_LAS)
    grp_list_da_MFBL.append(grp_da_MFBL)
    grp_list_da_MFHL.append(grp_da_MFHL)
    grp_list_da_MFOT.append(grp_da_MFOT)
    grp_list_da_OTH.append(grp_da_OTH)
    grp_list_da_PL.append(grp_da_PL)
    grp_list_da_PLBL.append(grp_da_PLBL)
    grp_list_da_RL.append(grp_da_RL)
    grp_list_da_SCC.append(grp_da_SCC)
    grp_list_da_SEL.append(grp_da_SEL)

    grp_oa_AL = 0
    grp_oa_BL = 0
    grp_oa_CC = 0
    grp_oa_CD = 0
    grp_oa_CV = 0
    grp_oa_GL = 0
    grp_oa_HL = 0
    grp_oa_LAS = 0
    grp_oa_MFBL = 0
    grp_oa_MFHL = 0
    grp_oa_MFOT = 0
    grp_oa_OTH = 0
    grp_oa_PL = 0
    grp_oa_PLBL = 0
    grp_oa_RL = 0
    grp_oa_SCC = 0
    grp_oa_SEL = 0

    grp_da_BL = 0
    grp_da_CC = 0
    grp_da_CD = 0
    grp_da_CV = 0
    grp_da_GL = 0
    grp_da_HL = 0
    grp_da_LAS = 0
    grp_da_MFBL = 0
    grp_da_MFHL = 0
    grp_da_MFOT = 0
    grp_da_OTH = 0
    grp_da_PL = 0
    grp_da_PLBL = 0
    grp_da_RL = 0
    grp_da_SCC = 0
    grp_da_SEL = 0

    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['overdueAmount'][i] == 'unknown') or (grp_slice['sanctionAmount'][i] == 'unknown') or (sum(grp_list_da_AL) == 0):
            Overdue_Disbursed_AL.append('unknown')
        else:
            Overdue_Disbursed_AL.append(
                sum(grp_list_oa_AL)/sum(grp_list_da_AL))

        if (grp_slice['overdueAmount'][i] == 'unknown') or (grp_slice['sanctionAmount'][i] == 'unknown') or (sum(grp_list_da_BL) == 0):
            Overdue_Disbursed_BL.append('unknown')
        else:
            Overdue_Disbursed_BL.append(
                sum(grp_list_oa_BL)/sum(grp_list_da_BL))

        if (grp_slice['overdueAmount'][i] == 'unknown') or (grp_slice['sanctionAmount'][i] == 'unknown') or (sum(grp_list_da_CC) == 0):
            Overdue_Disbursed_CC.append('unknown')
        else:
            Overdue_Disbursed_CC.append(
                sum(grp_list_oa_CC)/sum(grp_list_da_CC))

        if (grp_slice['overdueAmount'][i] == 'unknown') or (grp_slice['sanctionAmount'][i] == 'unknown') or (sum(grp_list_da_CD) == 0):
            Overdue_Disbursed_CD.append('unknown')
        else:
            Overdue_Disbursed_CD.append(
                sum(grp_list_oa_CD)/sum(grp_list_da_CD))

        if (grp_slice['overdueAmount'][i] == 'unknown') or (grp_slice['sanctionAmount'][i] == 'unknown') or (sum(grp_list_da_CV) == 0):
            Overdue_Disbursed_CV.append('unknown')
        else:
            Overdue_Disbursed_CV.append(
                sum(grp_list_oa_CV)/sum(grp_list_da_CV))

        if (grp_slice['overdueAmount'][i] == 'unknown') or (grp_slice['sanctionAmount'][i] == 'unknown') or (sum(grp_list_da_GL) == 0):
            Overdue_Disbursed_GL.append('unknown')
        else:
            Overdue_Disbursed_GL.append(
                sum(grp_list_oa_GL)/sum(grp_list_da_GL))

        if (grp_slice['overdueAmount'][i] == 'unknown') or (grp_slice['sanctionAmount'][i] == 'unknown') or (sum(grp_list_da_HL) == 0):
            Overdue_Disbursed_HL.append('unknown')
        else:
            Overdue_Disbursed_HL.append(
                sum(grp_list_oa_HL)/sum(grp_list_da_HL))

        if (grp_slice['overdueAmount'][i] == 'unknown') or (grp_slice['sanctionAmount'][i] == 'unknown') or (sum(grp_list_da_LAS) == 0):
            Overdue_Disbursed_LAS.append('unknown')
        else:
            Overdue_Disbursed_LAS.append(
                sum(grp_list_oa_LAS)/sum(grp_list_da_LAS))

        if (grp_slice['overdueAmount'][i] == 'unknown') or (grp_slice['sanctionAmount'][i] == 'unknown') or (sum(grp_list_da_MFBL) == 0):
            Overdue_Disbursed_MFBL.append('unknown')
        else:
            Overdue_Disbursed_MFBL.append(
                sum(grp_list_oa_MFBL)/sum(grp_list_da_MFBL))

        if (grp_slice['overdueAmount'][i] == 'unknown') or (grp_slice['sanctionAmount'][i] == 'unknown') or (sum(grp_list_da_MFHL) == 0):
            Overdue_Disbursed_MFHL.append('unknown')
        else:
            Overdue_Disbursed_MFHL.append(
                sum(grp_list_oa_MFHL)/sum(grp_list_da_MFHL))

        if (grp_slice['overdueAmount'][i] == 'unknown') or (grp_slice['sanctionAmount'][i] == 'unknown') or (sum(grp_list_da_MFOT) == 0):
            Overdue_Disbursed_MFOT.append('unknown')
        else:
            Overdue_Disbursed_MFOT.append(
                sum(grp_list_oa_MFOT)/sum(grp_list_da_MFOT))

        if (grp_slice['overdueAmount'][i] == 'unknown') or (grp_slice['sanctionAmount'][i] == 'unknown') or (sum(grp_list_da_OTH) == 0):
            Overdue_Disbursed_OTH.append('unknown')
        else:
            Overdue_Disbursed_OTH.append(
                sum(grp_list_oa_OTH)/sum(grp_list_da_OTH))

        if (grp_slice['overdueAmount'][i] == 'unknown') or (grp_slice['sanctionAmount'][i] == 'unknown') or (sum(grp_list_da_PL) == 0):
            Overdue_Disbursed_PL.append('unknown')
        else:
            Overdue_Disbursed_PL.append(
                sum(grp_list_oa_PL)/sum(grp_list_da_PL))

        if (grp_slice['overdueAmount'][i] == 'unknown') or (grp_slice['sanctionAmount'][i] == 'unknown') or (sum(grp_list_da_PLBL) == 0):
            Overdue_Disbursed_PLBL.append('unknown')
        else:
            Overdue_Disbursed_PLBL.append(
                sum(grp_list_oa_PLBL)/sum(grp_list_da_PLBL))

        if (grp_slice['overdueAmount'][i] == 'unknown') or (grp_slice['sanctionAmount'][i] == 'unknown') or (sum(grp_list_da_RL) == 0):
            Overdue_Disbursed_RL.append('unknown')
        else:
            Overdue_Disbursed_RL.append(
                sum(grp_list_oa_RL)/sum(grp_list_da_RL))

        if (grp_slice['overdueAmount'][i] == 'unknown') or (grp_slice['sanctionAmount'][i] == 'unknown') or (sum(grp_list_da_SCC) == 0):
            Overdue_Disbursed_SCC.append('unknown')
        else:
            Overdue_Disbursed_SCC.append(
                sum(grp_list_oa_SCC)/sum(grp_list_da_SCC))

        if (grp_slice['overdueAmount'][i] == 'unknown') or (grp_slice['sanctionAmount'][i] == 'unknown') or (sum(grp_list_da_SEL) == 0):
            Overdue_Disbursed_SEL.append('unknown')
        else:
            Overdue_Disbursed_SEL.append(
                sum(grp_list_oa_SEL)/sum(grp_list_da_SEL))

df['Overdue_Disbursed_AL'] = pd.Series(
    Overdue_Disbursed_AL).values
df['Overdue_Disbursed_BL'] = pd.Series(
    Overdue_Disbursed_BL).values
df['Overdue_Disbursed_CC'] = pd.Series(
    Overdue_Disbursed_CC).values
df['Overdue_Disbursed_CD'] = pd.Series(
    Overdue_Disbursed_CD).values
df['Overdue_Disbursed_CV'] = pd.Series(
    Overdue_Disbursed_CV).values
df['Overdue_Disbursed_GL'] = pd.Series(
    Overdue_Disbursed_GL).values
df['Overdue_Disbursed_HL'] = pd.Series(
    Overdue_Disbursed_HL).values
df['Overdue_Disbursed_LAS'] = pd.Series(
    Overdue_Disbursed_LAS).values
df['Overdue_Disbursed_MFBL'] = pd.Series(
    Overdue_Disbursed_MFBL).values
df['Overdue_Disbursed_MFHL'] = pd.Series(
    Overdue_Disbursed_MFHL).values
df['Overdue_Disbursed_MFOT'] = pd.Series(
    Overdue_Disbursed_MFOT).values
df['Overdue_Disbursed_OTH'] = pd.Series(
    Overdue_Disbursed_OTH).values
df['Overdue_Disbursed_PL'] = pd.Series(
    Overdue_Disbursed_PL).values
df['Overdue_Disbursed_PLBL'] = pd.Series(
    Overdue_Disbursed_PLBL).values
df['Overdue_Disbursed_RL'] = pd.Series(
    Overdue_Disbursed_RL).values
df['Overdue_Disbursed_SCC'] = pd.Series(
    Overdue_Disbursed_SCC).values
df['Overdue_Disbursed_SEL'] = pd.Series(
    Overdue_Disbursed_SEL).values

print("%s seconds" % (time.time() - start_time))
# Out:
# 1.1719107627868652 seconds

# %% [raw]
# a = df[['ID','accountType','Overdue_Disbursed_AL','overdueAmount','sanctionAmount']]
# a.head(60)

# %% [markdown]
# <a id='dateClosed_lt_PHED_wo'></a>
# ### Code for dateClosed_lt_PHED_wo

# %%
# dateClosed_lt_PHED==1 
# and Written-off and Settled Status is not null and not equals (00,01)

dateClosed_lt_PHED_wo = list()

for x in range(0, df.shape[0]):
    if (df['dateClosed_lt_PHED'][x] == 1) and (df['writeOff'][x] == 1) and (df['writtenOffAndSettledStatus'][x] != 'unknown'):
        dateClosed_lt_PHED_wo.append(1)
    elif (df['writtenOffAndSettledStatus'][x] == 'unknown'):
        dateClosed_lt_PHED_wo.append('unknown')
    else:
        dateClosed_lt_PHED_wo.append(0)
        
df['dateClosed_lt_PHED_wo'] = pd.Series(dateClosed_lt_PHED_wo).values
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/envs/ml_env/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'writeOff'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-279-60f7eec4e5f4> in <module>
#       5
#       6 for x in range(0, df.shape[0]):
# ----> 7     if (df['dateClosed_lt_PHED'][x] == 1) and (df['writeOff'][x] == 1) and (df['writtenOffAndSettledStatus'][x] != 'unknown'):
#       8         dateClosed_lt_PHED_wo.append(1)
#       9     elif (df['writtenOffAndSettledStatus'][x] == 'unknown'):
#
# ~/anaconda3/envs/ml_env/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2900             if self.columns.nlevels > 1:
#    2901                 return self._getitem_multilevel(key)
# -> 2902             indexer = self.columns.get_loc(key)
#    2903             if is_integer(indexer):
#    2904                 indexer = [indexer]
#
# ~/anaconda3/envs/ml_env/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
# -> 2897                 raise KeyError(key) from err
#    2898
#    2899         if tolerance is not None:
#
# KeyError: 'writeOff'

# %%
df['dateClosed_lt_PHED_wo'].value_counts()

# %% [markdown]
# ### Code for dateClosed_lt_PHED_wo_CNT

# %% [markdown]
# Indicates count of accounts where Date Closed for the account is < PaymenT History End Date and Written-off and
# Settled Status is not null <br>
# Sum(dateClosed_lt_PHED_wo) for the application

# %%
dateClosed_lt_PHED_wo_CNT = list()
count_list = list()
count = 0

grp_df = df.groupby('ID')

for x in range(0, len(unq_id_list)):
    grp_slice = grp_df.get_group(unq_id_list[x])
    #print(grp_slice)
    grp_slice.reset_index(drop=True, inplace=True)
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['dateClosed_lt_PHED_wo'][i]==1) or (grp_slice['dateClosed_lt_PHED_wo'][i]==0):
            count = count + grp_slice['dateClosed_lt_PHED_wo'][i]
        else:
            continue
    count_list.append(count)
    count = 0
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['dateClosed_lt_PHED_wo'][i]==1) or (grp_slice['dateClosed_lt_PHED_wo'][i]==0):
            dateClosed_lt_PHED_wo_CNT.append(count_list[x])
        else:
            dateClosed_lt_PHED_wo_CNT.append('unknown')
            
df['dateClosed_lt_PHED_wo_CNT'] = pd.Series(dateClosed_lt_PHED_wo_CNT).values

# %%
df['dateClosed_lt_PHED_wo_CNT'].value_counts()

# %% [markdown]
# <a id='dateClosed_lt_PHED_suit'></a>
# ### Code for dateClosed_lt_PHED_suit

# %%
df['suitFiledOrWilfulDefault'].fillna('unknown', inplace=True)

# %%
df['suitFiledOrWilfulDefault'].value_counts()

# %%
# dateClosed_lt_PHED==1 and WSuit Filed / Wilful
# Indicates whether Date Closed for the account is < PaymenT History End Date and Suit Filed / Wilful

dateClosed_lt_PHED_suit = list()

for x in range(0, df.shape[0]):
    if (df['dateClosed_lt_PHED'][x] == 1) and (df['suitFiledOrWilfulDefault'][x] == 1):
        dateClosed_lt_PHED_suit.append(1)
    elif (df['suitFiledOrWilfulDefault'][x] == 'unknown'):
        dateClosed_lt_PHED_suit.append('unknown')
    else:
        dateClosed_lt_PHED_suit.append(0)

df['dateClosed_lt_PHED_suit'] = pd.Series(dateClosed_lt_PHED_suit).values

# %%
df['dateClosed_lt_PHED_suit'].value_counts()

# %% [markdown]
# ### Code for dateClosed_lt_PHED_suit_CNT

# %% [markdown]
# Indicates count of accounts where Date Closed for the account is < PaymenT History End Date and Suit Filed / Wilful
# Default is not null <br>
# Sum(dateClosed_lt_PHED_suit) for the application

# %%
dateClosed_lt_PHED_suit_CNT = list()
count_list = list()
count = 0

grp_df = df.groupby('ID')

for x in range(0, len(unq_id_list)):
    grp_slice = grp_df.get_group(unq_id_list[x])
    #print(grp_slice)
    grp_slice.reset_index(drop=True, inplace=True)
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['dateClosed_lt_PHED_suit'][i]==1) or (grp_slice['dateClosed_lt_PHED_suit'][i]==0):
            count = count + grp_slice['dateClosed_lt_PHED_suit'][i]
        else:
            continue
    count_list.append(count)
    count = 0
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['dateClosed_lt_PHED_suit'][i]==1) or (grp_slice['dateClosed_lt_PHED_suit'][i]==0):
            dateClosed_lt_PHED_suit_CNT.append(count_list[x])
        else:
            dateClosed_lt_PHED_suit_CNT.append('unknown')
            
df['dateClosed_lt_PHED_suit_CNT'] = pd.Series(dateClosed_lt_PHED_suit_CNT).values

# %%
df['dateClosed_lt_PHED_suit_CNT'].value_counts()

# %% [markdown]
# <a id='dateClosed_lt_PHED_PH1M'></a>
# ### Code for dateClosed_lt_PHED_PH1M

# %% [markdown]
# - Indicates whether Date Closed for the account is < PaymenT History End Date and difference between Payment History End Date & Payment History Start Date = 1 month
# - dateClosed_lt_PHED==1 & |(PHED-PHSD)|=1 month

# %% [raw]
# #@delayed
# def numOfDays(date1, date2):
#     return (date2-date1).days
#
# # Driver program
# # YYMMDD
# #date1 = date(2018, 12, 13)
# #date2 = date(2019, 2, 25)
# #print(numOfDays(date1, date2), "days")

# %%
# PHED, PHSD > DDMMYYYY

month_diff = list()

for x in range(0, df.shape[0]):
    if pd.isnull(df['PHSD'][x]) or pd.isnull(df['PHED'][x]):
        month_diff.append('unknown')
    else:
        date1 = df['PHED'][x]
        date2 = df['PHSD'][x]   
        mo_diff = diff_month(date2, date1)
        month_diff.append(mo_diff)                                         

df['month_diff'] = pd.Series(month_diff).values

# %%
# Indicates whether Date Closed for the account is < PaymenT History End Date 
# and difference between Payment History End Date & Payment History Start Date = 1 month

# dateClosed_lt_PHED==1 & |(PHSD-PHED)|=1 month

dateClosed_lt_PHED_PH1M = list()

for x in range(0, df.shape[0]):
    if df['month_diff'][x]=='unknown':
        dateClosed_lt_PHED_PH1M.append('unknown')
    elif (df['month_diff'][x] == 1) and (df['dateClosed_lt_PHED'][x] == 1):
        dateClosed_lt_PHED_PH1M.append(1)
    else:
        dateClosed_lt_PHED_PH1M.append(0)

df['dateClosed_lt_PHED_PH1M'] = pd.Series(dateClosed_lt_PHED_PH1M).values

#df.drop(['month_diff'], axis=1, inplace=True)

# %%
df['dateClosed_lt_PHED_PH1M'].value_counts()

# %% [raw]
# df[['month_diff', 'dateClosed_lt_PHED']]

# %% [markdown]
# ### Code for dateClosed_lt_PHED_PH1M_CNT

# %% [markdown]
# - Indicates count of accounts where Date Closed for the account is < PaymenT History End Date and difference between Payment History End Date & Payment History Start Date = 1 month <br>
# - Sum(dateClosed_lt_PHED_PH1M) for the application

# %%
dateClosed_lt_PHED_PH1M_CNT = list()
count_list = list()
count = 0

grp_df = df.groupby('ID')

for x in range(0, len(unq_id_list)):
    grp_slice = grp_df.get_group(unq_id_list[x])
    #print(grp_slice)
    grp_slice.reset_index(drop=True, inplace=True)
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['dateClosed_lt_PHED_PH1M'][i]==1) or (grp_slice['dateClosed_lt_PHED_PH1M'][i]==0):
            count = count + grp_slice['dateClosed_lt_PHED_PH1M'][i]
        else:
            continue
    count_list.append(count)
    count = 0
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['dateClosed_lt_PHED_PH1M'][i]==1) or (grp_slice['dateClosed_lt_PHED_PH1M'][i]==0):
            dateClosed_lt_PHED_PH1M_CNT.append(count_list[x])
        else:
            dateClosed_lt_PHED_PH1M_CNT.append('unknown')
            
df['dateClosed_lt_PHED_PH1M_CNT'] = pd.Series(dateClosed_lt_PHED_PH1M_CNT).values

# %%
df['dateClosed_lt_PHED_PH1M_CNT'].value_counts()

# %% [markdown]
# <a id='dateClosed_lt_PHED_restruct'></a>
# ### Code for dateClosed_lt_PHED_restruct

# %%
# Indicates whether Date Closed for the account is < PaymenT History End Date 
# and Written-off and Settled Status is not null and equals (00,01)

# dateClosed_lt_PHED==1 and Written-off and Settled Status is not null and equals (00,01)

dateClosed_lt_PHED_restruct = list()

for x in range(0, df.shape[0]):
    if (df['restructured'][x]==1) and (df['dateClosed_lt_PHED'][x]==1):
        dateClosed_lt_PHED_restruct.append(1)
    elif (df['restructured'][x]=='unknown') or (df['dateClosed_lt_PHED'][x]=='unknown'):
        dateClosed_lt_PHED_restruct.append('unknown')
    else:
        dateClosed_lt_PHED_restruct.append(0)

df['dateClosed_lt_PHED_restruct'] = pd.Series(dateClosed_lt_PHED_restruct).values

# %%
df['dateClosed_lt_PHED_restruct'].value_counts()

# %% [markdown]
# ### Code for dateClosed_lt_PHED_restruct_CNT

# %% [markdown]
# Indicates count of accounts where Date Closed for the account is < PaymenT History End Date and Written-off and
# Settled Status is not null and equals (00,01) <br>
# Sum(dateClosed_lt_PHED_restruct) for the application

# %%
dateClosed_lt_PHED_restruct_CNT = list()
count_list = list()
count = 0

grp_df = df.groupby('ID')

for x in range(0, len(unq_id_list)):
    grp_slice = grp_df.get_group(unq_id_list[x])
    #print(grp_slice)
    grp_slice.reset_index(drop=True, inplace=True)
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['dateClosed_lt_PHED_restruct'][i]==1) or (grp_slice['dateClosed_lt_PHED_restruct'][i]==0):
            count = count + grp_slice['dateClosed_lt_PHED_restruct'][i]
        else:
            continue
    count_list.append(count)
    count = 0
    for i in range(0, grp_slice.shape[0]):
        if (grp_slice['dateClosed_lt_PHED_restruct'][i]==1) or (grp_slice['dateClosed_lt_PHED_restruct'][i]==0):
            dateClosed_lt_PHED_restruct_CNT.append(count_list[x])
        else:
            dateClosed_lt_PHED_restruct_CNT.append('unknown')
            
df['dateClosed_lt_PHED_restruct_CNT'] = pd.Series(dateClosed_lt_PHED_restruct_CNT).values

# %%
df['dateClosed_lt_PHED_restruct_CNT'].value_counts()

# %%
print("%s seconds" % (time.time() - start_time_nb))

# %%
df.shape
